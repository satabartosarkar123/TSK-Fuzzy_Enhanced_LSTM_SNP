# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import tensorflow as tf
import time as _timer_module

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 23417

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-23 15:34:18

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn_1 (RNN)                 (1, 8)                    352
#
#  dense_1 (Dense)             (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=1, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=1)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=1)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx]])

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 5.0% (lambda=0.05, sigma=5.264280)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3647.61484228 3625.27213803 3637.40961369 3628.5176553  3605.76735112]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=3798.6476, Expected=3797.1395
# Month=2, Predicted=3798.0911, Expected=3793.2399
# Month=3, Predicted=3794.1851, Expected=3762.5698
# Month=4, Predicted=3763.1363, Expected=3758.2863
# Month=5, Predicted=3758.7329, Expected=3757.3371
# Month=6, Predicted=3754.3998, Expected=3745.3391
# Month=7, Predicted=3742.8911, Expected=3767.9815
# Month=8, Predicted=3766.5920, Expected=3747.5162
# Month=9, Predicted=3746.7156, Expected=3773.4874
# Month=10, Predicted=3772.7330, Expected=3755.8279
# Month=11, Predicted=3754.9231, Expected=3784.3960
# Month=12, Predicted=3782.8780, Expected=3778.6584
# Month=13, Predicted=3779.1715, Expected=3759.5576
# Month=14, Predicted=3759.5779, Expected=3748.6813
# Month=15, Predicted=3748.6174, Expected=3749.2391
# Month=16, Predicted=3747.0302, Expected=3773.4998
# Month=17, Predicted=3772.7060, Expected=3843.5607
# Month=18, Predicted=3849.5859, Expected=3839.2938
# Month=19, Predicted=3846.3671, Expected=3883.1319
# Month=20, Predicted=3881.8693, Expected=3892.3624
# Month=21, Predicted=3896.5585, Expected=3921.8319
# Month=22, Predicted=3921.7078, Expected=3924.1716
# Month=23, Predicted=3926.0408, Expected=3906.4352
# Month=24, Predicted=3907.3267, Expected=3878.0016
# Month=25, Predicted=3879.1688, Expected=3889.9509
# Month=26, Predicted=3889.0243, Expected=3905.6694
# Month=27, Predicted=3906.2161, Expected=3882.2746
# Month=28, Predicted=3881.0326, Expected=3910.3364
# Month=29, Predicted=3910.0828, Expected=3879.0779
# Month=30, Predicted=3876.7638, Expected=3855.1204
# Month=31, Predicted=3856.6228, Expected=3879.6866
# Month=32, Predicted=3876.8433, Expected=3877.9371
# Month=33, Predicted=3877.8070, Expected=3948.6073
# Month=34, Predicted=3946.9837, Expected=3931.6704
# Month=35, Predicted=3938.0075, Expected=3930.4313
# Month=36, Predicted=3933.6818, Expected=3877.5935
# Month=37, Predicted=3877.0937, Expected=3844.4713
# Month=38, Predicted=3846.9530, Expected=3834.6835
# Month=39, Predicted=3829.0547, Expected=3832.6883
# Month=40, Predicted=3827.6136, Expected=3856.5873
# Month=41, Predicted=3854.5138, Expected=3855.4412
# Month=42, Predicted=3855.8964, Expected=3884.1232
# Month=43, Predicted=3883.2601, Expected=3855.0539
# Month=44, Predicted=3855.3487, Expected=3837.8331
# Month=45, Predicted=3840.4404, Expected=3849.4326
# Month=46, Predicted=3846.8836, Expected=3802.0479
# Month=47, Predicted=3797.3971, Expected=3783.8403
# Month=48, Predicted=3785.6404, Expected=3776.3675
# Month=49, Predicted=3771.0139, Expected=3794.9716
# Month=50, Predicted=3791.9115, Expected=3821.5976
# Month=51, Predicted=3822.6796, Expected=3880.4856
# Month=52, Predicted=3883.4264, Expected=3883.3492
# Month=53, Predicted=3888.4868, Expected=3883.4838
# Month=54, Predicted=3885.1405, Expected=3921.2289
# Month=55, Predicted=3921.8166, Expected=3913.7237
# Month=56, Predicted=3915.8921, Expected=3917.2010
# Month=57, Predicted=3917.3995, Expected=3939.0971
# Month=58, Predicted=3939.4280, Expected=3912.4792
# Month=59, Predicted=3912.0055, Expected=3887.7219
# Month=60, Predicted=3889.8293, Expected=3853.9044
# Run 1 — RMSE: 26.309880, MSE: 692.209790, NMSE: 0.0030636206
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=3797.1306, Expected=3797.1395
# Month=2, Predicted=3798.2291, Expected=3793.2399
# Month=3, Predicted=3792.5897, Expected=3762.5698
# Month=4, Predicted=3761.1819, Expected=3758.2863
# Month=5, Predicted=3757.1659, Expected=3757.3371
# Month=6, Predicted=3755.7645, Expected=3745.3391
# Month=7, Predicted=3744.3739, Expected=3767.9815
# Month=8, Predicted=3767.4039, Expected=3747.5162
# Month=9, Predicted=3747.3733, Expected=3773.4874
# Month=10, Predicted=3773.2735, Expected=3755.8279
# Month=11, Predicted=3755.7011, Expected=3784.3960
# Month=12, Predicted=3783.9812, Expected=3778.6584
# Month=13, Predicted=3778.9286, Expected=3759.5576
# Month=14, Predicted=3758.9715, Expected=3748.6813
# Month=15, Predicted=3747.7907, Expected=3749.2391
# Month=16, Predicted=3748.0471, Expected=3773.4998
# Month=17, Predicted=3773.0828, Expected=3843.5607
# Month=18, Predicted=3846.4127, Expected=3839.2938
# Month=19, Predicted=3843.8296, Expected=3883.1319
# Month=20, Predicted=3883.0874, Expected=3892.3624
# Month=21, Predicted=3893.8434, Expected=3921.8319
# Month=22, Predicted=3920.7299, Expected=3924.1716
# Month=23, Predicted=3923.6102, Expected=3906.4352
# Month=24, Predicted=3904.2337, Expected=3878.0016
# Month=25, Predicted=3876.0292, Expected=3889.9509
# Month=26, Predicted=3888.3481, Expected=3905.6694
# Month=27, Predicted=3905.2225, Expected=3882.2746
# Month=28, Predicted=3881.9311, Expected=3910.3364
# Month=29, Predicted=3910.0887, Expected=3879.0779
# Month=30, Predicted=3878.6536, Expected=3855.1204
# Month=31, Predicted=3855.5638, Expected=3879.6866
# Month=32, Predicted=3878.7262, Expected=3877.9371
# Month=33, Predicted=3878.3180, Expected=3948.6073
# Month=34, Predicted=3949.7162, Expected=3931.6704
# Month=35, Predicted=3935.5238, Expected=3930.4313
# Month=36, Predicted=3930.6900, Expected=3877.5935
# Month=37, Predicted=3876.2261, Expected=3844.4713
# Month=38, Predicted=3845.0813, Expected=3834.6835
# Month=39, Predicted=3832.9459, Expected=3832.6883
# Month=40, Predicted=3831.1505, Expected=3856.5873
# Month=41, Predicted=3856.4948, Expected=3855.4412
# Month=42, Predicted=3856.4107, Expected=3884.1232
# Month=43, Predicted=3884.8289, Expected=3855.0539
# Month=44, Predicted=3855.1483, Expected=3837.8331
# Month=45, Predicted=3837.9971, Expected=3849.4326
# Month=46, Predicted=3847.9716, Expected=3802.0479
# Month=47, Predicted=3800.4717, Expected=3783.8403
# Month=48, Predicted=3784.6314, Expected=3776.3675
# Month=49, Predicted=3774.6123, Expected=3794.9716
# Month=50, Predicted=3794.2698, Expected=3821.5976
# Month=51, Predicted=3822.8658, Expected=3880.4856
# Month=52, Predicted=3883.8186, Expected=3883.3492
# Month=53, Predicted=3887.4258, Expected=3883.4838
# Month=54, Predicted=3883.4416, Expected=3921.2289
# Month=55, Predicted=3920.1222, Expected=3913.7237
# Month=56, Predicted=3913.7573, Expected=3917.2010
# Month=57, Predicted=3915.2354, Expected=3939.0971
# Month=58, Predicted=3937.4732, Expected=3912.4792
# Month=59, Predicted=3911.0058, Expected=3887.7219
# Month=60, Predicted=3886.6067, Expected=3853.9044
# Run 2 — RMSE: 25.985831, MSE: 675.263409, NMSE: 0.0030511948
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====
# RMSE: 26.147856 ± 0.162025
# MSE:  683.736599 ± 8.473191
# NMSE: 0.0030574077 ± 0.0000062129
#
# Best run: 2
#   RMSE: 25.985831
#   MSE:  675.263409
#   NMSE: 0.0030511948
# === Best Run Metrics ===
# RMSE: 25.985831
# MSE:  675.263409
# NMSE: 0.0030511948
#
# ================================================================================
# EVALUATING NOISE LEVEL: 10.0% (lambda=0.1, sigma=10.528560)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3650.22968456 3624.54427607 3640.81922737 3636.5353106  3604.53470224]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=3791.3387, Expected=3798.2790
# Month=2, Predicted=3794.5181, Expected=3793.4798
# Month=3, Predicted=3792.0053, Expected=3759.1396
# Month=4, Predicted=3761.6194, Expected=3769.5726
# Month=5, Predicted=3770.0113, Expected=3760.6743
# Month=6, Predicted=3758.6577, Expected=3734.6782
# Month=7, Predicted=3734.9515, Expected=3768.9631
# Month=8, Predicted=3766.9576, Expected=3744.0323
# Month=9, Predicted=3747.6330, Expected=3777.9749
# Month=10, Predicted=3774.3249, Expected=3751.6559
# Month=11, Predicted=3756.2941, Expected=3783.7920
# Month=12, Predicted=3780.5877, Expected=3781.3168
# Month=13, Predicted=3782.6234, Expected=3764.1152
# Month=14, Predicted=3763.9883, Expected=3742.3626
# Month=15, Predicted=3744.5669, Expected=3747.4782
# Month=16, Predicted=3747.6689, Expected=3770.9995
# Month=17, Predicted=3767.5842, Expected=3840.1214
# Month=18, Predicted=3833.0582, Expected=3848.5877
# Month=19, Predicted=3852.7200, Expected=3885.2639
# Month=20, Predicted=3873.1933, Expected=3885.7247
# Month=21, Predicted=3884.1345, Expected=3926.6638
# Month=22, Predicted=3915.5386, Expected=3935.3432
# Month=23, Predicted=3932.3232, Expected=3911.8704
# Month=24, Predicted=3909.0132, Expected=3870.0032
# Month=25, Predicted=3871.6266, Expected=3887.4017
# Month=26, Predicted=3886.2209, Expected=3912.3387
# Month=27, Predicted=3907.1127, Expected=3878.5493
# Month=28, Predicted=3881.2037, Expected=3912.6728
# Month=29, Predicted=3910.6556, Expected=3883.1558
# Month=30, Predicted=3886.8440, Expected=3850.2408
# Month=31, Predicted=3852.6064, Expected=3879.3733
# Month=32, Predicted=3879.4332, Expected=3860.8741
# Month=33, Predicted=3862.9666, Expected=3943.2147
# Month=34, Predicted=3932.7318, Expected=3930.3408
# Month=35, Predicted=3940.4384, Expected=3923.8626
# Month=36, Predicted=3920.1310, Expected=3886.1869
# Month=37, Predicted=3890.8985, Expected=3836.9427
# Month=38, Predicted=3842.8777, Expected=3832.3670
# Month=39, Predicted=3834.0447, Expected=3833.3765
# Month=40, Predicted=3830.2675, Expected=3864.1745
# Month=41, Predicted=3860.7671, Expected=3847.8824
# Month=42, Predicted=3853.3383, Expected=3890.2464
# Month=43, Predicted=3885.7661, Expected=3855.1077
# Month=44, Predicted=3863.4843, Expected=3832.6661
# Month=45, Predicted=3835.0868, Expected=3851.8653
# Month=46, Predicted=3851.6513, Expected=3803.0958
# Month=47, Predicted=3808.0104, Expected=3780.6806
# Month=48, Predicted=3783.5392, Expected=3776.7349
# Month=49, Predicted=3777.1590, Expected=3792.9432
# Month=50, Predicted=3791.0550, Expected=3822.1952
# Month=51, Predicted=3820.9559, Expected=3883.9713
# Month=52, Predicted=3878.7623, Expected=3891.6985
# Month=53, Predicted=3894.7798, Expected=3876.9676
# Month=54, Predicted=3874.5774, Expected=3932.4578
# Month=55, Predicted=3924.3137, Expected=3903.4473
# Month=56, Predicted=3907.7755, Expected=3916.4019
# Month=57, Predicted=3912.5465, Expected=3942.1941
# Month=58, Predicted=3936.8128, Expected=3913.9584
# Month=59, Predicted=3915.2847, Expected=3884.4439
# Month=60, Predicted=3885.5444, Expected=3852.8088
# Run 1 — RMSE: 30.468164, MSE: 928.309019, NMSE: 0.0042514442
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=3788.1954, Expected=3798.2790
# Month=2, Predicted=3794.9434, Expected=3793.4798
# Month=3, Predicted=3791.5858, Expected=3759.1396
# Month=4, Predicted=3761.8302, Expected=3769.5726
# Month=5, Predicted=3773.2272, Expected=3760.6743
# Month=6, Predicted=3761.8777, Expected=3734.6782
# Month=7, Predicted=3738.3339, Expected=3768.9631
# Month=8, Predicted=3770.4289, Expected=3744.0323
# Month=9, Predicted=3747.4195, Expected=3777.9749
# Month=10, Predicted=3778.6867, Expected=3751.6559
# Month=11, Predicted=3754.5845, Expected=3783.7920
# Month=12, Predicted=3784.6103, Expected=3781.3168
# Month=13, Predicted=3781.2775, Expected=3764.1152
# Month=14, Predicted=3765.4981, Expected=3742.3626
# Month=15, Predicted=3745.8380, Expected=3747.4782
# Month=16, Predicted=3750.2557, Expected=3770.9995
# Month=17, Predicted=3769.8745, Expected=3840.1214
# Month=18, Predicted=3834.2323, Expected=3848.5877
# Month=19, Predicted=3846.4299, Expected=3885.2639
# Month=20, Predicted=3878.1247, Expected=3885.7247
# Month=21, Predicted=3881.3652, Expected=3926.6638
# Month=22, Predicted=3919.8461, Expected=3935.3432
# Month=23, Predicted=3930.6110, Expected=3911.8704
# Month=24, Predicted=3910.8203, Expected=3870.0032
# Month=25, Predicted=3874.5628, Expected=3887.4017
# Month=26, Predicted=3891.5373, Expected=3912.3387
# Month=27, Predicted=3911.0311, Expected=3878.5493
# Month=28, Predicted=3882.1399, Expected=3912.6728
# Month=29, Predicted=3914.7395, Expected=3883.1558
# Month=30, Predicted=3886.4969, Expected=3850.2408
# Month=31, Predicted=3855.4274, Expected=3879.3733
# Month=32, Predicted=3881.4721, Expected=3860.8741
# Month=33, Predicted=3863.8323, Expected=3943.2147
# Month=34, Predicted=3938.3222, Expected=3930.3408
# Month=35, Predicted=3932.5341, Expected=3923.8626
# Month=36, Predicted=3923.4312, Expected=3886.1869
# Month=37, Predicted=3889.7049, Expected=3836.9427
# Month=38, Predicted=3844.2284, Expected=3832.3670
# Month=39, Predicted=3835.4596, Expected=3833.3765
# Month=40, Predicted=3832.6862, Expected=3864.1745
# Month=41, Predicted=3861.1877, Expected=3847.8824
# Month=42, Predicted=3850.1259, Expected=3890.2464
# Month=43, Predicted=3886.9833, Expected=3855.1077
# Month=44, Predicted=3858.3951, Expected=3832.6661
# Month=45, Predicted=3836.5520, Expected=3851.8653
# Month=46, Predicted=3852.1531, Expected=3803.0958
# Month=47, Predicted=3809.2063, Expected=3780.6806
# Month=48, Predicted=3783.2747, Expected=3776.7349
# Month=49, Predicted=3774.6105, Expected=3792.9432
# Month=50, Predicted=3787.9119, Expected=3822.1952
# Month=51, Predicted=3818.1120, Expected=3883.9713
# Month=52, Predicted=3876.6110, Expected=3891.6985
# Month=53, Predicted=3887.4820, Expected=3876.9676
# Month=54, Predicted=3872.6141, Expected=3932.4578
# Month=55, Predicted=3925.0350, Expected=3903.4473
# Month=56, Predicted=3902.7323, Expected=3916.4019
# Month=57, Predicted=3916.8766, Expected=3942.1941
# Month=58, Predicted=3937.8828, Expected=3913.9584
# Month=59, Predicted=3914.9707, Expected=3884.4439
# Month=60, Predicted=3888.9710, Expected=3852.8088
# Run 2 — RMSE: 30.831483, MSE: 950.580370, NMSE: 0.0043776867
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====
# RMSE: 30.649824 ± 0.181660
# MSE:  939.444694 ± 11.135676
# NMSE: 0.0043145654 ± 0.0000631212
#
# Best run: 1
#   RMSE: 30.468164
#   MSE:  928.309019
#   NMSE: 0.0042514442
# === Best Run Metrics ===
# RMSE: 30.468164
# MSE:  928.309019
# NMSE: 0.0042514442

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
print(f"Average run time per model (s / 4): {_NOTEBOOK_ELAPSED / 4:.2f} seconds")
print(f"Process ID: {os.getpid()}")
# Out:
# Total notebook execution time: 0h 1m 14.33s
# Total seconds: 74.33
