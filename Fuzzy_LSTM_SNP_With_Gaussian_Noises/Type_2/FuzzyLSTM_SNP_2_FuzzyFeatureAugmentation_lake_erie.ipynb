# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import tensorflow as tf
import time as _timer_module

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 25443

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-23 15:34:20

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=1, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=1)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=1)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx]])

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 5.0% (lambda=0.05, sigma=0.100521)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.81293026 14.63510152 15.15010637 16.52909665 16.90246264]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=13.2383, Expected=13.7840
# Month=2, Predicted=14.2967, Expected=13.7004
# Month=3, Predicted=14.4043, Expected=14.4363
# Month=4, Predicted=15.2225, Expected=15.1919
# Month=5, Predicted=15.5815, Expected=15.4445
# Month=6, Predicted=15.3890, Expected=15.7639
# Month=7, Predicted=15.4972, Expected=15.7700
# Month=8, Predicted=15.4599, Expected=15.2926
# Month=9, Predicted=14.7320, Expected=14.8003
# Month=10, Predicted=14.3043, Expected=13.4873
# Month=11, Predicted=12.9852, Expected=13.5947
# Month=12, Predicted=13.6048, Expected=14.5004
# Month=13, Predicted=14.8210, Expected=14.5004
# Month=14, Predicted=15.0078, Expected=14.5226
# Month=15, Predicted=15.3092, Expected=14.7779
# Month=16, Predicted=15.4141, Expected=15.7646
# Month=17, Predicted=16.1024, Expected=16.4780
# Month=18, Predicted=16.5331, Expected=16.5025
# Month=19, Predicted=16.2307, Expected=16.7567
# Month=20, Predicted=16.4431, Expected=16.3907
# Month=21, Predicted=15.9006, Expected=15.7981
# Month=22, Predicted=15.3182, Expected=15.4836
# Month=23, Predicted=15.2507, Expected=15.2106
# Month=24, Predicted=15.1879, Expected=15.5082
# Month=25, Predicted=15.8239, Expected=15.9457
# Month=26, Predicted=16.5638, Expected=16.3350
# Month=27, Predicted=17.1584, Expected=16.1521
# Month=28, Predicted=16.6768, Expected=16.8057
# Month=29, Predicted=17.0566, Expected=16.8329
# Month=30, Predicted=16.7502, Expected=17.3837
# Month=31, Predicted=17.1980, Expected=17.5349
# Month=32, Predicted=17.3689, Expected=17.4365
# Month=33, Predicted=17.0469, Expected=16.6359
# Month=34, Predicted=16.1904, Expected=15.8030
# Month=35, Predicted=15.5161, Expected=15.5294
# Month=36, Predicted=15.5663, Expected=15.4137
# Month=37, Predicted=15.7044, Expected=15.7167
# Month=38, Predicted=16.3994, Expected=16.8325
# Month=39, Predicted=17.7067, Expected=16.3604
# Month=40, Predicted=16.7715, Expected=17.8380
# Month=41, Predicted=18.0291, Expected=18.7250
# Month=42, Predicted=18.8026, Expected=19.0853
# Month=43, Predicted=18.8513, Expected=19.6276
# Month=44, Predicted=19.3762, Expected=19.4313
# Month=45, Predicted=18.9805, Expected=18.2343
# Month=46, Predicted=17.6246, Expected=17.2360
# Month=47, Predicted=16.8094, Expected=16.6138
# Month=48, Predicted=16.4704, Expected=16.7456
# Month=49, Predicted=17.0019, Expected=15.8525
# Month=50, Predicted=16.1365, Expected=15.6449
# Month=51, Predicted=16.3790, Expected=16.0032
# Month=52, Predicted=16.8491, Expected=16.9730
# Month=53, Predicted=17.5539, Expected=17.6001
# Month=54, Predicted=17.7390, Expected=17.8705
# Month=55, Predicted=17.6560, Expected=17.9603
# Month=56, Predicted=17.6093, Expected=17.5197
# Month=57, Predicted=17.0283, Expected=17.0509
# Month=58, Predicted=16.4763, Expected=16.5616
# Month=59, Predicted=16.1549, Expected=16.3883
# Month=60, Predicted=16.2586, Expected=16.6219
# Run 1 — RMSE: 0.469762, MSE: 0.220676, NMSE: 0.0020841752
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=13.1293, Expected=13.7840
# Month=2, Predicted=14.1967, Expected=13.7004
# Month=3, Predicted=14.2714, Expected=14.4363
# Month=4, Predicted=15.0563, Expected=15.1919
# Month=5, Predicted=15.5375, Expected=15.4445
# Month=6, Predicted=15.3793, Expected=15.7639
# Month=7, Predicted=15.4739, Expected=15.7700
# Month=8, Predicted=15.3600, Expected=15.2926
# Month=9, Predicted=14.6742, Expected=14.8003
# Month=10, Predicted=14.1506, Expected=13.4873
# Month=11, Predicted=12.8512, Expected=13.5947
# Month=12, Predicted=13.4691, Expected=14.5004
# Month=13, Predicted=14.5756, Expected=14.5004
# Month=14, Predicted=14.7476, Expected=14.5226
# Month=15, Predicted=15.1966, Expected=14.7779
# Month=16, Predicted=15.2875, Expected=15.7646
# Month=17, Predicted=16.0483, Expected=16.4780
# Month=18, Predicted=16.5849, Expected=16.5025
# Month=19, Predicted=16.2225, Expected=16.7567
# Month=20, Predicted=16.3128, Expected=16.3907
# Month=21, Predicted=15.8478, Expected=15.7981
# Month=22, Predicted=15.1136, Expected=15.4836
# Month=23, Predicted=15.0423, Expected=15.2106
# Month=24, Predicted=15.0476, Expected=15.5082
# Month=25, Predicted=15.5953, Expected=15.9457
# Month=26, Predicted=16.3150, Expected=16.3350
# Month=27, Predicted=17.0066, Expected=16.1521
# Month=28, Predicted=16.5885, Expected=16.8057
# Month=29, Predicted=16.9945, Expected=16.8329
# Month=30, Predicted=16.8150, Expected=17.3837
# Month=31, Predicted=17.1788, Expected=17.5349
# Month=32, Predicted=17.3237, Expected=17.4365
# Month=33, Predicted=17.0430, Expected=16.6359
# Month=34, Predicted=16.0606, Expected=15.8030
# Month=35, Predicted=15.2687, Expected=15.5294
# Month=36, Predicted=15.3930, Expected=15.4137
# Month=37, Predicted=15.4659, Expected=15.7167
# Month=38, Predicted=16.1269, Expected=16.8325
# Month=39, Predicted=17.6295, Expected=16.3604
# Month=40, Predicted=16.8156, Expected=17.8380
# Month=41, Predicted=18.0647, Expected=18.7250
# Month=42, Predicted=18.9478, Expected=19.0853
# Month=43, Predicted=18.8527, Expected=19.6276
# Month=44, Predicted=19.2463, Expected=19.4313
# Month=45, Predicted=18.8906, Expected=18.2343
# Month=46, Predicted=17.2908, Expected=17.2360
# Month=47, Predicted=16.3229, Expected=16.6138
# Month=48, Predicted=16.1728, Expected=16.7456
# Month=49, Predicted=16.6307, Expected=15.8525
# Month=50, Predicted=15.7475, Expected=15.6449
# Month=51, Predicted=16.0831, Expected=16.0032
# Month=52, Predicted=16.8317, Expected=16.9730
# Month=53, Predicted=17.9404, Expected=17.6001
# Month=54, Predicted=18.0958, Expected=17.8705
# Month=55, Predicted=17.8740, Expected=17.9603
# Month=56, Predicted=17.7032, Expected=17.5197
# Month=57, Predicted=17.0149, Expected=17.0509
# Month=58, Predicted=16.3842, Expected=16.5616
# Month=59, Predicted=15.9697, Expected=16.3883
# Month=60, Predicted=16.0842, Expected=16.6219
# Run 2 — RMSE: 0.457408, MSE: 0.209222, NMSE: 0.0018036856
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.463585 ± 0.006177
# MSE:  0.214949 ± 0.005727
# NMSE: 0.0019439304 ± 0.0001402448
#
# Best run: 2
#   RMSE: 0.457408
#   MSE:  0.209222
#   NMSE: 0.0018036856
# === Best Run Metrics ===
# RMSE: 0.457408
# MSE:  0.209222
# NMSE: 0.0018036856
#
# ================================================================================
# EVALUATING NOISE LEVEL: 10.0% (lambda=0.1, sigma=0.201042)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.86286051 14.62120304 15.21521274 16.6821933  16.87892529]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=13.0797, Expected=13.8680
# Month=2, Predicted=14.2692, Expected=13.5869
# Month=3, Predicted=14.0295, Expected=14.4895
# Month=4, Predicted=15.0815, Expected=15.3368
# Month=5, Predicted=15.6427, Expected=15.1961
# Month=6, Predicted=15.2793, Expected=15.6838
# Month=7, Predicted=15.4954, Expected=15.8280
# Month=8, Predicted=15.4315, Expected=15.2722
# Month=9, Predicted=14.7558, Expected=14.8376
# Month=10, Predicted=14.3032, Expected=13.4266
# Month=11, Predicted=12.9480, Expected=13.6034
# Month=12, Predicted=13.4060, Expected=14.4847
# Month=13, Predicted=14.6088, Expected=14.6178
# Month=14, Predicted=15.1137, Expected=14.5481
# Month=15, Predicted=15.2797, Expected=14.8119
# Month=16, Predicted=15.2804, Expected=15.7232
# Month=17, Predicted=15.9505, Expected=16.4290
# Month=18, Predicted=16.5224, Expected=16.4590
# Month=19, Predicted=16.3470, Expected=16.7963
# Month=20, Predicted=16.4368, Expected=16.3484
# Month=21, Predicted=15.7933, Expected=15.8273
# Month=22, Predicted=15.2395, Expected=15.6922
# Month=23, Predicted=15.2523, Expected=15.2981
# Month=24, Predicted=15.0706, Expected=15.4755
# Month=25, Predicted=15.5170, Expected=16.0665
# Month=26, Predicted=16.3556, Expected=16.2940
# Month=27, Predicted=16.8355, Expected=15.9473
# Month=28, Predicted=16.4857, Expected=16.7043
# Month=29, Predicted=17.0158, Expected=16.6449
# Month=30, Predicted=16.7104, Expected=17.3483
# Month=31, Predicted=17.3462, Expected=17.5367
# Month=32, Predicted=17.3847, Expected=17.6050
# Month=33, Predicted=17.3655, Expected=16.6687
# Month=34, Predicted=16.2157, Expected=15.7810
# Month=35, Predicted=15.2942, Expected=15.6127
# Month=36, Predicted=15.3248, Expected=15.1915
# Month=37, Predicted=15.1585, Expected=15.7404
# Month=38, Predicted=16.0878, Expected=16.9100
# Month=39, Predicted=17.4632, Expected=16.2117
# Month=40, Predicted=16.7929, Expected=17.9529
# Month=41, Predicted=18.3313, Expected=18.7591
# Month=42, Predicted=18.8951, Expected=19.0435
# Month=43, Predicted=18.9239, Expected=19.6912
# Month=44, Predicted=19.3454, Expected=19.6595
# Month=45, Predicted=19.1101, Expected=18.2526
# Month=46, Predicted=17.5122, Expected=17.2609
# Month=47, Predicted=16.5396, Expected=16.5676
# Month=48, Predicted=16.1348, Expected=16.6601
# Month=49, Predicted=16.5979, Expected=15.9359
# Month=50, Predicted=16.1436, Expected=15.5589
# Month=51, Predicted=16.2366, Expected=16.0104
# Month=52, Predicted=16.7506, Expected=16.9250
# Month=53, Predicted=17.6586, Expected=17.6483
# Month=54, Predicted=17.9528, Expected=17.9041
# Month=55, Predicted=17.7161, Expected=18.0646
# Month=56, Predicted=17.7101, Expected=17.4685
# Month=57, Predicted=16.8909, Expected=17.0237
# Month=58, Predicted=16.2951, Expected=16.4632
# Month=59, Predicted=15.8415, Expected=16.3437
# Month=60, Predicted=15.9276, Expected=16.6599
# Run 1 — RMSE: 0.518316, MSE: 0.268652, NMSE: 0.0023150625
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=13.1004, Expected=13.8680
# Month=2, Predicted=14.2886, Expected=13.5869
# Month=3, Predicted=14.1971, Expected=14.4895
# Month=4, Predicted=15.2360, Expected=15.3368
# Month=5, Predicted=15.7320, Expected=15.1961
# Month=6, Predicted=15.2369, Expected=15.6838
# Month=7, Predicted=15.4127, Expected=15.8280
# Month=8, Predicted=15.5032, Expected=15.2722
# Month=9, Predicted=14.7860, Expected=14.8376
# Month=10, Predicted=14.3248, Expected=13.4266
# Month=11, Predicted=12.9969, Expected=13.6034
# Month=12, Predicted=13.4908, Expected=14.4847
# Month=13, Predicted=14.6027, Expected=14.6178
# Month=14, Predicted=15.0445, Expected=14.5481
# Month=15, Predicted=15.2482, Expected=14.8119
# Month=16, Predicted=15.4495, Expected=15.7232
# Month=17, Predicted=16.0607, Expected=16.4290
# Month=18, Predicted=16.4691, Expected=16.4590
# Month=19, Predicted=16.2716, Expected=16.7963
# Month=20, Predicted=16.4058, Expected=16.3484
# Month=21, Predicted=15.8479, Expected=15.8273
# Month=22, Predicted=15.3438, Expected=15.6922
# Month=23, Predicted=15.3678, Expected=15.2981
# Month=24, Predicted=15.1824, Expected=15.4755
# Month=25, Predicted=15.6419, Expected=16.0665
# Month=26, Predicted=16.4815, Expected=16.2940
# Month=27, Predicted=16.9480, Expected=15.9473
# Month=28, Predicted=16.5618, Expected=16.7043
# Month=29, Predicted=17.0419, Expected=16.6449
# Month=30, Predicted=16.7647, Expected=17.3483
# Month=31, Predicted=17.2526, Expected=17.5367
# Month=32, Predicted=17.3661, Expected=17.6050
# Month=33, Predicted=17.3327, Expected=16.6687
# Month=34, Predicted=16.2571, Expected=15.7810
# Month=35, Predicted=15.4568, Expected=15.6127
# Month=36, Predicted=15.4754, Expected=15.1915
# Month=37, Predicted=15.2809, Expected=15.7404
# Month=38, Predicted=16.1544, Expected=16.9100
# Month=39, Predicted=17.5480, Expected=16.2117
# Month=40, Predicted=16.8603, Expected=17.9529
# Month=41, Predicted=18.4377, Expected=18.7591
# Month=42, Predicted=18.9571, Expected=19.0435
# Month=43, Predicted=18.9082, Expected=19.6912
# Month=44, Predicted=19.2852, Expected=19.6595
# Month=45, Predicted=19.2465, Expected=18.2526
# Month=46, Predicted=17.5851, Expected=17.2609
# Month=47, Predicted=16.6484, Expected=16.5676
# Month=48, Predicted=16.1676, Expected=16.6601
# Month=49, Predicted=16.6176, Expected=15.9359
# Month=50, Predicted=16.0805, Expected=15.5589
# Month=51, Predicted=16.1095, Expected=16.0104
# Month=52, Predicted=16.8357, Expected=16.9250
# Month=53, Predicted=17.7142, Expected=17.6483
# Month=54, Predicted=17.9987, Expected=17.9041
# Month=55, Predicted=17.7387, Expected=18.0646
# Month=56, Predicted=17.6925, Expected=17.4685
# Month=57, Predicted=16.9786, Expected=17.0237
# Month=58, Predicted=16.2853, Expected=16.4632
# Month=59, Predicted=15.8937, Expected=16.3437
# Month=60, Predicted=16.0429, Expected=16.6599
# Run 2 — RMSE: 0.505776, MSE: 0.255809, NMSE: 0.0022421908
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.512046 ± 0.006270
# MSE:  0.262230 ± 0.006421
# NMSE: 0.0022786267 ± 0.0000364359
#
# Best run: 2
#   RMSE: 0.505776
#   MSE:  0.255809
#   NMSE: 0.0022421908
# === Best Run Metrics ===
# RMSE: 0.505776
# MSE:  0.255809
# NMSE: 0.0022421908

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
print(f"Average run time per model (s / 4): {_NOTEBOOK_ELAPSED / 4:.2f} seconds")
print(f"Process ID: {os.getpid()}")
# Out:
# Total notebook execution time: 0h 2m 15.16s
# Total seconds: 135.16
