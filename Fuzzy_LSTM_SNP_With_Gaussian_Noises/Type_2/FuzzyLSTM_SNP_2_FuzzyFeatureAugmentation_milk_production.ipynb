# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import tensorflow as tf
import time as _timer_module

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 25457

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-23 15:34:24

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=1, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            print(f'  Epoch {epoch+1}/100 completed, Loss: {history.history["loss"][0]:.6f}')
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=1)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=1)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Monthly Milk Production\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
    _molab_results.append([lam, all_rmse[best_idx], all_mse[best_idx], all_nmse[best_idx]])

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 5.0% (lambda=0.05, sigma=5.094994)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [591.53075587 560.29554415 643.29996953 663.75982873 725.80698985]
# Supervised data shape: (167, 3)
# Train: (107, 3), Test: (60, 3)
# X_train shape: (107, 1, 2), y_train shape: (107,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=761.9017, Expected=805.3122
# Month=2, Predicted=757.3310, Expected=755.6207
# Month=3, Predicted=866.1085, Expected=850.2239
# Month=4, Predicted=884.6987, Expected=877.8649
# Month=5, Predicted=937.5572, Expected=942.3069
# Month=6, Predicted=891.6359, Expected=925.5502
# Month=7, Predicted=820.7296, Expected=868.0199
# Month=8, Predicted=779.6511, Expected=835.5364
# Month=9, Predicted=777.7047, Expected=789.8231
# Month=10, Predicted=793.4318, Expected=794.0456
# Month=11, Predicted=778.7712, Expected=768.8227
# Month=12, Predicted=798.2698, Expected=803.8311
# Month=13, Predicted=814.1954, Expected=830.0303
# Month=14, Predicted=796.9817, Expected=794.3667
# Month=15, Predicted=877.0737, Expected=897.1472
# Month=16, Predicted=914.6205, Expected=892.8576
# Month=17, Predicted=974.8985, Expected=963.9900
# Month=18, Predicted=977.3665, Expected=946.1604
# Month=19, Predicted=975.3612, Expected=888.9532
# Month=20, Predicted=887.4189, Expected=852.1147
# Month=21, Predicted=814.8664, Expected=809.5077
# Month=22, Predicted=808.9634, Expected=807.4348
# Month=23, Predicted=792.7717, Expected=758.0994
# Month=24, Predicted=799.4364, Expected=805.3493
# Month=25, Predicted=800.7483, Expected=815.5876
# Month=26, Predicted=789.5926, Expected=775.4130
# Month=27, Predicted=848.2057, Expected=878.3155
# Month=28, Predicted=884.2262, Expected=905.8969
# Month=29, Predicted=953.8431, Expected=953.0093
# Month=30, Predicted=931.8591, Expected=922.3591
# Month=31, Predicted=886.4178, Expected=885.1449
# Month=32, Predicted=869.7902, Expected=830.7288
# Month=33, Predicted=818.4959, Expected=785.1589
# Month=34, Predicted=773.4996, Expected=797.6599
# Month=35, Predicted=776.0992, Expected=751.8099
# Month=36, Predicted=795.9650, Expected=802.9407
# Month=37, Predicted=806.1031, Expected=829.3241
# Month=38, Predicted=791.1290, Expected=781.9834
# Month=39, Predicted=878.6150, Expected=882.6977
# Month=40, Predicted=898.5368, Expected=895.2723
# Month=41, Predicted=960.5687, Expected=971.6593
# Month=42, Predicted=958.2122, Expected=948.5131
# Month=43, Predicted=913.1325, Expected=909.2763
# Month=44, Predicted=847.7970, Expected=868.7652
# Month=45, Predicted=843.5709, Expected=811.5353
# Month=46, Predicted=813.1428, Expected=813.1833
# Month=47, Predicted=785.9574, Expected=774.4932
# Month=48, Predicted=808.8716, Expected=809.3604
# Month=49, Predicted=810.9941, Expected=843.5061
# Month=50, Predicted=802.7304, Expected=784.4142
# Month=51, Predicted=894.1102, Expected=885.9303
# Month=52, Predicted=901.1414, Expected=906.3451
# Month=53, Predicted=960.2215, Expected=961.0340
# Month=54, Predicted=951.6171, Expected=941.0102
# Month=55, Predicted=911.2377, Expected=901.9030
# Month=56, Predicted=877.7264, Expected=853.8186
# Month=57, Predicted=834.0437, Expected=821.9084
# Month=58, Predicted=808.2000, Expected=829.1031
# Month=59, Predicted=817.6098, Expected=801.1884
# Month=60, Predicted=832.2845, Expected=852.6641
# Run 1 — RMSE: 23.438078, MSE: 549.343524, NMSE: 0.0022910609
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=777.0395, Expected=805.3122
# Month=2, Predicted=751.8420, Expected=755.6207
# Month=3, Predicted=857.1091, Expected=850.2239
# Month=4, Predicted=869.9400, Expected=877.8649
# Month=5, Predicted=947.3498, Expected=942.3069
# Month=6, Predicted=909.6001, Expected=925.5502
# Month=7, Predicted=860.5342, Expected=868.0199
# Month=8, Predicted=806.2070, Expected=835.5364
# Month=9, Predicted=791.2153, Expected=789.8231
# Month=10, Predicted=792.1349, Expected=794.0456
# Month=11, Predicted=769.8342, Expected=768.8227
# Month=12, Predicted=798.2643, Expected=803.8311
# Month=13, Predicted=825.2481, Expected=830.0303
# Month=14, Predicted=794.0980, Expected=794.3667
# Month=15, Predicted=875.0740, Expected=897.1472
# Month=16, Predicted=912.8804, Expected=892.8576
# Month=17, Predicted=962.9319, Expected=963.9900
# Month=18, Predicted=960.5670, Expected=946.1604
# Month=19, Predicted=950.2894, Expected=888.9532
# Month=20, Predicted=878.0540, Expected=852.1147
# Month=21, Predicted=829.5793, Expected=809.5077
# Month=22, Predicted=816.2628, Expected=807.4348
# Month=23, Predicted=800.4404, Expected=758.0994
# Month=24, Predicted=822.5197, Expected=805.3493
# Month=25, Predicted=839.2010, Expected=815.5876
# Month=26, Predicted=784.2620, Expected=775.4130
# Month=27, Predicted=861.3942, Expected=878.3155
# Month=28, Predicted=893.1509, Expected=905.8969
# Month=29, Predicted=936.7497, Expected=953.0093
# Month=30, Predicted=930.1239, Expected=922.3591
# Month=31, Predicted=868.2297, Expected=885.1449
# Month=32, Predicted=830.7584, Expected=830.7288
# Month=33, Predicted=805.7851, Expected=785.1589
# Month=34, Predicted=770.6416, Expected=797.6599
# Month=35, Predicted=765.7802, Expected=751.8099
# Month=36, Predicted=807.3256, Expected=802.9407
# Month=37, Predicted=834.9653, Expected=829.3241
# Month=38, Predicted=776.9892, Expected=781.9834
# Month=39, Predicted=879.8579, Expected=882.6977
# Month=40, Predicted=899.9316, Expected=895.2723
# Month=41, Predicted=957.3046, Expected=971.6593
# Month=42, Predicted=958.0871, Expected=948.5131
# Month=43, Predicted=918.6849, Expected=909.2763
# Month=44, Predicted=866.7531, Expected=868.7652
# Month=45, Predicted=843.1036, Expected=811.5353
# Month=46, Predicted=816.8138, Expected=813.1833
# Month=47, Predicted=779.8542, Expected=774.4932
# Month=48, Predicted=816.1967, Expected=809.3604
# Month=49, Predicted=837.1723, Expected=843.5061
# Month=50, Predicted=795.9105, Expected=784.4142
# Month=51, Predicted=898.0211, Expected=885.9303
# Month=52, Predicted=905.9889, Expected=906.3451
# Month=53, Predicted=958.2040, Expected=961.0340
# Month=54, Predicted=957.1475, Expected=941.0102
# Month=55, Predicted=922.4431, Expected=901.9030
# Month=56, Predicted=873.9520, Expected=853.8186
# Month=57, Predicted=838.6813, Expected=821.9084
# Month=58, Predicted=811.4048, Expected=829.1031
# Month=59, Predicted=811.5869, Expected=801.1884
# Month=60, Predicted=840.0490, Expected=852.6641
# Run 2 — RMSE: 16.923401, MSE: 286.401513, NMSE: 0.0013122072
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Milk Production (30 runs) =====
# RMSE: 20.180740 ± 3.257339
# MSE:  417.872518 ± 131.471005
# NMSE: 0.0018016341 ± 0.0004894268
#
# Best run: 2
#   RMSE: 16.923401
#   MSE:  286.401513
#   NMSE: 0.0013122072
# === Best Run Metrics ===
# RMSE: 16.923401
# MSE:  286.401513
# NMSE: 0.0013122072
#
# ================================================================================
# EVALUATING NOISE LEVEL: 10.0% (lambda=0.1, sigma=10.189989)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [594.06151175 559.59108829 646.59993907 671.51965746 724.61397969]
# Supervised data shape: (167, 3)
# Train: (107, 3), Test: (60, 3)
# X_train shape: (107, 1, 2), y_train shape: (107,)
#
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=754.2230, Expected=806.6244
# Month=2, Predicted=800.2151, Expected=755.2414
# Month=3, Predicted=837.2552, Expected=840.4477
# Month=4, Predicted=868.6039, Expected=877.7298
# Month=5, Predicted=910.2745, Expected=942.6137
# Month=6, Predicted=912.7149, Expected=938.1004
# Month=7, Predicted=881.1808, Expected=867.0398
# Month=8, Predicted=809.2208, Expected=837.0728
# Month=9, Predicted=797.4846, Expected=789.6463
# Month=10, Predicted=795.6123, Expected=788.0912
# Month=11, Predicted=788.9954, Expected=774.6454
# Month=12, Predicted=792.8368, Expected=807.6622
# Month=13, Predicted=808.7234, Expected=834.0606
# Month=14, Predicted=828.1712, Expected=789.7334
# Month=15, Predicted=848.9817, Expected=904.2945
# Month=16, Predicted=922.4350, Expected=885.7152
# Month=17, Predicted=962.9644, Expected=966.9801
# Month=18, Predicted=958.0812, Expected=957.3207
# Month=19, Predicted=950.3682, Expected=883.9064
# Month=20, Predicted=860.5759, Expected=849.2294
# Month=21, Predicted=818.2512, Expected=810.0154
# Month=22, Predicted=809.4331, Expected=804.8696
# Month=23, Predicted=806.8189, Expected=750.1988
# Month=24, Predicted=782.8217, Expected=805.6987
# Month=25, Predicted=809.1528, Expected=810.1751
# Month=26, Predicted=831.7488, Expected=777.8259
# Month=27, Predicted=831.6798, Expected=873.6311
# Month=28, Predicted=899.8199, Expected=913.7938
# Month=29, Predicted=953.7527, Expected=949.0187
# Month=30, Predicted=929.7794, Expected=920.7182
# Month=31, Predicted=869.9692, Expected=889.2897
# Month=32, Predicted=830.7024, Expected=824.4575
# Month=33, Predicted=807.8267, Expected=786.3178
# Month=34, Predicted=779.3504, Expected=804.3198
# Month=35, Predicted=805.9532, Expected=743.6198
# Month=36, Predicted=788.1995, Expected=803.8814
# Month=37, Predicted=808.6523, Expected=830.6482
# Month=38, Predicted=832.8013, Expected=785.9668
# Month=39, Predicted=851.8614, Expected=876.3955
# Month=40, Predicted=905.0261, Expected=888.5446
# Month=41, Predicted=945.2925, Expected=974.3186
# Month=42, Predicted=958.7338, Expected=950.0263
# Month=43, Predicted=931.6861, Expected=910.5525
# Month=44, Predicted=861.4485, Expected=870.5303
# Month=45, Predicted=841.7084, Expected=808.0706
# Month=46, Predicted=812.2776, Expected=814.3667
# Month=47, Predicted=806.4765, Expected=775.9864
# Month=48, Predicted=805.1788, Expected=805.7208
# Month=49, Predicted=808.3484, Expected=853.0122
# Month=50, Predicted=844.1827, Expected=786.8284
# Month=51, Predicted=873.5994, Expected=879.8606
# Month=52, Predicted=907.5427, Expected=909.6903
# Month=53, Predicted=955.2295, Expected=956.0680
# Month=54, Predicted=948.0759, Expected=945.0204
# Month=55, Predicted=912.4450, Expected=907.8061
# Month=56, Predicted=859.6250, Expected=849.6373
# Month=57, Predicted=824.6091, Expected=826.8168
# Month=58, Predicted=815.8016, Expected=831.2062
# Month=59, Predicted=836.4270, Expected=805.3768
# Month=60, Predicted=829.0625, Expected=862.3283
# Run 1 — RMSE: 28.406028, MSE: 806.902436, NMSE: 0.0042053732
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=762.9190, Expected=806.6244
# Month=2, Predicted=810.9412, Expected=755.2414
# Month=3, Predicted=828.6349, Expected=840.4477
# Month=4, Predicted=856.0045, Expected=877.7298
# Month=5, Predicted=896.0109, Expected=942.6137
# Month=6, Predicted=917.4003, Expected=938.1004
# Month=7, Predicted=894.8998, Expected=867.0398
# Month=8, Predicted=821.3921, Expected=837.0728
# Month=9, Predicted=795.8243, Expected=789.6463
# Month=10, Predicted=788.2855, Expected=788.0912
# Month=11, Predicted=781.5845, Expected=774.6454
# Month=12, Predicted=785.7670, Expected=807.6622
# Month=13, Predicted=811.8161, Expected=834.0606
# Month=14, Predicted=845.5632, Expected=789.7334
# Month=15, Predicted=849.1902, Expected=904.2945
# Month=16, Predicted=910.8807, Expected=885.7152
# Month=17, Predicted=960.9069, Expected=966.9801
# Month=18, Predicted=970.3441, Expected=957.3207
# Month=19, Predicted=957.5282, Expected=883.9064
# Month=20, Predicted=865.9639, Expected=849.2294
# Month=21, Predicted=821.2857, Expected=810.0154
# Month=22, Predicted=807.9472, Expected=804.8696
# Month=23, Predicted=807.0248, Expected=750.1988
# Month=24, Predicted=789.7838, Expected=805.6987
# Month=25, Predicted=811.0754, Expected=810.1751
# Month=26, Predicted=841.2110, Expected=777.8259
# Month=27, Predicted=834.7442, Expected=873.6311
# Month=28, Predicted=887.9660, Expected=913.7938
# Month=29, Predicted=940.4594, Expected=949.0187
# Month=30, Predicted=921.1109, Expected=920.7182
# Month=31, Predicted=870.1430, Expected=889.2897
# Month=32, Predicted=835.8657, Expected=824.4575
# Month=33, Predicted=808.9171, Expected=786.3178
# Month=34, Predicted=777.7917, Expected=804.3198
# Month=35, Predicted=792.2540, Expected=743.6198
# Month=36, Predicted=791.7562, Expected=803.8814
# Month=37, Predicted=806.5753, Expected=830.6482
# Month=38, Predicted=841.9097, Expected=785.9668
# Month=39, Predicted=851.6987, Expected=876.3955
# Month=40, Predicted=892.1996, Expected=888.5446
# Month=41, Predicted=928.7918, Expected=974.3186
# Month=42, Predicted=960.6569, Expected=950.0263
# Month=43, Predicted=937.4403, Expected=910.5525
# Month=44, Predicted=862.4571, Expected=870.5303
# Month=45, Predicted=832.1321, Expected=808.0706
# Month=46, Predicted=809.3818, Expected=814.3667
# Month=47, Predicted=797.9860, Expected=775.9864
# Month=48, Predicted=801.7515, Expected=805.7208
# Month=49, Predicted=809.1267, Expected=853.0122
# Month=50, Predicted=853.3062, Expected=786.8284
# Month=51, Predicted=874.3249, Expected=879.8606
# Month=52, Predicted=898.0752, Expected=909.6903
# Month=53, Predicted=941.7571, Expected=956.0680
# Month=54, Predicted=950.3866, Expected=945.0204
# Month=55, Predicted=918.6463, Expected=907.8061
# Month=56, Predicted=871.1569, Expected=849.6373
# Month=57, Predicted=833.8478, Expected=826.8168
# Month=58, Predicted=813.4416, Expected=831.2062
# Month=59, Predicted=825.5676, Expected=805.3768
# Month=60, Predicted=831.6995, Expected=862.3283
# Run 2 — RMSE: 30.155104, MSE: 909.330309, NMSE: 0.0049251612
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Milk Production (30 runs) =====
# RMSE: 29.280566 ± 0.874538
# MSE:  858.116373 ± 51.213936
# NMSE: 0.0045652672 ± 0.0003598940
#
# Best run: 1
#   RMSE: 28.406028
#   MSE:  806.902436
#   NMSE: 0.0042053732
# === Best Run Metrics ===
# RMSE: 28.406028
# MSE:  806.902436
# NMSE: 0.0042053732

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
print(f"Average run time per model (s / 4): {_NOTEBOOK_ELAPSED / 4:.2f} seconds")
print(f"Process ID: {os.getpid()}")
# Out:
# Total notebook execution time: 0h 0m 48.00s
# Total seconds: 48.00
