# %% [markdown]
# # Autoformer — S&P 500
#
# **Model**: Auto-Correlation with Series Decomposition
# **Reference**: Wu et al., 2021 — Autoformer: Decomposition Transformers with Auto-Correlation for Long-Term Series Forecasting
#
# ## Description
# This notebook implements the **Autoformer** Transformer architecture for univariate time-series
# forecasting on the S&P 500 dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Autoformer Architecture
#
# ### Series Decomposition
# Autoformer applies deep decomposition at each encoder layer:
#
# $$X_{\text{seasonal}}, X_{\text{trend}} = \text{SeriesDecomp}(X)$$
#
# The trend is extracted via moving average:
# $$X_{\text{trend}} = \text{AvgPool}(\text{Padding}(X))$$
# $$X_{\text{seasonal}} = X - X_{\text{trend}}$$
#
# ### Auto-Correlation Mechanism
# Instead of point-wise attention, Autoformer discovers **period-based dependencies** using FFT:
#
# 1. Compute auto-correlation via FFT: $R_{QK}(\tau) = \mathcal{F}^{-1}(\mathcal{F}(Q) \cdot \overline{\mathcal{F}(K)})$
# 2. Select top-$k$ time delays with highest correlation
# 3. Aggregate values at those delays with softmax weights
#
# This captures inherent periodicity in time series more naturally than dot-product attention.
#
# ### Complexity
# Auto-correlation operates in $O(L \log L)$ via FFT.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### Autoformer Model Definition

# %%
# ============================================================
# Autoformer: Auto-Correlation with Series Decomposition
# Reference: Wu et al., 2021
#
# Key ideas:
# 1. Series decomposition: separate trend and seasonal components
# 2. Auto-Correlation mechanism: replaces self-attention with
#    period-based dependencies via FFT
# ============================================================

class SeriesDecomposition(nn.Module):
    """Series decomposition block: extract trend via moving average."""
    def __init__(self, kernel_size=3):
        super().__init__()
        self.kernel_size = kernel_size
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        # x: (B, L, D)
        # Transpose for AvgPool1d: (B, D, L)
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class AutoCorrelationLayer(nn.Module):
    """
    Auto-Correlation Mechanism.
    Uses FFT to find period-based dependencies, then aggregates
    top-k correlated time delays.
    """
    def __init__(self, d_model, n_heads, factor=3):
        super().__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.factor = factor

        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, _ = x.shape
        H = self.n_heads
        D = self.d_k

        Q = self.W_Q(x).view(B, L, H, D).transpose(1, 2)  # [B, H, L, D]
        K = self.W_K(x).view(B, L, H, D).transpose(1, 2)
        V = self.W_V(x).view(B, L, H, D).transpose(1, 2)

        # Auto-correlation via FFT
        Q_fft = torch.fft.rfft(Q, dim=2)
        K_fft = torch.fft.rfft(K, dim=2)

        # Cross-correlation in frequency domain
        corr = Q_fft * torch.conj(K_fft)
        corr_real = torch.fft.irfft(corr, n=L, dim=2)  # [B, H, L, D]

        # Find top-k delays
        top_k = max(1, int(self.factor * np.log(L + 1)))
        top_k = min(top_k, L)

        # Mean correlation across D dimension
        mean_corr = corr_real.mean(dim=-1)  # [B, H, L]
        _, top_idx = mean_corr.topk(top_k, dim=-1)  # [B, H, top_k]

        # Aggregate values at top-k delays
        weights = torch.softmax(
            torch.gather(mean_corr, -1, top_idx), dim=-1
        )  # [B, H, top_k]

        # Roll and aggregate
        output = torch.zeros_like(V)
        for i in range(top_k):
            delay = top_idx[:, :, i:i+1].unsqueeze(-1).expand(-1, -1, -1, D)
            w = weights[:, :, i:i+1].unsqueeze(-1)  # [B, H, 1, 1]
            rolled_V = torch.roll(V, shifts=1, dims=2)  # Approximate roll
            output = output + w * rolled_V

        output = output.transpose(1, 2).contiguous().view(B, L, self.d_model)
        return self.out_proj(output)


class AutoformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.decomp1 = SeriesDecomposition(kernel_size=3)
        self.decomp2 = SeriesDecomposition(kernel_size=3)
        self.auto_corr = AutoCorrelationLayer(d_model, n_heads)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Auto-correlation + decomposition
        attn_out = self.auto_corr(x)
        x = x + self.dropout(attn_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class AutoformerModel(nn.Module):
    """
    Autoformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.decomp_init = SeriesDecomposition(kernel_size=3)
        self.encoder_layers = nn.ModuleList([
            AutoformerEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20129
# Trainable parameters: 20129
# Memory estimate: 78.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (251,)
# First 5 values: [2038.199951 2013.780029 2011.709961 1985.319946 1945.969971]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (250, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (190, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (190, 1, 1), y_train shape: (190,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=2155.7871, Expected=2158.2200
# Month=2, Predicted=2158.8653, Expected=2164.1899
# Month=3, Predicted=2164.8377, Expected=2160.3899
# Month=4, Predicted=2161.0300, Expected=2161.3501
# Month=5, Predicted=2161.9937, Expected=2137.6699
# Month=6, Predicted=2138.2998, Expected=2130.2600
# Month=7, Predicted=2130.8977, Expected=2139.6799
# Month=8, Predicted=2140.3308, Expected=2132.9500
# Month=9, Predicted=2133.5881, Expected=2138.3101
# Month=10, Predicted=2138.9573, Expected=2140.8101
# Month=11, Predicted=2141.4549, Expected=2142.5100
# Month=12, Predicted=2143.1542, Expected=2139.4299
# Month=13, Predicted=2140.0705, Expected=2148.5000
# Month=14, Predicted=2149.1505, Expected=2149.7200
# Month=15, Predicted=2150.3638, Expected=2136.9700
# Month=16, Predicted=2137.6046, Expected=2144.0601
# Month=17, Predicted=2144.7088, Expected=2132.2300
# Month=18, Predicted=2132.8651, Expected=2129.7800
# Month=19, Predicted=2130.4211, Expected=2128.6799
# Month=20, Predicted=2129.3220, Expected=2109.4299
# Month=21, Predicted=2110.0615, Expected=2098.8000
# Month=22, Predicted=2099.4358, Expected=2083.7900
# Month=23, Predicted=2084.4235, Expected=2100.5901
# Month=24, Predicted=2101.2483, Expected=2129.9199
# Month=25, Predicted=2130.5929, Expected=2131.5601
# Month=26, Predicted=2132.2042, Expected=2167.4900
# Month=27, Predicted=2168.1718, Expected=2162.7100
# Month=28, Predicted=2163.3494, Expected=2165.6399
# Month=29, Predicted=2166.2851, Expected=2168.2900
# Month=30, Predicted=2168.9350, Expected=2177.5300
# Month=31, Predicted=2178.1807, Expected=2178.6101
# Month=32, Predicted=2179.2538, Expected=2186.8501
# Month=33, Predicted=2187.4999, Expected=2186.4299
# Month=34, Predicted=2187.0725, Expected=2201.5601
# Month=35, Predicted=2202.2165, Expected=2198.5500
# Month=36, Predicted=2199.1907, Expected=2206.2700
# Month=37, Predicted=2206.9193, Expected=2210.2100
# Month=38, Predicted=2210.8560, Expected=2200.7600
# Month=39, Predicted=2201.3965, Expected=2204.9700
# Month=40, Predicted=2205.6162, Expected=2200.1699
# Month=41, Predicted=2200.8093, Expected=2191.1201
# Month=42, Predicted=2191.7568, Expected=2200.6499
# Month=43, Predicted=2201.3009, Expected=2207.2600
# Month=44, Predicted=2207.9083, Expected=2210.7200
# Month=45, Predicted=2211.3656, Expected=2241.1299
# Month=46, Predicted=2241.8042, Expected=2249.7300
# Month=47, Predicted=2250.3801, Expected=2258.8301
# Month=48, Predicted=2259.4806, Expected=2263.3201
# Month=49, Predicted=2263.9665, Expected=2268.3501
# Month=50, Predicted=2268.9970, Expected=2253.7700
# Month=51, Predicted=2254.4037, Expected=2266.8101
# Month=52, Predicted=2267.4644, Expected=2259.2400
# Month=53, Predicted=2259.8776, Expected=2266.5000
# Month=54, Predicted=2267.1489, Expected=2270.5400
# Month=55, Predicted=2271.1861, Expected=2262.9299
# Month=56, Predicted=2263.5675, Expected=2260.2500
# Month=57, Predicted=2260.8909, Expected=2266.2300
# Month=58, Predicted=2266.8777, Expected=2270.2300
# Month=59, Predicted=2270.8760, Expected=2249.5000
# Month=60, Predicted=2250.1309, Expected=2251.6101
# Run 1 — RMSE: 11.104169, MSE: 123.302576, NMSE: 0.0007465372, Time: 36.5s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2155.8094, Expected=2158.2200
# Month=2, Predicted=2158.8744, Expected=2164.1899
# Month=3, Predicted=2164.8430, Expected=2160.3899
# Month=4, Predicted=2161.0474, Expected=2161.3501
# Month=5, Predicted=2162.0055, Expected=2137.6699
# Month=6, Predicted=2138.3361, Expected=2130.2600
# Month=7, Predicted=2130.9192, Expected=2139.6799
# Month=8, Predicted=2140.3313, Expected=2132.9500
# Month=9, Predicted=2133.6088, Expected=2138.3101
# Month=10, Predicted=2138.9634, Expected=2140.8101
# Month=11, Predicted=2141.4647, Expected=2142.5100
# Month=12, Predicted=2143.1650, Expected=2139.4299
# Month=13, Predicted=2140.0871, Expected=2148.5000
# Month=14, Predicted=2149.1516, Expected=2149.7200
# Month=15, Predicted=2150.3752, Expected=2136.9700
# Month=12, Predicted=2143.2726, Expected=2139.4299
# Month=13, Predicted=2140.1955, Expected=2148.5000
# Month=14, Predicted=2149.2577, Expected=2149.7200
# Month=15, Predicted=2150.4829, Expected=2136.9700
# Month=16, Predicted=2137.7412, Expected=2144.0601
# Month=17, Predicted=2144.8191, Expected=2132.2300
# Month=18, Predicted=2133.0007, Expected=2129.7800
# Month=19, Predicted=2130.5452, Expected=2128.6799
# Month=20, Predicted=2129.4443, Expected=2109.4299
# Month=21, Predicted=2110.2047, Expected=2098.8000
# Month=22, Predicted=2099.5701, Expected=2083.7900
# Month=23, Predicted=2084.5626, Expected=2100.5901
# Month=24, Predicted=2101.3423, Expected=2129.9199
# Month=25, Predicted=2130.6626, Expected=2131.5601
# Month=26, Predicted=2132.3227, Expected=2167.4900
# Month=27, Predicted=2168.2273, Expected=2162.7100
# Month=28, Predicted=2163.4766, Expected=2165.6399
# Month=29, Predicted=2166.4017, Expected=2168.2900
# Month=30, Predicted=2169.0520, Expected=2177.5300
# Month=31, Predicted=2178.2876, Expected=2178.6101
# Month=32, Predicted=2179.3731, Expected=2186.8501
# Month=33, Predicted=2187.6084, Expected=2186.4299
# Month=34, Predicted=2187.1939, Expected=2201.5601
# Month=35, Predicted=2202.3135, Expected=2198.5500
# Month=36, Predicted=2199.3156, Expected=2206.2700
# Month=37, Predicted=2207.0286, Expected=2210.2100
# Month=38, Predicted=2210.9711, Expected=2200.7600
# Month=39, Predicted=2201.5294, Expected=2204.9700
# Month=40, Predicted=2205.7309, Expected=2200.1699
# Month=41, Predicted=2200.9366, Expected=2191.1201
# Month=42, Predicted=2191.8893, Expected=2200.6499
# Month=43, Predicted=2201.4073, Expected=2207.2600
# Month=44, Predicted=2208.0194, Expected=2210.7200
# Month=45, Predicted=2211.4814, Expected=2241.1299
# Month=46, Predicted=2241.8717, Expected=2249.7300
# Month=47, Predicted=2250.4880, Expected=2258.8301
# Month=48, Predicted=2259.5878, Expected=2263.3201
# Month=49, Predicted=2264.0809, Expected=2268.3501
# Month=50, Predicted=2269.1105, Expected=2253.7700
# Month=51, Predicted=2254.5423, Expected=2266.8101
# Month=52, Predicted=2267.5650, Expected=2259.2400
# Month=53, Predicted=2260.0083, Expected=2266.5000
# Month=54, Predicted=2267.2589, Expected=2270.5400
# Month=55, Predicted=2271.3011, Expected=2262.9299
# Month=56, Predicted=2263.6983, Expected=2260.2500
# Month=57, Predicted=2261.0154, Expected=2266.2300
# Month=58, Predicted=2266.9898, Expected=2270.2300
# Month=59, Predicted=2270.9911, Expected=2249.5000
# Month=60, Predicted=2250.2755, Expected=2251.6101
# Run 3 — RMSE: 11.094885, MSE: 123.096481, NMSE: 0.0007454120, Time: 50.4s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted
# Month=41, Predicted=2200.8877, Expected=2191.1201
# Month=42, Predicted=2191.8280, Expected=2200.6499
# Month=43, Predicted=2201.4006, Expected=2207.2600
# Month=44, Predicted=2208.0041, Expected=2210.7200
# Month=45, Predicted=2211.4568, Expected=2241.1299
# Month=46, Predicted=2241.9277, Expected=2249.7300
# Month=47, Predicted=2250.4786, Expected=2258.8301
# Month=48, Predicted=2259.5798, Expected=2263.3201
# Month=49, Predicted=2264.0593, Expected=2268.3501
# Month=50, Predicted=2269.0905, Expected=2253.7700
# Month=51, Predicted=2254.4649, Expected=2266.8101
# Month=52, Predicted=2267.5688, Expected=2259.2400
# Month=53, Predicted=2259.9513, Expected=2266.5000
# Month=54, Predicted=2267.2455, Expected=2270.5400
# Month=55, Predicted=2271.2782, Expected=2262.9299
# Month=56, Predicted=2263.6411, Expected=2260.2500
# Month=57, Predicted=2260.9727, Expected=2266.2300
# Month=58, Predicted=2266.9726, Expected=2270.2300
# Month=59, Predicted=2270.9681, Expected=2249.5000
# Month=60, Predicted=2250.1804, Expected=2251.6101
# Run 9 — RMSE: 11.096669, MSE: 123.136066, NMSE: 0.0007454872, Time: 55.1s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2155.7687, Expected=2158.2200
# Month=2, Predicted=2158.8366, Expected=2164.1899
# Month=3, Predicted=2164.8061, Expected=2160.3899
# Month=4, Predicted=2161.0078, Expected=2161.3501
# Month=5, Predicted=2161.9671, Expected=2137.6699
# Month=6, Predicted=2138.2925, Expected=2130.2600
# Month=7, Predicted=2130.8786, Expected=2139.6799
# Month=8, Predicted=2140.2956, Expected=2132.9500
# Month=9, Predicted=2133.5684, Expected=2138.3101
# Month=10, Predicted=2138.9263, Expected=2140.8101
# Month=11, Predicted=2141.4268, Expected=2142.5100
# Month=12, Predicted=2143.1269, Expected=2139.4299
# Month=13, Predicted=2140.0477, Expected=2148.5000
# Month=14, Predicted=2149.1157, Expected=2149.7200
# Month=15, Predicted=2150.3369, Expected=2136.9700
# Month=16, Predicted=2137.5898, Expected=2144.0601
# Month=17, Predicted=2144.6761, Expected=2132.2300
# Month=18, Predicted=2132.8496, Expected=2129.7800
# Month=19, Predicted=2130.3977, Expected=2128.6799
# Month=20, Predicted=2129.2973, Expected=2109.4299
# Month=21, Predicted=2110.0513, Expected=2098.8000
# Month=22, Predicted=2099.4194, Expected=2083.7900
# Month=23, Predicted=2084.4104, Expected=2100.5901
# Month=24, Predicted=2101.2048, Expected=2129.9199
# Month=25, Predicted=2130.5336, Expected=2131.5601
# Month=26, Predicted=2132.1770, Expected=2167.4900
# Month=27, Predicted=2168.1034, Expected=2162.7100
# Month=28, Predicted=2163.3281, Expected=2165.6399
# Month=29, Predicted=2166.2566, Expected=2168.2900
# Month=30, Predicted=2168.9068, Expected=2177.5300
# Month=31, Predicted=2178.1457, Expected=2178.6101
# Month=32, Predicted=2179.2271, Expected=2186.8501
# Month=33, Predicted=2187.4659, Expected=2186.4299
# Month=34, Predicted=2187.0472, Expected=2201.5601
# Month=35, Predicted=2202.1750, Expected=2198.5500
# Month=36, Predicted=2199.1678, Expected=2206.2700
# Month=28, Predicted=2163.4693, Expected=2165.6399
# Month=29, Predicted=2166.3983, Expected=2168.2900
# Month=30, Predicted=2169.0485, Expected=2177.5300
# Month=31, Predicted=2178.2877, Expected=2178.6101
# Month=32, Predicted=2179.3687, Expected=2186.8501
# Month=33, Predicted=2187.6079, Expected=2186.4299
# Month=34, Predicted=2187.1887, Expected=2201.5601
# Month=35, Predicted=2202.3170, Expected=2198.5500
# Month=36, Predicted=2199.3092, Expected=2206.2700
# Month=37, Predicted=2207.0279, Expected=2210.2100
# Month=38, Predicted=2210.9683, Expected=2200.7600
# Month=39, Predicted=2201.5198, Expected=2204.9700
# Month=40, Predicted=2205.7282, Expected=2200.1699
# Month=41, Predicted=2200.9292, Expected=2191.1201
# Month=42, Predicted=2191.8799, Expected=2200.6499
# Month=43, Predicted=2201.4075, Expected=2207.2600
# Month=44, Predicted=2208.0180, Expected=2210.7200
# Month=45, Predicted=2211.4783, Expected=2241.1299
# Month=46, Predicted=2241.8850, Expected=2249.7300
# Month=47, Predicted=2250.4877, Expected=2258.8301
# Month=48, Predicted=2259.5878, Expected=2263.3201
# Month=49, Predicted=2264.0783, Expected=2268.3501
# Month=50, Predicted=2269.1083, Expected=2253.7700
# Month=51, Predicted=2254.5304, Expected=2266.8101
# Month=52, Predicted=2267.5673, Expected=2259.2400
# Month=53, Predicted=2259.9996, Expected=2266.5000
# Month=54, Predicted=2267.2579, Expected=2270.5400
# Month=55, Predicted=2271.2983, Expected=2262.9299
# Month=56, Predicted=2263.6896, Expected=2260.2500
# Month=57, Predicted=2261.0091, Expected=2266.2300
# Month=58, Predicted=2266.9880, Expected=2270.2300
# Month=59, Predicted=2270.9883, Expected=2249.5000
# Month=60, Predicted=2250.2611, Expected=2251.6101
# Run 12 — RMSE: 11.095074, MSE: 123.100657, NMSE: 0.0007454105, Time: 55.5s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2155.8383, Expected=2158.2200
# Month=2, Predicted=2158.9044, Expected=2164.1899
# Month=3, Predicted=2164.8734, Expected=2160.3899
# Month=4, Predicted=2161.0768, Expected=2161.3501
# Month=5, Predicted=2162.0353, Expected=2137.6699
# Month=6, Predicted=2138.3639, Expected=2130.2600
# Month=7, Predicted=2130.9481, Expected=2139.6799
# Month=8, Predicted=2140.3622, Expected=2132.9500
# Month=9, Predicted=2133.6378, Expected=2138.3101
# Month=10, Predicted=2138.9937, Expected=2140.8101
# Month=11, Predicted=2141.4947, Expected=2142.5100
# Month=12, Predicted=2143.1950, Expected=2139.4299
# Month=13, Predicted=2140.1165, Expected=2148.5000
# Month=14, Predicted=2149.1824, Expected=2149.7200
# Month=15, Predicted=2150.4051, Expected=2136.9700
# Month=16, Predicted=2137.6600, Expected=2144.0601
# Month=17, Predicted=2144.7432, Expected=2132.2300
# Month=18, Predicted=2132.9197, Expected=2129.7800
# Month=19, Predicted=2130.4664, Expected=2128.6799
# Month=20, Predicted=2129.3659, Expected=2109.4299
# Month=21, Predicted=2110.1223, Expected=2098.8000
# Month=22, Predicted=2099.4893, Expected=2083.7900
# Month=23, Predicted=2084.4809, Expected=2100.5901
# Month=24, Predicted=2101.2699, Expected=2129.9199
# Month=25, Predicted=2130.5955, Expected=2131.5601
# Month=26, Predicted=2132.2450, Expected=2167.4900
# Month=27, Predicted=2168.1634, Expected=2162.7100
# Month=28, Predicted=2163.3972, Expected=2165.6399
# Month=29, Predicted=2166.3244, Expected=2168.2900
# Month=30, Predicted=2168.9747, Expected=2177.5300
# Month=31, Predicted=2178.2124, Expected=2178.6101
# Month=32, Predicted=2179.2953, Expected=2186.8501
# Month=33, Predicted=2187.5328, Expected=2186.4299
# Month=34, Predicted=2187.1156, Expected=2201.5601
# Month=35, Predicted=2202.2404, Expected=2198.5500
# Month=36, Predicted=2199.2366, Expected=2206.2700
# Month=37, Predicted=2206.9529, Expected=2210.2100
# Month=38, Predicted=2210.8941, Expected=2200.7600
# Month=39, Predicted=2201.4489, Expected=2204.9700
# Month=40, Predicted=2205.6541, Expected=2200.1699
# Month=41, Predicted=2200.8571, Expected=2191.1201
# Month=42, Predicted=2191.8088, Expected=2200.6499
# Month=43, Predicted=2201.3322, Expected=2207.2600
# Month=44, Predicted=2207.9433, Expected=2210.7200
# Month=45, Predicted=2211.4043, Expected=2241.1299
# Month=46, Predicted=2241.8051, Expected=2249.7300
# Month=47, Predicted=2250.4126, Expected=2258.8301
# Month=48, Predicted=2259.5125, Expected=2263.3201
# Month=49, Predicted=2264.0041, Expected=2268.3501
# Month=50, Predicted=2269.0339, Expected=2253.7700
# Month=51, Predicted=2254.4607, Expected=2266.8101
# Month=52, Predicted=2267.4911, Expected=2259.2400
# Month=53, Predicted=2259.9282, Expected=2266.5000
# Month=54, Predicted=2267.1830, Expected=2270.5400
# Month=55, Predicted=2271.2242, Expected=2262.9299
# Month=56, Predicted=2263.6181, Expected=2260.2500
# Month=57, Predicted=2260.9365, Expected=2266.2300
# Month=58, Predicted=2266.9135, Expected=2270.2300
# Month=59, Predicted=2270.9141, Expected=2249.5000
# Month=60, Predicted=2250.1929, Expected=2251.6101
# Run 13 — RMSE: 11.100989, MSE: 123.231946, NMSE: 0.0007461824, Time: 58.0s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2155.7821, Expected=2158.2200
# Month=2, Predicted=2158.8583, Expected=2164.1899
# Month=3, Predicted=2164.8299, Expected=2160.3899
# Month=4, Predicted=2161.0245, Expected=2161.3501
# Month=5, Predicted=2161.9873, Expected=2137.6699
# Month=6, Predicted=2138.2936, Expected=2130.2600
# Month=7, Predicted=2130.8926, Expected=2139.6799
# Month=8, Predicted=2140.3217, Expected=2132.9500
# Month=9, Predicted=2133.5830, Expected=2138.3101
# Month=10, Predicted=2138.9497, Expected=2140.8101
# Month=11, Predicted=2141.4481, Expected=2142.5100
# Month=12, Predicted=2143.1476, Expected=2139.4299
# Month=13, Predicted=2140.0649, Expected=2148.5000
# Month=14, Predicted=2149.1416, Expected=2149.7200
# Month=15, Predicted=2150.3573, Expected=2136.9700
# Month=16, Predicted=2137.5997, Expected=2144.0601
# Month=17, Predicted=2144.7006, Expected=2132.2300
# Month=18, Predicted=2132.8602, Expected=2129.7800
# Month=19, Predicted=2130.4154, Expected=2128.6799
# Month=20, Predicted=2129.3160, Expected=2109.4299
# Month=21, Predicted=2110.0560, Expected=2098.8000
# Month=22, Predicted=2099.4309, Expected=2083.7900
# Month=23, Predicted=2084.4185, Expected=2100.5901
# Month=24, Predicted=2101.2359, Expected=2129.9199
# Month=25, Predicted=2130.5724, Expected=2131.5601
# Month=26, Predicted=2132.1976, Expected=2167.4900
# Month=27, Predicted=2168.1460, Expected=2162.7100
# Month=28, Predicted=2163.3440, Expected=2165.6399
# Month=29, Predicted=2166.2782, Expected=2168.2900
# Month=30, Predicted=2168.9282, Expected=2177.5300
# Month=31, Predicted=2178.1717, Expected=2178.6101
# Month=32, Predicted=2179.2474, Expected=2186.8501
# Month=33, Predicted=2187.4913, Expected=2186.4299
# Month=34, Predicted=2187.0664, Expected=2201.5601
# Month=35, Predicted=2202.2049, Expected=2198.5500
# Month=36, Predicted=2199.1851, Expected=2206.2700
# Month=37, Predicted=2206.9109, Expected=2210.2100
# Month=38, Predicted=2210.8488, Expected=2200.7600
# Month=39, Predicted=2201.3915, Expected=2204.9700
# Month=40, Predicted=2205.6090, Expected=2200.1699
# Month=41, Predicted=2200.8040, Expected=2191.1201
# Month=42, Predicted=2191.7519, Expected=2200.6499
# Month=43, Predicted=2201.2918, Expected=2207.2600
# Month=44, Predicted=2207.9003, Expected=2210.7200
# Month=45, Predicted=2211.3585, Expected=2241.1299
# Month=46, Predicted=2241.7829, Expected=2249.7300
# Month=47, Predicted=2250.3713, Expected=2258.8301
# Month=48, Predicted=2259.4717, Expected=2263.3201
# Month=49, Predicted=2263.9592, Expected=2268.3501
# Month=50, Predicted=2268.9895, Expected=2253.7700
# Month=51, Predicted=2254.3987, Expected=2266.8101
# Month=52, Predicted=2267.4538, Expected=2259.2400
# Month=53, Predicted=2259.8725, Expected=2266.5000
# Month=54, Predicted=2267.1406, Expected=2270.5400
# Month=55, Predicted=2271.1789, Expected=2262.9299
# Month=56, Predicted=2263.5625, Expected=2260.2500
# Month=57, Predicted=2260.8852, Expected=2266.2300
# Month=58, Predicted=2266.8699, Expected=2270.2300
# Month=59, Predicted=2270.8688, Expected=2249.5000
# Month=60, Predicted=2250.1253, Expected=2251.6101
# Run 14 — RMSE: 11.104866, MSE: 123.318051, NMSE: 0.0007466331, Time: 94.1s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2155.7642, Expected=2158.2200
# Month=2, Predicted=2158.8117, Expected=2164.1899
# Month=3, Predicted=2164.7758, Expected=2160.3899
# Month=4, Predicted=2160.9954, Expected=2161.3501
# Month=5, Predicted=2161.9461, Expected=2137.6699
# Month=6, Predicted=2138.3144, Expected=2130.2600
# Month=7, Predicted=2130.8727, Expected=2139.6799
# Month=8, Predicted=2140.2588, Expected=2132.9500
# Month=9, Predicted=2133.5613, Expected=2138.3101
# Month=10, Predicted=2138.8971, Expected=2140.8101
# Month=11, Predicted=2141.4029, Expected=2142.5100
# Month=12, Predicted=2143.1045, Expected=2139.4299
# Month=13, Predicted=2140.0340, Expected=2148.5000
# Month=14, Predicted=2149.0796, Expected=2149.7200
# Month=15, Predicted=2150.3154, Expected=2136.9700
# Month=16, Predicted=2137.5932, Expected=2144.0601
# Month=17, Predicted=2144.6436, Expected=2132.2300
# Month=18, Predicted=2132.8514, Expected=2129.7800
# Month=19, Predicted=2130.3828, Expected=2128.6799
# Month=20, Predicted=2129.2800, Expected=2109.4299
# Month=21, Predicted=2110.0658, Expected=2098.8000
# Month=22, Predicted=2099.4191, Expected=2083.7900
# Month=23, Predicted=2084.4177, Expected=2100.5901
# Month=24, Predicted=2101.1538, Expected=2129.9199
# Month=25, Predicted=2130.4576, Expected=2131.5601
# Month=26, Predicted=2132.1546, Expected=2167.4900
# Month=27, Predicted=2168.0137, Expected=2162.7100
# Month=28, Predicted=2163.3174, Expected=2165.6399
# Month=29, Predicted=2166.2319, Expected=2168.2900
# Month=30, Predicted=2168.8826, Expected=2177.5300
# Month=31, Predicted=2178.1092, Expected=2178.6101
# Month=32, Predicted=2179.2058, Expected=2186.8501
# Month=33, Predicted=2187.4313, Expected=2186.4299
# Month=34, Predicted=2187.0287, Expected=2201.5601
# Month=35, Predicted=2202.1272, Expected=2198.5500
# Month=36, Predicted=2199.1540, Expected=2206.2700
# Month=37, Predicted=2206.8523, Expected=2210.2100
# Month=38, Predicted=2210.7999, Expected=2200.7600
# Month=39, Predicted=2201.3767, Expected=2204.9700
# Month=40, Predicted=2205.5594, Expected=2200.1699
# Month=41, Predicted=2200.7774, Expected=2191.1201
# Month=42, Predicted=2191.7360, Expected=2200.6499
# Month=43, Predicted=2201.2285, Expected=2207.2600
# Month=44, Predicted=2207.8446, Expected=2210.7200
# Month=45, Predicted=2211.3109, Expected=2241.1299
# Month=46, Predicted=2241.6653, Expected=2249.7300
# Month=47, Predicted=2250.3105, Expected=2258.8301
# Month=48, Predicted=2259.4096, Expected=2263.3201
# Month=49, Predicted=2263.9089, Expected=2268.3501
# Month=50, Predicted=2268.9379, Expected=2253.7700
# Month=51, Predicted=2254.3968, Expected=2266.8101
# Month=52, Predicted=2267.3815, Expected=2259.2400
# Month=53, Predicted=2259.8530, Expected=2266.5000
# Month=54, Predicted=2267.0832, Expected=2270.5400
# Month=55, Predicted=2271.1298, Expected=2262.9299
# Month=56, Predicted=2263.5430, Expected=2260.2500
# Month=57, Predicted=2260.8532, Expected=2266.2300
# Month=58, Predicted=2266.8158, Expected=2270.2300
# Month=59, Predicted=2270.8198, Expected=2249.5000
# Month=60, Predicted=2250.1388, Expected=2251.6101
# Run 15 — RMSE: 11.109216, MSE: 123.414674, NMSE: 0.0007473255, Time: 138.0s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2155.8624, Expected=2158.2200
# Month=2, Predicted=2158.9497, Expected=2164.1899
# Month=3, Predicted=2164.9241, Expected=2160.3899
# Month=4, Predicted=2161.1092, Expected=2161.3501
# Month=5, Predicted=2162.0766, Expected=2137.6699
# Month=6, Predicted=2138.3588, Expected=2130.2600
# Month=7, Predicted=2130.9737, Expected=2139.6799
# Month=8, Predicted=2140.4194, Expected=2132.9500
# Month=9, Predicted=2133.6647, Expected=2138.3101
# Month=10, Predicted=2139.0433, Expected=2140.8101
# Month=11, Predicted=2141.5389, Expected=2142.5100
# Month=12, Predicted=2143.2377, Expected=2139.4299
# Month=13, Predicted=2140.1503, Expected=2148.5000
# Month=14, Predicted=2149.2389, Expected=2149.7200
# Month=15, Predicted=2150.4469, Expected=2136.9700
# Month=16, Predicted=2137.6755, Expected=2144.0601
# Month=17, Predicted=2144.7960, Expected=2132.2300
# Month=18, Predicted=2132.9370, Expected=2129.7800
# Month=19, Predicted=2130.5013, Expected=2128.6799
# Month=20, Predicted=2129.4033, Expected=2109.4299
# Month=21, Predicted=2110.1256, Expected=2098.8000
# Month=22, Predicted=2099.5089, Expected=2083.7900
# Month=23, Predicted=2084.4922, Expected=2100.5901
# Month=24, Predicted=2101.3408, Expected=2129.9199
# ...
# Month=55, Predicted=2271.1018, Expected=2262.9299
# Month=56, Predicted=2263.5335, Expected=2260.2500
# Month=57, Predicted=2260.8297, Expected=2266.2300
# Month=58, Predicted=2266.7904, Expected=2270.2300
# Month=59, Predicted=2270.7917, Expected=2249.5000
# Month=60, Predicted=2250.1933, Expected=2251.6101
# Run 25 — RMSE: 11.109157, MSE: 123.413366, NMSE: 0.0007474624, Time: 81.6s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=2155.8463, Expected=2158.2200
# Month=2, Predicted=2158.8922, Expected=2164.1899
# Month=3, Predicted=2164.8560, Expected=2160.3899
# Month=4, Predicted=2161.0768, Expected=2161.3501
# Month=5, Predicted=2162.0268, Expected=2137.6699
# Month=6, Predicted=2138.3993, Expected=2130.2600
# Month=7, Predicted=2130.9547, Expected=2139.6799
# Month=8, Predicted=2140.3386, Expected=2132.9500
# Month=9, Predicted=2133.6431, Expected=2138.3101
# Month=10, Predicted=2138.9774, Expected=2140.8101
# Month=11, Predicted=2141.4835, Expected=2142.5100
# Month=12, Predicted=2143.1852, Expected=2139.4299
# Month=13, Predicted=2140.1153, Expected=2148.5000
# Month=14, Predicted=2149.1594, Expected=2149.7200
# Month=15, Predicted=2150.3962, Expected=2136.9700
# Month=16, Predicted=2137.6760, Expected=2144.0601
# Month=17, Predicted=2144.7237, Expected=2132.2300
# Month=18, Predicted=2132.9341, Expected=2129.7800
# Month=19, Predicted=2130.4641, Expected=2128.6799
# Month=20, Predicted=2129.3611, Expected=2109.4299
# Month=21, Predicted=2110.1499, Expected=2098.8000
# Month=22, Predicted=2099.5016, Expected=2083.7900
# Month=23, Predicted=2084.5009, Expected=2100.5901
# Month=24, Predicted=2101.2329, Expected=2129.9199
# Month=25, Predicted=2130.5358, Expected=2131.5601
# Month=26, Predicted=2132.2354, Expected=2167.4900
# Month=27, Predicted=2168.0917, Expected=2162.7100
# Month=28, Predicted=2163.3990, Expected=2165.6399
# Month=29, Predicted=2166.3124, Expected=2168.2900
# Month=30, Predicted=2168.9632, Expected=2177.5300
# Month=31, Predicted=2178.1890, Expected=2178.6101
# Month=32, Predicted=2179.2866, Expected=2186.8501
# Month=33, Predicted=2187.5113, Expected=2186.4299
# Month=34, Predicted=2187.1096, Expected=2201.5601
# Month=35, Predicted=2202.2065, Expected=2198.5500
# Month=36, Predicted=2199.2353, Expected=2206.2700
# Month=37, Predicted=2206.9323, Expected=2210.2100
# Month=38, Predicted=2210.8803, Expected=2200.7600
# Month=39, Predicted=2201.4590, Expected=2204.9700
# Month=40, Predicted=2205.6398, Expected=2200.1699
# Month=41, Predicted=2200.8590, Expected=2191.1201
# Month=42, Predicted=2191.8183, Expected=2200.6499
# Month=43, Predicted=2201.3083, Expected=2207.2600
# Month=44, Predicted=2207.9247, Expected=2210.7200
# Month=45, Predicted=2211.3914, Expected=2241.1299
# Month=46, Predicted=2241.7435, Expected=2249.7300
# Month=47, Predicted=2250.3904, Expected=2258.8301
# Month=48, Predicted=2259.4894, Expected=2263.3201
# Month=49, Predicted=2263.9893, Expected=2268.3501
# Month=50, Predicted=2269.0181, Expected=2253.7700
# Month=51, Predicted=2254.4800, Expected=2266.8101
# Month=52, Predicted=2267.4609, Expected=2259.2400
# Month=53, Predicted=2259.9350, Expected=2266.5000
# Month=54, Predicted=2267.1633, Expected=2270.5400
# Month=55, Predicted=2271.2102, Expected=2262.9299
# Month=56, Predicted=2263.6250, Expected=2260.2500
# Month=57, Predicted=2260.9345, Expected=2266.2300
# Month=58, Predicted=2266.8960, Expected=2270.2300
# Month=59, Predicted=2270.9002, Expected=2249.5000
# Month=60, Predicted=2250.2231, Expected=2251.6101
# Run 26 — RMSE: 11.102163, MSE: 123.258028, NMSE: 0.0007464273, Time: 84.0s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=2155.8738, Expected=2158.2200
# Month=2, Predicted=2158.9183, Expected=2164.1899
# Month=3, Predicted=2164.8817, Expected=2160.3899
# Month=4, Predicted=2161.1038, Expected=2161.3501
# Month=5, Predicted=2162.0532, Expected=2137.6699
# Month=6, Predicted=2138.4281, Expected=2130.2600
# Month=7, Predicted=2130.9820, Expected=2139.6799
# Month=8, Predicted=2140.3638, Expected=2132.9500
# Month=9, Predicted=2133.6705, Expected=2138.3101
# Month=10, Predicted=2139.0032, Expected=2140.8101
# Month=11, Predicted=2141.5097, Expected=2142.5100
# Month=12, Predicted=2143.2115, Expected=2139.4299
# Month=13, Predicted=2140.1422, Expected=2148.5000
# Month=14, Predicted=2149.1847, Expected=2149.7200
# Month=15, Predicted=2150.4225, Expected=2136.9700
# Month=16, Predicted=2137.7040, Expected=2144.0601
# Month=17, Predicted=2144.7492, Expected=2132.2300
# Month=18, Predicted=2132.9619, Expected=2129.7800
# Month=19, Predicted=2130.4909, Expected=2128.6799
# Month=20, Predicted=2129.3877, Expected=2109.4299
# Month=21, Predicted=2110.1784, Expected=2098.8000
# Month=22, Predicted=2099.5293, Expected=2083.7900
# Month=23, Predicted=2084.5291, Expected=2100.5901
# Month=24, Predicted=2101.2570, Expected=2129.9199
# Month=25, Predicted=2130.5577, Expected=2131.5601
# Month=26, Predicted=2132.2617, Expected=2167.4900
# Month=27, Predicted=2168.1124, Expected=2162.7100
# Month=28, Predicted=2163.4261, Expected=2165.6399
# Month=29, Predicted=2166.3386, Expected=2168.2900
# Month=30, Predicted=2168.9893, Expected=2177.5300
# Month=31, Predicted=2178.2143, Expected=2178.6101
# Month=32, Predicted=2179.3130, Expected=2186.8501
# Month=33, Predicted=2187.5366, Expected=2186.4299
# Month=34, Predicted=2187.1362, Expected=2201.5601
# Month=35, Predicted=2202.2308, Expected=2198.5500
# Month=36, Predicted=2199.2622, Expected=2206.2700
# Month=37, Predicted=2206.9578, Expected=2210.2100
# Month=38, Predicted=2210.9063, Expected=2200.7600
# Month=39, Predicted=2201.4866, Expected=2204.9700
# Month=40, Predicted=2205.6657, Expected=2200.1699
# Month=41, Predicted=2200.8861, Expected=2191.1201
# Month=42, Predicted=2191.8458, Expected=2200.6499
# Month=43, Predicted=2201.3335, Expected=2207.2600
# Month=44, Predicted=2207.9503, Expected=2210.7200
# Month=45, Predicted=2211.4174, Expected=2241.1299
# Month=46, Predicted=2241.7652, Expected=2249.7300
# Month=47, Predicted=2250.4157, Expected=2258.8301
# Month=48, Predicted=2259.5147, Expected=2263.3201
# Month=49, Predicted=2264.0152, Expected=2268.3501
# Month=50, Predicted=2269.0440, Expected=2253.7700
# Month=51, Predicted=2254.5081, Expected=2266.8101
# Month=52, Predicted=2267.4856, Expected=2259.2400
# Month=53, Predicted=2259.9624, Expected=2266.5000
# Month=54, Predicted=2267.1888, Expected=2270.5400
# Month=55, Predicted=2271.2362, Expected=2262.9299
# Month=56, Predicted=2263.6524, Expected=2260.2500
# Month=57, Predicted=2260.9614, Expected=2266.2300
# Month=58, Predicted=2266.9217, Expected=2270.2300
# Month=59, Predicted=2270.9262, Expected=2249.5000
# Month=60, Predicted=2250.2517, Expected=2251.6101
# Run 27 — RMSE: 11.100023, MSE: 123.210509, NMSE: 0.0007461584, Time: 89.4s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=2155.8801, Expected=2158.2200
# Month=2, Predicted=2158.9341, Expected=2164.1899
# Month=3, Predicted=2164.8999, Expected=2160.3899
# Month=4, Predicted=2161.1137, Expected=2161.3501
# Month=5, Predicted=2162.0672, Expected=2137.6699
# Month=6, Predicted=2138.4224, Expected=2130.2600
# Month=7, Predicted=2130.9890, Expected=2139.6799
# Month=8, Predicted=2140.3851, Expected=2132.9500
# Month=9, Predicted=2133.6780, Expected=2138.3101
# Month=10, Predicted=2139.0209, Expected=2140.8101
# Month=11, Predicted=2141.5250, Expected=2142.5100
# Month=12, Predicted=2143.2260, Expected=2139.4299
# Month=13, Predicted=2140.1528, Expected=2148.5000
# Month=14, Predicted=2149.2056, Expected=2149.7200
# Month=15, Predicted=2150.4367, Expected=2136.9700
# Month=16, Predicted=2137.7066, Expected=2144.0601
# Month=17, Predicted=2144.7685, Expected=2132.2300
# Month=18, Predicted=2132.9653, Expected=2129.7800
# Month=19, Predicted=2130.5020, Expected=2128.6799
# Month=20, Predicted=2129.3999, Expected=2109.4299
# Month=21, Predicted=2110.1760, Expected=2098.8000
# Month=22, Predicted=2099.5337, Expected=2083.7900
# Month=23, Predicted=2084.5299, Expected=2100.5901
# Month=24, Predicted=2101.2849, Expected=2129.9199
# Month=25, Predicted=2130.5973, Expected=2131.5601
# Month=26, Predicted=2132.2762, Expected=2167.4900
# Month=27, Predicted=2168.1583, Expected=2162.7100
# Month=28, Predicted=2163.4352, Expected=2165.6399
# Month=29, Predicted=2166.3542, Expected=2168.2900
# Month=30, Predicted=2169.0047, Expected=2177.5300
# Month=31, Predicted=2178.2354, Expected=2178.6101
# Month=32, Predicted=2179.3270, Expected=2186.8501
# Month=33, Predicted=2187.5569, Expected=2186.4299
# Month=34, Predicted=2187.1490, Expected=2201.5601
# Month=35, Predicted=2202.2572, Expected=2198.5500
# Month=36, Predicted=2199.2728, Expected=2206.2700
# Month=37, Predicted=2206.9775, Expected=2210.2100
# Month=38, Predicted=2210.9228, Expected=2200.7600
# Month=39, Predicted=2201.4919, Expected=2204.9700
# Month=40, Predicted=2205.6825, Expected=2200.1699
# Month=41, Predicted=2200.8952, Expected=2191.1201
# Month=42, Predicted=2191.8515, Expected=2200.6499
# Month=43, Predicted=2201.3549, Expected=2207.2600
# Month=44, Predicted=2207.9691, Expected=2210.7200
# Month=45, Predicted=2211.4335, Expected=2241.1299
# Month=46, Predicted=2241.8058, Expected=2249.7300
# Month=47, Predicted=2250.4363, Expected=2258.8301
# Month=48, Predicted=2259.5357, Expected=2263.3201
# Month=49, Predicted=2264.0322, Expected=2268.3501
# Month=50, Predicted=2269.0614, Expected=2253.7700
# Month=51, Predicted=2254.5093, Expected=2266.8101
# Month=52, Predicted=2267.5101, Expected=2259.2400
# Month=53, Predicted=2259.9692, Expected=2266.5000
# Month=54, Predicted=2267.2082, Expected=2270.5400
# Month=55, Predicted=2271.2528, Expected=2262.9299
# Month=56, Predicted=2263.6592, Expected=2260.2500
# Month=57, Predicted=2260.9723, Expected=2266.2300
# Month=58, Predicted=2266.9400, Expected=2270.2300
# Month=59, Predicted=2270.9428, Expected=2249.5000
# Month=60, Predicted=2250.2482, Expected=2251.6101
# Run 28 — RMSE: 11.098653, MSE: 123.180094, NMSE: 0.0007459391, Time: 86.6s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=2155.7911, Expected=2158.2200
# Month=2, Predicted=2158.8499, Expected=2164.1899
# Month=3, Predicted=2164.8167, Expected=2160.3899
# Month=4, Predicted=2161.0268, Expected=2161.3501
# Month=5, Predicted=2161.9822, Expected=2137.6699
# Month=6, Predicted=2138.3246, Expected=2130.2600
# Month=7, Predicted=2130.9005, Expected=2139.6799
# Month=8, Predicted=2140.3028, Expected=2132.9500
# Month=9, Predicted=2133.5898, Expected=2138.3101
# Month=10, Predicted=2138.9375, Expected=2140.8101
# Month=11, Predicted=2141.4406, Expected=2142.5100
# Month=12, Predicted=2143.1413, Expected=2139.4299
# Month=13, Predicted=2140.0662, Expected=2148.5000
# Month=14, Predicted=2149.1233, Expected=2149.7200
# Month=15, Predicted=2150.3518, Expected=2136.9700
# Month=16, Predicted=2137.6154, Expected=2144.0601
# Month=17, Predicted=2144.6856, Expected=2132.2300
# Month=18, Predicted=2132.8746, Expected=2129.7800
# Month=19, Predicted=2130.4156, Expected=2128.6799
# Month=20, Predicted=2129.3142, Expected=2109.4299
# Month=21, Predicted=2110.0810, Expected=2098.8000
# Month=22, Predicted=2099.4435, Expected=2083.7900
# Month=23, Predicted=2084.4375, Expected=2100.5901
# Month=24, Predicted=2101.2043, Expected=2129.9199
# Month=25, Predicted=2130.5181, Expected=2131.5601
# Month=26, Predicted=2132.1915, Expected=2167.4900
# Month=27, Predicted=2168.0790, Expected=2162.7100
# Month=28, Predicted=2163.3479, Expected=2165.6399
# Month=29, Predicted=2166.2699, Expected=2168.2900
# Month=30, Predicted=2168.9204, Expected=2177.5300
# Month=31, Predicted=2178.1531, Expected=2178.6101
# Month=32, Predicted=2179.2421, Expected=2186.8501
# Month=33, Predicted=2187.4743, Expected=2186.4299
# Month=34, Predicted=2187.0635, Expected=2201.5601
# Month=35, Predicted=2202.1763, Expected=2198.5500
# Month=36, Predicted=2199.1862, Expected=2206.2700
# Month=37, Predicted=2206.8948, Expected=2210.2100
# Month=38, Predicted=2210.8389, Expected=2200.7600
# Month=39, Predicted=2201.4024, Expected=2204.9700
# Month=40, Predicted=2205.5986, Expected=2200.1699
# Month=41, Predicted=2200.8079, Expected=2191.1201
# Month=42, Predicted=2191.7621, Expected=2200.6499
# Month=43, Predicted=2201.2727, Expected=2207.2600
# Month=44, Predicted=2207.8861, Expected=2210.7200
# Month=45, Predicted=2211.3494, Expected=2241.1299
# Month=46, Predicted=2241.7266, Expected=2249.7300
# Month=47, Predicted=2250.3538, Expected=2258.8301
# Month=48, Predicted=2259.4533, Expected=2263.3201
# Month=49, Predicted=2263.9484, Expected=2268.3501
# Month=50, Predicted=2268.9779, Expected=2253.7700
# Month=51, Predicted=2254.4171, Expected=2266.8101
# Month=52, Predicted=2267.4288, Expected=2259.2400
# Month=53, Predicted=2259.8806, Expected=2266.5000
# Month=54, Predicted=2267.1253, Expected=2270.5400
# Month=55, Predicted=2271.1689, Expected=2262.9299
# Month=56, Predicted=2263.5706, Expected=2260.2500
# Month=57, Predicted=2260.8858, Expected=2266.2300
# Month=58, Predicted=2266.8567, Expected=2270.2300
# Month=59, Predicted=2270.8589, Expected=2249.5000
# Month=60, Predicted=2250.1523, Expected=2251.6101
# Run 29 — RMSE: 11.105758, MSE: 123.337865, NMSE: 0.0007468280, Time: 96.6s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=2156.0868, Expected=2158.2200
# Month=2, Predicted=2158.5340, Expected=2164.1899
# Month=3, Predicted=2164.3732, Expected=2160.3899
# Month=4, Predicted=2161.0731, Expected=2161.3501
# Month=5, Predicted=2161.7708, Expected=2137.6699
# Month=6, Predicted=2139.3691, Expected=2130.2600
# Month=7, Predicted=2131.1505, Expected=2139.6799
# Month=8, Predicted=2139.7406, Expected=2132.9500
# Month=9, Predicted=2133.8014, Expected=2138.3101
# Month=10, Predicted=2138.5190, Expected=2140.8101
# Month=11, Predicted=2141.1521, Expected=2142.5100
# Month=12, Predicted=2142.8924, Expected=2139.4299
# Month=13, Predicted=2140.0722, Expected=2148.5000
# Month=14, Predicted=2148.5711, Expected=2149.7200
# Month=15, Predicted=2150.1271, Expected=2136.9700
# Month=16, Predicted=2138.1597, Expected=2144.0601
# Month=17, Predicted=2144.1991, Expected=2132.2300
# Month=18, Predicted=2133.3696, Expected=2129.7800
# Month=19, Predicted=2130.3867, Expected=2128.6799
# Month=20, Predicted=2129.2115, Expected=2109.4299
# Month=21, Predicted=2110.9446, Expected=2098.8000
# Month=22, Predicted=2099.8732, Expected=2083.7900
# Month=23, Predicted=2085.0989, Expected=2100.5901
# Month=24, Predicted=2100.5655, Expected=2129.9199
# Month=25, Predicted=2130.5900, Expected=2131.5601
# Month=26, Predicted=2131.9455, Expected=2167.4900
# Month=27, Predicted=2169.0574, Expected=2162.7100
# Month=28, Predicted=2163.4493, Expected=2165.6399
# Month=29, Predicted=2165.9607, Expected=2168.2900
# Month=30, Predicted=2168.6246, Expected=2177.5300
# Month=31, Predicted=2177.5960, Expected=2178.6101
# Month=32, Predicted=2179.0245, Expected=2186.8501
# Month=33, Predicted=2186.9480, Expected=2186.4299
# Month=34, Predicted=2186.9243, Expected=2201.5601
# Month=35, Predicted=2201.5290, Expected=2198.5500
# Month=36, Predicted=2199.1884, Expected=2206.2700
# Month=37, Predicted=2206.3859, Expected=2210.2100
# Month=38, Predicted=2210.4826, Expected=2200.7600
# Month=39, Predicted=2201.7669, Expected=2204.9700
# Month=40, Predicted=2205.2301, Expected=2200.1699
# Month=41, Predicted=2200.9104, Expected=2191.1201
# Month=42, Predicted=2192.1043, Expected=2200.6499
# Month=43, Predicted=2200.7074, Expected=2207.2600
# Month=44, Predicted=2207.4175, Expected=2210.7200
# Month=45, Predicted=2211.0152, Expected=2241.1299
# Month=46, Predicted=2241.9206, Expected=2249.7300
# Month=47, Predicted=2249.8159, Expected=2258.8301
# Month=48, Predicted=2258.9003, Expected=2263.3201
# Month=49, Predicted=2263.5674, Expected=2268.3501
# Month=50, Predicted=2268.5734, Expected=2253.7700
# Month=51, Predicted=2255.0567, Expected=2266.8101
# Month=52, Predicted=2266.7937, Expected=2259.2400
# Month=53, Predicted=2260.1397, Expected=2266.5000
# Month=54, Predicted=2266.6326, Expected=2270.5400
# Month=55, Predicted=2270.8080, Expected=2262.9299
# Month=56, Predicted=2263.8319, Expected=2260.2500
# Month=57, Predicted=2260.8697, Expected=2266.2300
# Month=58, Predicted=2266.4128, Expected=2270.2300
# Month=59, Predicted=2270.4998, Expected=2249.5000
# Month=60, Predicted=2251.0800, Expected=2251.6101
# Run 30 — RMSE: 11.129380, MSE: 123.863110, NMSE: 0.0007529700, Time: 98.2s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Autoformer on S&P 500 (30 runs) =====
# RMSE: 11.107278 ± 0.019017
# MSE:  123.371987 ± 0.423423
# NMSE: 0.0007474606 ± 0.0000036927
# Avg training time: 76.8s ± 24.8s
#
# Best run: 24
#   RMSE: 11.085909
#   MSE:  122.897385
#   NMSE: 0.0007442363

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Autoformer — S&P 500\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Autoformer — S&P 500\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 11.085909
# MSE:  122.897385
# NMSE: 0.0007442363

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Autoformer_SP500_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to Autoformer_SP500_predictions.csv

# %% [markdown]
# ## Observations
#
# ### Autoformer on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
