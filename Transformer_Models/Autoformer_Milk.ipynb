# %% [markdown]
# # Autoformer — Monthly Milk Production
#
# **Model**: Auto-Correlation with Series Decomposition
# **Reference**: Wu et al., 2021 — Autoformer: Decomposition Transformers with Auto-Correlation for Long-Term Series Forecasting
#
# ## Description
# This notebook implements the **Autoformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Milk Production dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Autoformer Architecture
#
# ### Series Decomposition
# Autoformer applies deep decomposition at each encoder layer:
#
# $$X_{\text{seasonal}}, X_{\text{trend}} = \text{SeriesDecomp}(X)$$
#
# The trend is extracted via moving average:
# $$X_{\text{trend}} = \text{AvgPool}(\text{Padding}(X))$$
# $$X_{\text{seasonal}} = X - X_{\text{trend}}$$
#
# ### Auto-Correlation Mechanism
# Instead of point-wise attention, Autoformer discovers **period-based dependencies** using FFT:
#
# 1. Compute auto-correlation via FFT: $R_{QK}(\tau) = \mathcal{F}^{-1}(\mathcal{F}(Q) \cdot \overline{\mathcal{F}(K)})$
# 2. Select top-$k$ time delays with highest correlation
# 3. Aggregate values at those delays with softmax weights
#
# This captures inherent periodicity in time series more naturally than dot-product attention.
#
# ### Complexity
# Auto-correlation operates in $O(L \log L)$ via FFT.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### Autoformer Model Definition

# %%
# ============================================================
# Autoformer: Auto-Correlation with Series Decomposition
# Reference: Wu et al., 2021
#
# Key ideas:
# 1. Series decomposition: separate trend and seasonal components
# 2. Auto-Correlation mechanism: replaces self-attention with
#    period-based dependencies via FFT
# ============================================================

class SeriesDecomposition(nn.Module):
    """Series decomposition block: extract trend via moving average."""
    def __init__(self, kernel_size=3):
        super().__init__()
        self.kernel_size = kernel_size
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        # x: (B, L, D)
        # Transpose for AvgPool1d: (B, D, L)
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class AutoCorrelationLayer(nn.Module):
    """
    Auto-Correlation Mechanism.
    Uses FFT to find period-based dependencies, then aggregates
    top-k correlated time delays.
    """
    def __init__(self, d_model, n_heads, factor=3):
        super().__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.factor = factor

        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, _ = x.shape
        H = self.n_heads
        D = self.d_k

        Q = self.W_Q(x).view(B, L, H, D).transpose(1, 2)  # [B, H, L, D]
        K = self.W_K(x).view(B, L, H, D).transpose(1, 2)
        V = self.W_V(x).view(B, L, H, D).transpose(1, 2)

        # Auto-correlation via FFT
        Q_fft = torch.fft.rfft(Q, dim=2)
        K_fft = torch.fft.rfft(K, dim=2)

        # Cross-correlation in frequency domain
        corr = Q_fft * torch.conj(K_fft)
        corr_real = torch.fft.irfft(corr, n=L, dim=2)  # [B, H, L, D]

        # Find top-k delays
        top_k = max(1, int(self.factor * np.log(L + 1)))
        top_k = min(top_k, L)

        # Mean correlation across D dimension
        mean_corr = corr_real.mean(dim=-1)  # [B, H, L]
        _, top_idx = mean_corr.topk(top_k, dim=-1)  # [B, H, top_k]

        # Aggregate values at top-k delays
        weights = torch.softmax(
            torch.gather(mean_corr, -1, top_idx), dim=-1
        )  # [B, H, top_k]

        # Roll and aggregate
        output = torch.zeros_like(V)
        for i in range(top_k):
            delay = top_idx[:, :, i:i+1].unsqueeze(-1).expand(-1, -1, -1, D)
            w = weights[:, :, i:i+1].unsqueeze(-1)  # [B, H, 1, 1]
            rolled_V = torch.roll(V, shifts=1, dims=2)  # Approximate roll
            output = output + w * rolled_V

        output = output.transpose(1, 2).contiguous().view(B, L, self.d_model)
        return self.out_proj(output)


class AutoformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.decomp1 = SeriesDecomposition(kernel_size=3)
        self.decomp2 = SeriesDecomposition(kernel_size=3)
        self.auto_corr = AutoCorrelationLayer(d_model, n_heads)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Auto-correlation + decomposition
        attn_out = self.auto_corr(x)
        x = x + self.dropout(attn_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class AutoformerModel(nn.Module):
    """
    Autoformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.decomp_init = SeriesDecomposition(kernel_size=3)
        self.encoder_layers = nn.ModuleList([
            AutoformerEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20129
# Trainable parameters: 20129
# Memory estimate: 78.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=740.2270, Expected=804.0000
# Month=2, Predicted=796.0404, Expected=756.0000
# Month=3, Predicted=735.8784, Expected=860.0000
# Month=4, Predicted=871.4936, Expected=878.0000
# Month=5, Predicted=864.9026, Expected=942.0000
# Month=6, Predicted=937.2460, Expected=913.0000
# Month=7, Predicted=899.3618, Expected=869.0000
# Month=8, Predicted=850.9387, Expected=834.0000
# Month=9, Predicted=819.1559, Expected=790.0000
# Month=10, Predicted=771.9387, Expected=800.0000
# Month=11, Predicted=786.7366, Expected=763.0000
# Month=12, Predicted=747.5988, Expected=800.0000
# Month=13, Predicted=788.7322, Expected=826.0000
# Month=14, Predicted=813.4072, Expected=799.0000
# Month=15, Predicted=785.6282, Expected=890.0000
# Month=16, Predicted=895.7237, Expected=900.0000
# Month=17, Predicted=886.7366, Expected=961.0000
# Month=18, Predicted=955.3001, Expected=935.0000
# Month=19, Predicted=921.7394, Expected=894.0000
# Month=20, Predicted=877.2205, Expected=855.0000
# Month=21, Predicted=838.9553, Expected=809.0000
# Month=22, Predicted=789.9596, Expected=810.0000
# Month=23, Predicted=796.8553, Expected=766.0000
# Month=24, Predicted=747.9387, Expected=805.0000
# Month=25, Predicted=794.0556, Expected=821.0000
# Month=26, Predicted=807.8317, Expected=773.0000
# Month=27, Predicted=752.8784, Expected=883.0000
# Month=28, Predicted=897.1491, Expected=898.0000
# Month=29, Predicted=884.8040, Expected=957.0000
# Month=30, Predicted=950.6987, Expected=924.0000
# Month=31, Predicted=909.6316, Expected=881.0000
# Month=32, Predicted=863.3905, Expected=837.0000
# Month=33, Predicted=818.9387, Expected=784.0000
# Month=34, Predicted=760.7227, Expected=791.0000
# Month=35, Predicted=777.7470, Expected=760.0000
# Month=36, Predicted=746.0316, Expected=802.0000
# Month=37, Predicted=791.5891, Expected=828.0000
# Month=38, Predicted=815.4072, Expected=778.0000
# Month=39, Predicted=756.6938, Expected=889.0000
# Month=40, Predicted=903.5862, Expected=902.0000
# Month=41, Predicted=888.7632, Expected=969.0000
# Month=42, Predicted=965.2430, Expected=947.0000
# Month=43, Predicted=934.0555, Expected=908.0000
# Month=44, Predicted=891.9553, Expected=867.0000
# Month=45, Predicted=850.2205, Expected=815.0000
# Month=46, Predicted=792.4056, Expected=812.0000
# Month=47, Predicted=798.9680, Expected=773.0000
# Month=48, Predicted=756.9553, Expected=813.0000
# Month=49, Predicted=802.2270, Expected=834.0000
# Month=50, Predicted=821.0491, Expected=782.0000
# Month=51, Predicted=759.4056, Expected=892.0000
# Month=52, Predicted=906.1491, Expected=903.0000
# Month=53, Predicted=889.7411, Expected=966.0000
# Month=54, Predicted=960.9249, Expected=937.0000
# Month=55, Predicted=923.3618, Expected=896.0000
# Month=56, Predicted=879.2205, Expected=858.0000
# Month=57, Predicted=842.2882, Expected=817.0000
# Month=58, Predicted=800.2205, Expected=827.0000
# Month=59, Predicted=813.7366, Expected=797.0000
# Month=60, Predicted=783.2051, Expected=843.0000
# Run 1 — RMSE: 51.247550, MSE: 2626.311331, NMSE: 0.0100475103, Time: 21.0s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=749.4618, Expected=804.0000
# Month=2, Predicted=805.7163, Expected=756.0000
# Month=3, Predicted=725.7535, Expected=860.0000
# Month=4, Predicted=874.0342, Expected=878.0000
# Month=5, Predicted=870.6419, Expected=942.0000
# Month=6, Predicted=946.4112, Expected=913.0000
# Month=7, Predicted=890.4537, Expected=869.0000
# Month=8, Predicted=840.4544, Expected=834.0000
# Month=9, Predicted=809.1268, Expected=790.0000
# Month=10, Predicted=761.4544, Expected=800.0000
# Month=11, Predicted=790.3753, Expected=763.0000
# Month=12, Predicted=737.3295, Expected=800.0000
# Month=13, Predicted=797.6955, Expected=826.0000
# Month=14, Predicted=820.8183, Expected=799.0000
# Month=15, Predicted=777.2076, Expected=890.0000
# Month=16, Predicted=900.9202, Expected=900.0000
# Month=17, Predicted=890.3753, Expected=961.0000
# Month=18, Predicted=964.6801, Expected=935.0000
# Month=19, Predicted=913.5806, Expected=894.0000
# Month=20, Predicted=866.7026, Expected=855.0000
# Month=21, Predicted=828.5214, Expected=809.0000
# Month=22, Predicted=779.6091, Expected=810.0000
# Month=23, Predicted=797.6944, Expected=766.0000
# Month=24, Predicted=737.4544, Expected=805.0000
# Month=25, Predicted=803.2071, Expected=821.0000
# Month=26, Predicted=813.0844, Expected=773.0000
# Month=27, Predicted=742.7535, Expected=883.0000
# Month=28, Predicted=898.4702, Expected=898.0000
# Month=29, Predicted=889.8035, Expected=957.0000
# Month=30, Predicted=960.1912, Expected=924.0000
# Month=31, Predicted=899.9133, Expected=881.0000
# Month=32, Predicted=852.8731, Expected=837.0000
# Month=33, Predicted=808.4544, Expected=784.0000
# Month=34, Predicted=751.5702, Expected=791.0000
# Month=35, Predicted=780.4983, Expected=760.0000
# Month=36, Predicted=736.6889, Expected=802.0000
# Month=37, Predicted=800.9691, Expected=828.0000
# Month=38, Predicted=822.8183, Expected=778.0000
# Month=39, Predicted=746.8877, Expected=889.0000
# Month=40, Predicted=904.7094, Expected=902.0000
# Month=41, Predicted=893.2370, Expected=969.0000
# Month=42, Predicted=974.1400, Expected=947.0000
# Month=43, Predicted=927.0456, Expected=908.0000
# Month=44, Predicted=881.5214, Expected=867.0000
# Month=45, Predicted=839.7026, Expected=815.0000
# Month=46, Predicted=783.0118, Expected=812.0000
# Month=47, Predicted=798.4518, Expected=773.0000
# Month=48, Predicted=746.5214, Expected=813.0000
# Month=49, Predicted=811.4618, Expected=834.0000
# Month=50, Predicted=827.4677, Expected=782.0000
# Month=51, Predicted=750.0118, Expected=892.0000
# Month=52, Predicted=907.4702, Expected=903.0000
# Month=53, Predicted=893.6642, Expected=966.0000
# Month=54, Predicted=970.1678, Expected=937.0000
# Month=55, Predicted=914.4537, Expected=896.0000
# Month=56, Predicted=868.7026, Expected=858.0000
# Month=57, Predicted=831.9268, Expected=817.0000
# Month=58, Predicted=789.7026, Expected=827.0000
# Month=59, Predicted=817.3753, Expected=797.0000
# Month=60, Predicted=774.0726, Expected=843.0000
# Run 2 — RMSE: 53.492010, MSE: 2861.395142, NMSE: 0.0100053267, Time: 20.5s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=753.2844, Expected=804.0000
# Month=2, Predicted=808.3446, Expected=756.0000
# Month=3, Predicted=734.4500, Expected=860.0000
# Month=4, Predicted=872.3252, Expected=878.0000
# Month=5, Predicted=876.7782, Expected=942.0000
# Month=6, Predicted=948.0942, Expected=913.0000
# Month=7, Predicted=905.7076, Expected=869.0000
# Month=8, Predicted=851.8667, Expected=834.0000
# Month=9, Predicted=824.2803, Expected=790.0000
# Month=10, Predicted=772.8667, Expected=800.0000
# Month=11, Predicted=797.4606, Expected=763.0000
# Month=12, Predicted=752.0260, Expected=800.0000
# Month=13, Predicted=801.8105, Expected=826.0000
# Month=14, Predicted=826.0677, Expected=799.0000
# Month=15, Predicted=792.1540, Expected=890.0000
# Month=16, Predicted=900.3399, Expected=900.0000
# Month=17, Predicted=897.4606, Expected=961.0000
# Month=18, Predicted=966.6170, Expected=935.0000
# Month=19, Predicted=928.3277, Expected=894.0000
# Month=20, Predicted=879.8142, Expected=855.0000
# Month=21, Predicted=842.5336, Expected=809.0000
# Month=22, Predicted=789.7102, Expected=810.0000
# Month=23, Predicted=806.0112, Expected=766.0000
# Month=24, Predicted=748.8667, Expected=805.0000
# Month=25, Predicted=807.1264, Expected=821.0000
# Month=26, Predicted=819.4509, Expected=773.0000
# Month=27, Predicted=751.4500, Expected=883.0000
# Month=28, Predicted=896.2243, Expected=898.0000
# Month=29, Predicted=896.2866, Expected=957.0000
# Month=30, Predicted=962.2988, Expected=924.0000
# Month=31, Predicted=915.2998, Expected=881.0000
# Month=32, Predicted=864.8926, Expected=837.0000
# Month=33, Predicted=819.8667, Expected=784.0000
# Month=34, Predicted=756.6009, Expected=791.0000
# Month=35, Predicted=787.9662, Expected=760.0000
# Month=36, Predicted=752.1002, Expected=802.0000
# Month=37, Predicted=804.6006, Expected=828.0000
# Month=38, Predicted=828.0677, Expected=778.0000
# Month=39, Predicted=754.1271, Expected=889.0000
# Month=40, Predicted=902.3730, Expected=902.0000
# Month=41, Predicted=899.9568, Expected=969.0000
# Month=42, Predicted=975.5709, Expected=947.0000
# Month=43, Predicted=940.7909, Expected=908.0000
# Month=44, Predicted=895.5336, Expected=867.0000
# Month=45, Predicted=852.8142, Expected=815.0000
# Month=46, Predicted=788.7772, Expected=812.0000
# Month=47, Predicted=807.4327, Expected=773.0000
# Month=48, Predicted=760.5336, Expected=813.0000
# Month=49, Predicted=815.2844, Expected=834.0000
# Month=50, Predicted=833.2652, Expected=782.0000
# Month=51, Predicted=755.7772, Expected=892.0000
# Month=52, Predicted=905.2243, Expected=903.0000
# Month=53, Predicted=900.6261, Expected=966.0000
# Month=54, Predicted=971.9351, Expected=937.0000
# Month=55, Predicted=929.7076, Expected=896.0000
# Month=56, Predicted=881.8142, Expected=858.0000
# Month=57, Predicted=846.3092, Expected=817.0000
# Month=58, Predicted=802.8142, Expected=827.0000
# Month=59, Predicted=824.4606, Expected=797.0000
# Month=60, Predicted=789.4262, Expected=843.0000
# Run 3 — RMSE: 51.414882, MSE: 2643.490119, NMSE: 0.0100314594, Time: 24.4s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=745.3990, Expected=804.0000
# Month=2, Predicted=800.7149, Expected=756.0000
# Month=3, Predicted=725.0068, Expected=860.0000
# Month=4, Predicted=867.8976, Expected=878.0000
# Month=5, Predicted=869.7425, Expected=942.0000
# Month=6, Predicted=940.9205, Expected=913.0000
# Month=7, Predicted=905.4516, Expected=869.0000
# Month=8, Predicted=845.0214, Expected=834.0000
# Month=9, Predicted=822.2476, Expected=790.0000
# Month=10, Predicted=766.0214, Expected=800.0000
# Month=11, Predicted=791.4124, Expected=763.0000
# Month=12, Predicted=749.1120, Expected=800.0000
# Month=13, Predicted=793.9259, Expected=826.0000
# Month=14, Predicted=818.4619, Expected=799.0000
# Month=15, Predicted=792.1876, Expected=890.0000
# Month=16, Predicted=894.8746, Expected=900.0000
# Month=17, Predicted=891.4124, Expected=961.0000
# Month=18, Predicted=959.3018, Expected=935.0000
# Month=19, Predicted=928.4515, Expected=894.0000
# Month=20, Predicted=874.7854, Expected=855.0000
# Month=21, Predicted=838.6147, Expected=809.0000
# Month=22, Predicted=781.5832, Expected=810.0000
# Month=23, Predicted=801.6287, Expected=766.0000
# Month=24, Predicted=742.0214, Expected=805.0000
# Month=25, Predicted=799.2383, Expected=821.0000
# Month=26, Predicted=812.6196, Expected=773.0000
# Month=27, Predicted=742.0068, Expected=883.0000
# Month=28, Predicted=892.3132, Expected=898.0000
# Month=29, Predicted=889.5678, Expected=957.0000
# Month=30, Predicted=954.8959, Expected=924.0000
# Month=31, Predicted=914.0094, Expected=881.0000
# Month=32, Predicted=858.6695, Expected=837.0000
# Month=33, Predicted=813.0214, Expected=784.0000
# Month=34, Predicted=743.8103, Expected=791.0000
# Month=35, Predicted=782.4094, Expected=760.0000
# Month=36, Predicted=751.4035, Expected=802.0000
# Month=37, Predicted=796.7289, Expected=828.0000
# Month=38, Predicted=820.4619, Expected=778.0000
# Month=39, Predicted=743.3491, Expected=889.0000
# Month=40, Predicted=898.5501, Expected=902.0000
# Month=41, Predicted=893.4842, Expected=969.0000
# Month=42, Predicted=968.5503, Expected=947.0000
# Month=43, Predicted=940.9460, Expected=908.0000
# Month=44, Predicted=891.6147, Expected=867.0000
# Month=45, Predicted=847.7854, Expected=815.0000
# Month=46, Predicted=776.6575, Expected=812.0000
# Month=47, Predicted=803.9489, Expected=773.0000
# Month=48, Predicted=756.6147, Expected=813.0000
# Month=49, Predicted=807.3990, Expected=834.0000
# Month=50, Predicted=825.9718, Expected=782.0000
# Month=51, Predicted=743.6575, Expected=892.0000
# Month=52, Predicted=901.3132, Expected=903.0000
# Month=53, Predicted=894.4290, Expected=966.0000
# Month=54, Predicted=964.7130, Expected=937.0000
# Month=55, Predicted=929.4516, Expected=896.0000
# Month=56, Predicted=876.7854, Expected=858.0000
# Month=57, Predicted=842.9071, Expected=817.0000
# Month=58, Predicted=797.7854, Expected=827.0000
# Month=59, Predicted=818.4124, Expected=797.0000
# Month=60, Predicted=788.9689, Expected=843.0000
# Run 4 — RMSE: 53.560126, MSE: 2868.687107, NMSE: 0.0102986170, Time: 27.3s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=749.4161, Expected=804.0000
# Month=2, Predicted=805.1861, Expected=756.0000
# Month=3, Predicted=729.4741, Expected=860.0000
# Month=4, Predicted=871.9209, Expected=878.0000
# Month=5, Predicted=871.6723, Expected=942.0000
# Month=6, Predicted=945.5235, Expected=913.0000
# Month=7, Predicted=894.3022, Expected=869.0000
# Month=8, Predicted=844.3428, Expected=834.0000
# Month=9, Predicted=813.1032, Expected=790.0000
# Month=10, Predicted=765.3428, Expected=800.0000
# Month=11, Predicted=791.8902, Expected=763.0000
# Month=12, Predicted=741.3180, Expected=800.0000
# Month=13, Predicted=797.7753, Expected=826.0000
# Month=14, Predicted=821.4137, Expected=799.0000
# Month=15, Predicted=780.9870, Expected=890.0000
# Month=16, Predicted=899.2157, Expected=900.0000
# Month=17, Predicted=891.8902, Expected=961.0000
# Month=18, Predicted=963.8867, Expected=935.0000
# Month=19, Predicted=917.3210, Expected=894.0000
# Month=20, Predicted=870.6625, Expected=855.0000
# Month=21, Predicted=832.5047, Expected=809.0000
# Month=22, Predicted=783.4243, Expected=810.0000
# Month=23, Predicted=799.8007, Expected=766.0000
# Month=24, Predicted=741.3428, Expected=805.0000
# Month=25, Predicted=803.2026, Expected=821.0000
# Month=26, Predicted=814.2315, Expected=773.0000
# Month=27, Predicted=746.4741, Expected=883.0000
# Month=28, Predicted=896.1603, Expected=898.0000
# Month=29, Predicted=891.0100, Expected=957.0000
# Month=30, Predicted=959.4618, Expected=924.0000
# Month=31, Predicted=903.8616, Expected=881.0000
# Month=32, Predicted=856.7903, Expected=837.0000
# Month=33, Predicted=812.3428, Expected=784.0000
# Month=34, Predicted=754.9573, Expected=791.0000
# Month=35, Predicted=782.2059, Expected=760.0000
# Month=36, Predicted=740.5942, Expected=802.0000
# Month=37, Predicted=800.8429, Expected=828.0000
# Month=38, Predicted=823.4137, Expected=778.0000
# Month=39, Predicted=750.4918, Expected=889.0000
# Month=40, Predicted=902.3663, Expected=902.0000
# Month=41, Predicted=894.5648, Expected=969.0000
# Month=42, Predicted=973.1597, Expected=947.0000
# Month=43, Predicted=930.6049, Expected=908.0000
# Month=44, Predicted=885.5047, Expected=867.0000
# Month=45, Predicted=843.6625, Expected=815.0000
# Month=46, Predicted=786.4770, Expected=812.0000
# Month=47, Predicted=800.8293, Expected=773.0000
# Month=48, Predicted=750.5047, Expected=813.0000
# Month=49, Predicted=811.4161, Expected=834.0000
# Month=50, Predicted=828.3289, Expected=782.0000
# Month=51, Predicted=753.4770, Expected=892.0000
# Month=52, Predicted=905.1603, Expected=903.0000
# Month=53, Predicted=895.1160, Expected=966.0000
# Month=54, Predicted=969.3113, Expected=937.0000
# Month=55, Predicted=918.3022, Expected=896.0000
# Month=56, Predicted=872.6625, Expected=858.0000
# Month=57, Predicted=835.9149, Expected=817.0000
# Month=58, Predicted=793.6625, Expected=827.0000
# Month=59, Predicted=818.8902, Expected=797.0000
# Month=60, Predicted=777.9512, Expected=843.0000
# Run 5 — RMSE: 52.416904, MSE: 2747.531823, NMSE: 0.0099965290, Time: 30.4s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=753.2473, Expected=804.0000
# Month=2, Predicted=809.0786, Expected=756.0000
# Month=3, Predicted=725.5012, Expected=860.0000
# Month=4, Predicted=877.6998, Expected=878.0000
# Month=5, Predicted=876.0974, Expected=942.0000
# Month=6, Predicted=949.6289, Expected=913.0000
# Month=7, Predicted=908.1961, Expected=869.0000
# Month=8, Predicted=845.9003, Expected=834.0000
# Month=9, Predicted=824.0870, Expected=790.0000
# Month=10, Predicted=766.9003, Expected=800.0000
# Month=11, Predicted=796.9848, Expected=763.0000
# Month=12, Predicted=750.6886, Expected=800.0000
# Month=13, Predicted=801.6268, Expected=826.0000
# Month=14, Predicted=825.4813, Expected=799.0000
# Month=15, Predicted=795.2244, Expected=890.0000
# Month=16, Predicted=904.3268, Expected=900.0000
# Month=17, Predicted=896.9848, Expected=961.0000
# Month=18, Predicted=967.9209, Expected=935.0000
# Month=19, Predicted=931.6241, Expected=894.0000
# Month=20, Predicted=875.9320, Expected=855.0000
# Month=21, Predicted=839.9613, Expected=809.0000
# Month=22, Predicted=782.2811, Expected=810.0000
# Month=23, Predicted=806.3577, Expected=766.0000
# Month=24, Predicted=742.9003, Expected=805.0000
# Month=25, Predicted=807.0390, Expected=821.0000
# Month=26, Predicted=818.7869, Expected=773.0000
# Month=27, Predicted=742.5012, Expected=883.0000
# Month=28, Predicted=902.2765, Expected=898.0000
# Month=29, Predicted=895.6386, Expected=957.0000
# Month=30, Predicted=963.4539, Expected=924.0000
# Month=31, Predicted=916.1395, Expected=881.0000
# Month=32, Predicted=859.6358, Expected=837.0000
# Month=33, Predicted=813.9003, Expected=784.0000
# Month=34, Predicted=743.6230, Expected=791.0000
# Month=35, Predicted=787.6822, Expected=760.0000
# Month=36, Predicted=753.8404, Expected=802.0000
# Month=37, Predicted=804.6683, Expected=828.0000
# Month=38, Predicted=827.4813, Expected=778.0000
# Month=39, Predicted=743.6037, Expected=889.0000
# Month=40, Predicted=908.5403, Expected=902.0000
# Month=41, Predicted=899.3581, Expected=969.0000
# Month=42, Predicted=977.3454, Expected=947.0000
# Month=43, Predicted=944.5650, Expected=908.0000
# Month=44, Predicted=892.9613, Expected=867.0000
# Month=45, Predicted=848.9320, Expected=815.0000
# Month=46, Predicted=776.6285, Expected=812.0000
# Month=47, Predicted=808.3972, Expected=773.0000
# Month=48, Predicted=757.9613, Expected=813.0000
# Month=49, Predicted=815.2473, Expected=834.0000
# Month=50, Predicted=832.5930, Expected=782.0000
# Month=51, Predicted=743.6285, Expected=892.0000
# Month=52, Predicted=911.2765, Expected=903.0000
# Month=53, Predicted=900.1022, Expected=966.0000
# Month=54, Predicted=973.3919, Expected=937.0000
# Month=55, Predicted=932.1961, Expected=896.0000
# Month=56, Predicted=877.9320, Expected=858.0000
# Month=57, Predicted=844.3646, Expected=817.0000
# Month=58, Predicted=798.9320, Expected=827.0000
# Month=59, Predicted=823.9848, Expected=797.0000
# Month=60, Predicted=791.5606, Expected=843.0000
# Run 6 — RMSE: 53.618733, MSE: 2874.968560, NMSE: 0.0100676947, Time: 25.8s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=752.4847, Expected=804.0000
# Month=2, Predicted=809.1894, Expected=756.0000
# Month=3, Predicted=732.7698, Expected=860.0000
# Month=4, Predicted=877.7005, Expected=878.0000
# Month=5, Predicted=874.4464, Expected=942.0000
# Month=6, Predicted=950.4429, Expected=913.0000
# Month=7, Predicted=899.9552, Expected=869.0000
# Month=8, Predicted=848.4293, Expected=834.0000
# Month=9, Predicted=818.4019, Expected=790.0000
# Month=10, Predicted=769.4293, Expected=800.0000
# Month=11, Predicted=795.0745, Expected=763.0000
# Month=12, Predicted=746.4183, Expected=800.0000
# Month=13, Predicted=800.6894, Expected=826.0000
# Month=14, Predicted=824.0550, Expected=799.0000
# Month=15, Predicted=786.6818, Expected=890.0000
# Month=16, Predicted=905.3766, Expected=900.0000
# Month=17, Predicted=895.0745, Expected=961.0000
# Month=18, Predicted=968.5606, Expected=935.0000
# Month=19, Predicted=923.0234, Expected=894.0000
# Month=20, Predicted=875.2436, Expected=855.0000
# Month=21, Predicted=837.3658, Expected=809.0000
# Month=22, Predicted=787.1334, Expected=810.0000
# Month=23, Predicted=803.7046, Expected=766.0000
# Month=24, Predicted=745.4293, Expected=805.0000
# Month=25, Predicted=806.2164, Expected=821.0000
# Month=26, Predicted=817.0835, Expected=773.0000
# Month=27, Predicted=749.7698, Expected=883.0000
# Month=28, Predicted=901.5261, Expected=898.0000
# Month=29, Predicted=893.9074, Expected=957.0000
# Month=30, Predicted=963.9685, Expected=924.0000
# Month=31, Predicted=909.3179, Expected=881.0000
# Month=32, Predicted=861.0515, Expected=837.0000
# Month=33, Predicted=816.4293, Expected=784.0000
# Month=34, Predicted=757.0788, Expected=791.0000
# Month=35, Predicted=785.6057, Expected=760.0000
# Month=36, Predicted=746.1681, Expected=802.0000
# Month=37, Predicted=804.0301, Expected=828.0000
# Month=38, Predicted=826.0550, Expected=778.0000
# Month=39, Predicted=753.3405, Expected=889.0000
# Month=40, Predicted=907.6493, Expected=902.0000
# Month=41, Predicted=897.5653, Expected=969.0000
# Month=42, Predicted=978.3136, Expected=947.0000
# Month=43, Predicted=936.2564, Expected=908.0000
# Month=44, Predicted=890.3658, Expected=867.0000
# Month=45, Predicted=848.2436, Expected=815.0000
# Month=46, Predicted=788.8479, Expected=812.0000
# Month=47, Predicted=805.1017, Expected=773.0000
# Month=48, Predicted=755.3658, Expected=813.0000
# Month=49, Predicted=814.4847, Expected=834.0000
# Month=50, Predicted=831.0194, Expected=782.0000
# Month=51, Predicted=755.8479, Expected=892.0000
# Month=52, Predicted=910.5261, Expected=903.0000
# Month=53, Predicted=898.2354, Expected=966.0000
# Month=54, Predicted=974.1499, Expected=937.0000
# Month=55, Predicted=923.9552, Expected=896.0000
# Month=56, Predicted=877.2436, Expected=858.0000
# Month=57, Predicted=840.9008, Expected=817.0000
# Month=58, Predicted=798.2436, Expected=827.0000
# Month=59, Predicted=822.0745, Expected=797.0000
# Month=60, Predicted=783.5694, Expected=843.0000
# Run 7 — RMSE: 51.816555, MSE: 2684.955350, NMSE: 0.0098412568, Time: 27.5s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=751.8207, Expected=804.0000
# Month=2, Predicted=807.2873, Expected=756.0000
# Month=3, Predicted=726.7209, Expected=860.0000
# Month=4, Predicted=873.2461, Expected=878.0000
# Month=5, Predicted=874.4425, Expected=942.0000
# Month=6, Predicted=947.3950, Expected=913.0000
# Month=7, Predicted=894.1780, Expected=869.0000
# Month=8, Predicted=842.1260, Expected=834.0000
# Month=9, Predicted=812.1537, Expected=790.0000
# Month=10, Predicted=763.1260, Expected=800.0000
# Month=11, Predicted=794.6323, Expected=763.0000
# Month=12, Predicted=740.0857, Expected=800.0000
# Month=13, Predicted=800.2488, Expected=826.0000
# Month=14, Predicted=824.1022, Expected=799.0000
# Month=15, Predicted=781.1247, Expected=890.0000
# Month=16, Predicted=900.6860, Expected=900.0000
# Month=17, Predicted=894.6323, Expected=961.0000
# Month=18, Predicted=965.8170, Expected=935.0000
# Month=19, Predicted=917.5864, Expected=894.0000
# Month=20, Predicted=868.8638, Expected=855.0000
# Month=21, Predicted=830.9887, Expected=809.0000
# Month=22, Predicted=780.9355, Expected=810.0000
# Month=23, Predicted=802.3233, Expected=766.0000
# Month=24, Predicted=739.1260, Expected=805.0000
# Month=25, Predicted=805.6304, Expected=821.0000
# Month=26, Predicted=817.0068, Expected=773.0000
# Month=27, Predicted=743.7209, Expected=883.0000
# Month=28, Predicted=897.4189, Expected=898.0000
# Month=29, Predicted=893.7851, Expected=957.0000
# Month=30, Predicted=961.4331, Expected=924.0000
# Month=31, Predicted=903.1921, Expected=881.0000
# Month=32, Predicted=854.7118, Expected=837.0000
# Month=33, Predicted=810.1260, Expected=784.0000
# Month=34, Predicted=751.5880, Expected=791.0000
# Month=35, Predicted=784.8999, Expected=760.0000
# Month=36, Predicted=740.2004, Expected=802.0000
# Month=37, Predicted=803.2006, Expected=828.0000
# Month=38, Predicted=826.1022, Expected=778.0000
# Month=39, Predicted=747.4836, Expected=889.0000
# Month=40, Predicted=903.6136, Expected=902.0000
# Month=41, Predicted=897.3332, Expected=969.0000
# Month=42, Predicted=974.9756, Expected=947.0000
# Month=43, Predicted=931.3558, Expected=908.0000
# Month=44, Predicted=883.9887, Expected=867.0000
# Month=45, Predicted=841.8638, Expected=815.0000
# Month=46, Predicted=783.2249, Expected=812.0000
# Month=47, Predicted=803.1756, Expected=773.0000
# Month=48, Predicted=748.9887, Expected=813.0000
# Month=49, Predicted=813.8207, Expected=834.0000
# Month=50, Predicted=831.0789, Expected=782.0000
# Month=51, Predicted=750.2249, Expected=892.0000
# Month=52, Predicted=906.4189, Expected=903.0000
# Month=53, Predicted=897.8693, Expected=966.0000
# Month=54, Predicted=971.2021, Expected=937.0000
# Month=55, Predicted=918.1780, Expected=896.0000
# Month=56, Predicted=870.8638, Expected=858.0000
# Month=57, Predicted=834.5408, Expected=817.0000
# Month=58, Predicted=791.8638, Expected=827.0000
# Month=59, Predicted=821.6323, Expected=797.0000
# Month=60, Predicted=777.6930, Expected=843.0000
# Run 8 — RMSE: 53.039966, MSE: 2813.237957, NMSE: 0.0100083757, Time: 27.0s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=749.7300, Expected=804.0000
# Month=2, Predicted=806.4215, Expected=756.0000
# Month=3, Predicted=720.3895, Expected=860.0000
# Month=4, Predicted=874.9692, Expected=878.0000
# Month=5, Predicted=869.7715, Expected=942.0000
# Month=6, Predicted=947.3482, Expected=913.0000
# Month=7, Predicted=886.2609, Expected=869.0000
# Month=8, Predicted=835.3140, Expected=834.0000
# Month=9, Predicted=804.5360, Expected=790.0000
# Month=10, Predicted=756.3140, Expected=800.0000
# Month=11, Predicted=788.9854, Expected=763.0000
# Month=12, Predicted=732.6113, Expected=800.0000
# Month=13, Predicted=797.8372, Expected=826.0000
# Month=14, Predicted=820.4161, Expected=799.0000
# Month=15, Predicted=773.1523, Expected=890.0000
# Month=16, Predicted=901.9715, Expected=900.0000
# Month=17, Predicted=888.9854, Expected=961.0000
# Month=18, Predicted=965.5659, Expected=935.0000
# Month=19, Predicted=909.5948, Expected=894.0000
# Month=20, Predicted=861.7385, Expected=855.0000
# Month=21, Predicted=823.6787, Expected=809.0000
# Month=22, Predicted=774.3552, Expected=810.0000
# Month=23, Predicted=795.6741, Expected=766.0000
# Month=24, Predicted=732.3140, Expected=805.0000
# Month=25, Predicted=803.4342, Expected=821.0000
# Month=26, Predicted=812.0885, Expected=773.0000
# Month=27, Predicted=737.3895, Expected=883.0000
# Month=28, Predicted=899.3262, Expected=898.0000
# Month=29, Predicted=888.7437, Expected=957.0000
# Month=30, Predicted=961.0380, Expected=924.0000
# Month=31, Predicted=895.4526, Expected=881.0000
# Month=32, Predicted=847.7906, Expected=837.0000
# Month=33, Predicted=803.3140, Expected=784.0000
# Month=34, Predicted=745.9458, Expected=791.0000
# Month=35, Predicted=778.9027, Expected=760.0000
# Month=36, Predicted=732.3610, Expected=802.0000
# Month=37, Predicted=801.3163, Expected=828.0000
# Month=38, Predicted=822.4161, Expected=778.0000
# Month=39, Predicted=741.4169, Expected=889.0000
# Month=40, Predicted=905.5511, Expected=902.0000
# Month=41, Predicted=892.0472, Expected=969.0000
# Month=42, Predicted=975.1196, Expected=947.0000
# Month=43, Predicted=923.3425, Expected=908.0000
# Month=44, Predicted=876.6787, Expected=867.0000
# Month=45, Predicted=834.7385, Expected=815.0000
# Month=46, Predicted=777.4378, Expected=812.0000
# Month=47, Predicted=796.1410, Expected=773.0000
# Month=48, Predicted=741.6787, Expected=813.0000
# Month=49, Predicted=811.7300, Expected=834.0000
# Month=50, Predicted=826.7794, Expected=782.0000
# Month=51, Predicted=744.4378, Expected=892.0000
# Month=52, Predicted=908.3262, Expected=903.0000
# Month=53, Predicted=892.3416, Expected=966.0000
# Month=54, Predicted=971.0887, Expected=937.0000
# Month=55, Predicted=910.2609, Expected=896.0000
# Month=56, Predicted=863.7385, Expected=858.0000
# Month=57, Predicted=827.1460, Expected=817.0000
# Month=58, Predicted=784.7385, Expected=827.0000
# Month=59, Predicted=815.9854, Expected=797.0000
# Month=60, Predicted=769.8120, Expected=843.0000
# Run 9 — RMSE: 55.144493, MSE: 3040.915163, NMSE: 0.0100928006, Time: 28.6s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=751.4539, Expected=804.0000
# Month=2, Predicted=806.4698, Expected=756.0000
# Month=3, Predicted=732.2710, Expected=860.0000
# Month=4, Predicted=870.7638, Expected=878.0000
# Month=5, Predicted=874.9748, Expected=942.0000
# Month=6, Predicted=946.2034, Expected=913.0000
# Month=7, Predicted=898.4371, Expected=869.0000
# Month=8, Predicted=847.5078, Expected=834.0000
# Month=9, Predicted=816.9360, Expected=790.0000
# Month=10, Predicted=768.5078, Expected=800.0000
# Month=11, Predicted=795.5952, Expected=763.0000
# Month=12, Predicted=745.0238, Expected=800.0000
# Month=13, Predicted=799.9901, Expected=826.0000
# Month=14, Predicted=824.2717, Expected=799.0000
# Month=15, Predicted=785.1961, Expected=890.0000
# Month=16, Predicted=898.5965, Expected=900.0000
# Month=17, Predicted=895.5952, Expected=961.0000
# Month=18, Predicted=964.7273, Expected=935.0000
# Month=19, Predicted=921.5624, Expected=894.0000
# Month=20, Predicted=874.0768, Expected=855.0000
# Month=21, Predicted=836.0709, Expected=809.0000
# Month=22, Predicted=786.4099, Expected=810.0000
# Month=23, Predicted=803.8774, Expected=766.0000
# Month=24, Predicted=744.5078, Expected=805.0000
# Month=25, Predicted=805.2993, Expected=821.0000
# Month=26, Predicted=817.6395, Expected=773.0000
# Month=27, Predicted=749.2710, Expected=883.0000
# Month=28, Predicted=894.7708, Expected=898.0000
# Month=29, Predicted=894.4697, Expected=957.0000
# Month=30, Predicted=960.4113, Expected=924.0000
# Month=31, Predicted=907.8082, Expected=881.0000
# Month=32, Predicted=860.0412, Expected=837.0000
# Month=33, Predicted=815.5078, Expected=784.0000
# Month=34, Predicted=757.2495, Expected=791.0000
# Month=35, Predicted=786.0462, Expected=760.0000
# Month=36, Predicted=744.6415, Expected=802.0000
# Month=37, Predicted=802.7629, Expected=828.0000
# Month=38, Predicted=826.2717, Expected=778.0000
# Month=39, Predicted=753.0917, Expected=889.0000
# Month=40, Predicted=900.9389, Expected=902.0000
# Month=41, Predicted=898.1253, Expected=969.0000
# Month=42, Predicted=973.6821, Expected=947.0000
# Month=43, Predicted=934.9438, Expected=908.0000
# Month=44, Predicted=889.0709, Expected=867.0000
# Month=45, Predicted=847.0768, Expected=815.0000
# Month=46, Predicted=788.8731, Expected=812.0000
# Month=47, Predicted=805.0333, Expected=773.0000
# Month=48, Predicted=754.0709, Expected=813.0000
# Month=49, Predicted=813.4539, Expected=834.0000
# Month=50, Predicted=831.4684, Expected=782.0000
# Month=51, Predicted=755.8731, Expected=892.0000
# Month=52, Predicted=903.7708, Expected=903.0000
# Month=53, Predicted=898.7739, Expected=966.0000
# Month=54, Predicted=970.0444, Expected=937.0000
# Month=55, Predicted=922.4371, Expected=896.0000
# Month=56, Predicted=876.0768, Expected=858.0000
# Month=57, Predicted=839.5525, Expected=817.0000
# Month=58, Predicted=797.0768, Expected=827.0000
# Month=59, Predicted=822.5952, Expected=797.0000
# Month=60, Predicted=782.0439, Expected=843.0000
# Run 10 — RMSE: 51.651348, MSE: 2667.861724, NMSE: 0.0099988874, Time: 32.8s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=749.8933, Expected=804.0000
# Month=2, Predicted=805.4914, Expected=756.0000
# Month=3, Predicted=728.7591, Expected=860.0000
# Month=4, Predicted=872.0417, Expected=878.0000
# Month=5, Predicted=872.4087, Expected=942.0000
# Month=6, Predicted=945.7157, Expected=913.0000
# Month=7, Predicted=894.2077, Expected=869.0000
# Month=8, Predicted=843.7217, Expected=834.0000
# Month=9, Predicted=812.7786, Expected=790.0000
# Month=10, Predicted=764.7217, Expected=800.0000
# Month=11, Predicted=792.6561, Expected=763.0000
# Month=12, Predicted=740.9203, Expected=800.0000
# Month=13, Predicted=798.2944, Expected=826.0000
# Month=14, Predicted=822.0754, Expected=799.0000
# Month=15, Predicted=780.9698, Expected=890.0000
# Month=16, Predicted=899.3074, Expected=900.0000
# Month=17, Predicted=892.6561, Expected=961.0000
# Month=18, Predicted=964.1058, Expected=935.0000
# Month=19, Predicted=917.3421, Expected=894.0000
# Month=20, Predicted=870.1295, Expected=855.0000
# Month=21, Predicted=832.0372, Expected=809.0000
# Month=22, Predicted=782.7525, Expected=810.0000
# Month=23, Predicted=800.5236, Expected=766.0000
# Month=24, Predicted=740.7217, Expected=805.0000
# Month=25, Predicted=803.6938, Expected=821.0000
# Month=26, Predicted=814.9803, Expected=773.0000
# Month=27, Predicted=745.7591, Expected=883.0000
# Month=28, Predicted=896.3061, Expected=898.0000
# Month=29, Predicted=891.7639, Expected=957.0000
# Month=30, Predicted=959.7006, Expected=924.0000
# Month=31, Predicted=903.6125, Expected=881.0000
# Month=32, Predicted=856.1971, Expected=837.0000
# Month=33, Predicted=811.7217, Expected=784.0000
# Month=34, Predicted=754.1718, Expected=791.0000
# Month=35, Predicted=782.9675, Expected=760.0000
# Month=36, Predicted=740.4221, Expected=802.0000
# Month=37, Predicted=801.2922, Expected=828.0000
# Month=38, Predicted=824.0754, Expected=778.0000
# Month=39, Predicted=749.7417, Expected=889.0000
# Month=40, Predicted=902.5169, Expected=902.0000
# Month=41, Predicted=895.3262, Expected=969.0000
# Month=42, Predicted=973.3281, Expected=947.0000
# Month=43, Predicted=930.7750, Expected=908.0000
# Month=44, Predicted=885.0372, Expected=867.0000
# Month=45, Predicted=843.1295, Expected=815.0000
# Month=46, Predicted=785.7009, Expected=812.0000
# Month=47, Predicted=801.5023, Expected=773.0000
# Month=48, Predicted=750.0372, Expected=813.0000
# Month=49, Predicted=811.8933, Expected=834.0000
# Month=50, Predicted=829.0415, Expected=782.0000
# Month=51, Predicted=752.7009, Expected=892.0000
# Month=52, Predicted=905.3061, Expected=903.0000
# Month=53, Predicted=895.8814, Expected=966.0000
# Month=54, Predicted=969.5121, Expected=937.0000
# Month=55, Predicted=918.2077, Expected=896.0000
# Month=56, Predicted=872.1295, Expected=858.0000
# Month=57, Predicted=835.4818, Expected=817.0000
# Month=58, Predicted=793.1295, Expected=827.0000
# Month=59, Predicted=819.6561, Expected=797.0000
# Month=60, Predicted=777.8179, Expected=843.0000
# Run 11 — RMSE: 52.555742, MSE: 2762.106065, NMSE: 0.0100036215, Time: 38.9s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=748.7992, Expected=804.0000
# Month=2, Predicted=804.4425, Expected=756.0000
# Month=3, Predicted=726.5936, Expected=860.0000
# Month=4, Predicted=872.4640, Expected=878.0000
# Month=5, Predicted=871.8340, Expected=942.0000
# Month=6, Predicted=944.8552, Expected=913.0000
# Month=7, Predicted=893.9555, Expected=869.0000
# Month=8, Predicted=842.0162, Expected=834.0000
# Month=9, Predicted=812.0233, Expected=790.0000
# Month=10, Predicted=763.0162, Expected=800.0000
# Month=11, Predicted=792.4133, Expected=763.0000
# Month=12, Predicted=739.9703, Expected=800.0000
# Month=13, Predicted=797.2253, Expected=826.0000
# Month=14, Predicted=821.2259, Expected=799.0000
# Month=15, Predicted=780.8544, Expected=890.0000
# Month=16, Predicted=899.2333, Expected=900.0000
# Month=17, Predicted=892.4133, Expected=961.0000
# Month=18, Predicted=963.1836, Expected=935.0000
# Month=19, Predicted=917.2889, Expected=894.0000
# Month=20, Predicted=868.7592, Expected=855.0000
# Month=21, Predicted=830.8817, Expected=809.0000
# Month=22, Predicted=780.8180, Expected=810.0000
# Month=23, Predicted=800.6394, Expected=766.0000
# Month=24, Predicted=739.0162, Expected=805.0000
# Month=25, Predicted=802.6064, Expected=821.0000
# Month=26, Predicted=814.4854, Expected=773.0000
# Month=27, Predicted=743.5936, Expected=883.0000
# Month=28, Predicted=896.9842, Expected=898.0000
# Month=29, Predicted=891.3099, Expected=957.0000
# Month=30, Predicted=958.7412, Expected=924.0000
# Month=31, Predicted=903.0392, Expected=881.0000
# Month=32, Predicted=854.6048, Expected=837.0000
# Month=33, Predicted=810.0162, Expected=784.0000
# Month=34, Predicted=751.4346, Expected=791.0000
# Month=35, Predicted=782.8512, Expected=760.0000
# Month=36, Predicted=740.0169, Expected=802.0000
# Month=37, Predicted=800.1894, Expected=828.0000
# Month=38, Predicted=823.2259, Expected=778.0000
# Month=39, Predicted=747.3455, Expected=889.0000
# Month=40, Predicted=903.2393, Expected=902.0000
# Month=41, Predicted=894.9559, Expected=969.0000
# Month=42, Predicted=972.5359, Expected=947.0000
# Month=43, Predicted=930.9272, Expected=908.0000
# Month=44, Predicted=883.8817, Expected=867.0000
# Month=45, Predicted=841.7592, Expected=815.0000
# Month=46, Predicted=783.0763, Expected=812.0000
# Month=47, Predicted=801.7421, Expected=773.0000
# Month=48, Predicted=748.8817, Expected=813.0000
# Month=49, Predicted=810.7992, Expected=834.0000
# Month=50, Predicted=828.3544, Expected=782.0000
# Month=51, Predicted=750.0763, Expected=892.0000
# Month=52, Predicted=905.9842, Expected=903.0000
# Month=53, Predicted=895.5960, Expected=966.0000
# Month=54, Predicted=968.6303, Expected=937.0000
# Month=55, Predicted=917.9555, Expected=896.0000
# Month=56, Predicted=870.7592, Expected=858.0000
# Month=57, Predicted=834.4304, Expected=817.0000
# Month=58, Predicted=791.7592, Expected=827.0000
# Month=59, Predicted=819.4133, Expected=797.0000
# Month=60, Predicted=777.4911, Expected=843.0000
# Run 12 — RMSE: 53.078231, MSE: 2817.298628, NMSE: 0.0100367271, Time: 35.3s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=747.5380, Expected=804.0000
# Month=2, Predicted=803.9706, Expected=756.0000
# Month=3, Predicted=722.0234, Expected=860.0000
# Month=4, Predicted=876.5417, Expected=878.0000
# Month=5, Predicted=868.5215, Expected=942.0000
# Month=6, Predicted=945.0191, Expected=913.0000
# Month=7, Predicted=887.0774, Expected=869.0000
# Month=8, Predicted=836.7716, Expected=834.0000
# Month=9, Predicted=805.6054, Expected=790.0000
# Month=10, Predicted=757.7716, Expected=800.0000
# Month=11, Predicted=788.1156, Expected=763.0000
# Month=12, Predicted=733.7660, Expected=800.0000
# Month=13, Predicted=795.7488, Expected=826.0000
# Month=14, Predicted=818.7895, Expected=799.0000
# Month=15, Predicted=773.8852, Expected=890.0000
# Month=16, Predicted=901.7039, Expected=900.0000
# Month=17, Predicted=888.1156, Expected=961.0000
# Month=18, Predicted=963.1663, Expected=935.0000
# Month=19, Predicted=910.2860, Expected=894.0000
# Month=20, Predicted=863.0654, Expected=855.0000
# Month=21, Predicted=824.9193, Expected=809.0000
# Month=22, Predicted=775.9008, Expected=810.0000
# Month=23, Predicted=795.2183, Expected=766.0000
# Month=24, Predicted=733.7716, Expected=805.0000
# Month=25, Predicted=801.2753, Expected=821.0000
# Month=26, Predicted=810.9340, Expected=773.0000
# Month=27, Predicted=739.0234, Expected=883.0000
# Month=28, Predicted=901.8809, Expected=898.0000
# Month=29, Predicted=887.6369, Expected=957.0000
# Month=30, Predicted=958.6075, Expected=924.0000
# Month=31, Predicted=896.4372, Expected=881.0000
# Month=32, Predicted=849.2046, Expected=837.0000
# Month=33, Predicted=804.7716, Expected=784.0000
# Month=34, Predicted=747.8031, Expected=791.0000
# Month=35, Predicted=778.1730, Expected=760.0000
# Month=36, Predicted=733.2613, Expected=802.0000
# Month=37, Predicted=799.0627, Expected=828.0000
# Month=38, Predicted=820.7895, Expected=778.0000
# Month=39, Predicted=743.1399, Expected=889.0000
# Month=40, Predicted=908.2756, Expected=902.0000
# Month=41, Predicted=891.0356, Expected=969.0000
# Month=42, Predicted=972.8913, Expected=947.0000
# Month=43, Predicted=923.8675, Expected=908.0000
# Month=44, Predicted=877.9193, Expected=867.0000
# Month=45, Predicted=836.0654, Expected=815.0000
# Month=46, Predicted=779.2502, Expected=812.0000
# Month=47, Predicted=795.8626, Expected=773.0000
# Month=48, Predicted=742.9193, Expected=813.0000
# Month=49, Predicted=809.5380, Expected=834.0000
# Month=50, Predicted=825.3866, Expected=782.0000
# Month=51, Predicted=746.2502, Expected=892.0000
# Month=52, Predicted=910.8809, Expected=903.0000
# Month=53, Predicted=891.4247, Expected=966.0000
# Month=54, Predicted=968.7327, Expected=937.0000
# Month=55, Predicted=911.0774, Expected=896.0000
# Month=56, Predicted=865.0654, Expected=858.0000
# Month=57, Predicted=828.3436, Expected=817.0000
# Month=58, Predicted=786.0654, Expected=827.0000
# Month=59, Predicted=815.1156, Expected=797.0000
# Month=60, Predicted=770.6704, Expected=843.0000
# Run 13 — RMSE: 54.661599, MSE: 2987.890447, NMSE: 0.0100494083, Time: 33.4s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=751.7991, Expected=804.0000
# Month=2, Predicted=807.5497, Expected=756.0000
# Month=3, Predicted=724.9711, Expected=860.0000
# Month=4, Predicted=875.5125, Expected=878.0000
# Month=5, Predicted=874.2563, Expected=942.0000
# Month=6, Predicted=947.9686, Expected=913.0000
# Month=7, Predicted=894.5150, Expected=869.0000
# Month=8, Predicted=840.9847, Expected=834.0000
# Month=9, Predicted=812.0728, Expected=790.0000
# Month=10, Predicted=761.9847, Expected=800.0000
# Month=11, Predicted=794.5332, Expected=763.0000
# Month=12, Predicted=739.8124, Expected=800.0000
# Month=13, Predicted=800.1773, Expected=826.0000
# Month=14, Predicted=823.9154, Expected=799.0000
# Month=15, Predicted=781.5492, Expected=890.0000
# Month=16, Predicted=902.2936, Expected=900.0000
# Month=17, Predicted=894.5332, Expected=961.0000
# Month=18, Predicted=966.2998, Expected=935.0000
# Month=19, Predicted=918.0456, Expected=894.0000
# Month=20, Predicted=868.1292, Expected=855.0000
# Month=21, Predicted=830.4971, Expected=809.0000
# Month=22, Predicted=779.4982, Expected=810.0000
# Month=23, Predicted=802.4232, Expected=766.0000
# Month=24, Predicted=737.9847, Expected=805.0000
# Month=25, Predicted=805.5914, Expected=821.0000
# Month=26, Predicted=816.8339, Expected=773.0000
# Month=27, Predicted=741.9711, Expected=883.0000
# Month=28, Predicted=900.0289, Expected=898.0000
# Month=29, Predicted=893.6209, Expected=957.0000
# Month=30, Predicted=961.8577, Expected=924.0000
# Month=31, Predicted=903.2771, Expected=881.0000
# Month=32, Predicted=853.7113, Expected=837.0000
# Month=33, Predicted=808.9847, Expected=784.0000
# Month=34, Predicted=749.0038, Expected=791.0000
# Month=35, Predicted=784.8563, Expected=760.0000
# Month=36, Predicted=740.4245, Expected=802.0000
# Month=37, Predicted=803.2159, Expected=828.0000
# Month=38, Predicted=825.9154, Expected=778.0000
# Month=39, Predicted=745.4075, Expected=889.0000
# Month=40, Predicted=906.2832, Expected=902.0000
# Month=41, Predicted=897.1909, Expected=969.0000
# Month=42, Predicted=975.6444, Expected=947.0000
# Month=43, Predicted=931.8981, Expected=908.0000
# Month=44, Predicted=883.4971, Expected=867.0000
# Month=45, Predicted=841.1292, Expected=815.0000
# Month=46, Predicted=780.8120, Expected=812.0000
# Month=47, Predicted=803.3878, Expected=773.0000
# Month=48, Predicted=748.4971, Expected=813.0000
# Month=49, Predicted=813.7991, Expected=834.0000
# Month=50, Predicted=830.8829, Expected=782.0000
# Month=51, Predicted=747.8120, Expected=892.0000
# Month=52, Predicted=909.0289, Expected=903.0000
# Month=53, Predicted=897.7543, Expected=966.0000
# Month=54, Predicted=971.7449, Expected=937.0000
# Month=55, Predicted=918.5150, Expected=896.0000
# Month=56, Predicted=870.1292, Expected=858.0000
# Month=57, Predicted=834.1615, Expected=817.0000
# Month=58, Predicted=791.1292, Expected=827.0000
# Month=59, Predicted=821.5332, Expected=797.0000
# Month=60, Predicted=777.9768, Expected=843.0000
# Run 14 — RMSE: 53.514982, MSE: 2863.853247, NMSE: 0.0099986031, Time: 30.5s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=749.7289, Expected=804.0000
# Month=2, Predicted=805.4819, Expected=756.0000
# Month=3, Predicted=734.6310, Expected=860.0000
# Month=4, Predicted=875.9358, Expected=878.0000
# Month=5, Predicted=873.1045, Expected=942.0000
# Month=6, Predicted=946.1532, Expected=913.0000
# Month=7, Predicted=904.9310, Expected=869.0000
# Month=8, Predicted=851.8046, Expected=834.0000
# Month=9, Predicted=823.5322, Expected=790.0000
# Month=10, Predicted=772.8046, Expected=800.0000
# Month=11, Predicted=794.1861, Expected=763.0000
# Month=12, Predicted=751.3746, Expected=800.0000
# Month=13, Predicted=798.1565, Expected=826.0000
# Month=14, Predicted=822.2619, Expected=799.0000
# Month=15, Predicted=791.4194, Expected=890.0000
# Month=16, Predicted=901.8349, Expected=900.0000
# Month=17, Predicted=894.1861, Expected=961.0000
# Month=18, Predicted=964.3947, Expected=935.0000
# Month=19, Predicted=927.6152, Expected=894.0000
# Month=20, Predicted=879.4785, Expected=855.0000
# Month=21, Predicted=842.0239, Expected=809.0000
# Month=22, Predicted=789.7986, Expected=810.0000
# Month=23, Predicted=803.5389, Expected=766.0000
# Month=24, Predicted=748.8046, Expected=805.0000
# Month=25, Predicted=803.5355, Expected=821.0000
# Month=26, Predicted=815.8497, Expected=773.0000
# Month=27, Predicted=751.6310, Expected=883.0000
# Month=28, Predicted=900.8813, Expected=898.0000
# Month=29, Predicted=892.7282, Expected=957.0000
# Month=30, Predicted=959.9013, Expected=924.0000
# Month=31, Predicted=914.5031, Expected=881.0000
# Month=32, Predicted=864.7420, Expected=837.0000
# Month=33, Predicted=819.8046, Expected=784.0000
# Month=34, Predicted=756.6307, Expected=791.0000
# Month=35, Predicted=784.9196, Expected=760.0000
# Month=36, Predicted=751.2979, Expected=802.0000
# Month=37, Predicted=801.1236, Expected=828.0000
# Month=38, Predicted=824.2619, Expected=778.0000
# Month=39, Predicted=754.3200, Expected=889.0000
# Month=40, Predicted=907.2079, Expected=902.0000
# Month=41, Predicted=896.4977, Expected=969.0000
# Month=42, Predicted=973.9333, Expected=947.0000
# Month=43, Predicted=940.1324, Expected=908.0000
# Month=44, Predicted=895.0239, Expected=867.0000
# Month=45, Predicted=852.4785, Expected=815.0000
# Month=46, Predicted=788.8865, Expected=812.0000
# Month=47, Predicted=805.4039, Expected=773.0000
# Month=48, Predicted=760.0239, Expected=813.0000
# Month=49, Predicted=811.7289, Expected=834.0000
# Month=50, Predicted=829.5141, Expected=782.0000
# Month=51, Predicted=755.8865, Expected=892.0000
# Month=52, Predicted=909.8813, Expected=903.0000
# Month=53, Predicted=897.2852, Expected=966.0000
# Month=54, Predicted=969.8979, Expected=937.0000
# Month=55, Predicted=928.9310, Expected=896.0000
# Month=56, Predicted=881.4785, Expected=858.0000
# Month=57, Predicted=845.7236, Expected=817.0000
# Month=58, Predicted=802.4785, Expected=827.0000
# Month=59, Predicted=821.1861, Expected=797.0000
# Month=60, Predicted=788.6337, Expected=843.0000
# Run 15 — RMSE: 51.423604, MSE: 2644.387063, NMSE: 0.0099490910, Time: 30.2s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=746.4007, Expected=804.0000
# Month=2, Predicted=802.3171, Expected=756.0000
# Month=3, Predicted=725.9930, Expected=860.0000
# Month=4, Predicted=872.1779, Expected=878.0000
# Month=5, Predicted=868.6998, Expected=942.0000
# Month=6, Predicted=942.9787, Expected=913.0000
# Month=7, Predicted=890.5554, Expected=869.0000
# Month=8, Predicted=840.6816, Expected=834.0000
# Month=9, Predicted=809.3007, Expected=790.0000
# Month=10, Predicted=761.6816, Expected=800.0000
# Month=11, Predicted=788.9105, Expected=763.0000
# Month=12, Predicted=737.5199, Expected=800.0000
# Month=13, Predicted=794.7536, Expected=826.0000
# Month=14, Predicted=818.4161, Expected=799.0000
# Month=15, Predicted=777.2765, Expected=890.0000
# Month=16, Predicted=898.3290, Expected=900.0000
# Month=17, Predicted=888.9105, Expected=961.0000
# Month=18, Predicted=961.2330, Expected=935.0000
# Month=19, Predicted=913.6311, Expected=894.0000
# Month=20, Predicted=866.9173, Expected=855.0000
# Month=21, Predicted=828.7252, Expected=809.0000
# Month=22, Predicted=779.8429, Expected=810.0000
# Month=23, Predicted=796.7412, Expected=766.0000
# Month=24, Predicted=737.6816, Expected=805.0000
# Month=25, Predicted=800.1842, Expected=821.0000
# Month=26, Predicted=811.2615, Expected=773.0000
# Month=27, Predicted=742.9930, Expected=883.0000
# Month=28, Predicted=896.9900, Expected=898.0000
# Month=29, Predicted=888.0404, Expected=957.0000
# Month=30, Predicted=956.7443, Expected=924.0000
# Month=31, Predicted=900.0672, Expected=881.0000
# Month=32, Predicted=853.0965, Expected=837.0000
# Month=33, Predicted=808.6816, Expected=784.0000
# Month=34, Predicted=751.8241, Expected=791.0000
# Month=35, Predicted=779.2092, Expected=760.0000
# Month=36, Predicted=736.8189, Expected=802.0000
# Month=37, Predicted=797.8364, Expected=828.0000
# Month=38, Predicted=820.4161, Expected=778.0000
# Month=39, Predicted=747.1327, Expected=889.0000
# Month=40, Predicted=903.2933, Expected=902.0000
# Month=41, Predicted=891.5936, Expected=969.0000
# Month=42, Predicted=970.7396, Expected=947.0000
# Month=43, Predicted=927.0100, Expected=908.0000
# Month=44, Predicted=881.7252, Expected=867.0000
# Month=45, Predicted=839.9173, Expected=815.0000
# Month=46, Predicted=783.2626, Expected=812.0000
# Month=47, Predicted=797.7056, Expected=773.0000
# Month=48, Predicted=746.7252, Expected=813.0000
# Month=49, Predicted=808.4007, Expected=834.0000
# Month=50, Predicted=825.3490, Expected=782.0000
# Month=51, Predicted=750.2626, Expected=892.0000
# Month=52, Predicted=905.9900, Expected=903.0000
# Month=53, Predicted=892.1400, Expected=966.0000
# Month=54, Predicted=966.7285, Expected=937.0000
# Month=55, Predicted=914.5554, Expected=896.0000
# Month=56, Predicted=868.9173, Expected=858.0000
# Month=57, Predicted=832.1243, Expected=817.0000
# Month=58, Predicted=789.9173, Expected=827.0000
# Month=59, Predicted=815.9105, Expected=797.0000
# Month=60, Predicted=774.1890, Expected=843.0000
# Run 16 — RMSE: 53.411280, MSE: 2852.764876, NMSE: 0.0100629996, Time: 34.5s
#
# ===== RUN 17/30 =====
# ...
# Month=42, Predicted=973.3743, Expected=947.0000
# Month=43, Predicted=932.7032, Expected=908.0000
# Month=44, Predicted=886.2044, Expected=867.0000
# Month=45, Predicted=844.1508, Expected=815.0000
# Month=46, Predicted=785.6979, Expected=812.0000
# Month=47, Predicted=803.4845, Expected=773.0000
# Month=48, Predicted=751.2044, Expected=813.0000
# Month=49, Predicted=812.8154, Expected=834.0000
# Month=50, Predicted=830.5120, Expected=782.0000
# Month=51, Predicted=752.6979, Expected=892.0000
# Month=52, Predicted=903.7443, Expected=903.0000
# Month=53, Predicted=897.6056, Expected=966.0000
# Month=54, Predicted=969.6958, Expected=937.0000
# Month=55, Predicted=919.9215, Expected=896.0000
# Month=56, Predicted=873.1508, Expected=858.0000
# Month=57, Predicted=836.7173, Expected=817.0000
# Month=58, Predicted=794.1508, Expected=827.0000
# Month=59, Predicted=821.4033, Expected=797.0000
# Month=60, Predicted=779.4902, Expected=843.0000
# Run 25 — RMSE: 52.387670, MSE: 2744.467932, NMSE: 0.0100332305, Time: 75.3s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=750.8911, Expected=804.0000
# Month=2, Predicted=807.3550, Expected=756.0000
# Month=3, Predicted=720.7058, Expected=860.0000
# Month=4, Predicted=875.9478, Expected=878.0000
# Month=5, Predicted=871.3837, Expected=942.0000
# Month=6, Predicted=948.1554, Expected=913.0000
# Month=7, Predicted=887.5922, Expected=869.0000
# Month=8, Predicted=835.8833, Expected=834.0000
# Month=9, Predicted=805.6012, Expected=790.0000
# Month=10, Predicted=756.8833, Expected=800.0000
# Month=11, Predicted=790.7262, Expected=763.0000
# Month=12, Predicted=733.5759, Expected=800.0000
# Month=13, Predicted=799.0590, Expected=826.0000
# Month=14, Predicted=821.8696, Expected=799.0000
# Month=15, Predicted=774.5598, Expected=890.0000
# Month=16, Predicted=902.7888, Expected=900.0000
# Month=17, Predicted=890.7262, Expected=961.0000
# Month=18, Predicted=966.4005, Expected=935.0000
# Month=19, Predicted=911.0380, Expected=894.0000
# Month=20, Predicted=862.4850, Expected=855.0000
# Month=21, Predicted=824.5370, Expected=809.0000
# Month=22, Predicted=774.8003, Expected=810.0000
# Month=23, Predicted=797.4982, Expected=766.0000
# Month=24, Predicted=732.8833, Expected=805.0000
# Month=25, Predicted=804.6153, Expected=821.0000
# Month=26, Predicted=813.7365, Expected=773.0000
# Month=27, Predicted=737.7058, Expected=883.0000
# Month=28, Predicted=900.4087, Expected=898.0000
# Month=29, Predicted=890.4087, Expected=957.0000
# Month=30, Predicted=961.8938, Expected=924.0000
# Month=31, Predicted=896.6126, Expected=881.0000
# Month=32, Predicted=848.4203, Expected=837.0000
# Month=33, Predicted=803.8833, Expected=784.0000
# Month=34, Predicted=745.9226, Expected=791.0000
# Month=35, Predicted=780.6799, Expected=760.0000
# Month=36, Predicted=733.6096, Expected=802.0000
# Month=37, Predicted=802.4381, Expected=828.0000
# Month=38, Predicted=823.8696, Expected=778.0000
# Month=39, Predicted=741.6003, Expected=889.0000
# Month=40, Predicted=906.6525, Expected=902.0000
# Month=41, Predicted=893.7446, Expected=969.0000
# Month=42, Predicted=975.9050, Expected=947.0000
# Month=43, Predicted=924.9128, Expected=908.0000
# Month=44, Predicted=877.5370, Expected=867.0000
# Month=45, Predicted=835.4850, Expected=815.0000
# Month=46, Predicted=777.4843, Expected=812.0000
# Month=47, Predicted=797.9741, Expected=773.0000
# Month=48, Predicted=742.5370, Expected=813.0000
# Month=49, Predicted=812.8911, Expected=834.0000
# Month=50, Predicted=828.3345, Expected=782.0000
# Month=51, Predicted=744.4843, Expected=892.0000
# Month=52, Predicted=909.4087, Expected=903.0000
# Month=53, Predicted=894.0687, Expected=966.0000
# Month=54, Predicted=971.9044, Expected=937.0000
# Month=55, Predicted=911.5922, Expected=896.0000
# Month=56, Predicted=864.4850, Expected=858.0000
# Month=57, Predicted=828.0581, Expected=817.0000
# Month=58, Predicted=785.4850, Expected=827.0000
# Month=59, Predicted=817.7262, Expected=797.0000
# Month=60, Predicted=771.1027, Expected=843.0000
# Run 26 — RMSE: 54.952412, MSE: 3019.767601, NMSE: 0.0100623566, Time: 85.2s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=750.7204, Expected=804.0000
# Month=2, Predicted=806.7076, Expected=756.0000
# Month=3, Predicted=734.8483, Expected=860.0000
# Month=4, Predicted=876.4436, Expected=878.0000
# Month=5, Predicted=873.7487, Expected=942.0000
# Month=6, Predicted=947.4965, Expected=913.0000
# Month=7, Predicted=901.4184, Expected=869.0000
# Month=8, Predicted=850.5114, Expected=834.0000
# Month=9, Predicted=820.1966, Expected=790.0000
# Month=10, Predicted=771.5114, Expected=800.0000
# Month=11, Predicted=794.6700, Expected=763.0000
# Month=12, Predicted=748.3045, Expected=800.0000
# Month=13, Predicted=799.0919, Expected=826.0000
# Month=14, Predicted=823.0174, Expected=799.0000
# Month=15, Predicted=788.0235, Expected=890.0000
# Month=16, Predicted=902.8468, Expected=900.0000
# Month=17, Predicted=894.6700, Expected=961.0000
# Month=18, Predicted=965.7174, Expected=935.0000
# Month=19, Predicted=924.3036, Expected=894.0000
# Month=20, Predicted=877.2692, Expected=855.0000
# Month=21, Predicted=839.3299, Expected=809.0000
# Month=22, Predicted=789.2258, Expected=810.0000
# Month=23, Predicted=803.6167, Expected=766.0000
# Month=24, Predicted=747.5114, Expected=805.0000
# Month=25, Predicted=804.5081, Expected=821.0000
# Month=26, Predicted=816.4625, Expected=773.0000
# Month=27, Predicted=751.8483, Expected=883.0000
# Month=28, Predicted=901.0905, Expected=898.0000
# Month=29, Predicted=893.3237, Expected=957.0000
# Month=30, Predicted=961.2051, Expected=924.0000
# Month=31, Predicted=911.0099, Expected=881.0000
# Month=32, Predicted=863.1199, Expected=837.0000
# Month=33, Predicted=818.5114, Expected=784.0000
# Month=34, Predicted=759.0061, Expected=791.0000
# Month=35, Predicted=785.3054, Expected=760.0000
# Month=36, Predicted=747.7489, Expected=802.0000
# Month=37, Predicted=802.1531, Expected=828.0000
# Month=38, Predicted=825.0174, Expected=778.0000
# Month=39, Predicted=755.3791, Expected=889.0000
# Month=40, Predicted=907.3637, Expected=902.0000
# Month=41, Predicted=897.0545, Expected=969.0000
# Month=42, Predicted=975.2869, Expected=947.0000
# Month=43, Predicted=937.2898, Expected=908.0000
# Month=44, Predicted=892.3299, Expected=867.0000
# Month=45, Predicted=850.2692, Expected=815.0000
# Month=46, Predicted=790.8194, Expected=812.0000
# Month=47, Predicted=805.1662, Expected=773.0000
# Month=48, Predicted=757.3299, Expected=813.0000
# Month=49, Predicted=812.7204, Expected=834.0000
# Month=50, Predicted=830.2009, Expected=782.0000
# Month=51, Predicted=757.8194, Expected=892.0000
# Month=52, Predicted=910.0905, Expected=903.0000
# Month=53, Predicted=897.7958, Expected=966.0000
# Month=54, Predicted=971.2355, Expected=937.0000
# Month=55, Predicted=925.4184, Expected=896.0000
# Month=56, Predicted=879.2692, Expected=858.0000
# Month=57, Predicted=842.8278, Expected=817.0000
# Month=58, Predicted=800.2692, Expected=827.0000
# Month=59, Predicted=821.6700, Expected=797.0000
# Month=60, Predicted=785.0920, Expected=843.0000
# Run 27 — RMSE: 51.276147, MSE: 2629.243236, NMSE: 0.0098710308, Time: 73.5s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=748.7294, Expected=804.0000
# Month=2, Predicted=804.9867, Expected=756.0000
# Month=3, Predicted=722.2007, Expected=860.0000
# Month=4, Predicted=873.9052, Expected=878.0000
# Month=5, Predicted=869.8595, Expected=942.0000
# Month=6, Predicted=945.7089, Expected=913.0000
# Month=7, Predicted=888.2771, Expected=869.0000
# Month=8, Predicted=837.2283, Expected=834.0000
# Month=9, Predicted=806.5663, Expected=790.0000
# Month=10, Predicted=758.2283, Expected=800.0000
# Month=11, Predicted=789.5190, Expected=763.0000
# Month=12, Predicted=734.6301, Expected=800.0000
# Month=13, Predicted=796.9630, Expected=826.0000
# Month=14, Predicted=820.0723, Expected=799.0000
# Month=15, Predicted=775.1478, Expected=890.0000
# Month=16, Predicted=900.5034, Expected=900.0000
# Month=17, Predicted=889.5190, Expected=961.0000
# Month=18, Predicted=963.9667, Expected=935.0000
# Month=19, Predicted=911.5770, Expected=894.0000
# Month=20, Predicted=863.7096, Expected=855.0000
# Month=21, Predicted=825.6778, Expected=809.0000
# Month=22, Predicted=776.2219, Expected=810.0000
# Month=23, Predicted=796.6927, Expected=766.0000
# Month=24, Predicted=734.2283, Expected=805.0000
# Month=25, Predicted=802.4747, Expected=821.0000
# Month=26, Predicted=812.2876, Expected=773.0000
# Month=27, Predicted=739.2007, Expected=883.0000
# Month=28, Predicted=898.5114, Expected=898.0000
# Month=29, Predicted=888.9985, Expected=957.0000
# Month=30, Predicted=959.4721, Expected=924.0000
# Month=31, Predicted=897.4863, Expected=881.0000
# Month=32, Predicted=849.7259, Expected=837.0000
# Month=33, Predicted=805.2283, Expected=784.0000
# Month=34, Predicted=747.5863, Expected=791.0000
# Month=35, Predicted=779.6017, Expected=760.0000
# Month=36, Predicted=734.3899, Expected=802.0000
# Month=37, Predicted=800.2364, Expected=828.0000
# Month=38, Predicted=822.0723, Expected=778.0000
# Month=39, Predicted=743.1653, Expected=889.0000
# Month=40, Predicted=904.7814, Expected=902.0000
# Month=41, Predicted=892.4137, Expected=969.0000
# Month=42, Predicted=973.4522, Expected=947.0000
# Month=43, Predicted=925.2527, Expected=908.0000
# Month=44, Predicted=878.6778, Expected=867.0000
# Month=45, Predicted=836.7096, Expected=815.0000
# Month=46, Predicted=779.1160, Expected=812.0000
# Month=47, Predicted=797.3595, Expected=773.0000
# Month=48, Predicted=743.6778, Expected=813.0000
# Month=49, Predicted=810.7294, Expected=834.0000
# Month=50, Predicted=826.7026, Expected=782.0000
# Month=51, Predicted=746.1160, Expected=892.0000
# Month=52, Predicted=907.5114, Expected=903.0000
# Month=53, Predicted=892.8197, Expected=966.0000
# Month=54, Predicted=969.4614, Expected=937.0000
# Month=55, Predicted=912.2771, Expected=896.0000
# Month=56, Predicted=865.7096, Expected=858.0000
# Month=57, Predicted=829.1559, Expected=817.0000
# Month=58, Predicted=786.7096, Expected=827.0000
# Month=59, Predicted=816.5190, Expected=797.0000
# Month=60, Predicted=771.8356, Expected=843.0000
# Run 28 — RMSE: 54.497318, MSE: 2969.957670, NMSE: 0.0100830536, Time: 62.4s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=751.2175, Expected=804.0000
# Month=2, Predicted=806.6944, Expected=756.0000
# Month=3, Predicted=727.3063, Expected=860.0000
# Month=4, Predicted=872.5747, Expected=878.0000
# Month=5, Predicted=873.7965, Expected=942.0000
# Month=6, Predicted=946.7842, Expected=913.0000
# Month=7, Predicted=894.4291, Expected=869.0000
# Month=8, Predicted=842.6951, Expected=834.0000
# Month=9, Predicted=812.5698, Expected=790.0000
# Month=10, Predicted=763.6951, Expected=800.0000
# Month=11, Predicted=794.0093, Expected=763.0000
# Month=12, Predicted=740.5475, Expected=800.0000
# Month=13, Predicted=799.6388, Expected=826.0000
# Month=14, Predicted=823.4643, Expected=799.0000
# Month=15, Predicted=781.3145, Expected=890.0000
# Month=16, Predicted=900.0044, Expected=900.0000
# Month=17, Predicted=894.0093, Expected=961.0000
# Month=18, Predicted=965.2131, Expected=935.0000
# Month=19, Predicted=917.7449, Expected=894.0000
# Month=20, Predicted=869.3981, Expected=855.0000
# Month=21, Predicted=831.4902, Expected=809.0000
# Month=22, Predicted=781.5173, Expected=810.0000
# Month=23, Predicted=801.7869, Expected=766.0000
# Month=24, Predicted=739.6951, Expected=805.0000
# Month=25, Predicted=805.0250, Expected=821.0000
# Month=26, Predicted=816.3629, Expected=773.0000
# Month=27, Predicted=744.3063, Expected=883.0000
# Month=28, Predicted=896.7712, Expected=898.0000
# Month=29, Predicted=893.1430, Expected=957.0000
# Month=30, Predicted=960.8330, Expected=924.0000
# Month=31, Predicted=903.5573, Expected=881.0000
# Month=32, Predicted=855.2713, Expected=837.0000
# Month=33, Predicted=810.6951, Expected=784.0000
# Month=34, Predicted=752.1402, Expected=791.0000
# Month=35, Predicted=784.2975, Expected=760.0000
# Month=36, Predicted=740.5102, Expected=802.0000
# Month=37, Predicted=802.6011, Expected=828.0000
# Month=38, Predicted=825.4643, Expected=778.0000
# Month=39, Predicted=748.0631, Expected=889.0000
# Month=40, Predicted=902.9712, Expected=902.0000
# Month=41, Predicted=896.6967, Expected=969.0000
# Month=42, Predicted=974.3566, Expected=947.0000
# Month=43, Predicted=931.3871, Expected=908.0000
# Month=44, Predicted=884.4902, Expected=867.0000
# Month=45, Predicted=842.3981, Expected=815.0000
# Month=46, Predicted=783.7887, Expected=812.0000
# Month=47, Predicted=802.7032, Expected=773.0000
# Month=48, Predicted=749.4902, Expected=813.0000
# Month=49, Predicted=813.2175, Expected=834.0000
# Month=50, Predicted=830.4334, Expected=782.0000
# Month=51, Predicted=750.7887, Expected=892.0000
# Month=52, Predicted=905.7712, Expected=903.0000
# Month=53, Predicted=897.2410, Expected=966.0000
# Month=54, Predicted=970.5937, Expected=937.0000
# Month=55, Predicted=918.4291, Expected=896.0000
# Month=56, Predicted=871.3981, Expected=858.0000
# Month=57, Predicted=835.0232, Expected=817.0000
# Month=58, Predicted=792.3981, Expected=827.0000
# Month=59, Predicted=821.0093, Expected=797.0000
# Month=60, Predicted=777.9739, Expected=843.0000
# Run 29 — RMSE: 52.893216, MSE: 2797.692271, NMSE: 0.0100158716, Time: 71.0s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=750.3907, Expected=804.0000
# Month=2, Predicted=805.6811, Expected=756.0000
# Month=3, Predicted=729.1920, Expected=860.0000
# Month=4, Predicted=870.8206, Expected=878.0000
# Month=5, Predicted=873.3980, Expected=942.0000
# Month=6, Predicted=945.6240, Expected=913.0000
# Month=7, Predicted=895.7773, Expected=869.0000
# Month=8, Predicted=844.5187, Expected=834.0000
# Month=9, Predicted=814.1444, Expected=790.0000
# Month=10, Predicted=765.5187, Expected=800.0000
# Month=11, Predicted=793.8268, Expected=763.0000
# Month=12, Predicted=742.1884, Expected=800.0000
# Month=13, Predicted=798.8598, Expected=826.0000
# Month=14, Predicted=822.8860, Expected=799.0000
# Month=15, Predicted=782.5806, Expected=890.0000
# Month=16, Predicted=898.4587, Expected=900.0000
# Month=17, Predicted=893.8268, Expected=961.0000
# Month=18, Predicted=964.0929, Expected=935.0000
# Month=19, Predicted=918.9691, Expected=894.0000
# Month=20, Predicted=871.1539, Expected=855.0000
# Month=21, Predicted=833.1918, Expected=809.0000
# Month=22, Predicted=783.3763, Expected=810.0000
# Month=23, Predicted=801.8964, Expected=766.0000
# Month=24, Predicted=741.5187, Expected=805.0000
# Month=25, Predicted=804.2139, Expected=821.0000
# Month=26, Predicted=816.0147, Expected=773.0000
# Month=27, Predicted=746.1920, Expected=883.0000
# Month=28, Predicted=894.9169, Expected=898.0000
# Month=29, Predicted=892.8209, Expected=957.0000
# Month=30, Predicted=959.7394, Expected=924.0000
# Month=31, Predicted=905.0605, Expected=881.0000
# Month=32, Predicted=857.0743, Expected=837.0000
# Month=33, Predicted=812.5187, Expected=784.0000
# Month=34, Predicted=754.0522, Expected=791.0000
# Month=35, Predicted=784.2065, Expected=760.0000
# Month=36, Predicted=741.9377, Expected=802.0000
# Month=37, Predicted=801.7438, Expected=828.0000
# Month=38, Predicted=824.8860, Expected=778.0000
# Month=39, Predicted=749.9665, Expected=889.0000
# Month=40, Predicted=901.1000, Expected=902.0000
# Month=41, Predicted=896.4286, Expected=969.0000
# Month=42, Predicted=973.1563, Expected=947.0000
# Month=43, Predicted=932.4394, Expected=908.0000
# Month=44, Predicted=886.1918, Expected=867.0000
# Month=45, Predicted=844.1539, Expected=815.0000
# Month=46, Predicted=785.7003, Expected=812.0000
# Month=47, Predicted=802.9593, Expected=773.0000
# Month=48, Predicted=751.1918, Expected=813.0000
# Month=49, Predicted=812.3907, Expected=834.0000
# Month=50, Predicted=829.9635, Expected=782.0000
# Month=51, Predicted=752.7003, Expected=892.0000
# Month=52, Predicted=903.9169, Expected=903.0000
# Month=53, Predicted=897.0293, Expected=966.0000
# Month=54, Predicted=969.4469, Expected=937.0000
# Month=55, Predicted=919.7773, Expected=896.0000
# Month=56, Predicted=873.1539, Expected=858.0000
# Month=57, Predicted=836.6952, Expected=817.0000
# Month=58, Predicted=794.1539, Expected=827.0000
# Month=59, Predicted=820.8268, Expected=797.0000
# Month=60, Predicted=779.3622, Expected=843.0000
# Run 30 — RMSE: 52.398371, MSE: 2745.589238, NMSE: 0.0100318048, Time: 64.7s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Autoformer on Monthly Milk Production (30 runs) =====
# RMSE: 52.829836 ± 1.115098
# MSE:  2792.234987 ± 118.164314
# NMSE: 0.0100251653 ± 0.0000808796
# Avg training time: 39.2s ± 17.6s
#
# Best run: 24
#   RMSE: 51.175297
#   MSE:  2618.911040
#   NMSE: 0.0099821383

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Autoformer — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Autoformer — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 51.175297
# MSE:  2618.911040
# NMSE: 0.0099821383

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Autoformer_Milk_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to Autoformer_Milk_predictions.csv

# %% [markdown]
# ## Observations
#
# ### Autoformer on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
