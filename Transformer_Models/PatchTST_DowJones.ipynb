# %% [markdown]
# # PatchTST — Dow Jones Industrial Index
#
# **Model**: Patch-based Time Series Transformer
# **Reference**: Nie et al., 2023 — A Time Series is Worth 64 Words: Long-term Forecasting with Transformers
#
# ## Description
# This notebook implements the **PatchTST** Transformer architecture for univariate time-series
# forecasting on the Dow Jones Industrial Index dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: PatchTST Architecture
#
# ### Patching
# Time series is segmented into **subseries-level patches**:
# $$P_i = x[i \cdot S : i \cdot S + P], \quad i = 0, 1, \ldots, N-1$$
#
# where $P$ = patch length, $S$ = stride, $N$ = number of patches.
#
# Each patch is projected to $d_{\text{model}}$ dimensions via a linear layer.
#
# ### Channel Independence
# Each variate (channel) is processed **independently** through the same Transformer backbone, reducing parameters and improving robustness.
#
# ### Instance Normalization
# Applied per-instance to handle distribution shift between training and testing:
# $$\hat{x} = \frac{x - \mu_x}{\sigma_x}$$
#
# ### Standard Transformer
# After patching, a standard Transformer encoder processes the patch tokens with multi-head self-attention and feed-forward layers.
#
# ### Complexity
# Patching reduces the effective sequence length from $L$ to $N = L/S$, achieving $O(N^2) = O((L/S)^2)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.8.0+cpu
# NumPy version: 2.0.2
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### PatchTST Model Definition

# %%
# ============================================================
# PatchTST: Patch-based Time Series Transformer
# Reference: Nie et al., 2023
#
# Key ideas:
# 1. Patching: segment time series into subseries-level patches
# 2. Channel independence: each variate processed independently
# 3. Instance normalization for distribution shift
#
# For our single-step (seq_len=1) setup, patch_len=1 naturally.
# The architecture still applies the full Transformer pipeline.
# ============================================================

class PatchEmbedding(nn.Module):
    """
    Patch embedding for time series.
    Segments input into patches and projects to d_model.
    For seq_len=1, patch_len=1, this is equivalent to a linear projection.
    """
    def __init__(self, input_dim, d_model, patch_len=1, stride=1):
        super().__init__()
        self.patch_len = patch_len
        self.stride = stride
        self.proj = nn.Linear(patch_len * input_dim, d_model)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape
        # Number of patches
        n_patches = max(1, (L - self.patch_len) // self.stride + 1)

        patches = []
        for i in range(n_patches):
            start = i * self.stride
            end = start + self.patch_len
            patch = x[:, start:end, :].reshape(B, -1)  # (B, patch_len * C)
            patches.append(patch)

        patches = torch.stack(patches, dim=1)  # (B, n_patches, patch_len * C)
        return self.proj(patches)  # (B, n_patches, d_model)


class PatchTSTEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = nn.MultiheadAttention(d_model, n_heads,
                                                dropout=dropout,
                                                batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_out, _ = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_out))
        ff_out = self.ff(x)
        x = self.norm2(x + ff_out)
        return x


class PatchTSTModel(nn.Module):
    """
    PatchTST for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, patch_len=1, stride=1, dropout=0.1):
        super().__init__()
        # Instance normalization
        self.instance_norm = nn.InstanceNorm1d(input_dim, affine=False)

        self.patch_embed = PatchEmbedding(input_dim, d_model, patch_len, stride)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            PatchTSTEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.flatten_head = nn.Linear(d_model, 1)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape

        # Instance normalization (channel-wise)
        if L > 1:
            x = self.instance_norm(x.transpose(1, 2)).transpose(1, 2)

        # Patch embedding
        x = self.patch_embed(x)  # (B, n_patches, d_model)
        n_patches = x.shape[1]
        x = x + self.pos_embedding[:, :n_patches, :]

        # Transformer encoder
        for layer in self.encoder_layers:
            x = layer(x)

        # Use last patch for prediction
        x = x[:, -1, :]
        return self.flatten_head(x)

# %%
# Quick model check
set_seed(0)
test_model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20385
# Trainable parameters: 20385
# Memory estimate: 79.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 1), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3799.7605, Expected=3796.0000
# Month=2, Predicted=3798.1952, Expected=3793.0000
# Month=3, Predicted=3795.2024, Expected=3766.0000
# Month=4, Predicted=3768.3272, Expected=3747.0000
# Month=5, Predicted=3749.2938, Expected=3754.0000
# Month=6, Predicted=3756.1199, Expected=3756.0000
# Month=7, Predicted=3758.1643, Expected=3767.0000
# Month=8, Predicted=3769.0792, Expected=3751.0000
# Month=9, Predicted=3753.2795, Expected=3769.0000
# Month=10, Predicted=3770.9951, Expected=3760.0000
# Month=11, Predicted=3762.2414, Expected=3785.0000
# Month=12, Predicted=3786.8961, Expected=3776.0000
# Month=13, Predicted=3778.2414, Expected=3755.0000
# Month=14, Predicted=3757.3028, Expected=3755.0000
# Month=15, Predicted=3757.1802, Expected=3751.0000
# Month=16, Predicted=3753.2094, Expected=3776.0000
# Month=17, Predicted=3777.8961, Expected=3847.0000
# Month=18, Predicted=3848.3758, Expected=3830.0000
# Month=19, Predicted=3832.2844, Expected=3881.0000
# Month=20, Predicted=3882.5445, Expected=3899.0000
# Month=21, Predicted=3900.9951, Expected=3917.0000
# Month=22, Predicted=3918.9951, Expected=3913.0000
# Month=23, Predicted=3915.2094, Expected=3901.0000
# Month=24, Predicted=3903.2586, Expected=3886.0000
# Month=25, Predicted=3888.2745, Expected=3892.5000
# Month=26, Predicted=3894.6247, Expected=3899.0000
# Month=27, Predicted=3901.1247, Expected=3886.0000
# Month=28, Predicted=3888.2641, Expected=3908.0000
# Month=29, Predicted=3909.9400, Expected=3875.0000
# Month=30, Predicted=3877.3484, Expected=3860.0000
# Month=31, Predicted=3862.2745, Expected=3880.0000
# Month=32, Predicted=3881.9681, Expected=3895.0000
# Month=33, Predicted=3897.0332, Expected=3954.0000
# Month=34, Predicted=3955.4684, Expected=3933.0000
# Month=35, Predicted=3935.3028, Expected=3937.0000
# Month=36, Predicted=3939.1474, Expected=3869.0000
# Month=37, Predicted=3871.4331, Expected=3852.0000
# Month=38, Predicted=3854.2844, Expected=3837.0000
# Month=39, Predicted=3839.2745, Expected=3832.0000
# Month=40, Predicted=3834.2162, Expected=3849.0000
# Month=41, Predicted=3851.0081, Expected=3863.0000
# Month=42, Predicted=3865.0452, Expected=3878.0000
# Month=43, Predicted=3880.0332, Expected=3855.0000
# Month=44, Predicted=3857.3113, Expected=3843.0000
# Month=45, Predicted=3845.2586, Expected=3847.0000
# Month=46, Predicted=3849.1474, Expected=3801.0000
# Month=47, Predicted=3803.3863, Expected=3787.0000
# Month=48, Predicted=3789.2693, Expected=3776.0000
# Month=49, Predicted=3778.2530, Expected=3797.0000
# Month=50, Predicted=3798.9542, Expected=3821.0000
# Month=51, Predicted=3822.9109, Expected=3877.0000
# Month=52, Predicted=3878.4953, Expected=3875.0000
# Month=53, Predicted=3877.1952, Expected=3890.0000
# Month=54, Predicted=3892.0332, Expected=3910.0000
# Month=55, Predicted=3911.9681, Expected=3924.0000
# Month=56, Predicted=3926.0452, Expected=3918.0000
# Month=57, Predicted=3920.2227, Expected=3936.0000
# Month=58, Predicted=3937.9951, Expected=3911.0000
# Month=59, Predicted=3913.3194, Expected=3891.0000
# Month=60, Predicted=3893.2983, Expected=3855.0000
# Run 1 — RMSE: 24.507844, MSE: 600.634438, NMSE: 0.0027570136, Time: 192.8s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3799.7054, Expected=3796.0000
# Month=2, Predicted=3797.7698, Expected=3793.0000
# Month=3, Predicted=3794.7716, Expected=3766.0000
# Month=4, Predicted=3767.8149, Expected=3747.0000
# Month=5, Predicted=3748.8006, Expected=3754.0000
# Month=6, Predicted=3755.7535, Expected=3756.0000
# Month=7, Predicted=3757.7626, Expected=3767.0000
# Month=8, Predicted=3768.7463, Expected=3751.0000
# Month=9, Predicted=3752.7951, Expected=3769.0000
# Month=10, Predicted=3770.7338, Expected=3760.0000
# Month=11, Predicted=3761.7825, Expected=3785.0000
# Month=12, Predicted=3786.7213, Expected=3776.0000
# Month=13, Predicted=3777.7825, Expected=3755.0000
# Month=14, Predicted=3756.8042, Expected=3755.0000
# Month=15, Predicted=3756.7662, Expected=3751.0000
# Month=16, Predicted=3752.7734, Expected=3776.0000
# Month=17, Predicted=3777.7213, Expected=3847.0000
# Month=18, Predicted=3848.6429, Expected=3830.0000
# Month=19, Predicted=3831.7970, Expected=3881.0000
# Month=20, Predicted=3882.6761, Expected=3899.0000
# Month=21, Predicted=3900.7338, Expected=3917.0000
# Month=22, Predicted=3918.7338, Expected=3913.0000
# Month=23, Predicted=3914.7734, Expected=3901.0000
# Month=24, Predicted=3902.7879, Expected=3886.0000
# Month=25, Predicted=3887.7933, Expected=3892.5000
# Month=26, Predicted=3894.2545, Expected=3899.0000
# Month=27, Predicted=3900.7545, Expected=3886.0000
# Month=28, Predicted=3887.7897, Expected=3908.0000
# Month=29, Predicted=3909.7266, Expected=3875.0000
# Month=30, Predicted=3876.8256, Expected=3860.0000
# Month=31, Predicted=3861.7933, Expected=3880.0000
# Month=32, Predicted=3881.7302, Expected=3895.0000
# Month=33, Predicted=3896.7391, Expected=3954.0000
# Month=34, Predicted=3955.6626, Expected=3933.0000
# Month=35, Predicted=3934.8042, Expected=3937.0000
# Month=36, Predicted=3938.7590, Expected=3869.0000
# Month=37, Predicted=3870.8869, Expected=3852.0000
# Month=38, Predicted=3853.7970, Expected=3837.0000
# Month=39, Predicted=3838.7933, Expected=3832.0000
# Month=40, Predicted=3833.7753, Expected=3849.0000
# Month=41, Predicted=3850.7355, Expected=3863.0000
# Month=42, Predicted=3864.7409, Expected=3878.0000
# Month=43, Predicted=3879.7391, Expected=3855.0000
# Month=44, Predicted=3856.8078, Expected=3843.0000
# Month=45, Predicted=3844.7879, Expected=3847.0000
# Month=46, Predicted=3848.7590, Expected=3801.0000
# Month=47, Predicted=3802.8487, Expected=3787.0000
# Month=48, Predicted=3788.7915, Expected=3776.0000
# Month=49, Predicted=3777.7861, Expected=3797.0000
# Month=50, Predicted=3798.7284, Expected=3821.0000
# Month=51, Predicted=3822.7230, Expected=3877.0000
# Month=52, Predicted=3878.6676, Expected=3875.0000
# Month=53, Predicted=3876.7698, Expected=3890.0000
# Month=54, Predicted=3891.7391, Expected=3910.0000
# Month=55, Predicted=3911.7302, Expected=3924.0000
# Month=56, Predicted=3925.7409, Expected=3918.0000
# Month=57, Predicted=3919.7771, Expected=3936.0000
# Month=58, Predicted=3937.7338, Expected=3911.0000
# Month=59, Predicted=3912.8113, Expected=3891.0000
# Month=60, Predicted=3892.8024, Expected=3855.0000
# Run 2 — RMSE: 24.480866, MSE: 599.312822, NMSE: 0.0027481146, Time: 187.6s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3800.0137, Expected=3796.0000
# Month=2, Predicted=3798.0384, Expected=3793.0000
# Month=3, Predicted=3795.0393, Expected=3766.0000
# Month=4, Predicted=3768.0684, Expected=3747.0000
# Month=5, Predicted=3749.0570, Expected=3754.0000
# Month=6, Predicted=3756.0308, Expected=3756.0000
# Month=7, Predicted=3758.0349, Expected=3767.0000
# Month=8, Predicted=3769.0278, Expected=3751.0000
# Month=9, Predicted=3753.0532, Expected=3769.0000
# Month=10, Predicted=3771.0229, Expected=3760.0000
# Month=11, Predicted=3762.0453, Expected=3785.0000
# Month=12, Predicted=3787.0186, Expected=3776.0000
# Month=13, Predicted=3778.0453, Expected=3755.0000
# Month=14, Predicted=3757.0597, Expected=3755.0000
# Month=15, Predicted=3757.0366, Expected=3751.0000
# Month=16, Predicted=3753.0403, Expected=3776.0000
# Month=17, Predicted=3778.0186, Expected=3847.0000
# Month=18, Predicted=3848.9987, Expected=3830.0000
# Month=19, Predicted=3832.0545, Expected=3881.0000
# Month=20, Predicted=3883.0059, Expected=3899.0000
# Month=21, Predicted=3901.0229, Expected=3917.0000
# Month=22, Predicted=3919.0229, Expected=3913.0000
# Month=23, Predicted=3915.0403, Expected=3901.0000
# Month=24, Predicted=3903.0486, Expected=3886.0000
# Month=25, Predicted=3888.0520, Expected=3892.5000
# Month=26, Predicted=3894.5312, Expected=3899.0000
# Month=27, Predicted=3901.0312, Expected=3886.0000
# Month=28, Predicted=3888.0497, Expected=3908.0000
# Month=29, Predicted=3910.0204, Expected=3875.0000
# Month=30, Predicted=3877.0787, Expected=3860.0000
# Month=31, Predicted=3862.0520, Expected=3880.0000
# Month=32, Predicted=3882.0216, Expected=3895.0000
# Month=33, Predicted=3897.0249, Expected=3954.0000
# Month=34, Predicted=3956.0028, Expected=3933.0000
# Month=35, Predicted=3935.0597, Expected=3937.0000
# Month=36, Predicted=3939.0332, Expected=3869.0000
# Month=37, Predicted=3871.2236, Expected=3852.0000
# Month=38, Predicted=3854.0545, Expected=3837.0000
# Month=39, Predicted=3839.0520, Expected=3832.0000
# Month=40, Predicted=3834.0413, Expected=3849.0000
# Month=41, Predicted=3851.0236, Expected=3863.0000
# Month=42, Predicted=3865.0256, Expected=3878.0000
# Month=43, Predicted=3880.0249, Expected=3855.0000
# Month=44, Predicted=3857.0625, Expected=3843.0000
# Month=45, Predicted=3845.0486, Expected=3847.0000
# Month=46, Predicted=3849.0332, Expected=3801.0000
# Month=47, Predicted=3803.1087, Expected=3787.0000
# Month=48, Predicted=3789.0509, Expected=3776.0000
# Month=49, Predicted=3778.0475, Expected=3797.0000
# Month=50, Predicted=3799.0210, Expected=3821.0000
# Month=51, Predicted=3823.0192, Expected=3877.0000
# Month=52, Predicted=3879.0039, Expected=3875.0000
# Month=53, Predicted=3877.0384, Expected=3890.0000
# Month=54, Predicted=3892.0249, Expected=3910.0000
# Month=55, Predicted=3912.0216, Expected=3924.0000
# Month=56, Predicted=3926.0256, Expected=3918.0000
# Month=57, Predicted=3920.0422, Expected=3936.0000
# Month=58, Predicted=3938.0229, Expected=3911.0000
# Month=59, Predicted=3913.0654, Expected=3891.0000
# Month=60, Predicted=3893.0583, Expected=3855.0000
# Run 3 — RMSE: 24.491392, MSE: 599.828286, NMSE: 0.0027496078, Time: 189.8s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3800.0259, Expected=3796.0000
# Month=2, Predicted=3798.0275, Expected=3793.0000
# Month=3, Predicted=3795.0276, Expected=3766.0000
# Month=4, Predicted=3768.0292, Expected=3747.0000
# Month=5, Predicted=3749.0286, Expected=3754.0000
# Month=6, Predicted=3756.0271, Expected=3756.0000
# Month=7, Predicted=3758.0273, Expected=3767.0000
# Month=8, Predicted=3769.0269, Expected=3751.0000
# Month=9, Predicted=3753.0284, Expected=3769.0000
# Month=10, Predicted=3771.0265, Expected=3760.0000
# Month=11, Predicted=3762.0280, Expected=3785.0000
# Month=12, Predicted=3787.0262, Expected=3776.0000
# Month=13, Predicted=3778.0280, Expected=3755.0000
# Month=14, Predicted=3757.0288, Expected=3755.0000
# Month=15, Predicted=3757.0274, Expected=3751.0000
# Month=16, Predicted=3753.0277, Expected=3776.0000
# Month=17, Predicted=3778.0262, Expected=3847.0000
# Month=18, Predicted=3849.0247, Expected=3830.0000
# Month=19, Predicted=3832.0285, Expected=3881.0000
# Month=20, Predicted=3883.0253, Expected=3899.0000
# Month=21, Predicted=3901.0265, Expected=3917.0000
# Month=22, Predicted=3919.0265, Expected=3913.0000
# Month=23, Predicted=3915.0277, Expected=3901.0000
# Month=24, Predicted=3903.0282, Expected=3886.0000
# Month=25, Predicted=3888.0283, Expected=3892.5000
# Month=26, Predicted=3894.5271, Expected=3899.0000
# Month=27, Predicted=3901.0271, Expected=3886.0000
# Month=28, Predicted=3888.0282, Expected=3908.0000
# Month=29, Predicted=3910.0264, Expected=3875.0000
# Month=30, Predicted=3877.0297, Expected=3860.0000
# Month=31, Predicted=3862.0283, Expected=3880.0000
# Month=32, Predicted=3882.0264, Expected=3895.0000
# Month=33, Predicted=3897.0267, Expected=3954.0000
# Month=34, Predicted=3956.0251, Expected=3933.0000
# Month=35, Predicted=3935.0288, Expected=3937.0000
# Month=36, Predicted=3939.0272, Expected=3869.0000
# Month=37, Predicted=3871.0340, Expected=3852.0000
# Month=38, Predicted=3854.0285, Expected=3837.0000
# Month=39, Predicted=3839.0283, Expected=3832.0000
# Month=40, Predicted=3834.0277, Expected=3849.0000
# Month=41, Predicted=3851.0266, Expected=3863.0000
# Month=42, Predicted=3865.0267, Expected=3878.0000
# Month=43, Predicted=3880.0267, Expected=3855.0000
# Month=44, Predicted=3857.0289, Expected=3843.0000
# Month=45, Predicted=3845.0282, Expected=3847.0000
# Month=46, Predicted=3849.0272, Expected=3801.0000
# Month=47, Predicted=3803.0310, Expected=3787.0000
# Month=48, Predicted=3789.0283, Expected=3776.0000
# Month=49, Predicted=3778.0281, Expected=3797.0000
# Month=50, Predicted=3799.0264, Expected=3821.0000
# Month=51, Predicted=3823.0263, Expected=3877.0000
# Month=52, Predicted=3879.0251, Expected=3875.0000
# Month=53, Predicted=3877.0275, Expected=3890.0000
# Month=54, Predicted=3892.0267, Expected=3910.0000
# Month=55, Predicted=3912.0264, Expected=3924.0000
# Month=56, Predicted=3926.0267, Expected=3918.0000
# Month=57, Predicted=3920.0278, Expected=3936.0000
# Month=58, Predicted=3938.0265, Expected=3911.0000
# Month=59, Predicted=3913.0291, Expected=3891.0000
# Month=60, Predicted=3893.0287, Expected=3855.0000
# Run 4 — RMSE: 24.486272, MSE: 599.577495, NMSE: 0.0027482641, Time: 186.7s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3800.4714, Expected=3796.0000
# Month=2, Predicted=3798.4958, Expected=3793.0000
# Month=3, Predicted=3795.4968, Expected=3766.0000
# Month=4, Predicted=3768.5325, Expected=3747.0000
# Month=5, Predicted=3749.5176, Expected=3754.0000
# Month=6, Predicted=3756.4877, Expected=3756.0000
# Month=7, Predicted=3758.4920, Expected=3767.0000
# Month=8, Predicted=3769.4847, Expected=3751.0000
# Month=9, Predicted=3753.5129, Expected=3769.0000
# Month=10, Predicted=3771.4800, Expected=3760.0000
# Month=11, Predicted=3762.5035, Expected=3785.0000
# Month=12, Predicted=3787.4759, Expected=3776.0000
# Month=13, Predicted=3778.5035, Expected=3755.0000
# Month=14, Predicted=3757.5209, Expected=3755.0000
# Month=15, Predicted=3757.4938, Expected=3751.0000
# Month=16, Predicted=3753.4978, Expected=3776.0000
# Month=17, Predicted=3778.4759, Expected=3847.0000
# Month=18, Predicted=3849.4587, Expected=3830.0000
# Month=19, Predicted=3832.5144, Expected=3881.0000
# Month=20, Predicted=3883.4646, Expected=3899.0000
# Month=21, Predicted=3901.4800, Expected=3917.0000
# Month=22, Predicted=3919.4800, Expected=3913.0000
# Month=23, Predicted=3915.4978, Expected=3901.0000
# Month=24, Predicted=3903.5073, Expected=3886.0000
# Month=25, Predicted=3888.5114, Expected=3892.5000
# Month=26, Predicted=3894.9881, Expected=3899.0000
# Month=27, Predicted=3901.4881, Expected=3886.0000
# Month=28, Predicted=3888.5086, Expected=3908.0000
# Month=29, Predicted=3910.4775, Expected=3875.0000
# Month=30, Predicted=3877.5469, Expected=3860.0000
# Month=31, Predicted=3862.5114, Expected=3880.0000
# Month=32, Predicted=3882.4787, Expected=3895.0000
# Month=33, Predicted=3897.4819, Expected=3954.0000
# Month=34, Predicted=3956.4620, Expected=3933.0000
# Month=35, Predicted=3935.5209, Expected=3937.0000
# Month=36, Predicted=3939.4902, Expected=3869.0000
# Month=37, Predicted=3873.5314, Expected=3852.0000
# Month=38, Predicted=3854.5144, Expected=3837.0000
# Month=39, Predicted=3839.5114, Expected=3832.0000
# Month=40, Predicted=3834.4989, Expected=3849.0000
# Month=41, Predicted=3851.4806, Expected=3863.0000
# Month=42, Predicted=3865.4826, Expected=3878.0000
# Month=43, Predicted=3880.4819, Expected=3855.0000
# Month=44, Predicted=3857.5246, Expected=3843.0000
# Month=45, Predicted=3845.5073, Expected=3847.0000
# Month=46, Predicted=3849.4902, Expected=3801.0000
# Month=47, Predicted=3803.5934, Expected=3787.0000
# Month=48, Predicted=3789.5100, Expected=3776.0000
# Month=49, Predicted=3778.5060, Expected=3797.0000
# Month=50, Predicted=3799.4781, Expected=3821.0000
# Month=51, Predicted=3823.4764, Expected=3877.0000
# Month=52, Predicted=3879.4630, Expected=3875.0000
# Month=53, Predicted=3877.4958, Expected=3890.0000
# Month=54, Predicted=3892.4819, Expected=3910.0000
# Month=55, Predicted=3912.4787, Expected=3924.0000
# Month=56, Predicted=3926.4826, Expected=3918.0000
# Month=57, Predicted=3920.5000, Expected=3936.0000
# Month=58, Predicted=3938.4800, Expected=3911.0000
# Month=59, Predicted=3913.5284, Expected=3891.0000
# Month=60, Predicted=3893.5192, Expected=3855.0000
# Run 5 — RMSE: 24.542617, MSE: 602.340046, NMSE: 0.0027589763, Time: 190.3s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3799.6860, Expected=3796.0000
# Month=2, Predicted=3797.6937, Expected=3793.0000
# Month=3, Predicted=3794.6940, Expected=3766.0000
# Month=4, Predicted=3767.7053, Expected=3747.0000
# Month=5, Predicted=3748.7005, Expected=3754.0000
# Month=6, Predicted=3755.6911, Expected=3756.0000
# Month=7, Predicted=3757.6925, Expected=3767.0000
# Month=8, Predicted=3768.6902, Expected=3751.0000
# Month=9, Predicted=3752.6990, Expected=3769.0000
# Month=10, Predicted=3770.6887, Expected=3760.0000
# Month=11, Predicted=3761.6961, Expected=3785.0000
# Month=12, Predicted=3786.6874, Expected=3776.0000
# Month=13, Predicted=3777.6961, Expected=3755.0000
# Month=14, Predicted=3756.7016, Expected=3755.0000
# Month=15, Predicted=3756.6931, Expected=3751.0000
# Month=16, Predicted=3752.6943, Expected=3776.0000
# Month=17, Predicted=3777.6874, Expected=3847.0000
# Month=18, Predicted=3848.6819, Expected=3830.0000
# Month=19, Predicted=3831.6995, Expected=3881.0000
# Month=20, Predicted=3882.6838, Expected=3899.0000
# Month=21, Predicted=3900.6887, Expected=3917.0000
# Month=22, Predicted=3918.6887, Expected=3913.0000
# Month=23, Predicted=3914.6943, Expected=3901.0000
# Month=24, Predicted=3902.6973, Expected=3886.0000
# Month=25, Predicted=3887.6986, Expected=3892.5000
# Month=26, Predicted=3894.1913, Expected=3899.0000
# Month=27, Predicted=3900.6913, Expected=3886.0000
# Month=28, Predicted=3887.6977, Expected=3908.0000
# Month=29, Predicted=3909.6879, Expected=3875.0000
# Month=30, Predicted=3876.7101, Expected=3860.0000
# Month=31, Predicted=3861.6986, Expected=3880.0000
# Month=32, Predicted=3881.6883, Expected=3895.0000
# Month=33, Predicted=3896.6893, Expected=3954.0000
# Month=34, Predicted=3955.6830, Expected=3933.0000
# Month=35, Predicted=3934.7016, Expected=3937.0000
# Month=36, Predicted=3938.6919, Expected=3869.0000
# Month=37, Predicted=3870.8572, Expected=3852.0000
# Month=38, Predicted=3853.6995, Expected=3837.0000
# Month=39, Predicted=3838.6986, Expected=3832.0000
# Month=40, Predicted=3833.6946, Expected=3849.0000
# Month=41, Predicted=3850.6889, Expected=3863.0000
# Month=42, Predicted=3864.6895, Expected=3878.0000
# Month=43, Predicted=3879.6893, Expected=3855.0000
# Month=44, Predicted=3856.7028, Expected=3843.0000
# Month=45, Predicted=3844.6973, Expected=3847.0000
# Month=46, Predicted=3848.6919, Expected=3801.0000
# Month=47, Predicted=3802.7265, Expected=3787.0000
# Month=48, Predicted=3788.6981, Expected=3776.0000
# Month=49, Predicted=3777.6969, Expected=3797.0000
# Month=50, Predicted=3798.6881, Expected=3821.0000
# Month=51, Predicted=3822.6876, Expected=3877.0000
# Month=52, Predicted=3878.6833, Expected=3875.0000
# Month=53, Predicted=3876.6937, Expected=3890.0000
# Month=54, Predicted=3891.6893, Expected=3910.0000
# Month=55, Predicted=3911.6883, Expected=3924.0000
# Month=56, Predicted=3925.6895, Expected=3918.0000
# Month=57, Predicted=3919.6950, Expected=3936.0000
# Month=58, Predicted=3937.6887, Expected=3911.0000
# Month=59, Predicted=3912.7040, Expected=3891.0000
# Month=60, Predicted=3892.7011, Expected=3855.0000
# Run 6 — RMSE: 24.476728, MSE: 599.110217, NMSE: 0.0027465815, Time: 188.8s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3800.0571, Expected=3796.0000
# Month=2, Predicted=3798.0526, Expected=3793.0000
# Month=3, Predicted=3795.0525, Expected=3766.0000
# Month=4, Predicted=3768.0488, Expected=3747.0000
# Month=5, Predicted=3749.0501, Expected=3754.0000
# Month=6, Predicted=3756.0538, Expected=3756.0000
# Month=7, Predicted=3758.0531, Expected=3767.0000
# Month=8, Predicted=3769.0543, Expected=3751.0000
# Month=9, Predicted=3753.0505, Expected=3769.0000
# Month=10, Predicted=3771.0552, Expected=3760.0000
# Month=11, Predicted=3762.0516, Expected=3785.0000
# Month=12, Predicted=3787.0561, Expected=3776.0000
# Month=13, Predicted=3778.0516, Expected=3755.0000
# Month=14, Predicted=3757.0498, Expected=3755.0000
# Month=15, Predicted=3757.0529, Expected=3751.0000
# Month=16, Predicted=3753.0523, Expected=3776.0000
# Month=17, Predicted=3778.0561, Expected=3847.0000
# Month=18, Predicted=3849.0608, Expected=3830.0000
# Month=19, Predicted=3832.0504, Expected=3881.0000
# Month=20, Predicted=3883.0589, Expected=3899.0000
# Month=21, Predicted=3901.0552, Expected=3917.0000
# Month=22, Predicted=3919.0552, Expected=3913.0000
# Month=23, Predicted=3915.0523, Expected=3901.0000
# Month=24, Predicted=3903.0511, Expected=3886.0000
# Month=25, Predicted=3888.0507, Expected=3892.5000
# Month=26, Predicted=3894.5537, Expected=3899.0000
# Month=27, Predicted=3901.0537, Expected=3886.0000
# Month=28, Predicted=3888.0510, Expected=3908.0000
# Month=29, Predicted=3910.0557, Expected=3875.0000
# Month=30, Predicted=3877.0478, Expected=3860.0000
# Month=31, Predicted=3862.0507, Expected=3880.0000
# Month=32, Predicted=3882.0555, Expected=3895.0000
# Month=33, Predicted=3897.0549, Expected=3954.0000
# Month=34, Predicted=3956.0597, Expected=3933.0000
# Month=35, Predicted=3935.0498, Expected=3937.0000
# Month=36, Predicted=3939.0534, Expected=3869.0000
# Month=37, Predicted=3871.0409, Expected=3852.0000
# Month=38, Predicted=3854.0504, Expected=3837.0000
# Month=39, Predicted=3839.0507, Expected=3832.0000
# Month=40, Predicted=3834.0522, Expected=3849.0000
# Month=41, Predicted=3851.0551, Expected=3863.0000
# Month=42, Predicted=3865.0547, Expected=3878.0000
# Month=43, Predicted=3880.0549, Expected=3855.0000
# Month=44, Predicted=3857.0494, Expected=3843.0000
# Month=45, Predicted=3845.0511, Expected=3847.0000
# Month=46, Predicted=3849.0534, Expected=3801.0000
# Month=47, Predicted=3803.0454, Expected=3787.0000
# Month=48, Predicted=3789.0508, Expected=3776.0000
# Month=49, Predicted=3778.0513, Expected=3797.0000
# Month=50, Predicted=3799.0556, Expected=3821.0000
# Month=51, Predicted=3823.0560, Expected=3877.0000
# Month=52, Predicted=3879.0594, Expected=3875.0000
# Month=53, Predicted=3877.0526, Expected=3890.0000
# Month=54, Predicted=3892.0549, Expected=3910.0000
# Month=55, Predicted=3912.0555, Expected=3924.0000
# Month=56, Predicted=3926.0547, Expected=3918.0000
# Month=57, Predicted=3920.0520, Expected=3936.0000
# Month=58, Predicted=3938.0552, Expected=3911.0000
# Month=59, Predicted=3913.0491, Expected=3891.0000
# Month=60, Predicted=3893.0499, Expected=3855.0000
# Run 7 — RMSE: 24.486736, MSE: 599.600250, NMSE: 0.0027482596, Time: 189.3s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3799.1470, Expected=3796.0000
# Month=2, Predicted=3798.3094, Expected=3793.0000
# Month=3, Predicted=3795.3270, Expected=3766.0000
# Month=4, Predicted=3768.6233, Expected=3747.0000
# Month=5, Predicted=3749.5438, Expected=3754.0000
# Month=6, Predicted=3756.1058, Expected=3756.0000
# Month=7, Predicted=3758.2303, Expected=3767.0000
# Month=8, Predicted=3768.9838, Expected=3751.0000
# Month=9, Predicted=3753.5102, Expected=3769.0000
# Month=10, Predicted=3770.7378, Expected=3760.0000
# Month=11, Predicted=3762.4203, Expected=3785.0000
# Month=12, Predicted=3786.4771, Expected=3776.0000
# Month=13, Predicted=3778.4203, Expected=3755.0000
# Month=14, Predicted=3757.5649, Expected=3755.0000
# Month=15, Predicted=3757.2718, Expected=3751.0000
# Month=16, Predicted=3753.3439, Expected=3776.0000
# Month=17, Predicted=3777.4771, Expected=3847.0000
# Month=18, Predicted=3847.0652, Expected=3830.0000
# Month=19, Predicted=3832.5217, Expected=3881.0000
# Month=20, Predicted=3881.5919, Expected=3899.0000
# Month=21, Predicted=3900.7378, Expected=3917.0000
# Month=22, Predicted=3918.7378, Expected=3913.0000
# Month=23, Predicted=3915.3439, Expected=3901.0000
# Month=24, Predicted=3903.4610, Expected=3886.0000
# Month=25, Predicted=3888.4984, Expected=3892.5000
# Month=26, Predicted=3894.6197, Expected=3899.0000
# Month=27, Predicted=3901.1197, Expected=3886.0000
# Month=28, Predicted=3888.4738, Expected=3908.0000
# Month=29, Predicted=3909.5893, Expected=3875.0000
# Month=30, Predicted=3877.6773, Expected=3860.0000
# Month=31, Predicted=3862.4984, Expected=3880.0000
# Month=32, Predicted=3881.6639, Expected=3895.0000
# Month=33, Predicted=3896.8466, Expected=3954.0000
# Month=34, Predicted=3954.3671, Expected=3933.0000
# Month=35, Predicted=3935.5649, Expected=3937.0000
# Month=36, Predicted=3939.1843, Expected=3869.0000
# Month=37, Predicted=3871.9524, Expected=3852.0000
# Month=38, Predicted=3854.5217, Expected=3837.0000
# Month=39, Predicted=3839.4984, Expected=3832.0000
# Month=40, Predicted=3834.3602, Expected=3849.0000
# Month=41, Predicted=3850.7745, Expected=3863.0000
# Month=42, Predicted=3864.8820, Expected=3878.0000
# Month=43, Predicted=3879.8466, Expected=3855.0000
# Month=44, Predicted=3857.5850, Expected=3843.0000
# Month=45, Predicted=3845.4610, Expected=3847.0000
# Month=46, Predicted=3849.1843, Expected=3801.0000
# Month=47, Predicted=3803.7878, Expected=3787.0000
# Month=48, Predicted=3789.4862, Expected=3776.0000
# Month=49, Predicted=3778.4478, Expected=3797.0000
# Month=50, Predicted=3798.6266, Expected=3821.0000
# Month=51, Predicted=3822.5145, Expected=3877.0000
# Month=52, Predicted=3877.4489, Expected=3875.0000
# Month=53, Predicted=3877.3094, Expected=3890.0000
# Month=54, Predicted=3891.8466, Expected=3910.0000
# Month=55, Predicted=3911.6639, Expected=3924.0000
# Month=56, Predicted=3925.8820, Expected=3918.0000
# Month=57, Predicted=3920.3760, Expected=3936.0000
# Month=58, Predicted=3937.7378, Expected=3911.0000
# Month=59, Predicted=3913.6044, Expected=3891.0000
# Month=60, Predicted=3893.5545, Expected=3855.0000
# Run 8 — RMSE: 24.542237, MSE: 602.321380, NMSE: 0.0027715979, Time: 187.2s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3797.4138, Expected=3796.0000
# Month=2, Predicted=3798.2282, Expected=3793.0000
# Month=3, Predicted=3795.2348, Expected=3766.0000
# Month=4, Predicted=3768.3242, Expected=3747.0000
# Month=5, Predicted=3749.3041, Expected=3754.0000
# Month=6, Predicted=3756.1423, Expected=3756.0000
# Month=7, Predicted=3758.1967, Expected=3767.0000
# Month=8, Predicted=3769.0800, Expected=3751.0000
# Month=9, Predicted=3753.2948, Expected=3769.0000
# Month=10, Predicted=3770.8161, Expected=3760.0000
# Month=11, Predicted=3762.2675, Expected=3785.0000
# Month=12, Predicted=3785.6133, Expected=3776.0000
# Month=13, Predicted=3778.2675, Expected=3755.0000
# Month=14, Predicted=3757.3097, Expected=3755.0000
# Month=15, Predicted=3757.2135, Expected=3751.0000
# Month=16, Predicted=3753.2411, Expected=3776.0000
# Month=17, Predicted=3776.6133, Expected=3847.0000
# Month=18, Predicted=3845.3808, Expected=3830.0000
# Month=19, Predicted=3832.2980, Expected=3881.0000
# Month=20, Predicted=3879.7568, Expected=3899.0000
# Month=21, Predicted=3900.8161, Expected=3917.0000
# Month=22, Predicted=3918.8161, Expected=3913.0000
# Month=23, Predicted=3915.2411, Expected=3901.0000
# Month=24, Predicted=3903.2803, Expected=3886.0000
# Month=25, Predicted=3888.2914, Expected=3892.5000
# Month=26, Predicted=3894.6488, Expected=3899.0000
# Month=27, Predicted=3901.1488, Expected=3886.0000
# Month=28, Predicted=3888.2842, Expected=3908.0000
# Month=29, Predicted=3909.2072, Expected=3875.0000
# Month=30, Predicted=3877.3360, Expected=3860.0000
# Month=31, Predicted=3862.2914, Expected=3880.0000
# Month=32, Predicted=3881.5701, Expected=3895.0000
# Month=33, Predicted=3896.9839, Expected=3954.0000
# Month=34, Predicted=3952.5884, Expected=3933.0000
# Month=35, Predicted=3935.3097, Expected=3937.0000
# Month=36, Predicted=3939.1774, Expected=3869.0000
# Month=37, Predicted=3871.3768, Expected=3852.0000
# Month=38, Predicted=3854.2980, Expected=3837.0000
# Month=39, Predicted=3839.2914, Expected=3832.0000
# Month=40, Predicted=3834.2470, Expected=3849.0000
# Month=41, Predicted=3850.8918, Expected=3863.0000
# Month=42, Predicted=3865.0140, Expected=3878.0000
# Month=43, Predicted=3879.9839, Expected=3855.0000
# Month=44, Predicted=3857.3149, Expected=3843.0000
# Month=45, Predicted=3845.2803, Expected=3847.0000
# Month=46, Predicted=3849.1774, Expected=3801.0000
# Month=47, Predicted=3803.3553, Expected=3787.0000
# Month=48, Predicted=3789.2879, Expected=3776.0000
# Month=49, Predicted=3778.2763, Expected=3797.0000
# Month=50, Predicted=3798.3991, Expected=3821.0000
# Month=51, Predicted=3821.8062, Expected=3877.0000
# Month=52, Predicted=3875.6483, Expected=3875.0000
# Month=53, Predicted=3877.2282, Expected=3890.0000
# Month=54, Predicted=3891.9839, Expected=3910.0000
# Month=55, Predicted=3911.5701, Expected=3924.0000
# Month=56, Predicted=3926.0140, Expected=3918.0000
# Month=57, Predicted=3920.2525, Expected=3936.0000
# Month=58, Predicted=3937.8161, Expected=3911.0000
# Month=59, Predicted=3913.3197, Expected=3891.0000
# Month=60, Predicted=3893.3070, Expected=3855.0000
# Run 9 — RMSE: 24.548737, MSE: 602.640503, NMSE: 0.0027741011, Time: 192.9s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3800.6478, Expected=3796.0000
# Month=2, Predicted=3798.6542, Expected=3793.0000
# Month=3, Predicted=3795.6544, Expected=3766.0000
# Month=4, Predicted=3768.6607, Expected=3747.0000
# Month=5, Predicted=3749.6584, Expected=3754.0000
# Month=6, Predicted=3756.6524, Expected=3756.0000
# Month=7, Predicted=3758.6534, Expected=3767.0000
# Month=8, Predicted=3769.6516, Expected=3751.0000
# Month=9, Predicted=3753.6576, Expected=3769.0000
# Month=10, Predicted=3771.6504, Expected=3760.0000
# Month=11, Predicted=3762.6558, Expected=3785.0000
# Month=12, Predicted=3787.6492, Expected=3776.0000
# Month=13, Predicted=3778.6558, Expected=3755.0000
# Month=14, Predicted=3757.6589, Expected=3755.0000
# Month=15, Predicted=3757.6538, Expected=3751.0000
# Month=16, Predicted=3753.6547, Expected=3776.0000
# Month=17, Predicted=3778.6492, Expected=3847.0000
# Month=18, Predicted=3849.6434, Expected=3830.0000
# Month=19, Predicted=3832.6578, Expected=3881.0000
# Month=20, Predicted=3883.6456, Expected=3899.0000
# Month=21, Predicted=3901.6504, Expected=3917.0000
# Month=22, Predicted=3919.6504, Expected=3913.0000
# Month=23, Predicted=3915.6547, Expected=3901.0000
# Month=24, Predicted=3903.6565, Expected=3886.0000
# Month=25, Predicted=3888.6573, Expected=3892.5000
# Month=26, Predicted=3895.1525, Expected=3899.0000
# Month=27, Predicted=3901.6525, Expected=3886.0000
# Month=28, Predicted=3888.6568, Expected=3908.0000
# Month=29, Predicted=3910.6497, Expected=3875.0000
# Month=30, Predicted=3877.6626, Expected=3860.0000
# Month=31, Predicted=3862.6573, Expected=3880.0000
# Month=32, Predicted=3882.6500, Expected=3895.0000
# Month=33, Predicted=3897.6509, Expected=3954.0000
# Month=34, Predicted=3956.6446, Expected=3933.0000
# Month=35, Predicted=3935.6589, Expected=3937.0000
# Month=36, Predicted=3939.6530, Expected=3869.0000
# Month=37, Predicted=3871.6785, Expected=3852.0000
# Month=38, Predicted=3854.6578, Expected=3837.0000
# Month=39, Predicted=3839.6573, Expected=3832.0000
# Month=40, Predicted=3834.6549, Expected=3849.0000
# Month=41, Predicted=3851.6505, Expected=3863.0000
# Month=42, Predicted=3865.6511, Expected=3878.0000
# Month=43, Predicted=3880.6509, Expected=3855.0000
# Month=44, Predicted=3857.6595, Expected=3843.0000
# Month=45, Predicted=3845.6565, Expected=3847.0000
# Month=46, Predicted=3849.6530, Expected=3801.0000
# Month=47, Predicted=3803.6674, Expected=3787.0000
# Month=48, Predicted=3789.6571, Expected=3776.0000
# Month=49, Predicted=3778.6563, Expected=3797.0000
# Month=50, Predicted=3799.6498, Expected=3821.0000
# Month=51, Predicted=3823.6494, Expected=3877.0000
# Month=52, Predicted=3879.6450, Expected=3875.0000
# Month=53, Predicted=3877.6542, Expected=3890.0000
# Month=54, Predicted=3892.6509, Expected=3910.0000
# Month=55, Predicted=3912.6500, Expected=3924.0000
# Month=56, Predicted=3926.6511, Expected=3918.0000
# Month=57, Predicted=3920.6551, Expected=3936.0000
# Month=58, Predicted=3938.6504, Expected=3911.0000
# Month=59, Predicted=3913.6601, Expected=3891.0000
# Month=60, Predicted=3893.6586, Expected=3855.0000
# Run 10 — RMSE: 24.522440, MSE: 601.350050, NMSE: 0.0027551192, Time: 156.4s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3799.8116, Expected=3796.0000
# Month=2, Predicted=3797.8164, Expected=3793.0000
# Month=3, Predicted=3794.8166, Expected=3766.0000
# Month=4, Predicted=3767.8227, Expected=3747.0000
# Month=5, Predicted=3748.8202, Expected=3754.0000
# Month=6, Predicted=3755.8149, Expected=3756.0000
# Month=7, Predicted=3757.8157, Expected=3767.0000
# Month=8, Predicted=3768.8143, Expected=3751.0000
# Month=9, Predicted=3752.8194, Expected=3769.0000
# Month=10, Predicted=3770.8134, Expected=3760.0000
# Month=11, Predicted=3761.8178, Expected=3785.0000
# Month=12, Predicted=3786.8126, Expected=3776.0000
# Month=13, Predicted=3777.8178, Expected=3755.0000
# Month=14, Predicted=3756.8208, Expected=3755.0000
# Month=15, Predicted=3756.8160, Expected=3751.0000
# Month=16, Predicted=3752.8168, Expected=3776.0000
# Month=17, Predicted=3777.8126, Expected=3847.0000
# Month=18, Predicted=3848.8089, Expected=3830.0000
# Month=19, Predicted=3831.8197, Expected=3881.0000
# Month=20, Predicted=3882.8102, Expected=3899.0000
# Month=21, Predicted=3900.8134, Expected=3917.0000
# Month=22, Predicted=3918.8134, Expected=3913.0000
# Month=23, Predicted=3914.8168, Expected=3901.0000
# Month=24, Predicted=3902.8185, Expected=3886.0000
# Month=25, Predicted=3887.8192, Expected=3892.5000
# Month=26, Predicted=3894.3150, Expected=3899.0000
# Month=27, Predicted=3900.8150, Expected=3886.0000
# Month=28, Predicted=3887.8187, Expected=3908.0000
# Month=29, Predicted=3909.8129, Expected=3875.0000
# Month=30, Predicted=3876.8250, Expected=3860.0000
# Month=31, Predicted=3861.8192, Expected=3880.0000
# Month=32, Predicted=3881.8131, Expected=3895.0000
# Month=33, Predicted=3896.8138, Expected=3954.0000
# Month=34, Predicted=3955.8097, Expected=3933.0000
# Month=35, Predicted=3934.8208, Expected=3937.0000
# Month=36, Predicted=3938.8154, Expected=3869.0000
# Month=37, Predicted=3870.8551, Expected=3852.0000
# Month=38, Predicted=3853.8197, Expected=3837.0000
# Month=39, Predicted=3838.8192, Expected=3832.0000
# Month=40, Predicted=3833.8170, Expected=3849.0000
# Month=41, Predicted=3850.8135, Expected=3863.0000
# Month=42, Predicted=3864.8139, Expected=3878.0000
# Month=43, Predicted=3879.8138, Expected=3855.0000
# Month=44, Predicted=3856.8214, Expected=3843.0000
# Month=45, Predicted=3844.8185, Expected=3847.0000
# Month=46, Predicted=3848.8154, Expected=3801.0000
# Month=47, Predicted=3802.8319, Expected=3787.0000
# Month=48, Predicted=3788.8189, Expected=3776.0000
# Month=49, Predicted=3777.8182, Expected=3797.0000
# Month=50, Predicted=3798.8130, Expected=3821.0000
# Month=51, Predicted=3822.8127, Expected=3877.0000
# Month=52, Predicted=3878.8099, Expected=3875.0000
# Month=53, Predicted=3876.8164, Expected=3890.0000
# Month=54, Predicted=3891.8138, Expected=3910.0000
# Month=55, Predicted=3911.8131, Expected=3924.0000
# Month=56, Predicted=3925.8139, Expected=3918.0000
# Month=57, Predicted=3919.8172, Expected=3936.0000
# Month=58, Predicted=3937.8134, Expected=3911.0000
# Month=59, Predicted=3912.8220, Expected=3891.0000
# Month=60, Predicted=3892.8205, Expected=3855.0000
# Run 11 — RMSE: 24.478688, MSE: 599.206176, NMSE: 0.0027468991, Time: 156.5s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3799.2892, Expected=3796.0000
# Month=2, Predicted=3798.2378, Expected=3793.0000
# Month=3, Predicted=3795.2417, Expected=3766.0000
# Month=4, Predicted=3768.2993, Expected=3747.0000
# Month=5, Predicted=3749.2859, Expected=3754.0000
# Month=6, Predicted=3756.1940, Expected=3756.0000
# Month=7, Predicted=3758.2203, Expected=3767.0000
# Month=8, Predicted=3769.1696, Expected=3751.0000
# Month=9, Predicted=3753.2797, Expected=3769.0000
# Month=10, Predicted=3771.1014, Expected=3760.0000
# Month=11, Predicted=3762.2619, Expected=3785.0000
# Month=12, Predicted=3786.8375, Expected=3776.0000
# Month=13, Predicted=3778.2619, Expected=3755.0000
# Month=14, Predicted=3757.2896, Expected=3755.0000
# Month=15, Predicted=3757.2294, Expected=3751.0000
# Month=16, Predicted=3753.2454, Expected=3776.0000
# Month=17, Predicted=3777.8375, Expected=3847.0000
# Month=18, Predicted=3847.1215, Expected=3830.0000
# Month=19, Predicted=3832.2819, Expected=3881.0000
# Month=20, Predicted=3881.5443, Expected=3899.0000
# Month=21, Predicted=3901.1014, Expected=3917.0000
# Month=22, Predicted=3919.1014, Expected=3913.0000
# Month=23, Predicted=3915.2454, Expected=3901.0000
# Month=24, Predicted=3903.2702, Expected=3886.0000
# Month=25, Predicted=3888.2775, Expected=3892.5000
# Month=26, Predicted=3894.6969, Expected=3899.0000
# Month=27, Predicted=3901.1969, Expected=3886.0000
# Month=28, Predicted=3888.2727, Expected=3908.0000
# Month=29, Predicted=3909.9827, Expected=3875.0000
# Month=30, Predicted=3877.3070, Expected=3860.0000
# Month=31, Predicted=3862.2775, Expected=3880.0000
# Month=32, Predicted=3882.0538, Expected=3895.0000
# Month=33, Predicted=3897.1402, Expected=3954.0000
# Month=34, Predicted=3954.3410, Expected=3933.0000
# Month=35, Predicted=3935.2896, Expected=3937.0000
# Month=36, Predicted=3939.2104, Expected=3869.0000
# Month=37, Predicted=3871.3321, Expected=3852.0000
# Month=38, Predicted=3854.2819, Expected=3837.0000
# Month=39, Predicted=3839.2775, Expected=3832.0000
# Month=40, Predicted=3834.2490, Expected=3849.0000
# Month=41, Predicted=3851.1176, Expected=3863.0000
# Month=42, Predicted=3865.1487, Expected=3878.0000
# Month=43, Predicted=3880.1402, Expected=3855.0000
# Month=44, Predicted=3857.2931, Expected=3843.0000
# Month=45, Predicted=3845.2702, Expected=3847.0000
# Month=46, Predicted=3849.2104, Expected=3801.0000
# Month=47, Predicted=3803.3193, Expected=3787.0000
# Month=48, Predicted=3789.2751, Expected=3776.0000
# Month=49, Predicted=3778.2675, Expected=3797.0000
# Month=50, Predicted=3799.0212, Expected=3821.0000
# Month=51, Predicted=3822.8902, Expected=3877.0000
# Month=52, Predicted=3877.4101, Expected=3875.0000
# Month=53, Predicted=3877.2378, Expected=3890.0000
# Month=54, Predicted=3892.1402, Expected=3910.0000
# Month=55, Predicted=3912.0538, Expected=3924.0000
# Month=56, Predicted=3926.1487, Expected=3918.0000
# Month=57, Predicted=3920.2524, Expected=3936.0000
# Month=58, Predicted=3938.1014, Expected=3911.0000
# Month=59, Predicted=3913.2963, Expected=3891.0000
# Month=60, Predicted=3893.2878, Expected=3855.0000
# Run 12 — RMSE: 24.485410, MSE: 599.535279, NMSE: 0.0027553243, Time: 157.3s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3798.9427, Expected=3796.0000
# Month=2, Predicted=3798.0001, Expected=3793.0000
# Month=3, Predicted=3795.0037, Expected=3766.0000
# Month=4, Predicted=3768.0581, Expected=3747.0000
# Month=5, Predicted=3749.0449, Expected=3754.0000
# Month=6, Predicted=3755.9572, Expected=3756.0000
# Month=7, Predicted=3757.9836, Expected=3767.0000
# Month=8, Predicted=3768.9294, Expected=3751.0000
# Month=9, Predicted=3753.0390, Expected=3769.0000
# Month=10, Predicted=3770.8566, Expected=3760.0000
# Month=11, Predicted=3762.0224, Expected=3785.0000
# Month=12, Predicted=3786.7004, Expected=3776.0000
# Month=13, Predicted=3778.0224, Expected=3755.0000
# Month=14, Predicted=3757.0485, Expected=3755.0000
# Month=15, Predicted=3756.9922, Expected=3751.0000
# Month=16, Predicted=3753.0072, Expected=3776.0000
# Month=17, Predicted=3777.7004, Expected=3847.0000
# Month=18, Predicted=3846.3945, Expected=3830.0000
# Month=19, Predicted=3832.0410, Expected=3881.0000
# Month=20, Predicted=3880.6711, Expected=3899.0000
# Month=21, Predicted=3900.8566, Expected=3917.0000
# Month=22, Predicted=3918.8566, Expected=3913.0000
# Month=23, Predicted=3915.0072, Expected=3901.0000
# Month=24, Predicted=3903.0300, Expected=3886.0000
# Month=25, Predicted=3888.0369, Expected=3892.5000
# Month=26, Predicted=3894.4602, Expected=3899.0000
# Month=27, Predicted=3900.9602, Expected=3886.0000
# Month=28, Predicted=3888.0324, Expected=3908.0000
# Month=29, Predicted=3909.7866, Expected=3875.0000
# Month=30, Predicted=3877.0660, Expected=3860.0000
# Month=31, Predicted=3862.0369, Expected=3880.0000
# Month=32, Predicted=3881.8258, Expected=3895.0000
# Month=33, Predicted=3896.8928, Expected=3954.0000
# Month=34, Predicted=3953.5903, Expected=3933.0000
# Month=35, Predicted=3935.0485, Expected=3937.0000
# Month=36, Predicted=3938.9739, Expected=3869.0000
# Month=37, Predicted=3871.0951, Expected=3852.0000
# Month=38, Predicted=3854.0410, Expected=3837.0000
# Month=39, Predicted=3839.0369, Expected=3832.0000
# Month=40, Predicted=3834.0105, Expected=3849.0000
# Month=41, Predicted=3850.8697, Expected=3863.0000
# Month=42, Predicted=3864.9030, Expected=3878.0000
# Month=43, Predicted=3879.8928, Expected=3855.0000
# Month=44, Predicted=3857.0519, Expected=3843.0000
# Month=45, Predicted=3845.0300, Expected=3847.0000
# Month=46, Predicted=3848.9739, Expected=3801.0000
# Month=47, Predicted=3803.0796, Expected=3787.0000
# Month=48, Predicted=3789.0347, Expected=3776.0000
# Month=49, Predicted=3778.0276, Expected=3797.0000
# Month=50, Predicted=3798.8075, Expected=3821.0000
# Month=51, Predicted=3822.7340, Expected=3877.0000
# Month=52, Predicted=3876.6266, Expected=3875.0000
# Month=53, Predicted=3877.0001, Expected=3890.0000
# Month=54, Predicted=3891.8928, Expected=3910.0000
# Month=55, Predicted=3911.8258, Expected=3924.0000
# Month=56, Predicted=3925.9030, Expected=3918.0000
# Month=57, Predicted=3920.0137, Expected=3936.0000
# Month=58, Predicted=3937.8566, Expected=3911.0000
# Month=59, Predicted=3913.0551, Expected=3891.0000
# Month=60, Predicted=3893.0467, Expected=3855.0000
# Run 13 — RMSE: 24.463537, MSE: 598.464619, NMSE: 0.0027534115, Time: 160.8s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3799.7009, Expected=3796.0000
# Month=2, Predicted=3797.8875, Expected=3793.0000
# Month=3, Predicted=3794.8928, Expected=3766.0000
# Month=4, Predicted=3768.0096, Expected=3747.0000
# Month=5, Predicted=3748.9728, Expected=3754.0000
# Month=6, Predicted=3755.8395, Expected=3756.0000
# Month=7, Predicted=3757.8663, Expected=3767.0000
# Month=8, Predicted=3768.8180, Expected=3751.0000
# Month=9, Predicted=3752.9584, Expected=3769.0000
# Month=10, Predicted=3770.7808, Expected=3760.0000
# Month=11, Predicted=3761.9237, Expected=3785.0000
# Month=12, Predicted=3786.7447, Expected=3776.0000
# Month=13, Predicted=3777.9237, Expected=3755.0000
# Month=14, Predicted=3756.9822, Expected=3755.0000
# Month=15, Predicted=3756.8770, Expected=3751.0000
# Month=16, Predicted=3752.8980, Expected=3776.0000
# Month=17, Predicted=3777.7447, Expected=3847.0000
# Month=18, Predicted=3848.5575, Expected=3830.0000
# Month=19, Predicted=3831.9632, Expected=3881.0000
# Month=20, Predicted=3882.6278, Expected=3899.0000
# Month=21, Predicted=3900.7808, Expected=3917.0000
# Month=22, Predicted=3918.7808, Expected=3913.0000
# Month=23, Predicted=3914.8980, Expected=3901.0000
# Month=24, Predicted=3902.9388, Expected=3886.0000
# Month=25, Predicted=3887.9536, Expected=3892.5000
# Month=26, Predicted=3894.3422, Expected=3899.0000
# Month=27, Predicted=3900.8422, Expected=3886.0000
# Month=28, Predicted=3887.9437, Expected=3908.0000
# Month=29, Predicted=3909.7600, Expected=3875.0000
# Month=30, Predicted=3877.0359, Expected=3860.0000
# Month=31, Predicted=3861.9536, Expected=3880.0000
# Month=32, Predicted=3881.7703, Expected=3895.0000
# Month=33, Predicted=3896.7966, Expected=3954.0000
# Month=34, Predicted=3955.5977, Expected=3933.0000
# Month=35, Predicted=3934.9822, Expected=3937.0000
# Month=36, Predicted=3938.8556, Expected=3869.0000
# Month=37, Predicted=3871.1725, Expected=3852.0000
# Month=38, Predicted=3853.9632, Expected=3837.0000
# Month=39, Predicted=3838.9536, Expected=3832.0000
# Month=40, Predicted=3833.9032, Expected=3849.0000
# Month=41, Predicted=3850.7860, Expected=3863.0000
# Month=42, Predicted=3864.8020, Expected=3878.0000
# Month=43, Predicted=3879.7966, Expected=3855.0000
# Month=44, Predicted=3856.9915, Expected=3843.0000
# Month=45, Predicted=3844.9388, Expected=3847.0000
# Month=46, Predicted=3848.8556, Expected=3801.0000
# Month=47, Predicted=3803.0891, Expected=3787.0000
# Month=48, Predicted=3788.9487, Expected=3776.0000
# Month=49, Predicted=3777.9338, Expected=3797.0000
# Month=50, Predicted=3798.7651, Expected=3821.0000
# Month=51, Predicted=3822.7498, Expected=3877.0000
# Month=52, Predicted=3878.6087, Expected=3875.0000
# Month=53, Predicted=3876.8875, Expected=3890.0000
# Month=54, Predicted=3891.7966, Expected=3910.0000
# Month=55, Predicted=3911.7703, Expected=3924.0000
# Month=56, Predicted=3925.8020, Expected=3918.0000
# Month=57, Predicted=3919.9084, Expected=3936.0000
# Month=58, Predicted=3937.7808, Expected=3911.0000
# Month=59, Predicted=3913.0006, Expected=3891.0000
# Month=60, Predicted=3892.9775, Expected=3855.0000
# Run 14 — RMSE: 24.493768, MSE: 599.944674, NMSE: 0.0027521384, Time: 161.3s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3798.8934, Expected=3796.0000
# Month=2, Predicted=3797.9644, Expected=3793.0000
# Month=3, Predicted=3794.9741, Expected=3766.0000
# Month=4, Predicted=3768.1353, Expected=3747.0000
# Month=5, Predicted=3749.0933, Expected=3754.0000
# Month=6, Predicted=3755.8573, Expected=3756.0000
# Month=7, Predicted=3757.9217, Expected=3767.0000
# Month=8, Predicted=3768.7930, Expected=3751.0000
# Month=9, Predicted=3753.0751, Expected=3769.0000
# Month=10, Predicted=3770.6342, Expected=3760.0000
# Month=11, Predicted=3762.0259, Expected=3785.0000
# Month=12, Predicted=3786.3815, Expected=3776.0000
# Month=13, Predicted=3778.0259, Expected=3755.0000
# Month=14, Predicted=3757.1046, Expected=3755.0000
# Month=15, Predicted=3756.9438, Expected=3751.0000
# Month=16, Predicted=3752.9835, Expected=3776.0000
# Month=17, Predicted=3777.3815, Expected=3847.0000
# Month=18, Predicted=3846.0687, Expected=3830.0000
# Month=19, Predicted=3832.0814, Expected=3881.0000
# Month=20, Predicted=3880.8707, Expected=3899.0000
# Month=21, Predicted=3900.6342, Expected=3917.0000
# Month=22, Predicted=3918.6342, Expected=3913.0000
# Month=23, Predicted=3914.9835, Expected=3901.0000
# Month=24, Predicted=3903.0483, Expected=3886.0000
# Month=25, Predicted=3888.0687, Expected=3892.5000
# Month=26, Predicted=3894.3644, Expected=3899.0000
# Month=27, Predicted=3900.8644, Expected=3886.0000
# Month=28, Predicted=3888.0553, Expected=3908.0000
# Month=29, Predicted=3909.5036, Expected=3875.0000
# Month=30, Predicted=3877.1617, Expected=3860.0000
# Month=31, Predicted=3862.0687, Expected=3880.0000
# Month=32, Predicted=3881.5732, Expected=3895.0000
# Month=33, Predicted=3896.7113, Expected=3954.0000
# Month=34, Predicted=3953.5028, Expected=3933.0000
# Month=35, Predicted=3935.1046, Expected=3937.0000
# Month=36, Predicted=3938.8976, Expected=3869.0000
# Month=37, Predicted=3871.2669, Expected=3852.0000
# Month=38, Predicted=3854.0814, Expected=3837.0000
# Month=39, Predicted=3839.0687, Expected=3832.0000
# Month=40, Predicted=3833.9925, Expected=3849.0000
# Month=41, Predicted=3850.6617, Expected=3863.0000
# Month=42, Predicted=3864.7338, Expected=3878.0000
# Month=43, Predicted=3879.7113, Expected=3855.0000
# Month=44, Predicted=3857.1154, Expected=3843.0000
# Month=45, Predicted=3845.0483, Expected=3847.0000
# Month=46, Predicted=3848.8976, Expected=3801.0000
# Month=47, Predicted=3803.2086, Expected=3787.0000
# Month=48, Predicted=3789.0621, Expected=3776.0000
# Month=49, Predicted=3778.0411, Expected=3797.0000
# Month=50, Predicted=3798.5396, Expected=3821.0000
# Month=51, Predicted=3822.4246, Expected=3877.0000
# Month=52, Predicted=3876.6321, Expected=3875.0000
# Month=53, Predicted=3876.9644, Expected=3890.0000
# Month=54, Predicted=3891.7113, Expected=3910.0000
# Month=55, Predicted=3911.5732, Expected=3924.0000
# Month=56, Predicted=3925.7338, Expected=3918.0000
# Month=57, Predicted=3920.0013, Expected=3936.0000
# Month=58, Predicted=3937.6342, Expected=3911.0000
# Month=59, Predicted=3913.1256, Expected=3891.0000
# Month=60, Predicted=3893.0991, Expected=3855.0000
# Run 15 — RMSE: 24.485629, MSE: 599.546017, NMSE: 0.0027595884, Time: 158.1s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3800.1388, Expected=3796.0000
# Month=2, Predicted=3798.1609, Expected=3793.0000
# Month=3, Predicted=3795.1618, Expected=3766.0000
# Month=4, Predicted=3768.1906, Expected=3747.0000
# Month=5, Predicted=3749.1789, Expected=3754.0000
# Month=6, Predicted=3756.1539, Expected=3756.0000
# Month=7, Predicted=3758.1576, Expected=3767.0000
# Month=8, Predicted=3769.1512, Expected=3751.0000
# Month=9, Predicted=3753.1752, Expected=3769.0000
# Month=10, Predicted=3771.1468, Expected=3760.0000
# Month=11, Predicted=3762.1675, Expected=3785.0000
# Month=12, Predicted=3787.1430, Expected=3776.0000
# Month=13, Predicted=3778.1675, Expected=3755.0000
# Month=14, Predicted=3757.1816, Expected=3755.0000
# Month=15, Predicted=3757.1593, Expected=3751.0000
# Month=16, Predicted=3753.1627, Expected=3776.0000
# Month=17, Predicted=3778.1430, Expected=3847.0000
# Month=18, Predicted=3849.1262, Expected=3830.0000
# Month=19, Predicted=3832.1764, Expected=3881.0000
# Month=20, Predicted=3883.1322, Expected=3899.0000
# Month=21, Predicted=3901.1468, Expected=3917.0000
# Month=22, Predicted=3919.1468, Expected=3913.0000
# Month=23, Predicted=3915.1627, Expected=3901.0000
# Month=24, Predicted=3903.1706, Expected=3886.0000
# ...
# Month=55, Predicted=3911.8182, Expected=3924.0000
# Month=56, Predicted=3925.8184, Expected=3918.0000
# Month=57, Predicted=3919.8189, Expected=3936.0000
# Month=58, Predicted=3937.8183, Expected=3911.0000
# Month=59, Predicted=3912.8195, Expected=3891.0000
# Month=60, Predicted=3892.8194, Expected=3855.0000
# Run 25 — RMSE: 24.477853, MSE: 599.165272, NMSE: 0.0027466735, Time: 115.1s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3798.6000, Expected=3796.0000
# Month=2, Predicted=3798.0285, Expected=3793.0000
# Month=3, Predicted=3795.0388, Expected=3766.0000
# Month=4, Predicted=3768.1947, Expected=3747.0000
# Month=5, Predicted=3749.1569, Expected=3754.0000
# Month=6, Predicted=3755.9087, Expected=3756.0000
# Month=7, Predicted=3757.9819, Expected=3767.0000
# Month=8, Predicted=3768.8341, Expected=3751.0000
# Month=9, Predicted=3753.1399, Expected=3769.0000
# Month=10, Predicted=3770.6502, Expected=3760.0000
# Month=11, Predicted=3762.0921, Expected=3785.0000
# Month=12, Predicted=3786.3475, Expected=3776.0000
# Month=13, Predicted=3778.0921, Expected=3755.0000
# Month=14, Predicted=3757.1673, Expected=3755.0000
# Month=15, Predicted=3757.0063, Expected=3751.0000
# Month=16, Predicted=3753.0487, Expected=3776.0000
# Month=17, Predicted=3777.3475, Expected=3847.0000
# Month=18, Predicted=3844.8272, Expected=3830.0000
# Month=19, Predicted=3832.1458, Expected=3881.0000
# Month=20, Predicted=3879.9074, Expected=3899.0000
# Month=21, Predicted=3900.6502, Expected=3917.0000
# Month=22, Predicted=3918.6502, Expected=3913.0000
# Month=23, Predicted=3915.0487, Expected=3901.0000
# Month=24, Predicted=3903.1142, Expected=3886.0000
# Month=25, Predicted=3888.1338, Expected=3892.5000
# Month=26, Predicted=3894.4170, Expected=3899.0000
# Month=27, Predicted=3900.9170, Expected=3886.0000
# Month=28, Predicted=3888.1210, Expected=3908.0000
# Month=29, Predicted=3909.4973, Expected=3875.0000
# Month=30, Predicted=3877.2177, Expected=3860.0000
# Month=31, Predicted=3862.1338, Expected=3880.0000
# Month=32, Predicted=3881.5794, Expected=3895.0000
# Month=33, Predicted=3896.7393, Expected=3954.0000
# Month=34, Predicted=3952.4179, Expected=3933.0000
# Month=35, Predicted=3935.1673, Expected=3937.0000
# Month=36, Predicted=3938.9549, Expected=3869.0000
# Month=37, Predicted=3871.3036, Expected=3852.0000
# Month=38, Predicted=3854.1458, Expected=3837.0000
# Month=39, Predicted=3839.1338, Expected=3832.0000
# Month=40, Predicted=3834.0582, Expected=3849.0000
# Month=41, Predicted=3850.6820, Expected=3863.0000
# Month=42, Predicted=3864.7653, Expected=3878.0000
# Month=43, Predicted=3879.7393, Expected=3855.0000
# Month=44, Predicted=3857.1770, Expected=3843.0000
# Month=45, Predicted=3845.1142, Expected=3847.0000
# Month=46, Predicted=3848.9549, Expected=3801.0000
# Month=47, Predicted=3803.2571, Expected=3787.0000
# Month=48, Predicted=3789.1275, Expected=3776.0000
# Month=49, Predicted=3778.1071, Expected=3797.0000
# Month=50, Predicted=3798.5399, Expected=3821.0000
# Month=51, Predicted=3822.4015, Expected=3877.0000
# Month=52, Predicted=3875.5903, Expected=3875.0000
# Month=53, Predicted=3877.0285, Expected=3890.0000
# Month=54, Predicted=3891.7393, Expected=3910.0000
# Month=55, Predicted=3911.5794, Expected=3924.0000
# Month=56, Predicted=3925.7653, Expected=3918.0000
# Month=57, Predicted=3920.0672, Expected=3936.0000
# Month=58, Predicted=3937.6502, Expected=3911.0000
# Month=59, Predicted=3913.1861, Expected=3891.0000
# Month=60, Predicted=3893.1621, Expected=3855.0000
# Run 26 — RMSE: 24.476420, MSE: 599.095133, NMSE: 0.0027620691, Time: 116.3s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3797.7126, Expected=3796.0000
# Month=2, Predicted=3798.2780, Expected=3793.0000
# Month=3, Predicted=3795.2874, Expected=3766.0000
# Month=4, Predicted=3768.4274, Expected=3747.0000
# Month=5, Predicted=3749.3939, Expected=3754.0000
# Month=6, Predicted=3756.1659, Expected=3756.0000
# Month=7, Predicted=3758.2350, Expected=3767.0000
# Month=8, Predicted=3769.0910, Expected=3751.0000
# Month=9, Predicted=3753.3788, Expected=3769.0000
# Month=10, Predicted=3770.8663, Expected=3760.0000
# Month=11, Predicted=3762.3359, Expected=3785.0000
# Month=12, Predicted=3786.3440, Expected=3776.0000
# Month=13, Predicted=3778.3359, Expected=3755.0000
# Month=14, Predicted=3757.4032, Expected=3755.0000
# Month=15, Predicted=3757.2576, Expected=3751.0000
# Month=16, Predicted=3753.2965, Expected=3776.0000
# Month=17, Predicted=3777.3440, Expected=3847.0000
# Month=18, Predicted=3843.1449, Expected=3830.0000
# Month=19, Predicted=3832.3840, Expected=3881.0000
# Month=20, Predicted=3878.1870, Expected=3899.0000
# Month=21, Predicted=3900.8663, Expected=3917.0000
# Month=22, Predicted=3918.8663, Expected=3913.0000
# Month=23, Predicted=3915.2965, Expected=3901.0000
# Month=24, Predicted=3903.3557, Expected=3886.0000
# Month=25, Predicted=3888.3734, Expected=3892.5000
# Month=26, Predicted=3894.6738, Expected=3899.0000
# Month=27, Predicted=3901.1738, Expected=3886.0000
# Month=28, Predicted=3888.3618, Expected=3908.0000
# Month=29, Predicted=3909.6225, Expected=3875.0000
# Month=30, Predicted=3877.4474, Expected=3860.0000
# Month=31, Predicted=3862.3734, Expected=3880.0000
# Month=32, Predicted=3881.7595, Expected=3895.0000
# Month=33, Predicted=3896.9842, Expected=3954.0000
# Month=34, Predicted=3950.6753, Expected=3933.0000
# Month=35, Predicted=3935.4032, Expected=3937.0000
# Month=36, Predicted=3939.2098, Expected=3869.0000
# Month=37, Predicted=3871.5180, Expected=3852.0000
# Month=38, Predicted=3854.3840, Expected=3837.0000
# Month=39, Predicted=3839.3734, Expected=3832.0000
# Month=40, Predicted=3834.3051, Expected=3849.0000
# Month=41, Predicted=3850.9105, Expected=3863.0000
# Month=42, Predicted=3865.0152, Expected=3878.0000
# Month=43, Predicted=3879.9842, Expected=3855.0000
# Month=44, Predicted=3857.4118, Expected=3843.0000
# Month=45, Predicted=3845.3557, Expected=3847.0000
# Month=46, Predicted=3849.2098, Expected=3801.0000
# Month=47, Predicted=3803.4807, Expected=3787.0000
# Month=48, Predicted=3789.3677, Expected=3776.0000
# Month=49, Predicted=3778.3494, Expected=3797.0000
# Month=50, Predicted=3798.6952, Expected=3821.0000
# Month=51, Predicted=3822.4480, Expected=3877.0000
# Month=52, Predicted=3873.8460, Expected=3875.0000
# Month=53, Predicted=3877.2780, Expected=3890.0000
# Month=54, Predicted=3891.9842, Expected=3910.0000
# Month=55, Predicted=3911.7595, Expected=3924.0000
# Month=56, Predicted=3926.0152, Expected=3918.0000
# Month=57, Predicted=3920.3133, Expected=3936.0000
# Month=58, Predicted=3937.8663, Expected=3911.0000
# Month=59, Predicted=3913.4198, Expected=3891.0000
# Month=60, Predicted=3893.3986, Expected=3855.0000
# Run 27 — RMSE: 24.482603, MSE: 599.397866, NMSE: 0.0027696692, Time: 115.6s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3798.9561, Expected=3796.0000
# Month=2, Predicted=3798.8032, Expected=3793.0000
# Month=3, Predicted=3795.8130, Expected=3766.0000
# Month=4, Predicted=3768.9508, Expected=3747.0000
# Month=5, Predicted=3749.9175, Expected=3754.0000
# Month=6, Predicted=3756.6729, Expected=3756.0000
# Month=7, Predicted=3758.7567, Expected=3767.0000
# Month=8, Predicted=3769.5713, Expected=3751.0000
# Month=9, Predicted=3753.9027, Expected=3769.0000
# Month=10, Predicted=3771.2712, Expected=3760.0000
# Month=11, Predicted=3762.8612, Expected=3785.0000
# Month=12, Predicted=3786.7738, Expected=3776.0000
# Month=13, Predicted=3778.8612, Expected=3755.0000
# Month=14, Predicted=3757.9265, Expected=3755.0000
# Month=15, Predicted=3757.7817, Expected=3751.0000
# Month=16, Predicted=3753.8222, Expected=3776.0000
# Month=17, Predicted=3777.7738, Expected=3847.0000
# Month=18, Predicted=3846.8897, Expected=3830.0000
# Month=19, Predicted=3832.9078, Expected=3881.0000
# Month=20, Predicted=3880.9798, Expected=3899.0000
# Month=21, Predicted=3901.2712, Expected=3917.0000
# Month=22, Predicted=3919.2712, Expected=3913.0000
# Month=23, Predicted=3915.8222, Expected=3901.0000
# Month=24, Predicted=3903.8804, Expected=3886.0000
# Month=25, Predicted=3888.8975, Expected=3892.5000
# Month=26, Predicted=3895.1831, Expected=3899.0000
# Month=27, Predicted=3901.6831, Expected=3886.0000
# Month=28, Predicted=3888.8863, Expected=3908.0000
# Month=29, Predicted=3910.0106, Expected=3875.0000
# Month=30, Predicted=3877.9715, Expected=3860.0000
# Month=31, Predicted=3862.8975, Expected=3880.0000
# Month=32, Predicted=3882.1494, Expected=3895.0000
# Month=33, Predicted=3897.4226, Expected=3954.0000
# Month=34, Predicted=3953.8798, Expected=3933.0000
# Month=35, Predicted=3935.9265, Expected=3937.0000
# Month=36, Predicted=3939.7275, Expected=3869.0000
# Month=37, Predicted=3872.0528, Expected=3852.0000
# Month=38, Predicted=3854.9078, Expected=3837.0000
# Month=39, Predicted=3839.8975, Expected=3832.0000
# Month=40, Predicted=3834.8308, Expected=3849.0000
# Month=41, Predicted=3851.3258, Expected=3863.0000
# Month=42, Predicted=3865.4651, Expected=3878.0000
# Month=43, Predicted=3880.4226, Expected=3855.0000
# Month=44, Predicted=3857.9351, Expected=3843.0000
# Month=45, Predicted=3845.8804, Expected=3847.0000
# Month=46, Predicted=3849.7275, Expected=3801.0000
# Month=47, Predicted=3804.0078, Expected=3787.0000
# Month=48, Predicted=3789.8920, Expected=3776.0000
# Month=49, Predicted=3778.8743, Expected=3797.0000
# Month=50, Predicted=3799.0820, Expected=3821.0000
# Month=51, Predicted=3822.8562, Expected=3877.0000
# Month=52, Predicted=3876.9008, Expected=3875.0000
# Month=53, Predicted=3877.8032, Expected=3890.0000
# Month=54, Predicted=3892.4226, Expected=3910.0000
# Month=55, Predicted=3912.1494, Expected=3924.0000
# Month=56, Predicted=3926.4651, Expected=3918.0000
# Month=57, Predicted=3920.8390, Expected=3936.0000
# Month=58, Predicted=3938.2712, Expected=3911.0000
# Month=59, Predicted=3913.9431, Expected=3891.0000
# Month=60, Predicted=3893.9221, Expected=3855.0000
# Run 28 — RMSE: 24.556842, MSE: 603.038500, NMSE: 0.0027761842, Time: 115.8s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3796.8765, Expected=3796.0000
# Month=2, Predicted=3798.8950, Expected=3793.0000
# Month=3, Predicted=3795.9079, Expected=3766.0000
# Month=4, Predicted=3769.0990, Expected=3747.0000
# Month=5, Predicted=3750.0518, Expected=3754.0000
# Month=6, Predicted=3756.7334, Expected=3756.0000
# Month=7, Predicted=3758.8355, Expected=3767.0000
# Month=8, Predicted=3769.6123, Expected=3751.0000
# Month=9, Predicted=3754.0309, Expected=3769.0000
# Month=10, Predicted=3771.2065, Expected=3760.0000
# Month=11, Predicted=3762.9729, Expected=3785.0000
# Month=12, Predicted=3786.1705, Expected=3776.0000
# Month=13, Predicted=3778.9729, Expected=3755.0000
# Month=14, Predicted=3758.0646, Expected=3755.0000
# Month=15, Predicted=3757.8671, Expected=3751.0000
# Month=16, Predicted=3753.9200, Expected=3776.0000
# Month=17, Predicted=3777.1705, Expected=3847.0000
# Month=18, Predicted=3842.3300, Expected=3830.0000
# Month=19, Predicted=3833.0381, Expected=3881.0000
# Month=20, Predicted=3877.4845, Expected=3899.0000
# Month=21, Predicted=3901.2065, Expected=3917.0000
# Month=22, Predicted=3919.2065, Expected=3913.0000
# Month=23, Predicted=3915.9200, Expected=3901.0000
# Month=24, Predicted=3903.9996, Expected=3886.0000
# Month=25, Predicted=3889.0235, Expected=3892.5000
# Month=26, Predicted=3895.2456, Expected=3899.0000
# Month=27, Predicted=3901.7456, Expected=3886.0000
# Month=28, Predicted=3889.0079, Expected=3908.0000
# Month=29, Predicted=3909.7339, Expected=3875.0000
# Month=30, Predicted=3878.1283, Expected=3860.0000
# Month=31, Predicted=3863.0235, Expected=3880.0000
# Month=32, Predicted=3882.0028, Expected=3895.0000
# Month=33, Predicted=3897.4246, Expected=3954.0000
# Month=34, Predicted=3949.9048, Expected=3933.0000
# Month=35, Predicted=3936.0646, Expected=3937.0000
# Month=36, Predicted=3939.7993, Expected=3869.0000
# Month=37, Predicted=3872.2400, Expected=3852.0000
# Month=38, Predicted=3855.0381, Expected=3837.0000
# Month=39, Predicted=3840.0235, Expected=3832.0000
# Month=40, Predicted=3834.9316, Expected=3849.0000
# Month=41, Predicted=3851.2891, Expected=3863.0000
# Month=42, Predicted=3865.4803, Expected=3878.0000
# Month=43, Predicted=3880.4246, Expected=3855.0000
# Month=44, Predicted=3858.0767, Expected=3843.0000
# Month=45, Predicted=3845.9996, Expected=3847.0000
# Month=46, Predicted=3849.7993, Expected=3801.0000
# Month=47, Predicted=3804.1792, Expected=3787.0000
# Month=48, Predicted=3790.0158, Expected=3776.0000
# Month=49, Predicted=3778.9911, Expected=3797.0000
# Month=50, Predicted=3798.8776, Expected=3821.0000
# Month=51, Predicted=3822.3818, Expected=3877.0000
# Month=52, Predicted=3873.0970, Expected=3875.0000
# Month=53, Predicted=3877.8950, Expected=3890.0000
# Month=54, Predicted=3892.4246, Expected=3910.0000
# Month=55, Predicted=3912.0028, Expected=3924.0000
# Month=56, Predicted=3926.4803, Expected=3918.0000
# Month=57, Predicted=3920.9426, Expected=3936.0000
# Month=58, Predicted=3938.2065, Expected=3911.0000
# Month=59, Predicted=3914.0882, Expected=3891.0000
# Month=60, Predicted=3894.0583, Expected=3855.0000
# Run 29 — RMSE: 24.560733, MSE: 603.229585, NMSE: 0.0027906051, Time: 115.9s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3799.8913, Expected=3796.0000
# Month=2, Predicted=3797.8988, Expected=3793.0000
# Month=3, Predicted=3794.8990, Expected=3766.0000
# Month=4, Predicted=3767.9043, Expected=3747.0000
# Month=5, Predicted=3748.9026, Expected=3754.0000
# Month=6, Predicted=3755.8969, Expected=3756.0000
# Month=7, Predicted=3757.8979, Expected=3767.0000
# Month=8, Predicted=3768.8960, Expected=3751.0000
# Month=9, Predicted=3752.9019, Expected=3769.0000
# Month=10, Predicted=3770.8945, Expected=3760.0000
# Month=11, Predicted=3761.9003, Expected=3785.0000
# Month=12, Predicted=3786.8931, Expected=3776.0000
# Month=13, Predicted=3777.9003, Expected=3755.0000
# Month=14, Predicted=3756.9030, Expected=3755.0000
# Month=15, Predicted=3756.8984, Expected=3751.0000
# Month=16, Predicted=3752.8992, Expected=3776.0000
# Month=17, Predicted=3777.8931, Expected=3847.0000
# Month=18, Predicted=3848.8845, Expected=3830.0000
# Month=19, Predicted=3831.9021, Expected=3881.0000
# Month=20, Predicted=3882.8881, Expected=3899.0000
# Month=21, Predicted=3900.8945, Expected=3917.0000
# Month=22, Predicted=3918.8945, Expected=3913.0000
# Month=23, Predicted=3914.8992, Expected=3901.0000
# Month=24, Predicted=3902.9010, Expected=3886.0000
# Month=25, Predicted=3887.9017, Expected=3892.5000
# Month=26, Predicted=3894.3970, Expected=3899.0000
# Month=27, Predicted=3900.8970, Expected=3886.0000
# Month=28, Predicted=3887.9012, Expected=3908.0000
# Month=29, Predicted=3909.8937, Expected=3875.0000
# Month=30, Predicted=3876.9057, Expected=3860.0000
# Month=31, Predicted=3861.9017, Expected=3880.0000
# Month=32, Predicted=3881.8941, Expected=3895.0000
# Month=33, Predicted=3896.8952, Expected=3954.0000
# Month=34, Predicted=3955.8866, Expected=3933.0000
# Month=35, Predicted=3934.9030, Expected=3937.0000
# Month=36, Predicted=3938.8975, Expected=3869.0000
# Month=37, Predicted=3870.9130, Expected=3852.0000
# Month=38, Predicted=3853.9021, Expected=3837.0000
# Month=39, Predicted=3838.9017, Expected=3832.0000
# Month=40, Predicted=3833.8995, Expected=3849.0000
# Month=41, Predicted=3850.8947, Expected=3863.0000
# Month=42, Predicted=3864.8954, Expected=3878.0000
# Month=43, Predicted=3879.8952, Expected=3855.0000
# Month=44, Predicted=3856.9034, Expected=3843.0000
# Month=45, Predicted=3844.9010, Expected=3847.0000
# Month=46, Predicted=3848.8975, Expected=3801.0000
# Month=47, Predicted=3802.9085, Expected=3787.0000
# Month=48, Predicted=3788.9015, Expected=3776.0000
# Month=49, Predicted=3777.9008, Expected=3797.0000
# Month=50, Predicted=3798.8939, Expected=3821.0000
# Month=51, Predicted=3822.8933, Expected=3877.0000
# Month=52, Predicted=3878.8871, Expected=3875.0000
# Month=53, Predicted=3876.8988, Expected=3890.0000
# Month=54, Predicted=3891.8952, Expected=3910.0000
# Month=55, Predicted=3911.8941, Expected=3924.0000
# Month=56, Predicted=3925.8954, Expected=3918.0000
# Month=57, Predicted=3919.8997, Expected=3936.0000
# Month=58, Predicted=3937.8945, Expected=3911.0000
# Month=59, Predicted=3912.9039, Expected=3891.0000
# Month=60, Predicted=3892.9028, Expected=3855.0000
# Run 30 — RMSE: 24.481314, MSE: 599.334751, NMSE: 0.0027474139, Time: 118.7s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — PatchTST on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.505192 ± 0.031404
# MSE:  600.505433 ± 1.539961
# NMSE: 0.0027582008 ± 0.0000113907
# Avg training time: 153.5s ± 29.3s
#
# Best run: 13
#   RMSE: 24.463537
#   MSE:  598.464619
#   NMSE: 0.0027534115

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('PatchTST — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('PatchTST — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.463537
# MSE:  598.464619
# NMSE: 0.0027534115

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'PatchTST_DowJones_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')

# %% [markdown]
# ## Observations
#
# ### PatchTST on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
