# %% [markdown]
# # PatchTST — Monthly Milk Production
#
# **Model**: Patch-based Time Series Transformer
# **Reference**: Nie et al., 2023 — A Time Series is Worth 64 Words: Long-term Forecasting with Transformers
#
# ## Description
# This notebook implements the **PatchTST** Transformer architecture for univariate time-series
# forecasting on the Monthly Milk Production dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: PatchTST Architecture
#
# ### Patching
# Time series is segmented into **subseries-level patches**:
# $$P_i = x[i \cdot S : i \cdot S + P], \quad i = 0, 1, \ldots, N-1$$
#
# where $P$ = patch length, $S$ = stride, $N$ = number of patches.
#
# Each patch is projected to $d_{\text{model}}$ dimensions via a linear layer.
#
# ### Channel Independence
# Each variate (channel) is processed **independently** through the same Transformer backbone, reducing parameters and improving robustness.
#
# ### Instance Normalization
# Applied per-instance to handle distribution shift between training and testing:
# $$\hat{x} = \frac{x - \mu_x}{\sigma_x}$$
#
# ### Standard Transformer
# After patching, a standard Transformer encoder processes the patch tokens with multi-head self-attention and feed-forward layers.
#
# ### Complexity
# Patching reduces the effective sequence length from $L$ to $N = L/S$, achieving $O(N^2) = O((L/S)^2)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.8.0+cpu
# NumPy version: 2.0.2
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### PatchTST Model Definition

# %%
# ============================================================
# PatchTST: Patch-based Time Series Transformer
# Reference: Nie et al., 2023
#
# Key ideas:
# 1. Patching: segment time series into subseries-level patches
# 2. Channel independence: each variate processed independently
# 3. Instance normalization for distribution shift
#
# For our single-step (seq_len=1) setup, patch_len=1 naturally.
# The architecture still applies the full Transformer pipeline.
# ============================================================

class PatchEmbedding(nn.Module):
    """
    Patch embedding for time series.
    Segments input into patches and projects to d_model.
    For seq_len=1, patch_len=1, this is equivalent to a linear projection.
    """
    def __init__(self, input_dim, d_model, patch_len=1, stride=1):
        super().__init__()
        self.patch_len = patch_len
        self.stride = stride
        self.proj = nn.Linear(patch_len * input_dim, d_model)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape
        # Number of patches
        n_patches = max(1, (L - self.patch_len) // self.stride + 1)

        patches = []
        for i in range(n_patches):
            start = i * self.stride
            end = start + self.patch_len
            patch = x[:, start:end, :].reshape(B, -1)  # (B, patch_len * C)
            patches.append(patch)

        patches = torch.stack(patches, dim=1)  # (B, n_patches, patch_len * C)
        return self.proj(patches)  # (B, n_patches, d_model)


class PatchTSTEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = nn.MultiheadAttention(d_model, n_heads,
                                                dropout=dropout,
                                                batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_out, _ = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_out))
        ff_out = self.ff(x)
        x = self.norm2(x + ff_out)
        return x


class PatchTSTModel(nn.Module):
    """
    PatchTST for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, patch_len=1, stride=1, dropout=0.1):
        super().__init__()
        # Instance normalization
        self.instance_norm = nn.InstanceNorm1d(input_dim, affine=False)

        self.patch_embed = PatchEmbedding(input_dim, d_model, patch_len, stride)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            PatchTSTEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.flatten_head = nn.Linear(d_model, 1)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape

        # Instance normalization (channel-wise)
        if L > 1:
            x = self.instance_norm(x.transpose(1, 2)).transpose(1, 2)

        # Patch embedding
        x = self.patch_embed(x)  # (B, n_patches, d_model)
        n_patches = x.shape[1]
        x = x + self.pos_embedding[:, :n_patches, :]

        # Transformer encoder
        for layer in self.encoder_layers:
            x = layer(x)

        # Use last patch for prediction
        x = x[:, -1, :]
        return self.flatten_head(x)

# %%
# Quick model check
set_seed(0)
test_model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20385
# Trainable parameters: 20385
# Memory estimate: 79.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=759.9757, Expected=804.0000
# Month=2, Predicted=814.6661, Expected=756.0000
# Month=3, Predicted=724.8281, Expected=860.0000
# Month=4, Predicted=872.9800, Expected=878.0000
# Month=5, Predicted=875.6517, Expected=942.0000
# Month=6, Predicted=953.5054, Expected=913.0000
# Month=7, Predicted=880.4384, Expected=869.0000
# Month=8, Predicted=837.6919, Expected=834.0000
# Month=9, Predicted=802.1613, Expected=790.0000
# Month=10, Predicted=758.6919, Expected=800.0000
# Month=11, Predicted=782.6443, Expected=763.0000
# Month=12, Predicted=731.3206, Expected=800.0000
# Month=13, Predicted=808.3831, Expected=826.0000
# Month=14, Predicted=830.6586, Expected=799.0000
# Month=15, Predicted=766.1699, Expected=890.0000
# Month=16, Predicted=902.6510, Expected=900.0000
# Month=17, Predicted=882.6443, Expected=961.0000
# Month=18, Predicted=972.3095, Expected=935.0000
# Month=19, Predicted=902.1217, Expected=894.0000
# Month=20, Predicted=862.5597, Expected=855.0000
# Month=21, Predicted=823.4511, Expected=809.0000
# Month=22, Predicted=777.7647, Expected=810.0000
# Month=23, Predicted=787.5859, Expected=766.0000
# Month=24, Predicted=734.6919, Expected=805.0000
# Month=25, Predicted=813.7902, Expected=821.0000
# Month=26, Predicted=815.4867, Expected=773.0000
# Month=27, Predicted=741.8281, Expected=883.0000
# Month=28, Predicted=896.1045, Expected=898.0000
# Month=29, Predicted=890.6301, Expected=957.0000
# Month=30, Predicted=968.1668, Expected=924.0000
# Month=31, Predicted=891.9649, Expected=881.0000
# Month=32, Predicted=849.6513, Expected=837.0000
# Month=33, Predicted=805.6919, Expected=784.0000
# Month=34, Predicted=752.9560, Expected=791.0000
# Month=35, Predicted=769.7048, Expected=760.0000
# Month=36, Predicted=727.7232, Expected=802.0000
# Month=37, Predicted=811.3154, Expected=828.0000
# Month=38, Predicted=832.6586, Expected=778.0000
# Month=39, Predicted=746.8838, Expected=889.0000
# Month=40, Predicted=902.1239, Expected=902.0000
# Month=41, Predicted=890.5381, Expected=969.0000
# Month=42, Predicted=980.6821, Expected=947.0000
# Month=43, Predicted=920.6377, Expected=908.0000
# Month=44, Predicted=876.4511, Expected=867.0000
# Month=45, Predicted=835.5597, Expected=815.0000
# Month=46, Predicted=783.9333, Expected=812.0000
# Month=47, Predicted=793.1889, Expected=773.0000
# Month=48, Predicted=741.4511, Expected=813.0000
# Month=49, Predicted=821.9757, Expected=834.0000
# Month=50, Predicted=835.1157, Expected=782.0000
# Month=51, Predicted=750.9333, Expected=892.0000
# Month=52, Predicted=905.1045, Expected=903.0000
# Month=53, Predicted=887.4588, Expected=966.0000
# Month=54, Predicted=977.4424, Expected=937.0000
# Month=55, Predicted=904.4384, Expected=896.0000
# Month=56, Predicted=864.5597, Expected=858.0000
# Month=57, Predicted=826.3890, Expected=817.0000
# Month=58, Predicted=785.5597, Expected=827.0000
# Month=59, Predicted=809.6443, Expected=797.0000
# Month=60, Predicted=764.5849, Expected=843.0000
# Run 1 — RMSE: 54.830703, MSE: 3006.405989, NMSE: 0.0101614233, Time: 124.8s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=750.4551, Expected=804.0000
# Month=2, Predicted=804.9414, Expected=756.0000
# Month=3, Predicted=733.3469, Expected=860.0000
# Month=4, Predicted=864.5828, Expected=878.0000
# Month=5, Predicted=874.3836, Expected=942.0000
# Month=6, Predicted=943.9844, Expected=913.0000
# Month=7, Predicted=908.8111, Expected=869.0000
# Month=8, Predicted=858.7310, Expected=834.0000
# Month=9, Predicted=830.1259, Expected=790.0000
# Month=10, Predicted=779.7310, Expected=800.0000
# Month=11, Predicted=795.2972, Expected=763.0000
# Month=12, Predicted=758.9020, Expected=800.0000
# Month=13, Predicted=799.0710, Expected=826.0000
# Month=14, Predicted=823.5480, Expected=799.0000
# Month=15, Predicted=794.6207, Expected=890.0000
# Month=16, Predicted=893.8986, Expected=900.0000
# Month=17, Predicted=895.2972, Expected=961.0000
# Month=18, Predicted=962.7178, Expected=935.0000
# Month=19, Predicted=930.5257, Expected=894.0000
# Month=20, Predicted=887.9404, Expected=855.0000
# Month=21, Predicted=850.2642, Expected=809.0000
# Month=22, Predicted=793.6015, Expected=810.0000
# Month=23, Predicted=804.4219, Expected=766.0000
# Month=24, Predicted=755.7310, Expected=805.0000
# Month=25, Predicted=804.3287, Expected=821.0000
# Month=26, Predicted=817.0983, Expected=773.0000
# Month=27, Predicted=750.3469, Expected=883.0000
# Month=28, Predicted=887.8602, Expected=898.0000
# Month=29, Predicted=893.9581, Expected=957.0000
# Month=30, Predicted=958.5328, Expected=924.0000
# Month=31, Predicted=920.1160, Expected=881.0000
# Month=32, Predicted=872.5230, Expected=837.0000
# Month=33, Predicted=826.7310, Expected=784.0000
# Month=34, Predicted=745.2485, Expected=791.0000
# Month=35, Predicted=785.9487, Expected=760.0000
# Month=36, Predicted=755.9881, Expected=802.0000
# Month=37, Predicted=801.7027, Expected=828.0000
# Month=38, Predicted=825.5480, Expected=778.0000
# Month=39, Predicted=747.4602, Expected=889.0000
# Month=40, Predicted=893.9043, Expected=902.0000
# Month=41, Predicted=897.6845, Expected=969.0000
# Month=42, Predicted=971.2385, Expected=947.0000
# Month=43, Predicted=942.1585, Expected=908.0000
# Month=44, Predicted=903.2642, Expected=867.0000
# Month=45, Predicted=860.9404, Expected=815.0000
# Month=46, Predicted=778.3584, Expected=812.0000
# Month=47, Predicted=806.2375, Expected=773.0000
# Month=48, Predicted=768.2642, Expected=813.0000
# Month=49, Predicted=812.4551, Expected=834.0000
# Month=50, Predicted=830.8192, Expected=782.0000
# Month=51, Predicted=745.3584, Expected=892.0000
# Month=52, Predicted=896.8602, Expected=903.0000
# Month=53, Predicted=898.4226, Expected=966.0000
# Month=54, Predicted=967.8969, Expected=937.0000
# Month=55, Predicted=932.8111, Expected=896.0000
# Month=56, Predicted=889.9404, Expected=858.0000
# Month=57, Predicted=853.6492, Expected=817.0000
# Month=58, Predicted=810.9404, Expected=827.0000
# Month=59, Predicted=822.2972, Expected=797.0000
# Month=60, Predicted=792.9028, Expected=843.0000
# Run 2 — RMSE: 52.755519, MSE: 2783.144768, NMSE: 0.0106374729, Time: 119.1s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=763.0016, Expected=804.0000
# Month=2, Predicted=816.7667, Expected=756.0000
# Month=3, Predicted=718.5758, Expected=860.0000
# Month=4, Predicted=873.1908, Expected=878.0000
# Month=5, Predicted=856.4074, Expected=942.0000
# Month=6, Predicted=954.9615, Expected=913.0000
# Month=7, Predicted=918.5023, Expected=869.0000
# Month=8, Predicted=835.1797, Expected=834.0000
# Month=9, Predicted=823.3893, Expected=790.0000
# Month=10, Predicted=756.1797, Expected=800.0000
# Month=11, Predicted=776.2452, Expected=763.0000
# Month=12, Predicted=744.5173, Expected=800.0000
# Month=13, Predicted=811.4670, Expected=826.0000
# Month=14, Predicted=819.0848, Expected=799.0000
# Month=15, Predicted=806.2845, Expected=890.0000
# Month=16, Predicted=903.1476, Expected=900.0000
# Month=17, Predicted=876.2452, Expected=961.0000
# Month=18, Predicted=973.9218, Expected=935.0000
# Month=19, Predicted=942.8221, Expected=894.0000
# Month=20, Predicted=864.7423, Expected=855.0000
# Month=21, Predicted=830.2513, Expected=809.0000
# Month=22, Predicted=773.1023, Expected=810.0000
# Month=23, Predicted=788.4039, Expected=766.0000
# Month=24, Predicted=732.1797, Expected=805.0000
# Month=25, Predicted=816.8578, Expected=821.0000
# Month=26, Predicted=798.4916, Expected=773.0000
# Month=27, Predicted=735.5758, Expected=883.0000
# Month=28, Predicted=896.2062, Expected=898.0000
# Month=29, Predicted=875.1247, Expected=957.0000
# Month=30, Predicted=969.8909, Expected=924.0000
# Month=31, Predicted=920.9460, Expected=881.0000
# Month=32, Predicted=848.4765, Expected=837.0000
# Month=33, Predicted=803.1797, Expected=784.0000
# Month=34, Predicted=744.3916, Expected=791.0000
# Month=35, Predicted=767.4806, Expected=760.0000
# Month=36, Predicted=762.3033, Expected=802.0000
# Month=37, Predicted=814.2228, Expected=828.0000
# Month=38, Predicted=821.0848, Expected=778.0000
# Month=39, Predicted=739.4719, Expected=889.0000
# Month=40, Predicted=902.2086, Expected=902.0000
# Month=41, Predicted=878.5778, Expected=969.0000
# Month=42, Predicted=981.9949, Expected=947.0000
# Month=43, Predicted=955.3939, Expected=908.0000
# Month=44, Predicted=883.2513, Expected=867.0000
# Month=45, Predicted=837.7423, Expected=815.0000
# Month=46, Predicted=775.6888, Expected=812.0000
# Month=47, Predicted=793.2159, Expected=773.0000
# Month=48, Predicted=748.2513, Expected=813.0000
# Month=49, Predicted=825.0016, Expected=834.0000
# Month=50, Predicted=814.4650, Expected=782.0000
# Month=51, Predicted=742.6888, Expected=892.0000
# Month=52, Predicted=905.2062, Expected=903.0000
# Month=53, Predicted=879.2908, Expected=966.0000
# Month=54, Predicted=978.9490, Expected=937.0000
# Month=55, Predicted=942.5023, Expected=896.0000
# Month=56, Predicted=866.7423, Expected=858.0000
# Month=57, Predicted=836.1411, Expected=817.0000
# Month=58, Predicted=787.7423, Expected=827.0000
# Month=59, Predicted=803.2452, Expected=797.0000
# Month=60, Predicted=801.1254, Expected=843.0000
# Run 3 — RMSE: 56.001320, MSE: 3136.147807, NMSE: 0.0101094172, Time: 112.6s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=759.0773, Expected=804.0000
# Month=2, Predicted=812.4937, Expected=756.0000
# Month=3, Predicted=715.2331, Expected=860.0000
# Month=4, Predicted=869.0220, Expected=878.0000
# Month=5, Predicted=882.5213, Expected=942.0000
# Month=6, Predicted=950.6898, Expected=913.0000
# Month=7, Predicted=912.1809, Expected=869.0000
# Month=8, Predicted=831.6119, Expected=834.0000
# Month=9, Predicted=829.2017, Expected=790.0000
# Month=10, Predicted=752.6119, Expected=800.0000
# Month=11, Predicted=791.4877, Expected=763.0000
# Month=12, Predicted=754.2752, Expected=800.0000
# Month=13, Predicted=807.9236, Expected=826.0000
# Month=14, Predicted=832.8682, Expected=799.0000
# Month=15, Predicted=798.4415, Expected=890.0000
# Month=16, Predicted=898.9490, Expected=900.0000
# Month=17, Predicted=891.4877, Expected=961.0000
# Month=18, Predicted=969.6446, Expected=935.0000
# Month=19, Predicted=934.4727, Expected=894.0000
# Month=20, Predicted=867.3772, Expected=855.0000
# Month=21, Predicted=839.0442, Expected=809.0000
# Month=22, Predicted=769.0905, Expected=810.0000
# Month=23, Predicted=786.2683, Expected=766.0000
# Month=24, Predicted=728.6119, Expected=805.0000
# Month=25, Predicted=813.0296, Expected=821.0000
# Month=26, Predicted=824.2129, Expected=773.0000
# Month=27, Predicted=732.2331, Expected=883.0000
# Month=28, Predicted=892.0495, Expected=898.0000
# Month=29, Predicted=900.3002, Expected=957.0000
# Month=30, Predicted=965.6114, Expected=924.0000
# Month=31, Predicted=921.3563, Expected=881.0000
# Month=32, Predicted=846.0038, Expected=837.0000
# Month=33, Predicted=799.6119, Expected=784.0000
# Month=34, Predicted=743.6885, Expected=791.0000
# Month=35, Predicted=771.9871, Expected=760.0000
# Month=36, Predicted=758.5532, Expected=802.0000
# Month=37, Predicted=810.1635, Expected=828.0000
# Month=38, Predicted=834.8682, Expected=778.0000
# Month=39, Predicted=737.1716, Expected=889.0000
# Month=40, Predicted=898.0537, Expected=902.0000
# Month=41, Predicted=901.5871, Expected=969.0000
# Month=42, Predicted=977.7304, Expected=947.0000
# Month=43, Predicted=946.1515, Expected=908.0000
# Month=44, Predicted=892.0442, Expected=867.0000
# Month=45, Predicted=840.3772, Expected=815.0000
# Month=46, Predicted=774.4732, Expected=812.0000
# Month=47, Predicted=794.2218, Expected=773.0000
# Month=48, Predicted=757.0442, Expected=813.0000
# Month=49, Predicted=821.0773, Expected=834.0000
# Month=50, Predicted=839.7445, Expected=782.0000
# Month=51, Predicted=741.4732, Expected=892.0000
# Month=52, Predicted=901.0495, Expected=903.0000
# Month=53, Predicted=897.8677, Expected=966.0000
# Month=54, Predicted=974.6753, Expected=937.0000
# Month=55, Predicted=936.1809, Expected=896.0000
# Month=56, Predicted=869.3772, Expected=858.0000
# Month=57, Predicted=846.1848, Expected=817.0000
# Month=58, Predicted=790.3772, Expected=827.0000
# Month=59, Predicted=818.4877, Expected=797.0000
# Month=60, Predicted=795.9228, Expected=843.0000
# Run 4 — RMSE: 55.007729, MSE: 3025.850269, NMSE: 0.0100037701, Time: 113.1s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=760.2817, Expected=804.0000
# Month=2, Predicted=813.0008, Expected=756.0000
# Month=3, Predicted=727.6064, Expected=860.0000
# Month=4, Predicted=868.7337, Expected=878.0000
# Month=5, Predicted=870.8164, Expected=942.0000
# Month=6, Predicted=950.8893, Expected=913.0000
# Month=7, Predicted=919.7827, Expected=869.0000
# Month=8, Predicted=845.8138, Expected=834.0000
# Month=9, Predicted=839.9505, Expected=790.0000
# Month=10, Predicted=766.8138, Expected=800.0000
# Month=11, Predicted=784.1466, Expected=763.0000
# Month=12, Predicted=767.8224, Expected=800.0000
# Month=13, Predicted=809.3963, Expected=826.0000
# Month=14, Predicted=834.6343, Expected=799.0000
# Month=15, Predicted=805.7925, Expected=890.0000
# Month=16, Predicted=898.7643, Expected=900.0000
# Month=17, Predicted=884.1466, Expected=961.0000
# Month=18, Predicted=969.9137, Expected=935.0000
# Month=19, Predicted=941.7535, Expected=894.0000
# Month=20, Predicted=882.8294, Expected=855.0000
# Month=21, Predicted=855.9250, Expected=809.0000
# Month=22, Predicted=782.5752, Expected=810.0000
# Month=23, Predicted=792.8615, Expected=766.0000
# Month=24, Predicted=742.8138, Expected=805.0000
# Month=25, Predicted=814.3169, Expected=821.0000
# Month=26, Predicted=810.4248, Expected=773.0000
# Month=27, Predicted=744.6064, Expected=883.0000
# Month=28, Predicted=891.7227, Expected=898.0000
# Month=29, Predicted=886.1220, Expected=957.0000
# Month=30, Predicted=965.9322, Expected=924.0000
# Month=31, Predicted=930.4366, Expected=881.0000
# Month=32, Predicted=860.3369, Expected=837.0000
# Month=33, Predicted=813.8138, Expected=784.0000
# Month=34, Predicted=753.1290, Expected=791.0000
# Month=35, Predicted=774.0507, Expected=760.0000
# Month=36, Predicted=766.6753, Expected=802.0000
# Month=37, Predicted=811.2192, Expected=828.0000
# Month=38, Predicted=836.6343, Expected=778.0000
# Month=39, Predicted=748.3282, Expected=889.0000
# Month=40, Predicted=897.7210, Expected=902.0000
# Month=41, Predicted=888.1129, Expected=969.0000
# Month=42, Predicted=977.8681, Expected=947.0000
# Month=43, Predicted=952.9387, Expected=908.0000
# Month=44, Predicted=908.9250, Expected=867.0000
# Month=45, Predicted=855.8294, Expected=815.0000
# Month=46, Predicted=784.4601, Expected=812.0000
# Month=47, Predicted=796.1455, Expected=773.0000
# Month=48, Predicted=773.9250, Expected=813.0000
# Month=49, Predicted=822.2817, Expected=834.0000
# Month=50, Predicted=833.7991, Expected=782.0000
# Month=51, Predicted=751.4601, Expected=892.0000
# Month=52, Predicted=900.7227, Expected=903.0000
# Month=53, Predicted=887.6904, Expected=966.0000
# Month=54, Predicted=974.8971, Expected=937.0000
# Month=55, Predicted=943.7827, Expected=896.0000
# Month=56, Predicted=884.8294, Expected=858.0000
# Month=57, Predicted=861.5458, Expected=817.0000
# Month=58, Predicted=805.8294, Expected=827.0000
# Month=59, Predicted=811.1466, Expected=797.0000
# Month=60, Predicted=803.7419, Expected=843.0000
# Run 5 — RMSE: 53.885922, MSE: 2903.692561, NMSE: 0.0105622681, Time: 127.6s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=762.4100, Expected=804.0000
# Month=2, Predicted=815.3142, Expected=756.0000
# Month=3, Predicted=723.1662, Expected=860.0000
# Month=4, Predicted=871.2292, Expected=878.0000
# Month=5, Predicted=879.5741, Expected=942.0000
# Month=6, Predicted=953.2783, Expected=913.0000
# Month=7, Predicted=913.7042, Expected=869.0000
# Month=8, Predicted=834.8421, Expected=834.0000
# Month=9, Predicted=800.4636, Expected=790.0000
# Month=10, Predicted=755.8421, Expected=800.0000
# Month=11, Predicted=776.4032, Expected=763.0000
# Month=12, Predicted=727.1787, Expected=800.0000
# Month=13, Predicted=811.4526, Expected=826.0000
# Month=14, Predicted=837.8082, Expected=799.0000
# Month=15, Predicted=802.8562, Expected=890.0000
# Month=16, Predicted=901.2389, Expected=900.0000
# Month=17, Predicted=876.4032, Expected=961.0000
# Month=18, Predicted=972.2861, Expected=935.0000
# Month=19, Predicted=939.6770, Expected=894.0000
# Month=20, Predicted=858.7208, Expected=855.0000
# Month=21, Predicted=819.1195, Expected=809.0000
# Month=22, Predicted=775.5416, Expected=810.0000
# Month=23, Predicted=783.4368, Expected=766.0000
# Month=24, Predicted=731.8421, Expected=805.0000
# Month=25, Predicted=816.4228, Expected=821.0000
# Month=26, Predicted=810.4232, Expected=773.0000
# Month=27, Predicted=740.1662, Expected=883.0000
# Month=28, Predicted=894.2257, Expected=898.0000
# Month=29, Predicted=883.3254, Expected=957.0000
# Month=30, Predicted=968.2920, Expected=924.0000
# Month=31, Predicted=900.5487, Expected=881.0000
# Month=32, Predicted=846.4699, Expected=837.0000
# Month=33, Predicted=802.8421, Expected=784.0000
# Month=34, Predicted=752.4146, Expected=791.0000
# Month=35, Predicted=765.6938, Expected=760.0000
# Month=36, Predicted=752.6912, Expected=802.0000
# Month=37, Predicted=813.3879, Expected=828.0000
# Month=38, Predicted=839.8082, Expected=778.0000
# Month=39, Predicted=745.7155, Expected=889.0000
# Month=40, Predicted=900.2252, Expected=902.0000
# Month=41, Predicted=882.2363, Expected=969.0000
# Month=42, Predicted=980.2716, Expected=947.0000
# Month=43, Predicted=952.9493, Expected=908.0000
# Month=44, Predicted=872.1195, Expected=867.0000
# Month=45, Predicted=831.7208, Expected=815.0000
# Month=46, Predicted=783.1967, Expected=812.0000
# Month=47, Predicted=785.5568, Expected=773.0000
# Month=48, Predicted=737.1195, Expected=813.0000
# Month=49, Predicted=824.4100, Expected=834.0000
# Month=50, Predicted=844.8563, Expected=782.0000
# Month=51, Predicted=750.1967, Expected=892.0000
# Month=52, Predicted=903.2257, Expected=903.0000
# Month=53, Predicted=880.3455, Expected=966.0000
# Month=54, Predicted=977.2808, Expected=937.0000
# Month=55, Predicted=937.7042, Expected=896.0000
# Month=56, Predicted=860.7208, Expected=858.0000
# Month=57, Predicted=822.0080, Expected=817.0000
# Month=58, Predicted=781.7208, Expected=827.0000
# Month=59, Predicted=803.4032, Expected=797.0000
# Month=60, Predicted=794.6434, Expected=843.0000
# Run 6 — RMSE: 55.011476, MSE: 3026.262490, NMSE: 0.0098807454, Time: 66.6s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=744.2627, Expected=804.0000
# Month=2, Predicted=798.5876, Expected=756.0000
# Month=3, Predicted=727.2183, Expected=860.0000
# Month=4, Predicted=873.8104, Expected=878.0000
# Month=5, Predicted=867.0445, Expected=942.0000
# Month=6, Predicted=937.8399, Expected=913.0000
# Month=7, Predicted=892.5858, Expected=869.0000
# Month=8, Predicted=842.4932, Expected=834.0000
# Month=9, Predicted=811.5927, Expected=790.0000
# Month=10, Predicted=763.4932, Expected=800.0000
# Month=11, Predicted=787.3406, Expected=763.0000
# Month=12, Predicted=739.8029, Expected=800.0000
# Month=13, Predicted=792.7997, Expected=826.0000
# Month=14, Predicted=816.7291, Expected=799.0000
# Month=15, Predicted=779.1387, Expected=890.0000
# Month=16, Predicted=897.8028, Expected=900.0000
# Month=17, Predicted=887.3406, Expected=961.0000
# Month=18, Predicted=956.3554, Expected=935.0000
# Month=19, Predicted=915.3970, Expected=894.0000
# Month=20, Predicted=869.0175, Expected=855.0000
# Month=21, Predicted=830.9452, Expected=809.0000
# Month=22, Predicted=781.3893, Expected=810.0000
# Month=23, Predicted=795.5153, Expected=766.0000
# Month=24, Predicted=739.4932, Expected=805.0000
# Month=25, Predicted=798.1149, Expected=821.0000
# Month=26, Predicted=809.6167, Expected=773.0000
# Month=27, Predicted=744.2183, Expected=883.0000
# Month=28, Predicted=898.8363, Expected=898.0000
# Month=29, Predicted=886.4028, Expected=957.0000
# Month=30, Predicted=952.1102, Expected=924.0000
# Month=31, Predicted=902.3173, Expected=881.0000
# Month=32, Predicted=855.0190, Expected=837.0000
# Month=33, Predicted=810.4932, Expected=784.0000
# Month=34, Predicted=752.0378, Expected=791.0000
# Month=35, Predicted=777.7156, Expected=760.0000
# Month=36, Predicted=738.9803, Expected=802.0000
# Month=37, Predicted=795.5372, Expected=828.0000
# Month=38, Predicted=818.7291, Expected=778.0000
# Month=39, Predicted=747.9852, Expected=889.0000
# Month=40, Predicted=905.1336, Expected=902.0000
# Month=41, Predicted=889.9759, Expected=969.0000
# Month=42, Predicted=965.5010, Expected=947.0000
# Month=43, Predicted=928.3260, Expected=908.0000
# Month=44, Predicted=883.9452, Expected=867.0000
# Month=45, Predicted=842.0175, Expected=815.0000
# Month=46, Predicted=783.6982, Expected=812.0000
# Month=47, Predicted=796.7630, Expected=773.0000
# Month=48, Predicted=748.9452, Expected=813.0000
# Month=49, Predicted=806.2627, Expected=834.0000
# Month=50, Predicted=823.6835, Expected=782.0000
# Month=51, Predicted=750.6982, Expected=892.0000
# Month=52, Predicted=907.8363, Expected=903.0000
# Month=53, Predicted=890.5515, Expected=966.0000
# Month=54, Predicted=961.6606, Expected=937.0000
# Month=55, Predicted=916.5858, Expected=896.0000
# Month=56, Predicted=871.0175, Expected=858.0000
# Month=57, Predicted=834.3827, Expected=817.0000
# Month=58, Predicted=792.0175, Expected=827.0000
# Month=59, Predicted=814.3406, Expected=797.0000
# Month=60, Predicted=776.2900, Expected=843.0000
# Run 7 — RMSE: 53.003912, MSE: 2809.414655, NMSE: 0.0101146040, Time: 57.4s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=768.3342, Expected=804.0000
# Month=2, Predicted=783.8918, Expected=756.0000
# Month=3, Predicted=730.2934, Expected=860.0000
# Month=4, Predicted=878.5088, Expected=878.0000
# Month=5, Predicted=910.1080, Expected=942.0000
# Month=6, Predicted=913.3371, Expected=913.0000
# Month=7, Predicted=887.4701, Expected=869.0000
# Month=8, Predicted=843.3229, Expected=834.0000
# Month=9, Predicted=808.4027, Expected=790.0000
# Month=10, Predicted=764.3229, Expected=800.0000
# Month=11, Predicted=778.4808, Expected=763.0000
# Month=12, Predicted=737.3830, Expected=800.0000
# Month=13, Predicted=818.8820, Expected=826.0000
# Month=14, Predicted=848.4967, Expected=799.0000
# Month=15, Predicted=773.4960, Expected=890.0000
# Month=16, Predicted=907.2520, Expected=900.0000
# Month=17, Predicted=878.4808, Expected=961.0000
# Month=18, Predicted=932.1535, Expected=935.0000
# Month=19, Predicted=909.5098, Expected=894.0000
# Month=20, Predicted=868.3472, Expected=855.0000
# Month=21, Predicted=829.3646, Expected=809.0000
# Month=22, Predicted=783.3078, Expected=810.0000
# Month=23, Predicted=785.5316, Expected=766.0000
# Month=24, Predicted=740.3229, Expected=805.0000
# Month=25, Predicted=822.8921, Expected=821.0000
# Month=26, Predicted=866.1911, Expected=773.0000
# Month=27, Predicted=747.2934, Expected=883.0000
# Month=28, Predicted=901.8069, Expected=898.0000
# Month=29, Predicted=935.9674, Expected=957.0000
# Month=30, Predicted=928.3833, Expected=924.0000
# Month=31, Predicted=898.4236, Expected=881.0000
# Month=32, Predicted=855.3307, Expected=837.0000
# Month=33, Predicted=811.3229, Expected=784.0000
# Month=34, Predicted=758.2606, Expected=791.0000
# Month=35, Predicted=767.7199, Expected=760.0000
# Month=36, Predicted=734.4461, Expected=802.0000
# Month=37, Predicted=818.0442, Expected=828.0000
# Month=38, Predicted=850.4967, Expected=778.0000
# Month=39, Predicted=752.2798, Expected=889.0000
# Month=40, Predicted=907.8477, Expected=902.0000
# Month=41, Predicted=888.5972, Expected=969.0000
# Month=42, Predicted=942.1614, Expected=947.0000
# Month=43, Predicted=921.5710, Expected=908.0000
# Month=44, Predicted=882.3646, Expected=867.0000
# Month=45, Predicted=841.3472, Expected=815.0000
# Month=46, Predicted=789.2669, Expected=812.0000
# Month=47, Predicted=787.1895, Expected=773.0000
# Month=48, Predicted=747.3646, Expected=813.0000
# Month=49, Predicted=830.3342, Expected=834.0000
# Month=50, Predicted=859.4206, Expected=782.0000
# Month=51, Predicted=756.2669, Expected=892.0000
# Month=52, Predicted=910.8069, Expected=903.0000
# Month=53, Predicted=882.7188, Expected=966.0000
# Month=54, Predicted=937.1930, Expected=937.0000
# Month=55, Predicted=911.4701, Expected=896.0000
# Month=56, Predicted=870.3472, Expected=858.0000
# Month=57, Predicted=832.3737, Expected=817.0000
# Month=58, Predicted=791.3472, Expected=827.0000
# Month=59, Predicted=805.4808, Expected=797.0000
# Month=60, Predicted=771.4579, Expected=843.0000
# Run 8 — RMSE: 52.445935, MSE: 2750.576116, NMSE: 0.0109340990, Time: 57.8s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=754.0560, Expected=804.0000
# Month=2, Predicted=789.8356, Expected=756.0000
# Month=3, Predicted=728.6059, Expected=860.0000
# Month=4, Predicted=879.0527, Expected=878.0000
# Month=5, Predicted=880.8951, Expected=942.0000
# Month=6, Predicted=911.2315, Expected=913.0000
# Month=7, Predicted=914.9391, Expected=869.0000
# Month=8, Predicted=852.6204, Expected=834.0000
# Month=9, Predicted=832.3574, Expected=790.0000
# Month=10, Predicted=773.6204, Expected=800.0000
# Month=11, Predicted=802.1777, Expected=763.0000
# Month=12, Predicted=759.3514, Expected=800.0000
# Month=13, Predicted=803.7130, Expected=826.0000
# Month=14, Predicted=829.7339, Expected=799.0000
# Month=15, Predicted=801.5705, Expected=890.0000
# Month=16, Predicted=909.1371, Expected=900.0000
# Month=17, Predicted=902.1777, Expected=961.0000
# Month=18, Predicted=930.5184, Expected=935.0000
# Month=19, Predicted=937.8089, Expected=894.0000
# Month=20, Predicted=884.3837, Expected=855.0000
# Month=21, Predicted=848.7471, Expected=809.0000
# Month=22, Predicted=787.1218, Expected=810.0000
# Month=23, Predicted=811.9048, Expected=766.0000
# Month=24, Predicted=749.6204, Expected=805.0000
# Month=25, Predicted=808.3271, Expected=821.0000
# Month=26, Predicted=823.6877, Expected=773.0000
# Month=27, Predicted=745.6059, Expected=883.0000
# Month=28, Predicted=902.0083, Expected=898.0000
# Month=29, Predicted=900.5896, Expected=957.0000
# Month=30, Predicted=928.0122, Expected=924.0000
# Month=31, Predicted=923.8960, Expected=881.0000
# Month=32, Predicted=867.1103, Expected=837.0000
# Month=33, Predicted=820.6204, Expected=784.0000
# Month=34, Predicted=747.5977, Expected=791.0000
# Month=35, Predicted=793.0093, Expected=760.0000
# Month=36, Predicted=761.0657, Expected=802.0000
# Month=37, Predicted=804.3095, Expected=828.0000
# Month=38, Predicted=831.7339, Expected=778.0000
# Month=39, Predicted=746.0185, Expected=889.0000
# Month=40, Predicted=908.0020, Expected=902.0000
# Month=41, Predicted=904.4076, Expected=969.0000
# Month=42, Predicted=939.5461, Expected=947.0000
# Month=43, Predicted=950.3443, Expected=908.0000
# Month=44, Predicted=901.7471, Expected=867.0000
# Month=45, Predicted=857.3837, Expected=815.0000
# Month=46, Predicted=779.7633, Expected=812.0000
# Month=47, Predicted=814.0437, Expected=773.0000
# Month=48, Predicted=766.7471, Expected=813.0000
# Month=49, Predicted=816.0560, Expected=834.0000
# Month=50, Predicted=837.2224, Expected=782.0000
# Month=51, Predicted=746.7633, Expected=892.0000
# Month=52, Predicted=911.0083, Expected=903.0000
# Month=53, Predicted=905.2480, Expected=966.0000
# Month=54, Predicted=935.1233, Expected=937.0000
# Month=55, Predicted=938.9391, Expected=896.0000
# Month=56, Predicted=886.3837, Expected=858.0000
# Month=57, Predicted=853.1336, Expected=817.0000
# Month=58, Predicted=807.3837, Expected=827.0000
# Month=59, Predicted=829.1777, Expected=797.0000
# Month=60, Predicted=798.5357, Expected=843.0000
# Run 9 — RMSE: 52.059370, MSE: 2710.178006, NMSE: 0.0111571931, Time: 56.4s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=757.7400, Expected=804.0000
# Month=2, Predicted=812.6431, Expected=756.0000
# Month=3, Predicted=725.0761, Expected=860.0000
# Month=4, Predicted=873.2326, Expected=878.0000
# Month=5, Predicted=880.7868, Expected=942.0000
# Month=6, Predicted=951.9576, Expected=913.0000
# Month=7, Predicted=912.1520, Expected=869.0000
# Month=8, Predicted=838.9350, Expected=834.0000
# Month=9, Predicted=828.2292, Expected=790.0000
# Month=10, Predicted=759.9350, Expected=800.0000
# Month=11, Predicted=801.4782, Expected=763.0000
# Month=12, Predicted=752.7584, Expected=800.0000
# Month=13, Predicted=806.2425, Expected=826.0000
# Month=14, Predicted=830.2663, Expected=799.0000
# Month=15, Predicted=798.6778, Expected=890.0000
# Month=16, Predicted=902.3619, Expected=900.0000
# Month=17, Predicted=901.4782, Expected=961.0000
# Month=18, Predicted=970.6228, Expected=935.0000
# Month=19, Predicted=934.8494, Expected=894.0000
# Month=20, Predicted=868.4566, Expected=855.0000
# Month=21, Predicted=837.2235, Expected=809.0000
# Month=22, Predicted=778.3132, Expected=810.0000
# Month=23, Predicted=810.5010, Expected=766.0000
# Month=24, Predicted=735.9350, Expected=805.0000
# Month=25, Predicted=811.5766, Expected=821.0000
# Month=26, Predicted=823.4343, Expected=773.0000
# Month=27, Predicted=742.0761, Expected=883.0000
# Month=28, Predicted=896.5890, Expected=898.0000
# Month=29, Predicted=900.2632, Expected=957.0000
# Month=30, Predicted=966.3902, Expected=924.0000
# Month=31, Predicted=920.7601, Expected=881.0000
# Month=32, Predicted=851.6722, Expected=837.0000
# Month=33, Predicted=806.9350, Expected=784.0000
# Month=34, Predicted=752.8415, Expected=791.0000
# Month=35, Predicted=792.0811, Expected=760.0000
# Month=36, Predicted=758.2585, Expected=802.0000
# Month=37, Predicted=809.0596, Expected=828.0000
# Month=38, Predicted=832.2663, Expected=778.0000
# Month=39, Predicted=746.9509, Expected=889.0000
# Month=40, Predicted=902.6459, Expected=902.0000
# Month=41, Predicted=903.9336, Expected=969.0000
# Month=42, Predicted=979.2763, Expected=947.0000
# Month=43, Predicted=947.1829, Expected=908.0000
# Month=44, Predicted=890.2235, Expected=867.0000
# Month=45, Predicted=841.4566, Expected=815.0000
# Month=46, Predicted=783.8712, Expected=812.0000
# Month=47, Predicted=812.2850, Expected=773.0000
# Month=48, Predicted=755.2235, Expected=813.0000
# Month=49, Predicted=819.7400, Expected=834.0000
# Month=50, Predicted=837.3338, Expected=782.0000
# Month=51, Predicted=750.8712, Expected=892.0000
# Month=52, Predicted=905.5890, Expected=903.0000
# Month=53, Predicted=904.6242, Expected=966.0000
# Month=54, Predicted=975.8479, Expected=937.0000
# Month=55, Predicted=936.1520, Expected=896.0000
# Month=56, Predicted=870.4566, Expected=858.0000
# Month=57, Predicted=844.3465, Expected=817.0000
# Month=58, Predicted=791.4566, Expected=827.0000
# Month=59, Predicted=828.4782, Expected=797.0000
# Month=60, Predicted=795.7631, Expected=843.0000
# Run 10 — RMSE: 53.124535, MSE: 2822.216205, NMSE: 0.0099724239, Time: 65.0s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=747.3197, Expected=804.0000
# Month=2, Predicted=786.8680, Expected=756.0000
# Month=3, Predicted=720.7515, Expected=860.0000
# Month=4, Predicted=877.1263, Expected=878.0000
# Month=5, Predicted=863.9145, Expected=942.0000
# Month=6, Predicted=914.2244, Expected=913.0000
# Month=7, Predicted=883.5735, Expected=869.0000
# Month=8, Predicted=834.9851, Expected=834.0000
# Month=9, Predicted=802.7481, Expected=790.0000
# Month=10, Predicted=755.9851, Expected=800.0000
# Month=11, Predicted=782.1342, Expected=763.0000
# Month=12, Predicted=731.1356, Expected=800.0000
# Month=13, Predicted=796.5043, Expected=826.0000
# Month=14, Predicted=816.9720, Expected=799.0000
# Month=15, Predicted=770.1753, Expected=890.0000
# Month=16, Predicted=907.5550, Expected=900.0000
# Month=17, Predicted=882.1342, Expected=961.0000
# Month=18, Predicted=934.9782, Expected=935.0000
# Month=19, Predicted=906.4743, Expected=894.0000
# Month=20, Predicted=860.9079, Expected=855.0000
# Month=21, Predicted=822.5222, Expected=809.0000
# Month=22, Predicted=774.3688, Expected=810.0000
# Month=23, Predicted=789.0880, Expected=766.0000
# Month=24, Predicted=731.9851, Expected=805.0000
# Month=25, Predicted=801.5065, Expected=821.0000
# Month=26, Predicted=805.8440, Expected=773.0000
# Month=27, Predicted=737.7515, Expected=883.0000
# Month=28, Predicted=900.0388, Expected=898.0000
# Month=29, Predicted=882.3418, Expected=957.0000
# Month=30, Predicted=932.6227, Expected=924.0000
# Month=31, Predicted=893.3590, Expected=881.0000
# Month=32, Predicted=847.2929, Expected=837.0000
# Month=33, Predicted=802.9851, Expected=784.0000
# Month=34, Predicted=747.2035, Expected=791.0000
# Month=35, Predicted=772.0147, Expected=760.0000
# Month=36, Predicted=729.9677, Expected=802.0000
# Month=37, Predicted=797.5355, Expected=828.0000
# Month=38, Predicted=818.9720, Expected=778.0000
# Month=39, Predicted=742.1331, Expected=889.0000
# Month=40, Predicted=906.0285, Expected=902.0000
# Month=41, Predicted=885.4008, Expected=969.0000
# Month=42, Predicted=940.1631, Expected=947.0000
# Month=43, Predicted=919.6555, Expected=908.0000
# Month=44, Predicted=875.5222, Expected=867.0000
# Month=45, Predicted=833.9079, Expected=815.0000
# Month=46, Predicted=778.5136, Expected=812.0000
# Month=47, Predicted=789.9420, Expected=773.0000
# Month=48, Predicted=740.5222, Expected=813.0000
# Month=49, Predicted=809.3197, Expected=834.0000
# Month=50, Predicted=821.6840, Expected=782.0000
# Month=51, Predicted=745.5136, Expected=892.0000
# Month=52, Predicted=909.0388, Expected=903.0000
# Month=53, Predicted=885.5385, Expected=966.0000
# Month=54, Predicted=938.7230, Expected=937.0000
# Month=55, Predicted=907.5735, Expected=896.0000
# Month=56, Predicted=862.9079, Expected=858.0000
# Month=57, Predicted=825.8290, Expected=817.0000
# Month=58, Predicted=783.9079, Expected=827.0000
# Month=59, Predicted=809.1342, Expected=797.0000
# Month=60, Predicted=767.2710, Expected=843.0000
# Run 11 — RMSE: 54.631631, MSE: 2984.615152, NMSE: 0.0107545793, Time: 80.8s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=752.2920, Expected=804.0000
# Month=2, Predicted=807.3006, Expected=756.0000
# Month=3, Predicted=724.6794, Expected=860.0000
# Month=4, Predicted=868.1627, Expected=878.0000
# Month=5, Predicted=875.1430, Expected=942.0000
# Month=6, Predicted=946.7008, Expected=913.0000
# Month=7, Predicted=908.9898, Expected=869.0000
# Month=8, Predicted=851.4853, Expected=834.0000
# Month=9, Predicted=829.0972, Expected=790.0000
# Month=10, Predicted=772.4853, Expected=800.0000
# Month=11, Predicted=795.7271, Expected=763.0000
# Month=12, Predicted=756.9841, Expected=800.0000
# Month=13, Predicted=800.7709, Expected=826.0000
# Month=14, Predicted=824.7054, Expected=799.0000
# Month=15, Predicted=794.8653, Expected=890.0000
# Month=16, Predicted=897.2532, Expected=900.0000
# Month=17, Predicted=895.7271, Expected=961.0000
# Month=18, Predicted=965.3437, Expected=935.0000
# Month=19, Predicted=930.7711, Expected=894.0000
# Month=20, Predicted=883.3558, Expected=855.0000
# Month=21, Predicted=847.1656, Expected=809.0000
# Month=22, Predicted=784.8975, Expected=810.0000
# Month=23, Predicted=804.6535, Expected=766.0000
# Month=24, Predicted=748.4853, Expected=805.0000
# Month=25, Predicted=806.1206, Expected=821.0000
# Month=26, Predicted=817.7656, Expected=773.0000
# Month=27, Predicted=741.6794, Expected=883.0000
# Month=28, Predicted=891.5315, Expected=898.0000
# Month=29, Predicted=894.5814, Expected=957.0000
# Month=30, Predicted=961.0956, Expected=924.0000
# Month=31, Predicted=919.7090, Expected=881.0000
# Month=32, Predicted=866.1864, Expected=837.0000
# Month=33, Predicted=819.4853, Expected=784.0000
# Month=34, Predicted=741.7441, Expected=791.0000
# Month=35, Predicted=786.2893, Expected=760.0000
# Month=36, Predicted=755.9682, Expected=802.0000
# Month=37, Predicted=803.6275, Expected=828.0000
# Month=38, Predicted=826.7054, Expected=778.0000
# Month=39, Predicted=740.7255, Expected=889.0000
# Month=40, Predicted=897.5902, Expected=902.0000
# Month=41, Predicted=898.2246, Expected=969.0000
# Month=42, Predicted=974.0408, Expected=947.0000
# Month=43, Predicted=942.3288, Expected=908.0000
# Month=44, Predicted=900.1656, Expected=867.0000
# Month=45, Predicted=856.3558, Expected=815.0000
# Month=46, Predicted=773.9450, Expected=812.0000
# Month=47, Predicted=806.4390, Expected=773.0000
# Month=48, Predicted=765.1656, Expected=813.0000
# Month=49, Predicted=814.2920, Expected=834.0000
# Month=50, Predicted=831.7241, Expected=782.0000
# Month=51, Predicted=740.9450, Expected=892.0000
# Month=52, Predicted=900.5315, Expected=903.0000
# Month=53, Predicted=898.8871, Expected=966.0000
# Month=54, Predicted=970.5837, Expected=937.0000
# Month=55, Predicted=932.9898, Expected=896.0000
# Month=56, Predicted=885.3558, Expected=858.0000
# Month=57, Predicted=851.1787, Expected=817.0000
# Month=58, Predicted=806.3558, Expected=827.0000
# Month=59, Predicted=822.7271, Expected=797.0000
# Month=60, Predicted=793.0025, Expected=843.0000
# Run 12 — RMSE: 54.006088, MSE: 2916.657535, NMSE: 0.0105562408, Time: 87.3s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=757.5845, Expected=804.0000
# Month=2, Predicted=812.2426, Expected=756.0000
# Month=3, Predicted=737.1423, Expected=860.0000
# Month=4, Predicted=871.8963, Expected=878.0000
# Month=5, Predicted=880.4652, Expected=942.0000
# Month=6, Predicted=951.3345, Expected=913.0000
# Month=7, Predicted=909.4233, Expected=869.0000
# Month=8, Predicted=861.2865, Expected=834.0000
# Month=9, Predicted=830.5484, Expected=790.0000
# Month=10, Predicted=782.2865, Expected=800.0000
# Month=11, Predicted=800.5309, Expected=763.0000
# Month=12, Predicted=759.4074, Expected=800.0000
# Month=13, Predicted=806.1303, Expected=826.0000
# Month=14, Predicted=830.1836, Expected=799.0000
# Month=15, Predicted=795.3250, Expected=890.0000
# Month=16, Predicted=901.2377, Expected=900.0000
# Month=17, Predicted=900.5309, Expected=961.0000
# Month=18, Predicted=970.0599, Expected=935.0000
# Month=19, Predicted=931.2741, Expected=894.0000
# Month=20, Predicted=889.1882, Expected=855.0000
# Month=21, Predicted=851.0207, Expected=809.0000
# Month=22, Predicted=797.2083, Expected=810.0000
# Month=23, Predicted=808.3326, Expected=766.0000
# Month=24, Predicted=758.2865, Expected=805.0000
# Month=25, Predicted=811.4364, Expected=821.0000
# Month=26, Predicted=822.9978, Expected=773.0000
# Month=27, Predicted=754.1423, Expected=883.0000
# Month=28, Predicted=895.1612, Expected=898.0000
# Month=29, Predicted=899.7593, Expected=957.0000
# Month=30, Predicted=965.8677, Expected=924.0000
# Month=31, Predicted=920.5603, Expected=881.0000
# Month=32, Predicted=874.5671, Expected=837.0000
# Month=33, Predicted=829.2865, Expected=784.0000
# Month=34, Predicted=747.6220, Expected=791.0000
# Month=35, Predicted=790.7811, Expected=760.0000
# Month=36, Predicted=756.5075, Expected=802.0000
# Month=37, Predicted=808.8709, Expected=828.0000
# Month=38, Predicted=832.1836, Expected=778.0000
# Month=39, Predicted=749.8877, Expected=889.0000
# Month=40, Predicted=901.2033, Expected=902.0000
# Month=41, Predicted=903.2740, Expected=969.0000
# Month=42, Predicted=978.5938, Expected=947.0000
# Month=43, Predicted=943.0885, Expected=908.0000
# Month=44, Predicted=904.0207, Expected=867.0000
# Month=45, Predicted=862.1882, Expected=815.0000
# Month=46, Predicted=780.3464, Expected=812.0000
# Month=47, Predicted=809.4779, Expected=773.0000
# Month=48, Predicted=769.0207, Expected=813.0000
# Month=49, Predicted=819.5845, Expected=834.0000
# Month=50, Predicted=837.1393, Expected=782.0000
# Month=51, Predicted=747.3464, Expected=892.0000
# Month=52, Predicted=904.1612, Expected=903.0000
# Month=53, Predicted=903.7801, Expected=966.0000
# Month=54, Predicted=975.2447, Expected=937.0000
# Month=55, Predicted=933.4233, Expected=896.0000
# Month=56, Predicted=891.1882, Expected=858.0000
# Month=57, Predicted=854.2548, Expected=817.0000
# Month=58, Predicted=812.1882, Expected=827.0000
# Month=59, Predicted=827.5309, Expected=797.0000
# Month=60, Predicted=793.4680, Expected=843.0000
# Run 13 — RMSE: 52.441590, MSE: 2750.120375, NMSE: 0.0104315863, Time: 88.9s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=764.3820, Expected=804.0000
# Month=2, Predicted=817.2507, Expected=756.0000
# Month=3, Predicted=721.1779, Expected=860.0000
# Month=4, Predicted=873.1018, Expected=878.0000
# Month=5, Predicted=893.1597, Expected=942.0000
# Month=6, Predicted=955.1927, Expected=913.0000
# Month=7, Predicted=878.8612, Expected=869.0000
# Month=8, Predicted=834.2084, Expected=834.0000
# Month=9, Predicted=799.3731, Expected=790.0000
# Month=10, Predicted=755.2084, Expected=800.0000
# Month=11, Predicted=772.4424, Expected=763.0000
# Month=12, Predicted=728.3140, Expected=800.0000
# Month=13, Predicted=813.4331, Expected=826.0000
# Month=14, Predicted=839.8353, Expected=799.0000
# Month=15, Predicted=765.3843, Expected=890.0000
# Month=16, Predicted=903.1209, Expected=900.0000
# Month=17, Predicted=872.4424, Expected=961.0000
# Month=18, Predicted=974.2059, Expected=935.0000
# Month=19, Predicted=902.0038, Expected=894.0000
# Month=20, Predicted=859.2418, Expected=855.0000
# Month=21, Predicted=820.2724, Expected=809.0000
# Month=22, Predicted=774.1917, Expected=810.0000
# Month=23, Predicted=781.5037, Expected=766.0000
# Month=24, Predicted=731.2084, Expected=805.0000
# Month=25, Predicted=818.3977, Expected=821.0000
# Month=26, Predicted=836.0365, Expected=773.0000
# Month=27, Predicted=738.1779, Expected=883.0000
# Month=28, Predicted=896.0948, Expected=898.0000
# Month=29, Predicted=908.4274, Expected=957.0000
# Month=30, Predicted=970.2156, Expected=924.0000
# Month=31, Predicted=889.4624, Expected=881.0000
# Month=32, Predicted=846.2183, Expected=837.0000
# Month=33, Predicted=802.2084, Expected=784.0000
# Month=34, Predicted=749.1522, Expected=791.0000
# Month=35, Predicted=761.7869, Expected=760.0000
# Month=36, Predicted=725.6068, Expected=802.0000
# Month=37, Predicted=815.3539, Expected=828.0000
# Month=38, Predicted=841.8353, Expected=778.0000
# Month=39, Predicted=743.1664, Expected=889.0000
# Month=40, Predicted=902.0937, Expected=902.0000
# Month=41, Predicted=883.7698, Expected=969.0000
# Month=42, Predicted=982.1811, Expected=947.0000
# Month=43, Predicted=950.2182, Expected=908.0000
# Month=44, Predicted=873.2724, Expected=867.0000
# Month=45, Predicted=832.2418, Expected=815.0000
# Month=46, Predicted=780.1566, Expected=812.0000
# Month=47, Predicted=788.5048, Expected=773.0000
# Month=48, Predicted=738.2724, Expected=813.0000
# Month=49, Predicted=826.3820, Expected=834.0000
# Month=50, Predicted=848.3984, Expected=782.0000
# Month=51, Predicted=747.1566, Expected=892.0000
# Month=52, Predicted=905.0948, Expected=903.0000
# Month=53, Predicted=876.7832, Expected=966.0000
# Month=54, Predicted=979.1969, Expected=937.0000
# Month=55, Predicted=902.8612, Expected=896.0000
# Month=56, Predicted=861.2418, Expected=858.0000
# Month=57, Predicted=823.2915, Expected=817.0000
# Month=58, Predicted=782.2418, Expected=827.0000
# Month=59, Predicted=799.4424, Expected=797.0000
# Month=60, Predicted=762.7146, Expected=843.0000
# Run 14 — RMSE: 56.914949, MSE: 3239.311448, NMSE: 0.0102752651, Time: 87.2s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=764.1591, Expected=804.0000
# Month=2, Predicted=806.7405, Expected=756.0000
# Month=3, Predicted=725.1742, Expected=860.0000
# Month=4, Predicted=878.3999, Expected=878.0000
# Month=5, Predicted=884.0324, Expected=942.0000
# Month=6, Predicted=918.5618, Expected=913.0000
# Month=7, Predicted=905.5370, Expected=869.0000
# Month=8, Predicted=838.2227, Expected=834.0000
# Month=9, Predicted=805.1942, Expected=790.0000
# Month=10, Predicted=759.2227, Expected=800.0000
# Month=11, Predicted=803.3110, Expected=763.0000
# Month=12, Predicted=732.7695, Expected=800.0000
# Month=13, Predicted=812.3837, Expected=826.0000
# Month=14, Predicted=834.9140, Expected=799.0000
# Month=15, Predicted=796.5723, Expected=890.0000
# Month=16, Predicted=908.7353, Expected=900.0000
# Month=17, Predicted=903.3110, Expected=961.0000
# Month=18, Predicted=938.2521, Expected=935.0000
# Month=19, Predicted=934.2136, Expected=894.0000
# Month=20, Predicted=863.2697, Expected=855.0000
# Month=21, Predicted=824.3742, Expected=809.0000
# Month=22, Predicted=778.1989, Expected=810.0000
# Month=23, Predicted=811.4574, Expected=766.0000
# Month=24, Predicted=735.2227, Expected=805.0000
# Month=25, Predicted=817.9121, Expected=821.0000
# Month=26, Predicted=826.3147, Expected=773.0000
# Month=27, Predicted=742.1742, Expected=883.0000
# Month=28, Predicted=901.3275, Expected=898.0000
# Month=29, Predicted=902.9619, Expected=957.0000
# Month=30, Predicted=935.8040, Expected=924.0000
# Month=31, Predicted=899.7093, Expected=881.0000
# Month=32, Predicted=850.2348, Expected=837.0000
# Month=33, Predicted=806.2227, Expected=784.0000
# Month=34, Predicted=753.1150, Expected=791.0000
# Month=35, Predicted=793.4741, Expected=760.0000
# Month=36, Predicted=744.4154, Expected=802.0000
# Month=37, Predicted=815.6036, Expected=828.0000
# Month=38, Predicted=836.9140, Expected=778.0000
# Month=39, Predicted=747.1495, Expected=889.0000
# Month=40, Predicted=907.3175, Expected=902.0000
# Month=41, Predicted=906.2744, Expected=969.0000
# Month=42, Predicted=946.1929, Expected=947.0000
# Month=43, Predicted=949.6605, Expected=908.0000
# Month=44, Predicted=877.3742, Expected=867.0000
# Month=45, Predicted=836.2697, Expected=815.0000
# Month=46, Predicted=784.1260, Expected=812.0000
# Month=47, Predicted=813.4866, Expected=773.0000
# Month=48, Predicted=742.3742, Expected=813.0000
# Month=49, Predicted=826.1591, Expected=834.0000
# Month=50, Predicted=841.1227, Expected=782.0000
# Month=51, Predicted=751.1260, Expected=892.0000
# Month=52, Predicted=910.3275, Expected=903.0000
# Month=53, Predicted=906.6209, Expected=966.0000
# Month=54, Predicted=942.6415, Expected=937.0000
# Month=55, Predicted=929.5370, Expected=896.0000
# Month=56, Predicted=865.2697, Expected=858.0000
# Month=57, Predicted=827.5087, Expected=817.0000
# Month=58, Predicted=786.2697, Expected=827.0000
# Month=59, Predicted=830.3110, Expected=797.0000
# Month=60, Predicted=785.8510, Expected=843.0000
# Run 15 — RMSE: 52.121792, MSE: 2716.681238, NMSE: 0.0104841405, Time: 88.0s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=756.5757, Expected=804.0000
# Month=2, Predicted=801.2024, Expected=756.0000
# Month=3, Predicted=730.3472, Expected=860.0000
# Month=4, Predicted=875.0067, Expected=878.0000
# Month=5, Predicted=877.5334, Expected=942.0000
# Month=6, Predicted=933.6861, Expected=913.0000
# Month=7, Predicted=887.3823, Expected=869.0000
# Month=8, Predicted=843.3545, Expected=834.0000
# Month=9, Predicted=808.3720, Expected=790.0000
# Month=10, Predicted=764.3545, Expected=800.0000
# Month=11, Predicted=771.0507, Expected=763.0000
# Month=12, Predicted=737.3681, Expected=800.0000
# Month=13, Predicted=806.9083, Expected=826.0000
# Month=14, Predicted=834.3286, Expected=799.0000
# Month=15, Predicted=773.3848, Expected=890.0000
# Month=16, Predicted=897.8604, Expected=900.0000
# Month=17, Predicted=871.0507, Expected=961.0000
# Month=18, Predicted=953.3727, Expected=935.0000
# Month=19, Predicted=909.3856, Expected=894.0000
# Month=20, Predicted=868.3602, Expected=855.0000
# Month=21, Predicted=829.3642, Expected=809.0000
# Month=22, Predicted=783.3508, Expected=810.0000
# Month=23, Predicted=783.8295, Expected=766.0000
# Month=24, Predicted=740.3545, Expected=805.0000
# Month=25, Predicted=811.0516, Expected=821.0000
# Month=26, Predicted=812.3824, Expected=773.0000
# Month=27, Predicted=747.3472, Expected=883.0000
# Month=28, Predicted=899.8165, Expected=898.0000
# Month=29, Predicted=882.6701, Expected=957.0000
# Month=30, Predicted=950.2466, Expected=924.0000
# Month=31, Predicted=898.3758, Expected=881.0000
# Month=32, Predicted=855.3564, Expected=837.0000
# Month=33, Predicted=811.3545, Expected=784.0000
# Month=34, Predicted=758.3389, Expected=791.0000
# Month=35, Predicted=763.7223, Expected=760.0000
# Month=36, Predicted=734.3793, Expected=802.0000
# Month=37, Predicted=806.5399, Expected=828.0000
# Month=38, Predicted=836.3286, Expected=778.0000
# Month=39, Predicted=752.3437, Expected=889.0000
# Month=40, Predicted=906.0237, Expected=902.0000
# Month=41, Predicted=872.1787, Expected=969.0000
# Month=42, Predicted=960.8036, Expected=947.0000
# Month=43, Predicted=921.3859, Expected=908.0000
# Month=44, Predicted=882.3642, Expected=867.0000
# Month=45, Predicted=841.3602, Expected=815.0000
# Month=46, Predicted=789.3404, Expected=812.0000
# Month=47, Predicted=786.0971, Expected=773.0000
# Month=48, Predicted=747.3642, Expected=813.0000
# Month=49, Predicted=818.5757, Expected=834.0000
# Month=50, Predicted=839.1947, Expected=782.0000
# Month=51, Predicted=756.3404, Expected=892.0000
# Month=52, Predicted=908.8165, Expected=903.0000
# Month=53, Predicted=873.5273, Expected=966.0000
# Month=54, Predicted=957.8266, Expected=937.0000
# Month=55, Predicted=911.3823, Expected=896.0000
# Month=56, Predicted=870.3602, Expected=858.0000
# Month=57, Predicted=832.3661, Expected=817.0000
# Month=58, Predicted=791.3602, Expected=827.0000
# Month=59, Predicted=798.0507, Expected=797.0000
# Month=60, Predicted=771.3809, Expected=843.0000
# Run 16 — RMSE: 53.367657, MSE: 2848.106853, NMSE: 0.0107454123, Time: 88.7s
#
# ===== RUN 17/30 =====
# ...
# Month=42, Predicted=978.5686, Expected=947.0000
# Month=43, Predicted=944.0116, Expected=908.0000
# Month=44, Predicted=892.9666, Expected=867.0000
# Month=45, Predicted=846.1012, Expected=815.0000
# Month=46, Predicted=778.5908, Expected=812.0000
# Month=47, Predicted=811.3856, Expected=773.0000
# Month=48, Predicted=757.9666, Expected=813.0000
# Month=49, Predicted=818.2193, Expected=834.0000
# Month=50, Predicted=836.5489, Expected=782.0000
# Month=51, Predicted=745.5908, Expected=892.0000
# Month=52, Predicted=908.2226, Expected=903.0000
# Month=53, Predicted=904.2415, Expected=966.0000
# Month=54, Predicted=974.9051, Expected=937.0000
# Month=55, Predicted=932.7508, Expected=896.0000
# Month=56, Predicted=875.1012, Expected=858.0000
# Month=57, Predicted=845.2330, Expected=817.0000
# Month=58, Predicted=796.1012, Expected=827.0000
# Month=59, Predicted=828.1110, Expected=797.0000
# Month=60, Predicted=792.3983, Expected=843.0000
# Run 25 — RMSE: 54.273196, MSE: 2945.579800, NMSE: 0.0101436341, Time: 88.0s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=756.3808, Expected=804.0000
# Month=2, Predicted=812.1796, Expected=756.0000
# Month=3, Predicted=740.9156, Expected=860.0000
# Month=4, Predicted=873.3323, Expected=878.0000
# Month=5, Predicted=875.6387, Expected=942.0000
# Month=6, Predicted=951.8641, Expected=913.0000
# Month=7, Predicted=906.1223, Expected=869.0000
# Month=8, Predicted=860.1931, Expected=834.0000
# Month=9, Predicted=827.8695, Expected=790.0000
# Month=10, Predicted=781.1931, Expected=800.0000
# Month=11, Predicted=794.1764, Expected=763.0000
# Month=12, Predicted=756.8831, Expected=800.0000
# Month=13, Predicted=804.5678, Expected=826.0000
# Month=14, Predicted=826.9219, Expected=799.0000
# Month=15, Predicted=791.7736, Expected=890.0000
# Month=16, Predicted=902.5017, Expected=900.0000
# Month=17, Predicted=894.1764, Expected=961.0000
# Month=18, Predicted=970.4526, Expected=935.0000
# Month=19, Predicted=927.5920, Expected=894.0000
# Month=20, Predicted=887.0849, Expected=855.0000
# Month=21, Predicted=848.6597, Expected=809.0000
# Month=22, Predicted=797.8469, Expected=810.0000
# Month=23, Predicted=801.0663, Expected=766.0000
# Month=24, Predicted=757.1931, Expected=805.0000
# Month=25, Predicted=810.1178, Expected=821.0000
# Month=26, Predicted=817.7664, Expected=773.0000
# Month=27, Predicted=757.9156, Expected=883.0000
# Month=28, Predicted=896.6552, Expected=898.0000
# Month=29, Predicted=894.3281, Expected=957.0000
# Month=30, Predicted=966.1597, Expected=924.0000
# Month=31, Predicted=917.7020, Expected=881.0000
# Month=32, Predicted=872.9983, Expected=837.0000
# Month=33, Predicted=828.1931, Expected=784.0000
# Month=34, Predicted=743.4013, Expected=791.0000
# Month=35, Predicted=783.9828, Expected=760.0000
# Month=36, Predicted=753.4398, Expected=802.0000
# Month=37, Predicted=807.8841, Expected=828.0000
# Month=38, Predicted=828.9219, Expected=778.0000
# Month=39, Predicted=755.1972, Expected=889.0000
# Month=40, Predicted=902.7059, Expected=902.0000
# Month=41, Predicted=897.4544, Expected=969.0000
# Month=42, Predicted=979.2453, Expected=947.0000
# Month=43, Predicted=938.8410, Expected=908.0000
# Month=44, Predicted=901.6597, Expected=867.0000
# Month=45, Predicted=860.0849, Expected=815.0000
# Month=46, Predicted=779.7542, Expected=812.0000
# Month=47, Predicted=802.2886, Expected=773.0000
# Month=48, Predicted=766.6597, Expected=813.0000
# Month=49, Predicted=818.3808, Expected=834.0000
# Month=50, Predicted=832.9190, Expected=782.0000
# Month=51, Predicted=746.7542, Expected=892.0000
# Month=52, Predicted=905.6552, Expected=903.0000
# Month=53, Predicted=897.5956, Expected=966.0000
# Month=54, Predicted=975.7304, Expected=937.0000
# Month=55, Predicted=930.1223, Expected=896.0000
# Month=56, Predicted=889.0849, Expected=858.0000
# Month=57, Predicted=851.8073, Expected=817.0000
# Month=58, Predicted=810.0849, Expected=827.0000
# Month=59, Predicted=821.1764, Expected=797.0000
# Month=60, Predicted=790.2861, Expected=843.0000
# Run 26 — RMSE: 51.946232, MSE: 2698.411022, NMSE: 0.0101934588, Time: 87.5s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=769.5615, Expected=804.0000
# Month=2, Predicted=822.1906, Expected=756.0000
# Month=3, Predicted=722.6594, Expected=860.0000
# Month=4, Predicted=877.8052, Expected=878.0000
# Month=5, Predicted=919.3084, Expected=942.0000
# Month=6, Predicted=960.0371, Expected=913.0000
# Month=7, Predicted=879.7293, Expected=869.0000
# Month=8, Predicted=835.6700, Expected=834.0000
# Month=9, Predicted=800.7008, Expected=790.0000
# Month=10, Predicted=756.6700, Expected=800.0000
# Month=11, Predicted=824.9772, Expected=763.0000
# Month=12, Predicted=729.6929, Expected=800.0000
# Month=13, Predicted=818.7162, Expected=826.0000
# Month=14, Predicted=846.2227, Expected=799.0000
# Month=15, Predicted=765.7409, Expected=890.0000
# Month=16, Predicted=907.8532, Expected=900.0000
# Month=17, Predicted=924.9772, Expected=961.0000
# Month=18, Predicted=979.0713, Expected=935.0000
# Month=19, Predicted=901.7472, Expected=894.0000
# Month=20, Predicted=860.6790, Expected=855.0000
# Month=21, Predicted=821.6857, Expected=809.0000
# Month=22, Predicted=775.6645, Expected=810.0000
# Month=23, Predicted=777.4731, Expected=766.0000
# Month=24, Predicted=732.6700, Expected=805.0000
# Month=25, Predicted=823.6083, Expected=821.0000
# Month=26, Predicted=883.8477, Expected=773.0000
# Month=27, Predicted=739.6594, Expected=883.0000
# Month=28, Predicted=900.7876, Expected=898.0000
# Month=29, Predicted=962.9439, Expected=957.0000
# Month=30, Predicted=975.0969, Expected=924.0000
# Month=31, Predicted=890.7094, Expected=881.0000
# Month=32, Predicted=847.6729, Expected=837.0000
# Month=33, Predicted=803.6700, Expected=784.0000
# Month=34, Predicted=750.6481, Expected=791.0000
# Month=35, Predicted=760.7847, Expected=760.0000
# Month=36, Predicted=726.7188, Expected=802.0000
# Month=37, Predicted=820.4792, Expected=828.0000
# Month=38, Predicted=848.2227, Expected=778.0000
# Month=39, Predicted=744.6547, Expected=889.0000
# Month=40, Predicted=906.7849, Expected=902.0000
# Month=41, Predicted=967.0232, Expected=969.0000
# Month=42, Predicted=987.0069, Expected=947.0000
# Month=43, Predicted=913.7764, Expected=908.0000
# Month=44, Predicted=874.6857, Expected=867.0000
# Month=45, Predicted=833.6790, Expected=815.0000
# Month=46, Predicted=781.6502, Expected=812.0000
# Month=47, Predicted=779.1690, Expected=773.0000
# Month=48, Predicted=739.6857, Expected=813.0000
# Month=49, Predicted=831.5615, Expected=834.0000
# Month=50, Predicted=858.1843, Expected=782.0000
# Month=51, Predicted=748.6502, Expected=892.0000
# Month=52, Predicted=909.7876, Expected=903.0000
# Month=53, Predicted=965.3090, Expected=966.0000
# Month=54, Predicted=984.0480, Expected=937.0000
# Month=55, Predicted=903.7293, Expected=896.0000
# Month=56, Predicted=862.6790, Expected=858.0000
# Month=57, Predicted=824.6892, Expected=817.0000
# Month=58, Predicted=783.6790, Expected=827.0000
# Month=59, Predicted=851.9772, Expected=797.0000
# Month=60, Predicted=763.7239, Expected=843.0000
# Run 27 — RMSE: 55.291265, MSE: 3057.123988, NMSE: 0.0087838222, Time: 87.4s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=758.7282, Expected=804.0000
# Month=2, Predicted=812.6200, Expected=756.0000
# Month=3, Predicted=731.4841, Expected=860.0000
# Month=4, Predicted=869.9227, Expected=878.0000
# Month=5, Predicted=880.8242, Expected=942.0000
# Month=6, Predicted=951.0817, Expected=913.0000
# Month=7, Predicted=925.7969, Expected=869.0000
# Month=8, Predicted=846.8672, Expected=834.0000
# Month=9, Predicted=827.0949, Expected=790.0000
# Month=10, Predicted=767.8672, Expected=800.0000
# Month=11, Predicted=794.7658, Expected=763.0000
# Month=12, Predicted=750.3289, Expected=800.0000
# Month=13, Predicted=807.4273, Expected=826.0000
# Month=14, Predicted=831.6660, Expected=799.0000
# Month=15, Predicted=814.5699, Expected=890.0000
# Month=16, Predicted=899.7319, Expected=900.0000
# Month=17, Predicted=894.7658, Expected=961.0000
# Month=18, Predicted=969.9728, Expected=935.0000
# Month=19, Predicted=951.3747, Expected=894.0000
# Month=20, Predicted=874.6693, Expected=855.0000
# Month=21, Predicted=838.4014, Expected=809.0000
# Month=22, Predicted=785.5346, Expected=810.0000
# Month=23, Predicted=784.4443, Expected=766.0000
# Month=24, Predicted=743.8672, Expected=805.0000
# Month=25, Predicted=812.6334, Expected=821.0000
# Month=26, Predicted=822.6074, Expected=773.0000
# Month=27, Predicted=748.4841, Expected=883.0000
# Month=28, Predicted=892.9953, Expected=898.0000
# Month=29, Predicted=898.8638, Expected=957.0000
# Month=30, Predicted=965.8939, Expected=924.0000
# Month=31, Predicted=924.6021, Expected=881.0000
# Month=32, Predicted=859.6734, Expected=837.0000
# Month=33, Predicted=814.8672, Expected=784.0000
# Month=34, Predicted=757.6481, Expected=791.0000
# Month=35, Predicted=778.7208, Expected=760.0000
# Month=36, Predicted=767.8086, Expected=802.0000
# Month=37, Predicted=809.9034, Expected=828.0000
# Month=38, Predicted=833.6660, Expected=778.0000
# Month=39, Predicted=752.6393, Expected=889.0000
# Month=40, Predicted=899.0067, Expected=902.0000
# Month=41, Predicted=901.0011, Expected=969.0000
# Month=42, Predicted=978.1805, Expected=947.0000
# Month=43, Predicted=964.5388, Expected=908.0000
# Month=44, Predicted=891.4014, Expected=867.0000
# Month=45, Predicted=847.6693, Expected=815.0000
# Month=46, Predicted=788.9480, Expected=812.0000
# Month=47, Predicted=792.7923, Expected=773.0000
# Month=48, Predicted=756.4014, Expected=813.0000
# Month=49, Predicted=820.7282, Expected=834.0000
# Month=50, Predicted=838.1733, Expected=782.0000
# Month=51, Predicted=755.9480, Expected=892.0000
# Month=52, Predicted=901.9953, Expected=903.0000
# Month=53, Predicted=899.4272, Expected=966.0000
# Month=54, Predicted=975.0466, Expected=937.0000
# Month=55, Predicted=949.7969, Expected=896.0000
# Month=56, Predicted=876.6693, Expected=858.0000
# Month=57, Predicted=843.1763, Expected=817.0000
# Month=58, Predicted=797.6693, Expected=827.0000
# Month=59, Predicted=821.7658, Expected=797.0000
# Month=60, Predicted=807.6165, Expected=843.0000
# Run 28 — RMSE: 51.802381, MSE: 2683.486698, NMSE: 0.0095136332, Time: 87.2s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=743.2700, Expected=804.0000
# Month=2, Predicted=794.2204, Expected=756.0000
# Month=3, Predicted=741.4803, Expected=860.0000
# Month=4, Predicted=874.5214, Expected=878.0000
# Month=5, Predicted=867.1719, Expected=942.0000
# Month=6, Predicted=930.5032, Expected=913.0000
# Month=7, Predicted=900.7678, Expected=869.0000
# Month=8, Predicted=856.1458, Expected=834.0000
# Month=9, Predicted=822.2142, Expected=790.0000
# Month=10, Predicted=777.1458, Expected=800.0000
# Month=11, Predicted=786.7135, Expected=763.0000
# Month=12, Predicted=751.2030, Expected=800.0000
# Month=13, Predicted=792.2493, Expected=826.0000
# Month=14, Predicted=817.0141, Expected=799.0000
# Month=15, Predicted=786.5062, Expected=890.0000
# Month=16, Predicted=898.8851, Expected=900.0000
# Month=17, Predicted=886.7135, Expected=961.0000
# Month=18, Predicted=949.5880, Expected=935.0000
# Month=19, Predicted=922.3615, Expected=894.0000
# Month=20, Predicted=881.8320, Expected=855.0000
# Month=21, Predicted=843.0832, Expected=809.0000
# Month=22, Predicted=795.4332, Expected=810.0000
# Month=23, Predicted=794.6041, Expected=766.0000
# Month=24, Predicted=753.1458, Expected=805.0000
# Month=25, Predicted=797.2822, Expected=821.0000
# Month=26, Predicted=809.5928, Expected=773.0000
# Month=27, Predicted=758.4803, Expected=883.0000
# Month=28, Predicted=898.7366, Expected=898.0000
# Month=29, Predicted=886.2894, Expected=957.0000
# Month=30, Predicted=945.8567, Expected=924.0000
# Month=31, Predicted=912.1353, Expected=881.0000
# Month=32, Predicted=868.4212, Expected=837.0000
# Month=33, Predicted=824.1458, Expected=784.0000
# Month=34, Predicted=766.0082, Expected=791.0000
# Month=35, Predicted=776.8267, Expected=760.0000
# Month=36, Predicted=747.9818, Expected=802.0000
# Month=37, Predicted=794.1831, Expected=828.0000
# Month=38, Predicted=819.0141, Expected=778.0000
# Month=39, Predicted=762.2708, Expected=889.0000
# Month=40, Predicted=904.8954, Expected=902.0000
# Month=41, Predicted=889.6633, Expected=969.0000
# Month=42, Predicted=957.9115, Expected=947.0000
# Month=43, Predicted=933.7224, Expected=908.0000
# Month=44, Predicted=896.0832, Expected=867.0000
# Month=45, Predicted=854.8320, Expected=815.0000
# Month=46, Predicted=797.8154, Expected=812.0000
# Month=47, Predicted=796.3604, Expected=773.0000
# Month=48, Predicted=761.0832, Expected=813.0000
# Month=49, Predicted=805.2700, Expected=834.0000
# Month=50, Predicted=823.9557, Expected=782.0000
# Month=51, Predicted=764.8154, Expected=892.0000
# Month=52, Predicted=907.7366, Expected=903.0000
# Month=53, Predicted=890.0277, Expected=966.0000
# Month=54, Predicted=954.4825, Expected=937.0000
# Month=55, Predicted=924.7678, Expected=896.0000
# Month=56, Predicted=883.8320, Expected=858.0000
# Month=57, Predicted=846.1580, Expected=817.0000
# Month=58, Predicted=804.8320, Expected=827.0000
# Month=59, Predicted=813.7135, Expected=797.0000
# Month=60, Predicted=784.8815, Expected=843.0000
# Run 29 — RMSE: 49.817558, MSE: 2481.789048, NMSE: 0.0101451384, Time: 90.1s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=765.1967, Expected=804.0000
# Month=2, Predicted=818.4062, Expected=756.0000
# Month=3, Predicted=734.0630, Expected=860.0000
# Month=4, Predicted=874.6389, Expected=878.0000
# Month=5, Predicted=884.7227, Expected=942.0000
# Month=6, Predicted=956.4957, Expected=913.0000
# Month=7, Predicted=919.7029, Expected=869.0000
# Month=8, Predicted=860.1670, Expected=834.0000
# Month=9, Predicted=838.7238, Expected=790.0000
# Month=10, Predicted=781.1670, Expected=800.0000
# Month=11, Predicted=769.3886, Expected=763.0000
# Month=12, Predicted=766.2671, Expected=800.0000
# Month=13, Predicted=814.1109, Expected=826.0000
# Month=14, Predicted=839.3038, Expected=799.0000
# Month=15, Predicted=805.7955, Expected=890.0000
# Month=16, Predicted=904.6080, Expected=900.0000
# Month=17, Predicted=869.3886, Expected=961.0000
# Month=18, Predicted=975.4755, Expected=935.0000
# Month=19, Predicted=941.7501, Expected=894.0000
# Month=20, Predicted=892.1218, Expected=855.0000
# Month=21, Predicted=856.1600, Expected=809.0000
# Month=22, Predicted=793.9369, Expected=810.0000
# Month=23, Predicted=772.7024, Expected=766.0000
# Month=24, Predicted=757.1670, Expected=805.0000
# Month=25, Predicted=819.1706, Expected=821.0000
# Month=26, Predicted=819.6037, Expected=773.0000
# Month=27, Predicted=751.0630, Expected=883.0000
# Month=28, Predicted=897.6505, Expected=898.0000
# Month=29, Predicted=890.6945, Expected=957.0000
# Month=30, Predicted=971.4605, Expected=924.0000
# Month=31, Predicted=929.7158, Expected=881.0000
# Month=32, Predicted=874.8333, Expected=837.0000
# Month=33, Predicted=828.1670, Expected=784.0000
# Month=34, Predicted=747.9313, Expected=791.0000
# Month=35, Predicted=755.6688, Expected=760.0000
# Month=36, Predicted=766.3542, Expected=802.0000
# Month=37, Predicted=816.2426, Expected=828.0000
# Month=38, Predicted=841.3038, Expected=778.0000
# Month=39, Predicted=749.4662, Expected=889.0000
# Month=40, Predicted=903.6523, Expected=902.0000
# Month=41, Predicted=882.2829, Expected=969.0000
# Month=42, Predicted=983.5137, Expected=947.0000
# Month=43, Predicted=952.9284, Expected=908.0000
# Month=44, Predicted=909.1600, Expected=867.0000
# Month=45, Predicted=865.1218, Expected=815.0000
# Month=46, Predicted=781.0521, Expected=812.0000
# Month=47, Predicted=778.1821, Expected=773.0000
# Month=48, Predicted=774.1600, Expected=813.0000
# Month=49, Predicted=827.1967, Expected=834.0000
# Month=50, Predicted=845.4522, Expected=782.0000
# Month=51, Predicted=748.0521, Expected=892.0000
# Month=52, Predicted=906.6505, Expected=903.0000
# Month=53, Predicted=874.9830, Expected=966.0000
# Month=54, Predicted=980.4893, Expected=937.0000
# Month=55, Predicted=943.7029, Expected=896.0000
# Month=56, Predicted=894.1218, Expected=858.0000
# Month=57, Predicted=860.3101, Expected=817.0000
# Month=58, Predicted=815.1218, Expected=827.0000
# Month=59, Predicted=796.3886, Expected=797.0000
# Month=60, Predicted=803.5621, Expected=843.0000
# Run 30 — RMSE: 54.700310, MSE: 2992.123956, NMSE: 0.0105075354, Time: 90.0s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — PatchTST on Monthly Milk Production (30 runs) =====
# RMSE: 53.832877 ± 2.022589
# MSE:  2902.069564 ± 217.247012
# NMSE: 0.0103455297 ± 0.0005021524
# Avg training time: 88.5s ± 17.3s
#
# Best run: 22
#   RMSE: 49.068971
#   MSE:  2407.763928
#   NMSE: 0.0113701907

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('PatchTST — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('PatchTST — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 49.068971
# MSE:  2407.763928
# NMSE: 0.0113701907

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'PatchTST_Milk_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to PatchTST_Milk_predictions.csv

# %% [markdown]
# ## Observations
#
# ### PatchTST on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
