# %% [markdown]
# # Pyraformer — Monthly Milk Production
#
# **Model**: Pyramidal Attention for Time Series
# **Reference**: Liu et al., 2022 — Pyraformer: Low-Complexity Pyramidal Attention for Long-Range Time Series Modeling and Forecasting
#
# ## Description
# This notebook implements the **Pyraformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Milk Production dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Pyraformer Architecture
#
# ### Pyramidal Attention
# Pyraformer builds a **multi-resolution temporal hierarchy**:
#
# **Level 0 (finest)**: Original sequence tokens
# **Level 1**: Downsampled by factor 2
# **Level $k$**: Downsampled by factor $2^k$
#
# ### CSCM (Coarser-Scale Construction Module)
# Builds the pyramid using 1D convolutions with stride 2:
# $$X^{(k+1)} = \text{Conv1D}(X^{(k)}, \text{stride}=2)$$
#
# ### PAM (Pyramidal Attention Module)
# Two types of attention connections:
#
# 1. **Intra-scale**: Self-attention within each resolution level
# 2. **Inter-scale**: Cross-attention from finer to coarser scales
#
# The finest level queries attend to coarser-level summaries, capturing both local detail and global context.
#
# ### Complexity
# The pyramidal structure reduces attention complexity from $O(L^2)$ to $O(L)$ by limiting attention to $O(1)$ connections per node across scales.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### Pyraformer Model Definition

# %%
# ============================================================
# Pyraformer: Pyramidal Attention for Time Series
# Reference: Liu et al., 2022
#
# Key ideas:
# 1. Pyramidal attention: multi-resolution temporal hierarchy
# 2. Coarser-scale nodes summarize finer-scale patterns
# 3. Inter-scale and intra-scale attention connections
# 4. Reduces complexity from O(L^2) to O(L)
#
# For our setup, we build a simplified pyramid with CSCM
# (Coarser-Scale Construction Module) and PAM
# (Pyramidal Attention Module).
# ============================================================

class CoarserScaleConstruction(nn.Module):
    """
    CSCM: Coarser-Scale Construction Module.
    Builds pyramid by progressively downsampling the sequence.
    Uses 1D convolutions with stride=2 for downsampling.
    """
    def __init__(self, d_model, n_scales=2):
        super().__init__()
        self.n_scales = n_scales
        self.downsample_layers = nn.ModuleList([
            nn.Sequential(
                nn.Conv1d(d_model, d_model, kernel_size=3, stride=2, padding=1),
                nn.GELU(),
            )
            for _ in range(n_scales)
        ])

    def forward(self, x):
        """
        x: (B, L, D)
        Returns list of tensors at different scales.
        """
        scales = [x]
        current = x.transpose(1, 2)  # (B, D, L)
        for layer in self.downsample_layers:
            current = layer(current)
            scales.append(current.transpose(1, 2))
        return scales


class PyramidAttentionLayer(nn.Module):
    """
    Pyramidal Attention: applies attention within and across scales.
    - Intra-scale: standard self-attention within each resolution
    - Inter-scale: attention from finer to coarser scale
    """
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        # Intra-scale attention
        self.self_attn = nn.MultiheadAttention(d_model, n_heads,
                                                dropout=dropout,
                                                batch_first=True)
        # Inter-scale attention (cross-attention from fine to coarse)
        self.cross_attn = nn.MultiheadAttention(d_model, n_heads,
                                                 dropout=dropout,
                                                 batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x_fine, x_coarse=None):
        # Intra-scale self-attention
        attn_out, _ = self.self_attn(x_fine, x_fine, x_fine)
        x = self.norm1(x_fine + self.dropout(attn_out))

        # Inter-scale cross-attention (if coarse scale available)
        if x_coarse is not None:
            cross_out, _ = self.cross_attn(x, x_coarse, x_coarse)
            x = self.norm2(x + self.dropout(cross_out))

        # Feed-forward
        ff_out = self.ff(x)
        x = self.norm3(x + ff_out)
        return x


class PyraformerModel(nn.Module):
    """
    Pyraformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, n_scales=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)

        # CSCM: build multi-scale pyramid
        self.cscm = CoarserScaleConstruction(d_model, n_scales)

        # Pyramidal attention layers (one per scale at finest level)
        self.pyramid_layers = nn.ModuleList([
            PyramidAttentionLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])

        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        # Build pyramid
        scales = self.cscm(x)  # List of tensors at different resolutions

        # Apply pyramidal attention at finest scale with coarser context
        finest = scales[0]
        for i, layer in enumerate(self.pyramid_layers):
            # Use next coarser scale as context (if available)
            coarse_idx = min(i + 1, len(scales) - 1)
            coarse = scales[coarse_idx]
            finest = layer(finest, coarse)

        x = finest[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = PyraformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 35169
# Trainable parameters: 35169
# Memory estimate: 137.4 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = PyraformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=757.8059, Expected=804.0000
# Month=2, Predicted=796.0922, Expected=756.0000
# Month=3, Predicted=713.7834, Expected=860.0000
# Month=4, Predicted=880.0829, Expected=878.0000
# Month=5, Predicted=865.9102, Expected=942.0000
# Month=6, Predicted=913.5482, Expected=913.0000
# Month=7, Predicted=918.9390, Expected=869.0000
# Month=8, Predicted=839.4199, Expected=834.0000
# Month=9, Predicted=828.9844, Expected=790.0000
# Month=10, Predicted=760.4199, Expected=800.0000
# Month=11, Predicted=782.6711, Expected=763.0000
# Month=12, Predicted=750.9464, Expected=800.0000
# Month=13, Predicted=805.9596, Expected=826.0000
# Month=14, Predicted=822.2609, Expected=799.0000
# Month=15, Predicted=805.6004, Expected=890.0000
# Month=16, Predicted=907.7817, Expected=900.0000
# Month=17, Predicted=882.6711, Expected=961.0000
# Month=18, Predicted=933.6519, Expected=935.0000
# Month=19, Predicted=941.5152, Expected=894.0000
# Month=20, Predicted=868.8794, Expected=855.0000
# Month=21, Predicted=835.4979, Expected=809.0000
# Month=22, Predicted=771.8905, Expected=810.0000
# Month=23, Predicted=791.4818, Expected=766.0000
# Month=24, Predicted=736.4199, Expected=805.0000
# Month=25, Predicted=811.6472, Expected=821.0000
# Month=26, Predicted=807.2385, Expected=773.0000
# Month=27, Predicted=730.7834, Expected=883.0000
# Month=28, Predicted=903.4373, Expected=898.0000
# Month=29, Predicted=883.4900, Expected=957.0000
# Month=30, Predicted=932.5461, Expected=924.0000
# Month=31, Predicted=924.3835, Expected=881.0000
# Month=32, Predicted=852.8752, Expected=837.0000
# Month=33, Predicted=807.4199, Expected=784.0000
# Month=34, Predicted=740.4167, Expected=791.0000
# Month=35, Predicted=772.7194, Expected=760.0000
# Month=36, Predicted=763.9608, Expected=802.0000
# Month=37, Predicted=808.7062, Expected=828.0000
# Month=38, Predicted=824.2609, Expected=778.0000
# Month=39, Predicted=734.8475, Expected=889.0000
# Month=40, Predicted=909.4791, Expected=902.0000
# Month=41, Predicted=886.1764, Expected=969.0000
# Month=42, Predicted=939.5847, Expected=947.0000
# Month=43, Predicted=950.9925, Expected=908.0000
# Month=44, Predicted=888.4979, Expected=867.0000
# Month=45, Predicted=841.8794, Expected=815.0000
# Month=46, Predicted=771.5162, Expected=812.0000
# Month=47, Predicted=794.6922, Expected=773.0000
# Month=48, Predicted=753.4979, Expected=813.0000
# Month=49, Predicted=819.8059, Expected=834.0000
# Month=50, Predicted=824.8045, Expected=782.0000
# Month=51, Predicted=738.5162, Expected=892.0000
# Month=52, Predicted=912.4373, Expected=903.0000
# Month=53, Predicted=886.1109, Expected=966.0000
# Month=54, Predicted=937.7278, Expected=937.0000
# Month=55, Predicted=942.9390, Expected=896.0000
# Month=56, Predicted=870.8794, Expected=858.0000
# Month=57, Predicted=842.1423, Expected=817.0000
# Month=58, Predicted=791.8794, Expected=827.0000
# Month=59, Predicted=809.6711, Expected=797.0000
# Month=60, Predicted=802.1316, Expected=843.0000
# Run 1 — RMSE: 54.830380, MSE: 3006.370563, NMSE: 0.0109686525, Time: 48.4s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=755.9281, Expected=804.0000
# Month=2, Predicted=789.0779, Expected=756.0000
# Month=3, Predicted=709.1533, Expected=860.0000
# Month=4, Predicted=881.3800, Expected=878.0000
# Month=5, Predicted=884.9560, Expected=942.0000
# Month=6, Predicted=913.8562, Expected=913.0000
# Month=7, Predicted=910.4555, Expected=869.0000
# Month=8, Predicted=842.7851, Expected=834.0000
# Month=9, Predicted=825.3370, Expected=790.0000
# Month=10, Predicted=763.7851, Expected=800.0000
# Month=11, Predicted=806.6038, Expected=763.0000
# Month=12, Predicted=751.4289, Expected=800.0000
# Month=13, Predicted=805.7947, Expected=826.0000
# Month=14, Predicted=832.9618, Expected=799.0000
# Month=15, Predicted=797.8400, Expected=890.0000
# Month=16, Predicted=911.5919, Expected=900.0000
# Month=17, Predicted=906.6038, Expected=961.0000
# Month=18, Predicted=929.7924, Expected=935.0000
# Month=19, Predicted=934.4415, Expected=894.0000
# Month=20, Predicted=875.1457, Expected=855.0000
# Month=21, Predicted=840.0065, Expected=809.0000
# Month=22, Predicted=771.5464, Expected=810.0000
# Month=23, Predicted=815.9041, Expected=766.0000
# Month=24, Predicted=739.7851, Expected=805.0000
# Month=25, Predicted=810.2638, Expected=821.0000
# Month=26, Predicted=827.8948, Expected=773.0000
# Month=27, Predicted=726.1533, Expected=883.0000
# Month=28, Predicted=904.2199, Expected=898.0000
# Month=29, Predicted=904.8570, Expected=957.0000
# Month=30, Predicted=925.5785, Expected=924.0000
# Month=31, Predicted=917.7671, Expected=881.0000
# Month=32, Predicted=857.8143, Expected=837.0000
# Month=33, Predicted=810.7851, Expected=784.0000
# Month=34, Predicted=736.2182, Expected=791.0000
# Month=35, Predicted=797.4049, Expected=760.0000
# Month=36, Predicted=755.7846, Expected=802.0000
# Month=37, Predicted=806.0639, Expected=828.0000
# Month=38, Predicted=834.9618, Expected=778.0000
# Month=39, Predicted=729.3228, Expected=889.0000
# Month=40, Predicted=910.1942, Expected=902.0000
# Month=41, Predicted=908.7680, Expected=969.0000
# Month=42, Predicted=945.3517, Expected=947.0000
# Month=43, Predicted=948.3715, Expected=908.0000
# Month=44, Predicted=893.0065, Expected=867.0000
# Month=45, Predicted=848.1457, Expected=815.0000
# Month=46, Predicted=766.7271, Expected=812.0000
# Month=47, Predicted=817.4839, Expected=773.0000
# Month=48, Predicted=758.0065, Expected=813.0000
# Month=49, Predicted=817.9281, Expected=834.0000
# Month=50, Predicted=841.0079, Expected=782.0000
# Month=51, Predicted=733.7271, Expected=892.0000
# Month=52, Predicted=913.2199, Expected=903.0000
# Month=53, Predicted=909.6625, Expected=966.0000
# Month=54, Predicted=936.6419, Expected=937.0000
# Month=55, Predicted=934.4555, Expected=896.0000
# Month=56, Predicted=877.1457, Expected=858.0000
# Month=57, Predicted=844.7813, Expected=817.0000
# Month=58, Predicted=798.1457, Expected=827.0000
# Month=59, Predicted=833.6038, Expected=797.0000
# Month=60, Predicted=793.6594, Expected=843.0000
# Run 2 — RMSE: 55.474022, MSE: 3077.367078, NMSE: 0.0112881479, Time: 44.3s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=757.4180, Expected=804.0000
# Month=2, Predicted=791.2755, Expected=756.0000
# Month=3, Predicted=717.7983, Expected=860.0000
# Month=4, Predicted=875.7163, Expected=878.0000
# Month=5, Predicted=886.7351, Expected=942.0000
# Month=6, Predicted=909.7108, Expected=913.0000
# Month=7, Predicted=923.2490, Expected=869.0000
# Month=8, Predicted=833.1812, Expected=834.0000
# Month=9, Predicted=836.6941, Expected=790.0000
# Month=10, Predicted=754.1812, Expected=800.0000
# Month=11, Predicted=808.9644, Expected=763.0000
# Month=12, Predicted=756.5050, Expected=800.0000
# Month=13, Predicted=807.2048, Expected=826.0000
# Month=14, Predicted=834.4233, Expected=799.0000
# Month=15, Predicted=809.7407, Expected=890.0000
# Month=16, Predicted=905.5391, Expected=900.0000
# Month=17, Predicted=908.9644, Expected=961.0000
# Month=18, Predicted=929.7446, Expected=935.0000
# Month=19, Predicted=945.8652, Expected=894.0000
# Month=20, Predicted=864.0439, Expected=855.0000
# Month=21, Predicted=834.8229, Expected=809.0000
# Month=22, Predicted=771.6731, Expected=810.0000
# Month=23, Predicted=819.3307, Expected=766.0000
# Month=24, Predicted=730.1812, Expected=805.0000
# Month=25, Predicted=811.7210, Expected=821.0000
# Month=26, Predicted=829.7922, Expected=773.0000
# Month=27, Predicted=734.7983, Expected=883.0000
# Month=28, Predicted=898.6712, Expected=898.0000
# Month=29, Predicted=906.8199, Expected=957.0000
# Month=30, Predicted=927.6766, Expected=924.0000
# Month=31, Predicted=931.1025, Expected=881.0000
# Month=32, Predicted=846.4577, Expected=837.0000
# Month=33, Predicted=801.1812, Expected=784.0000
# Month=34, Predicted=744.1218, Expected=791.0000
# Month=35, Predicted=800.0661, Expected=760.0000
# Month=36, Predicted=769.2110, Expected=802.0000
# Month=37, Predicted=807.6418, Expected=828.0000
# Month=38, Predicted=836.4233, Expected=778.0000
# Month=39, Predicted=739.0905, Expected=889.0000
# Month=40, Predicted=904.6624, Expected=902.0000
# Month=41, Predicted=910.8756, Expected=969.0000
# Month=42, Predicted=937.0699, Expected=947.0000
# Month=43, Predicted=957.9394, Expected=908.0000
# Month=44, Predicted=887.8229, Expected=867.0000
# Month=45, Predicted=837.0439, Expected=815.0000
# Month=46, Predicted=775.4348, Expected=812.0000
# Month=47, Predicted=821.5624, Expected=773.0000
# Month=48, Predicted=752.8229, Expected=813.0000
# Month=49, Predicted=819.4180, Expected=834.0000
# Month=50, Predicted=842.6397, Expected=782.0000
# Month=51, Predicted=742.4348, Expected=892.0000
# Month=52, Predicted=907.6712, Expected=903.0000
# Month=53, Predicted=911.9337, Expected=966.0000
# Month=54, Predicted=933.8645, Expected=937.0000
# Month=55, Predicted=947.2490, Expected=896.0000
# Month=56, Predicted=866.0439, Expected=858.0000
# Month=57, Predicted=844.7726, Expected=817.0000
# Month=58, Predicted=787.0439, Expected=827.0000
# Month=59, Predicted=835.9644, Expected=797.0000
# Month=60, Predicted=806.8215, Expected=843.0000
# Run 3 — RMSE: 54.051551, MSE: 2921.570153, NMSE: 0.0110358332, Time: 40.6s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=771.1188, Expected=804.0000
# Month=2, Predicted=774.9322, Expected=756.0000
# Month=3, Predicted=719.0310, Expected=860.0000
# Month=4, Predicted=879.0783, Expected=878.0000
# Month=5, Predicted=878.5919, Expected=942.0000
# Month=6, Predicted=911.8797, Expected=913.0000
# Month=7, Predicted=931.5482, Expected=869.0000
# Month=8, Predicted=839.7627, Expected=834.0000
# Month=9, Predicted=844.8651, Expected=790.0000
# Month=10, Predicted=760.7627, Expected=800.0000
# Month=11, Predicted=773.2017, Expected=763.0000
# Month=12, Predicted=765.7308, Expected=800.0000
# Month=13, Predicted=820.2520, Expected=826.0000
# Month=14, Predicted=847.2418, Expected=799.0000
# Month=15, Predicted=818.4797, Expected=890.0000
# Month=16, Predicted=908.8905, Expected=900.0000
# Month=17, Predicted=873.2017, Expected=961.0000
# Month=18, Predicted=930.0255, Expected=935.0000
# Month=19, Predicted=954.8259, Expected=894.0000
# Month=20, Predicted=873.2578, Expected=855.0000
# Month=21, Predicted=845.5270, Expected=809.0000
# Month=22, Predicted=775.5792, Expected=810.0000
# Month=23, Predicted=780.3148, Expected=766.0000
# Month=24, Predicted=736.7627, Expected=805.0000
# Month=25, Predicted=825.1629, Expected=821.0000
# Month=26, Predicted=809.2826, Expected=773.0000
# Month=27, Predicted=736.0310, Expected=883.0000
# Month=28, Predicted=902.1219, Expected=898.0000
# Month=29, Predicted=881.5343, Expected=957.0000
# Month=30, Predicted=925.9267, Expected=924.0000
# Month=31, Predicted=938.9588, Expected=881.0000
# Month=32, Predicted=854.0025, Expected=837.0000
# Month=33, Predicted=807.7627, Expected=784.0000
# Month=34, Predicted=741.7980, Expected=791.0000
# Month=35, Predicted=762.4984, Expected=760.0000
# Month=36, Predicted=777.1782, Expected=802.0000
# Month=37, Predicted=821.9835, Expected=828.0000
# Month=38, Predicted=849.2418, Expected=778.0000
# Month=39, Predicted=738.3348, Expected=889.0000
# Month=40, Predicted=908.1281, Expected=902.0000
# Month=41, Predicted=879.3519, Expected=969.0000
# Month=42, Predicted=940.5860, Expected=947.0000
# Month=43, Predicted=966.2423, Expected=908.0000
# Month=44, Predicted=898.5270, Expected=867.0000
# Month=45, Predicted=846.2578, Expected=815.0000
# Month=46, Predicted=773.4689, Expected=812.0000
# Month=47, Predicted=782.3449, Expected=773.0000
# Month=48, Predicted=763.5270, Expected=813.0000
# Month=49, Predicted=833.1188, Expected=834.0000
# Month=50, Predicted=850.2630, Expected=782.0000
# Month=51, Predicted=740.4689, Expected=892.0000
# Month=52, Predicted=911.1219, Expected=903.0000
# Month=53, Predicted=877.1706, Expected=966.0000
# Month=54, Predicted=935.5128, Expected=937.0000
# Month=55, Predicted=955.5482, Expected=896.0000
# Month=56, Predicted=875.2578, Expected=858.0000
# Month=57, Predicted=854.8974, Expected=817.0000
# Month=58, Predicted=796.2578, Expected=827.0000
# Month=59, Predicted=800.2017, Expected=797.0000
# Month=60, Predicted=814.9353, Expected=843.0000
# Run 4 — RMSE: 55.622122, MSE: 3093.820415, NMSE: 0.0114218289, Time: 41.9s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=769.4781, Expected=804.0000
# Month=2, Predicted=773.2881, Expected=756.0000
# Month=3, Predicted=712.2863, Expected=860.0000
# Month=4, Predicted=877.6811, Expected=878.0000
# Month=5, Predicted=884.5509, Expected=942.0000
# Month=6, Predicted=910.6616, Expected=913.0000
# Month=7, Predicted=927.7646, Expected=869.0000
# Month=8, Predicted=831.9667, Expected=834.0000
# Month=9, Predicted=835.0194, Expected=790.0000
# Month=10, Predicted=752.9667, Expected=800.0000
# Month=11, Predicted=773.7145, Expected=763.0000
# Month=12, Predicted=741.4753, Expected=800.0000
# Month=13, Predicted=818.9429, Expected=826.0000
# Month=14, Predicted=843.5366, Expected=799.0000
# Month=15, Predicted=814.0415, Expected=890.0000
# Month=16, Predicted=907.4505, Expected=900.0000
# Month=17, Predicted=873.7145, Expected=961.0000
# Month=18, Predicted=928.2654, Expected=935.0000
# Month=19, Predicted=949.9588, Expected=894.0000
# Month=20, Predicted=861.4531, Expected=855.0000
# Month=21, Predicted=824.9779, Expected=809.0000
# Month=22, Predicted=768.8938, Expected=810.0000
# Month=23, Predicted=780.4855, Expected=766.0000
# Month=24, Predicted=728.9667, Expected=805.0000
# Month=25, Predicted=823.7024, Expected=821.0000
# Month=26, Predicted=818.4353, Expected=773.0000
# Month=27, Predicted=729.2863, Expected=883.0000
# Month=28, Predicted=900.7457, Expected=898.0000
# Month=29, Predicted=889.7077, Expected=957.0000
# Month=30, Predicted=923.9268, Expected=924.0000
# Month=31, Predicted=934.5485, Expected=881.0000
# Month=32, Predicted=845.4969, Expected=837.0000
# Month=33, Predicted=799.9667, Expected=784.0000
# Month=34, Predicted=735.7068, Expected=791.0000
# Month=35, Predicted=762.4773, Expected=760.0000
# Month=36, Predicted=773.6309, Expected=802.0000
# Month=37, Predicted=819.6498, Expected=828.0000
# Month=38, Predicted=845.5366, Expected=778.0000
# Month=39, Predicted=730.9449, Expected=889.0000
# Month=40, Predicted=906.7550, Expected=902.0000
# Month=41, Predicted=883.2875, Expected=969.0000
# Month=42, Predicted=939.6957, Expected=947.0000
# Month=43, Predicted=960.1329, Expected=908.0000
# Month=44, Predicted=877.9779, Expected=867.0000
# Month=45, Predicted=834.4531, Expected=815.0000
# Month=46, Predicted=766.8182, Expected=812.0000
# Month=47, Predicted=782.7024, Expected=773.0000
# Month=48, Predicted=742.9779, Expected=813.0000
# Month=49, Predicted=831.4781, Expected=834.0000
# Month=50, Predicted=847.5499, Expected=782.0000
# Month=51, Predicted=733.8182, Expected=892.0000
# Month=52, Predicted=909.7457, Expected=903.0000
# Month=53, Predicted=878.3139, Expected=966.0000
# Month=54, Predicted=934.0979, Expected=937.0000
# Month=55, Predicted=951.7646, Expected=896.0000
# Month=56, Predicted=863.4531, Expected=858.0000
# Month=57, Predicted=830.1323, Expected=817.0000
# Month=58, Predicted=784.4531, Expected=827.0000
# Month=59, Predicted=800.7145, Expected=797.0000
# Month=60, Predicted=811.3414, Expected=843.0000
# Run 5 — RMSE: 56.609465, MSE: 3204.631481, NMSE: 0.0110324791, Time: 42.6s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=754.0933, Expected=804.0000
# Month=2, Predicted=800.2935, Expected=756.0000
# Month=3, Predicted=720.3221, Expected=860.0000
# Month=4, Predicted=879.1837, Expected=878.0000
# Month=5, Predicted=880.5864, Expected=942.0000
# Month=6, Predicted=914.2337, Expected=913.0000
# Month=7, Predicted=919.1192, Expected=869.0000
# Month=8, Predicted=838.4368, Expected=834.0000
# Month=9, Predicted=838.2164, Expected=790.0000
# Month=10, Predicted=759.4368, Expected=800.0000
# Month=11, Predicted=802.1549, Expected=763.0000
# Month=12, Predicted=761.8978, Expected=800.0000
# Month=13, Predicted=803.2849, Expected=826.0000
# Month=14, Predicted=829.1159, Expected=799.0000
# Month=15, Predicted=804.9172, Expected=890.0000
# Month=16, Predicted=908.7527, Expected=900.0000
# Month=17, Predicted=902.1549, Expected=961.0000
# Month=18, Predicted=937.0618, Expected=935.0000
# Month=19, Predicted=940.7961, Expected=894.0000
# Month=20, Predicted=869.4002, Expected=855.0000
# Month=21, Predicted=839.3095, Expected=809.0000
# Month=22, Predicted=775.6609, Expected=810.0000
# Month=23, Predicted=812.3420, Expected=766.0000
# Month=24, Predicted=735.4368, Expected=805.0000
# Month=25, Predicted=808.1748, Expected=821.0000
# Month=26, Predicted=823.4506, Expected=773.0000
# Month=27, Predicted=737.3221, Expected=883.0000
# Month=28, Predicted=902.2942, Expected=898.0000
# Month=29, Predicted=900.3872, Expected=957.0000
# Month=30, Predicted=936.6870, Expected=924.0000
# Month=31, Predicted=929.8086, Expected=881.0000
# Month=32, Predicted=852.0850, Expected=837.0000
# Month=33, Predicted=806.4368, Expected=784.0000
# Month=34, Predicted=743.8401, Expected=791.0000
# Month=35, Predicted=793.1167, Expected=760.0000
# Month=36, Predicted=766.1783, Expected=802.0000
# Month=37, Predicted=804.8628, Expected=828.0000
# Month=38, Predicted=831.1159, Expected=778.0000
# Month=39, Predicted=740.2934, Expected=889.0000
# Month=40, Predicted=908.3100, Expected=902.0000
# Month=41, Predicted=904.2743, Expected=969.0000
# Month=42, Predicted=938.9158, Expected=947.0000
# Month=43, Predicted=952.2734, Expected=908.0000
# Month=44, Predicted=892.3095, Expected=867.0000
# Month=45, Predicted=842.4002, Expected=815.0000
# Month=46, Predicted=775.5710, Expected=812.0000
# Month=47, Predicted=814.7099, Expected=773.0000
# Month=48, Predicted=757.3095, Expected=813.0000
# Month=49, Predicted=816.0933, Expected=834.0000
# Month=50, Predicted=836.7980, Expected=782.0000
# Month=51, Predicted=742.5710, Expected=892.0000
# Month=52, Predicted=911.2942, Expected=903.0000
# Month=53, Predicted=905.1868, Expected=966.0000
# Month=54, Predicted=939.3236, Expected=937.0000
# Month=55, Predicted=943.1192, Expected=896.0000
# Month=56, Predicted=871.4002, Expected=858.0000
# Month=57, Predicted=850.5898, Expected=817.0000
# Month=58, Predicted=792.4002, Expected=827.0000
# Month=59, Predicted=829.1549, Expected=797.0000
# Month=60, Predicted=803.1777, Expected=843.0000
# Run 6 — RMSE: 53.541104, MSE: 2866.649819, NMSE: 0.0109338274, Time: 45.8s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=737.9824, Expected=804.0000
# Month=2, Predicted=781.2411, Expected=756.0000
# Month=3, Predicted=752.7815, Expected=860.0000
# Month=4, Predicted=879.4873, Expected=878.0000
# Month=5, Predicted=868.8711, Expected=942.0000
# Month=6, Predicted=906.0783, Expected=913.0000
# Month=7, Predicted=908.1026, Expected=869.0000
# Month=8, Predicted=865.7232, Expected=834.0000
# Month=9, Predicted=829.6420, Expected=790.0000
# Month=10, Predicted=786.7232, Expected=800.0000
# Month=11, Predicted=791.6813, Expected=763.0000
# Month=12, Predicted=758.8418, Expected=800.0000
# Month=13, Predicted=787.9160, Expected=826.0000
# Month=14, Predicted=815.9443, Expected=799.0000
# Month=15, Predicted=793.9350, Expected=890.0000
# Month=16, Predicted=908.7099, Expected=900.0000
# Month=17, Predicted=891.6813, Expected=961.0000
# Month=18, Predicted=927.6963, Expected=935.0000
# Month=19, Predicted=929.8526, Expected=894.0000
# Month=20, Predicted=890.2997, Expected=855.0000
# Month=21, Predicted=851.0584, Expected=809.0000
# Month=22, Predicted=805.9818, Expected=810.0000
# Month=23, Predicted=802.5496, Expected=766.0000
# Month=24, Predicted=762.7232, Expected=805.0000
# Month=25, Predicted=792.3234, Expected=821.0000
# Month=26, Predicted=812.0793, Expected=773.0000
# Month=27, Predicted=769.7815, Expected=883.0000
# Month=28, Predicted=902.5269, Expected=898.0000
# Month=29, Predicted=889.1816, Expected=957.0000
# Month=30, Predicted=926.0686, Expected=924.0000
# Month=31, Predicted=919.4542, Expected=881.0000
# Month=32, Predicted=877.5747, Expected=837.0000
# Month=33, Predicted=833.7232, Expected=784.0000
# Month=34, Predicted=745.5555, Expected=791.0000
# Month=35, Predicted=782.9747, Expected=760.0000
# Month=36, Predicted=755.2751, Expected=802.0000
# Month=37, Predicted=788.1894, Expected=828.0000
# Month=38, Predicted=817.9443, Expected=778.0000
# Month=39, Predicted=771.2117, Expected=889.0000
# Month=40, Predicted=908.5223, Expected=902.0000
# Month=41, Predicted=893.3835, Expected=969.0000
# Month=42, Predicted=931.7582, Expected=947.0000
# Month=43, Predicted=941.5283, Expected=908.0000
# Month=44, Predicted=904.0584, Expected=867.0000
# Month=45, Predicted=863.2997, Expected=815.0000
# Month=46, Predicted=782.8501, Expected=812.0000
# Month=47, Predicted=804.9214, Expected=773.0000
# Month=48, Predicted=769.0584, Expected=813.0000
# Month=49, Predicted=799.9824, Expected=834.0000
# Month=50, Predicted=824.5459, Expected=782.0000
# Month=51, Predicted=749.8501, Expected=892.0000
# Month=52, Predicted=911.5269, Expected=903.0000
# Month=53, Predicted=894.5826, Expected=966.0000
# Month=54, Predicted=930.8128, Expected=937.0000
# Month=55, Predicted=932.1026, Expected=896.0000
# Month=56, Predicted=892.2997, Expected=858.0000
# Month=57, Predicted=853.9476, Expected=817.0000
# Month=58, Predicted=813.2997, Expected=827.0000
# Month=59, Predicted=818.6813, Expected=797.0000
# Month=60, Predicted=792.1882, Expected=843.0000
# Run 7 — RMSE: 49.890184, MSE: 2489.030448, NMSE: 0.0108549447, Time: 44.9s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=746.2767, Expected=804.0000
# Month=2, Predicted=791.9651, Expected=756.0000
# Month=3, Predicted=708.8915, Expected=860.0000
# Month=4, Predicted=883.1926, Expected=878.0000
# Month=5, Predicted=875.0139, Expected=942.0000
# Month=6, Predicted=908.1474, Expected=913.0000
# Month=7, Predicted=909.3238, Expected=869.0000
# Month=8, Predicted=845.5774, Expected=834.0000
# Month=9, Predicted=827.2464, Expected=790.0000
# Month=10, Predicted=766.5774, Expected=800.0000
# Month=11, Predicted=797.2854, Expected=763.0000
# Month=12, Predicted=754.4418, Expected=800.0000
# Month=13, Predicted=795.8595, Expected=826.0000
# Month=14, Predicted=822.7938, Expected=799.0000
# Month=15, Predicted=795.9127, Expected=890.0000
# Month=16, Predicted=910.1940, Expected=900.0000
# Month=17, Predicted=897.2854, Expected=961.0000
# Month=18, Predicted=933.1798, Expected=935.0000
# Month=19, Predicted=932.1545, Expected=894.0000
# Month=20, Predicted=879.2983, Expected=855.0000
# Month=21, Predicted=843.9051, Expected=809.0000
# Month=22, Predicted=773.1601, Expected=810.0000
# Month=23, Predicted=807.7767, Expected=766.0000
# Month=24, Predicted=742.5774, Expected=805.0000
# Month=25, Predicted=800.4950, Expected=821.0000
# Month=26, Predicted=818.0681, Expected=773.0000
# Month=27, Predicted=725.8915, Expected=883.0000
# Month=28, Predicted=906.8001, Expected=898.0000
# Month=29, Predicted=895.0980, Expected=957.0000
# Month=30, Predicted=934.3640, Expected=924.0000
# Month=31, Predicted=918.5672, Expected=881.0000
# Month=32, Predicted=861.1529, Expected=837.0000
# Month=33, Predicted=813.5774, Expected=784.0000
# Month=34, Predicted=736.2151, Expected=791.0000
# Month=35, Predicted=788.4310, Expected=760.0000
# Month=36, Predicted=755.5615, Expected=802.0000
# Month=37, Predicted=796.7532, Expected=828.0000
# Month=38, Predicted=824.7938, Expected=778.0000
# Month=39, Predicted=729.4169, Expected=889.0000
# Month=40, Predicted=912.8734, Expected=902.0000
# Month=41, Predicted=899.1648, Expected=969.0000
# Month=42, Predicted=935.2566, Expected=947.0000
# Month=43, Predicted=944.8488, Expected=908.0000
# Month=44, Predicted=896.9051, Expected=867.0000
# Month=45, Predicted=852.2983, Expected=815.0000
# Month=46, Predicted=766.8401, Expected=812.0000
# Month=47, Predicted=810.0128, Expected=773.0000
# Month=48, Predicted=761.9051, Expected=813.0000
# Month=49, Predicted=808.2767, Expected=834.0000
# Month=50, Predicted=830.9397, Expected=782.0000
# Month=51, Predicted=733.8401, Expected=892.0000
# Month=52, Predicted=915.8001, Expected=903.0000
# Month=53, Predicted=900.2423, Expected=966.0000
# Month=54, Predicted=933.6019, Expected=937.0000
# Month=55, Predicted=933.3238, Expected=896.0000
# Month=56, Predicted=881.2983, Expected=858.0000
# Month=57, Predicted=848.2844, Expected=817.0000
# Month=58, Predicted=802.2983, Expected=827.0000
# Month=59, Predicted=824.2854, Expected=797.0000
# Month=60, Predicted=792.9674, Expected=843.0000
# Run 8 — RMSE: 55.831507, MSE: 3117.157153, NMSE: 0.0113494119, Time: 47.9s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=750.2484, Expected=804.0000
# Month=2, Predicted=793.7517, Expected=756.0000
# Month=3, Predicted=729.2148, Expected=860.0000
# Month=4, Predicted=875.7768, Expected=878.0000
# Month=5, Predicted=877.1540, Expected=942.0000
# Month=6, Predicted=910.6771, Expected=913.0000
# Month=7, Predicted=910.6881, Expected=869.0000
# Month=8, Predicted=854.4173, Expected=834.0000
# Month=9, Predicted=830.0432, Expected=790.0000
# Month=10, Predicted=775.4173, Expected=800.0000
# Month=11, Predicted=799.0644, Expected=763.0000
# Month=12, Predicted=757.9673, Expected=800.0000
# Month=13, Predicted=799.3316, Expected=826.0000
# Month=14, Predicted=825.2580, Expected=799.0000
# Month=15, Predicted=796.9623, Expected=890.0000
# Month=16, Predicted=905.1353, Expected=900.0000
# Month=17, Predicted=899.0644, Expected=961.0000
# Month=18, Predicted=929.7627, Expected=935.0000
# Month=19, Predicted=933.0717, Expected=894.0000
# Month=20, Predicted=885.0825, Expected=855.0000
# Month=21, Predicted=848.3965, Expected=809.0000
# Month=22, Predicted=788.7500, Expected=810.0000
# Month=23, Predicted=808.9636, Expected=766.0000
# Month=24, Predicted=751.4173, Expected=805.0000
# Month=25, Predicted=804.2878, Expected=821.0000
# Month=26, Predicted=820.1305, Expected=773.0000
# Month=27, Predicted=746.2148, Expected=883.0000
# Month=28, Predicted=899.0029, Expected=898.0000
# Month=29, Predicted=897.1191, Expected=957.0000
# Month=30, Predicted=926.2351, Expected=924.0000
# Month=31, Predicted=920.7886, Expected=881.0000
# Month=32, Predicted=868.6665, Expected=837.0000
# Month=33, Predicted=822.4173, Expected=784.0000
# Month=34, Predicted=745.5804, Expected=791.0000
# Month=35, Predicted=790.0321, Expected=760.0000
# Month=36, Predicted=757.3128, Expected=802.0000
# Month=37, Predicted=801.1158, Expected=828.0000
# Month=38, Predicted=827.2580, Expected=778.0000
# Month=39, Predicted=745.4401, Expected=889.0000
# Month=40, Predicted=905.0361, Expected=902.0000
# Month=41, Predicted=901.0969, Expected=969.0000
# Month=42, Predicted=937.8630, Expected=947.0000
# Month=43, Predicted=945.3859, Expected=908.0000
# Month=44, Predicted=901.3965, Expected=867.0000
# Month=45, Predicted=858.0825, Expected=815.0000
# Month=46, Predicted=778.2119, Expected=812.0000
# Month=47, Predicted=810.9116, Expected=773.0000
# Month=48, Predicted=766.3965, Expected=813.0000
# Month=49, Predicted=812.2484, Expected=834.0000
# Month=50, Predicted=833.1912, Expected=782.0000
# Month=51, Predicted=745.2119, Expected=892.0000
# Month=52, Predicted=908.0029, Expected=903.0000
# Month=53, Predicted=902.0752, Expected=966.0000
# Month=54, Predicted=934.6792, Expected=937.0000
# Month=55, Predicted=934.6881, Expected=896.0000
# Month=56, Predicted=887.0825, Expected=858.0000
# Month=57, Predicted=852.2569, Expected=817.0000
# Month=58, Predicted=808.0825, Expected=827.0000
# Month=59, Predicted=826.0644, Expected=797.0000
# Month=60, Predicted=794.5156, Expected=843.0000
# Run 9 — RMSE: 52.207156, MSE: 2725.587140, NMSE: 0.0113092887, Time: 56.0s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=737.0391, Expected=804.0000
# Month=2, Predicted=790.0067, Expected=756.0000
# Month=3, Predicted=720.4959, Expected=860.0000
# Month=4, Predicted=879.5036, Expected=878.0000
# Month=5, Predicted=864.6093, Expected=942.0000
# Month=6, Predicted=928.4352, Expected=913.0000
# Month=7, Predicted=902.6519, Expected=869.0000
# Month=8, Predicted=841.1143, Expected=834.0000
# Month=9, Predicted=823.8644, Expected=790.0000
# Month=10, Predicted=762.1143, Expected=800.0000
# Month=11, Predicted=786.9286, Expected=763.0000
# Month=12, Predicted=751.8872, Expected=800.0000
# Month=13, Predicted=786.0845, Expected=826.0000
# Month=14, Predicted=812.3425, Expected=799.0000
# Month=15, Predicted=788.3777, Expected=890.0000
# Month=16, Predicted=909.6285, Expected=900.0000
# Month=17, Predicted=886.9286, Expected=961.0000
# Month=18, Predicted=947.2303, Expected=935.0000
# Month=19, Predicted=924.2444, Expected=894.0000
# Month=20, Predicted=874.4919, Expected=855.0000
# Month=21, Predicted=841.0461, Expected=809.0000
# Month=22, Predicted=777.0530, Expected=810.0000
# Month=23, Predicted=797.3318, Expected=766.0000
# Month=24, Predicted=738.1143, Expected=805.0000
# Month=25, Predicted=791.0530, Expected=821.0000
# Month=26, Predicted=807.6848, Expected=773.0000
# Month=27, Predicted=737.4959, Expected=883.0000
# Month=28, Predicted=902.4778, Expected=898.0000
# Month=29, Predicted=884.7237, Expected=957.0000
# Month=30, Predicted=943.1420, Expected=924.0000
# Month=31, Predicted=914.0402, Expected=881.0000
# Month=32, Predicted=855.5369, Expected=837.0000
# Month=33, Predicted=809.1143, Expected=784.0000
# Month=34, Predicted=741.3878, Expected=791.0000
# Month=35, Predicted=778.0587, Expected=760.0000
# Month=36, Predicted=749.9020, Expected=802.0000
# Month=37, Predicted=788.0156, Expected=828.0000
# Month=38, Predicted=814.3425, Expected=778.0000
# Month=39, Predicted=739.2438, Expected=889.0000
# Month=40, Predicted=908.4768, Expected=902.0000
# Month=41, Predicted=888.8037, Expected=969.0000
# Month=42, Predicted=955.7918, Expected=947.0000
# Month=43, Predicted=935.7757, Expected=908.0000
# Month=44, Predicted=894.0461, Expected=867.0000
# Month=45, Predicted=847.4919, Expected=815.0000
# Month=46, Predicted=773.4780, Expected=812.0000
# Month=47, Predicted=799.5230, Expected=773.0000
# Month=48, Predicted=759.0461, Expected=813.0000
# Month=49, Predicted=799.0391, Expected=834.0000
# Month=50, Predicted=820.5023, Expected=782.0000
# Month=51, Predicted=740.4780, Expected=892.0000
# Month=52, Predicted=911.4778, Expected=903.0000
# Month=53, Predicted=889.8863, Expected=966.0000
# Month=54, Predicted=952.3546, Expected=937.0000
# Month=55, Predicted=926.6519, Expected=896.0000
# Month=56, Predicted=876.4919, Expected=858.0000
# Month=57, Predicted=845.7897, Expected=817.0000
# Month=58, Predicted=797.4919, Expected=827.0000
# Month=59, Predicted=813.9286, Expected=797.0000
# Month=60, Predicted=786.7838, Expected=843.0000
# Run 10 — RMSE: 54.600032, MSE: 2981.163456, NMSE: 0.0104516483, Time: 58.9s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=759.0320, Expected=804.0000
# Month=2, Predicted=783.6402, Expected=756.0000
# Month=3, Predicted=720.4502, Expected=860.0000
# Month=4, Predicted=877.3051, Expected=878.0000
# Month=5, Predicted=887.7936, Expected=942.0000
# Month=6, Predicted=913.5725, Expected=913.0000
# Month=7, Predicted=918.8125, Expected=869.0000
# Month=8, Predicted=846.0653, Expected=834.0000
# Month=9, Predicted=835.1913, Expected=790.0000
# Month=10, Predicted=767.0653, Expected=800.0000
# Month=11, Predicted=809.0390, Expected=763.0000
# Month=12, Predicted=761.1469, Expected=800.0000
# Month=13, Predicted=809.1934, Expected=826.0000
# Month=14, Predicted=836.2542, Expected=799.0000
# Month=15, Predicted=805.5657, Expected=890.0000
# Month=16, Predicted=907.2434, Expected=900.0000
# Month=17, Predicted=909.0390, Expected=961.0000
# Month=18, Predicted=931.8930, Expected=935.0000
# Month=19, Predicted=941.8609, Expected=894.0000
# Month=20, Predicted=881.8807, Expected=855.0000
# Month=21, Predicted=848.7874, Expected=809.0000
# Month=22, Predicted=779.1140, Expected=810.0000
# Month=23, Predicted=818.4352, Expected=766.0000
# Month=24, Predicted=743.0653, Expected=805.0000
# Month=25, Predicted=813.4994, Expected=821.0000
# Month=26, Predicted=830.6122, Expected=773.0000
# Month=27, Predicted=737.4502, Expected=883.0000
# Month=28, Predicted=900.3295, Expected=898.0000
# Month=29, Predicted=907.5171, Expected=957.0000
# Month=30, Predicted=928.2759, Expected=924.0000
# Month=31, Predicted=927.2958, Expected=881.0000
# Month=32, Predicted=861.7662, Expected=837.0000
# Month=33, Predicted=814.0653, Expected=784.0000
# Month=34, Predicted=741.0385, Expected=791.0000
# Month=35, Predicted=799.7847, Expected=760.0000
# Month=36, Predicted=764.7670, Expected=802.0000
# Month=37, Predicted=808.7460, Expected=828.0000
# Month=38, Predicted=838.2542, Expected=778.0000
# Month=39, Predicted=738.3713, Expected=889.0000
# Month=40, Predicted=906.3334, Expected=902.0000
# Month=41, Predicted=911.3234, Expected=969.0000
# Month=42, Predicted=944.1275, Expected=947.0000
# Month=43, Predicted=954.6629, Expected=908.0000
# Month=44, Predicted=901.7874, Expected=867.0000
# Month=45, Predicted=854.8807, Expected=815.0000
# Month=46, Predicted=772.7981, Expected=812.0000
# Month=47, Predicted=820.3323, Expected=773.0000
# Month=48, Predicted=766.7874, Expected=813.0000
# Month=49, Predicted=821.0320, Expected=834.0000
# Month=50, Predicted=844.0286, Expected=782.0000
# Month=51, Predicted=739.7981, Expected=892.0000
# Month=52, Predicted=909.3295, Expected=903.0000
# Month=53, Predicted=912.1316, Expected=966.0000
# Month=54, Predicted=937.1713, Expected=937.0000
# Month=55, Predicted=942.8125, Expected=896.0000
# Month=56, Predicted=883.8807, Expected=858.0000
# Month=57, Predicted=854.1538, Expected=817.0000
# Month=58, Predicted=804.8807, Expected=827.0000
# Month=59, Predicted=836.0390, Expected=797.0000
# Month=60, Predicted=802.3332, Expected=843.0000
# Run 11 — RMSE: 53.759375, MSE: 2890.070374, NMSE: 0.0112536197, Time: 53.2s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=733.3743, Expected=804.0000
# Month=2, Predicted=787.0154, Expected=756.0000
# Month=3, Predicted=712.5087, Expected=860.0000
# Month=4, Predicted=879.2374, Expected=878.0000
# Month=5, Predicted=860.6351, Expected=942.0000
# Month=6, Predicted=927.5801, Expected=913.0000
# Month=7, Predicted=920.7257, Expected=869.0000
# Month=8, Predicted=836.8776, Expected=834.0000
# Month=9, Predicted=836.2058, Expected=790.0000
# Month=10, Predicted=757.8776, Expected=800.0000
# Month=11, Predicted=783.0746, Expected=763.0000
# Month=12, Predicted=760.2659, Expected=800.0000
# Month=13, Predicted=782.3714, Expected=826.0000
# Month=14, Predicted=808.4776, Expected=799.0000
# Month=15, Predicted=806.6264, Expected=890.0000
# Month=16, Predicted=898.3398, Expected=900.0000
# Month=17, Predicted=883.0746, Expected=961.0000
# Month=18, Predicted=945.5825, Expected=935.0000
# Month=19, Predicted=942.3256, Expected=894.0000
# Month=20, Predicted=875.3915, Expected=855.0000
# Month=21, Predicted=845.1544, Expected=809.0000
# Month=22, Predicted=769.9260, Expected=810.0000
# Month=23, Predicted=794.7590, Expected=766.0000
# Month=24, Predicted=733.8776, Expected=805.0000
# Month=25, Predicted=787.3704, Expected=821.0000
# Month=26, Predicted=803.7029, Expected=773.0000
# Month=27, Predicted=729.5087, Expected=883.0000
# Month=28, Predicted=905.5855, Expected=898.0000
# Month=29, Predicted=880.7446, Expected=957.0000
# Month=30, Predicted=941.0576, Expected=924.0000
# Month=31, Predicted=929.3025, Expected=881.0000
# Month=32, Predicted=853.1850, Expected=837.0000
# Month=33, Predicted=804.8776, Expected=784.0000
# Month=34, Predicted=736.1876, Expected=791.0000
# Month=35, Predicted=774.4248, Expected=760.0000
# Month=36, Predicted=767.0265, Expected=802.0000
# Month=37, Predicted=784.3934, Expected=828.0000
# Month=38, Predicted=810.4776, Expected=778.0000
# Month=39, Predicted=731.9844, Expected=889.0000
# Month=40, Predicted=912.0627, Expected=902.0000
# Month=41, Predicted=884.8485, Expected=969.0000
# Month=42, Predicted=955.8699, Expected=947.0000
# Month=43, Predicted=951.7684, Expected=908.0000
# Month=44, Predicted=898.1544, Expected=867.0000
# Month=45, Predicted=848.3915, Expected=815.0000
# Month=46, Predicted=767.6090, Expected=812.0000
# Month=47, Predicted=798.4093, Expected=773.0000
# Month=48, Predicted=763.1544, Expected=813.0000
# Month=49, Predicted=795.3743, Expected=834.0000
# Month=50, Predicted=816.5610, Expected=782.0000
# Month=51, Predicted=734.6090, Expected=892.0000
# Month=52, Predicted=914.5855, Expected=903.0000
# Month=53, Predicted=885.9879, Expected=966.0000
# Month=54, Predicted=951.2173, Expected=937.0000
# Month=55, Predicted=944.7257, Expected=896.0000
# Month=56, Predicted=877.3915, Expected=858.0000
# Month=57, Predicted=851.9771, Expected=817.0000
# Month=58, Predicted=798.3915, Expected=827.0000
# Month=59, Predicted=810.0746, Expected=797.0000
# Month=60, Predicted=804.4877, Expected=843.0000
# Run 12 — RMSE: 56.814578, MSE: 3227.896315, NMSE: 0.0105779068, Time: 53.1s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=765.4392, Expected=804.0000
# Month=2, Predicted=797.3982, Expected=756.0000
# Month=3, Predicted=716.7103, Expected=860.0000
# Month=4, Predicted=877.5214, Expected=878.0000
# Month=5, Predicted=862.5695, Expected=942.0000
# Month=6, Predicted=917.1866, Expected=913.0000
# Month=7, Predicted=920.4951, Expected=869.0000
# Month=8, Predicted=832.1367, Expected=834.0000
# Month=9, Predicted=824.0239, Expected=790.0000
# Month=10, Predicted=753.1367, Expected=800.0000
# Month=11, Predicted=780.5283, Expected=763.0000
# Month=12, Predicted=743.0722, Expected=800.0000
# Month=13, Predicted=813.7178, Expected=826.0000
# Month=14, Predicted=823.9350, Expected=799.0000
# Month=15, Predicted=807.9343, Expected=890.0000
# Month=16, Predicted=906.9812, Expected=900.0000
# Month=17, Predicted=880.5283, Expected=961.0000
# Month=18, Predicted=936.2926, Expected=935.0000
# Month=19, Predicted=944.2130, Expected=894.0000
# Month=20, Predicted=861.4525, Expected=855.0000
# Month=21, Predicted=827.4833, Expected=809.0000
# Month=22, Predicted=770.6141, Expected=810.0000
# Month=23, Predicted=791.4148, Expected=766.0000
# Month=24, Predicted=729.1367, Expected=805.0000
# Month=25, Predicted=819.3091, Expected=821.0000
# Month=26, Predicted=803.9300, Expected=773.0000
# Month=27, Predicted=733.7103, Expected=883.0000
# Month=28, Predicted=900.6118, Expected=898.0000
# Month=29, Predicted=880.3016, Expected=957.0000
# Month=30, Predicted=932.8030, Expected=924.0000
# Month=31, Predicted=922.8273, Expected=881.0000
# Month=32, Predicted=845.2436, Expected=837.0000
# Month=33, Predicted=800.1367, Expected=784.0000
# Month=34, Predicted=743.7553, Expected=791.0000
# Month=35, Predicted=771.2799, Expected=760.0000
# Month=36, Predicted=764.4191, Expected=802.0000
# Month=37, Predicted=816.4103, Expected=828.0000
# Month=38, Predicted=825.9350, Expected=778.0000
# Month=39, Predicted=738.1766, Expected=889.0000
# Month=40, Predicted=906.6245, Expected=902.0000
# Month=41, Predicted=883.3511, Expected=969.0000
# Month=42, Predicted=944.3681, Expected=947.0000
# Month=43, Predicted=955.1718, Expected=908.0000
# Month=44, Predicted=880.4833, Expected=867.0000
# Month=45, Predicted=834.4525, Expected=815.0000
# Month=46, Predicted=774.8611, Expected=812.0000
# Month=47, Predicted=795.6998, Expected=773.0000
# Month=48, Predicted=745.4833, Expected=813.0000
# Month=49, Predicted=827.4392, Expected=834.0000
# Month=50, Predicted=822.2474, Expected=782.0000
# Month=51, Predicted=741.8611, Expected=892.0000
# Month=52, Predicted=909.6118, Expected=903.0000
# Month=53, Predicted=883.7329, Expected=966.0000
# Month=54, Predicted=941.1759, Expected=937.0000
# Month=55, Predicted=944.4951, Expected=896.0000
# Month=56, Predicted=863.4525, Expected=858.0000
# Month=57, Predicted=833.9099, Expected=817.0000
# Month=58, Predicted=784.4525, Expected=827.0000
# Month=59, Predicted=807.5283, Expected=797.0000
# Month=60, Predicted=803.2078, Expected=843.0000
# Run 13 — RMSE: 54.552486, MSE: 2975.973759, NMSE: 0.0107413125, Time: 51.8s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=755.8767, Expected=804.0000
# Month=2, Predicted=804.3308, Expected=756.0000
# Month=3, Predicted=717.8173, Expected=860.0000
# Month=4, Predicted=878.7930, Expected=878.0000
# Month=5, Predicted=882.3505, Expected=942.0000
# Month=6, Predicted=913.5412, Expected=913.0000
# Month=7, Predicted=915.6907, Expected=869.0000
# Month=8, Predicted=834.5527, Expected=834.0000
# Month=9, Predicted=836.3007, Expected=790.0000
# Month=10, Predicted=755.5527, Expected=800.0000
# Month=11, Predicted=803.7961, Expected=763.0000
# Month=12, Predicted=764.7121, Expected=800.0000
# Month=13, Predicted=805.0297, Expected=826.0000
# Month=14, Predicted=830.8557, Expected=799.0000
# Month=15, Predicted=801.8067, Expected=890.0000
# Month=16, Predicted=908.2178, Expected=900.0000
# Month=17, Predicted=903.7961, Expected=961.0000
# Month=18, Predicted=935.0304, Expected=935.0000
# Month=19, Predicted=937.8577, Expected=894.0000
# Month=20, Predicted=863.1234, Expected=855.0000
# Month=21, Predicted=841.4612, Expected=809.0000
# Month=22, Predicted=772.4860, Expected=810.0000
# Month=23, Predicted=813.3646, Expected=766.0000
# Month=24, Predicted=731.5527, Expected=805.0000
# Month=25, Predicted=809.9416, Expected=821.0000
# Month=26, Predicted=825.2075, Expected=773.0000
# Month=27, Predicted=734.8173, Expected=883.0000
# Month=28, Predicted=901.9530, Expected=898.0000
# Month=29, Predicted=902.1360, Expected=957.0000
# Month=30, Predicted=938.0859, Expected=924.0000
# Month=31, Predicted=926.4350, Expected=881.0000
# Month=32, Predicted=847.7072, Expected=837.0000
# Month=33, Predicted=802.5527, Expected=784.0000
# Month=34, Predicted=742.8056, Expected=791.0000
# Month=35, Predicted=794.6203, Expected=760.0000
# Month=36, Predicted=762.5616, Expected=802.0000
# Month=37, Predicted=806.6959, Expected=828.0000
# Month=38, Predicted=832.8557, Expected=778.0000
# Month=39, Predicted=738.4513, Expected=889.0000
# Month=40, Predicted=907.9761, Expected=902.0000
# Month=41, Predicted=905.9952, Expected=969.0000
# Month=42, Predicted=942.6557, Expected=947.0000
# Month=43, Predicted=950.0150, Expected=908.0000
# Month=44, Predicted=894.4612, Expected=867.0000
# Month=45, Predicted=836.1234, Expected=815.0000
# Month=46, Predicted=774.3078, Expected=812.0000
# Month=47, Predicted=815.2679, Expected=773.0000
# Month=48, Predicted=759.4612, Expected=813.0000
# Month=49, Predicted=817.8767, Expected=834.0000
# Month=50, Predicted=838.5582, Expected=782.0000
# Month=51, Predicted=741.3078, Expected=892.0000
# Month=52, Predicted=910.9530, Expected=903.0000
# Month=53, Predicted=906.8603, Expected=966.0000
# Month=54, Predicted=937.6604, Expected=937.0000
# Month=55, Predicted=939.6907, Expected=896.0000
# Month=56, Predicted=865.1234, Expected=858.0000
# Month=57, Predicted=858.0510, Expected=817.0000
# Month=58, Predicted=786.1234, Expected=827.0000
# Month=59, Predicted=830.7961, Expected=797.0000
# Month=60, Predicted=799.6270, Expected=843.0000
# Run 14 — RMSE: 54.034742, MSE: 2919.753391, NMSE: 0.0110453681, Time: 51.8s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=772.2793, Expected=804.0000
# Month=2, Predicted=774.1569, Expected=756.0000
# Month=3, Predicted=714.9690, Expected=860.0000
# Month=4, Predicted=878.4551, Expected=878.0000
# Month=5, Predicted=867.1842, Expected=942.0000
# Month=6, Predicted=911.7619, Expected=913.0000
# Month=7, Predicted=922.1819, Expected=869.0000
# Month=8, Predicted=833.3865, Expected=834.0000
# Month=9, Predicted=819.8670, Expected=790.0000
# Month=10, Predicted=754.3865, Expected=800.0000
# Month=11, Predicted=772.7603, Expected=763.0000
# Month=12, Predicted=738.2411, Expected=800.0000
# Month=13, Predicted=822.9289, Expected=826.0000
# Month=14, Predicted=844.4426, Expected=799.0000
# Month=15, Predicted=809.0827, Expected=890.0000
# Month=16, Predicted=908.0712, Expected=900.0000
# Month=17, Predicted=872.7603, Expected=961.0000
# Month=18, Predicted=929.7074, Expected=935.0000
# Month=19, Predicted=944.8307, Expected=894.0000
# Month=20, Predicted=862.4974, Expected=855.0000
# Month=21, Predicted=826.0961, Expected=809.0000
# Month=22, Predicted=770.5587, Expected=810.0000
# Month=23, Predicted=781.1491, Expected=766.0000
# Month=24, Predicted=730.3865, Expected=805.0000
# Month=25, Predicted=827.0853, Expected=821.0000
# Month=26, Predicted=802.5054, Expected=773.0000
# Month=27, Predicted=731.9690, Expected=883.0000
# Month=28, Predicted=901.5947, Expected=898.0000
# Month=29, Predicted=876.7899, Expected=957.0000
# Month=30, Predicted=925.4634, Expected=924.0000
# Month=31, Predicted=922.1844, Expected=881.0000
# Month=32, Predicted=846.7857, Expected=837.0000
# Month=33, Predicted=801.3865, Expected=784.0000
# Month=34, Predicted=738.8870, Expected=791.0000
# Month=35, Predicted=762.7235, Expected=760.0000
# Month=36, Predicted=765.7416, Expected=802.0000
# Month=37, Predicted=820.0670, Expected=828.0000
# Month=38, Predicted=846.4426, Expected=778.0000
# Month=39, Predicted=734.8978, Expected=889.0000
# Month=40, Predicted=907.6160, Expected=902.0000
# Month=41, Predicted=877.2448, Expected=969.0000
# Month=42, Predicted=940.6261, Expected=947.0000
# Month=43, Predicted=951.5536, Expected=908.0000
# Month=44, Predicted=879.0961, Expected=867.0000
# Month=45, Predicted=835.4974, Expected=815.0000
# Month=46, Predicted=770.4215, Expected=812.0000
# Month=47, Predicted=783.4527, Expected=773.0000
# Month=48, Predicted=744.0961, Expected=813.0000
# Month=49, Predicted=834.2793, Expected=834.0000
# Month=50, Predicted=837.6411, Expected=782.0000
# Month=51, Predicted=737.4215, Expected=892.0000
# Month=52, Predicted=910.5947, Expected=903.0000
# Month=53, Predicted=876.3505, Expected=966.0000
# Month=54, Predicted=935.3220, Expected=937.0000
# Month=55, Predicted=946.1819, Expected=896.0000
# Month=56, Predicted=864.4974, Expected=858.0000
# Month=57, Predicted=830.6368, Expected=817.0000
# Month=58, Predicted=785.4974, Expected=827.0000
# Month=59, Predicted=799.7603, Expected=797.0000
# Month=60, Predicted=804.8574, Expected=843.0000
# Run 15 — RMSE: 55.949246, MSE: 3130.318138, NMSE: 0.0111419011, Time: 45.4s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=751.5066, Expected=804.0000
# Month=2, Predicted=791.5094, Expected=756.0000
# Month=3, Predicted=720.1207, Expected=860.0000
# Month=4, Predicted=875.2003, Expected=878.0000
# Month=5, Predicted=879.4085, Expected=942.0000
# Month=6, Predicted=912.3076, Expected=913.0000
# Month=7, Predicted=913.3693, Expected=869.0000
# Month=8, Predicted=833.7501, Expected=834.0000
# Month=9, Predicted=824.2782, Expected=790.0000
# Month=10, Predicted=754.7501, Expected=800.0000
# Month=11, Predicted=800.7804, Expected=763.0000
# Month=12, Predicted=743.8528, Expected=800.0000
# Month=13, Predicted=801.3273, Expected=826.0000
# Month=14, Predicted=827.9778, Expected=799.0000
# Month=15, Predicted=800.0987, Expected=890.0000
# Month=16, Predicted=905.2464, Expected=900.0000
# Month=17, Predicted=900.7804, Expected=961.0000
# Month=18, Predicted=931.9292, Expected=935.0000
# Month=19, Predicted=936.2927, Expected=894.0000
# Month=20, Predicted=860.7545, Expected=855.0000
# Month=21, Predicted=826.5318, Expected=809.0000
# Month=22, Predicted=773.3916, Expected=810.0000
# Month=23, Predicted=810.4698, Expected=766.0000
# Month=24, Predicted=730.7501, Expected=805.0000
# Month=25, Predicted=805.8267, Expected=821.0000
# Month=26, Predicted=822.2364, Expected=773.0000
# Month=27, Predicted=737.1207, Expected=883.0000
# Month=28, Predicted=898.0654, Expected=898.0000
# Month=29, Predicted=899.1521, Expected=957.0000
# Month=30, Predicted=930.7556, Expected=924.0000
# Month=31, Predicted=919.9305, Expected=881.0000
# Month=32, Predicted=846.0796, Expected=837.0000
# Month=33, Predicted=801.7501, Expected=784.0000
# Month=34, Predicted=747.9275, Expected=791.0000
# Month=35, Predicted=791.6187, Expected=760.0000
# Month=36, Predicted=758.8730, Expected=802.0000
# Month=37, Predicted=801.6973, Expected=828.0000
# Month=38, Predicted=829.9778, Expected=778.0000
# Month=39, Predicted=741.9359, Expected=889.0000
# Month=40, Predicted=904.0413, Expected=902.0000
# Month=41, Predicted=902.9913, Expected=969.0000
# Month=42, Predicted=942.5403, Expected=947.0000
# Month=43, Predicted=948.4842, Expected=908.0000
# Month=44, Predicted=879.5318, Expected=867.0000
# Month=45, Predicted=833.7545, Expected=815.0000
# Month=46, Predicted=778.8917, Expected=812.0000
# Month=47, Predicted=812.4997, Expected=773.0000
# Month=48, Predicted=744.5318, Expected=813.0000
# Month=49, Predicted=813.5066, Expected=834.0000
# Month=50, Predicted=835.6596, Expected=782.0000
# Month=51, Predicted=745.8917, Expected=892.0000
# Month=52, Predicted=907.0654, Expected=903.0000
# Month=53, Predicted=903.8458, Expected=966.0000
# Month=54, Predicted=936.0543, Expected=937.0000
# Month=55, Predicted=937.3693, Expected=896.0000
# Month=56, Predicted=862.7545, Expected=858.0000
# Month=57, Predicted=833.7268, Expected=817.0000
# Month=58, Predicted=783.7545, Expected=827.0000
# Month=59, Predicted=827.7804, Expected=797.0000
# Month=60, Predicted=796.7489, Expected=843.0000
# Run 16 — RMSE: 53.194881, MSE: 2829.695378, NMSE: 0.0106343060, Time: 53.1s
#
# ===== RUN 17/30 =====
# ...
# Month=42, Predicted=936.4865, Expected=947.0000
# Month=43, Predicted=951.6844, Expected=908.0000
# Month=44, Predicted=891.7408, Expected=867.0000
# Month=45, Predicted=842.9275, Expected=815.0000
# Month=46, Predicted=768.2133, Expected=812.0000
# Month=47, Predicted=788.4696, Expected=773.0000
# Month=48, Predicted=756.7408, Expected=813.0000
# Month=49, Predicted=831.2088, Expected=834.0000
# Month=50, Predicted=848.1336, Expected=782.0000
# Month=51, Predicted=735.2133, Expected=892.0000
# Month=52, Predicted=908.5472, Expected=903.0000
# Month=53, Predicted=876.2947, Expected=966.0000
# Month=54, Predicted=934.1757, Expected=937.0000
# Month=55, Predicted=942.8880, Expected=896.0000
# Month=56, Predicted=871.9275, Expected=858.0000
# Month=57, Predicted=846.0693, Expected=817.0000
# Month=58, Predicted=792.9275, Expected=827.0000
# Month=59, Predicted=799.2917, Expected=797.0000
# Month=60, Predicted=802.4310, Expected=843.0000
# Run 25 — RMSE: 56.515289, MSE: 3193.977943, NMSE: 0.0118256811, Time: 50.7s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=762.8430, Expected=804.0000
# Month=2, Predicted=785.2911, Expected=756.0000
# Month=3, Predicted=721.2378, Expected=860.0000
# Month=4, Predicted=873.9613, Expected=878.0000
# Month=5, Predicted=888.1465, Expected=942.0000
# Month=6, Predicted=911.1376, Expected=913.0000
# Month=7, Predicted=919.2452, Expected=869.0000
# Month=8, Predicted=845.3702, Expected=834.0000
# Month=9, Predicted=836.3511, Expected=790.0000
# Month=10, Predicted=766.3702, Expected=800.0000
# Month=11, Predicted=809.3652, Expected=763.0000
# Month=12, Predicted=762.4083, Expected=800.0000
# Month=13, Predicted=811.8566, Expected=826.0000
# Month=14, Predicted=836.9859, Expected=799.0000
# Month=15, Predicted=805.8305, Expected=890.0000
# Month=16, Predicted=904.1462, Expected=900.0000
# Month=17, Predicted=909.3652, Expected=961.0000
# Month=18, Predicted=930.9878, Expected=935.0000
# Month=19, Predicted=942.0599, Expected=894.0000
# Month=20, Predicted=881.8960, Expected=855.0000
# Month=21, Predicted=849.7164, Expected=809.0000
# Month=22, Predicted=779.1182, Expected=810.0000
# Month=23, Predicted=818.7864, Expected=766.0000
# Month=24, Predicted=742.3702, Expected=805.0000
# Month=25, Predicted=816.8818, Expected=821.0000
# Month=26, Predicted=830.9370, Expected=773.0000
# Month=27, Predicted=738.2378, Expected=883.0000
# Month=28, Predicted=896.9274, Expected=898.0000
# Month=29, Predicted=907.8346, Expected=957.0000
# Month=30, Predicted=928.1299, Expected=924.0000
# Month=31, Predicted=928.2053, Expected=881.0000
# Month=32, Predicted=861.0470, Expected=837.0000
# Month=33, Predicted=813.3702, Expected=784.0000
# Month=34, Predicted=741.3805, Expected=791.0000
# Month=35, Predicted=800.1307, Expected=760.0000
# Month=36, Predicted=765.4181, Expected=802.0000
# Month=37, Predicted=813.5619, Expected=828.0000
# Month=38, Predicted=838.9859, Expected=778.0000
# Month=39, Predicted=739.3580, Expected=889.0000
# Month=40, Predicted=902.9231, Expected=902.0000
# Month=41, Predicted=911.6371, Expected=969.0000
# Month=42, Predicted=938.1154, Expected=947.0000
# Month=43, Predicted=954.7027, Expected=908.0000
# Month=44, Predicted=902.7164, Expected=867.0000
# Month=45, Predicted=854.8960, Expected=815.0000
# Month=46, Predicted=773.3930, Expected=812.0000
# Month=47, Predicted=820.6365, Expected=773.0000
# Month=48, Predicted=767.7164, Expected=813.0000
# Month=49, Predicted=824.8430, Expected=834.0000
# Month=50, Predicted=844.4662, Expected=782.0000
# Month=51, Predicted=740.3930, Expected=892.0000
# Month=52, Predicted=905.9274, Expected=903.0000
# Month=53, Predicted=912.4521, Expected=966.0000
# Month=54, Predicted=935.3245, Expected=937.0000
# Month=55, Predicted=943.2452, Expected=896.0000
# Month=56, Predicted=883.8960, Expected=858.0000
# Month=57, Predicted=855.3243, Expected=817.0000
# Month=58, Predicted=804.8960, Expected=827.0000
# Month=59, Predicted=836.3652, Expected=797.0000
# Month=60, Predicted=802.8690, Expected=843.0000
# Run 26 — RMSE: 53.582906, MSE: 2871.127765, NMSE: 0.0114547510, Time: 47.5s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=765.6818, Expected=804.0000
# Month=2, Predicted=774.9568, Expected=756.0000
# Month=3, Predicted=717.4312, Expected=860.0000
# Month=4, Predicted=876.2836, Expected=878.0000
# Month=5, Predicted=858.4662, Expected=942.0000
# Month=6, Predicted=908.8826, Expected=913.0000
# Month=7, Predicted=916.6553, Expected=869.0000
# Month=8, Predicted=835.0233, Expected=834.0000
# Month=9, Predicted=824.3886, Expected=790.0000
# Month=10, Predicted=756.0233, Expected=800.0000
# Month=11, Predicted=772.7960, Expected=763.0000
# Month=12, Predicted=745.7751, Expected=800.0000
# Month=13, Predicted=814.7684, Expected=826.0000
# Month=14, Predicted=831.6938, Expected=799.0000
# Month=15, Predicted=804.1473, Expected=890.0000
# Month=16, Predicted=905.9458, Expected=900.0000
# Month=17, Predicted=872.7960, Expected=961.0000
# Month=18, Predicted=927.2677, Expected=935.0000
# Month=19, Predicted=940.6055, Expected=894.0000
# Month=20, Predicted=865.3500, Expected=855.0000
# Month=21, Predicted=831.2192, Expected=809.0000
# Month=22, Predicted=772.3931, Expected=810.0000
# Month=23, Predicted=783.0102, Expected=766.0000
# Month=24, Predicted=732.0233, Expected=805.0000
# Month=25, Predicted=819.7846, Expected=821.0000
# Month=26, Predicted=798.1237, Expected=773.0000
# Month=27, Predicted=734.4312, Expected=883.0000
# Month=28, Predicted=899.3726, Expected=898.0000
# Month=29, Predicted=873.9491, Expected=957.0000
# Month=30, Predicted=923.4763, Expected=924.0000
# Month=31, Predicted=920.7836, Expected=881.0000
# Month=32, Predicted=848.5940, Expected=837.0000
# Month=33, Predicted=803.0233, Expected=784.0000
# Month=34, Predicted=743.1255, Expected=791.0000
# Month=35, Predicted=763.1353, Expected=760.0000
# Month=36, Predicted=761.0587, Expected=802.0000
# Month=37, Predicted=816.1488, Expected=828.0000
# Month=38, Predicted=833.6938, Expected=778.0000
# Month=39, Predicted=738.1170, Expected=889.0000
# Month=40, Predicted=905.3854, Expected=902.0000
# Month=41, Predicted=876.2634, Expected=969.0000
# Month=42, Predicted=937.7087, Expected=947.0000
# Month=43, Predicted=953.1794, Expected=908.0000
# Month=44, Predicted=884.2192, Expected=867.0000
# Month=45, Predicted=838.3500, Expected=815.0000
# Month=46, Predicted=774.3494, Expected=812.0000
# Month=47, Predicted=788.7516, Expected=773.0000
# Month=48, Predicted=749.2192, Expected=813.0000
# Month=49, Predicted=827.6818, Expected=834.0000
# Month=50, Predicted=822.8968, Expected=782.0000
# Month=51, Predicted=741.3494, Expected=892.0000
# Month=52, Predicted=908.3726, Expected=903.0000
# Month=53, Predicted=876.1788, Expected=966.0000
# Month=54, Predicted=932.5517, Expected=937.0000
# Month=55, Predicted=940.6553, Expected=896.0000
# Month=56, Predicted=867.3500, Expected=858.0000
# Month=57, Predicted=837.2639, Expected=817.0000
# Month=58, Predicted=788.3500, Expected=827.0000
# Month=59, Predicted=799.7960, Expected=797.0000
# Month=60, Predicted=799.5270, Expected=843.0000
# Run 27 — RMSE: 54.956316, MSE: 3020.196614, NMSE: 0.0111536296, Time: 48.2s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=751.3942, Expected=804.0000
# Month=2, Predicted=795.3574, Expected=756.0000
# Month=3, Predicted=736.6789, Expected=860.0000
# Month=4, Predicted=880.7905, Expected=878.0000
# Month=5, Predicted=874.9052, Expected=942.0000
# Month=6, Predicted=903.5445, Expected=913.0000
# Month=7, Predicted=905.0911, Expected=869.0000
# Month=8, Predicted=857.2756, Expected=834.0000
# Month=9, Predicted=825.2472, Expected=790.0000
# Month=10, Predicted=778.2756, Expected=800.0000
# Month=11, Predicted=794.8029, Expected=763.0000
# Month=12, Predicted=753.8379, Expected=800.0000
# Month=13, Predicted=800.7523, Expected=826.0000
# Month=14, Predicted=825.2378, Expected=799.0000
# Month=15, Predicted=791.2759, Expected=890.0000
# Month=16, Predicted=909.0973, Expected=900.0000
# Month=17, Predicted=894.8029, Expected=961.0000
# Month=18, Predicted=932.6621, Expected=935.0000
# Month=19, Predicted=927.3537, Expected=894.0000
# Month=20, Predicted=883.7020, Expected=855.0000
# Month=21, Predicted=845.3356, Expected=809.0000
# Month=22, Predicted=795.3601, Expected=810.0000
# Month=23, Predicted=803.3829, Expected=766.0000
# Month=24, Predicted=754.2756, Expected=805.0000
# Month=25, Predicted=805.5642, Expected=821.0000
# Month=26, Predicted=817.3255, Expected=773.0000
# Month=27, Predicted=753.6789, Expected=883.0000
# Month=28, Predicted=904.1459, Expected=898.0000
# Month=29, Predicted=894.0462, Expected=957.0000
# Month=30, Predicted=935.8234, Expected=924.0000
# Month=31, Predicted=915.5844, Expected=881.0000
# Month=32, Predicted=869.8513, Expected=837.0000
# Month=33, Predicted=825.2756, Expected=784.0000
# Month=34, Predicted=735.4274, Expected=791.0000
# Month=35, Predicted=785.2078, Expected=760.0000
# Month=36, Predicted=751.8628, Expected=802.0000
# Month=37, Predicted=801.8842, Expected=828.0000
# Month=38, Predicted=827.2378, Expected=778.0000
# Month=39, Predicted=737.4507, Expected=889.0000
# Month=40, Predicted=910.1930, Expected=902.0000
# Month=41, Predicted=897.5151, Expected=969.0000
# Month=42, Predicted=928.0450, Expected=947.0000
# Month=43, Predicted=939.5824, Expected=908.0000
# Month=44, Predicted=898.3356, Expected=867.0000
# Month=45, Predicted=856.7020, Expected=815.0000
# Month=46, Predicted=766.9746, Expected=812.0000
# Month=47, Predicted=805.0728, Expected=773.0000
# Month=48, Predicted=763.3356, Expected=813.0000
# Month=49, Predicted=813.3942, Expected=834.0000
# Month=50, Predicted=831.8023, Expected=782.0000
# Month=51, Predicted=733.9746, Expected=892.0000
# Month=52, Predicted=913.1459, Expected=903.0000
# Month=53, Predicted=898.0279, Expected=966.0000
# Month=54, Predicted=930.2302, Expected=937.0000
# Month=55, Predicted=929.0911, Expected=896.0000
# Month=56, Predicted=885.7020, Expected=858.0000
# Month=57, Predicted=848.6002, Expected=817.0000
# Month=58, Predicted=806.7020, Expected=827.0000
# Month=59, Predicted=821.8029, Expected=797.0000
# Month=60, Predicted=788.9828, Expected=843.0000
# Run 28 — RMSE: 52.819727, MSE: 2789.923536, NMSE: 0.0113955211, Time: 48.7s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=766.9754, Expected=804.0000
# Month=2, Predicted=776.8060, Expected=756.0000
# Month=3, Predicted=716.0714, Expected=860.0000
# Month=4, Predicted=879.7467, Expected=878.0000
# Month=5, Predicted=872.3840, Expected=942.0000
# Month=6, Predicted=915.1952, Expected=913.0000
# Month=7, Predicted=914.6419, Expected=869.0000
# Month=8, Predicted=835.1652, Expected=834.0000
# Month=9, Predicted=818.2977, Expected=790.0000
# Month=10, Predicted=756.1652, Expected=800.0000
# Month=11, Predicted=782.3892, Expected=763.0000
# Month=12, Predicted=742.5994, Expected=800.0000
# Month=13, Predicted=817.3939, Expected=826.0000
# Month=14, Predicted=838.2385, Expected=799.0000
# Month=15, Predicted=802.7555, Expected=890.0000
# Month=16, Predicted=909.4018, Expected=900.0000
# Month=17, Predicted=882.3892, Expected=961.0000
# Month=18, Predicted=930.7316, Expected=935.0000
# Month=19, Predicted=939.2733, Expected=894.0000
# Month=20, Predicted=866.1493, Expected=855.0000
# Month=21, Predicted=831.1270, Expected=809.0000
# Month=22, Predicted=771.7362, Expected=810.0000
# Month=23, Predicted=790.9151, Expected=766.0000
# Month=24, Predicted=732.1652, Expected=805.0000
# Month=25, Predicted=821.6689, Expected=821.0000
# Month=26, Predicted=810.6485, Expected=773.0000
# Month=27, Predicted=733.0714, Expected=883.0000
# Month=28, Predicted=902.8598, Expected=898.0000
# Month=29, Predicted=885.7277, Expected=957.0000
# Month=30, Predicted=925.8450, Expected=924.0000
# Month=31, Predicted=915.3233, Expected=881.0000
# Month=32, Predicted=849.0878, Expected=837.0000
# Month=33, Predicted=803.1652, Expected=784.0000
# Month=34, Predicted=740.8533, Expected=791.0000
# Month=35, Predicted=772.2410, Expected=760.0000
# Month=36, Predicted=757.6168, Expected=802.0000
# Month=37, Predicted=815.4047, Expected=828.0000
# Month=38, Predicted=840.2385, Expected=778.0000
# Month=39, Predicted=736.2546, Expected=889.0000
# Month=40, Predicted=908.8771, Expected=902.0000
# Month=41, Predicted=886.8461, Expected=969.0000
# Month=42, Predicted=948.1754, Expected=947.0000
# Month=43, Predicted=950.7222, Expected=908.0000
# Month=44, Predicted=884.1270, Expected=867.0000
# Month=45, Predicted=839.1493, Expected=815.0000
# Month=46, Predicted=772.1771, Expected=812.0000
# Month=47, Predicted=793.8598, Expected=773.0000
# Month=48, Predicted=749.1270, Expected=813.0000
# Month=49, Predicted=828.9754, Expected=834.0000
# Month=50, Predicted=836.3914, Expected=782.0000
# Month=51, Predicted=739.1771, Expected=892.0000
# Month=52, Predicted=911.8598, Expected=903.0000
# Month=53, Predicted=886.0179, Expected=966.0000
# Month=54, Predicted=937.7479, Expected=937.0000
# Month=55, Predicted=938.6419, Expected=896.0000
# Month=56, Predicted=868.1493, Expected=858.0000
# Month=57, Predicted=835.8975, Expected=817.0000
# Month=58, Predicted=789.1493, Expected=827.0000
# Month=59, Predicted=809.3892, Expected=797.0000
# Month=60, Predicted=796.9068, Expected=843.0000
# Run 29 — RMSE: 54.545514, MSE: 2975.213127, NMSE: 0.0108568140, Time: 45.3s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=750.5664, Expected=804.0000
# Month=2, Predicted=789.8208, Expected=756.0000
# Month=3, Predicted=715.8007, Expected=860.0000
# Month=4, Predicted=880.3749, Expected=878.0000
# Month=5, Predicted=871.3873, Expected=942.0000
# Month=6, Predicted=917.5540, Expected=913.0000
# Month=7, Predicted=923.7465, Expected=869.0000
# Month=8, Predicted=834.7990, Expected=834.0000
# Month=9, Predicted=836.4564, Expected=790.0000
# Month=10, Predicted=755.7990, Expected=800.0000
# Month=11, Predicted=789.9503, Expected=763.0000
# Month=12, Predicted=757.4410, Expected=800.0000
# Month=13, Predicted=799.9977, Expected=826.0000
# Month=14, Predicted=823.1980, Expected=799.0000
# Month=15, Predicted=810.0844, Expected=890.0000
# Month=16, Predicted=910.5923, Expected=900.0000
# Month=17, Predicted=889.9503, Expected=961.0000
# Month=18, Predicted=937.2492, Expected=935.0000
# Month=19, Predicted=946.0194, Expected=894.0000
# Month=20, Predicted=868.3932, Expected=855.0000
# Month=21, Predicted=838.6823, Expected=809.0000
# Month=22, Predicted=770.9743, Expected=810.0000
# Month=23, Predicted=798.8862, Expected=766.0000
# Month=24, Predicted=731.7990, Expected=805.0000
# Month=25, Predicted=804.7965, Expected=821.0000
# Month=26, Predicted=813.4285, Expected=773.0000
# Month=27, Predicted=732.8007, Expected=883.0000
# Month=28, Predicted=903.3091, Expected=898.0000
# Month=29, Predicted=889.9653, Expected=957.0000
# Month=30, Predicted=934.7219, Expected=924.0000
# Month=31, Predicted=931.1192, Expected=881.0000
# Month=32, Predicted=849.2486, Expected=837.0000
# Month=33, Predicted=802.7990, Expected=784.0000
# Month=34, Predicted=742.4476, Expected=791.0000
# Month=35, Predicted=780.1225, Expected=760.0000
# Month=36, Predicted=769.5831, Expected=802.0000
# Month=37, Predicted=800.8022, Expected=828.0000
# Month=38, Predicted=825.1980, Expected=778.0000
# Month=39, Predicted=736.8487, Expected=889.0000
# Month=40, Predicted=909.2997, Expected=902.0000
# Month=41, Predicted=893.0879, Expected=969.0000
# Month=42, Predicted=946.3870, Expected=947.0000
# Month=43, Predicted=956.4780, Expected=908.0000
# Month=44, Predicted=891.6823, Expected=867.0000
# Month=45, Predicted=841.3932, Expected=815.0000
# Month=46, Predicted=773.5287, Expected=812.0000
# Month=47, Predicted=802.2222, Expected=773.0000
# Month=48, Predicted=756.6823, Expected=813.0000
# Month=49, Predicted=812.5664, Expected=834.0000
# Month=50, Predicted=828.8582, Expected=782.0000
# Month=51, Predicted=740.5287, Expected=892.0000
# Month=52, Predicted=912.3091, Expected=903.0000
# Month=53, Predicted=893.3006, Expected=966.0000
# Month=54, Predicted=941.5609, Expected=937.0000
# Month=55, Predicted=947.7465, Expected=896.0000
# Month=56, Predicted=870.3932, Expected=858.0000
# Month=57, Predicted=847.1935, Expected=817.0000
# Month=58, Predicted=791.3932, Expected=827.0000
# Month=59, Predicted=816.9503, Expected=797.0000
# Month=60, Predicted=807.2898, Expected=843.0000
# Run 30 — RMSE: 54.572259, MSE: 2978.131505, NMSE: 0.0106207742, Time: 46.2s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Pyraformer on Monthly Milk Production (30 runs) =====
# RMSE: 54.293196 ± 1.491570
# MSE:  2949.975896 ± 160.564253
# NMSE: 0.0110797388 ± 0.0003165194
# Avg training time: 50.2s ± 5.1s
#
# Best run: 7
#   RMSE: 49.890184
#   MSE:  2489.030448
#   NMSE: 0.0108549447

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Pyraformer — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Pyraformer — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 49.890184
# MSE:  2489.030448
# NMSE: 0.0108549447

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Pyraformer_Milk_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to Pyraformer_Milk_predictions.csv

# %% [markdown]
# ## Observations
#
# ### Pyraformer on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
