# %% [markdown]
# # FEDformer — Dow Jones Industrial Index
#
# **Model**: Frequency Enhanced Decomposed Transformer
# **Reference**: Zhou et al., 2022 — FEDformer: Frequency Enhanced Decomposed Transformer for Long-term Series Forecasting
#
# ## Description
# This notebook implements the **FEDformer** Transformer architecture for univariate time-series
# forecasting on the Dow Jones Industrial Index dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: FEDformer Architecture
#
# ### Frequency Enhanced Attention
# FEDformer operates in the **frequency domain** rather than the time domain:
#
# 1. Transform input to frequency space via FFT: $X_f = \mathcal{F}(X)$
# 2. Randomly select $M$ Fourier modes (random mode selection)
# 3. Apply learned linear transformations to selected modes
# 4. Transform back via inverse FFT: $X = \mathcal{F}^{-1}(X_f)$
#
# ### Frequency Domain Mixing
# The Fourier block applies learned complex-valued weights:
# $$Y_f[m] = W \cdot X_f[m], \quad m \in \{\text{selected modes}\}$$
#
# where $W = W_{\text{real}} + i \cdot W_{\text{imag}}$ is a learnable complex weight matrix.
#
# ### Series Decomposition
# Like Autoformer, FEDformer uses moving-average decomposition at each layer to separate trend and seasonal components.
#
# ### Complexity
# By selecting only $M \ll L$ Fourier modes, FEDformer achieves $O(L)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### FEDformer Model Definition

# %%
# ============================================================
# FEDformer: Frequency Enhanced Decomposed Transformer
# Reference: Zhou et al., 2022
#
# Key ideas:
# 1. Frequency attention: attention in Fourier space via random
#    mode selection (keeps top-M Fourier modes)
# 2. Series decomposition (shared with Autoformer)
# 3. Mixture of Experts (MoE) for frequency domain processing
# ============================================================

class FourierBlock(nn.Module):
    """
    Fourier-based attention block.
    Operates in the frequency domain by selecting random Fourier modes
    and applying learned linear transformations.
    """
    def __init__(self, d_model, n_modes=8):
        super().__init__()
        self.d_model = d_model
        self.n_modes = n_modes

        # Learnable complex weights for frequency domain
        self.scale = 1.0 / d_model
        self.W_real = nn.Parameter(self.scale * torch.randn(d_model, d_model))
        self.W_imag = nn.Parameter(self.scale * torch.randn(d_model, d_model))

    def forward(self, x):
        # x: (B, L, D)
        B, L, D = x.shape

        # FFT along sequence dimension
        x_fft = torch.fft.rfft(x, dim=1)  # (B, L//2+1, D)
        freq_len = x_fft.shape[1]

        # Select modes (all modes for short sequences)
        n_modes = min(self.n_modes, freq_len)

        # Apply learnable frequency transform on selected modes
        out_fft = torch.zeros_like(x_fft)
        selected = x_fft[:, :n_modes, :]

        # Complex multiplication with learned weights
        W_complex = torch.complex(self.W_real, self.W_imag)
        selected_out = torch.einsum('bld,dd->bld', selected, W_complex)
        out_fft[:, :n_modes, :] = selected_out

        # Inverse FFT
        output = torch.fft.irfft(out_fft, n=L, dim=1)  # (B, L, D)
        return output


class FEDSeriesDecomposition(nn.Module):
    """Series decomposition via moving average (shared design)."""
    def __init__(self, kernel_size=3):
        super().__init__()
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class FEDformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, n_modes=8, dropout=0.1):
        super().__init__()
        self.fourier_block = FourierBlock(d_model, n_modes)
        self.decomp1 = FEDSeriesDecomposition(kernel_size=3)
        self.decomp2 = FEDSeriesDecomposition(kernel_size=3)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Fourier block + decomposition
        fourier_out = self.fourier_block(x)
        x = x + self.dropout(fourier_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class FEDformerModel(nn.Module):
    """
    FEDformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_modes=8, n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            FEDformerEncoderLayer(d_model, n_heads, d_ff, n_modes, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 15905
# Trainable parameters: 15905
# Memory estimate: 62.1 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 1), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3797.5658, Expected=3796.0000
# Month=2, Predicted=3797.1665, Expected=3793.0000
# Month=3, Predicted=3794.2006, Expected=3766.0000
# Month=4, Predicted=3767.3002, Expected=3747.0000
# Month=5, Predicted=3748.4717, Expected=3754.0000
# Month=6, Predicted=3754.8173, Expected=3756.0000
# Month=7, Predicted=3757.0192, Expected=3767.0000
# Month=8, Predicted=3767.6460, Expected=3751.0000
# Month=9, Predicted=3752.4750, Expected=3769.0000
# Month=10, Predicted=3769.3318, Expected=3760.0000
# Month=11, Predicted=3761.3739, Expected=3785.0000
# Month=12, Predicted=3785.0039, Expected=3776.0000
# Month=13, Predicted=3777.3739, Expected=3755.0000
# Month=14, Predicted=3756.4512, Expected=3755.0000
# Month=15, Predicted=3756.0948, Expected=3751.0000
# Month=16, Predicted=3752.2335, Expected=3776.0000
# Month=17, Predicted=3776.0039, Expected=3847.0000
# Month=18, Predicted=3844.6227, Expected=3830.0000
# Month=19, Predicted=3831.4774, Expected=3881.0000
# Month=20, Predicted=3879.6967, Expected=3899.0000
# Month=21, Predicted=3899.3318, Expected=3917.0000
# Month=22, Predicted=3917.3318, Expected=3913.0000
# Month=23, Predicted=3914.2335, Expected=3901.0000
# Month=24, Predicted=3902.4336, Expected=3886.0000
# Month=25, Predicted=3887.4692, Expected=3892.5000
# Month=26, Predicted=3893.3382, Expected=3899.0000
# Month=27, Predicted=3899.8382, Expected=3886.0000
# Month=28, Predicted=3887.4483, Expected=3908.0000
# Month=29, Predicted=3908.1459, Expected=3875.0000
# Month=30, Predicted=3876.0473, Expected=3860.0000
# Month=31, Predicted=3861.4692, Expected=3880.0000
# Month=32, Predicted=3880.2394, Expected=3895.0000
# Month=33, Predicted=3895.4684, Expected=3954.0000
# Month=34, Predicted=3952.2726, Expected=3933.0000
# Month=35, Predicted=3934.4512, Expected=3937.0000
# Month=36, Predicted=3937.9404, Expected=3869.0000
# Month=37, Predicted=3876.3149, Expected=3852.0000
# Month=38, Predicted=3853.4774, Expected=3837.0000
# Month=39, Predicted=3838.4692, Expected=3832.0000
# Month=40, Predicted=3833.2649, Expected=3849.0000
# Month=41, Predicted=3849.3777, Expected=3863.0000
# Month=42, Predicted=3863.5133, Expected=3878.0000
# Month=43, Predicted=3878.4684, Expected=3855.0000
# Month=44, Predicted=3856.4156, Expected=3843.0000
# Month=45, Predicted=3844.4336, Expected=3847.0000
# Month=46, Predicted=3847.9404, Expected=3801.0000
# Month=47, Predicted=3801.8556, Expected=3787.0000
# Month=48, Predicted=3788.4603, Expected=3776.0000
# Month=49, Predicted=3777.4161, Expected=3797.0000
# Month=50, Predicted=3797.1928, Expected=3821.0000
# Month=51, Predicted=3821.0515, Expected=3877.0000
# Month=52, Predicted=3875.4326, Expected=3875.0000
# Month=53, Predicted=3876.1665, Expected=3890.0000
# Month=54, Predicted=3890.4684, Expected=3910.0000
# Month=55, Predicted=3910.2394, Expected=3924.0000
# Month=56, Predicted=3924.5133, Expected=3918.0000
# Month=57, Predicted=3919.2948, Expected=3936.0000
# Month=58, Predicted=3936.3318, Expected=3911.0000
# Month=59, Predicted=3912.3649, Expected=3891.0000
# Month=60, Predicted=3892.4633, Expected=3855.0000
# Run 1 — RMSE: 24.583175, MSE: 604.332485, NMSE: 0.0027827005, Time: 26.9s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3797.8669, Expected=3796.0000
# Month=2, Predicted=3797.7118, Expected=3793.0000
# Month=3, Predicted=3794.7630, Expected=3766.0000
# Month=4, Predicted=3768.9902, Expected=3747.0000
# Month=5, Predicted=3749.5813, Expected=3754.0000
# Month=6, Predicted=3755.2511, Expected=3756.0000
# Month=7, Predicted=3757.5071, Expected=3767.0000
# Month=8, Predicted=3768.0462, Expected=3751.0000
# Month=9, Predicted=3753.4279, Expected=3769.0000
# Month=10, Predicted=3769.6876, Expected=3760.0000
# Month=11, Predicted=3762.0699, Expected=3785.0000
# Month=12, Predicted=3785.3287, Expected=3776.0000
# Month=13, Predicted=3778.0699, Expected=3755.0000
# Month=14, Predicted=3757.6835, Expected=3755.0000
# Month=15, Predicted=3756.6094, Expected=3751.0000
# Month=16, Predicted=3752.8141, Expected=3776.0000
# Month=17, Predicted=3776.3287, Expected=3847.0000
# Month=18, Predicted=3844.9622, Expected=3830.0000
# Month=19, Predicted=3832.4790, Expected=3881.0000
# Month=20, Predicted=3879.9931, Expected=3899.0000
# Month=21, Predicted=3899.6876, Expected=3917.0000
# Month=22, Predicted=3917.6876, Expected=3913.0000
# Month=23, Predicted=3914.8141, Expected=3901.0000
# Month=24, Predicted=3903.2234, Expected=3886.0000
# Month=25, Predicted=3888.3768, Expected=3892.5000
# Month=26, Predicted=3893.7767, Expected=3899.0000
# Month=27, Predicted=3900.2767, Expected=3886.0000
# Month=28, Predicted=3888.2745, Expected=3908.0000
# Month=29, Predicted=3908.4825, Expected=3875.0000
# Month=30, Predicted=3878.2969, Expected=3860.0000
# Month=31, Predicted=3862.3768, Expected=3880.0000
# Month=32, Predicted=3880.5851, Expected=3895.0000
# Month=33, Predicted=3895.8413, Expected=3954.0000
# Month=34, Predicted=3952.5812, Expected=3933.0000
# Month=35, Predicted=3935.6835, Expected=3937.0000
# Month=36, Predicted=3938.4047, Expected=3869.0000
# Month=37, Predicted=3874.0850, Expected=3852.0000
# Month=38, Predicted=3854.4790, Expected=3837.0000
# Month=39, Predicted=3839.3768, Expected=3832.0000
# Month=40, Predicted=3833.8653, Expected=3849.0000
# Month=41, Predicted=3849.7388, Expected=3863.0000
# Month=42, Predicted=3863.8926, Expected=3878.0000
# Month=43, Predicted=3878.8413, Expected=3855.0000
# Month=44, Predicted=3857.7858, Expected=3843.0000
# Month=45, Predicted=3845.2234, Expected=3847.0000
# Month=46, Predicted=3848.4047, Expected=3801.0000
# Month=47, Predicted=3804.9611, Expected=3787.0000
# Month=48, Predicted=3789.3256, Expected=3776.0000
# Month=49, Predicted=3778.1722, Expected=3797.0000
# Month=50, Predicted=3797.5338, Expected=3821.0000
# Month=51, Predicted=3821.3800, Expected=3877.0000
# Month=52, Predicted=3875.7357, Expected=3875.0000
# Month=53, Predicted=3876.7118, Expected=3890.0000
# Month=54, Predicted=3890.8413, Expected=3910.0000
# Month=55, Predicted=3910.5851, Expected=3924.0000
# Month=56, Predicted=3924.8926, Expected=3918.0000
# Month=57, Predicted=3919.9165, Expected=3936.0000
# Month=58, Predicted=3936.6876, Expected=3911.0000
# Month=59, Predicted=3913.8880, Expected=3891.0000
# Month=60, Predicted=3893.6324, Expected=3855.0000
# Run 2 — RMSE: 24.640218, MSE: 607.140329, NMSE: 0.0028030747, Time: 25.9s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3797.4462, Expected=3796.0000
# Month=2, Predicted=3797.2039, Expected=3793.0000
# Month=3, Predicted=3794.2527, Expected=3766.0000
# Month=4, Predicted=3768.4241, Expected=3747.0000
# Month=5, Predicted=3749.0336, Expected=3754.0000
# Month=6, Predicted=3754.7645, Expected=3756.0000
# Month=7, Predicted=3757.0086, Expected=3767.0000
# Month=8, Predicted=3767.5693, Expected=3751.0000
# Month=9, Predicted=3752.8872, Expected=3769.0000
# Month=10, Predicted=3769.2275, Expected=3760.0000
# Month=11, Predicted=3761.5456, Expected=3785.0000
# Month=12, Predicted=3784.8857, Expected=3776.0000
# Month=13, Predicted=3777.5456, Expected=3755.0000
# Month=14, Predicted=3757.1312, Expected=3755.0000
# Month=15, Predicted=3756.1063, Expected=3751.0000
# Month=16, Predicted=3752.3015, Expected=3776.0000
# Month=17, Predicted=3775.8857, Expected=3847.0000
# Month=18, Predicted=3844.6389, Expected=3830.0000
# Month=19, Predicted=3831.9360, Expected=3881.0000
# Month=20, Predicted=3879.6159, Expected=3899.0000
# Month=21, Predicted=3899.2275, Expected=3917.0000
# Month=22, Predicted=3917.2275, Expected=3913.0000
# Month=23, Predicted=3914.3015, Expected=3901.0000
# Month=24, Predicted=3902.6920, Expected=3886.0000
# Month=25, Predicted=3887.8384, Expected=3892.5000
# Month=26, Predicted=3893.2889, Expected=3899.0000
# Month=27, Predicted=3899.7889, Expected=3886.0000
# Month=28, Predicted=3887.7408, Expected=3908.0000
# Month=29, Predicted=3908.0322, Expected=3875.0000
# Month=30, Predicted=3877.7168, Expected=3860.0000
# Month=31, Predicted=3861.8384, Expected=3880.0000
# Month=32, Predicted=3880.1298, Expected=3895.0000
# Month=33, Predicted=3895.3740, Expected=3954.0000
# Month=34, Predicted=3952.2251, Expected=3933.0000
# Month=35, Predicted=3935.1312, Expected=3937.0000
# Month=36, Predicted=3937.9110, Expected=3869.0000
# Month=37, Predicted=3873.4243, Expected=3852.0000
# Month=38, Predicted=3853.9360, Expected=3837.0000
# Month=39, Predicted=3838.8384, Expected=3832.0000
# Month=40, Predicted=3833.3503, Expected=3849.0000
# Month=41, Predicted=3849.2763, Expected=3863.0000
# Month=42, Predicted=3863.4228, Expected=3878.0000
# Month=43, Predicted=3878.3740, Expected=3855.0000
# Month=44, Predicted=3857.2289, Expected=3843.0000
# Month=45, Predicted=3844.6920, Expected=3847.0000
# Month=46, Predicted=3847.9110, Expected=3801.0000
# Month=47, Predicted=3804.3511, Expected=3787.0000
# Month=48, Predicted=3788.7896, Expected=3776.0000
# Month=49, Predicted=3777.6432, Expected=3797.0000
# Month=50, Predicted=3797.0810, Expected=3821.0000
# Month=51, Predicted=3820.9345, Expected=3877.0000
# Month=52, Predicted=3875.3717, Expected=3875.0000
# Month=53, Predicted=3876.2039, Expected=3890.0000
# Month=54, Predicted=3890.3740, Expected=3910.0000
# Month=55, Predicted=3910.1298, Expected=3924.0000
# Month=56, Predicted=3924.4228, Expected=3918.0000
# Month=57, Predicted=3919.3991, Expected=3936.0000
# Month=58, Predicted=3936.2275, Expected=3911.0000
# Month=59, Predicted=3913.3265, Expected=3891.0000
# Month=60, Predicted=3893.0824, Expected=3855.0000
# Run 3 — RMSE: 24.624989, MSE: 606.390096, NMSE: 0.0027989633, Time: 32.8s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3798.2309, Expected=3796.0000
# Month=2, Predicted=3797.1029, Expected=3793.0000
# Month=3, Predicted=3794.1112, Expected=3766.0000
# Month=4, Predicted=3766.5647, Expected=3747.0000
# Month=5, Predicted=3747.9297, Expected=3754.0000
# Month=6, Predicted=3754.9674, Expected=3756.0000
# Month=7, Predicted=3757.0546, Expected=3767.0000
# Month=8, Predicted=3767.8814, Expected=3751.0000
# Month=9, Predicted=3752.0192, Expected=3769.0000
# Month=10, Predicted=3769.7061, Expected=3760.0000
# Month=11, Predicted=3761.1212, Expected=3785.0000
# Month=12, Predicted=3785.5081, Expected=3776.0000
# Month=13, Predicted=3777.1212, Expected=3755.0000
# Month=14, Predicted=3755.8542, Expected=3755.0000
# Month=15, Predicted=3756.0816, Expected=3751.0000
# Month=16, Predicted=3752.1179, Expected=3776.0000
# Month=17, Predicted=3776.5081, Expected=3847.0000
# Month=18, Predicted=3845.9544, Expected=3830.0000
# Month=19, Predicted=3830.9926, Expected=3881.0000
# Month=20, Predicted=3880.6638, Expected=3899.0000
# Month=21, Predicted=3899.7061, Expected=3917.0000
# Month=22, Predicted=3917.7061, Expected=3913.0000
# Month=23, Predicted=3914.1179, Expected=3901.0000
# Month=24, Predicted=3902.0947, Expected=3886.0000
# Month=25, Predicted=3887.0427, Expected=3892.5000
# Month=26, Predicted=3893.4772, Expected=3899.0000
# Month=27, Predicted=3899.9772, Expected=3886.0000
# Month=28, Predicted=3887.0803, Expected=3908.0000
# Month=29, Predicted=3908.5952, Expected=3875.0000
# Month=30, Predicted=3875.2516, Expected=3860.0000
# Month=31, Predicted=3861.0427, Expected=3880.0000
# Month=32, Predicted=3880.6515, Expected=3895.0000
# Month=33, Predicted=3895.7846, Expected=3954.0000
# Month=34, Predicted=3953.3841, Expected=3933.0000
# Month=35, Predicted=3933.8542, Expected=3937.0000
# Month=36, Predicted=3938.0229, Expected=3869.0000
# Month=37, Predicted=3877.5147, Expected=3852.0000
# Month=38, Predicted=3852.9926, Expected=3837.0000
# Month=39, Predicted=3838.0427, Expected=3832.0000
# Month=40, Predicted=3833.1227, Expected=3849.0000
# Month=41, Predicted=3849.7328, Expected=3863.0000
# Month=42, Predicted=3863.8097, Expected=3878.0000
# Month=43, Predicted=3878.7846, Expected=3855.0000
# Month=44, Predicted=3855.7669, Expected=3843.0000
# Month=45, Predicted=3844.0947, Expected=3847.0000
# Month=46, Predicted=3848.0229, Expected=3801.0000
# Month=47, Predicted=3801.4346, Expected=3787.0000
# Month=48, Predicted=3788.0630, Expected=3776.0000
# Month=49, Predicted=3777.1062, Expected=3797.0000
# Month=50, Predicted=3797.6236, Expected=3821.0000
# Month=51, Predicted=3821.5375, Expected=3877.0000
# Month=52, Predicted=3876.4897, Expected=3875.0000
# Month=53, Predicted=3876.1029, Expected=3890.0000
# Month=54, Predicted=3890.7846, Expected=3910.0000
# Month=55, Predicted=3910.6515, Expected=3924.0000
# Month=56, Predicted=3924.8097, Expected=3918.0000
# Month=57, Predicted=3919.1255, Expected=3936.0000
# Month=58, Predicted=3936.7061, Expected=3911.0000
# Month=59, Predicted=3911.6695, Expected=3891.0000
# Month=60, Predicted=3891.8935, Expected=3855.0000
# Run 4 — RMSE: 24.553905, MSE: 602.894255, NMSE: 0.0027666591, Time: 34.8s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3796.1014, Expected=3796.0000
# Month=2, Predicted=3798.2886, Expected=3793.0000
# Month=3, Predicted=3795.3211, Expected=3766.0000
# Month=4, Predicted=3768.9489, Expected=3747.0000
# Month=5, Predicted=3749.7205, Expected=3754.0000
# Month=6, Predicted=3755.8644, Expected=3756.0000
# Month=7, Predicted=3758.1339, Expected=3767.0000
# Month=8, Predicted=3768.5680, Expected=3751.0000
# Month=9, Predicted=3753.6467, Expected=3769.0000
# Month=10, Predicted=3769.8362, Expected=3760.0000
# Month=11, Predicted=3762.4834, Expected=3785.0000
# Month=12, Predicted=3784.8098, Expected=3776.0000
# Month=13, Predicted=3778.4834, Expected=3755.0000
# Month=14, Predicted=3757.7729, Expected=3755.0000
# Month=15, Predicted=3757.2167, Expected=3751.0000
# Month=16, Predicted=3753.3516, Expected=3776.0000
# Month=17, Predicted=3775.8098, Expected=3847.0000
# Month=18, Predicted=3836.6418, Expected=3830.0000
# Month=19, Predicted=3832.6708, Expected=3881.0000
# Month=20, Predicted=3875.2306, Expected=3899.0000
# Month=21, Predicted=3899.8362, Expected=3917.0000
# Month=22, Predicted=3917.8362, Expected=3913.0000
# Month=23, Predicted=3915.3516, Expected=3901.0000
# Month=24, Predicted=3903.5536, Expected=3886.0000
# Month=25, Predicted=3888.6231, Expected=3892.5000
# Month=26, Predicted=3894.3960, Expected=3899.0000
# Month=27, Predicted=3900.8960, Expected=3886.0000
# Month=28, Predicted=3888.5766, Expected=3908.0000
# Month=29, Predicted=3908.2855, Expected=3875.0000
# Month=30, Predicted=3878.1539, Expected=3860.0000
# Month=31, Predicted=3862.6231, Expected=3880.0000
# Month=32, Predicted=3880.5730, Expected=3895.0000
# Month=33, Predicted=3896.1853, Expected=3954.0000
# Month=34, Predicted=3946.3627, Expected=3933.0000
# Month=35, Predicted=3935.7729, Expected=3937.0000
# Month=36, Predicted=3939.0378, Expected=3869.0000
# Month=37, Predicted=3873.6439, Expected=3852.0000
# Month=38, Predicted=3854.6708, Expected=3837.0000
# Month=39, Predicted=3839.6231, Expected=3832.0000
# Month=40, Predicted=3834.3804, Expected=3849.0000
# Month=41, Predicted=3849.9586, Expected=3863.0000
# Month=42, Predicted=3864.2896, Expected=3878.0000
# Month=43, Predicted=3879.1853, Expected=3855.0000
# Month=44, Predicted=3857.8283, Expected=3843.0000
# Month=45, Predicted=3845.5536, Expected=3847.0000
# Month=46, Predicted=3849.0378, Expected=3801.0000
# Month=47, Predicted=3804.6728, Expected=3787.0000
# Month=48, Predicted=3789.5997, Expected=3776.0000
# Month=49, Predicted=3778.5305, Expected=3797.0000
# Month=50, Predicted=3797.4323, Expected=3821.0000
# Month=51, Predicted=3820.9742, Expected=3877.0000
# Month=52, Predicted=3870.0592, Expected=3875.0000
# Month=53, Predicted=3877.2886, Expected=3890.0000
# Month=54, Predicted=3891.1853, Expected=3910.0000
# Month=55, Predicted=3910.5730, Expected=3924.0000
# Month=56, Predicted=3925.2896, Expected=3918.0000
# Month=57, Predicted=3920.4078, Expected=3936.0000
# Month=58, Predicted=3936.8362, Expected=3911.0000
# Month=59, Predicted=3913.8869, Expected=3891.0000
# Month=60, Predicted=3893.7464, Expected=3855.0000
# Run 5 — RMSE: 24.639293, MSE: 607.094772, NMSE: 0.0028246995, Time: 31.6s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3797.9533, Expected=3796.0000
# Month=2, Predicted=3797.4292, Expected=3793.0000
# Month=3, Predicted=3794.4682, Expected=3766.0000
# Month=4, Predicted=3768.3706, Expected=3747.0000
# Month=5, Predicted=3749.0769, Expected=3754.0000
# Month=6, Predicted=3755.0733, Expected=3756.0000
# Month=7, Predicted=3757.2721, Expected=3767.0000
# Month=8, Predicted=3767.9122, Expected=3751.0000
# Month=9, Predicted=3752.9649, Expected=3769.0000
# Month=10, Predicted=3769.6262, Expected=3760.0000
# Month=11, Predicted=3761.6998, Expected=3785.0000
# Month=12, Predicted=3785.3350, Expected=3776.0000
# Month=13, Predicted=3777.6998, Expected=3755.0000
# Month=14, Predicted=3757.1510, Expected=3755.0000
# Month=15, Predicted=3756.3508, Expected=3751.0000
# Month=16, Predicted=3752.5070, Expected=3776.0000
# Month=17, Predicted=3776.3350, Expected=3847.0000
# Month=18, Predicted=3845.3059, Expected=3830.0000
# Month=19, Predicted=3832.0023, Expected=3881.0000
# Month=20, Predicted=3880.2109, Expected=3899.0000
# Month=21, Predicted=3899.6262, Expected=3917.0000
# Month=22, Predicted=3917.6262, Expected=3913.0000
# Month=23, Predicted=3914.5070, Expected=3901.0000
# Month=24, Predicted=3902.8141, Expected=3886.0000
# Month=25, Predicted=3887.9274, Expected=3892.5000
# Month=26, Predicted=3893.5933, Expected=3899.0000
# Month=27, Predicted=3900.0933, Expected=3886.0000
# Month=28, Predicted=3887.8519, Expected=3908.0000
# Month=29, Predicted=3908.4605, Expected=3875.0000
# Month=30, Predicted=3877.5864, Expected=3860.0000
# Month=31, Predicted=3861.9274, Expected=3880.0000
# Month=32, Predicted=3880.5436, Expected=3895.0000
# Month=33, Predicted=3895.7494, Expected=3954.0000
# Month=34, Predicted=3952.8526, Expected=3933.0000
# Month=35, Predicted=3935.1510, Expected=3937.0000
# Month=36, Predicted=3938.1929, Expected=3869.0000
# Month=37, Predicted=3872.7722, Expected=3852.0000
# Month=38, Predicted=3854.0023, Expected=3837.0000
# Month=39, Predicted=3838.9274, Expected=3832.0000
# Month=40, Predicted=3833.5458, Expected=3849.0000
# Month=41, Predicted=3849.6674, Expected=3863.0000
# Month=42, Predicted=3863.7903, Expected=3878.0000
# Month=43, Predicted=3878.7494, Expected=3855.0000
# Month=44, Predicted=3857.2246, Expected=3843.0000
# Month=45, Predicted=3844.8141, Expected=3847.0000
# Month=46, Predicted=3848.1929, Expected=3801.0000
# Month=47, Predicted=3804.0408, Expected=3787.0000
# Month=48, Predicted=3788.8897, Expected=3776.0000
# Month=49, Predicted=3777.7761, Expected=3797.0000
# Month=50, Predicted=3797.5021, Expected=3821.0000
# Month=51, Predicted=3821.3769, Expected=3877.0000
# Month=52, Predicted=3875.9876, Expected=3875.0000
# Month=53, Predicted=3876.4292, Expected=3890.0000
# Month=54, Predicted=3890.7494, Expected=3910.0000
# Month=55, Predicted=3910.5436, Expected=3924.0000
# Month=56, Predicted=3924.7903, Expected=3918.0000
# Month=57, Predicted=3919.5845, Expected=3936.0000
# Month=58, Predicted=3936.6262, Expected=3911.0000
# Month=59, Predicted=3913.2978, Expected=3891.0000
# Month=60, Predicted=3893.1140, Expected=3855.0000
# Run 6 — RMSE: 24.583415, MSE: 604.344300, NMSE: 0.0027867182, Time: 30.9s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3797.5842, Expected=3796.0000
# Month=2, Predicted=3797.3014, Expected=3793.0000
# Month=3, Predicted=3794.3491, Expected=3766.0000
# Month=4, Predicted=3768.4954, Expected=3747.0000
# Month=5, Predicted=3749.1132, Expected=3754.0000
# Month=6, Predicted=3754.8718, Expected=3756.0000
# Month=7, Predicted=3757.1104, Expected=3767.0000
# Month=8, Predicted=3767.6810, Expected=3751.0000
# Month=9, Predicted=3752.9699, Expected=3769.0000
# Month=10, Predicted=3769.3471, Expected=3760.0000
# Month=11, Predicted=3761.6356, Expected=3785.0000
# Month=12, Predicted=3785.0133, Expected=3776.0000
# Month=13, Predicted=3777.6356, Expected=3755.0000
# Month=14, Predicted=3757.2087, Expected=3755.0000
# Month=15, Predicted=3756.2059, Expected=3751.0000
# Month=16, Predicted=3752.3968, Expected=3776.0000
# Month=17, Predicted=3776.0133, Expected=3847.0000
# Month=18, Predicted=3844.8222, Expected=3830.0000
# Month=19, Predicted=3832.0176, Expected=3881.0000
# Month=20, Predicted=3879.7743, Expected=3899.0000
# Month=21, Predicted=3899.3471, Expected=3917.0000
# Month=22, Predicted=3917.3471, Expected=3913.0000
# Month=23, Predicted=3914.3968, Expected=3901.0000
# Month=24, Predicted=3902.7788, Expected=3886.0000
# Month=25, Predicted=3887.9221, Expected=3892.5000
# Month=26, Predicted=3893.3957, Expected=3899.0000
# Month=27, Predicted=3899.8957, Expected=3886.0000
# Month=28, Predicted=3887.8266, Expected=3908.0000
# Month=29, Predicted=3908.1563, Expected=3875.0000
# Month=30, Predicted=3877.7822, Expected=3860.0000
# Month=31, Predicted=3861.9221, Expected=3880.0000
# Month=32, Predicted=3880.2517, Expected=3895.0000
# Month=33, Predicted=3895.4901, Expected=3954.0000
# Month=34, Predicted=3952.3934, Expected=3933.0000
# Month=35, Predicted=3935.2087, Expected=3937.0000
# Month=36, Predicted=3938.0150, Expected=3869.0000
# Month=37, Predicted=3873.4568, Expected=3852.0000
# Month=38, Predicted=3854.0176, Expected=3837.0000
# Month=39, Predicted=3838.9221, Expected=3832.0000
# Month=40, Predicted=3833.4446, Expected=3849.0000
# Month=41, Predicted=3849.3948, Expected=3863.0000
# Month=42, Predicted=3863.5378, Expected=3878.0000
# Month=43, Predicted=3878.4901, Expected=3855.0000
# Month=44, Predicted=3857.3043, Expected=3843.0000
# Month=45, Predicted=3844.7788, Expected=3847.0000
# Month=46, Predicted=3848.0150, Expected=3801.0000
# Month=47, Predicted=3804.4039, Expected=3787.0000
# Month=48, Predicted=3788.8743, Expected=3776.0000
# Month=49, Predicted=3777.7311, Expected=3797.0000
# Month=50, Predicted=3797.2040, Expected=3821.0000
# Month=51, Predicted=3821.0609, Expected=3877.0000
# Month=52, Predicted=3875.5362, Expected=3875.0000
# Month=53, Predicted=3876.3014, Expected=3890.0000
# Month=54, Predicted=3890.4901, Expected=3910.0000
# Month=55, Predicted=3910.2517, Expected=3924.0000
# Month=56, Predicted=3924.5378, Expected=3918.0000
# Month=57, Predicted=3919.4923, Expected=3936.0000
# Month=58, Predicted=3936.3471, Expected=3911.0000
# Month=59, Predicted=3913.3999, Expected=3891.0000
# Month=60, Predicted=3893.1610, Expected=3855.0000
# Run 7 — RMSE: 24.621386, MSE: 606.212639, NMSE: 0.0027977167, Time: 31.9s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3797.9167, Expected=3796.0000
# Month=2, Predicted=3797.1300, Expected=3793.0000
# Month=3, Predicted=3794.1634, Expected=3766.0000
# Month=4, Predicted=3767.9563, Expected=3747.0000
# Month=5, Predicted=3748.6933, Expected=3754.0000
# Month=6, Predicted=3754.8293, Expected=3756.0000
# Month=7, Predicted=3756.9966, Expected=3767.0000
# Month=8, Predicted=3767.6951, Expected=3751.0000
# Month=9, Predicted=3752.5944, Expected=3769.0000
# Month=10, Predicted=3769.4594, Expected=3760.0000
# Month=11, Predicted=3761.3627, Expected=3785.0000
# Month=12, Predicted=3785.2226, Expected=3776.0000
# Month=13, Predicted=3777.3627, Expected=3755.0000
# Month=14, Predicted=3756.7592, Expected=3755.0000
# Month=15, Predicted=3756.0634, Expected=3751.0000
# Month=16, Predicted=3752.1966, Expected=3776.0000
# Month=17, Predicted=3776.2226, Expected=3847.0000
# Month=18, Predicted=3845.6422, Expected=3830.0000
# Month=19, Predicted=3831.6274, Expected=3881.0000
# Month=20, Predicted=3880.3344, Expected=3899.0000
# Month=21, Predicted=3899.4594, Expected=3917.0000
# Month=22, Predicted=3917.4594, Expected=3913.0000
# Month=23, Predicted=3914.1966, Expected=3901.0000
# Month=24, Predicted=3902.4621, Expected=3886.0000
# Month=25, Predicted=3887.5614, Expected=3892.5000
# Month=26, Predicted=3893.3461, Expected=3899.0000
# Month=27, Predicted=3899.8461, Expected=3886.0000
# Month=28, Predicted=3887.4952, Expected=3908.0000
# Month=29, Predicted=3908.3242, Expected=3875.0000
# Month=30, Predicted=3877.1526, Expected=3860.0000
# Month=31, Predicted=3861.5614, Expected=3880.0000
# Month=32, Predicted=3880.3918, Expected=3895.0000
# Month=33, Predicted=3895.5605, Expected=3954.0000
# Month=34, Predicted=3953.0585, Expected=3933.0000
# Month=35, Predicted=3934.7592, Expected=3937.0000
# Month=36, Predicted=3937.9298, Expected=3869.0000
# Month=37, Predicted=3872.2829, Expected=3852.0000
# Month=38, Predicted=3853.6274, Expected=3837.0000
# Month=39, Predicted=3838.5614, Expected=3832.0000
# Month=40, Predicted=3833.2299, Expected=3849.0000
# Month=41, Predicted=3849.4931, Expected=3863.0000
# Month=42, Predicted=3863.5942, Expected=3878.0000
# Month=43, Predicted=3878.5605, Expected=3855.0000
# Month=44, Predicted=3856.8250, Expected=3843.0000
# Month=45, Predicted=3844.4621, Expected=3847.0000
# Month=46, Predicted=3847.9298, Expected=3801.0000
# Month=47, Predicted=3803.5753, Expected=3787.0000
# Month=48, Predicted=3788.5283, Expected=3776.0000
# Month=49, Predicted=3777.4290, Expected=3797.0000
# Month=50, Predicted=3797.3580, Expected=3821.0000
# Month=51, Predicted=3821.2565, Expected=3877.0000
# Month=52, Predicted=3876.1621, Expected=3875.0000
# Month=53, Predicted=3876.1300, Expected=3890.0000
# Month=54, Predicted=3890.5605, Expected=3910.0000
# Month=55, Predicted=3910.3918, Expected=3924.0000
# Month=56, Predicted=3924.5942, Expected=3918.0000
# Month=57, Predicted=3919.2631, Expected=3936.0000
# Month=58, Predicted=3936.4594, Expected=3911.0000
# Month=59, Predicted=3912.8907, Expected=3891.0000
# Month=60, Predicted=3892.7263, Expected=3855.0000
# Run 8 — RMSE: 24.565989, MSE: 603.487818, NMSE: 0.0027800605, Time: 35.3s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3797.8089, Expected=3796.0000
# Month=2, Predicted=3797.5629, Expected=3793.0000
# Month=3, Predicted=3794.6118, Expected=3766.0000
# Month=4, Predicted=3768.7855, Expected=3747.0000
# Month=5, Predicted=3749.3939, Expected=3754.0000
# Month=6, Predicted=3755.1237, Expected=3756.0000
# Month=7, Predicted=3757.3677, Expected=3767.0000
# Month=8, Predicted=3767.9286, Expected=3751.0000
# Month=9, Predicted=3753.2471, Expected=3769.0000
# Month=10, Predicted=3769.5875, Expected=3760.0000
# Month=11, Predicted=3761.9049, Expected=3785.0000
# Month=12, Predicted=3785.2467, Expected=3776.0000
# Month=13, Predicted=3777.9049, Expected=3755.0000
# Month=14, Predicted=3757.4918, Expected=3755.0000
# Month=15, Predicted=3756.4653, Expected=3751.0000
# Month=16, Predicted=3752.6606, Expected=3776.0000
# Month=17, Predicted=3776.2467, Expected=3847.0000
# Month=18, Predicted=3845.0143, Expected=3830.0000
# Month=19, Predicted=3832.2961, Expected=3881.0000
# Month=20, Predicted=3879.9833, Expected=3899.0000
# Month=21, Predicted=3899.5875, Expected=3917.0000
# Month=22, Predicted=3917.5875, Expected=3913.0000
# Month=23, Predicted=3914.6606, Expected=3901.0000
# Month=24, Predicted=3903.0515, Expected=3886.0000
# Month=25, Predicted=3888.1982, Expected=3892.5000
# Month=26, Predicted=3893.6481, Expected=3899.0000
# Month=27, Predicted=3900.1481, Expected=3886.0000
# Month=28, Predicted=3888.1004, Expected=3908.0000
# Month=29, Predicted=3908.3927, Expected=3875.0000
# Month=30, Predicted=3878.0794, Expected=3860.0000
# Month=31, Predicted=3862.1982, Expected=3880.0000
# Month=32, Predicted=3880.4901, Expected=3895.0000
# Month=33, Predicted=3895.7337, Expected=3954.0000
# Month=34, Predicted=3952.5954, Expected=3933.0000
# Month=35, Predicted=3935.4918, Expected=3937.0000
# Month=36, Predicted=3938.2701, Expected=3869.0000
# Month=37, Predicted=3873.7979, Expected=3852.0000
# Month=38, Predicted=3854.2961, Expected=3837.0000
# Month=39, Predicted=3839.1982, Expected=3832.0000
# Month=40, Predicted=3833.7095, Expected=3849.0000
# Month=41, Predicted=3849.6362, Expected=3863.0000
# Month=42, Predicted=3863.7824, Expected=3878.0000
# Month=43, Predicted=3878.7337, Expected=3855.0000
# Month=44, Predicted=3857.5897, Expected=3843.0000
# Month=45, Predicted=3845.0515, Expected=3847.0000
# Month=46, Predicted=3848.2701, Expected=3801.0000
# Month=47, Predicted=3804.7170, Expected=3787.0000
# Month=48, Predicted=3789.1493, Expected=3776.0000
# Month=49, Predicted=3778.0027, Expected=3797.0000
# Month=50, Predicted=3797.4414, Expected=3821.0000
# Month=51, Predicted=3821.2953, Expected=3877.0000
# Month=52, Predicted=3875.7408, Expected=3875.0000
# Month=53, Predicted=3876.5629, Expected=3890.0000
# Month=54, Predicted=3890.7337, Expected=3910.0000
# Month=55, Predicted=3910.4901, Expected=3924.0000
# Month=56, Predicted=3924.7824, Expected=3918.0000
# Month=57, Predicted=3919.7583, Expected=3936.0000
# Month=58, Predicted=3936.5875, Expected=3911.0000
# Month=59, Predicted=3913.6876, Expected=3891.0000
# Month=60, Predicted=3893.4428, Expected=3855.0000
# Run 9 — RMSE: 24.628837, MSE: 606.579606, NMSE: 0.0027996625, Time: 45.3s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3797.6355, Expected=3796.0000
# Month=2, Predicted=3797.7964, Expected=3793.0000
# Month=3, Predicted=3794.8564, Expected=3766.0000
# Month=4, Predicted=3769.2952, Expected=3747.0000
# Month=5, Predicted=3749.8157, Expected=3754.0000
# Month=6, Predicted=3755.2565, Expected=3756.0000
# Month=7, Predicted=3757.5565, Expected=3767.0000
# Month=8, Predicted=3768.0164, Expected=3751.0000
# Month=9, Predicted=3753.6359, Expected=3769.0000
# Month=10, Predicted=3769.5963, Expected=3760.0000
# Month=11, Predicted=3762.2162, Expected=3785.0000
# Month=12, Predicted=3785.1760, Expected=3776.0000
# Month=13, Predicted=3778.2162, Expected=3755.0000
# Month=14, Predicted=3757.9356, Expected=3755.0000
# Month=15, Predicted=3756.6764, Expected=3751.0000
# Month=16, Predicted=3752.9164, Expected=3776.0000
# Month=17, Predicted=3776.1760, Expected=3847.0000
# Month=18, Predicted=3844.4115, Expected=3830.0000
# Month=19, Predicted=3832.6959, Expected=3881.0000
# Month=20, Predicted=3879.6140, Expected=3899.0000
# Month=21, Predicted=3899.5963, Expected=3917.0000
# Month=22, Predicted=3917.5963, Expected=3913.0000
# Month=23, Predicted=3914.9164, Expected=3901.0000
# Month=24, Predicted=3903.3961, Expected=3886.0000
# Month=25, Predicted=3888.5760, Expected=3892.5000
# Month=26, Predicted=3893.7865, Expected=3899.0000
# Month=27, Predicted=3900.2865, Expected=3886.0000
# Month=28, Predicted=3888.4561, Expected=3908.0000
# Month=29, Predicted=3908.3561, Expected=3875.0000
# Month=30, Predicted=3878.6546, Expected=3860.0000
# Month=31, Predicted=3862.5760, Expected=3880.0000
# Month=32, Predicted=3880.4762, Expected=3895.0000
# Month=33, Predicted=3895.7764, Expected=3954.0000
# Month=34, Predicted=3952.1331, Expected=3933.0000
# Month=35, Predicted=3935.9356, Expected=3937.0000
# Month=36, Predicted=3938.4365, Expected=3869.0000
# Month=37, Predicted=3874.7494, Expected=3852.0000
# Month=38, Predicted=3854.6959, Expected=3837.0000
# Month=39, Predicted=3839.5760, Expected=3832.0000
# Month=40, Predicted=3833.9763, Expected=3849.0000
# Month=41, Predicted=3849.6563, Expected=3863.0000
# Month=42, Predicted=3863.8364, Expected=3878.0000
# Month=43, Predicted=3878.7764, Expected=3855.0000
# Month=44, Predicted=3858.0555, Expected=3843.0000
# Month=45, Predicted=3845.3961, Expected=3847.0000
# Month=46, Predicted=3848.4365, Expected=3801.0000
# Month=47, Predicted=3805.4331, Expected=3787.0000
# Month=48, Predicted=3789.5160, Expected=3776.0000
# Month=49, Predicted=3778.3361, Expected=3797.0000
# Month=50, Predicted=3797.4162, Expected=3821.0000
# Month=51, Predicted=3821.2361, Expected=3877.0000
# Month=52, Predicted=3875.3135, Expected=3875.0000
# Month=53, Predicted=3876.7964, Expected=3890.0000
# Month=54, Predicted=3890.7764, Expected=3910.0000
# Month=55, Predicted=3910.4762, Expected=3924.0000
# Month=56, Predicted=3924.8364, Expected=3918.0000
# Month=57, Predicted=3920.0363, Expected=3936.0000
# Month=58, Predicted=3936.5963, Expected=3911.0000
# Month=59, Predicted=3914.1753, Expected=3891.0000
# Month=60, Predicted=3893.8757, Expected=3855.0000
# Run 10 — RMSE: 24.677188, MSE: 608.963614, NMSE: 0.0028145771, Time: 41.9s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3797.8793, Expected=3796.0000
# Month=2, Predicted=3798.2339, Expected=3793.0000
# Month=3, Predicted=3795.2999, Expected=3766.0000
# Month=4, Predicted=3769.8926, Expected=3747.0000
# Month=5, Predicted=3750.3597, Expected=3754.0000
# Month=6, Predicted=3755.6416, Expected=3756.0000
# Month=7, Predicted=3757.9703, Expected=3767.0000
# Month=8, Predicted=3768.3791, Expected=3751.0000
# Month=9, Predicted=3754.1603, Expected=3769.0000
# Month=10, Predicted=3769.9210, Expected=3760.0000
# Month=11, Predicted=3762.6963, Expected=3785.0000
# Month=12, Predicted=3785.4643, Expected=3776.0000
# Month=13, Predicted=3778.6963, Expected=3755.0000
# Month=14, Predicted=3758.4927, Expected=3755.0000
# Month=15, Predicted=3757.1020, Expected=3751.0000
# Month=16, Predicted=3753.3659, Expected=3776.0000
# Month=17, Predicted=3776.4643, Expected=3847.0000
# Month=18, Predicted=3844.4967, Expected=3830.0000
# Month=19, Predicted=3833.2267, Expected=3881.0000
# Month=20, Predicted=3879.7803, Expected=3899.0000
# Month=21, Predicted=3899.9210, Expected=3917.0000
# Month=22, Predicted=3917.9210, Expected=3913.0000
# Month=23, Predicted=3915.3659, Expected=3901.0000
# Month=24, Predicted=3903.8950, Expected=3886.0000
# Month=25, Predicted=3889.0940, Expected=3892.5000
# Month=26, Predicted=3894.1744, Expected=3899.0000
# Month=27, Predicted=3900.6744, Expected=3886.0000
# Month=28, Predicted=3888.9613, Expected=3908.0000
# Month=29, Predicted=3908.6599, Expected=3875.0000
# Month=30, Predicted=3879.2937, Expected=3860.0000
# Month=31, Predicted=3863.0940, Expected=3880.0000
# Month=32, Predicted=3880.7904, Expected=3895.0000
# Month=33, Predicted=3896.1171, Expected=3954.0000
# Month=34, Predicted=3952.2657, Expected=3933.0000
# Month=35, Predicted=3936.4927, Expected=3937.0000
# Month=36, Predicted=3938.8387, Expected=3869.0000
# Month=37, Predicted=3875.6553, Expected=3852.0000
# Month=38, Predicted=3855.2267, Expected=3837.0000
# Month=39, Predicted=3840.0940, Expected=3832.0000
# Month=40, Predicted=3834.4319, Expected=3849.0000
# Month=41, Predicted=3849.9863, Expected=3863.0000
# Month=42, Predicted=3864.1826, Expected=3878.0000
# Month=43, Predicted=3879.1171, Expected=3855.0000
# Month=44, Predicted=3858.6259, Expected=3843.0000
# Month=45, Predicted=3845.8950, Expected=3847.0000
# Month=46, Predicted=3848.8387, Expected=3801.0000
# Month=47, Predicted=3806.1665, Expected=3787.0000
# Month=48, Predicted=3790.0276, Expected=3776.0000
# Month=49, Predicted=3778.8287, Expected=3797.0000
# Month=50, Predicted=3797.7251, Expected=3821.0000
# Month=51, Predicted=3821.5295, Expected=3877.0000
# Month=52, Predicted=3875.4585, Expected=3875.0000
# Month=53, Predicted=3877.2339, Expected=3890.0000
# Month=54, Predicted=3891.1171, Expected=3910.0000
# Month=55, Predicted=3910.7904, Expected=3924.0000
# Month=56, Predicted=3925.1826, Expected=3918.0000
# Month=57, Predicted=3920.4980, Expected=3936.0000
# Month=58, Predicted=3936.9210, Expected=3911.0000
# Month=59, Predicted=3914.7592, Expected=3891.0000
# Month=60, Predicted=3894.4262, Expected=3855.0000
# Run 11 — RMSE: 24.718178, MSE: 610.988343, NMSE: 0.0028252495, Time: 38.4s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3797.8674, Expected=3796.0000
# Month=2, Predicted=3797.5677, Expected=3793.0000
# Month=3, Predicted=3794.6144, Expected=3766.0000
# Month=4, Predicted=3768.7263, Expected=3747.0000
# Month=5, Predicted=3749.3576, Expected=3754.0000
# Month=6, Predicted=3755.1461, Expected=3756.0000
# Month=7, Predicted=3757.3806, Expected=3767.0000
# Month=8, Predicted=3767.9580, Expected=3751.0000
# Month=9, Predicted=3753.2188, Expected=3769.0000
# Month=10, Predicted=3769.6277, Expected=3760.0000
# Month=11, Predicted=3761.8940, Expected=3785.0000
# Month=12, Predicted=3785.2959, Expected=3776.0000
# Month=13, Predicted=3777.8940, Expected=3755.0000
# Month=14, Predicted=3757.4499, Expected=3755.0000
# Month=15, Predicted=3756.4743, Expected=3751.0000
# Month=16, Predicted=3752.6611, Expected=3776.0000
# Month=17, Predicted=3776.2959, Expected=3847.0000
# Month=18, Predicted=3845.0829, Expected=3830.0000
# Month=19, Predicted=3832.2651, Expected=3881.0000
# Month=20, Predicted=3880.0519, Expected=3899.0000
# Month=21, Predicted=3899.6277, Expected=3917.0000
# Month=22, Predicted=3917.6277, Expected=3913.0000
# Month=23, Predicted=3914.6611, Expected=3901.0000
# Month=24, Predicted=3903.0334, Expected=3886.0000
# Month=25, Predicted=3888.1725, Expected=3892.5000
# Month=26, Predicted=3893.6696, Expected=3899.0000
# Month=27, Predicted=3900.1696, Expected=3886.0000
# Month=28, Predicted=3888.0798, Expected=3908.0000
# Month=29, Predicted=3908.4383, Expected=3875.0000
# Month=30, Predicted=3878.0016, Expected=3860.0000
# Month=31, Predicted=3862.1725, Expected=3880.0000
# Month=32, Predicted=3880.5330, Expected=3895.0000
# Month=33, Predicted=3895.7694, Expected=3954.0000
# Month=34, Predicted=3952.6655, Expected=3933.0000
# Month=35, Predicted=3935.4499, Expected=3937.0000
# Month=36, Predicted=3938.2869, Expected=3869.0000
# Month=37, Predicted=3873.5855, Expected=3852.0000
# Month=38, Predicted=3854.2651, Expected=3837.0000
# Month=39, Predicted=3839.1725, Expected=3832.0000
# Month=40, Predicted=3833.7077, Expected=3849.0000
# Month=41, Predicted=3849.6749, Expected=3863.0000
# Month=42, Predicted=3863.8166, Expected=3878.0000
# Month=43, Predicted=3878.7694, Expected=3855.0000
# Month=44, Predicted=3857.5422, Expected=3843.0000
# Month=45, Predicted=3845.0334, Expected=3847.0000
# Month=46, Predicted=3848.2869, Expected=3801.0000
# Month=47, Predicted=3804.5942, Expected=3787.0000
# Month=48, Predicted=3789.1262, Expected=3776.0000
# Month=49, Predicted=3777.9870, Expected=3797.0000
# Month=50, Predicted=3797.4856, Expected=3821.0000
# Month=51, Predicted=3821.3434, Expected=3877.0000
# Month=52, Predicted=3875.8106, Expected=3875.0000
# Month=53, Predicted=3876.5677, Expected=3890.0000
# Month=54, Predicted=3890.7694, Expected=3910.0000
# Month=55, Predicted=3910.5330, Expected=3924.0000
# Month=56, Predicted=3924.8166, Expected=3918.0000
# Month=57, Predicted=3919.7544, Expected=3936.0000
# Month=58, Predicted=3936.6277, Expected=3911.0000
# Month=59, Predicted=3913.6343, Expected=3891.0000
# Month=60, Predicted=3893.4038, Expected=3855.0000
# Run 12 — RMSE: 24.618635, MSE: 606.077205, NMSE: 0.0027968446, Time: 35.5s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3797.7412, Expected=3796.0000
# Month=2, Predicted=3797.8034, Expected=3793.0000
# Month=3, Predicted=3794.8606, Expected=3766.0000
# Month=4, Predicted=3769.2340, Expected=3747.0000
# Month=5, Predicted=3749.7764, Expected=3754.0000
# Month=6, Predicted=3755.2880, Expected=3756.0000
# Month=7, Predicted=3757.5744, Expected=3767.0000
# Month=8, Predicted=3768.0590, Expected=3751.0000
# Month=9, Predicted=3753.6047, Expected=3769.0000
# Month=10, Predicted=3769.6580, Expected=3760.0000
# Month=11, Predicted=3762.2041, Expected=3785.0000
# Month=12, Predicted=3785.2570, Expected=3776.0000
# Month=13, Predicted=3778.2041, Expected=3755.0000
# Month=14, Predicted=3757.8908, Expected=3755.0000
# Month=15, Predicted=3756.6889, Expected=3751.0000
# Month=16, Predicted=3752.9179, Expected=3776.0000
# Month=17, Predicted=3776.2570, Expected=3847.0000
# Month=18, Predicted=3844.6192, Expected=3830.0000
# Month=19, Predicted=3832.6619, Expected=3881.0000
# Month=20, Predicted=3879.7665, Expected=3899.0000
# Month=21, Predicted=3899.6580, Expected=3917.0000
# Month=22, Predicted=3917.6580, Expected=3913.0000
# Month=23, Predicted=3914.9179, Expected=3901.0000
# Month=24, Predicted=3903.3758, Expected=3886.0000
# Month=25, Predicted=3888.5475, Expected=3892.5000
# Month=26, Predicted=3893.8167, Expected=3899.0000
# Month=27, Predicted=3900.3167, Expected=3886.0000
# Month=28, Predicted=3888.4330, Expected=3908.0000
# Month=29, Predicted=3908.4288, Expected=3875.0000
# Month=30, Predicted=3878.5772, Expected=3860.0000
# Month=31, Predicted=3862.5475, Expected=3880.0000
# Month=32, Predicted=3880.5434, Expected=3895.0000
# Month=33, Predicted=3895.8299, Expected=3954.0000
# Month=34, Predicted=3952.3077, Expected=3933.0000
# Month=35, Predicted=3935.8908, Expected=3937.0000
# Month=36, Predicted=3938.4598, Expected=3869.0000
# Month=37, Predicted=3874.5778, Expected=3852.0000
# Month=38, Predicted=3854.6619, Expected=3837.0000
# Month=39, Predicted=3839.5475, Expected=3832.0000
# Month=40, Predicted=3833.9751, Expected=3849.0000
# Month=41, Predicted=3849.7153, Expected=3863.0000
# Month=42, Predicted=3863.8871, Expected=3878.0000
# Month=43, Predicted=3878.8299, Expected=3855.0000
# Month=44, Predicted=3858.0052, Expected=3843.0000
# Month=45, Predicted=3845.3758, Expected=3847.0000
# Month=46, Predicted=3848.4598, Expected=3801.0000
# Month=47, Predicted=3805.3206, Expected=3787.0000
# Month=48, Predicted=3789.4902, Expected=3776.0000
# Month=49, Predicted=3778.3185, Expected=3797.0000
# Month=50, Predicted=3797.4861, Expected=3821.0000
# Month=51, Predicted=3821.3143, Expected=3877.0000
# Month=52, Predicted=3875.4798, Expected=3875.0000
# Month=53, Predicted=3876.8034, Expected=3890.0000
# Month=54, Predicted=3890.8299, Expected=3910.0000
# Month=55, Predicted=3910.5434, Expected=3924.0000
# Month=56, Predicted=3924.8871, Expected=3918.0000
# Month=57, Predicted=3920.0324, Expected=3936.0000
# Month=58, Predicted=3936.6580, Expected=3911.0000
# Month=59, Predicted=3914.1196, Expected=3891.0000
# Month=60, Predicted=3893.8336, Expected=3855.0000
# Run 13 — RMSE: 24.666383, MSE: 608.430457, NMSE: 0.0028111237, Time: 38.2s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3797.7072, Expected=3796.0000
# Month=2, Predicted=3797.5625, Expected=3793.0000
# Month=3, Predicted=3794.5978, Expected=3766.0000
# Month=4, Predicted=3768.0816, Expected=3747.0000
# Month=5, Predicted=3748.9664, Expected=3754.0000
# Month=6, Predicted=3755.1860, Expected=3756.0000
# Month=7, Predicted=3757.4075, Expected=3767.0000
# Month=8, Predicted=3767.9909, Expected=3751.0000
# Month=9, Predicted=3752.9215, Expected=3769.0000
# Month=10, Predicted=3769.6216, Expected=3760.0000
# Month=11, Predicted=3761.7779, Expected=3785.0000
# Month=12, Predicted=3785.2295, Expected=3776.0000
# Month=13, Predicted=3777.7779, Expected=3755.0000
# Month=14, Predicted=3756.9935, Expected=3755.0000
# Month=15, Predicted=3756.4877, Expected=3751.0000
# Month=16, Predicted=3752.6316, Expected=3776.0000
# Month=17, Predicted=3776.2295, Expected=3847.0000
# Month=18, Predicted=3844.4849, Expected=3830.0000
# Month=19, Predicted=3831.9373, Expected=3881.0000
# Month=20, Predicted=3879.6955, Expected=3899.0000
# Month=21, Predicted=3899.6216, Expected=3917.0000
# Month=22, Predicted=3917.6216, Expected=3913.0000
# Month=23, Predicted=3914.6316, Expected=3901.0000
# Month=24, Predicted=3902.8475, Expected=3886.0000
# Month=25, Predicted=3887.9048, Expected=3892.5000
# Month=26, Predicted=3893.7094, Expected=3899.0000
# Month=27, Predicted=3900.2094, Expected=3886.0000
# Month=28, Predicted=3887.8679, Expected=3908.0000
# Month=29, Predicted=3908.3996, Expected=3875.0000
# Month=30, Predicted=3877.2315, Expected=3860.0000
# Month=31, Predicted=3861.9048, Expected=3880.0000
# Month=32, Predicted=3880.5114, Expected=3895.0000
# Month=33, Predicted=3895.7834, Expected=3954.0000
# Month=34, Predicted=3952.2134, Expected=3933.0000
# Month=35, Predicted=3934.9935, Expected=3937.0000
# Month=36, Predicted=3938.3223, Expected=3869.0000
# Month=37, Predicted=3877.3441, Expected=3852.0000
# Month=38, Predicted=3853.9373, Expected=3837.0000
# Month=39, Predicted=3838.9048, Expected=3832.0000
# Month=40, Predicted=3833.6639, Expected=3849.0000
# Month=41, Predicted=3849.6761, Expected=3863.0000
# Month=42, Predicted=3863.8363, Expected=3878.0000
# Month=43, Predicted=3878.7834, Expected=3855.0000
# Month=44, Predicted=3857.0204, Expected=3843.0000
# Month=45, Predicted=3844.8475, Expected=3847.0000
# Month=46, Predicted=3848.3223, Expected=3801.0000
# Month=47, Predicted=3804.1779, Expected=3787.0000
# Month=48, Predicted=3788.8870, Expected=3776.0000
# Month=49, Predicted=3777.8257, Expected=3797.0000
# Month=50, Predicted=3797.4557, Expected=3821.0000
# Month=51, Predicted=3821.2865, Expected=3877.0000
# Month=52, Predicted=3875.3945, Expected=3875.0000
# Month=53, Predicted=3876.5625, Expected=3890.0000
# Month=54, Predicted=3890.7834, Expected=3910.0000
# Month=55, Predicted=3910.5114, Expected=3924.0000
# Month=56, Predicted=3924.8363, Expected=3918.0000
# Month=57, Predicted=3919.6947, Expected=3936.0000
# Month=58, Predicted=3936.6216, Expected=3911.0000
# Month=59, Predicted=3913.0489, Expected=3891.0000
# Month=60, Predicted=3892.9801, Expected=3855.0000
# Run 14 — RMSE: 24.646052, MSE: 607.427904, NMSE: 0.0028003732, Time: 38.9s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3797.5079, Expected=3796.0000
# Month=2, Predicted=3797.0003, Expected=3793.0000
# Month=3, Predicted=3794.0409, Expected=3766.0000
# Month=4, Predicted=3768.0023, Expected=3747.0000
# Month=5, Predicted=3748.6847, Expected=3754.0000
# Month=6, Predicted=3754.6326, Expected=3756.0000
# Month=7, Predicted=3756.8373, Expected=3767.0000
# Month=8, Predicted=3767.4679, Expected=3751.0000
# Month=9, Predicted=3752.5649, Expected=3769.0000
# Month=10, Predicted=3769.1782, Expected=3760.0000
# Month=11, Predicted=3761.2837, Expected=3785.0000
# Month=12, Predicted=3784.8862, Expected=3776.0000
# Month=13, Predicted=3777.2837, Expected=3755.0000
# Month=14, Predicted=3756.7644, Expected=3755.0000
# Month=15, Predicted=3755.9189, Expected=3751.0000
# Month=16, Predicted=3752.0815, Expected=3776.0000
# Month=17, Predicted=3775.8862, Expected=3847.0000
# Month=18, Predicted=3844.9214, Expected=3830.0000
# Month=19, Predicted=3831.6049, Expected=3881.0000
# Month=20, Predicted=3879.7846, Expected=3899.0000
# Month=21, Predicted=3899.1782, Expected=3917.0000
# Month=22, Predicted=3917.1782, Expected=3913.0000
# Month=23, Predicted=3914.0815, Expected=3901.0000
# Month=24, Predicted=3902.4045, Expected=3886.0000
# Month=25, Predicted=3887.5249, Expected=3892.5000
# Month=26, Predicted=3893.1531, Expected=3899.0000
# Month=27, Predicted=3899.6531, Expected=3886.0000
# Month=28, Predicted=3887.4447, Expected=3908.0000
# Month=29, Predicted=3908.0116, Expected=3875.0000
# Month=30, Predicted=3877.2386, Expected=3860.0000
# Month=31, Predicted=3861.5249, Expected=3880.0000
# Month=32, Predicted=3880.0950, Expected=3895.0000
# Month=33, Predicted=3895.3026, Expected=3954.0000
# Month=34, Predicted=3952.4408, Expected=3933.0000
# Month=35, Predicted=3934.7644, Expected=3937.0000
# Month=36, Predicted=3937.7555, Expected=3869.0000
# Month=37, Predicted=3872.5884, Expected=3852.0000
# Month=38, Predicted=3853.6049, Expected=3837.0000
# Month=39, Predicted=3838.5249, Expected=3832.0000
# Month=40, Predicted=3833.1220, Expected=3849.0000
# Month=41, Predicted=3849.2197, Expected=3863.0000
# Month=42, Predicted=3863.3440, Expected=3878.0000
# Month=43, Predicted=3878.3026, Expected=3855.0000
# Month=44, Predicted=3856.8439, Expected=3843.0000
# Month=45, Predicted=3844.4045, Expected=3847.0000
# Month=46, Predicted=3847.7555, Expected=3801.0000
# Month=47, Predicted=3803.7455, Expected=3787.0000
# Month=48, Predicted=3788.4848, Expected=3776.0000
# Month=49, Predicted=3777.3643, Expected=3797.0000
# Month=50, Predicted=3797.0533, Expected=3821.0000
# Month=51, Predicted=3820.9281, Expected=3877.0000
# Month=52, Predicted=3875.5700, Expected=3875.0000
# Month=53, Predicted=3876.0003, Expected=3890.0000
# Month=54, Predicted=3890.3026, Expected=3910.0000
# Month=55, Predicted=3910.0950, Expected=3924.0000
# Month=56, Predicted=3924.3440, Expected=3918.0000
# Month=57, Predicted=3919.1625, Expected=3936.0000
# Month=58, Predicted=3936.1782, Expected=3911.0000
# Month=59, Predicted=3912.9232, Expected=3891.0000
# Month=60, Predicted=3892.7246, Expected=3855.0000
# Run 15 — RMSE: 24.591701, MSE: 604.751738, NMSE: 0.0027887532, Time: 36.5s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3795.8616, Expected=3796.0000
# Month=2, Predicted=3797.7255, Expected=3793.0000
# Month=3, Predicted=3794.7274, Expected=3766.0000
# Month=4, Predicted=3767.7174, Expected=3747.0000
# Month=5, Predicted=3748.6735, Expected=3754.0000
# Month=6, Predicted=3755.5502, Expected=3756.0000
# Month=7, Predicted=3757.6894, Expected=3767.0000
# Month=8, Predicted=3768.3338, Expected=3751.0000
# Month=9, Predicted=3752.6756, Expected=3769.0000
# Month=10, Predicted=3769.6736, Expected=3760.0000
# Month=11, Predicted=3761.7076, Expected=3785.0000
# Month=12, Predicted=3784.6371, Expected=3776.0000
# Month=13, Predicted=3777.7076, Expected=3755.0000
# Month=14, Predicted=3756.6776, Expected=3755.0000
# Month=15, Predicted=3756.7139, Expected=3751.0000
# Month=16, Predicted=3752.7273, Expected=3776.0000
# Month=17, Predicted=3775.6371, Expected=3847.0000
# Month=18, Predicted=3836.7398, Expected=3830.0000
# Month=19, Predicted=3831.6739, Expected=3881.0000
# Month=20, Predicted=3875.0168, Expected=3899.0000
# Month=21, Predicted=3899.6736, Expected=3917.0000
# Month=22, Predicted=3917.6736, Expected=3913.0000
# Month=23, Predicted=3914.7273, Expected=3901.0000
# Month=24, Predicted=3902.6911, Expected=3886.0000
# ...
# Month=55, Predicted=3910.6143, Expected=3924.0000
# Month=56, Predicted=3924.8722, Expected=3918.0000
# Month=57, Predicted=3919.5973, Expected=3936.0000
# Month=58, Predicted=3936.7013, Expected=3911.0000
# Month=59, Predicted=3912.7684, Expected=3891.0000
# Month=60, Predicted=3892.7948, Expected=3855.0000
# Run 25 — RMSE: 24.558631, MSE: 603.126352, NMSE: 0.0027781391, Time: 81.9s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3796.8878, Expected=3796.0000
# Month=2, Predicted=3798.3200, Expected=3793.0000
# Month=3, Predicted=3795.3228, Expected=3766.0000
# Month=4, Predicted=3768.2042, Expected=3747.0000
# Month=5, Predicted=3749.2261, Expected=3754.0000
# Month=6, Predicted=3756.1503, Expected=3756.0000
# Month=7, Predicted=3758.2814, Expected=3767.0000
# Month=8, Predicted=3768.9580, Expected=3751.0000
# Month=9, Predicted=3753.2470, Expected=3769.0000
# Month=10, Predicted=3770.3896, Expected=3760.0000
# Month=11, Predicted=3762.3028, Expected=3785.0000
# Month=12, Predicted=3785.4940, Expected=3776.0000
# Month=13, Predicted=3778.3028, Expected=3755.0000
# Month=14, Predicted=3757.2155, Expected=3755.0000
# Month=15, Predicted=3757.3068, Expected=3751.0000
# Month=16, Predicted=3753.3235, Expected=3776.0000
# Month=17, Predicted=3776.4940, Expected=3847.0000
# Month=18, Predicted=3837.2144, Expected=3830.0000
# Month=19, Predicted=3832.2395, Expected=3881.0000
# Month=20, Predicted=3875.9903, Expected=3899.0000
# Month=21, Predicted=3900.3896, Expected=3917.0000
# Month=22, Predicted=3918.3896, Expected=3913.0000
# Month=23, Predicted=3915.3235, Expected=3901.0000
# Month=24, Predicted=3903.2796, Expected=3886.0000
# Month=25, Predicted=3888.2549, Expected=3892.5000
# Month=26, Predicted=3894.6684, Expected=3899.0000
# Month=27, Predicted=3901.1684, Expected=3886.0000
# Month=28, Predicted=3888.2713, Expected=3908.0000
# Month=29, Predicted=3908.9184, Expected=3875.0000
# Month=30, Predicted=3877.2268, Expected=3860.0000
# Month=31, Predicted=3862.2549, Expected=3880.0000
# Month=32, Predicted=3881.1677, Expected=3895.0000
# Month=33, Predicted=3896.6720, Expected=3954.0000
# Month=34, Predicted=3947.0474, Expected=3933.0000
# Month=35, Predicted=3935.2155, Expected=3937.0000
# Month=36, Predicted=3939.2417, Expected=3869.0000
# Month=37, Predicted=3871.7601, Expected=3852.0000
# Month=38, Predicted=3854.2395, Expected=3837.0000
# Month=39, Predicted=3839.2549, Expected=3832.0000
# Month=40, Predicted=3834.3222, Expected=3849.0000
# Month=41, Predicted=3850.4904, Expected=3863.0000
# Month=42, Predicted=3864.7529, Expected=3878.0000
# Month=43, Predicted=3879.6720, Expected=3855.0000
# Month=44, Predicted=3857.2081, Expected=3843.0000
# Month=45, Predicted=3845.2796, Expected=3847.0000
# Month=46, Predicted=3849.2417, Expected=3801.0000
# Month=47, Predicted=3803.3719, Expected=3787.0000
# Month=48, Predicted=3789.2630, Expected=3776.0000
# Month=49, Predicted=3778.2877, Expected=3797.0000
# Month=50, Predicted=3798.0465, Expected=3821.0000
# Month=51, Predicted=3821.6422, Expected=3877.0000
# Month=52, Predicted=3870.7737, Expected=3875.0000
# Month=53, Predicted=3877.3200, Expected=3890.0000
# Month=54, Predicted=3891.6720, Expected=3910.0000
# Month=55, Predicted=3911.1677, Expected=3924.0000
# Month=56, Predicted=3925.7529, Expected=3918.0000
# Month=57, Predicted=3920.3192, Expected=3936.0000
# Month=58, Predicted=3937.3896, Expected=3911.0000
# Month=59, Predicted=3913.2043, Expected=3891.0000
# Month=60, Predicted=3893.2204, Expected=3855.0000
# Run 26 — RMSE: 24.509154, MSE: 600.698647, NMSE: 0.0027887494, Time: 69.5s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3797.3521, Expected=3796.0000
# Month=2, Predicted=3797.2330, Expected=3793.0000
# Month=3, Predicted=3794.2851, Expected=3766.0000
# Month=4, Predicted=3768.5359, Expected=3747.0000
# Month=5, Predicted=3749.1190, Expected=3754.0000
# Month=6, Predicted=3754.7635, Expected=3756.0000
# Month=7, Predicted=3757.0244, Expected=3767.0000
# Month=8, Predicted=3767.5548, Expected=3751.0000
# Month=9, Predicted=3752.9627, Expected=3769.0000
# Month=10, Predicted=3769.1892, Expected=3760.0000
# Month=11, Predicted=3761.5979, Expected=3785.0000
# Month=12, Predicted=3784.8232, Expected=3776.0000
# Month=13, Predicted=3777.5979, Expected=3755.0000
# Month=14, Predicted=3757.2232, Expected=3755.0000
# Month=15, Predicted=3756.1287, Expected=3751.0000
# Month=16, Predicted=3752.3372, Expected=3776.0000
# Month=17, Predicted=3775.8232, Expected=3847.0000
# Month=18, Predicted=3844.4067, Expected=3830.0000
# Month=19, Predicted=3832.0148, Expected=3881.0000
# Month=20, Predicted=3879.4600, Expected=3899.0000
# Month=21, Predicted=3899.1892, Expected=3917.0000
# Month=22, Predicted=3917.1892, Expected=3913.0000
# Month=23, Predicted=3914.3372, Expected=3901.0000
# Month=24, Predicted=3902.7542, Expected=3886.0000
# Month=25, Predicted=3887.9106, Expected=3892.5000
# Month=26, Predicted=3893.2896, Expected=3899.0000
# Month=27, Predicted=3899.7896, Expected=3886.0000
# Month=28, Predicted=3887.8063, Expected=3908.0000
# Month=29, Predicted=3907.9801, Expected=3875.0000
# Month=30, Predicted=3877.8488, Expected=3860.0000
# Month=31, Predicted=3861.9106, Expected=3880.0000
# Month=32, Predicted=3880.0846, Expected=3895.0000
# Month=33, Predicted=3895.3459, Expected=3954.0000
# Month=34, Predicted=3952.0392, Expected=3933.0000
# Month=35, Predicted=3935.2232, Expected=3937.0000
# Month=36, Predicted=3937.9201, Expected=3869.0000
# Month=37, Predicted=3873.6787, Expected=3852.0000
# Month=38, Predicted=3854.0148, Expected=3837.0000
# Month=39, Predicted=3838.9106, Expected=3832.0000
# Month=40, Predicted=3833.3894, Expected=3849.0000
# Month=41, Predicted=3849.2414, Expected=3863.0000
# Month=42, Predicted=3863.3981, Expected=3878.0000
# Month=43, Predicted=3878.3459, Expected=3855.0000
# Month=44, Predicted=3857.3275, Expected=3843.0000
# Month=45, Predicted=3844.7542, Expected=3847.0000
# Month=46, Predicted=3847.9201, Expected=3801.0000
# Month=47, Predicted=3804.5271, Expected=3787.0000
# Month=48, Predicted=3788.8584, Expected=3776.0000
# Month=49, Predicted=3777.7021, Expected=3797.0000
# Month=50, Predicted=3797.0324, Expected=3821.0000
# Month=51, Predicted=3820.8755, Expected=3877.0000
# Month=52, Predicted=3875.1971, Expected=3875.0000
# Month=53, Predicted=3876.2330, Expected=3890.0000
# Month=54, Predicted=3890.3459, Expected=3910.0000
# Month=55, Predicted=3910.0846, Expected=3924.0000
# Month=56, Predicted=3924.3981, Expected=3918.0000
# Month=57, Predicted=3919.4415, Expected=3936.0000
# Month=58, Predicted=3936.1892, Expected=3911.0000
# Month=59, Predicted=3913.4317, Expected=3891.0000
# Month=60, Predicted=3893.1711, Expected=3855.0000
# Run 27 — RMSE: 24.638166, MSE: 607.039214, NMSE: 0.0028031982, Time: 59.3s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3797.6776, Expected=3796.0000
# Month=2, Predicted=3796.9379, Expected=3793.0000
# Month=3, Predicted=3793.9714, Expected=3766.0000
# Month=4, Predicted=3767.7541, Expected=3747.0000
# Month=5, Predicted=3748.4981, Expected=3754.0000
# Month=6, Predicted=3754.6322, Expected=3756.0000
# Month=7, Predicted=3756.8028, Expected=3767.0000
# Month=8, Predicted=3767.4943, Expected=3751.0000
# Month=9, Predicted=3752.4008, Expected=3769.0000
# Month=10, Predicted=3769.2500, Expected=3760.0000
# Month=11, Predicted=3761.1712, Expected=3785.0000
# Month=12, Predicted=3785.0019, Expected=3776.0000
# Month=13, Predicted=3777.1712, Expected=3755.0000
# Month=14, Predicted=3756.5625, Expected=3755.0000
# Month=15, Predicted=3755.8705, Expected=3751.0000
# Month=16, Predicted=3752.0049, Expected=3776.0000
# Month=17, Predicted=3776.0019, Expected=3847.0000
# Month=18, Predicted=3845.2853, Expected=3830.0000
# Month=19, Predicted=3831.4333, Expected=3881.0000
# Month=20, Predicted=3880.0490, Expected=3899.0000
# Month=21, Predicted=3899.2500, Expected=3917.0000
# Month=22, Predicted=3917.2500, Expected=3913.0000
# Month=23, Predicted=3914.0049, Expected=3901.0000
# Month=24, Predicted=3902.2701, Expected=3886.0000
# Month=25, Predicted=3887.3683, Expected=3892.5000
# Month=26, Predicted=3893.1493, Expected=3899.0000
# Month=27, Predicted=3899.6493, Expected=3886.0000
# Month=28, Predicted=3887.3029, Expected=3908.0000
# Month=29, Predicted=3908.1087, Expected=3875.0000
# Month=30, Predicted=3876.9431, Expected=3860.0000
# Month=31, Predicted=3861.3683, Expected=3880.0000
# Month=32, Predicted=3880.1795, Expected=3895.0000
# Month=33, Predicted=3895.3552, Expected=3954.0000
# Month=34, Predicted=3952.7465, Expected=3933.0000
# Month=35, Predicted=3934.5625, Expected=3937.0000
# Month=36, Predicted=3937.7348, Expected=3869.0000
# Month=37, Predicted=3871.9983, Expected=3852.0000
# Month=38, Predicted=3853.4333, Expected=3837.0000
# Month=39, Predicted=3838.3683, Expected=3832.0000
# Month=40, Predicted=3833.0383, Expected=3849.0000
# Month=41, Predicted=3849.2851, Expected=3863.0000
# Month=42, Predicted=3863.3901, Expected=3878.0000
# Month=43, Predicted=3878.3552, Expected=3855.0000
# Month=44, Predicted=3856.6267, Expected=3843.0000
# Month=45, Predicted=3844.2701, Expected=3847.0000
# Month=46, Predicted=3847.7348, Expected=3801.0000
# Month=47, Predicted=3803.3440, Expected=3787.0000
# Month=48, Predicted=3788.3356, Expected=3776.0000
# Month=49, Predicted=3777.2372, Expected=3797.0000
# Month=50, Predicted=3797.1442, Expected=3821.0000
# Month=51, Predicted=3821.0376, Expected=3877.0000
# Month=52, Predicted=3875.8604, Expected=3875.0000
# Month=53, Predicted=3875.9379, Expected=3890.0000
# Month=54, Predicted=3890.3552, Expected=3910.0000
# Month=55, Predicted=3910.1795, Expected=3924.0000
# Month=56, Predicted=3924.3901, Expected=3918.0000
# Month=57, Predicted=3919.0717, Expected=3936.0000
# Month=58, Predicted=3936.2500, Expected=3911.0000
# Month=59, Predicted=3912.6906, Expected=3891.0000
# Month=60, Predicted=3892.5303, Expected=3855.0000
# Run 28 — RMSE: 24.564532, MSE: 603.416247, NMSE: 0.0027802429, Time: 65.2s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3797.5623, Expected=3796.0000
# Month=2, Predicted=3797.0145, Expected=3793.0000
# Month=3, Predicted=3794.0544, Expected=3766.0000
# Month=4, Predicted=3768.0066, Expected=3747.0000
# Month=5, Predicted=3748.6905, Expected=3754.0000
# Month=6, Predicted=3754.6541, Expected=3756.0000
# Month=7, Predicted=3756.8545, Expected=3767.0000
# Month=8, Predicted=3767.4934, Expected=3751.0000
# Month=9, Predicted=3752.5717, Expected=3769.0000
# Month=10, Predicted=3769.2112, Expected=3760.0000
# Month=11, Predicted=3761.2936, Expected=3785.0000
# Month=12, Predicted=3784.9280, Expected=3776.0000
# Month=13, Predicted=3777.2936, Expected=3755.0000
# Month=14, Predicted=3756.7697, Expected=3755.0000
# Month=15, Predicted=3755.9346, Expected=3751.0000
# Month=16, Predicted=3752.0943, Expected=3776.0000
# Month=17, Predicted=3775.9280, Expected=3847.0000
# Month=18, Predicted=3845.0396, Expected=3830.0000
# Month=19, Predicted=3831.6113, Expected=3881.0000
# Month=20, Predicted=3879.8665, Expected=3899.0000
# Month=21, Predicted=3899.2112, Expected=3917.0000
# Month=22, Predicted=3917.2112, Expected=3913.0000
# Month=23, Predicted=3914.0943, Expected=3901.0000
# Month=24, Predicted=3902.4129, Expected=3886.0000
# Month=25, Predicted=3887.5320, Expected=3892.5000
# Month=26, Predicted=3893.1742, Expected=3899.0000
# Month=27, Predicted=3899.6742, Expected=3886.0000
# Month=28, Predicted=3887.4526, Expected=3908.0000
# Month=29, Predicted=3908.0495, Expected=3875.0000
# Month=30, Predicted=3877.2428, Expected=3860.0000
# Month=31, Predicted=3861.5320, Expected=3880.0000
# Month=32, Predicted=3880.1304, Expected=3895.0000
# Month=33, Predicted=3895.3323, Expected=3954.0000
# Month=34, Predicted=3952.5368, Expected=3933.0000
# Month=35, Predicted=3934.7697, Expected=3937.0000
# Month=36, Predicted=3937.7744, Expected=3869.0000
# Month=37, Predicted=3872.6075, Expected=3852.0000
# Month=38, Predicted=3853.6113, Expected=3837.0000
# Month=39, Predicted=3838.5320, Expected=3832.0000
# Month=40, Predicted=3833.1342, Expected=3849.0000
# Month=41, Predicted=3849.2516, Expected=3863.0000
# Month=42, Predicted=3863.3726, Expected=3878.0000
# Month=43, Predicted=3878.3323, Expected=3855.0000
# Month=44, Predicted=3856.8487, Expected=3843.0000
# Month=45, Predicted=3844.4129, Expected=3847.0000
# Month=46, Predicted=3847.7744, Expected=3801.0000
# Month=47, Predicted=3803.7523, Expected=3787.0000
# Month=48, Predicted=3788.4923, Expected=3776.0000
# Month=49, Predicted=3777.3731, Expected=3797.0000
# Month=50, Predicted=3797.0900, Expected=3821.0000
# Month=51, Predicted=3820.9685, Expected=3877.0000
# Month=52, Predicted=3875.6606, Expected=3875.0000
# Month=53, Predicted=3876.0145, Expected=3890.0000
# Month=54, Predicted=3890.3323, Expected=3910.0000
# Month=55, Predicted=3910.1304, Expected=3924.0000
# Month=56, Predicted=3924.3726, Expected=3918.0000
# Month=57, Predicted=3919.1741, Expected=3936.0000
# Month=58, Predicted=3936.2112, Expected=3911.0000
# Month=59, Predicted=3912.9277, Expected=3891.0000
# Month=60, Predicted=3892.7301, Expected=3855.0000
# Run 29 — RMSE: 24.590247, MSE: 604.680233, NMSE: 0.0027880041, Time: 69.7s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3797.8157, Expected=3796.0000
# Month=2, Predicted=3797.2003, Expected=3793.0000
# Month=3, Predicted=3794.2386, Expected=3766.0000
# Month=4, Predicted=3768.1548, Expected=3747.0000
# Month=5, Predicted=3748.8500, Expected=3754.0000
# Month=6, Predicted=3754.8553, Expected=3756.0000
# Month=7, Predicted=3757.0470, Expected=3767.0000
# Month=8, Predicted=3767.7017, Expected=3751.0000
# Month=9, Predicted=3752.7355, Expected=3769.0000
# Month=10, Predicted=3769.4325, Expected=3760.0000
# Month=11, Predicted=3761.4681, Expected=3785.0000
# Month=12, Predicted=3785.1630, Expected=3776.0000
# Month=13, Predicted=3777.4681, Expected=3755.0000
# Month=14, Predicted=3756.9262, Expected=3755.0000
# Month=15, Predicted=3756.1237, Expected=3751.0000
# Month=16, Predicted=3752.2769, Expected=3776.0000
# Month=17, Predicted=3776.1630, Expected=3847.0000
# Month=18, Predicted=3845.3808, Expected=3830.0000
# Month=19, Predicted=3831.7737, Expected=3881.0000
# Month=20, Predicted=3880.1579, Expected=3899.0000
# Month=21, Predicted=3899.4325, Expected=3917.0000
# Month=22, Predicted=3917.4325, Expected=3913.0000
# Month=23, Predicted=3914.2769, Expected=3901.0000
# Month=24, Predicted=3902.5828, Expected=3886.0000
# Month=25, Predicted=3887.6973, Expected=3892.5000
# Month=26, Predicted=3893.3744, Expected=3899.0000
# Month=27, Predicted=3899.8744, Expected=3886.0000
# Month=28, Predicted=3887.6210, Expected=3908.0000
# Month=29, Predicted=3908.2785, Expected=3875.0000
# Month=30, Predicted=3877.3829, Expected=3860.0000
# Month=31, Predicted=3861.6973, Expected=3880.0000
# Month=32, Predicted=3880.3556, Expected=3895.0000
# Month=33, Predicted=3895.5479, Expected=3954.0000
# Month=34, Predicted=3952.8475, Expected=3933.0000
# Month=35, Predicted=3934.9262, Expected=3937.0000
# Month=36, Predicted=3937.9703, Expected=3869.0000
# Month=37, Predicted=3872.7071, Expected=3852.0000
# Month=38, Predicted=3853.7737, Expected=3837.0000
# Month=39, Predicted=3838.6973, Expected=3832.0000
# Month=40, Predicted=3833.3151, Expected=3849.0000
# Month=41, Predicted=3849.4710, Expected=3863.0000
# Month=42, Predicted=3863.5864, Expected=3878.0000
# Month=43, Predicted=3878.5479, Expected=3855.0000
# Month=44, Predicted=3857.0024, Expected=3843.0000
# Month=45, Predicted=3844.5828, Expected=3847.0000
# Month=46, Predicted=3847.9703, Expected=3801.0000
# Month=47, Predicted=3803.8761, Expected=3787.0000
# Month=48, Predicted=3788.6592, Expected=3776.0000
# Month=49, Predicted=3777.5446, Expected=3797.0000
# Month=50, Predicted=3797.3171, Expected=3821.0000
# Month=51, Predicted=3821.2015, Expected=3877.0000
# Month=52, Predicted=3875.9639, Expected=3875.0000
# Month=53, Predicted=3876.2003, Expected=3890.0000
# Month=54, Predicted=3890.5479, Expected=3910.0000
# Month=55, Predicted=3910.3556, Expected=3924.0000
# Month=56, Predicted=3924.5864, Expected=3918.0000
# Month=57, Predicted=3919.3534, Expected=3936.0000
# Month=58, Predicted=3936.4325, Expected=3911.0000
# Month=59, Predicted=3913.0786, Expected=3891.0000
# Month=60, Predicted=3892.8881, Expected=3855.0000
# Run 30 — RMSE: 24.584769, MSE: 604.410879, NMSE: 0.0027860581, Time: 66.8s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — FEDformer on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.607428 ± 0.049415
# MSE:  605.527958 ± 2.432275
# NMSE: 0.0027958988 ± 0.0000147224
# Avg training time: 48.9s ± 19.2s
#
# Best run: 26
#   RMSE: 24.509154
#   MSE:  600.698647
#   NMSE: 0.0027887494

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('FEDformer — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('FEDformer — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.509154
# MSE:  600.698647
# NMSE: 0.0027887494

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'FEDformer_DowJones_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to FEDformer_DowJones_predictions.csv

# %% [markdown]
# ## Observations
#
# ### FEDformer on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
