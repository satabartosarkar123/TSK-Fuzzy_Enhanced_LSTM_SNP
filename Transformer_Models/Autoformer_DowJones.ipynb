# %% [markdown]
# # Autoformer — Dow Jones Industrial Index
#
# **Model**: Auto-Correlation with Series Decomposition
# **Reference**: Wu et al., 2021 — Autoformer: Decomposition Transformers with Auto-Correlation for Long-Term Series Forecasting
#
# ## Description
# This notebook implements the **Autoformer** Transformer architecture for univariate time-series
# forecasting on the Dow Jones Industrial Index dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: Autoformer Architecture
#
# ### Series Decomposition
# Autoformer applies deep decomposition at each encoder layer:
#
# $$X_{\text{seasonal}}, X_{\text{trend}} = \text{SeriesDecomp}(X)$$
#
# The trend is extracted via moving average:
# $$X_{\text{trend}} = \text{AvgPool}(\text{Padding}(X))$$
# $$X_{\text{seasonal}} = X - X_{\text{trend}}$$
#
# ### Auto-Correlation Mechanism
# Instead of point-wise attention, Autoformer discovers **period-based dependencies** using FFT:
#
# 1. Compute auto-correlation via FFT: $R_{QK}(\tau) = \mathcal{F}^{-1}(\mathcal{F}(Q) \cdot \overline{\mathcal{F}(K)})$
# 2. Select top-$k$ time delays with highest correlation
# 3. Aggregate values at those delays with softmax weights
#
# This captures inherent periodicity in time series more naturally than dot-product attention.
#
# ### Complexity
# Auto-correlation operates in $O(L \log L)$ via FFT.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### Autoformer Model Definition

# %%
# ============================================================
# Autoformer: Auto-Correlation with Series Decomposition
# Reference: Wu et al., 2021
#
# Key ideas:
# 1. Series decomposition: separate trend and seasonal components
# 2. Auto-Correlation mechanism: replaces self-attention with
#    period-based dependencies via FFT
# ============================================================

class SeriesDecomposition(nn.Module):
    """Series decomposition block: extract trend via moving average."""
    def __init__(self, kernel_size=3):
        super().__init__()
        self.kernel_size = kernel_size
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        # x: (B, L, D)
        # Transpose for AvgPool1d: (B, D, L)
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class AutoCorrelationLayer(nn.Module):
    """
    Auto-Correlation Mechanism.
    Uses FFT to find period-based dependencies, then aggregates
    top-k correlated time delays.
    """
    def __init__(self, d_model, n_heads, factor=3):
        super().__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.factor = factor

        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, _ = x.shape
        H = self.n_heads
        D = self.d_k

        Q = self.W_Q(x).view(B, L, H, D).transpose(1, 2)  # [B, H, L, D]
        K = self.W_K(x).view(B, L, H, D).transpose(1, 2)
        V = self.W_V(x).view(B, L, H, D).transpose(1, 2)

        # Auto-correlation via FFT
        Q_fft = torch.fft.rfft(Q, dim=2)
        K_fft = torch.fft.rfft(K, dim=2)

        # Cross-correlation in frequency domain
        corr = Q_fft * torch.conj(K_fft)
        corr_real = torch.fft.irfft(corr, n=L, dim=2)  # [B, H, L, D]

        # Find top-k delays
        top_k = max(1, int(self.factor * np.log(L + 1)))
        top_k = min(top_k, L)

        # Mean correlation across D dimension
        mean_corr = corr_real.mean(dim=-1)  # [B, H, L]
        _, top_idx = mean_corr.topk(top_k, dim=-1)  # [B, H, top_k]

        # Aggregate values at top-k delays
        weights = torch.softmax(
            torch.gather(mean_corr, -1, top_idx), dim=-1
        )  # [B, H, top_k]

        # Roll and aggregate
        output = torch.zeros_like(V)
        for i in range(top_k):
            delay = top_idx[:, :, i:i+1].unsqueeze(-1).expand(-1, -1, -1, D)
            w = weights[:, :, i:i+1].unsqueeze(-1)  # [B, H, 1, 1]
            rolled_V = torch.roll(V, shifts=1, dims=2)  # Approximate roll
            output = output + w * rolled_V

        output = output.transpose(1, 2).contiguous().view(B, L, self.d_model)
        return self.out_proj(output)


class AutoformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.decomp1 = SeriesDecomposition(kernel_size=3)
        self.decomp2 = SeriesDecomposition(kernel_size=3)
        self.auto_corr = AutoCorrelationLayer(d_model, n_heads)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Auto-correlation + decomposition
        attn_out = self.auto_corr(x)
        x = x + self.dropout(attn_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class AutoformerModel(nn.Module):
    """
    Autoformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.decomp_init = SeriesDecomposition(kernel_size=3)
        self.encoder_layers = nn.ModuleList([
            AutoformerEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20129
# Trainable parameters: 20129
# Memory estimate: 78.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 1), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3798.8703, Expected=3796.0000
# Month=2, Predicted=3797.1143, Expected=3793.0000
# Month=3, Predicted=3794.1212, Expected=3766.0000
# Month=4, Predicted=3767.2896, Expected=3747.0000
# Month=5, Predicted=3748.2330, Expected=3754.0000
# Month=6, Predicted=3755.0524, Expected=3756.0000
# Month=7, Predicted=3757.0867, Expected=3767.0000
# Month=8, Predicted=3768.0251, Expected=3751.0000
# Month=9, Predicted=3752.2119, Expected=3769.0000
# Month=10, Predicted=3769.9775, Expected=3760.0000
# Month=11, Predicted=3761.1629, Expected=3785.0000
# Month=12, Predicted=3785.9304, Expected=3776.0000
# Month=13, Predicted=3777.1629, Expected=3755.0000
# Month=14, Predicted=3756.2471, Expected=3755.0000
# Month=15, Predicted=3756.1005, Expected=3751.0000
# Month=16, Predicted=3752.1282, Expected=3776.0000
# Month=17, Predicted=3776.9304, Expected=3847.0000
# Month=18, Predicted=3847.6295, Expected=3830.0000
# Month=19, Predicted=3831.2189, Expected=3881.0000
# Month=20, Predicted=3881.7584, Expected=3899.0000
# Month=21, Predicted=3899.9775, Expected=3917.0000
# Month=22, Predicted=3917.9775, Expected=3913.0000
# Month=23, Predicted=3914.1282, Expected=3901.0000
# Month=24, Predicted=3902.1839, Expected=3886.0000
# Month=25, Predicted=3887.2049, Expected=3892.5000
# Month=26, Predicted=3893.5558, Expected=3899.0000
# Month=27, Predicted=3900.0558, Expected=3886.0000
# Month=28, Predicted=3887.1909, Expected=3908.0000
# Month=29, Predicted=3908.9505, Expected=3875.0000
# Month=30, Predicted=3876.3324, Expected=3860.0000
# Month=31, Predicted=3861.2049, Expected=3880.0000
# Month=32, Predicted=3880.9640, Expected=3895.0000
# Month=33, Predicted=3895.9979, Expected=3954.0000
# Month=34, Predicted=3954.7065, Expected=3933.0000
# Month=35, Predicted=3934.2471, Expected=3937.0000
# Month=36, Predicted=3938.0730, Expected=3869.0000
# Month=37, Predicted=3870.5874, Expected=3852.0000
# Month=38, Predicted=3853.2189, Expected=3837.0000
# Month=39, Predicted=3838.2049, Expected=3832.0000
# Month=40, Predicted=3833.1351, Expected=3849.0000
# Month=41, Predicted=3849.9843, Expected=3863.0000
# Month=42, Predicted=3864.0046, Expected=3878.0000
# Month=43, Predicted=3878.9979, Expected=3855.0000
# Month=44, Predicted=3856.2612, Expected=3843.0000
# Month=45, Predicted=3844.1839, Expected=3847.0000
# Month=46, Predicted=3848.0730, Expected=3801.0000
# Month=47, Predicted=3802.4260, Expected=3787.0000
# Month=48, Predicted=3788.1979, Expected=3776.0000
# Month=49, Predicted=3777.1769, Expected=3797.0000
# Month=50, Predicted=3797.9573, Expected=3821.0000
# Month=51, Predicted=3821.9371, Expected=3877.0000
# Month=52, Predicted=3877.7259, Expected=3875.0000
# Month=53, Predicted=3876.1143, Expected=3890.0000
# Month=54, Predicted=3890.9979, Expected=3910.0000
# Month=55, Predicted=3910.9640, Expected=3924.0000
# Month=56, Predicted=3925.0046, Expected=3918.0000
# Month=57, Predicted=3919.1421, Expected=3936.0000
# Month=58, Predicted=3936.9775, Expected=3911.0000
# Month=59, Predicted=3912.2754, Expected=3891.0000
# Month=60, Predicted=3892.2400, Expected=3855.0000
# Run 1 — RMSE: 24.482823, MSE: 599.408636, NMSE: 0.0027509958, Time: 41.9s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3798.9625, Expected=3796.0000
# Month=2, Predicted=3797.0579, Expected=3793.0000
# Month=3, Predicted=3794.0605, Expected=3766.0000
# Month=4, Predicted=3767.1251, Expected=3747.0000
# Month=5, Predicted=3748.1035, Expected=3754.0000
# Month=6, Predicted=3755.0339, Expected=3756.0000
# Month=7, Predicted=3757.0472, Expected=3767.0000
# Month=8, Predicted=3768.0232, Expected=3751.0000
# Month=9, Predicted=3752.0954, Expected=3769.0000
# Month=10, Predicted=3770.0047, Expected=3760.0000
# Month=11, Predicted=3761.0766, Expected=3785.0000
# Month=12, Predicted=3785.9862, Expected=3776.0000
# Month=13, Predicted=3777.0766, Expected=3755.0000
# Month=14, Predicted=3756.1089, Expected=3755.0000
# Month=15, Predicted=3756.0525, Expected=3751.0000
# Month=16, Predicted=3752.0632, Expected=3776.0000
# Month=17, Predicted=3776.9862, Expected=3847.0000
# Month=18, Predicted=3847.8664, Expected=3830.0000
# Month=19, Predicted=3831.0981, Expected=3881.0000
# Month=20, Predicted=3881.9181, Expected=3899.0000
# Month=21, Predicted=3900.0047, Expected=3917.0000
# Month=22, Predicted=3918.0047, Expected=3913.0000
# Month=23, Predicted=3914.0632, Expected=3901.0000
# Month=24, Predicted=3902.0847, Expected=3886.0000
# Month=25, Predicted=3887.0927, Expected=3892.5000
# Month=26, Predicted=3893.5352, Expected=3899.0000
# Month=27, Predicted=3900.0352, Expected=3886.0000
# Month=28, Predicted=3887.0874, Expected=3908.0000
# Month=29, Predicted=3908.9941, Expected=3875.0000
# Month=30, Predicted=3876.1414, Expected=3860.0000
# Month=31, Predicted=3861.0927, Expected=3880.0000
# Month=32, Predicted=3880.9994, Expected=3895.0000
# Month=33, Predicted=3896.0126, Expected=3954.0000
# Month=34, Predicted=3954.8974, Expected=3933.0000
# Month=35, Predicted=3934.1089, Expected=3937.0000
# Month=36, Predicted=3938.0418, Expected=3869.0000
# Month=37, Predicted=3870.2373, Expected=3852.0000
# Month=38, Predicted=3853.0981, Expected=3837.0000
# Month=39, Predicted=3838.0927, Expected=3832.0000
# Month=40, Predicted=3833.0659, Expected=3849.0000
# Month=41, Predicted=3850.0073, Expected=3863.0000
# Month=42, Predicted=3864.0153, Expected=3878.0000
# Month=43, Predicted=3879.0126, Expected=3855.0000
# Month=44, Predicted=3856.1143, Expected=3843.0000
# Month=45, Predicted=3844.0847, Expected=3847.0000
# Month=46, Predicted=3848.0418, Expected=3801.0000
# Month=47, Predicted=3802.1768, Expected=3787.0000
# Month=48, Predicted=3788.0900, Expected=3776.0000
# Month=49, Predicted=3777.0820, Expected=3797.0000
# Month=50, Predicted=3797.9967, Expected=3821.0000
# Month=51, Predicted=3821.9888, Expected=3877.0000
# Month=52, Predicted=3877.9052, Expected=3875.0000
# Month=53, Predicted=3876.0579, Expected=3890.0000
# Month=54, Predicted=3891.0126, Expected=3910.0000
# Month=55, Predicted=3910.9994, Expected=3924.0000
# Month=56, Predicted=3925.0153, Expected=3918.0000
# Month=57, Predicted=3919.0686, Expected=3936.0000
# Month=58, Predicted=3937.0047, Expected=3911.0000
# Month=59, Predicted=3912.1197, Expected=3891.0000
# Month=60, Predicted=3892.1062, Expected=3855.0000
# Run 2 — RMSE: 24.470062, MSE: 598.783950, NMSE: 0.0027465222, Time: 52.5s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3798.7863, Expected=3796.0000
# Month=2, Predicted=3798.1562, Expected=3793.0000
# Month=3, Predicted=3795.1940, Expected=3766.0000
# Month=4, Predicted=3769.0978, Expected=3747.0000
# Month=5, Predicted=3749.7973, Expected=3754.0000
# Month=6, Predicted=3755.8153, Expected=3756.0000
# Month=7, Predicted=3758.0048, Expected=3767.0000
# Month=8, Predicted=3768.6634, Expected=3751.0000
# Month=9, Predicted=3753.6844, Expected=3769.0000
# Month=10, Predicted=3770.3972, Expected=3760.0000
# Month=11, Predicted=3762.4206, Expected=3785.0000
# Month=12, Predicted=3786.1303, Expected=3776.0000
# Month=13, Predicted=3778.4206, Expected=3755.0000
# Month=14, Predicted=3757.8725, Expected=3755.0000
# Month=15, Predicted=3757.0805, Expected=3751.0000
# Month=16, Predicted=3753.2318, Expected=3776.0000
# Month=17, Predicted=3777.1303, Expected=3847.0000
# Month=18, Predicted=3846.3611, Expected=3830.0000
# Month=19, Predicted=3832.7221, Expected=3881.0000
# Month=20, Predicted=3881.1336, Expected=3899.0000
# Month=21, Predicted=3900.3972, Expected=3917.0000
# Month=22, Predicted=3918.3972, Expected=3913.0000
# Month=23, Predicted=3915.2318, Expected=3901.0000
# Month=24, Predicted=3903.5337, Expected=3886.0000
# Month=25, Predicted=3888.6468, Expected=3892.5000
# Month=26, Predicted=3894.3342, Expected=3899.0000
# Month=27, Predicted=3900.8342, Expected=3886.0000
# Month=28, Predicted=3888.5714, Expected=3908.0000
# Month=29, Predicted=3909.2448, Expected=3875.0000
# Month=30, Predicted=3878.3227, Expected=3860.0000
# Month=31, Predicted=3862.6468, Expected=3880.0000
# Month=32, Predicted=3881.3210, Expected=3895.0000
# Month=33, Predicted=3896.5114, Expected=3954.0000
# Month=34, Predicted=3953.8252, Expected=3933.0000
# Month=35, Predicted=3935.8725, Expected=3937.0000
# Month=36, Predicted=3938.9290, Expected=3869.0000
# Month=37, Predicted=3873.6269, Expected=3852.0000
# Month=38, Predicted=3854.7221, Expected=3837.0000
# Month=39, Predicted=3839.6468, Expected=3832.0000
# Month=40, Predicted=3834.2696, Expected=3849.0000
# Month=41, Predicted=3850.4353, Expected=3863.0000
# Month=42, Predicted=3864.5494, Expected=3878.0000
# Month=43, Predicted=3879.5114, Expected=3855.0000
# Month=44, Predicted=3857.9476, Expected=3843.0000
# Month=45, Predicted=3845.5337, Expected=3847.0000
# Month=46, Predicted=3848.9290, Expected=3801.0000
# Month=47, Predicted=3804.8085, Expected=3787.0000
# Month=48, Predicted=3789.6091, Expected=3776.0000
# Month=49, Predicted=3778.4960, Expected=3797.0000
# Month=50, Predicted=3798.2829, Expected=3821.0000
# Month=51, Predicted=3822.1685, Expected=3877.0000
# Month=52, Predicted=3876.9409, Expected=3875.0000
# Month=53, Predicted=3877.1562, Expected=3890.0000
# Month=54, Predicted=3891.5114, Expected=3910.0000
# Month=55, Predicted=3911.3210, Expected=3924.0000
# Month=56, Predicted=3925.5494, Expected=3918.0000
# Month=57, Predicted=3920.3073, Expected=3936.0000
# Month=58, Predicted=3937.3972, Expected=3911.0000
# Month=59, Predicted=3914.0227, Expected=3891.0000
# Month=60, Predicted=3893.8349, Expected=3855.0000
# Run 3 — RMSE: 24.604978, MSE: 605.404964, NMSE: 0.0027896545, Time: 58.7s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3798.3429, Expected=3796.0000
# Month=2, Predicted=3797.0360, Expected=3793.0000
# Month=3, Predicted=3794.0546, Expected=3766.0000
# Month=4, Predicted=3767.4917, Expected=3747.0000
# Month=5, Predicted=3748.3481, Expected=3754.0000
# Month=6, Predicted=3754.8668, Expected=3756.0000
# Month=7, Predicted=3756.9611, Expected=3767.0000
# Month=8, Predicted=3767.7907, Expected=3751.0000
# Month=9, Predicted=3752.2938, Expected=3769.0000
# Month=10, Predicted=3769.6563, Expected=3760.0000
# Month=11, Predicted=3761.1657, Expected=3785.0000
# Month=12, Predicted=3785.5203, Expected=3776.0000
# Month=13, Predicted=3777.1657, Expected=3755.0000
# Month=14, Predicted=3756.3842, Expected=3755.0000
# Month=15, Predicted=3755.9986, Expected=3751.0000
# Month=16, Predicted=3752.0732, Expected=3776.0000
# Month=17, Predicted=3776.5203, Expected=3847.0000
# Month=18, Predicted=3846.5860, Expected=3830.0000
# Month=19, Predicted=3831.3119, Expected=3881.0000
# Month=20, Predicted=3881.0006, Expected=3899.0000
# Month=21, Predicted=3899.6563, Expected=3917.0000
# Month=22, Predicted=3917.6563, Expected=3913.0000
# Month=23, Predicted=3914.0732, Expected=3901.0000
# Month=24, Predicted=3902.2208, Expected=3886.0000
# Month=25, Predicted=3887.2756, Expected=3892.5000
# Month=26, Predicted=3893.3763, Expected=3899.0000
# Month=27, Predicted=3899.8763, Expected=3886.0000
# Month=28, Predicted=3887.2391, Expected=3908.0000
# Month=29, Predicted=3908.5788, Expected=3875.0000
# Month=30, Predicted=3876.5980, Expected=3860.0000
# Month=31, Predicted=3861.2756, Expected=3880.0000
# Month=32, Predicted=3880.6176, Expected=3895.0000
# Month=33, Predicted=3895.7141, Expected=3954.0000
# Month=34, Predicted=3953.8363, Expected=3933.0000
# Month=35, Predicted=3934.3842, Expected=3937.0000
# Month=36, Predicted=3937.9235, Expected=3869.0000
# Month=37, Predicted=3871.1957, Expected=3852.0000
# Month=38, Predicted=3853.3119, Expected=3837.0000
# Month=39, Predicted=3838.2756, Expected=3832.0000
# Month=40, Predicted=3833.0918, Expected=3849.0000
# Month=41, Predicted=3849.6756, Expected=3863.0000
# Month=42, Predicted=3863.7333, Expected=3878.0000
# Month=43, Predicted=3878.7141, Expected=3855.0000
# Month=44, Predicted=3856.4202, Expected=3843.0000
# Month=45, Predicted=3844.2208, Expected=3847.0000
# Month=46, Predicted=3847.9235, Expected=3801.0000
# Month=47, Predicted=3802.8244, Expected=3787.0000
# Month=48, Predicted=3788.2573, Expected=3776.0000
# Month=49, Predicted=3777.2024, Expected=3797.0000
# Month=50, Predicted=3797.5982, Expected=3821.0000
# Month=51, Predicted=3821.5398, Expected=3877.0000
# Month=52, Predicted=3876.8982, Expected=3875.0000
# Month=53, Predicted=3876.0360, Expected=3890.0000
# Month=54, Predicted=3890.7141, Expected=3910.0000
# Month=55, Predicted=3910.6176, Expected=3924.0000
# Month=56, Predicted=3924.7333, Expected=3918.0000
# Month=57, Predicted=3919.1103, Expected=3936.0000
# Month=58, Predicted=3936.6563, Expected=3911.0000
# Month=59, Predicted=3912.4560, Expected=3891.0000
# Month=60, Predicted=3892.3662, Expected=3855.0000
# Run 4 — RMSE: 24.515714, MSE: 601.020233, NMSE: 0.0027632691, Time: 57.1s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3798.2671, Expected=3796.0000
# Month=2, Predicted=3797.2659, Expected=3793.0000
# Month=3, Predicted=3794.2934, Expected=3766.0000
# Month=4, Predicted=3767.9510, Expected=3747.0000
# Month=5, Predicted=3748.7325, Expected=3754.0000
# Month=6, Predicted=3755.0176, Expected=3756.0000
# Month=7, Predicted=3757.1556, Expected=3767.0000
# Month=8, Predicted=3767.9069, Expected=3751.0000
# Month=9, Predicted=3752.6504, Expected=3769.0000
# Month=10, Predicted=3769.7128, Expected=3760.0000
# Month=11, Predicted=3761.4584, Expected=3785.0000
# Month=12, Predicted=3785.5182, Expected=3776.0000
# Month=13, Predicted=3777.4584, Expected=3755.0000
# Month=14, Predicted=3756.7872, Expected=3755.0000
# Month=15, Predicted=3756.2108, Expected=3751.0000
# Month=16, Predicted=3752.3209, Expected=3776.0000
# Month=17, Predicted=3776.5182, Expected=3847.0000
# Month=18, Predicted=3846.2249, Expected=3830.0000
# Month=19, Predicted=3831.6778, Expected=3881.0000
# Month=20, Predicted=3880.7902, Expected=3899.0000
# Month=21, Predicted=3899.7128, Expected=3917.0000
# Month=22, Predicted=3917.7128, Expected=3913.0000
# Month=23, Predicted=3914.3209, Expected=3901.0000
# Month=24, Predicted=3902.5407, Expected=3886.0000
# Month=25, Predicted=3887.6230, Expected=3892.5000
# Month=26, Predicted=3893.5314, Expected=3899.0000
# Month=27, Predicted=3900.0314, Expected=3886.0000
# Month=28, Predicted=3887.5682, Expected=3908.0000
# Month=29, Predicted=3908.6016, Expected=3875.0000
# Month=30, Predicted=3877.1144, Expected=3860.0000
# Month=31, Predicted=3861.6230, Expected=3880.0000
# Month=32, Predicted=3880.6573, Expected=3895.0000
# Month=33, Predicted=3895.7961, Expected=3954.0000
# Month=34, Predicted=3953.5646, Expected=3933.0000
# Month=35, Predicted=3934.7872, Expected=3937.0000
# Month=36, Predicted=3938.1004, Expected=3869.0000
# Month=37, Predicted=3872.0600, Expected=3852.0000
# Month=38, Predicted=3853.6778, Expected=3837.0000
# Month=39, Predicted=3838.6230, Expected=3832.0000
# Month=40, Predicted=3833.3485, Expected=3849.0000
# Month=41, Predicted=3849.7406, Expected=3863.0000
# Month=42, Predicted=3863.8238, Expected=3878.0000
# Month=43, Predicted=3878.7961, Expected=3855.0000
# Month=44, Predicted=3856.8418, Expected=3843.0000
# Month=45, Predicted=3844.5407, Expected=3847.0000
# Month=46, Predicted=3848.1004, Expected=3801.0000
# Month=47, Predicted=3803.4671, Expected=3787.0000
# Month=48, Predicted=3788.5956, Expected=3776.0000
# Month=49, Predicted=3777.5133, Expected=3797.0000
# Month=50, Predicted=3797.6295, Expected=3821.0000
# Month=51, Predicted=3821.5460, Expected=3877.0000
# Month=52, Predicted=3876.6493, Expected=3875.0000
# Month=53, Predicted=3876.2659, Expected=3890.0000
# Month=54, Predicted=3890.7961, Expected=3910.0000
# Month=55, Predicted=3910.6573, Expected=3924.0000
# Month=56, Predicted=3924.8238, Expected=3918.0000
# Month=57, Predicted=3919.3760, Expected=3936.0000
# Month=58, Predicted=3936.7128, Expected=3911.0000
# Month=59, Predicted=3912.8964, Expected=3891.0000
# Month=60, Predicted=3892.7598, Expected=3855.0000
# Run 5 — RMSE: 24.547281, MSE: 602.569004, NMSE: 0.0027735631, Time: 65.4s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3799.1565, Expected=3796.0000
# Month=2, Predicted=3797.1928, Expected=3793.0000
# Month=3, Predicted=3794.1939, Expected=3766.0000
# Month=4, Predicted=3767.2197, Expected=3747.0000
# Month=5, Predicted=3748.2109, Expected=3754.0000
# Month=6, Predicted=3755.1835, Expected=3756.0000
# Month=7, Predicted=3757.1886, Expected=3767.0000
# Month=8, Predicted=3768.1794, Expected=3751.0000
# Month=9, Predicted=3752.2077, Expected=3769.0000
# Month=10, Predicted=3770.1723, Expected=3760.0000
# Month=11, Predicted=3761.2002, Expected=3785.0000
# Month=12, Predicted=3786.1653, Expected=3776.0000
# Month=13, Predicted=3777.2002, Expected=3755.0000
# Month=14, Predicted=3756.2131, Expected=3755.0000
# Month=15, Predicted=3756.1907, Expected=3751.0000
# Month=16, Predicted=3752.1949, Expected=3776.0000
# Month=17, Predicted=3777.1653, Expected=3847.0000
# Month=18, Predicted=3848.1221, Expected=3830.0000
# Month=19, Predicted=3831.2088, Expected=3881.0000
# Month=20, Predicted=3882.1403, Expected=3899.0000
# Month=21, Predicted=3900.1723, Expected=3917.0000
# Month=22, Predicted=3918.1723, Expected=3913.0000
# Month=23, Predicted=3914.1949, Expected=3901.0000
# Month=24, Predicted=3902.2034, Expected=3886.0000
# Month=25, Predicted=3887.2066, Expected=3892.5000
# Month=26, Predicted=3893.6840, Expected=3899.0000
# Month=27, Predicted=3900.1840, Expected=3886.0000
# Month=28, Predicted=3887.2045, Expected=3908.0000
# Month=29, Predicted=3909.1683, Expected=3875.0000
# Month=30, Predicted=3876.2264, Expected=3860.0000
# Month=31, Predicted=3861.2066, Expected=3880.0000
# Month=32, Predicted=3881.1703, Expected=3895.0000
# Month=33, Predicted=3896.1753, Expected=3954.0000
# Month=34, Predicted=3955.1330, Expected=3933.0000
# Month=35, Predicted=3934.2131, Expected=3937.0000
# Month=36, Predicted=3938.1866, Expected=3869.0000
# Month=37, Predicted=3870.2668, Expected=3852.0000
# Month=38, Predicted=3853.2088, Expected=3837.0000
# Month=39, Predicted=3838.2066, Expected=3832.0000
# Month=40, Predicted=3833.1960, Expected=3849.0000
# Month=41, Predicted=3850.1733, Expected=3863.0000
# Month=42, Predicted=3864.1763, Expected=3878.0000
# Month=43, Predicted=3879.1753, Expected=3855.0000
# Month=44, Predicted=3856.2153, Expected=3843.0000
# Month=45, Predicted=3844.2034, Expected=3847.0000
# Month=46, Predicted=3848.1866, Expected=3801.0000
# Month=47, Predicted=3802.2411, Expected=3787.0000
# Month=48, Predicted=3788.2055, Expected=3776.0000
# Month=49, Predicted=3777.2023, Expected=3797.0000
# Month=50, Predicted=3798.1693, Expected=3821.0000
# Month=51, Predicted=3822.1663, Expected=3877.0000
# Month=52, Predicted=3878.1357, Expected=3875.0000
# Month=53, Predicted=3876.1928, Expected=3890.0000
# Month=54, Predicted=3891.1753, Expected=3910.0000
# Month=55, Predicted=3911.1703, Expected=3924.0000
# Month=56, Predicted=3925.1763, Expected=3918.0000
# Month=57, Predicted=3919.1970, Expected=3936.0000
# Month=58, Predicted=3937.1723, Expected=3911.0000
# Month=59, Predicted=3912.2175, Expected=3891.0000
# Month=60, Predicted=3892.2120, Expected=3855.0000
# Run 6 — RMSE: 24.466547, MSE: 598.611939, NMSE: 0.0027450504, Time: 77.0s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3797.9773, Expected=3796.0000
# Month=2, Predicted=3797.7229, Expected=3793.0000
# Month=3, Predicted=3794.7715, Expected=3766.0000
# Month=4, Predicted=3768.9401, Expected=3747.0000
# Month=5, Predicted=3749.5502, Expected=3754.0000
# Month=6, Predicted=3755.2857, Expected=3756.0000
# Month=7, Predicted=3757.5285, Expected=3767.0000
# Month=8, Predicted=3768.0916, Expected=3751.0000
# Month=9, Predicted=3753.4040, Expected=3769.0000
# Month=10, Predicted=3769.7521, Expected=3760.0000
# Month=11, Predicted=3762.0633, Expected=3785.0000
# Month=12, Predicted=3785.4129, Expected=3776.0000
# Month=13, Predicted=3778.0633, Expected=3755.0000
# Month=14, Predicted=3757.6476, Expected=3755.0000
# Month=15, Predicted=3756.6257, Expected=3751.0000
# Month=16, Predicted=3752.8201, Expected=3776.0000
# Month=17, Predicted=3776.4129, Expected=3847.0000
# Month=18, Predicted=3845.1921, Expected=3830.0000
# Month=19, Predicted=3832.4527, Expected=3881.0000
# Month=20, Predicted=3880.1559, Expected=3899.0000
# Month=21, Predicted=3899.7521, Expected=3917.0000
# Month=22, Predicted=3917.7521, Expected=3913.0000
# Month=23, Predicted=3914.8201, Expected=3901.0000
# Month=24, Predicted=3903.2093, Expected=3886.0000
# Month=25, Predicted=3888.3553, Expected=3892.5000
# Month=26, Predicted=3893.8100, Expected=3899.0000
# Month=27, Predicted=3900.3100, Expected=3886.0000
# Month=28, Predicted=3888.2580, Expected=3908.0000
# Month=29, Predicted=3908.5582, Expected=3875.0000
# Month=30, Predicted=3878.2328, Expected=3860.0000
# Month=31, Predicted=3862.3553, Expected=3880.0000
# Month=32, Predicted=3880.6551, Expected=3895.0000
# Month=33, Predicted=3895.8975, Expected=3954.0000
# Month=34, Predicted=3952.7701, Expected=3933.0000
# Month=35, Predicted=3935.6476, Expected=3937.0000
# Month=36, Predicted=3938.4314, Expected=3869.0000
# Month=37, Predicted=3873.9445, Expected=3852.0000
# Month=38, Predicted=3854.4527, Expected=3837.0000
# Month=39, Predicted=3839.3553, Expected=3832.0000
# Month=40, Predicted=3833.8688, Expected=3849.0000
# Month=41, Predicted=3849.8006, Expected=3863.0000
# Month=42, Predicted=3863.9460, Expected=3878.0000
# Month=43, Predicted=3878.8975, Expected=3855.0000
# Month=44, Predicted=3857.7451, Expected=3843.0000
# Month=45, Predicted=3845.2093, Expected=3847.0000
# Month=46, Predicted=3848.4314, Expected=3801.0000
# Month=47, Predicted=3804.8677, Expected=3787.0000
# Month=48, Predicted=3789.3067, Expected=3776.0000
# Month=49, Predicted=3778.1606, Expected=3797.0000
# Month=50, Predicted=3797.6067, Expected=3821.0000
# Month=51, Predicted=3821.4613, Expected=3877.0000
# Month=52, Predicted=3875.9147, Expected=3875.0000
# Month=53, Predicted=3876.7229, Expected=3890.0000
# Month=54, Predicted=3890.8975, Expected=3910.0000
# Month=55, Predicted=3910.6551, Expected=3924.0000
# Month=56, Predicted=3924.9460, Expected=3918.0000
# Month=57, Predicted=3919.9174, Expected=3936.0000
# Month=58, Predicted=3936.7521, Expected=3911.0000
# Month=59, Predicted=3913.8426, Expected=3891.0000
# Month=60, Predicted=3893.5989, Expected=3855.0000
# Run 7 — RMSE: 24.631228, MSE: 606.697412, NMSE: 0.0027999973, Time: 65.0s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3798.2175, Expected=3796.0000
# Month=2, Predicted=3797.8095, Expected=3793.0000
# Month=3, Predicted=3794.8545, Expected=3766.0000
# Month=4, Predicted=3768.9459, Expected=3747.0000
# Month=5, Predicted=3749.5795, Expected=3754.0000
# Month=6, Predicted=3755.4066, Expected=3756.0000
# Month=7, Predicted=3757.6300, Expected=3767.0000
# Month=8, Predicted=3768.2287, Expected=3751.0000
# Month=9, Predicted=3753.4427, Expected=3769.0000
# Month=10, Predicted=3769.9187, Expected=3760.0000
# Month=11, Predicted=3762.1251, Expected=3785.0000
# Month=12, Predicted=3785.6107, Expected=3776.0000
# Month=13, Predicted=3778.1251, Expected=3755.0000
# Month=14, Predicted=3757.6708, Expected=3755.0000
# Month=15, Predicted=3756.7197, Expected=3751.0000
# Month=16, Predicted=3752.8995, Expected=3776.0000
# Month=17, Predicted=3776.6107, Expected=3847.0000
# Month=18, Predicted=3845.6336, Expected=3830.0000
# Month=19, Predicted=3832.4883, Expected=3881.0000
# Month=20, Predicted=3880.4833, Expected=3899.0000
# Month=21, Predicted=3899.9187, Expected=3917.0000
# Month=22, Predicted=3917.9187, Expected=3913.0000
# Month=23, Predicted=3914.8995, Expected=3901.0000
# Month=24, Predicted=3903.2610, Expected=3886.0000
# Month=25, Predicted=3888.3972, Expected=3892.5000
# Month=26, Predicted=3893.9289, Expected=3899.0000
# Month=27, Predicted=3900.4289, Expected=3886.0000
# Month=28, Predicted=3888.3064, Expected=3908.0000
# Month=29, Predicted=3908.7425, Expected=3875.0000
# Month=30, Predicted=3878.2225, Expected=3860.0000
# Month=31, Predicted=3862.3972, Expected=3880.0000
# Month=32, Predicted=3880.8305, Expected=3895.0000
# Month=33, Predicted=3896.0513, Expected=3954.0000
# Month=34, Predicted=3953.1416, Expected=3933.0000
# Month=35, Predicted=3935.6708, Expected=3937.0000
# Month=36, Predicted=3938.5406, Expected=3869.0000
# Month=37, Predicted=3873.8662, Expected=3852.0000
# Month=38, Predicted=3854.4883, Expected=3837.0000
# Month=39, Predicted=3839.3972, Expected=3832.0000
# Month=40, Predicted=3833.9445, Expected=3849.0000
# Month=41, Predicted=3849.9629, Expected=3863.0000
# Month=42, Predicted=3864.0956, Expected=3878.0000
# Month=43, Predicted=3879.0513, Expected=3855.0000
# Month=44, Predicted=3857.7624, Expected=3843.0000
# Month=45, Predicted=3845.2610, Expected=3847.0000
# Month=46, Predicted=3848.5406, Expected=3801.0000
# Month=47, Predicted=3804.8270, Expected=3787.0000
# Month=48, Predicted=3789.3518, Expected=3776.0000
# Month=49, Predicted=3778.2157, Expected=3797.0000
# Month=50, Predicted=3797.7865, Expected=3821.0000
# Month=51, Predicted=3821.6546, Expected=3877.0000
# Month=52, Predicted=3876.2695, Expected=3875.0000
# Month=53, Predicted=3876.8095, Expected=3890.0000
# Month=54, Predicted=3891.0513, Expected=3910.0000
# Month=55, Predicted=3910.8305, Expected=3924.0000
# Month=56, Predicted=3925.0956, Expected=3918.0000
# Month=57, Predicted=3919.9896, Expected=3936.0000
# Month=58, Predicted=3936.9187, Expected=3911.0000
# Month=59, Predicted=3913.8541, Expected=3891.0000
# Month=60, Predicted=3893.6251, Expected=3855.0000
# Run 8 — RMSE: 24.621991, MSE: 606.242461, NMSE: 0.0027961988, Time: 68.3s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3797.8591, Expected=3796.0000
# Month=2, Predicted=3797.5083, Expected=3793.0000
# Month=3, Predicted=3794.5541, Expected=3766.0000
# Month=4, Predicted=3768.6539, Expected=3747.0000
# Month=5, Predicted=3749.2873, Expected=3754.0000
# Month=6, Predicted=3755.0959, Expected=3756.0000
# Month=7, Predicted=3757.3250, Expected=3767.0000
# Month=8, Predicted=3767.9127, Expected=3751.0000
# Month=9, Predicted=3753.1498, Expected=3769.0000
# Month=10, Predicted=3769.5920, Expected=3760.0000
# Month=11, Predicted=3761.8290, Expected=3785.0000
# Month=12, Predicted=3785.2713, Expected=3776.0000
# Month=13, Predicted=3777.8290, Expected=3755.0000
# Month=14, Predicted=3757.3790, Expected=3755.0000
# Month=15, Predicted=3756.4166, Expected=3751.0000
# Month=16, Predicted=3752.5999, Expected=3776.0000
# Month=17, Predicted=3776.2713, Expected=3847.0000
# Month=18, Predicted=3845.1649, Expected=3830.0000
# Month=19, Predicted=3832.1956, Expected=3881.0000
# Month=20, Predicted=3880.0806, Expected=3899.0000
# Month=21, Predicted=3899.5920, Expected=3917.0000
# Month=22, Predicted=3917.5920, Expected=3913.0000
# Month=23, Predicted=3914.5999, Expected=3901.0000
# Month=24, Predicted=3902.9665, Expected=3886.0000
# Month=25, Predicted=3888.1040, Expected=3892.5000
# Month=26, Predicted=3893.6188, Expected=3899.0000
# Month=27, Predicted=3900.1188, Expected=3886.0000
# Month=28, Predicted=3888.0123, Expected=3908.0000
# Month=29, Predicted=3908.4087, Expected=3875.0000
# Month=30, Predicted=3877.9289, Expected=3860.0000
# Month=31, Predicted=3862.1040, Expected=3880.0000
# Month=32, Predicted=3880.5004, Expected=3895.0000
# Month=33, Predicted=3895.7294, Expected=3954.0000
# Month=34, Predicted=3952.7143, Expected=3933.0000
# Month=35, Predicted=3935.3790, Expected=3937.0000
# Month=36, Predicted=3938.2334, Expected=3869.0000
# Month=37, Predicted=3873.5333, Expected=3852.0000
# Month=38, Predicted=3854.1956, Expected=3837.0000
# Month=39, Predicted=3839.1040, Expected=3832.0000
# Month=40, Predicted=3833.6458, Expected=3849.0000
# Month=41, Predicted=3849.6378, Expected=3863.0000
# Month=42, Predicted=3863.7752, Expected=3878.0000
# Month=43, Predicted=3878.7294, Expected=3855.0000
# Month=44, Predicted=3857.4706, Expected=3843.0000
# Month=45, Predicted=3844.9665, Expected=3847.0000
# Month=46, Predicted=3848.2334, Expected=3801.0000
# Month=47, Predicted=3804.5248, Expected=3787.0000
# Month=48, Predicted=3789.0582, Expected=3776.0000
# Month=49, Predicted=3777.9207, Expected=3797.0000
# Month=50, Predicted=3797.4545, Expected=3821.0000
# Month=51, Predicted=3821.3171, Expected=3877.0000
# Month=52, Predicted=3875.8516, Expected=3875.0000
# Month=53, Predicted=3876.5083, Expected=3890.0000
# Month=54, Predicted=3890.7294, Expected=3910.0000
# Month=55, Predicted=3910.5004, Expected=3924.0000
# Month=56, Predicted=3924.7752, Expected=3918.0000
# Month=57, Predicted=3919.6916, Expected=3936.0000
# Month=58, Predicted=3936.5920, Expected=3911.0000
# Month=59, Predicted=3913.5623, Expected=3891.0000
# Month=60, Predicted=3893.3331, Expected=3855.0000
# Run 9 — RMSE: 24.616177, MSE: 605.956173, NMSE: 0.0027957638, Time: 65.6s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3797.6815, Expected=3796.0000
# Month=2, Predicted=3797.7311, Expected=3793.0000
# Month=3, Predicted=3794.7885, Expected=3766.0000
# Month=4, Predicted=3769.1736, Expected=3747.0000
# Month=5, Predicted=3749.7099, Expected=3754.0000
# Month=6, Predicted=3755.2162, Expected=3756.0000
# Month=7, Predicted=3757.5020, Expected=3767.0000
# Month=8, Predicted=3767.9879, Expected=3751.0000
# Month=9, Predicted=3753.5366, Expected=3769.0000
# Month=10, Predicted=3769.5893, Expected=3760.0000
# Month=11, Predicted=3762.1331, Expected=3785.0000
# Month=12, Predicted=3785.1916, Expected=3776.0000
# Month=13, Predicted=3778.1331, Expected=3755.0000
# Month=14, Predicted=3757.8257, Expected=3755.0000
# Month=15, Predicted=3756.6165, Expected=3751.0000
# Month=16, Predicted=3752.8458, Expected=3776.0000
# Month=17, Predicted=3776.1916, Expected=3847.0000
# Month=18, Predicted=3844.5915, Expected=3830.0000
# Month=19, Predicted=3832.5943, Expected=3881.0000
# Month=20, Predicted=3879.7204, Expected=3899.0000
# Month=21, Predicted=3899.5893, Expected=3917.0000
# Month=22, Predicted=3917.5893, Expected=3913.0000
# Month=23, Predicted=3914.8458, Expected=3901.0000
# Month=24, Predicted=3903.3058, Expected=3886.0000
# Month=25, Predicted=3888.4788, Expected=3892.5000
# Month=26, Predicted=3893.7447, Expected=3899.0000
# Month=27, Predicted=3900.2447, Expected=3886.0000
# Month=28, Predicted=3888.3635, Expected=3908.0000
# Month=29, Predicted=3908.3619, Expected=3875.0000
# Month=30, Predicted=3878.5229, Expected=3860.0000
# Month=31, Predicted=3862.4788, Expected=3880.0000
# Month=32, Predicted=3880.4756, Expected=3895.0000
# Month=33, Predicted=3895.7600, Expected=3954.0000
# Month=34, Predicted=3952.2688, Expected=3933.0000
# Month=35, Predicted=3935.8257, Expected=3937.0000
# Month=36, Predicted=3938.3876, Expected=3869.0000
# Month=37, Predicted=3874.5877, Expected=3852.0000
# Month=38, Predicted=3854.5943, Expected=3837.0000
# Month=39, Predicted=3839.4788, Expected=3832.0000
# Month=40, Predicted=3833.9032, Expected=3849.0000
# Month=41, Predicted=3849.6462, Expected=3863.0000
# Month=42, Predicted=3863.8169, Expected=3878.0000
# Month=43, Predicted=3878.7600, Expected=3855.0000
# Month=44, Predicted=3857.9415, Expected=3843.0000
# Month=45, Predicted=3845.3058, Expected=3847.0000
# Month=46, Predicted=3848.3876, Expected=3801.0000
# Month=47, Predicted=3805.2841, Expected=3787.0000
# Month=48, Predicted=3789.4211, Expected=3776.0000
# Month=49, Predicted=3778.2482, Expected=3797.0000
# Month=50, Predicted=3797.4187, Expected=3821.0000
# Month=51, Predicted=3821.2484, Expected=3877.0000
# Month=52, Predicted=3875.4382, Expected=3875.0000
# Month=53, Predicted=3876.7311, Expected=3890.0000
# Month=54, Predicted=3890.7600, Expected=3910.0000
# Month=55, Predicted=3910.4756, Expected=3924.0000
# Month=56, Predicted=3924.8169, Expected=3918.0000
# Month=57, Predicted=3919.9607, Expected=3936.0000
# Month=58, Predicted=3936.5893, Expected=3911.0000
# Month=59, Predicted=3914.0575, Expected=3891.0000
# Month=60, Predicted=3893.7678, Expected=3855.0000
# Run 10 — RMSE: 24.666919, MSE: 608.456914, NMSE: 0.0028111596, Time: 67.3s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3798.0667, Expected=3796.0000
# Month=2, Predicted=3797.8896, Expected=3793.0000
# Month=3, Predicted=3794.9399, Expected=3766.0000
# Month=4, Predicted=3769.1426, Expected=3747.0000
# Month=5, Predicted=3749.7428, Expected=3754.0000
# Month=6, Predicted=3755.4359, Expected=3756.0000
# Month=7, Predicted=3757.6881, Expected=3767.0000
# Month=8, Predicted=3768.2338, Expected=3751.0000
# Month=9, Predicted=3753.5926, Expected=3769.0000
# Month=10, Predicted=3769.8795, Expected=3760.0000
# Month=11, Predicted=3762.2415, Expected=3785.0000
# Month=12, Predicted=3785.5244, Expected=3776.0000
# Month=13, Predicted=3778.2415, Expected=3755.0000
# Month=14, Predicted=3757.8429, Expected=3755.0000
# Month=15, Predicted=3756.7888, Expected=3751.0000
# Month=16, Predicted=3752.9902, Expected=3776.0000
# Month=17, Predicted=3776.5244, Expected=3847.0000
# Month=18, Predicted=3845.1710, Expected=3830.0000
# Month=19, Predicted=3832.6427, Expected=3881.0000
# Month=20, Predicted=3880.1985, Expected=3899.0000
# Month=21, Predicted=3899.8795, Expected=3917.0000
# Month=22, Predicted=3917.8795, Expected=3913.0000
# Month=23, Predicted=3914.9902, Expected=3901.0000
# Month=24, Predicted=3903.3921, Expected=3886.0000
# Month=25, Predicted=3888.5425, Expected=3892.5000
# Month=26, Predicted=3893.9611, Expected=3899.0000
# Month=27, Predicted=3900.4611, Expected=3886.0000
# Month=28, Predicted=3888.4422, Expected=3908.0000
# Month=29, Predicted=3908.6767, Expected=3875.0000
# Month=30, Predicted=3878.4418, Expected=3860.0000
# Month=31, Predicted=3862.5425, Expected=3880.0000
# Month=32, Predicted=3880.7781, Expected=3895.0000
# Month=33, Predicted=3896.0314, Expected=3954.0000
# Month=34, Predicted=3952.7882, Expected=3933.0000
# Month=35, Predicted=3935.8429, Expected=3937.0000
# Month=36, Predicted=3938.5872, Expected=3869.0000
# Month=37, Predicted=3874.1747, Expected=3852.0000
# Month=38, Predicted=3854.6427, Expected=3837.0000
# Month=39, Predicted=3839.5425, Expected=3832.0000
# Month=40, Predicted=3834.0405, Expected=3849.0000
# Month=41, Predicted=3849.9302, Expected=3863.0000
# Month=42, Predicted=3864.0821, Expected=3878.0000
# Month=43, Predicted=3879.0314, Expected=3855.0000
# Month=44, Predicted=3857.9429, Expected=3843.0000
# Month=45, Predicted=3845.3921, Expected=3847.0000
# Month=46, Predicted=3848.5872, Expected=3801.0000
# Month=47, Predicted=3805.0879, Expected=3787.0000
# Month=48, Predicted=3789.4924, Expected=3776.0000
# Month=49, Predicted=3778.3419, Expected=3797.0000
# Month=50, Predicted=3797.7274, Expected=3821.0000
# Month=51, Predicted=3821.5752, Expected=3877.0000
# Month=52, Predicted=3875.9422, Expected=3875.0000
# Month=53, Predicted=3876.8896, Expected=3890.0000
# Month=54, Predicted=3891.0314, Expected=3910.0000
# Month=55, Predicted=3910.7781, Expected=3924.0000
# Month=56, Predicted=3925.0821, Expected=3918.0000
# Month=57, Predicted=3920.0908, Expected=3936.0000
# Month=58, Predicted=3936.8795, Expected=3911.0000
# Month=59, Predicted=3914.0428, Expected=3891.0000
# Month=60, Predicted=3893.7928, Expected=3855.0000
# Run 11 — RMSE: 24.640705, MSE: 607.164356, NMSE: 0.0028028027, Time: 69.2s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3797.7549, Expected=3796.0000
# Month=2, Predicted=3797.2179, Expected=3793.0000
# Month=3, Predicted=3794.2581, Expected=3766.0000
# Month=4, Predicted=3768.2139, Expected=3747.0000
# Month=5, Predicted=3748.8970, Expected=3754.0000
# Month=6, Predicted=3754.8554, Expected=3756.0000
# Month=7, Predicted=3757.0570, Expected=3767.0000
# Month=8, Predicted=3767.6935, Expected=3751.0000
# Month=9, Predicted=3752.7777, Expected=3769.0000
# Month=10, Predicted=3769.4093, Expected=3760.0000
# Month=11, Predicted=3761.4984, Expected=3785.0000
# Month=12, Predicted=3785.1238, Expected=3776.0000
# Month=13, Predicted=3777.4984, Expected=3755.0000
# Month=14, Predicted=3756.9763, Expected=3755.0000
# Month=15, Predicted=3756.1375, Expected=3751.0000
# Month=16, Predicted=3752.2982, Expected=3776.0000
# Month=17, Predicted=3776.1238, Expected=3847.0000
# Month=18, Predicted=3845.2172, Expected=3830.0000
# Month=19, Predicted=3831.8175, Expected=3881.0000
# Month=20, Predicted=3880.0525, Expected=3899.0000
# Month=21, Predicted=3899.4093, Expected=3917.0000
# Month=22, Predicted=3917.4093, Expected=3913.0000
# Month=23, Predicted=3914.2982, Expected=3901.0000
# Month=24, Predicted=3902.6183, Expected=3886.0000
# Month=25, Predicted=3887.7379, Expected=3892.5000
# Month=26, Predicted=3893.3756, Expected=3899.0000
# Month=27, Predicted=3899.8756, Expected=3886.0000
# Month=28, Predicted=3887.6582, Expected=3908.0000
# Month=29, Predicted=3908.2463, Expected=3875.0000
# Month=30, Predicted=3877.4505, Expected=3860.0000
# Month=31, Predicted=3861.7379, Expected=3880.0000
# Month=32, Predicted=3880.3279, Expected=3895.0000
# Month=33, Predicted=3895.5313, Expected=3954.0000
# Month=34, Predicted=3952.7195, Expected=3933.0000
# Month=35, Predicted=3934.9763, Expected=3937.0000
# Month=36, Predicted=3937.9764, Expected=3869.0000
# Month=37, Predicted=3872.8124, Expected=3852.0000
# Month=38, Predicted=3853.8175, Expected=3837.0000
# Month=39, Predicted=3838.7379, Expected=3832.0000
# Month=40, Predicted=3833.3383, Expected=3849.0000
# Month=41, Predicted=3849.4500, Expected=3863.0000
# Month=42, Predicted=3863.5719, Expected=3878.0000
# Month=43, Predicted=3878.5313, Expected=3855.0000
# Month=44, Predicted=3857.0556, Expected=3843.0000
# Month=45, Predicted=3844.6183, Expected=3847.0000
# Month=46, Predicted=3847.9764, Expected=3801.0000
# Month=47, Predicted=3803.9599, Expected=3787.0000
# Month=48, Predicted=3788.6980, Expected=3776.0000
# Month=49, Predicted=3777.5784, Expected=3797.0000
# Month=50, Predicted=3797.2871, Expected=3821.0000
# Month=51, Predicted=3821.1647, Expected=3877.0000
# Month=52, Predicted=3875.8446, Expected=3875.0000
# Month=53, Predicted=3876.2179, Expected=3890.0000
# Month=54, Predicted=3890.5313, Expected=3910.0000
# Month=55, Predicted=3910.3279, Expected=3924.0000
# Month=56, Predicted=3924.5719, Expected=3918.0000
# Month=57, Predicted=3919.3784, Expected=3936.0000
# Month=58, Predicted=3936.4093, Expected=3911.0000
# Month=59, Predicted=3913.1348, Expected=3891.0000
# Month=60, Predicted=3892.9367, Expected=3855.0000
# Run 12 — RMSE: 24.590709, MSE: 604.702990, NMSE: 0.0027882241, Time: 122.5s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3798.5419, Expected=3796.0000
# Month=2, Predicted=3796.8971, Expected=3793.0000
# Month=3, Predicted=3793.9069, Expected=3766.0000
# Month=4, Predicted=3767.1422, Expected=3747.0000
# Month=5, Predicted=3748.0639, Expected=3754.0000
# Month=6, Predicted=3754.8085, Expected=3756.0000
# Month=7, Predicted=3756.8577, Expected=3767.0000
# Month=8, Predicted=3767.7691, Expected=3751.0000
# Month=9, Predicted=3752.0345, Expected=3769.0000
# Month=10, Predicted=3769.7001, Expected=3760.0000
# Month=11, Predicted=3760.9658, Expected=3785.0000
# Month=12, Predicted=3785.6309, Expected=3776.0000
# Month=13, Predicted=3776.9658, Expected=3755.0000
# Month=14, Predicted=3756.0835, Expected=3755.0000
# Month=15, Predicted=3755.8774, Expected=3751.0000
# Month=16, Predicted=3751.9167, Expected=3776.0000
# Month=17, Predicted=3776.6309, Expected=3847.0000
# Month=18, Predicted=3847.1743, Expected=3830.0000
# Month=19, Predicted=3831.0443, Expected=3881.0000
# Month=20, Predicted=3881.3733, Expected=3899.0000
# Month=21, Predicted=3899.7001, Expected=3917.0000
# Month=22, Predicted=3917.7001, Expected=3913.0000
# Month=23, Predicted=3913.9167, Expected=3901.0000
# Month=24, Predicted=3901.9953, Expected=3886.0000
# Month=25, Predicted=3887.0247, Expected=3892.5000
# Month=26, Predicted=3893.3135, Expected=3899.0000
# Month=27, Predicted=3899.8135, Expected=3886.0000
# Month=28, Predicted=3887.0051, Expected=3908.0000
# Month=29, Predicted=3908.6606, Expected=3875.0000
# Month=30, Predicted=3876.2009, Expected=3860.0000
# Month=31, Predicted=3861.0247, Expected=3880.0000
# Month=32, Predicted=3880.6803, Expected=3895.0000
# Month=33, Predicted=3895.7297, Expected=3954.0000
# Month=34, Predicted=3954.2938, Expected=3933.0000
# Month=35, Predicted=3934.0835, Expected=3937.0000
# Month=36, Predicted=3937.8381, Expected=3869.0000
# Month=37, Predicted=3870.5416, Expected=3852.0000
# Month=38, Predicted=3853.0443, Expected=3837.0000
# Month=39, Predicted=3838.0247, Expected=3832.0000
# Month=40, Predicted=3832.9266, Expected=3849.0000
# Month=41, Predicted=3849.7099, Expected=3863.0000
# Month=42, Predicted=3863.7395, Expected=3878.0000
# Month=43, Predicted=3878.7297, Expected=3855.0000
# Month=44, Predicted=3856.1031, Expected=3843.0000
# Month=45, Predicted=3843.9953, Expected=3847.0000
# Month=46, Predicted=3847.8381, Expected=3801.0000
# Month=47, Predicted=3802.3277, Expected=3787.0000
# Month=48, Predicted=3788.0149, Expected=3776.0000
# Month=49, Predicted=3776.9855, Expected=3797.0000
# Month=50, Predicted=3797.6705, Expected=3821.0000
# Month=51, Predicted=3821.6408, Expected=3877.0000
# Month=52, Predicted=3877.3236, Expected=3875.0000
# Month=53, Predicted=3875.8971, Expected=3890.0000
# Month=54, Predicted=3890.7297, Expected=3910.0000
# Month=55, Predicted=3910.6803, Expected=3924.0000
# Month=56, Predicted=3924.7395, Expected=3918.0000
# Month=57, Predicted=3918.9364, Expected=3936.0000
# Month=58, Predicted=3936.7001, Expected=3911.0000
# Month=59, Predicted=3912.1227, Expected=3891.0000
# Month=60, Predicted=3892.0737, Expected=3855.0000
# Run 13 — RMSE: 24.490592, MSE: 599.789088, NMSE: 0.0027539606, Time: 165.5s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3798.9195, Expected=3796.0000
# Month=2, Predicted=3797.2440, Expected=3793.0000
# Month=3, Predicted=3794.2531, Expected=3766.0000
# Month=4, Predicted=3767.4718, Expected=3747.0000
# Month=5, Predicted=3748.3987, Expected=3754.0000
# Month=6, Predicted=3755.1625, Expected=3756.0000
# Month=7, Predicted=3757.2078, Expected=3767.0000
# Month=8, Predicted=3768.1264, Expected=3751.0000
# Month=9, Predicted=3752.3713, Expected=3769.0000
# Month=10, Predicted=3770.0633, Expected=3760.0000
# Month=11, Predicted=3761.3076, Expected=3785.0000
# Month=12, Predicted=3786.0003, Expected=3776.0000
# Month=13, Predicted=3777.3076, Expected=3755.0000
# Month=14, Predicted=3756.4170, Expected=3755.0000
# Month=15, Predicted=3756.2259, Expected=3751.0000
# Month=16, Predicted=3752.2622, Expected=3776.0000
# Month=17, Predicted=3777.0003, Expected=3847.0000
# Month=18, Predicted=3847.5893, Expected=3830.0000
# Month=19, Predicted=3831.3805, Expected=3881.0000
# Month=20, Predicted=3881.7674, Expected=3899.0000
# Month=21, Predicted=3900.0633, Expected=3917.0000
# Month=22, Predicted=3918.0633, Expected=3913.0000
# Month=23, Predicted=3914.2622, Expected=3901.0000
# Month=24, Predicted=3902.3349, Expected=3886.0000
# Month=25, Predicted=3887.3622, Expected=3892.5000
# Month=26, Predicted=3893.6671, Expected=3899.0000
# Month=27, Predicted=3900.1671, Expected=3886.0000
# Month=28, Predicted=3887.3440, Expected=3908.0000
# Month=29, Predicted=3909.0273, Expected=3875.0000
# Month=30, Predicted=3876.5269, Expected=3860.0000
# Month=31, Predicted=3861.3622, Expected=3880.0000
# Month=32, Predicted=3881.0453, Expected=3895.0000
# Month=33, Predicted=3896.0903, Expected=3954.0000
# Month=34, Predicted=3954.6961, Expected=3933.0000
# Month=35, Predicted=3934.4170, Expected=3937.0000
# Month=36, Predicted=3938.1897, Expected=3869.0000
# Month=37, Predicted=3870.8506, Expected=3852.0000
# Month=38, Predicted=3853.3805, Expected=3837.0000
# Month=39, Predicted=3838.3622, Expected=3832.0000
# Month=40, Predicted=3833.2713, Expected=3849.0000
# Month=41, Predicted=3850.0723, Expected=3863.0000
# Month=42, Predicted=3864.0993, Expected=3878.0000
# Month=43, Predicted=3879.0903, Expected=3855.0000
# Month=44, Predicted=3856.4352, Expected=3843.0000
# Month=45, Predicted=3844.3349, Expected=3847.0000
# Month=46, Predicted=3848.1897, Expected=3801.0000
# Month=47, Predicted=3802.6465, Expected=3787.0000
# Month=48, Predicted=3788.3531, Expected=3776.0000
# Month=49, Predicted=3777.3258, Expected=3797.0000
# Month=50, Predicted=3798.0363, Expected=3821.0000
# Month=51, Predicted=3822.0093, Expected=3877.0000
# Month=52, Predicted=3877.7228, Expected=3875.0000
# Month=53, Predicted=3876.2440, Expected=3890.0000
# Month=54, Predicted=3891.0903, Expected=3910.0000
# Month=55, Predicted=3911.0453, Expected=3924.0000
# Month=56, Predicted=3925.0993, Expected=3918.0000
# Month=57, Predicted=3919.2803, Expected=3936.0000
# Month=58, Predicted=3937.0633, Expected=3911.0000
# Month=59, Predicted=3912.4535, Expected=3891.0000
# Month=60, Predicted=3892.4078, Expected=3855.0000
# Run 14 — RMSE: 24.489840, MSE: 599.752273, NMSE: 0.0027534138, Time: 140.7s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3797.5861, Expected=3796.0000
# Month=2, Predicted=3797.3882, Expected=3793.0000
# Month=3, Predicted=3794.4381, Expected=3766.0000
# Month=4, Predicted=3768.6357, Expected=3747.0000
# Month=5, Predicted=3749.2369, Expected=3754.0000
# Month=6, Predicted=3754.9383, Expected=3756.0000
# Month=7, Predicted=3757.1883, Expected=3767.0000
# Month=8, Predicted=3767.7382, Expected=3751.0000
# Month=9, Predicted=3753.0872, Expected=3769.0000
# Month=10, Predicted=3769.3878, Expected=3760.0000
# Month=11, Predicted=3761.7378, Expected=3785.0000
# Month=12, Predicted=3785.0373, Expected=3776.0000
# Month=13, Predicted=3777.7378, Expected=3755.0000
# Month=14, Predicted=3757.3366, Expected=3755.0000
# Month=15, Predicted=3756.2882, Expected=3751.0000
# Month=16, Predicted=3752.4881, Expected=3776.0000
# Month=17, Predicted=3776.0373, Expected=3847.0000
# Month=18, Predicted=3844.7273, Expected=3830.0000
# Month=19, Predicted=3832.1371, Expected=3881.0000
# Month=20, Predicted=3879.7329, Expected=3899.0000
# Month=21, Predicted=3899.3878, Expected=3917.0000
# Month=22, Predicted=3917.3878, Expected=3913.0000
# Month=23, Predicted=3914.4881, Expected=3901.0000
# Month=24, Predicted=3902.8876, Expected=3886.0000
# Month=25, Predicted=3888.0373, Expected=3892.5000
# Month=26, Predicted=3893.4633, Expected=3899.0000
# Month=27, Predicted=3899.9633, Expected=3886.0000
# Month=28, Predicted=3887.9375, Expected=3908.0000
# Month=29, Predicted=3908.1875, Expected=3875.0000
# Month=30, Predicted=3877.9347, Expected=3860.0000
# Month=31, Predicted=3862.0373, Expected=3880.0000
# Month=32, Predicted=3880.2877, Expected=3895.0000
# Month=33, Predicted=3895.5380, Expected=3954.0000
# Month=34, Predicted=3952.3309, Expected=3933.0000
# Month=35, Predicted=3935.3366, Expected=3937.0000
# Month=36, Predicted=3938.0883, Expected=3869.0000
# Month=37, Predicted=3873.6750, Expected=3852.0000
# Month=38, Predicted=3854.1371, Expected=3837.0000
# Month=39, Predicted=3839.0373, Expected=3832.0000
# Month=40, Predicted=3833.5380, Expected=3849.0000
# Month=41, Predicted=3849.4379, Expected=3863.0000
# Month=42, Predicted=3863.5881, Expected=3878.0000
# Month=43, Predicted=3878.5380, Expected=3855.0000
# Month=44, Predicted=3857.4363, Expected=3843.0000
# Month=45, Predicted=3844.8876, Expected=3847.0000
# Month=46, Predicted=3848.0883, Expected=3801.0000
# Month=47, Predicted=3804.5818, Expected=3787.0000
# Month=48, Predicted=3788.9874, Expected=3776.0000
# Month=49, Predicted=3777.8377, Expected=3797.0000
# Month=50, Predicted=3797.2376, Expected=3821.0000
# Month=51, Predicted=3821.0874, Expected=3877.0000
# Month=52, Predicted=3875.4817, Expected=3875.0000
# Month=53, Predicted=3876.3882, Expected=3890.0000
# Month=54, Predicted=3890.5380, Expected=3910.0000
# Month=55, Predicted=3910.2877, Expected=3924.0000
# Month=56, Predicted=3924.5881, Expected=3918.0000
# Month=57, Predicted=3919.5880, Expected=3936.0000
# Month=58, Predicted=3936.3878, Expected=3911.0000
# Month=59, Predicted=3913.5360, Expected=3891.0000
# Month=60, Predicted=3893.2867, Expected=3855.0000
# Run 15 — RMSE: 24.630277, MSE: 606.650556, NMSE: 0.0028005764, Time: 123.5s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3798.0972, Expected=3796.0000
# Month=2, Predicted=3797.3385, Expected=3793.0000
# Month=3, Predicted=3794.3726, Expected=3766.0000
# Month=4, Predicted=3768.1859, Expected=3747.0000
# Month=5, Predicted=3748.9157, Expected=3754.0000
# Month=6, Predicted=3755.0309, Expected=3756.0000
# Month=7, Predicted=3757.2020, Expected=3767.0000
# Month=8, Predicted=3767.8936, Expected=3751.0000
# Month=9, Predicted=3752.8141, Expected=3769.0000
# Month=10, Predicted=3769.6526, Expected=3760.0000
# Month=11, Predicted=3761.5767, Expected=3785.0000
# Month=12, Predicted=3785.4105, Expected=3776.0000
# Month=13, Predicted=3777.5767, Expected=3755.0000
# Month=14, Predicted=3756.9833, Expected=3755.0000
# Month=15, Predicted=3756.2702, Expected=3751.0000
# Month=16, Predicted=3752.4066, Expected=3776.0000
# Month=17, Predicted=3776.4105, Expected=3847.0000
# Month=18, Predicted=3845.7829, Expected=3830.0000
# Month=19, Predicted=3831.8480, Expected=3881.0000
# Month=20, Predicted=3880.4990, Expected=3899.0000
# Month=21, Predicted=3899.6526, Expected=3917.0000
# Month=22, Predicted=3917.6526, Expected=3913.0000
# Month=23, Predicted=3914.4066, Expected=3901.0000
# Month=24, Predicted=3902.6785, Expected=3886.0000
# ...
# Month=55, Predicted=3910.5865, Expected=3924.0000
# Month=56, Predicted=3924.9190, Expected=3918.0000
# Month=57, Predicted=3920.0280, Expected=3936.0000
# Month=58, Predicted=3936.6973, Expected=3911.0000
# Month=59, Predicted=3914.0824, Expected=3891.0000
# Month=60, Predicted=3893.8048, Expected=3855.0000
# Run 25 — RMSE: 24.659612, MSE: 608.096473, NMSE: 0.0028089050, Time: 114.9s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3798.0644, Expected=3796.0000
# Month=2, Predicted=3797.1243, Expected=3793.0000
# Month=3, Predicted=3794.1536, Expected=3766.0000
# Month=4, Predicted=3767.8546, Expected=3747.0000
# Month=5, Predicted=3748.6214, Expected=3754.0000
# Month=6, Predicted=3754.8602, Expected=3756.0000
# Month=7, Predicted=3757.0070, Expected=3767.0000
# Month=8, Predicted=3767.7427, Expected=3751.0000
# Month=9, Predicted=3752.5338, Expected=3769.0000
# Month=10, Predicted=3769.5367, Expected=3760.0000
# Month=11, Predicted=3761.3292, Expected=3785.0000
# Month=12, Predicted=3785.3303, Expected=3776.0000
# Month=13, Predicted=3777.3292, Expected=3755.0000
# Month=14, Predicted=3756.6797, Expected=3755.0000
# Month=15, Predicted=3756.0656, Expected=3751.0000
# Month=16, Predicted=3752.1829, Expected=3776.0000
# Month=17, Predicted=3776.3303, Expected=3847.0000
# Month=18, Predicted=3845.9644, Expected=3830.0000
# Month=19, Predicted=3831.5630, Expected=3881.0000
# Month=20, Predicted=3880.5603, Expected=3899.0000
# Month=21, Predicted=3899.5367, Expected=3917.0000
# Month=22, Predicted=3917.5367, Expected=3913.0000
# Month=23, Predicted=3914.1829, Expected=3901.0000
# Month=24, Predicted=3902.4169, Expected=3886.0000
# Month=25, Predicted=3887.5046, Expected=3892.5000
# Month=26, Predicted=3893.3749, Expected=3899.0000
# Month=27, Predicted=3899.8749, Expected=3886.0000
# Month=28, Predicted=3887.4462, Expected=3908.0000
# Month=29, Predicted=3908.4188, Expected=3875.0000
# Month=30, Predicted=3877.0292, Expected=3860.0000
# Month=31, Predicted=3861.5046, Expected=3880.0000
# Month=32, Predicted=3880.4777, Expected=3895.0000
# Month=33, Predicted=3895.6250, Expected=3954.0000
# Month=34, Predicted=3953.3224, Expected=3933.0000
# Month=35, Predicted=3934.6797, Expected=3937.0000
# Month=36, Predicted=3937.9483, Expected=3869.0000
# Month=37, Predicted=3872.0432, Expected=3852.0000
# Month=38, Predicted=3853.5630, Expected=3837.0000
# Month=39, Predicted=3838.5046, Expected=3832.0000
# Month=40, Predicted=3833.2121, Expected=3849.0000
# Month=41, Predicted=3849.5661, Expected=3863.0000
# Month=42, Predicted=3863.6544, Expected=3878.0000
# Month=43, Predicted=3878.6250, Expected=3855.0000
# Month=44, Predicted=3856.7380, Expected=3843.0000
# Month=45, Predicted=3844.4169, Expected=3847.0000
# Month=46, Predicted=3847.9483, Expected=3801.0000
# Month=47, Predicted=3803.4068, Expected=3787.0000
# Month=48, Predicted=3788.4754, Expected=3776.0000
# Month=49, Predicted=3777.3877, Expected=3797.0000
# Month=50, Predicted=3797.4483, Expected=3821.0000
# Month=51, Predicted=3821.3598, Expected=3877.0000
# Month=52, Predicted=3876.4117, Expected=3875.0000
# Month=53, Predicted=3876.1243, Expected=3890.0000
# Month=54, Predicted=3890.6250, Expected=3910.0000
# Month=55, Predicted=3910.4777, Expected=3924.0000
# Month=56, Predicted=3924.6544, Expected=3918.0000
# Month=57, Predicted=3919.2414, Expected=3936.0000
# Month=58, Predicted=3936.5367, Expected=3911.0000
# Month=59, Predicted=3912.7963, Expected=3891.0000
# Month=60, Predicted=3892.6506, Expected=3855.0000
# Run 26 — RMSE: 24.552809, MSE: 602.840428, NMSE: 0.0027754738, Time: 107.5s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3798.5897, Expected=3796.0000
# Month=2, Predicted=3797.1557, Expected=3793.0000
# Month=3, Predicted=3794.1712, Expected=3766.0000
# Month=4, Predicted=3767.5387, Expected=3747.0000
# Month=5, Predicted=3748.4171, Expected=3754.0000
# Month=6, Predicted=3755.0158, Expected=3756.0000
# Month=7, Predicted=3757.0936, Expected=3767.0000
# Month=8, Predicted=3767.9532, Expected=3751.0000
# Month=9, Predicted=3752.3712, Expected=3769.0000
# Month=10, Predicted=3769.8433, Expected=3760.0000
# Month=11, Predicted=3761.2638, Expected=3785.0000
# Month=12, Predicted=3785.7327, Expected=3776.0000
# Month=13, Predicted=3777.2638, Expected=3755.0000
# Month=14, Predicted=3756.4476, Expected=3755.0000
# Month=15, Predicted=3756.1247, Expected=3751.0000
# Month=16, Predicted=3752.1867, Expected=3776.0000
# Month=17, Predicted=3776.7327, Expected=3847.0000
# Month=18, Predicted=3846.9921, Expected=3830.0000
# Month=19, Predicted=3831.3865, Expected=3881.0000
# Month=20, Predicted=3881.3169, Expected=3899.0000
# Month=21, Predicted=3899.8433, Expected=3917.0000
# Month=22, Predicted=3917.8433, Expected=3913.0000
# Month=23, Predicted=3914.1867, Expected=3901.0000
# Month=24, Predicted=3902.3099, Expected=3886.0000
# Month=25, Predicted=3887.3559, Expected=3892.5000
# Month=26, Predicted=3893.5236, Expected=3899.0000
# Month=27, Predicted=3900.0236, Expected=3886.0000
# Month=28, Predicted=3887.3253, Expected=3908.0000
# Month=29, Predicted=3908.7802, Expected=3875.0000
# Month=30, Predicted=3876.6293, Expected=3860.0000
# Month=31, Predicted=3861.3559, Expected=3880.0000
# Month=32, Predicted=3880.8117, Expected=3895.0000
# Month=33, Predicted=3895.8905, Expected=3954.0000
# Month=34, Predicted=3954.1875, Expected=3933.0000
# Month=35, Predicted=3934.4476, Expected=3937.0000
# Month=36, Predicted=3938.0625, Expected=3869.0000
# Month=37, Predicted=3871.1481, Expected=3852.0000
# Month=38, Predicted=3853.3865, Expected=3837.0000
# Month=39, Predicted=3838.3559, Expected=3832.0000
# Month=40, Predicted=3833.2021, Expected=3849.0000
# Month=41, Predicted=3849.8590, Expected=3863.0000
# Month=42, Predicted=3863.9062, Expected=3878.0000
# Month=43, Predicted=3878.8905, Expected=3855.0000
# Month=44, Predicted=3856.4780, Expected=3843.0000
# Month=45, Predicted=3844.3099, Expected=3847.0000
# Month=46, Predicted=3848.0625, Expected=3801.0000
# Month=47, Predicted=3802.8240, Expected=3787.0000
# Month=48, Predicted=3788.3406, Expected=3776.0000
# Month=49, Predicted=3777.2946, Expected=3797.0000
# Month=50, Predicted=3797.7960, Expected=3821.0000
# Month=51, Predicted=3821.7485, Expected=3877.0000
# Month=52, Predicted=3877.2361, Expected=3875.0000
# Month=53, Predicted=3876.1557, Expected=3890.0000
# Month=54, Predicted=3890.8905, Expected=3910.0000
# Month=55, Predicted=3910.8117, Expected=3924.0000
# Month=56, Predicted=3924.9062, Expected=3918.0000
# Month=57, Predicted=3919.2176, Expected=3936.0000
# Month=58, Predicted=3936.8433, Expected=3911.0000
# Month=59, Predicted=3912.5084, Expected=3891.0000
# Month=60, Predicted=3892.4323, Expected=3855.0000
# Run 27 — RMSE: 24.507371, MSE: 600.611253, NMSE: 0.0027600013, Time: 135.4s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3798.7409, Expected=3796.0000
# Month=2, Predicted=3797.1291, Expected=3793.0000
# Month=3, Predicted=3794.1399, Expected=3766.0000
# Month=4, Predicted=3767.3964, Expected=3747.0000
# Month=5, Predicted=3748.3111, Expected=3754.0000
# Month=6, Predicted=3755.0325, Expected=3756.0000
# Month=7, Predicted=3757.0862, Expected=3767.0000
# Month=8, Predicted=3767.9894, Expected=3751.0000
# Month=9, Predicted=3752.2790, Expected=3769.0000
# Month=10, Predicted=3769.9139, Expected=3760.0000
# Month=11, Predicted=3761.2042, Expected=3785.0000
# Month=12, Predicted=3785.8383, Expected=3776.0000
# Month=13, Predicted=3777.2042, Expected=3755.0000
# Month=14, Predicted=3756.3324, Expected=3755.0000
# Month=15, Predicted=3756.1077, Expected=3751.0000
# Month=16, Predicted=3752.1506, Expected=3776.0000
# Month=17, Predicted=3776.8383, Expected=3847.0000
# Month=18, Predicted=3847.3378, Expected=3830.0000
# Month=19, Predicted=3831.2897, Expected=3881.0000
# Month=20, Predicted=3881.5562, Expected=3899.0000
# Month=21, Predicted=3899.9139, Expected=3917.0000
# Month=22, Predicted=3917.9139, Expected=3913.0000
# Month=23, Predicted=3914.1506, Expected=3901.0000
# Month=24, Predicted=3902.2363, Expected=3886.0000
# Month=25, Predicted=3887.2683, Expected=3892.5000
# Month=26, Predicted=3893.5378, Expected=3899.0000
# Month=27, Predicted=3900.0378, Expected=3886.0000
# Month=28, Predicted=3887.2470, Expected=3908.0000
# Month=29, Predicted=3908.8707, Expected=3875.0000
# Month=30, Predicted=3876.4602, Expected=3860.0000
# Month=31, Predicted=3861.2683, Expected=3880.0000
# Month=32, Predicted=3880.8923, Expected=3895.0000
# Month=33, Predicted=3895.9463, Expected=3954.0000
# Month=34, Predicted=3954.4690, Expected=3933.0000
# Month=35, Predicted=3934.3324, Expected=3937.0000
# Month=36, Predicted=3938.0647, Expected=3869.0000
# Month=37, Predicted=3870.8301, Expected=3852.0000
# Month=38, Predicted=3853.2897, Expected=3837.0000
# Month=39, Predicted=3838.2683, Expected=3832.0000
# Month=40, Predicted=3833.1613, Expected=3849.0000
# Month=41, Predicted=3849.9247, Expected=3863.0000
# Month=42, Predicted=3863.9571, Expected=3878.0000
# Month=43, Predicted=3878.9463, Expected=3855.0000
# Month=44, Predicted=3856.3537, Expected=3843.0000
# Month=45, Predicted=3844.2363, Expected=3847.0000
# Month=46, Predicted=3848.0647, Expected=3801.0000
# Month=47, Predicted=3802.5980, Expected=3787.0000
# Month=48, Predicted=3788.2577, Expected=3776.0000
# Month=49, Predicted=3777.2256, Expected=3797.0000
# Month=50, Predicted=3797.8815, Expected=3821.0000
# Month=51, Predicted=3821.8491, Expected=3877.0000
# Month=52, Predicted=3877.5017, Expected=3875.0000
# Month=53, Predicted=3876.1291, Expected=3890.0000
# Month=54, Predicted=3890.9463, Expected=3910.0000
# Month=55, Predicted=3910.8923, Expected=3924.0000
# Month=56, Predicted=3924.9571, Expected=3918.0000
# Month=57, Predicted=3919.1720, Expected=3936.0000
# Month=58, Predicted=3936.9139, Expected=3911.0000
# Month=59, Predicted=3912.3751, Expected=3891.0000
# Month=60, Predicted=3892.3217, Expected=3855.0000
# Run 28 — RMSE: 24.493390, MSE: 599.926173, NMSE: 0.0027549410, Time: 182.0s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3798.0309, Expected=3796.0000
# Month=2, Predicted=3797.3918, Expected=3793.0000
# Month=3, Predicted=3794.4296, Expected=3766.0000
# Month=4, Predicted=3768.3348, Expected=3747.0000
# Month=5, Predicted=3749.0332, Expected=3754.0000
# Month=6, Predicted=3755.0519, Expected=3756.0000
# Month=7, Predicted=3757.2408, Expected=3767.0000
# Month=8, Predicted=3767.9008, Expected=3751.0000
# Month=9, Predicted=3752.9201, Expected=3769.0000
# Month=10, Predicted=3769.6362, Expected=3760.0000
# Month=11, Predicted=3761.6560, Expected=3785.0000
# Month=12, Predicted=3785.3715, Expected=3776.0000
# Month=13, Predicted=3777.6560, Expected=3755.0000
# Month=14, Predicted=3757.1086, Expected=3755.0000
# Month=15, Predicted=3756.3163, Expected=3751.0000
# Month=16, Predicted=3752.4673, Expected=3776.0000
# Month=17, Predicted=3776.3715, Expected=3847.0000
# Month=18, Predicted=3845.6282, Expected=3830.0000
# Month=19, Predicted=3831.9578, Expected=3881.0000
# Month=20, Predicted=3880.3869, Expected=3899.0000
# Month=21, Predicted=3899.6362, Expected=3917.0000
# Month=22, Predicted=3917.6362, Expected=3913.0000
# Month=23, Predicted=3914.4673, Expected=3901.0000
# Month=24, Predicted=3902.7692, Expected=3886.0000
# Month=25, Predicted=3887.8824, Expected=3892.5000
# Month=26, Predicted=3893.5708, Expected=3899.0000
# Month=27, Predicted=3900.0708, Expected=3886.0000
# Month=28, Predicted=3887.8069, Expected=3908.0000
# Month=29, Predicted=3908.4849, Expected=3875.0000
# Month=30, Predicted=3877.5609, Expected=3860.0000
# Month=31, Predicted=3861.8824, Expected=3880.0000
# Month=32, Predicted=3880.5606, Expected=3895.0000
# Month=33, Predicted=3895.7496, Expected=3954.0000
# Month=34, Predicted=3953.0836, Expected=3933.0000
# Month=35, Predicted=3935.1086, Expected=3937.0000
# Month=36, Predicted=3938.1652, Expected=3869.0000
# Month=37, Predicted=3872.8778, Expected=3852.0000
# Month=38, Predicted=3853.9578, Expected=3837.0000
# Month=39, Predicted=3838.8824, Expected=3832.0000
# Month=40, Predicted=3833.5051, Expected=3849.0000
# Month=41, Predicted=3849.6740, Expected=3863.0000
# Month=42, Predicted=3863.7874, Expected=3878.0000
# Month=43, Predicted=3878.7496, Expected=3855.0000
# Month=44, Predicted=3857.1840, Expected=3843.0000
# Month=45, Predicted=3844.7692, Expected=3847.0000
# Month=46, Predicted=3848.1652, Expected=3801.0000
# Month=47, Predicted=3804.0504, Expected=3787.0000
# Month=48, Predicted=3788.8447, Expected=3776.0000
# Month=49, Predicted=3777.7315, Expected=3797.0000
# Month=50, Predicted=3797.5227, Expected=3821.0000
# Month=51, Predicted=3821.4093, Expected=3877.0000
# Month=52, Predicted=3876.1974, Expected=3875.0000
# Month=53, Predicted=3876.3918, Expected=3890.0000
# Month=54, Predicted=3890.7496, Expected=3910.0000
# Month=55, Predicted=3910.5606, Expected=3924.0000
# Month=56, Predicted=3924.7874, Expected=3918.0000
# Month=57, Predicted=3919.5428, Expected=3936.0000
# Month=58, Predicted=3936.6362, Expected=3911.0000
# Month=59, Predicted=3913.2594, Expected=3891.0000
# Month=60, Predicted=3893.0709, Expected=3855.0000
# Run 29 — RMSE: 24.584677, MSE: 604.406333, NMSE: 0.0027857315, Time: 191.9s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3798.2753, Expected=3796.0000
# Month=2, Predicted=3797.5600, Expected=3793.0000
# Month=3, Predicted=3794.5965, Expected=3766.0000
# Month=4, Predicted=3768.4835, Expected=3747.0000
# Month=5, Predicted=3749.1852, Expected=3754.0000
# Month=6, Predicted=3755.2339, Expected=3756.0000
# Month=7, Predicted=3757.4147, Expected=3767.0000
# Month=8, Predicted=3768.0900, Expected=3751.0000
# Month=9, Predicted=3753.0740, Expected=3769.0000
# Month=10, Predicted=3769.8398, Expected=3760.0000
# Month=11, Predicted=3761.8160, Expected=3785.0000
# Month=12, Predicted=3785.5916, Expected=3776.0000
# Month=13, Predicted=3777.8160, Expected=3755.0000
# Month=14, Predicted=3757.2595, Expected=3755.0000
# Month=15, Predicted=3756.4873, Expected=3751.0000
# Month=16, Predicted=3752.6330, Expected=3776.0000
# Month=17, Predicted=3776.5916, Expected=3847.0000
# Month=18, Predicted=3846.0094, Expected=3830.0000
# Month=19, Predicted=3832.1110, Expected=3881.0000
# Month=20, Predicted=3880.6869, Expected=3899.0000
# Month=21, Predicted=3899.8398, Expected=3917.0000
# Month=22, Predicted=3917.8398, Expected=3913.0000
# Month=23, Predicted=3914.6330, Expected=3901.0000
# Month=24, Predicted=3902.9263, Expected=3886.0000
# Month=25, Predicted=3888.0370, Expected=3892.5000
# Month=26, Predicted=3893.7519, Expected=3899.0000
# Month=27, Predicted=3900.2519, Expected=3886.0000
# Month=28, Predicted=3887.9632, Expected=3908.0000
# Month=29, Predicted=3908.6977, Expected=3875.0000
# Month=30, Predicted=3877.7090, Expected=3860.0000
# Month=31, Predicted=3862.0370, Expected=3880.0000
# Month=32, Predicted=3880.7687, Expected=3895.0000
# Month=33, Predicted=3895.9468, Expected=3954.0000
# Month=34, Predicted=3953.4140, Expected=3933.0000
# Month=35, Predicted=3935.2595, Expected=3937.0000
# Month=36, Predicted=3938.3422, Expected=3869.0000
# Month=37, Predicted=3873.0540, Expected=3852.0000
# Month=38, Predicted=3854.1110, Expected=3837.0000
# Month=39, Predicted=3839.0370, Expected=3832.0000
# Month=40, Predicted=3833.6695, Expected=3849.0000
# Month=41, Predicted=3849.8754, Expected=3863.0000
# Month=42, Predicted=3863.9825, Expected=3878.0000
# Month=43, Predicted=3878.9468, Expected=3855.0000
# Month=44, Predicted=3857.3340, Expected=3843.0000
# Month=45, Predicted=3844.9263, Expected=3847.0000
# Month=46, Predicted=3848.3422, Expected=3801.0000
# Month=47, Predicted=3804.2027, Expected=3787.0000
# Month=48, Predicted=3789.0001, Expected=3776.0000
# Month=49, Predicted=3777.8895, Expected=3797.0000
# Month=50, Predicted=3797.7332, Expected=3821.0000
# Month=51, Predicted=3821.6269, Expected=3877.0000
# Month=52, Predicted=3876.5161, Expected=3875.0000
# Month=53, Predicted=3876.5600, Expected=3890.0000
# Month=54, Predicted=3890.9468, Expected=3910.0000
# Month=55, Predicted=3910.7687, Expected=3924.0000
# Month=56, Predicted=3924.9825, Expected=3918.0000
# Month=57, Predicted=3919.7061, Expected=3936.0000
# Month=58, Predicted=3936.8398, Expected=3911.0000
# Month=59, Predicted=3913.4087, Expected=3891.0000
# Month=60, Predicted=3893.2223, Expected=3855.0000
# Run 30 — RMSE: 24.585366, MSE: 604.440225, NMSE: 0.0027849445, Time: 169.5s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Autoformer on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.564339 ± 0.072628
# MSE:  603.412048 ± 3.568727
# NMSE: 0.0027779071 ± 0.0000235607
# Avg training time: 103.1s ± 39.0s
#
# Best run: 21
#   RMSE: 24.464521
#   MSE:  598.512809
#   NMSE: 0.0027444279

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Autoformer — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Autoformer — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.464521
# MSE:  598.512809
# NMSE: 0.0027444279

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Autoformer_DowJones_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to Autoformer_DowJones_predictions.csv

# %% [markdown]
# ## Observations
#
# ### Autoformer on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
