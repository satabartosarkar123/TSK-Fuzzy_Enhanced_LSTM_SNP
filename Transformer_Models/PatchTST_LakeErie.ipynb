# %% [markdown]
# # PatchTST — Monthly Lake Erie Levels
#
# **Model**: Patch-based Time Series Transformer
# **Reference**: Nie et al., 2023 — A Time Series is Worth 64 Words: Long-term Forecasting with Transformers
#
# ## Description
# This notebook implements the **PatchTST** Transformer architecture for univariate time-series
# forecasting on the Monthly Lake Erie Levels dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: PatchTST Architecture
#
# ### Patching
# Time series is segmented into **subseries-level patches**:
# $$P_i = x[i \cdot S : i \cdot S + P], \quad i = 0, 1, \ldots, N-1$$
#
# where $P$ = patch length, $S$ = stride, $N$ = number of patches.
#
# Each patch is projected to $d_{\text{model}}$ dimensions via a linear layer.
#
# ### Channel Independence
# Each variate (channel) is processed **independently** through the same Transformer backbone, reducing parameters and improving robustness.
#
# ### Instance Normalization
# Applied per-instance to handle distribution shift between training and testing:
# $$\hat{x} = \frac{x - \mu_x}{\sigma_x}$$
#
# ### Standard Transformer
# After patching, a standard Transformer encoder processes the patch tokens with multi-head self-attention and feed-forward layers.
#
# ### Complexity
# Patching reduces the effective sequence length from $L$ to $N = L/S$, achieving $O(N^2) = O((L/S)^2)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.8.0+cpu
# NumPy version: 2.0.2
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### PatchTST Model Definition

# %%
# ============================================================
# PatchTST: Patch-based Time Series Transformer
# Reference: Nie et al., 2023
#
# Key ideas:
# 1. Patching: segment time series into subseries-level patches
# 2. Channel independence: each variate processed independently
# 3. Instance normalization for distribution shift
#
# For our single-step (seq_len=1) setup, patch_len=1 naturally.
# The architecture still applies the full Transformer pipeline.
# ============================================================

class PatchEmbedding(nn.Module):
    """
    Patch embedding for time series.
    Segments input into patches and projects to d_model.
    For seq_len=1, patch_len=1, this is equivalent to a linear projection.
    """
    def __init__(self, input_dim, d_model, patch_len=1, stride=1):
        super().__init__()
        self.patch_len = patch_len
        self.stride = stride
        self.proj = nn.Linear(patch_len * input_dim, d_model)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape
        # Number of patches
        n_patches = max(1, (L - self.patch_len) // self.stride + 1)

        patches = []
        for i in range(n_patches):
            start = i * self.stride
            end = start + self.patch_len
            patch = x[:, start:end, :].reshape(B, -1)  # (B, patch_len * C)
            patches.append(patch)

        patches = torch.stack(patches, dim=1)  # (B, n_patches, patch_len * C)
        return self.proj(patches)  # (B, n_patches, d_model)


class PatchTSTEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = nn.MultiheadAttention(d_model, n_heads,
                                                dropout=dropout,
                                                batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_out, _ = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_out))
        ff_out = self.ff(x)
        x = self.norm2(x + ff_out)
        return x


class PatchTSTModel(nn.Module):
    """
    PatchTST for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, patch_len=1, stride=1, dropout=0.1):
        super().__init__()
        # Instance normalization
        self.instance_norm = nn.InstanceNorm1d(input_dim, affine=False)

        self.patch_embed = PatchEmbedding(input_dim, d_model, patch_len, stride)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            PatchTSTEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.flatten_head = nn.Linear(d_model, 1)

    def forward(self, x):
        # x: (B, L, C)
        B, L, C = x.shape

        # Instance normalization (channel-wise)
        if L > 1:
            x = self.instance_norm(x.transpose(1, 2)).transpose(1, 2)

        # Patch embedding
        x = self.patch_embed(x)  # (B, n_patches, d_model)
        n_patches = x.shape[1]
        x = x + self.pos_embedding[:, :n_patches, :]

        # Transformer encoder
        for layer in self.encoder_layers:
            x = layer(x)

        # Use last patch for prediction
        x = x[:, -1, :]
        return self.flatten_head(x)

# %%
# Quick model check
set_seed(0)
test_model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20385
# Trainable parameters: 20385
# Memory estimate: 79.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = PatchTSTModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2923, Expected=13.7000
# Month=2, Predicted=14.1063, Expected=13.8140
# Month=3, Predicted=13.9569, Expected=14.3830
# Month=4, Predicted=14.7893, Expected=15.0470
# Month=5, Predicted=15.5321, Expected=15.6930
# Month=6, Predicted=16.1631, Expected=15.8440
# Month=7, Predicted=16.0206, Expected=15.7120
# Month=8, Predicted=15.5024, Expected=15.3130
# Month=9, Predicted=14.9188, Expected=14.7630
# Month=10, Predicted=14.3039, Expected=13.5480
# Month=11, Predicted=12.9768, Expected=13.5860
# Month=12, Predicted=13.6320, Expected=14.5160
# Month=13, Predicted=15.1751, Expected=14.3830
# Month=14, Predicted=14.1723, Expected=14.4970
# Month=15, Predicted=14.6399, Expected=14.7440
# Month=16, Predicted=14.9783, Expected=15.8060
# Month=17, Predicted=16.5165, Expected=16.5270
# Month=18, Predicted=17.0580, Expected=16.5460
# Month=19, Predicted=16.5622, Expected=16.7170
# Month=20, Predicted=16.9087, Expected=16.4330
# Month=21, Predicted=16.1013, Expected=15.7690
# Month=22, Predicted=15.2740, Expected=15.2750
# Month=23, Predicted=14.8377, Expected=15.1230
# Month=24, Predicted=14.8923, Expected=15.5410
# Month=25, Predicted=15.8476, Expected=15.8250
# Month=26, Predicted=16.0748, Expected=16.3760
# Month=27, Predicted=16.7682, Expected=16.3570
# Month=28, Predicted=16.3102, Expected=16.9070
# Month=29, Predicted=17.2984, Expected=17.0210
# Month=30, Predicted=17.1639, Expected=17.4190
# Month=31, Predicted=17.7158, Expected=17.5330
# Month=32, Predicted=17.6759, Expected=17.2680
# Month=33, Predicted=16.9481, Expected=16.6030
# Month=34, Predicted=16.1077, Expected=15.8250
# Month=35, Predicted=15.3039, Expected=15.4460
# Month=36, Predicted=15.0618, Expected=15.6360
# Month=37, Predicted=15.8403, Expected=15.6930
# Month=38, Predicted=15.7668, Expected=16.7550
# Month=39, Predicted=17.4655, Expected=16.5090
# Month=40, Predicted=16.2016, Expected=17.7230
# Month=41, Predicted=18.4746, Expected=18.6910
# Month=42, Predicted=19.3668, Expected=19.1270
# Month=43, Predicted=19.4431, Expected=19.5640
# Month=44, Predicted=19.8806, Expected=19.2030
# Month=45, Predicted=18.8281, Expected=18.2160
# Month=46, Predicted=17.6642, Expected=17.2110
# Month=47, Predicted=16.6572, Expected=16.6600
# Month=48, Predicted=16.2005, Expected=16.8310
# Month=49, Predicted=17.0227, Expected=15.7690
# Month=50, Predicted=15.2096, Expected=15.7310
# Month=51, Predicted=15.6526, Expected=15.9960
# Month=52, Predicted=16.2381, Expected=17.0210
# Month=53, Predicted=17.7189, Expected=17.5520
# Month=54, Predicted=17.9291, Expected=17.8370
# Month=55, Predicted=18.0872, Expected=17.8560
# Month=56, Predicted=17.8722, Expected=17.5710
# Month=57, Predicted=17.2387, Expected=17.0780
# Month=58, Predicted=16.6411, Expected=16.6600
# Month=59, Predicted=16.2566, Expected=16.4330
# Month=60, Predicted=16.1388, Expected=16.5840
# Run 1 — RMSE: 0.506003, MSE: 0.256039, NMSE: 0.0019241316, Time: 441.3s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1982, Expected=13.7000
# Month=2, Predicted=14.0815, Expected=13.8140
# Month=3, Predicted=13.8625, Expected=14.3830
# Month=4, Predicted=14.7645, Expected=15.0470
# Month=5, Predicted=15.4879, Expected=15.6930
# Month=6, Predicted=16.1229, Expected=15.8440
# Month=7, Predicted=15.9283, Expected=15.7120
# Month=8, Predicted=15.5088, Expected=15.3130
# Month=9, Predicted=14.9317, Expected=14.7630
# Month=10, Predicted=14.3225, Expected=13.5480
# Month=11, Predicted=13.0014, Expected=13.5860
# Month=12, Predicted=13.5551, Expected=14.5160
# Month=13, Predicted=15.1064, Expected=14.3830
# Month=14, Predicted=14.1789, Expected=14.4970
# Month=15, Predicted=14.5455, Expected=14.7440
# Month=16, Predicted=14.9093, Expected=15.8060
# Month=17, Predicted=16.4603, Expected=16.5270
# Month=18, Predicted=17.0022, Expected=16.5460
# Month=19, Predicted=16.4947, Expected=16.7170
# Month=20, Predicted=16.8196, Expected=16.4330
# Month=21, Predicted=16.1144, Expected=15.7690
# Month=22, Predicted=15.2960, Expected=15.2750
# Month=23, Predicted=14.8539, Expected=15.1230
# Month=24, Predicted=14.9023, Expected=15.5410
# Month=25, Predicted=15.8243, Expected=15.8250
# Month=26, Predicted=16.0176, Expected=16.3760
# Month=27, Predicted=16.7459, Expected=16.3570
# Month=28, Predicted=16.2651, Expected=16.9070
# Month=29, Predicted=17.2763, Expected=17.0210
# Month=30, Predicted=17.0695, Expected=17.4190
# Month=31, Predicted=17.6891, Expected=17.5330
# Month=32, Predicted=17.5815, Expected=17.2680
# Month=33, Predicted=16.9616, Expected=16.6030
# Month=34, Predicted=16.1298, Expected=15.8250
# Month=35, Predicted=15.3272, Expected=15.4460
# Month=36, Predicted=15.0743, Expected=15.6360
# Month=37, Predicted=15.7553, Expected=15.6930
# Month=38, Predicted=15.6824, Expected=16.7550
# Month=39, Predicted=17.4093, Expected=16.5090
# Month=40, Predicted=16.2155, Expected=17.7230
# Month=41, Predicted=18.4431, Expected=18.6910
# Month=42, Predicted=19.3004, Expected=19.1270
# Month=43, Predicted=19.4221, Expected=19.5640
# Month=44, Predicted=19.8598, Expected=19.2030
# Month=45, Predicted=18.8404, Expected=18.2160
# Month=46, Predicted=17.6877, Expected=17.2110
# Month=47, Predicted=16.6808, Expected=16.6600
# Month=48, Predicted=16.2191, Expected=16.8310
# Month=49, Predicted=16.9336, Expected=15.7690
# Month=50, Predicted=15.2333, Expected=15.7310
# Month=51, Predicted=15.6192, Expected=15.9960
# Month=52, Predicted=16.1748, Expected=17.0210
# Month=53, Predicted=17.6580, Expected=17.5520
# Month=54, Predicted=17.9090, Expected=17.8370
# Month=55, Predicted=18.0303, Expected=17.8560
# Month=56, Predicted=17.8047, Expected=17.5710
# Month=57, Predicted=17.2518, Expected=17.0780
# Month=58, Predicted=16.6573, Expected=16.6600
# Month=59, Predicted=16.2700, Expected=16.4330
# Month=60, Predicted=16.1529, Expected=16.5840
# Run 2 — RMSE: 0.506345, MSE: 0.256385, NMSE: 0.0019306890, Time: 443.8s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2119, Expected=13.7000
# Month=2, Predicted=14.0485, Expected=13.8140
# Month=3, Predicted=13.8753, Expected=14.3830
# Month=4, Predicted=14.7315, Expected=15.0470
# Month=5, Predicted=15.4581, Expected=15.6930
# Month=6, Predicted=16.0900, Expected=15.8440
# Month=7, Predicted=15.9430, Expected=15.7120
# Month=8, Predicted=15.5262, Expected=15.3130
# Month=9, Predicted=14.9615, Expected=14.7630
# Month=10, Predicted=14.3496, Expected=13.5480
# Month=11, Predicted=12.9951, Expected=13.5860
# Month=12, Predicted=13.5658, Expected=14.5160
# Month=13, Predicted=15.1682, Expected=14.3830
# Month=14, Predicted=14.1964, Expected=14.4970
# Month=15, Predicted=14.5583, Expected=14.7440
# Month=16, Predicted=14.9271, Expected=15.8060
# Month=17, Predicted=16.5334, Expected=16.5270
# Month=18, Predicted=16.9887, Expected=16.5460
# Month=19, Predicted=16.5054, Expected=16.7170
# Month=20, Predicted=16.8353, Expected=16.4330
# Month=21, Predicted=16.1411, Expected=15.7690
# Month=22, Predicted=15.3177, Expected=15.2750
# Month=23, Predicted=14.8829, Expected=15.1230
# Month=24, Predicted=14.9210, Expected=15.5410
# Month=25, Predicted=15.8235, Expected=15.8250
# Month=26, Predicted=16.0344, Expected=16.3760
# Month=27, Predicted=16.7156, Expected=16.3570
# Month=28, Predicted=16.2766, Expected=16.9070
# Month=29, Predicted=17.2461, Expected=17.0210
# Month=30, Predicted=17.0823, Expected=17.4190
# Month=31, Predicted=17.6923, Expected=17.5330
# Month=32, Predicted=17.5943, Expected=17.2680
# Month=33, Predicted=16.9874, Expected=16.6030
# Month=34, Predicted=16.1514, Expected=15.8250
# Month=35, Predicted=15.3424, Expected=15.4460
# Month=36, Predicted=15.1040, Expected=15.6360
# Month=37, Predicted=15.7718, Expected=15.6930
# Month=38, Predicted=15.6933, Expected=16.7550
# Month=39, Predicted=17.4824, Expected=16.5090
# Month=40, Predicted=16.2402, Expected=17.7230
# Month=41, Predicted=18.5002, Expected=18.6910
# Month=42, Predicted=19.3689, Expected=19.1270
# Month=43, Predicted=19.4173, Expected=19.5640
# Month=44, Predicted=19.8548, Expected=19.2030
# Month=45, Predicted=18.8698, Expected=18.2160
# Month=46, Predicted=17.6915, Expected=17.2110
# Month=47, Predicted=16.6837, Expected=16.6600
# Month=48, Predicted=16.2463, Expected=16.8310
# Month=49, Predicted=16.9493, Expected=15.7690
# Month=50, Predicted=15.2335, Expected=15.7310
# Month=51, Predicted=15.6314, Expected=15.9960
# Month=52, Predicted=16.1923, Expected=17.0210
# Month=53, Predicted=17.7311, Expected=17.5520
# Month=54, Predicted=17.8823, Expected=17.8370
# Month=55, Predicted=18.0471, Expected=17.8560
# Month=56, Predicted=17.8154, Expected=17.5710
# Month=57, Predicted=17.2786, Expected=17.0780
# Month=58, Predicted=16.6863, Expected=16.6600
# Month=59, Predicted=16.2999, Expected=16.4330
# Month=60, Predicted=16.1766, Expected=16.5840
# Run 3 — RMSE: 0.506974, MSE: 0.257022, NMSE: 0.0019270615, Time: 445.3s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2355, Expected=13.7000
# Month=2, Predicted=14.0261, Expected=13.8140
# Month=3, Predicted=13.9010, Expected=14.3830
# Month=4, Predicted=14.7091, Expected=15.0470
# Month=5, Predicted=15.4398, Expected=15.6930
# Month=6, Predicted=16.0713, Expected=15.8440
# Month=7, Predicted=15.9637, Expected=15.7120
# Month=8, Predicted=15.4859, Expected=15.3130
# Month=9, Predicted=14.9204, Expected=14.7630
# Month=10, Predicted=14.3262, Expected=13.5480
# Month=11, Predicted=13.0662, Expected=13.5860
# Month=12, Predicted=13.5855, Expected=14.5160
# Month=13, Predicted=15.1250, Expected=14.3830
# Month=14, Predicted=14.1559, Expected=14.4970
# Month=15, Predicted=14.5840, Expected=14.7440
# Month=16, Predicted=14.9255, Expected=15.8060
# Month=17, Predicted=16.4842, Expected=16.5270
# Month=18, Predicted=16.9692, Expected=16.5460
# Month=19, Predicted=16.5198, Expected=16.7170
# Month=20, Predicted=16.8519, Expected=16.4330
# Month=21, Predicted=16.0946, Expected=15.7690
# Month=22, Predicted=15.3143, Expected=15.2750
# Month=23, Predicted=14.8512, Expected=15.1230
# Month=24, Predicted=14.8770, Expected=15.5410
# Month=25, Predicted=15.8002, Expected=15.8250
# Month=26, Predicted=16.0253, Expected=16.3760
# Month=27, Predicted=16.6922, Expected=16.3570
# Month=28, Predicted=16.2771, Expected=16.9070
# Month=29, Predicted=17.2227, Expected=17.0210
# Month=30, Predicted=17.1080, Expected=17.4190
# Month=31, Predicted=17.6701, Expected=17.5330
# Month=32, Predicted=17.6200, Expected=17.2680
# Month=33, Predicted=16.9402, Expected=16.6030
# Month=34, Predicted=16.1481, Expected=15.8250
# Month=35, Predicted=15.3594, Expected=15.4460
# Month=36, Predicted=15.0616, Expected=15.6360
# Month=37, Predicted=15.7840, Expected=15.6930
# Month=38, Predicted=15.7168, Expected=16.7550
# Month=39, Predicted=17.4332, Expected=16.5090
# Month=40, Predicted=16.1924, Expected=17.7230
# Month=41, Predicted=18.4548, Expected=18.6910
# Month=42, Predicted=19.3227, Expected=19.1270
# Month=43, Predicted=19.3934, Expected=19.5640
# Month=44, Predicted=19.8308, Expected=19.2030
# Month=45, Predicted=18.8264, Expected=18.2160
# Month=46, Predicted=17.7397, Expected=17.2110
# Month=47, Predicted=16.7341, Expected=16.6600
# Month=48, Predicted=16.2230, Expected=16.8310
# Month=49, Predicted=16.9659, Expected=15.7690
# Month=50, Predicted=15.2904, Expected=15.7310
# Month=51, Predicted=15.6239, Expected=15.9960
# Month=52, Predicted=16.1868, Expected=17.0210
# Month=53, Predicted=17.6824, Expected=17.5520
# Month=54, Predicted=17.8582, Expected=17.8370
# Month=55, Predicted=18.0378, Expected=17.8560
# Month=56, Predicted=17.8298, Expected=17.5710
# Month=57, Predicted=17.2320, Expected=17.0780
# Month=58, Predicted=16.6545, Expected=16.6600
# Month=59, Predicted=16.2601, Expected=16.4330
# Month=60, Predicted=16.1284, Expected=16.5840
# Run 4 — RMSE: 0.503381, MSE: 0.253393, NMSE: 0.0019196144, Time: 442.2s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.3088, Expected=13.7000
# Month=2, Predicted=14.0958, Expected=13.8140
# Month=3, Predicted=13.9725, Expected=14.3830
# Month=4, Predicted=14.7788, Expected=15.0470
# Month=5, Predicted=15.5365, Expected=15.6930
# Month=6, Predicted=16.1621, Expected=15.8440
# Month=7, Predicted=16.0389, Expected=15.7120
# Month=8, Predicted=15.5431, Expected=15.3130
# Month=9, Predicted=14.9437, Expected=14.7630
# Month=10, Predicted=14.3093, Expected=13.5480
# Month=11, Predicted=12.9981, Expected=13.5860
# Month=12, Predicted=13.6542, Expected=14.5160
# Month=13, Predicted=15.2272, Expected=14.3830
# Month=14, Predicted=14.2129, Expected=14.4970
# Month=15, Predicted=14.6555, Expected=14.7440
# Month=16, Predicted=15.0138, Expected=15.8060
# Month=17, Predicted=16.5582, Expected=16.5270
# Month=18, Predicted=17.0817, Expected=16.5460
# Month=19, Predicted=16.5886, Expected=16.7170
# Month=20, Predicted=16.9297, Expected=16.4330
# Month=21, Predicted=16.1293, Expected=15.7690
# Month=22, Predicted=15.2741, Expected=15.2750
# Month=23, Predicted=14.8496, Expected=15.1230
# Month=24, Predicted=14.9302, Expected=15.5410
# Month=25, Predicted=15.8825, Expected=15.8250
# Month=26, Predicted=16.1171, Expected=16.3760
# Month=27, Predicted=16.7595, Expected=16.3570
# Month=28, Predicted=16.3459, Expected=16.9070
# Month=29, Predicted=17.2899, Expected=17.0210
# Month=30, Predicted=17.1795, Expected=17.4190
# Month=31, Predicted=17.7562, Expected=17.5330
# Month=32, Predicted=17.6915, Expected=17.2680
# Month=33, Predicted=16.9760, Expected=16.6030
# Month=34, Predicted=16.1079, Expected=15.8250
# Month=35, Predicted=15.3063, Expected=15.4460
# Month=36, Predicted=15.0885, Expected=15.6360
# Month=37, Predicted=15.8645, Expected=15.6930
# Month=38, Predicted=15.7857, Expected=16.7550
# Month=39, Predicted=17.5072, Expected=16.5090
# Month=40, Predicted=16.2297, Expected=17.7230
# Month=41, Predicted=18.5007, Expected=18.6910
# Month=42, Predicted=19.4168, Expected=19.1270
# Month=43, Predicted=19.4720, Expected=19.5640
# Month=44, Predicted=19.9091, Expected=19.2030
# Month=45, Predicted=18.8558, Expected=18.2160
# Month=46, Predicted=17.6760, Expected=17.2110
# Month=47, Predicted=16.6699, Expected=16.6600
# Month=48, Predicted=16.2058, Expected=16.8310
# Month=49, Predicted=17.0437, Expected=15.7690
# Month=50, Predicted=15.2249, Expected=15.7310
# Month=51, Predicted=15.6923, Expected=15.9960
# Month=52, Predicted=16.2771, Expected=17.0210
# Month=53, Predicted=17.7642, Expected=17.5520
# Month=54, Predicted=17.9244, Expected=17.8370
# Month=55, Predicted=18.1297, Expected=17.8560
# Month=56, Predicted=17.8986, Expected=17.5710
# Month=57, Predicted=17.2667, Expected=17.0780
# Month=58, Predicted=16.6532, Expected=16.6600
# Month=59, Predicted=16.2793, Expected=16.4330
# Month=60, Predicted=16.1678, Expected=16.5840
# Run 5 — RMSE: 0.504882, MSE: 0.254906, NMSE: 0.0019074323, Time: 366.8s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2257, Expected=13.7000
# Month=2, Predicted=14.0605, Expected=13.8140
# Month=3, Predicted=13.8904, Expected=14.3830
# Month=4, Predicted=14.7435, Expected=15.0470
# Month=5, Predicted=15.4868, Expected=15.6930
# Month=6, Predicted=16.1162, Expected=15.8440
# Month=7, Predicted=15.9555, Expected=15.7120
# Month=8, Predicted=15.5299, Expected=15.3130
# Month=9, Predicted=14.9450, Expected=14.7630
# Month=10, Predicted=14.3363, Expected=13.5480
# Month=11, Predicted=12.9998, Expected=13.5860
# Month=12, Predicted=13.5837, Expected=14.5160
# Month=13, Predicted=15.1733, Expected=14.3830
# Month=14, Predicted=14.1999, Expected=14.4970
# Month=15, Predicted=14.5734, Expected=14.7440
# Month=16, Predicted=14.9337, Expected=15.8060
# Month=17, Predicted=16.5213, Expected=16.5270
# Month=18, Predicted=17.0213, Expected=16.5460
# Month=19, Predicted=16.5231, Expected=16.7170
# Month=20, Predicted=16.8464, Expected=16.4330
# Month=21, Predicted=16.1284, Expected=15.7690
# Month=22, Predicted=15.3090, Expected=15.2750
# Month=23, Predicted=14.8677, Expected=15.1230
# Month=24, Predicted=14.9220, Expected=15.5410
# Month=25, Predicted=15.8228, Expected=15.8250
# Month=26, Predicted=16.0394, Expected=16.3760
# Month=27, Predicted=16.7243, Expected=16.3570
# Month=28, Predicted=16.2926, Expected=16.9070
# Month=29, Predicted=17.2546, Expected=17.0210
# Month=30, Predicted=17.0974, Expected=17.4190
# Month=31, Predicted=17.6922, Expected=17.5330
# Month=32, Predicted=17.6094, Expected=17.2680
# Month=33, Predicted=16.9761, Expected=16.6030
# Month=34, Predicted=16.1427, Expected=15.8250
# Month=35, Predicted=15.3382, Expected=15.4460
# Month=36, Predicted=15.0876, Expected=15.6360
# Month=37, Predicted=15.7816, Expected=15.6930
# Month=38, Predicted=15.7110, Expected=16.7550
# Month=39, Predicted=17.4703, Expected=16.5090
# Month=40, Predicted=16.2305, Expected=17.7230
# Month=41, Predicted=18.4794, Expected=18.6910
# Month=42, Predicted=19.3679, Expected=19.1270
# Month=43, Predicted=19.4164, Expected=19.5640
# Month=44, Predicted=19.8538, Expected=19.2030
# Month=45, Predicted=18.8537, Expected=18.2160
# Month=46, Predicted=17.6930, Expected=17.2110
# Month=47, Predicted=16.6855, Expected=16.6600
# Month=48, Predicted=16.2330, Expected=16.8310
# Month=49, Predicted=16.9604, Expected=15.7690
# Month=50, Predicted=15.2363, Expected=15.7310
# Month=51, Predicted=15.6459, Expected=15.9960
# Month=52, Predicted=16.1981, Expected=17.0210
# Month=53, Predicted=17.7227, Expected=17.5520
# Month=54, Predicted=17.8879, Expected=17.8370
# Month=55, Predicted=18.0520, Expected=17.8560
# Month=56, Predicted=17.8331, Expected=17.5710
# Month=57, Predicted=17.2658, Expected=17.0780
# Month=58, Predicted=16.6711, Expected=16.6600
# Month=59, Predicted=16.2834, Expected=16.4330
# Month=60, Predicted=16.1687, Expected=16.5840
# Run 6 — RMSE: 0.505514, MSE: 0.255544, NMSE: 0.0019220637, Time: 377.6s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.3523, Expected=13.7000
# Month=2, Predicted=14.1597, Expected=13.8140
# Month=3, Predicted=14.0188, Expected=14.3830
# Month=4, Predicted=14.8427, Expected=15.0470
# Month=5, Predicted=15.6094, Expected=15.6930
# Month=6, Predicted=16.2373, Expected=15.8440
# Month=7, Predicted=16.0791, Expected=15.7120
# Month=8, Predicted=15.5770, Expected=15.3130
# Month=9, Predicted=14.9442, Expected=14.7630
# Month=10, Predicted=14.3417, Expected=13.5480
# Month=11, Predicted=13.0655, Expected=13.5860
# Month=12, Predicted=13.7047, Expected=14.5160
# Month=13, Predicted=15.2381, Expected=14.3830
# Month=14, Predicted=14.2466, Expected=14.4970
# Month=15, Predicted=14.7018, Expected=14.7440
# Month=16, Predicted=15.0306, Expected=15.8060
# Month=17, Predicted=16.5623, Expected=16.5270
# Month=18, Predicted=17.1398, Expected=16.5460
# Month=19, Predicted=16.6386, Expected=16.7170
# Month=20, Predicted=16.9656, Expected=16.4330
# Month=21, Predicted=16.1329, Expected=15.7690
# Month=22, Predicted=15.3237, Expected=15.2750
# Month=23, Predicted=14.8698, Expected=15.1230
# Month=24, Predicted=14.9606, Expected=15.5410
# Month=25, Predicted=15.8823, Expected=15.8250
# Month=26, Predicted=16.1251, Expected=16.3760
# Month=27, Predicted=16.8160, Expected=16.3570
# Month=28, Predicted=16.3937, Expected=16.9070
# Month=29, Predicted=17.3459, Expected=17.0210
# Month=30, Predicted=17.2258, Expected=17.4190
# Month=31, Predicted=17.7532, Expected=17.5330
# Month=32, Predicted=17.7378, Expected=17.2680
# Month=33, Predicted=16.9831, Expected=16.6030
# Month=34, Predicted=16.1576, Expected=15.8250
# Month=35, Predicted=15.3642, Expected=15.4460
# Month=36, Predicted=15.0868, Expected=15.6360
# Month=37, Predicted=15.8959, Expected=15.6930
# Month=38, Predicted=15.8361, Expected=16.7550
# Month=39, Predicted=17.5113, Expected=16.5090
# Month=40, Predicted=16.2408, Expected=17.7230
# Month=41, Predicted=18.5041, Expected=18.6910
# Month=42, Predicted=19.4247, Expected=19.1270
# Month=43, Predicted=19.4761, Expected=19.5640
# Month=44, Predicted=19.9135, Expected=19.2030
# Month=45, Predicted=18.8531, Expected=18.2160
# Month=46, Predicted=17.7401, Expected=17.2110
# Month=47, Predicted=16.7343, Expected=16.6600
# Month=48, Predicted=16.2385, Expected=16.8310
# Month=49, Predicted=17.0796, Expected=15.7690
# Month=50, Predicted=15.2901, Expected=15.7310
# Month=51, Predicted=15.7385, Expected=15.9960
# Month=52, Predicted=16.2895, Expected=17.0210
# Month=53, Predicted=17.7693, Expected=17.5520
# Month=54, Predicted=17.9712, Expected=17.8370
# Month=55, Predicted=18.1375, Expected=17.8560
# Month=56, Predicted=17.9486, Expected=17.5710
# Month=57, Predicted=17.2701, Expected=17.0780
# Month=58, Predicted=16.6731, Expected=16.6600
# Month=59, Predicted=16.2828, Expected=16.4330
# Month=60, Predicted=16.1830, Expected=16.5840
# Run 7 — RMSE: 0.504185, MSE: 0.254202, NMSE: 0.0019233442, Time: 368.1s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.3257, Expected=13.7000
# Month=2, Predicted=14.2241, Expected=13.8140
# Month=3, Predicted=13.9941, Expected=14.3830
# Month=4, Predicted=14.9071, Expected=15.0470
# Month=5, Predicted=15.6512, Expected=15.6930
# Month=6, Predicted=16.2839, Expected=15.8440
# Month=7, Predicted=16.0507, Expected=15.7120
# Month=8, Predicted=15.5791, Expected=15.3130
# Month=9, Predicted=14.9519, Expected=14.7630
# Month=10, Predicted=14.3414, Expected=13.5480
# Month=11, Predicted=13.0306, Expected=13.5860
# Month=12, Predicted=13.6881, Expected=14.5160
# Month=13, Predicted=15.2488, Expected=14.3830
# Month=14, Predicted=14.2488, Expected=14.4970
# Month=15, Predicted=14.6771, Expected=14.7440
# Month=16, Predicted=14.9961, Expected=15.8060
# Month=17, Predicted=16.5750, Expected=16.5270
# Month=18, Predicted=17.1684, Expected=16.5460
# Month=19, Predicted=16.6240, Expected=16.7170
# Month=20, Predicted=16.9354, Expected=16.4330
# Month=21, Predicted=16.1436, Expected=15.7690
# Month=22, Predicted=15.3159, Expected=15.2750
# Month=23, Predicted=14.8727, Expected=15.1230
# Month=24, Predicted=14.9647, Expected=15.5410
# Month=25, Predicted=15.9039, Expected=15.8250
# Month=26, Predicted=16.0925, Expected=16.3760
# Month=27, Predicted=16.8822, Expected=16.3570
# Month=28, Predicted=16.3829, Expected=16.9070
# Month=29, Predicted=17.4122, Expected=17.0210
# Month=30, Predicted=17.2011, Expected=17.4190
# Month=31, Predicted=17.7626, Expected=17.5330
# Month=32, Predicted=17.7131, Expected=17.2680
# Month=33, Predicted=16.9938, Expected=16.6030
# Month=34, Predicted=16.1496, Expected=15.8250
# Month=35, Predicted=15.3487, Expected=15.4460
# Month=36, Predicted=15.0954, Expected=15.6360
# Month=37, Predicted=15.8640, Expected=15.6930
# Month=38, Predicted=15.8175, Expected=16.7550
# Month=39, Predicted=17.5240, Expected=16.5090
# Month=40, Predicted=16.2511, Expected=17.7230
# Month=41, Predicted=18.5223, Expected=18.6910
# Month=42, Predicted=19.4354, Expected=19.1270
# Month=43, Predicted=19.5084, Expected=19.5640
# Month=44, Predicted=19.9465, Expected=19.2030
# Month=45, Predicted=18.8624, Expected=18.2160
# Month=46, Predicted=17.7129, Expected=17.2110
# Month=47, Predicted=16.7064, Expected=16.6600
# Month=48, Predicted=16.2380, Expected=16.8310
# Month=49, Predicted=17.0494, Expected=15.7690
# Month=50, Predicted=15.2599, Expected=15.7310
# Month=51, Predicted=15.7298, Expected=15.9960
# Month=52, Predicted=16.2554, Expected=17.0210
# Month=53, Predicted=17.7810, Expected=17.5520
# Month=54, Predicted=18.0374, Expected=17.8370
# Month=55, Predicted=18.1049, Expected=17.8560
# Month=56, Predicted=17.9340, Expected=17.5710
# Month=57, Predicted=17.2809, Expected=17.0780
# Month=58, Predicted=16.6761, Expected=16.6600
# Month=59, Predicted=16.2897, Expected=16.4330
# Month=60, Predicted=16.1927, Expected=16.5840
# Run 8 — RMSE: 0.510782, MSE: 0.260898, NMSE: 0.0019576348, Time: 371.5s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2864, Expected=13.7000
# Month=2, Predicted=14.1017, Expected=13.8140
# Month=3, Predicted=13.9491, Expected=14.3830
# Month=4, Predicted=14.7847, Expected=15.0470
# Month=5, Predicted=15.5458, Expected=15.6930
# Month=6, Predicted=16.1732, Expected=15.8440
# Month=7, Predicted=16.0172, Expected=15.7120
# Month=8, Predicted=15.5460, Expected=15.3130
# Month=9, Predicted=14.9470, Expected=14.7630
# Month=10, Predicted=14.3293, Expected=13.5480
# Month=11, Predicted=13.0104, Expected=13.5860
# Month=12, Predicted=13.6276, Expected=14.5160
# Month=13, Predicted=15.2070, Expected=14.3830
# Month=14, Predicted=14.2160, Expected=14.4970
# Month=15, Predicted=14.6321, Expected=14.7440
# Month=16, Predicted=14.9869, Expected=15.8060
# Month=17, Predicted=16.5407, Expected=16.5270
# Month=18, Predicted=17.0817, Expected=16.5460
# Month=19, Predicted=16.5626, Expected=16.7170
# Month=20, Predicted=16.9082, Expected=16.4330
# Month=21, Predicted=16.1378, Expected=15.7690
# Month=22, Predicted=15.2997, Expected=15.2750
# Month=23, Predicted=14.8634, Expected=15.1230
# Month=24, Predicted=14.9370, Expected=15.5410
# Month=25, Predicted=15.8437, Expected=15.8250
# Month=26, Predicted=16.0850, Expected=16.3760
# Month=27, Predicted=16.7610, Expected=16.3570
# Month=28, Predicted=16.3237, Expected=16.9070
# Month=29, Predicted=17.2911, Expected=17.0210
# Month=30, Predicted=17.1561, Expected=17.4190
# Month=31, Predicted=17.7150, Expected=17.5330
# Month=32, Predicted=17.6681, Expected=17.2680
# Month=33, Predicted=16.9864, Expected=16.6030
# Month=34, Predicted=16.1334, Expected=15.8250
# Month=35, Predicted=15.3304, Expected=15.4460
# Month=36, Predicted=15.0910, Expected=15.6360
# Month=37, Predicted=15.8425, Expected=15.6930
# Month=38, Predicted=15.7593, Expected=16.7550
# Month=39, Predicted=17.4897, Expected=16.5090
# Month=40, Predicted=16.2416, Expected=17.7230
# Month=41, Predicted=18.4886, Expected=18.6910
# Month=42, Predicted=19.3969, Expected=19.1270
# Month=43, Predicted=19.4366, Expected=19.5640
# Month=44, Predicted=19.8740, Expected=19.2030
# Month=45, Predicted=18.8584, Expected=18.2160
# Month=46, Predicted=17.6935, Expected=17.2110
# Month=47, Predicted=16.6869, Expected=16.6600
# Month=48, Predicted=16.2259, Expected=16.8310
# Month=49, Predicted=17.0222, Expected=15.7690
# Month=50, Predicted=15.2403, Expected=15.7310
# Month=51, Predicted=15.6734, Expected=15.9960
# Month=52, Predicted=16.2477, Expected=17.0210
# Month=53, Predicted=17.7455, Expected=17.5520
# Month=54, Predicted=17.9198, Expected=17.8370
# Month=55, Predicted=18.0974, Expected=17.8560
# Month=56, Predicted=17.8726, Expected=17.5710
# Month=57, Predicted=17.2751, Expected=17.0780
# Month=58, Predicted=16.6668, Expected=16.6600
# Month=59, Predicted=16.2840, Expected=16.4330
# Month=60, Predicted=16.1805, Expected=16.5840
# Run 9 — RMSE: 0.504474, MSE: 0.254494, NMSE: 0.0019178330, Time: 330.0s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2906, Expected=13.7000
# Month=2, Predicted=14.0892, Expected=13.8140
# Month=3, Predicted=13.9561, Expected=14.3830
# Month=4, Predicted=14.7722, Expected=15.0470
# Month=5, Predicted=15.5191, Expected=15.6930
# Month=6, Predicted=16.1493, Expected=15.8440
# Month=7, Predicted=16.0189, Expected=15.7120
# Month=8, Predicted=15.5532, Expected=15.3130
# Month=9, Predicted=14.9417, Expected=14.7630
# Month=10, Predicted=14.2959, Expected=13.5480
# Month=11, Predicted=13.0271, Expected=13.5860
# Month=12, Predicted=13.6440, Expected=14.5160
# Month=13, Predicted=15.1649, Expected=14.3830
# Month=14, Predicted=14.2231, Expected=14.4970
# Month=15, Predicted=14.6391, Expected=14.7440
# Month=16, Predicted=14.9796, Expected=15.8060
# Month=17, Predicted=16.5011, Expected=16.5270
# Month=18, Predicted=17.0472, Expected=16.5460
# Month=19, Predicted=16.5799, Expected=16.7170
# Month=20, Predicted=16.9075, Expected=16.4330
# Month=21, Predicted=16.1503, Expected=15.7690
# Month=22, Predicted=15.2722, Expected=15.2750
# Month=23, Predicted=14.8339, Expected=15.1230
# Month=24, Predicted=14.9429, Expected=15.5410
# Month=25, Predicted=15.8338, Expected=15.8250
# Month=26, Predicted=16.0754, Expected=16.3760
# Month=27, Predicted=16.7505, Expected=16.3570
# Month=28, Predicted=16.3406, Expected=16.9070
# Month=29, Predicted=17.2807, Expected=17.0210
# Month=30, Predicted=17.1631, Expected=17.4190
# Month=31, Predicted=17.7042, Expected=17.5330
# Month=32, Predicted=17.6751, Expected=17.2680
# Month=33, Predicted=16.9970, Expected=16.6030
# Month=34, Predicted=16.1061, Expected=15.8250
# Month=35, Predicted=15.3148, Expected=15.4460
# Month=36, Predicted=15.0923, Expected=15.6360
# Month=37, Predicted=15.8398, Expected=15.6930
# Month=38, Predicted=15.7740, Expected=16.7550
# Month=39, Predicted=17.4501, Expected=16.5090
# Month=40, Predicted=16.2501, Expected=17.7230
# Month=41, Predicted=18.4522, Expected=18.6910
# Month=42, Predicted=19.3553, Expected=19.1270
# Month=43, Predicted=19.4276, Expected=19.5640
# Month=44, Predicted=19.8651, Expected=19.2030
# Month=45, Predicted=18.8649, Expected=18.2160
# Month=46, Predicted=17.6970, Expected=17.2110
# Month=47, Predicted=16.6917, Expected=16.6600
# Month=48, Predicted=16.1925, Expected=16.8310
# Month=49, Predicted=17.0215, Expected=15.7690
# Month=50, Predicted=15.2489, Expected=15.7310
# Month=51, Predicted=15.6890, Expected=15.9960
# Month=52, Predicted=16.2393, Expected=17.0210
# Month=53, Predicted=17.7051, Expected=17.5520
# Month=54, Predicted=17.9109, Expected=17.8370
# Month=55, Predicted=18.0877, Expected=17.8560
# Month=56, Predicted=17.8899, Expected=17.5710
# Month=57, Predicted=17.2877, Expected=17.0780
# Month=58, Predicted=16.6375, Expected=16.6600
# Month=59, Predicted=16.2724, Expected=16.4330
# Month=60, Predicted=16.1872, Expected=16.5840
# Run 10 — RMSE: 0.498897, MSE: 0.248899, NMSE: 0.0018841682, Time: 274.7s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2795, Expected=13.7000
# Month=2, Predicted=14.1209, Expected=13.8140
# Month=3, Predicted=13.9365, Expected=14.3830
# Month=4, Predicted=14.8039, Expected=15.0470
# Month=5, Predicted=15.5035, Expected=15.6930
# Month=6, Predicted=16.1421, Expected=15.8440
# Month=7, Predicted=16.0159, Expected=15.7120
# Month=8, Predicted=15.4921, Expected=15.3130
# Month=9, Predicted=14.9261, Expected=14.7630
# Month=10, Predicted=14.3234, Expected=13.5480
# Month=11, Predicted=13.0087, Expected=13.5860
# Month=12, Predicted=13.5959, Expected=14.5160
# Month=13, Predicted=15.1272, Expected=14.3830
# Month=14, Predicted=14.1621, Expected=14.4970
# Month=15, Predicted=14.6195, Expected=14.7440
# Month=16, Predicted=15.0174, Expected=15.8060
# Month=17, Predicted=16.4951, Expected=16.5270
# Month=18, Predicted=17.0101, Expected=16.5460
# Month=19, Predicted=16.5269, Expected=16.7170
# Month=20, Predicted=16.9135, Expected=16.4330
# Month=21, Predicted=16.0994, Expected=15.7690
# Month=22, Predicted=15.2997, Expected=15.2750
# Month=23, Predicted=14.8531, Expected=15.1230
# Month=24, Predicted=14.8833, Expected=15.5410
# Month=25, Predicted=15.9104, Expected=15.8250
# Month=26, Predicted=16.1266, Expected=16.3760
# Month=27, Predicted=16.7909, Expected=16.3570
# Month=28, Predicted=16.2810, Expected=16.9070
# Month=29, Predicted=17.3216, Expected=17.0210
# Month=30, Predicted=17.1435, Expected=17.4190
# Month=31, Predicted=17.7805, Expected=17.5330
# Month=32, Predicted=17.6555, Expected=17.2680
# Month=33, Predicted=16.9450, Expected=16.6030
# Month=34, Predicted=16.1334, Expected=15.8250
# Month=35, Predicted=15.3330, Expected=15.4460
# Month=36, Predicted=15.0674, Expected=15.6360
# Month=37, Predicted=15.8542, Expected=15.6930
# Month=38, Predicted=15.7318, Expected=16.7550
# Month=39, Predicted=17.4441, Expected=16.5090
# Month=40, Predicted=16.1973, Expected=17.7230
# Month=41, Predicted=18.4795, Expected=18.6910
# Month=42, Predicted=19.3262, Expected=19.1270
# Month=43, Predicted=19.5031, Expected=19.5640
# Month=44, Predicted=19.9404, Expected=19.2030
# Month=45, Predicted=18.8321, Expected=18.2160
# Month=46, Predicted=17.6958, Expected=17.2110
# Month=47, Predicted=16.6889, Expected=16.6600
# Month=48, Predicted=16.2201, Expected=16.8310
# Month=49, Predicted=17.0275, Expected=15.7690
# Month=50, Predicted=15.2415, Expected=15.7310
# Month=51, Predicted=15.6276, Expected=15.9960
# Month=52, Predicted=16.2838, Expected=17.0210
# Month=53, Predicted=17.6899, Expected=17.5520
# Month=54, Predicted=17.9603, Expected=17.8370
# Month=55, Predicted=18.1393, Expected=17.8560
# Month=56, Predicted=17.8369, Expected=17.5710
# Month=57, Predicted=17.2369, Expected=17.0780
# Month=58, Predicted=16.6564, Expected=16.6600
# Month=59, Predicted=16.2656, Expected=16.4330
# Month=60, Predicted=16.1335, Expected=16.5840
# Run 11 — RMSE: 0.506685, MSE: 0.256729, NMSE: 0.0019181269, Time: 271.2s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2574, Expected=13.7000
# Month=2, Predicted=14.0919, Expected=13.8140
# Month=3, Predicted=13.9213, Expected=14.3830
# Month=4, Predicted=14.7749, Expected=15.0470
# Month=5, Predicted=15.5238, Expected=15.6930
# Month=6, Predicted=16.1528, Expected=15.8440
# Month=7, Predicted=15.9870, Expected=15.7120
# Month=8, Predicted=15.5077, Expected=15.3130
# Month=9, Predicted=14.9539, Expected=14.7630
# Month=10, Predicted=14.3314, Expected=13.5480
# Month=11, Predicted=12.9975, Expected=13.5860
# Month=12, Predicted=13.6000, Expected=14.5160
# Month=13, Predicted=15.1898, Expected=14.3830
# Month=14, Predicted=14.1777, Expected=14.4970
# Month=15, Predicted=14.6043, Expected=14.7440
# Month=16, Predicted=14.9555, Expected=15.8060
# Month=17, Predicted=16.5314, Expected=16.5270
# Month=18, Predicted=17.0567, Expected=16.5460
# Month=19, Predicted=16.5335, Expected=16.7170
# Month=20, Predicted=16.8768, Expected=16.4330
# Month=21, Predicted=16.1256, Expected=15.7690
# Month=22, Predicted=15.2935, Expected=15.2750
# Month=23, Predicted=14.8698, Expected=15.1230
# Month=24, Predicted=14.9002, Expected=15.5410
# Month=25, Predicted=15.8398, Expected=15.8250
# Month=26, Predicted=16.0573, Expected=16.3760
# Month=27, Predicted=16.7539, Expected=16.3570
# Month=28, Predicted=16.2906, Expected=16.9070
# Month=29, Predicted=17.2842, Expected=17.0210
# Month=30, Predicted=17.1283, Expected=17.4190
# Month=31, Predicted=17.7081, Expected=17.5330
# Month=32, Predicted=17.6403, Expected=17.2680
# Month=33, Predicted=16.9699, Expected=16.6030
# Month=34, Predicted=16.1272, Expected=15.8250
# Month=35, Predicted=15.3200, Expected=15.4460
# Month=36, Predicted=15.0961, Expected=15.6360
# Month=37, Predicted=15.8103, Expected=15.6930
# Month=38, Predicted=15.7325, Expected=16.7550
# Month=39, Predicted=17.4804, Expected=16.5090
# Month=40, Predicted=16.2209, Expected=17.7230
# Month=41, Predicted=18.4864, Expected=18.6910
# Month=42, Predicted=19.3820, Expected=19.1270
# Month=43, Predicted=19.4348, Expected=19.5640
# Month=44, Predicted=19.8723, Expected=19.2030
# Month=45, Predicted=18.8611, Expected=18.2160
# Month=46, Predicted=17.6809, Expected=17.2110
# Month=47, Predicted=16.6742, Expected=16.6600
# Month=48, Predicted=16.2279, Expected=16.8310
# Month=49, Predicted=16.9908, Expected=15.7690
# Month=50, Predicted=15.2275, Expected=15.7310
# Month=51, Predicted=15.6382, Expected=15.9960
# Month=52, Predicted=16.2179, Expected=17.0210
# Month=53, Predicted=17.7341, Expected=17.5520
# Month=54, Predicted=17.9154, Expected=17.8370
# Month=55, Predicted=18.0698, Expected=17.8560
# Month=56, Predicted=17.8435, Expected=17.5710
# Month=57, Predicted=17.2632, Expected=17.0780
# Month=58, Predicted=16.6733, Expected=16.6600
# Month=59, Predicted=16.2920, Expected=16.4330
# Month=60, Predicted=16.1557, Expected=16.5840
# Run 12 — RMSE: 0.507716, MSE: 0.257775, NMSE: 0.0019349356, Time: 272.7s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.3215, Expected=13.7000
# Month=2, Predicted=14.1143, Expected=13.8140
# Month=3, Predicted=13.9867, Expected=14.3830
# Month=4, Predicted=14.7973, Expected=15.0470
# Month=5, Predicted=15.6204, Expected=15.6930
# Month=6, Predicted=16.2413, Expected=15.8440
# Month=7, Predicted=16.0500, Expected=15.7120
# Month=8, Predicted=15.5888, Expected=15.3130
# Month=9, Predicted=14.9544, Expected=14.7630
# Month=10, Predicted=14.3377, Expected=13.5480
# Month=11, Predicted=13.0370, Expected=13.5860
# Month=12, Predicted=13.6768, Expected=14.5160
# Month=13, Predicted=15.2607, Expected=14.3830
# Month=14, Predicted=14.2585, Expected=14.4970
# Month=15, Predicted=14.6697, Expected=14.7440
# Month=16, Predicted=15.0129, Expected=15.8060
# Month=17, Predicted=16.5775, Expected=16.5270
# Month=18, Predicted=17.1633, Expected=16.5460
# Month=19, Predicted=16.6144, Expected=16.7170
# Month=20, Predicted=16.9389, Expected=16.4330
# Month=21, Predicted=16.1470, Expected=15.7690
# Month=22, Predicted=15.3111, Expected=15.2750
# Month=23, Predicted=14.8714, Expected=15.1230
# Month=24, Predicted=14.9741, Expected=15.5410
# Month=25, Predicted=15.8542, Expected=15.8250
# Month=26, Predicted=16.1099, Expected=16.3760
# Month=27, Predicted=16.7643, Expected=16.3570
# Month=28, Predicted=16.3792, Expected=16.9070
# Month=29, Predicted=17.2940, Expected=17.0210
# Month=30, Predicted=17.1937, Expected=17.4190
# Month=31, Predicted=17.7293, Expected=17.5330
# Month=32, Predicted=17.7057, Expected=17.2680
# Month=33, Predicted=16.9975, Expected=16.6030
# Month=34, Predicted=16.1449, Expected=15.8250
# Month=35, Predicted=15.3466, Expected=15.4460
# Month=36, Predicted=15.0982, Expected=15.6360
# Month=37, Predicted=15.8716, Expected=15.6930
# Month=38, Predicted=15.8056, Expected=16.7550
# Month=39, Predicted=17.5265, Expected=16.5090
# Month=40, Predicted=16.2553, Expected=17.7230
# Month=41, Predicted=18.5098, Expected=18.6910
# Month=42, Predicted=19.4454, Expected=19.1270
# Month=43, Predicted=19.4434, Expected=19.5640
# Month=44, Predicted=19.8806, Expected=19.2030
# Month=45, Predicted=18.8654, Expected=18.2160
# Month=46, Predicted=17.7168, Expected=17.2110
# Month=47, Predicted=16.7106, Expected=16.6600
# Month=48, Predicted=16.2344, Expected=16.8310
# Month=49, Predicted=17.0529, Expected=15.7690
# Month=50, Predicted=15.2651, Expected=15.7310
# Month=51, Predicted=15.7296, Expected=15.9960
# Month=52, Predicted=16.2732, Expected=17.0210
# Month=53, Predicted=17.7868, Expected=17.5520
# Month=54, Predicted=17.9177, Expected=17.8370
# Month=55, Predicted=18.1222, Expected=17.8560
# Month=56, Predicted=17.9244, Expected=17.5710
# Month=57, Predicted=17.2842, Expected=17.0780
# Month=58, Predicted=16.6748, Expected=16.6600
# Month=59, Predicted=16.2915, Expected=16.4330
# Month=60, Predicted=16.1977, Expected=16.5840
# Run 13 — RMSE: 0.504533, MSE: 0.254553, NMSE: 0.0019233572, Time: 265.7s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2530, Expected=13.7000
# Month=2, Predicted=14.0922, Expected=13.8140
# Month=3, Predicted=13.9163, Expected=14.3830
# Month=4, Predicted=14.7752, Expected=15.0470
# Month=5, Predicted=15.5220, Expected=15.6930
# Month=6, Predicted=16.1506, Expected=15.8440
# Month=7, Predicted=15.9837, Expected=15.7120
# Month=8, Predicted=15.5247, Expected=15.3130
# Month=9, Predicted=14.9495, Expected=14.7630
# Month=10, Predicted=14.3217, Expected=13.5480
# Month=11, Predicted=12.9934, Expected=13.5860
# Month=12, Predicted=13.5997, Expected=14.5160
# Month=13, Predicted=15.1970, Expected=14.3830
# Month=14, Predicted=14.1948, Expected=14.4970
# Month=15, Predicted=14.5993, Expected=14.7440
# Month=16, Predicted=14.9643, Expected=15.8060
# Month=17, Predicted=16.5357, Expected=16.5270
# Month=18, Predicted=17.0577, Expected=16.5460
# Month=19, Predicted=16.5357, Expected=16.7170
# Month=20, Predicted=16.8753, Expected=16.4330
# Month=21, Predicted=16.1357, Expected=15.7690
# Month=22, Predicted=15.2859, Expected=15.2750
# Month=23, Predicted=14.8600, Expected=15.1230
# Month=24, Predicted=14.9175, Expected=15.5410
# Month=25, Predicted=15.8585, Expected=15.8250
# Month=26, Predicted=16.0712, Expected=16.3760
# Month=27, Predicted=16.7559, Expected=16.3570
# Month=28, Predicted=16.2982, Expected=16.9070
# Month=29, Predicted=17.2863, Expected=17.0210
# Month=30, Predicted=17.1233, Expected=17.4190
# Month=31, Predicted=17.7280, Expected=17.5330
# Month=32, Predicted=17.6353, Expected=17.2680
# Month=33, Predicted=16.9820, Expected=16.6030
# Month=34, Predicted=16.1196, Expected=15.8250
# Month=35, Predicted=15.3141, Expected=15.4460
# Month=36, Predicted=15.0939, Expected=15.6360
# Month=37, Predicted=15.8110, Expected=15.6930
# Month=38, Predicted=15.7302, Expected=16.7550
# Month=39, Predicted=17.4847, Expected=16.5090
# Month=40, Predicted=16.2347, Expected=17.7230
# Month=41, Predicted=18.4856, Expected=18.6910
# Month=42, Predicted=19.3888, Expected=19.1270
# Month=43, Predicted=19.4518, Expected=19.5640
# Month=44, Predicted=19.8892, Expected=19.2030
# Month=45, Predicted=18.8612, Expected=18.2160
# Month=46, Predicted=17.6766, Expected=17.2110
# Month=47, Predicted=16.6700, Expected=16.6600
# Month=48, Predicted=16.2183, Expected=16.8310
# Month=49, Predicted=16.9893, Expected=15.7690
# Month=50, Predicted=15.2234, Expected=15.7310
# Month=51, Predicted=15.6483, Expected=15.9960
# Month=52, Predicted=16.2292, Expected=17.0210
# Month=53, Predicted=17.7395, Expected=17.5520
# Month=54, Predicted=17.9198, Expected=17.8370
# Month=55, Predicted=18.0839, Expected=17.8560
# Month=56, Predicted=17.8457, Expected=17.5710
# Month=57, Predicted=17.2731, Expected=17.0780
# Month=58, Predicted=16.6635, Expected=16.6600
# Month=59, Predicted=16.2858, Expected=16.4330
# Month=60, Predicted=16.1708, Expected=16.5840
# Run 14 — RMSE: 0.507049, MSE: 0.257099, NMSE: 0.0019237716, Time: 206.5s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2878, Expected=13.7000
# Month=2, Predicted=14.0584, Expected=13.8140
# Month=3, Predicted=13.9509, Expected=14.3830
# Month=4, Predicted=14.7414, Expected=15.0470
# Month=5, Predicted=15.5143, Expected=15.6930
# Month=6, Predicted=16.1379, Expected=15.8440
# Month=7, Predicted=16.0186, Expected=15.7120
# Month=8, Predicted=15.5724, Expected=15.3130
# Month=9, Predicted=14.9717, Expected=14.7630
# Month=10, Predicted=14.3585, Expected=13.5480
# Month=11, Predicted=13.0413, Expected=13.5860
# Month=12, Predicted=13.6371, Expected=14.5160
# Month=13, Predicted=15.1938, Expected=14.3830
# Month=14, Predicted=14.2424, Expected=14.4970
# Month=15, Predicted=14.6339, Expected=14.7440
# Month=16, Predicted=14.9913, Expected=15.8060
# Month=17, Predicted=16.5196, Expected=16.5270
# Month=18, Predicted=17.0619, Expected=16.5460
# Month=19, Predicted=16.5750, Expected=16.7170
# Month=20, Predicted=16.9101, Expected=16.4330
# Month=21, Predicted=16.1611, Expected=15.7690
# Month=22, Predicted=15.3305, Expected=15.2750
# Month=23, Predicted=14.8911, Expected=15.1230
# Month=24, Predicted=14.9633, Expected=15.5410
# Month=25, Predicted=15.8286, Expected=15.8250
# Month=26, Predicted=16.0888, Expected=16.3760
# Month=27, Predicted=16.7186, Expected=16.3570
# Month=28, Predicted=16.3418, Expected=16.9070
# Month=29, Predicted=17.2488, Expected=17.0210
# Month=30, Predicted=17.1579, Expected=17.4190
# Month=31, Predicted=17.7042, Expected=17.5330
# Month=32, Predicted=17.6699, Expected=17.2680
# Month=33, Predicted=17.0099, Expected=16.6030
# Month=34, Predicted=16.1642, Expected=15.8250
# Month=35, Predicted=15.3617, Expected=15.4460
# Month=36, Predicted=15.1152, Expected=15.6360
# Month=37, Predicted=15.8452, Expected=15.6930
# Month=38, Predicted=15.7661, Expected=16.7550
# Month=39, Predicted=17.4686, Expected=16.5090
# Month=40, Predicted=16.2656, Expected=17.7230
# Month=41, Predicted=18.4597, Expected=18.6910
# Month=42, Predicted=19.3814, Expected=19.1270
# Month=43, Predicted=19.4173, Expected=19.5640
# Month=44, Predicted=19.8544, Expected=19.2030
# Month=45, Predicted=18.8821, Expected=18.2160
# Month=46, Predicted=17.7248, Expected=17.2110
# Month=47, Predicted=16.7181, Expected=16.6600
# Month=48, Predicted=16.2551, Expected=16.8310
# Month=49, Predicted=17.0241, Expected=15.7690
# Month=50, Predicted=15.2715, Expected=15.7310
# Month=51, Predicted=15.6940, Expected=15.9960
# Month=52, Predicted=16.2522, Expected=17.0210
# Month=53, Predicted=17.7266, Expected=17.5520
# Month=54, Predicted=17.8796, Expected=17.8370
# Month=55, Predicted=18.1012, Expected=17.8560
# Month=56, Predicted=17.8850, Expected=17.5710
# Month=57, Predicted=17.2983, Expected=17.0780
# Month=58, Predicted=16.6945, Expected=16.6600
# Month=59, Predicted=16.3093, Expected=16.4330
# Month=60, Predicted=16.2050, Expected=16.5840
# Run 15 — RMSE: 0.498981, MSE: 0.248982, NMSE: 0.0018923254, Time: 206.8s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2908, Expected=13.7000
# Month=2, Predicted=14.1289, Expected=13.8140
# Month=3, Predicted=13.9564, Expected=14.3830
# Month=4, Predicted=14.8119, Expected=15.0470
# Month=5, Predicted=15.5529, Expected=15.6930
# Month=6, Predicted=16.1841, Expected=15.8440
# Month=7, Predicted=16.0194, Expected=15.7120
# Month=8, Predicted=15.5676, Expected=15.3130
# Month=9, Predicted=14.9490, Expected=14.7630
# Month=10, Predicted=14.3342, Expected=13.5480
# Month=11, Predicted=12.9922, Expected=13.5860
# Month=12, Predicted=13.6489, Expected=14.5160
# Month=13, Predicted=15.1987, Expected=14.3830
# Month=14, Predicted=14.2375, Expected=14.4970
# Month=15, Predicted=14.6394, Expected=14.7440
# Month=16, Predicted=14.9877, Expected=15.8060
# Month=17, Predicted=16.5421, Expected=16.5270
# Month=18, Predicted=17.0786, Expected=16.5460
# Month=19, Predicted=16.5869, Expected=16.7170
# Month=20, Predicted=16.9086, Expected=16.4330
# Month=21, Predicted=16.1409, Expected=15.7690
# Month=22, Predicted=15.3038, Expected=15.2750
# Month=23, Predicted=14.8675, Expected=15.1230
# Month=24, Predicted=14.9556, Expected=15.5410
# Month=25, Predicted=15.8726, Expected=15.8250
# Month=26, Predicted=16.0897, Expected=16.3760
# Month=27, Predicted=16.7912, Expected=16.3570
# Month=28, Predicted=16.3520, Expected=16.9070
# Month=29, Predicted=17.3215, Expected=17.0210
# Month=30, Predicted=17.1634, Expected=17.4190
# Month=31, Predicted=17.7404, Expected=17.5330
# Month=32, Predicted=17.6754, Expected=17.2680
# Month=33, Predicted=16.9908, Expected=16.6030
# Month=34, Predicted=16.1375, Expected=15.8250
# Month=35, Predicted=15.3311, Expected=15.4460
# Month=36, Predicted=15.0927, Expected=15.6360
# Month=37, Predicted=15.8419, Expected=15.6930
# Month=38, Predicted=15.7771, Expected=16.7550
# Month=39, Predicted=17.4911, Expected=16.5090
# Month=40, Predicted=16.2476, Expected=17.7230
# Month=41, Predicted=18.5026, Expected=18.6910
# Month=42, Predicted=19.3910, Expected=19.1270
# Month=43, Predicted=19.4681, Expected=19.5640
# Month=44, Predicted=19.9057, Expected=19.2030
# Month=45, Predicted=18.8598, Expected=18.2160
# Month=46, Predicted=17.6851, Expected=17.2110
# Month=47, Predicted=16.6776, Expected=16.6600
# Month=48, Predicted=16.2308, Expected=16.8310
# Month=49, Predicted=17.0226, Expected=15.7690
# Month=50, Predicted=15.2284, Expected=15.7310
# Month=51, Predicted=15.7024, Expected=15.9960
# Month=52, Predicted=16.2502, Expected=17.0210
# Month=53, Predicted=17.7439, Expected=17.5520
# Month=54, Predicted=17.9526, Expected=17.8370
# Month=55, Predicted=18.1022, Expected=17.8560
# Month=56, Predicted=17.8969, Expected=17.5710
# Month=57, Predicted=17.2782, Expected=17.0780
# Month=58, Predicted=16.6709, Expected=16.6600
# Month=59, Predicted=16.2864, Expected=16.4330
# Month=60, Predicted=16.1885, Expected=16.5840
# Run 16 — RMSE: 0.503520, MSE: 0.253532, NMSE: 0.0019058365, Time: 208.1s
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2915, Expected=13.7000
# Month=2, Predicted=14.0543, Expected=13.8140
# Month=3, Predicted=13.9555, Expected=14.3830
# Month=4, Predicted=14.7373, Expected=15.0470
# Month=5, Predicted=15.4212, Expected=15.6930
# Month=6, Predicted=16.0611, Expected=15.8440
# Month=7, Predicted=16.0219, Expected=15.7120
# Month=8, Predicted=15.5399, Expected=15.3130
# Month=9, Predicted=14.9502, Expected=14.7630
# Month=10, Predicted=14.3493, Expected=13.5480
# Month=11, Predicted=13.0654, Expected=13.5860
# Month=12, Predicted=13.6437, Expected=14.5160
# Month=13, Predicted=15.1133, Expected=14.3830
# Month=14, Predicted=14.2096, Expected=14.4970
# Month=15, Predicted=14.6385, Expected=14.7440
# Month=16, Predicted=15.0012, Expected=15.8060
# Month=17, Predicted=16.5047, Expected=16.5270
# Month=18, Predicted=16.9299, Expected=16.5460
# Month=19, Predicted=16.5807, Expected=16.7170
# Month=20, Predicted=16.9133, Expected=16.4330
# Month=21, Predicted=16.1206, Expected=15.7690
# Month=22, Predicted=15.3300, Expected=15.2750
# Month=23, Predicted=14.8781, Expected=15.1230
# Month=24, Predicted=14.9250, Expected=15.5410
# Month=25, Predicted=15.8784, Expected=15.8250
# Month=26, Predicted=16.1063, Expected=16.3760
# Month=27, Predicted=16.7289, Expected=16.3570
# Month=28, Predicted=16.3429, Expected=16.9070
# Month=29, Predicted=17.2599, Expected=17.0210
# Month=30, Predicted=17.1625, Expected=17.4190
# Month=31, Predicted=17.7511, Expected=17.5330
# Month=32, Predicted=17.6745, Expected=17.2680
# Month=33, Predicted=16.9665, Expected=16.6030
# Month=34, Predicted=16.1638, Expected=15.8250
# Month=35, Predicted=15.3698, Expected=15.4460
# Month=36, Predicted=15.0910, Expected=15.6360
# Month=37, Predicted=15.8489, Expected=15.6930
# Month=38, Predicted=15.7728, Expected=16.7550
# Month=39, Predicted=17.4537, Expected=16.5090
# Month=40, Predicted=16.2199, Expected=17.7230
# Month=41, Predicted=18.4778, Expected=18.6910
# Month=42, Predicted=19.3236, Expected=19.1270
# ...
# Month=28, Predicted=16.2784, Expected=16.9070
# Month=29, Predicted=17.3108, Expected=17.0210
# Month=30, Predicted=17.0890, Expected=17.4190
# Month=31, Predicted=17.7257, Expected=17.5330
# Month=32, Predicted=17.6010, Expected=17.2680
# Month=33, Predicted=16.9732, Expected=16.6030
# Month=34, Predicted=16.1222, Expected=15.8250
# Month=35, Predicted=15.3184, Expected=15.4460
# Month=36, Predicted=15.0825, Expected=15.6360
# Month=37, Predicted=15.7799, Expected=15.6930
# Month=38, Predicted=15.6987, Expected=16.7550
# Month=39, Predicted=17.4432, Expected=16.5090
# Month=40, Predicted=16.2273, Expected=17.7230
# Month=41, Predicted=18.4730, Expected=18.6910
# Month=42, Predicted=19.3344, Expected=19.1270
# Month=43, Predicted=19.4591, Expected=19.5640
# Month=44, Predicted=19.8967, Expected=19.2030
# Month=45, Predicted=18.8494, Expected=18.2160
# Month=46, Predicted=17.6856, Expected=17.2110
# Month=47, Predicted=16.6795, Expected=16.6600
# Month=48, Predicted=16.2171, Expected=16.8310
# Month=49, Predicted=16.9569, Expected=15.7690
# Month=50, Predicted=15.2349, Expected=15.7310
# Month=51, Predicted=15.6320, Expected=15.9960
# Month=52, Predicted=16.2049, Expected=17.0210
# Month=53, Predicted=17.6922, Expected=17.5520
# Month=54, Predicted=17.9442, Expected=17.8370
# Month=55, Predicted=18.0618, Expected=17.8560
# Month=56, Predicted=17.8193, Expected=17.5710
# Month=57, Predicted=17.2631, Expected=17.0780
# Month=58, Predicted=16.6589, Expected=16.6600
# Month=59, Predicted=16.2762, Expected=16.4330
# Month=60, Predicted=16.1648, Expected=16.5840
# Run 25 — RMSE: 0.507017, MSE: 0.257066, NMSE: 0.0019260633, Time: 225.8s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.2813, Expected=13.7000
# Month=2, Predicted=14.1004, Expected=13.8140
# Month=3, Predicted=13.9454, Expected=14.3830
# Month=4, Predicted=14.7834, Expected=15.0470
# Month=5, Predicted=15.5279, Expected=15.6930
# Month=6, Predicted=16.1582, Expected=15.8440
# Month=7, Predicted=16.0105, Expected=15.7120
# Month=8, Predicted=15.5183, Expected=15.3130
# Month=9, Predicted=14.9262, Expected=14.7630
# Month=10, Predicted=14.3086, Expected=13.5480
# Month=11, Predicted=12.9526, Expected=13.5860
# Month=12, Predicted=13.6241, Expected=14.5160
# Month=13, Predicted=15.1753, Expected=14.3830
# Month=14, Predicted=14.1882, Expected=14.4970
# Month=15, Predicted=14.6284, Expected=14.7440
# Month=16, Predicted=14.9746, Expected=15.8060
# Month=17, Predicted=16.5132, Expected=16.5270
# Month=18, Predicted=17.0562, Expected=16.5460
# Month=19, Predicted=16.5571, Expected=16.7170
# Month=20, Predicted=16.8998, Expected=16.4330
# Month=21, Predicted=16.1122, Expected=15.7690
# Month=22, Predicted=15.2748, Expected=15.2750
# Month=23, Predicted=14.8435, Expected=15.1230
# Month=24, Predicted=14.9083, Expected=15.5410
# Month=25, Predicted=15.8463, Expected=15.8250
# Month=26, Predicted=16.0732, Expected=16.3760
# Month=27, Predicted=16.7625, Expected=16.3570
# Month=28, Predicted=16.3123, Expected=16.9070
# Month=29, Predicted=17.2927, Expected=17.0210
# Month=30, Predicted=17.1524, Expected=17.4190
# Month=31, Predicted=17.7150, Expected=17.5330
# Month=32, Predicted=17.6644, Expected=17.2680
# Month=33, Predicted=16.9599, Expected=16.6030
# Month=34, Predicted=16.1085, Expected=15.8250
# Month=35, Predicted=15.2993, Expected=15.4460
# Month=36, Predicted=15.0697, Expected=15.6360
# Month=37, Predicted=15.8327, Expected=15.6930
# Month=38, Predicted=15.7569, Expected=16.7550
# Month=39, Predicted=17.4622, Expected=16.5090
# Month=40, Predicted=16.2142, Expected=17.7230
# Month=41, Predicted=18.4674, Expected=18.6910
# Month=42, Predicted=19.3661, Expected=19.1270
# Month=43, Predicted=19.4411, Expected=19.5640
# Month=44, Predicted=19.8787, Expected=19.2030
# Month=45, Predicted=18.8364, Expected=18.2160
# Month=46, Predicted=17.6490, Expected=17.2110
# Month=47, Predicted=16.6413, Expected=16.6600
# Month=48, Predicted=16.2052, Expected=16.8310
# Month=49, Predicted=17.0138, Expected=15.7690
# Month=50, Predicted=15.1912, Expected=15.7310
# Month=51, Predicted=15.6585, Expected=15.9960
# Month=52, Predicted=16.2355, Expected=17.0210
# Month=53, Predicted=17.7166, Expected=17.5520
# Month=54, Predicted=17.9238, Expected=17.8370
# Month=55, Predicted=18.0856, Expected=17.8560
# Month=56, Predicted=17.8671, Expected=17.5710
# Month=57, Predicted=17.2496, Expected=17.0780
# Month=58, Predicted=16.6470, Expected=16.6600
# Month=59, Predicted=16.2637, Expected=16.4330
# Month=60, Predicted=16.1524, Expected=16.5840
# Run 26 — RMSE: 0.505641, MSE: 0.255673, NMSE: 0.0019203442, Time: 226.2s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.3149, Expected=13.7000
# Month=2, Predicted=14.0777, Expected=13.8140
# Month=3, Predicted=13.9739, Expected=14.3830
# Month=4, Predicted=14.7607, Expected=15.0470
# Month=5, Predicted=15.5340, Expected=15.6930
# Month=6, Predicted=16.1565, Expected=15.8440
# Month=7, Predicted=16.0490, Expected=15.7120
# Month=8, Predicted=15.5482, Expected=15.3130
# Month=9, Predicted=14.9520, Expected=14.7630
# Month=10, Predicted=14.3385, Expected=13.5480
# Month=11, Predicted=13.0371, Expected=13.5860
# Month=12, Predicted=13.6391, Expected=14.5160
# Month=13, Predicted=15.2015, Expected=14.3830
# Month=14, Predicted=14.2181, Expected=14.4970
# Month=15, Predicted=14.6569, Expected=14.7440
# Month=16, Predicted=15.0290, Expected=15.8060
# Month=17, Predicted=16.5206, Expected=16.5270
# Month=18, Predicted=17.0837, Expected=16.5460
# Month=19, Predicted=16.5716, Expected=16.7170
# Month=20, Predicted=16.9433, Expected=16.4330
# Month=21, Predicted=16.1408, Expected=15.7690
# Month=22, Predicted=15.3129, Expected=15.2750
# Month=23, Predicted=14.8709, Expected=15.1230
# Month=24, Predicted=14.9391, Expected=15.5410
# Month=25, Predicted=15.8680, Expected=15.8250
# Month=26, Predicted=16.1270, Expected=16.3760
# Month=27, Predicted=16.7401, Expected=16.3570
# Month=28, Predicted=16.3291, Expected=16.9070
# Month=29, Predicted=17.2704, Expected=17.0210
# Month=30, Predicted=17.1809, Expected=17.4190
# Month=31, Predicted=17.7442, Expected=17.5330
# Month=32, Predicted=17.6929, Expected=17.2680
# Month=33, Predicted=16.9892, Expected=16.6030
# Month=34, Predicted=16.1467, Expected=15.8250
# Month=35, Predicted=15.3475, Expected=15.4460
# Month=36, Predicted=15.0955, Expected=15.6360
# Month=37, Predicted=15.8802, Expected=15.6930
# Month=38, Predicted=15.7736, Expected=16.7550
# Month=39, Predicted=17.4696, Expected=16.5090
# Month=40, Predicted=16.2443, Expected=17.7230
# Month=41, Predicted=18.4568, Expected=18.6910
# Month=42, Predicted=19.3868, Expected=19.1270
# Month=43, Predicted=19.4557, Expected=19.5640
# Month=44, Predicted=19.8928, Expected=19.2030
# Month=45, Predicted=18.8625, Expected=18.2160
# Month=46, Predicted=17.7163, Expected=17.2110
# Month=47, Predicted=16.7101, Expected=16.6600
# Month=48, Predicted=16.2352, Expected=16.8310
# Month=49, Predicted=17.0573, Expected=15.7690
# Month=50, Predicted=15.2646, Expected=15.7310
# Month=51, Predicted=15.6775, Expected=15.9960
# Month=52, Predicted=16.2901, Expected=17.0210
# Month=53, Predicted=17.7291, Expected=17.5520
# Month=54, Predicted=17.9043, Expected=17.8370
# Month=55, Predicted=18.1394, Expected=17.8560
# Month=56, Predicted=17.8816, Expected=17.5710
# Month=57, Predicted=17.2781, Expected=17.0780
# Month=58, Predicted=16.6743, Expected=16.6600
# Month=59, Predicted=16.2894, Expected=16.4330
# Month=60, Predicted=16.1831, Expected=16.5840
# Run 27 — RMSE: 0.502052, MSE: 0.252056, NMSE: 0.0019044322, Time: 226.1s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.3159, Expected=13.7000
# Month=2, Predicted=14.1705, Expected=13.8140
# Month=3, Predicted=13.9825, Expected=14.3830
# Month=4, Predicted=14.8535, Expected=15.0470
# Month=5, Predicted=15.6562, Expected=15.6930
# Month=6, Predicted=16.2814, Expected=15.8440
# Month=7, Predicted=16.0421, Expected=15.7120
# Month=8, Predicted=15.5389, Expected=15.3130
# Month=9, Predicted=14.9299, Expected=14.7630
# Month=10, Predicted=14.3082, Expected=13.5480
# Month=11, Predicted=12.9893, Expected=13.5860
# Month=12, Predicted=13.6625, Expected=14.5160
# Month=13, Predicted=15.2446, Expected=14.3830
# Month=14, Predicted=14.2087, Expected=14.4970
# Month=15, Predicted=14.6655, Expected=14.7440
# Month=16, Predicted=14.9865, Expected=15.8060
# Month=17, Predicted=16.5493, Expected=16.5270
# Month=18, Predicted=17.1854, Expected=16.5460
# Month=19, Predicted=16.5936, Expected=16.7170
# Month=20, Predicted=16.9276, Expected=16.4330
# Month=21, Predicted=16.1244, Expected=15.7690
# Month=22, Predicted=15.2777, Expected=15.2750
# Month=23, Predicted=14.8434, Expected=15.1230
# Month=24, Predicted=14.9279, Expected=15.5410
# Month=25, Predicted=15.8350, Expected=15.8250
# Month=26, Predicted=16.0775, Expected=16.3760
# Month=27, Predicted=16.8163, Expected=16.3570
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=17.3456, Expected=17.0210
# Month=30, Predicted=17.1895, Expected=17.4190
# Month=31, Predicted=17.7032, Expected=17.5330
# Month=32, Predicted=17.7015, Expected=17.2680
# Month=33, Predicted=16.9734, Expected=16.6030
# Month=34, Predicted=16.1115, Expected=15.8250
# Month=35, Predicted=15.3087, Expected=15.4460
# Month=36, Predicted=15.0746, Expected=15.6360
# Month=37, Predicted=15.8566, Expected=15.6930
# Month=38, Predicted=15.7964, Expected=16.7550
# Month=39, Predicted=17.4983, Expected=16.5090
# Month=40, Predicted=16.2291, Expected=17.7230
# Month=41, Predicted=18.4754, Expected=18.6910
# Month=42, Predicted=19.4249, Expected=19.1270
# Month=43, Predicted=19.4320, Expected=19.5640
# Month=44, Predicted=19.8697, Expected=19.2030
# Month=45, Predicted=18.8426, Expected=18.2160
# Month=46, Predicted=17.6724, Expected=17.2110
# Month=47, Predicted=16.6657, Expected=16.6600
# Month=48, Predicted=16.2048, Expected=16.8310
# Month=49, Predicted=17.0416, Expected=15.7690
# Month=50, Predicted=15.2192, Expected=15.7310
# Month=51, Predicted=15.6873, Expected=15.9960
# Month=52, Predicted=16.2436, Expected=17.0210
# Month=53, Predicted=17.7610, Expected=17.5520
# Month=54, Predicted=17.9605, Expected=17.8370
# Month=55, Predicted=18.0897, Expected=17.8560
# Month=56, Predicted=17.9036, Expected=17.5710
# Month=57, Predicted=17.2617, Expected=17.0780
# Month=58, Predicted=16.6468, Expected=16.6600
# Month=59, Predicted=16.2662, Expected=16.4330
# Month=60, Predicted=16.1684, Expected=16.5840
# Run 28 — RMSE: 0.509974, MSE: 0.260073, NMSE: 0.0019623530, Time: 225.3s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2939, Expected=13.7000
# Month=2, Predicted=14.1697, Expected=13.8140
# Month=3, Predicted=13.9596, Expected=14.3830
# Month=4, Predicted=14.8527, Expected=15.0470
# Month=5, Predicted=15.6179, Expected=15.6930
# Month=6, Predicted=16.2469, Expected=15.8440
# Month=7, Predicted=16.0223, Expected=15.7120
# Month=8, Predicted=15.5481, Expected=15.3130
# Month=9, Predicted=14.9474, Expected=14.7630
# Month=10, Predicted=14.3300, Expected=13.5480
# Month=11, Predicted=12.9970, Expected=13.5860
# Month=12, Predicted=13.6510, Expected=14.5160
# Month=13, Predicted=15.2261, Expected=14.3830
# Month=14, Predicted=14.2178, Expected=14.4970
# Month=15, Predicted=14.6426, Expected=14.7440
# Month=16, Predicted=14.9892, Expected=15.8060
# Month=17, Predicted=16.5449, Expected=16.5270
# Month=18, Predicted=17.1435, Expected=16.5460
# Month=19, Predicted=16.5877, Expected=16.7170
# Month=20, Predicted=16.9113, Expected=16.4330
# Month=21, Predicted=16.1282, Expected=15.7690
# Month=22, Predicted=15.2937, Expected=15.2750
# Month=23, Predicted=14.8661, Expected=15.1230
# Month=24, Predicted=14.9347, Expected=15.5410
# Month=25, Predicted=15.8626, Expected=15.8250
# Month=26, Predicted=16.0889, Expected=16.3760
# Month=27, Predicted=16.8244, Expected=16.3570
# Month=28, Predicted=16.3487, Expected=16.9070
# Month=29, Predicted=17.3542, Expected=17.0210
# Month=30, Predicted=17.1666, Expected=17.4190
# Month=31, Predicted=17.7296, Expected=17.5330
# Month=32, Predicted=17.6786, Expected=17.2680
# Month=33, Predicted=16.9758, Expected=16.6030
# Month=34, Predicted=16.1274, Expected=15.8250
# Month=35, Predicted=15.3196, Expected=15.4460
# Month=36, Predicted=15.0899, Expected=15.6360
# Month=37, Predicted=15.8445, Expected=15.6930
# Month=38, Predicted=15.7800, Expected=16.7550
# Month=39, Predicted=17.4939, Expected=16.5090
# Month=40, Predicted=16.2305, Expected=17.7230
# Month=41, Predicted=18.4829, Expected=18.6910
# Month=42, Predicted=19.4109, Expected=19.1270
# Month=43, Predicted=19.4603, Expected=19.5640
# Month=44, Predicted=19.8980, Expected=19.2030
# Month=45, Predicted=18.8557, Expected=18.2160
# Month=46, Predicted=17.6797, Expected=17.2110
# Month=47, Predicted=16.6731, Expected=16.6600
# Month=48, Predicted=16.2265, Expected=16.8310
# Month=49, Predicted=17.0253, Expected=15.7690
# Month=50, Predicted=15.2265, Expected=15.7310
# Month=51, Predicted=15.6963, Expected=15.9960
# Month=52, Predicted=16.2508, Expected=17.0210
# Month=53, Predicted=17.7531, Expected=17.5520
# Month=54, Predicted=17.9769, Expected=17.8370
# Month=55, Predicted=18.1014, Expected=17.8560
# Month=56, Predicted=17.8977, Expected=17.5710
# Month=57, Predicted=17.2656, Expected=17.0780
# Month=58, Predicted=16.6696, Expected=16.6600
# Month=59, Predicted=16.2856, Expected=16.4330
# Month=60, Predicted=16.1696, Expected=16.5840
# Run 29 — RMSE: 0.508204, MSE: 0.258271, NMSE: 0.0019429796, Time: 225.8s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2115, Expected=13.7000
# Month=2, Predicted=14.0456, Expected=13.8140
# Month=3, Predicted=13.8808, Expected=14.3830
# Month=4, Predicted=14.7286, Expected=15.0470
# Month=5, Predicted=15.4755, Expected=15.6930
# Month=6, Predicted=16.1056, Expected=15.8440
# Month=7, Predicted=15.9365, Expected=15.7120
# Month=8, Predicted=15.5222, Expected=15.3130
# Month=9, Predicted=14.9183, Expected=14.7630
# Month=10, Predicted=14.3004, Expected=13.5480
# Month=11, Predicted=12.9551, Expected=13.5860
# Month=12, Predicted=13.5860, Expected=14.5160
# Month=13, Predicted=15.1415, Expected=14.3830
# Month=14, Predicted=14.1921, Expected=14.4970
# Month=15, Predicted=14.5638, Expected=14.7440
# Month=16, Predicted=14.8899, Expected=15.8060
# Month=17, Predicted=16.4956, Expected=16.5270
# Month=18, Predicted=17.0047, Expected=16.5460
# Month=19, Predicted=16.5263, Expected=16.7170
# Month=20, Predicted=16.8219, Expected=16.4330
# Month=21, Predicted=16.1083, Expected=15.7690
# Month=22, Predicted=15.2660, Expected=15.2750
# Month=23, Predicted=14.8354, Expected=15.1230
# Month=24, Predicted=14.9123, Expected=15.5410
# Month=25, Predicted=15.7762, Expected=15.8250
# Month=26, Predicted=15.9892, Expected=16.3760
# Month=27, Predicted=16.7065, Expected=16.3570
# Month=28, Predicted=16.2954, Expected=16.9070
# Month=29, Predicted=17.2367, Expected=17.0210
# Month=30, Predicted=17.0878, Expected=17.4190
# Month=31, Predicted=17.6424, Expected=17.5330
# Month=32, Predicted=17.5998, Expected=17.2680
# Month=33, Predicted=16.9573, Expected=16.6030
# Month=34, Predicted=16.0997, Expected=15.8250
# Month=35, Predicted=15.2903, Expected=15.4460
# Month=36, Predicted=15.0620, Expected=15.6360
# Month=37, Predicted=15.7519, Expected=15.6930
# Month=38, Predicted=15.7115, Expected=16.7550
# Month=39, Predicted=17.4446, Expected=16.5090
# Month=40, Predicted=16.2130, Expected=17.7230
# Month=41, Predicted=18.4659, Expected=18.6910
# Month=42, Predicted=19.3370, Expected=19.1270
# Month=43, Predicted=19.3733, Expected=19.5640
# Month=44, Predicted=19.8109, Expected=19.2030
# Month=45, Predicted=18.8291, Expected=18.2160
# Month=46, Predicted=17.6436, Expected=17.2110
# Month=47, Predicted=16.6363, Expected=16.6600
# Month=48, Predicted=16.1970, Expected=16.8310
# Month=49, Predicted=16.9359, Expected=15.7690
# Month=50, Predicted=15.1881, Expected=15.7310
# Month=51, Predicted=15.6476, Expected=15.9960
# Month=52, Predicted=16.1509, Expected=17.0210
# Month=53, Predicted=17.6946, Expected=17.5520
# Month=54, Predicted=17.8663, Expected=17.8370
# Month=55, Predicted=18.0017, Expected=17.8560
# Month=56, Predicted=17.8363, Expected=17.5710
# Month=57, Predicted=17.2456, Expected=17.0780
# Month=58, Predicted=16.6389, Expected=16.6600
# Month=59, Predicted=16.2556, Expected=16.4330
# Month=60, Predicted=16.1525, Expected=16.5840
# Run 30 — RMSE: 0.505478, MSE: 0.255508, NMSE: 0.0019263854, Time: 225.7s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — PatchTST on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.504690 ± 0.003227
# MSE:  0.254723 ± 0.003251
# NMSE: 0.0019177702 ± 0.0000199524
# Avg training time: 280.0s ± 82.9s
#
# Best run: 17
#   RMSE: 0.496244
#   MSE:  0.246258
#   NMSE: 0.0018614385

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('PatchTST — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('PatchTST — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.496244
# MSE:  0.246258
# NMSE: 0.0018614385

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'PatchTST_LakeErie_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to PatchTST_LakeErie_predictions.csv

# %% [markdown]
# ## Observations
#
# ### PatchTST on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
