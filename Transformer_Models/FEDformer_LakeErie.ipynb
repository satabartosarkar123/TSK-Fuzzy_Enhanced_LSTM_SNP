# %% [markdown]
# # FEDformer — Monthly Lake Erie Levels
#
# **Model**: Frequency Enhanced Decomposed Transformer
# **Reference**: Zhou et al., 2022 — FEDformer: Frequency Enhanced Decomposed Transformer for Long-term Series Forecasting
#
# ## Description
# This notebook implements the **FEDformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Lake Erie Levels dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: FEDformer Architecture
#
# ### Frequency Enhanced Attention
# FEDformer operates in the **frequency domain** rather than the time domain:
#
# 1. Transform input to frequency space via FFT: $X_f = \mathcal{F}(X)$
# 2. Randomly select $M$ Fourier modes (random mode selection)
# 3. Apply learned linear transformations to selected modes
# 4. Transform back via inverse FFT: $X = \mathcal{F}^{-1}(X_f)$
#
# ### Frequency Domain Mixing
# The Fourier block applies learned complex-valued weights:
# $$Y_f[m] = W \cdot X_f[m], \quad m \in \{\text{selected modes}\}$$
#
# where $W = W_{\text{real}} + i \cdot W_{\text{imag}}$ is a learnable complex weight matrix.
#
# ### Series Decomposition
# Like Autoformer, FEDformer uses moving-average decomposition at each layer to separate trend and seasonal components.
#
# ### Complexity
# By selecting only $M \ll L$ Fourier modes, FEDformer achieves $O(L)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### FEDformer Model Definition

# %%
# ============================================================
# FEDformer: Frequency Enhanced Decomposed Transformer
# Reference: Zhou et al., 2022
#
# Key ideas:
# 1. Frequency attention: attention in Fourier space via random
#    mode selection (keeps top-M Fourier modes)
# 2. Series decomposition (shared with Autoformer)
# 3. Mixture of Experts (MoE) for frequency domain processing
# ============================================================

class FourierBlock(nn.Module):
    """
    Fourier-based attention block.
    Operates in the frequency domain by selecting random Fourier modes
    and applying learned linear transformations.
    """
    def __init__(self, d_model, n_modes=8):
        super().__init__()
        self.d_model = d_model
        self.n_modes = n_modes

        # Learnable complex weights for frequency domain
        self.scale = 1.0 / d_model
        self.W_real = nn.Parameter(self.scale * torch.randn(d_model, d_model))
        self.W_imag = nn.Parameter(self.scale * torch.randn(d_model, d_model))

    def forward(self, x):
        # x: (B, L, D)
        B, L, D = x.shape

        # FFT along sequence dimension
        x_fft = torch.fft.rfft(x, dim=1)  # (B, L//2+1, D)
        freq_len = x_fft.shape[1]

        # Select modes (all modes for short sequences)
        n_modes = min(self.n_modes, freq_len)

        # Apply learnable frequency transform on selected modes
        out_fft = torch.zeros_like(x_fft)
        selected = x_fft[:, :n_modes, :]

        # Complex multiplication with learned weights
        W_complex = torch.complex(self.W_real, self.W_imag)
        selected_out = torch.einsum('bld,dd->bld', selected, W_complex)
        out_fft[:, :n_modes, :] = selected_out

        # Inverse FFT
        output = torch.fft.irfft(out_fft, n=L, dim=1)  # (B, L, D)
        return output


class FEDSeriesDecomposition(nn.Module):
    """Series decomposition via moving average (shared design)."""
    def __init__(self, kernel_size=3):
        super().__init__()
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class FEDformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, n_modes=8, dropout=0.1):
        super().__init__()
        self.fourier_block = FourierBlock(d_model, n_modes)
        self.decomp1 = FEDSeriesDecomposition(kernel_size=3)
        self.decomp2 = FEDSeriesDecomposition(kernel_size=3)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Fourier block + decomposition
        fourier_out = self.fourier_block(x)
        x = x + self.dropout(fourier_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class FEDformerModel(nn.Module):
    """
    FEDformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_modes=8, n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            FEDformerEncoderLayer(d_model, n_heads, d_ff, n_modes, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 15905
# Trainable parameters: 15905
# Memory estimate: 62.1 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2076, Expected=13.7000
# Month=2, Predicted=14.0660, Expected=13.8140
# Month=3, Predicted=13.8781, Expected=14.3830
# Month=4, Predicted=14.7490, Expected=15.0470
# Month=5, Predicted=15.4756, Expected=15.6930
# Month=6, Predicted=16.1098, Expected=15.8440
# Month=7, Predicted=15.9324, Expected=15.7120
# Month=8, Predicted=15.6170, Expected=15.3130
# Month=9, Predicted=15.0501, Expected=14.7630
# Month=10, Predicted=14.4070, Expected=13.5480
# Month=11, Predicted=12.7907, Expected=13.5860
# Month=12, Predicted=13.6005, Expected=14.5160
# Month=13, Predicted=15.1133, Expected=14.3830
# Month=14, Predicted=14.2874, Expected=14.4970
# Month=15, Predicted=14.5611, Expected=14.7440
# Month=16, Predicted=14.8958, Expected=15.8060
# Month=17, Predicted=16.4808, Expected=16.5270
# Month=18, Predicted=16.9928, Expected=16.5460
# Month=19, Predicted=16.5482, Expected=16.7170
# Month=20, Predicted=16.8186, Expected=16.4330
# Month=21, Predicted=16.2419, Expected=15.7690
# Month=22, Predicted=15.3434, Expected=15.2750
# Month=23, Predicted=14.9534, Expected=15.1230
# Month=24, Predicted=15.0153, Expected=15.5410
# Month=25, Predicted=15.8065, Expected=15.8250
# Month=26, Predicted=16.0013, Expected=16.3760
# Month=27, Predicted=16.7301, Expected=16.3570
# Month=28, Predicted=16.3346, Expected=16.9070
# Month=29, Predicted=17.2604, Expected=17.0210
# Month=30, Predicted=17.0851, Expected=17.4190
# Month=31, Predicted=17.6712, Expected=17.5330
# Month=32, Predicted=17.5971, Expected=17.2680
# Month=33, Predicted=17.0888, Expected=16.6030
# Month=34, Predicted=16.1768, Expected=15.8250
# Month=35, Predicted=15.3302, Expected=15.4460
# Month=36, Predicted=15.1955, Expected=15.6360
# Month=37, Predicted=15.7501, Expected=15.6930
# Month=38, Predicted=15.7199, Expected=16.7550
# Month=39, Predicted=17.4298, Expected=16.5090
# Month=40, Predicted=16.3418, Expected=17.7230
# Month=41, Predicted=18.4795, Expected=18.6910
# Month=42, Predicted=19.3111, Expected=19.1270
# Month=43, Predicted=19.4045, Expected=19.5640
# Month=44, Predicted=19.8422, Expected=19.2030
# Month=45, Predicted=18.9637, Expected=18.2160
# Month=46, Predicted=17.5953, Expected=17.2110
# Month=47, Predicted=16.5795, Expected=16.6600
# Month=48, Predicted=16.3034, Expected=16.8310
# Month=49, Predicted=16.9326, Expected=15.7690
# Month=50, Predicted=15.1033, Expected=15.7310
# Month=51, Predicted=15.6963, Expected=15.9960
# Month=52, Predicted=16.1597, Expected=17.0210
# Month=53, Predicted=17.6746, Expected=17.5520
# Month=54, Predicted=17.8928, Expected=17.8370
# Month=55, Predicted=18.0140, Expected=17.8560
# Month=56, Predicted=17.8582, Expected=17.5710
# Month=57, Predicted=17.3793, Expected=17.0780
# Month=58, Predicted=16.7570, Expected=16.6600
# Month=59, Predicted=16.3853, Expected=16.4330
# Month=60, Predicted=16.2778, Expected=16.5840
# Run 1 — RMSE: 0.504283, MSE: 0.254302, NMSE: 0.0019126970, Time: 67.5s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1894, Expected=13.7000
# Month=2, Predicted=14.0352, Expected=13.8140
# Month=3, Predicted=13.8603, Expected=14.3830
# Month=4, Predicted=14.7182, Expected=15.0470
# Month=5, Predicted=15.4423, Expected=15.6930
# Month=6, Predicted=16.0769, Expected=15.8440
# Month=7, Predicted=15.9139, Expected=15.7120
# Month=8, Predicted=15.6015, Expected=15.3130
# Month=9, Predicted=15.0318, Expected=14.7630
# Month=10, Predicted=14.3850, Expected=13.5480
# Month=11, Predicted=12.7417, Expected=13.5860
# Month=12, Predicted=13.5839, Expected=14.5160
# Month=13, Predicted=15.0793, Expected=14.3830
# Month=14, Predicted=14.2719, Expected=14.4970
# Month=15, Predicted=14.5433, Expected=14.7440
# Month=16, Predicted=14.8749, Expected=15.8060
# Month=17, Predicted=16.4525, Expected=16.5270
# Month=18, Predicted=16.9583, Expected=16.5460
# Month=19, Predicted=16.5318, Expected=16.7170
# Month=20, Predicted=16.7996, Expected=16.4330
# Month=21, Predicted=16.2254, Expected=15.7690
# Month=22, Predicted=15.3178, Expected=15.2750
# Month=23, Predicted=14.9329, Expected=15.1230
# Month=24, Predicted=14.9998, Expected=15.5410
# Month=25, Predicted=15.7805, Expected=15.8250
# Month=26, Predicted=15.9794, Expected=16.3760
# Month=27, Predicted=16.6998, Expected=16.3570
# Month=28, Predicted=16.3186, Expected=16.9070
# Month=29, Predicted=17.2301, Expected=17.0210
# Month=30, Predicted=17.0673, Expected=17.4190
# Month=31, Predicted=17.6458, Expected=17.5330
# Month=32, Predicted=17.5793, Expected=17.2680
# Month=33, Predicted=17.0726, Expected=16.6030
# Month=34, Predicted=16.1512, Expected=15.8250
# Month=35, Predicted=15.3006, Expected=15.4460
# Month=36, Predicted=15.1776, Expected=15.6360
# Month=37, Predicted=15.7307, Expected=15.6930
# Month=38, Predicted=15.7030, Expected=16.7550
# Month=39, Predicted=17.4015, Expected=16.5090
# Month=40, Predicted=16.3257, Expected=17.7230
# Month=41, Predicted=18.4651, Expected=18.6910
# Month=42, Predicted=19.2782, Expected=19.1270
# Month=43, Predicted=19.3779, Expected=19.5640
# Month=44, Predicted=19.8155, Expected=19.2030
# Month=45, Predicted=18.9461, Expected=18.2160
# Month=46, Predicted=17.5569, Expected=17.2110
# Month=47, Predicted=16.5403, Expected=16.6600
# Month=48, Predicted=16.2814, Expected=16.8310
# Month=49, Predicted=16.9136, Expected=15.7690
# Month=50, Predicted=15.0616, Expected=15.7310
# Month=51, Predicted=15.6805, Expected=15.9960
# Month=52, Predicted=16.1384, Expected=17.0210
# Month=53, Predicted=17.6442, Expected=17.5520
# Month=54, Predicted=17.8631, Expected=17.8370
# Month=55, Predicted=17.9921, Expected=17.8560
# Month=56, Predicted=17.8418, Expected=17.5710
# Month=57, Predicted=17.3628, Expected=17.0780
# Month=58, Predicted=16.7366, Expected=16.6600
# Month=59, Predicted=16.3666, Expected=16.4330
# Month=60, Predicted=16.2619, Expected=16.5840
# Run 2 — RMSE: 0.505198, MSE: 0.255226, NMSE: 0.0019178564, Time: 75.8s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2043, Expected=13.7000
# Month=2, Predicted=14.0503, Expected=13.8140
# Month=3, Predicted=13.8751, Expected=14.3830
# Month=4, Predicted=14.7333, Expected=15.0470
# Month=5, Predicted=15.4571, Expected=15.6930
# Month=6, Predicted=16.0918, Expected=15.8440
# Month=7, Predicted=15.9288, Expected=15.7120
# Month=8, Predicted=15.6144, Expected=15.3130
# Month=9, Predicted=15.0412, Expected=14.7630
# Month=10, Predicted=14.3919, Expected=13.5480
# Month=11, Predicted=12.7324, Expected=13.5860
# Month=12, Predicted=13.5982, Expected=14.5160
# Month=13, Predicted=15.0920, Expected=14.3830
# Month=14, Predicted=14.2847, Expected=14.4970
# Month=15, Predicted=14.5581, Expected=14.7440
# Month=16, Predicted=14.8902, Expected=15.8060
# Month=17, Predicted=16.4638, Expected=16.5270
# Month=18, Predicted=16.9728, Expected=16.5460
# Month=19, Predicted=16.5460, Expected=16.7170
# Month=20, Predicted=16.8146, Expected=16.4330
# Month=21, Predicted=16.2365, Expected=15.7690
# Month=22, Predicted=15.3225, Expected=15.2750
# Month=23, Predicted=14.9408, Expected=15.1230
# Month=24, Predicted=15.0124, Expected=15.5410
# Month=25, Predicted=15.7960, Expected=15.8250
# Month=26, Predicted=15.9948, Expected=16.3760
# Month=27, Predicted=16.7150, Expected=16.3570
# Month=28, Predicted=16.3325, Expected=16.9070
# Month=29, Predicted=17.2454, Expected=17.0210
# Month=30, Predicted=17.0821, Expected=17.4190
# Month=31, Predicted=17.6613, Expected=17.5330
# Month=32, Predicted=17.5941, Expected=17.2680
# Month=33, Predicted=17.0839, Expected=16.6030
# Month=34, Predicted=16.1559, Expected=15.8250
# Month=35, Predicted=15.3028, Expected=15.4460
# Month=36, Predicted=15.1874, Expected=15.6360
# Month=37, Predicted=15.7458, Expected=15.6930
# Month=38, Predicted=15.7175, Expected=16.7550
# Month=39, Predicted=17.4128, Expected=16.5090
# Month=40, Predicted=16.3373, Expected=17.7230
# Month=41, Predicted=18.4744, Expected=18.6910
# Month=42, Predicted=19.2906, Expected=19.1270
# Month=43, Predicted=19.3934, Expected=19.5640
# Month=44, Predicted=19.8310, Expected=19.2030
# Month=45, Predicted=18.9561, Expected=18.2160
# Month=46, Predicted=17.5541, Expected=17.2110
# Month=47, Predicted=16.5370, Expected=16.6600
# Month=48, Predicted=16.2883, Expected=16.8310
# Month=49, Predicted=16.9286, Expected=15.7690
# Month=50, Predicted=15.0567, Expected=15.7310
# Month=51, Predicted=15.6942, Expected=15.9960
# Month=52, Predicted=16.1537, Expected=17.0210
# Month=53, Predicted=17.6559, Expected=17.5520
# Month=54, Predicted=17.8784, Expected=17.8370
# Month=55, Predicted=18.0074, Expected=17.8560
# Month=56, Predicted=17.8560, Expected=17.5710
# Month=57, Predicted=17.3738, Expected=17.0780
# Month=58, Predicted=16.7445, Expected=16.6600
# Month=59, Predicted=16.3758, Expected=16.4330
# Month=60, Predicted=16.2736, Expected=16.5840
# Run 3 — RMSE: 0.504725, MSE: 0.254747, NMSE: 0.0019123819, Time: 71.1s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1877, Expected=13.7000
# Month=2, Predicted=14.0211, Expected=13.8140
# Month=3, Predicted=13.8592, Expected=14.3830
# Month=4, Predicted=14.7041, Expected=15.0470
# Month=5, Predicted=15.4255, Expected=15.6930
# Month=6, Predicted=16.0606, Expected=15.8440
# Month=7, Predicted=15.9117, Expected=15.7120
# Month=8, Predicted=15.6074, Expected=15.3130
# Month=9, Predicted=15.0452, Expected=14.7630
# Month=10, Predicted=14.4028, Expected=13.5480
# Month=11, Predicted=12.7788, Expected=13.5860
# Month=12, Predicted=13.5849, Expected=14.5160
# Month=13, Predicted=15.0548, Expected=14.3830
# Month=14, Predicted=14.2777, Expected=14.4970
# Month=15, Predicted=14.5422, Expected=14.7440
# Month=16, Predicted=14.8700, Expected=15.8060
# Month=17, Predicted=16.4241, Expected=16.5270
# Month=18, Predicted=16.9399, Expected=16.5460
# Month=19, Predicted=16.5334, Expected=16.7170
# Month=20, Predicted=16.7968, Expected=16.4330
# Month=21, Predicted=16.2355, Expected=15.7690
# Month=22, Predicted=15.3388, Expected=15.2750
# Month=23, Predicted=14.9491, Expected=15.1230
# Month=24, Predicted=15.0061, Expected=15.5410
# Month=25, Predicted=15.7707, Expected=15.8250
# Month=26, Predicted=15.9735, Expected=16.3760
# Month=27, Predicted=16.6862, Expected=16.3570
# Month=28, Predicted=16.3212, Expected=16.9070
# Month=29, Predicted=17.2166, Expected=17.0210
# Month=30, Predicted=17.0662, Expected=17.4190
# Month=31, Predicted=17.6366, Expected=17.5330
# Month=32, Predicted=17.5782, Expected=17.2680
# Month=33, Predicted=17.0822, Expected=16.6030
# Month=34, Predicted=16.1722, Expected=15.8250
# Month=35, Predicted=15.3248, Expected=15.4460
# Month=36, Predicted=15.1905, Expected=15.6360
# Month=37, Predicted=15.7274, Expected=15.6930
# Month=38, Predicted=15.7035, Expected=16.7550
# Month=39, Predicted=17.3731, Expected=16.5090
# Month=40, Predicted=16.3348, Expected=17.7230
# Month=41, Predicted=18.4322, Expected=18.6910
# Month=42, Predicted=19.2526, Expected=19.1270
# Month=43, Predicted=19.3676, Expected=19.5640
# Month=44, Predicted=19.8052, Expected=19.2030
# Month=45, Predicted=18.9585, Expected=18.2160
# Month=46, Predicted=17.5873, Expected=17.2110
# Month=47, Predicted=16.5712, Expected=16.6600
# Month=48, Predicted=16.2991, Expected=16.8310
# Month=49, Predicted=16.9108, Expected=15.7690
# Month=50, Predicted=15.0941, Expected=15.7310
# Month=51, Predicted=15.6837, Expected=15.9960
# Month=52, Predicted=16.1329, Expected=17.0210
# Month=53, Predicted=17.6169, Expected=17.5520
# Month=54, Predicted=17.8501, Expected=17.8370
# Month=55, Predicted=17.9861, Expected=17.8560
# Month=56, Predicted=17.8434, Expected=17.5710
# Month=57, Predicted=17.3729, Expected=17.0780
# Month=58, Predicted=16.7527, Expected=16.6600
# Month=59, Predicted=16.3806, Expected=16.4330
# Month=60, Predicted=16.2704, Expected=16.5840
# Run 4 — RMSE: 0.502372, MSE: 0.252378, NMSE: 0.0019096114, Time: 76.5s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2184, Expected=13.7000
# Month=2, Predicted=14.0850, Expected=13.8140
# Month=3, Predicted=13.8884, Expected=14.3830
# Month=4, Predicted=14.7680, Expected=15.0470
# Month=5, Predicted=15.4944, Expected=15.6930
# Month=6, Predicted=16.1287, Expected=15.8440
# Month=7, Predicted=15.9437, Expected=15.7120
# Month=8, Predicted=15.6212, Expected=15.3130
# Month=9, Predicted=15.0493, Expected=14.7630
# Month=10, Predicted=14.4043, Expected=13.5480
# Month=11, Predicted=12.7845, Expected=13.5860
# Month=12, Predicted=13.6088, Expected=14.5160
# Month=13, Predicted=15.1231, Expected=14.3830
# Month=14, Predicted=14.2916, Expected=14.4970
# Month=15, Predicted=14.5714, Expected=14.7440
# Month=16, Predicted=14.9095, Expected=15.8060
# Month=17, Predicted=16.4805, Expected=16.5270
# Month=18, Predicted=17.0107, Expected=16.5460
# Month=19, Predicted=16.5560, Expected=16.7170
# Month=20, Predicted=16.8303, Expected=16.4330
# Month=21, Predicted=16.2430, Expected=15.7690
# Month=22, Predicted=15.3396, Expected=15.2750
# Month=23, Predicted=14.9513, Expected=15.1230
# Month=24, Predicted=15.0190, Expected=15.5410
# Month=25, Predicted=15.8240, Expected=15.8250
# Month=26, Predicted=16.0159, Expected=16.3760
# Month=27, Predicted=16.7490, Expected=16.3570
# Month=28, Predicted=16.3414, Expected=16.9070
# Month=29, Predicted=17.2794, Expected=17.0210
# Month=30, Predicted=17.0954, Expected=17.4190
# Month=31, Predicted=17.6883, Expected=17.5330
# Month=32, Predicted=17.6074, Expected=17.2680
# Month=33, Predicted=17.0902, Expected=16.6030
# Month=34, Predicted=16.1729, Expected=15.8250
# Month=35, Predicted=15.3256, Expected=15.4460
# Month=36, Predicted=15.1950, Expected=15.6360
# Month=37, Predicted=15.7624, Expected=15.6930
# Month=38, Predicted=15.7287, Expected=16.7550
# Month=39, Predicted=17.4295, Expected=16.5090
# Month=40, Predicted=16.3436, Expected=17.7230
# Month=41, Predicted=18.4625, Expected=18.6910
# Month=42, Predicted=19.3185, Expected=19.1270
# Month=43, Predicted=19.4223, Expected=19.5640
# Month=44, Predicted=19.8599, Expected=19.2030
# Month=45, Predicted=18.9635, Expected=18.2160
# Month=46, Predicted=17.5897, Expected=17.2110
# Month=47, Predicted=16.5738, Expected=16.6600
# Month=48, Predicted=16.3006, Expected=16.8310
# Month=49, Predicted=16.9443, Expected=15.7690
# Month=50, Predicted=15.0975, Expected=15.7310
# Month=51, Predicted=15.7027, Expected=15.9960
# Month=52, Predicted=16.1739, Expected=17.0210
# Month=53, Predicted=17.6776, Expected=17.5520
# Month=54, Predicted=17.9116, Expected=17.8370
# Month=55, Predicted=18.0286, Expected=17.8560
# Month=56, Predicted=17.8660, Expected=17.5710
# Month=57, Predicted=17.3803, Expected=17.0780
# Month=58, Predicted=16.7549, Expected=16.6600
# Month=59, Predicted=16.3843, Expected=16.4330
# Month=60, Predicted=16.2799, Expected=16.5840
# Run 5 — RMSE: 0.504557, MSE: 0.254578, NMSE: 0.0019130868, Time: 78.8s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.1963, Expected=13.7000
# Month=2, Predicted=14.0388, Expected=13.8140
# Month=3, Predicted=13.8673, Expected=14.3830
# Month=4, Predicted=14.7218, Expected=15.0470
# Month=5, Predicted=15.4454, Expected=15.6930
# Month=6, Predicted=16.0801, Expected=15.8440
# Month=7, Predicted=15.9206, Expected=15.7120
# Month=8, Predicted=15.6109, Expected=15.3130
# Month=9, Predicted=15.0441, Expected=14.7630
# Month=10, Predicted=14.3992, Expected=13.5480
# Month=11, Predicted=12.7658, Expected=13.5860
# Month=12, Predicted=13.5916, Expected=14.5160
# Month=13, Predicted=15.0811, Expected=14.3830
# Month=14, Predicted=14.2812, Expected=14.4970
# Month=15, Predicted=14.5503, Expected=14.7440
# Month=16, Predicted=14.8808, Expected=15.8060
# Month=17, Predicted=16.4538, Expected=16.5270
# Month=18, Predicted=16.9611, Expected=16.5460
# Month=19, Predicted=16.5397, Expected=16.7170
# Month=20, Predicted=16.8061, Expected=16.4330
# Month=21, Predicted=16.2364, Expected=15.7690
# Month=22, Predicted=15.3335, Expected=15.2750
# Month=23, Predicted=14.9464, Expected=15.1230
# Month=24, Predicted=15.0093, Expected=15.5410
# Month=25, Predicted=15.7851, Expected=15.8250
# Month=26, Predicted=15.9850, Expected=16.3760
# Month=27, Predicted=16.7035, Expected=16.3570
# Month=28, Predicted=16.3268, Expected=16.9070
# Month=29, Predicted=17.2339, Expected=17.0210
# Month=30, Predicted=17.0743, Expected=17.4190
# Month=31, Predicted=17.6505, Expected=17.5330
# Month=32, Predicted=17.5863, Expected=17.2680
# Month=33, Predicted=17.0833, Expected=16.6030
# Month=34, Predicted=16.1669, Expected=15.8250
# Month=35, Predicted=15.3178, Expected=15.4460
# Month=36, Predicted=15.1897, Expected=15.6360
# Month=37, Predicted=15.7370, Expected=15.6930
# Month=38, Predicted=15.7105, Expected=16.7550
# Month=39, Predicted=17.4028, Expected=16.5090
# Month=40, Predicted=16.3363, Expected=17.7230
# Month=41, Predicted=18.4660, Expected=18.6910
# Month=42, Predicted=19.2799, Expected=19.1270
# Month=43, Predicted=19.3824, Expected=19.5640
# Month=44, Predicted=19.8200, Expected=19.2030
# Month=45, Predicted=18.9580, Expected=18.2160
# Month=46, Predicted=17.5773, Expected=17.2110
# Month=47, Predicted=16.5610, Expected=16.6600
# Month=48, Predicted=16.2956, Expected=16.8310
# Month=49, Predicted=16.9201, Expected=15.7690
# Month=50, Predicted=15.0831, Expected=15.7310
# Month=51, Predicted=15.6889, Expected=15.9960
# Month=52, Predicted=16.1441, Expected=17.0210
# Month=53, Predicted=17.6456, Expected=17.5520
# Month=54, Predicted=17.8670, Expected=17.8370
# Month=55, Predicted=17.9976, Expected=17.8560
# Month=56, Predicted=17.8497, Expected=17.5710
# Month=57, Predicted=17.3738, Expected=17.0780
# Month=58, Predicted=16.7500, Expected=16.6600
# Month=59, Predicted=16.3792, Expected=16.4330
# Month=60, Predicted=16.2722, Expected=16.5840
# Run 6 — RMSE: 0.503584, MSE: 0.253597, NMSE: 0.0019104085, Time: 102.7s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1900, Expected=13.7000
# Month=2, Predicted=14.0371, Expected=13.8140
# Month=3, Predicted=13.8608, Expected=14.3830
# Month=4, Predicted=14.7201, Expected=15.0470
# Month=5, Predicted=15.4442, Expected=15.6930
# Month=6, Predicted=16.0788, Expected=15.8440
# Month=7, Predicted=15.9146, Expected=15.7120
# Month=8, Predicted=15.6004, Expected=15.3130
# Month=9, Predicted=15.0282, Expected=14.7630
# Month=10, Predicted=14.3796, Expected=13.5480
# Month=11, Predicted=12.7262, Expected=13.5860
# Month=12, Predicted=13.5840, Expected=14.5160
# Month=13, Predicted=15.0808, Expected=14.3830
# Month=14, Predicted=14.2707, Expected=14.4970
# Month=15, Predicted=14.5438, Expected=14.7440
# Month=16, Predicted=14.8760, Expected=15.8060
# Month=17, Predicted=16.4535, Expected=16.5270
# Month=18, Predicted=16.9602, Expected=16.5460
# Month=19, Predicted=16.5318, Expected=16.7170
# Month=20, Predicted=16.8004, Expected=16.4330
# Month=21, Predicted=16.2229, Expected=15.7690
# Month=22, Predicted=15.3110, Expected=15.2750
# Month=23, Predicted=14.9282, Expected=15.1230
# Month=24, Predicted=14.9984, Expected=15.5410
# Month=25, Predicted=15.7821, Expected=15.8250
# Month=26, Predicted=15.9807, Expected=16.3760
# Month=27, Predicted=16.7016, Expected=16.3570
# Month=28, Predicted=16.3183, Expected=16.9070
# Month=29, Predicted=17.2320, Expected=17.0210
# Month=30, Predicted=17.0678, Expected=17.4190
# Month=31, Predicted=17.6474, Expected=17.5330
# Month=32, Predicted=17.5798, Expected=17.2680
# Month=33, Predicted=17.0702, Expected=16.6030
# Month=34, Predicted=16.1444, Expected=15.8250
# Month=35, Predicted=15.2922, Expected=15.4460
# Month=36, Predicted=15.1742, Expected=15.6360
# Month=37, Predicted=15.7316, Expected=15.6930
# Month=38, Predicted=15.7032, Expected=16.7550
# Month=39, Predicted=17.4025, Expected=16.5090
# Month=40, Predicted=16.3236, Expected=17.7230
# Month=41, Predicted=18.4654, Expected=18.6910
# Month=42, Predicted=19.2796, Expected=19.1270
# Month=43, Predicted=19.3796, Expected=19.5640
# Month=44, Predicted=19.8172, Expected=19.2030
# Month=45, Predicted=18.9429, Expected=18.2160
# Month=46, Predicted=17.5454, Expected=17.2110
# Month=47, Predicted=16.5285, Expected=16.6600
# Month=48, Predicted=16.2760, Expected=16.8310
# Month=49, Predicted=16.9144, Expected=15.7690
# Month=50, Predicted=15.0487, Expected=15.7310
# Month=51, Predicted=15.6800, Expected=15.9960
# Month=52, Predicted=16.1396, Expected=17.0210
# Month=53, Predicted=17.6453, Expected=17.5520
# Month=54, Predicted=17.8650, Expected=17.8370
# Month=55, Predicted=17.9933, Expected=17.8560
# Month=56, Predicted=17.8418, Expected=17.5710
# Month=57, Predicted=17.3603, Expected=17.0780
# Month=58, Predicted=16.7319, Expected=16.6600
# Month=59, Predicted=16.3628, Expected=16.4330
# Month=60, Predicted=16.2599, Expected=16.5840
# Run 7 — RMSE: 0.505860, MSE: 0.255895, NMSE: 0.0019201497, Time: 96.4s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1892, Expected=13.7000
# Month=2, Predicted=14.0524, Expected=13.8140
# Month=3, Predicted=13.8595, Expected=14.3830
# Month=4, Predicted=14.7354, Expected=15.0470
# Month=5, Predicted=15.4617, Expected=15.6930
# Month=6, Predicted=16.0960, Expected=15.8440
# Month=7, Predicted=15.9143, Expected=15.7120
# Month=8, Predicted=15.5950, Expected=15.3130
# Month=9, Predicted=15.0253, Expected=14.7630
# Month=10, Predicted=14.3810, Expected=13.5480
# Month=11, Predicted=12.7605, Expected=13.5860
# Month=12, Predicted=13.5808, Expected=14.5160
# Month=13, Predicted=15.0924, Expected=14.3830
# Month=14, Predicted=14.2653, Expected=14.4970
# Month=15, Predicted=14.5425, Expected=14.7440
# Month=16, Predicted=14.8791, Expected=15.8060
# Month=17, Predicted=16.4522, Expected=16.5270
# Month=18, Predicted=16.9781, Expected=16.5460
# Month=19, Predicted=16.5282, Expected=16.7170
# Month=20, Predicted=16.8008, Expected=16.4330
# Month=21, Predicted=16.2181, Expected=15.7690
# Month=22, Predicted=15.3166, Expected=15.2750
# Month=23, Predicted=14.9278, Expected=15.1230
# Month=24, Predicted=14.9930, Expected=15.5410
# Month=25, Predicted=15.7921, Expected=15.8250
# Month=26, Predicted=15.9852, Expected=16.3760
# Month=27, Predicted=16.7164, Expected=16.3570
# Month=28, Predicted=16.3140, Expected=16.9070
# Month=29, Predicted=17.2468, Expected=17.0210
# Month=30, Predicted=17.0665, Expected=17.4190
# Month=31, Predicted=17.6565, Expected=17.5330
# Month=32, Predicted=17.5785, Expected=17.2680
# Month=33, Predicted=17.0653, Expected=16.6030
# Month=34, Predicted=16.1500, Expected=15.8250
# Month=35, Predicted=15.3027, Expected=15.4460
# Month=36, Predicted=15.1709, Expected=15.6360
# Month=37, Predicted=15.7326, Expected=15.6930
# Month=38, Predicted=15.7004, Expected=16.7550
# Month=39, Predicted=17.4012, Expected=16.5090
# Month=40, Predicted=16.3184, Expected=17.7230
# Month=41, Predicted=18.4381, Expected=18.6910
# Month=42, Predicted=19.2883, Expected=19.1270
# Month=43, Predicted=19.3902, Expected=19.5640
# Month=44, Predicted=19.8279, Expected=19.2030
# Month=45, Predicted=18.9393, Expected=18.2160
# Month=46, Predicted=17.5665, Expected=17.2110
# Month=47, Predicted=16.5506, Expected=16.6600
# Month=48, Predicted=16.2774, Expected=16.8310
# Month=49, Predicted=16.9148, Expected=15.7690
# Month=50, Predicted=15.0740, Expected=15.7310
# Month=51, Predicted=15.6755, Expected=15.9960
# Month=52, Predicted=16.1433, Expected=17.0210
# Month=53, Predicted=17.6485, Expected=17.5520
# Month=54, Predicted=17.8791, Expected=17.8370
# Month=55, Predicted=17.9979, Expected=17.8560
# Month=56, Predicted=17.8382, Expected=17.5710
# Month=57, Predicted=17.3555, Expected=17.0780
# Month=58, Predicted=16.7314, Expected=16.6600
# Month=59, Predicted=16.3604, Expected=16.4330
# Month=60, Predicted=16.2546, Expected=16.5840
# Run 8 — RMSE: 0.505993, MSE: 0.256029, NMSE: 0.0019239602, Time: 91.7s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2049, Expected=13.7000
# Month=2, Predicted=14.0697, Expected=13.8140
# Month=3, Predicted=13.8750, Expected=14.3830
# Month=4, Predicted=14.7527, Expected=15.0470
# Month=5, Predicted=15.4793, Expected=15.6930
# Month=6, Predicted=16.1135, Expected=15.8440
# Month=7, Predicted=15.9302, Expected=15.7120
# Month=8, Predicted=15.6067, Expected=15.3130
# Month=9, Predicted=15.0311, Expected=14.7630
# Month=10, Predicted=14.3830, Expected=13.5480
# Month=11, Predicted=12.7469, Expected=13.5860
# Month=12, Predicted=13.5953, Expected=14.5160
# Month=13, Predicted=15.1140, Expected=14.3830
# Month=14, Predicted=14.2771, Expected=14.4970
# Month=15, Predicted=14.5580, Expected=14.7440
# Month=16, Predicted=14.8957, Expected=15.8060
# Month=17, Predicted=16.4790, Expected=16.5270
# Month=18, Predicted=16.9961, Expected=16.5460
# Month=19, Predicted=16.5425, Expected=16.7170
# Month=20, Predicted=16.8168, Expected=16.4330
# Month=21, Predicted=16.2267, Expected=15.7690
# Month=22, Predicted=15.3158, Expected=15.2750
# Month=23, Predicted=14.9313, Expected=15.1230
# Month=24, Predicted=15.0044, Expected=15.5410
# Month=25, Predicted=15.8092, Expected=15.8250
# Month=26, Predicted=16.0020, Expected=16.3760
# Month=27, Predicted=16.7337, Expected=16.3570
# Month=28, Predicted=16.3277, Expected=16.9070
# Month=29, Predicted=17.2641, Expected=17.0210
# Month=30, Predicted=17.0820, Expected=17.4190
# Month=31, Predicted=17.6736, Expected=17.5330
# Month=32, Predicted=17.5940, Expected=17.2680
# Month=33, Predicted=17.0742, Expected=16.6030
# Month=34, Predicted=16.1491, Expected=15.8250
# Month=35, Predicted=15.2991, Expected=15.4460
# Month=36, Predicted=15.1772, Expected=15.6360
# Month=37, Predicted=15.7488, Expected=15.6930
# Month=38, Predicted=15.7152, Expected=16.7550
# Month=39, Predicted=17.4280, Expected=16.5090
# Month=40, Predicted=16.3278, Expected=17.7230
# Month=41, Predicted=18.4745, Expected=18.6910
# Month=42, Predicted=19.3112, Expected=19.1270
# Month=43, Predicted=19.4074, Expected=19.5640
# Month=44, Predicted=19.8451, Expected=19.2030
# Month=45, Predicted=18.9460, Expected=18.2160
# Month=46, Predicted=17.5579, Expected=17.2110
# Month=47, Predicted=16.5416, Expected=16.6600
# Month=48, Predicted=16.2794, Expected=16.8310
# Month=49, Predicted=16.9308, Expected=15.7690
# Month=50, Predicted=15.0638, Expected=15.7310
# Month=51, Predicted=15.6889, Expected=15.9960
# Month=52, Predicted=16.1600, Expected=17.0210
# Month=53, Predicted=17.6736, Expected=17.5520
# Month=54, Predicted=17.8964, Expected=17.8370
# Month=55, Predicted=18.0146, Expected=17.8560
# Month=56, Predicted=17.8525, Expected=17.5710
# Month=57, Predicted=17.3640, Expected=17.0780
# Month=58, Predicted=16.7349, Expected=16.6600
# Month=59, Predicted=16.3657, Expected=16.4330
# Month=60, Predicted=16.2644, Expected=16.5840
# Run 9 — RMSE: 0.506298, MSE: 0.256337, NMSE: 0.0019196289, Time: 85.6s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1897, Expected=13.7000
# Month=2, Predicted=14.0367, Expected=13.8140
# Month=3, Predicted=13.8606, Expected=14.3830
# Month=4, Predicted=14.7197, Expected=15.0470
# Month=5, Predicted=15.4438, Expected=15.6930
# Month=6, Predicted=16.0784, Expected=15.8440
# Month=7, Predicted=15.9143, Expected=15.7120
# Month=8, Predicted=15.6003, Expected=15.3130
# Month=9, Predicted=15.0285, Expected=14.7630
# Month=10, Predicted=14.3802, Expected=13.5480
# Month=11, Predicted=12.7282, Expected=13.5860
# Month=12, Predicted=13.5838, Expected=14.5160
# Month=13, Predicted=15.0805, Expected=14.3830
# Month=14, Predicted=14.2707, Expected=14.4970
# Month=15, Predicted=14.5436, Expected=14.7440
# Month=16, Predicted=14.8757, Expected=15.8060
# Month=17, Predicted=16.4534, Expected=16.5270
# Month=18, Predicted=16.9598, Expected=16.5460
# Month=19, Predicted=16.5316, Expected=16.7170
# Month=20, Predicted=16.8001, Expected=16.4330
# Month=21, Predicted=16.2231, Expected=15.7690
# Month=22, Predicted=15.3118, Expected=15.2750
# Month=23, Predicted=14.9287, Expected=15.1230
# Month=24, Predicted=14.9984, Expected=15.5410
# Month=25, Predicted=15.7817, Expected=15.8250
# Month=26, Predicted=15.9803, Expected=16.3760
# Month=27, Predicted=16.7012, Expected=16.3570
# Month=28, Predicted=16.3181, Expected=16.9070
# Month=29, Predicted=17.2316, Expected=17.0210
# Month=30, Predicted=17.0676, Expected=17.4190
# Month=31, Predicted=17.6470, Expected=17.5330
# Month=32, Predicted=17.5796, Expected=17.2680
# Month=33, Predicted=17.0704, Expected=16.6030
# Month=34, Predicted=16.1451, Expected=15.8250
# Month=35, Predicted=15.2932, Expected=15.4460
# Month=36, Predicted=15.1745, Expected=15.6360
# Month=37, Predicted=15.7312, Expected=15.6930
# Month=38, Predicted=15.7030, Expected=16.7550
# Month=39, Predicted=17.4024, Expected=16.5090
# Month=40, Predicted=16.3237, Expected=17.7230
# Month=41, Predicted=18.4654, Expected=18.6910
# Month=42, Predicted=19.2794, Expected=19.1270
# Month=43, Predicted=19.3792, Expected=19.5640
# Month=44, Predicted=19.8168, Expected=19.2030
# Month=45, Predicted=18.9431, Expected=18.2160
# Month=46, Predicted=17.5468, Expected=17.2110
# Month=47, Predicted=16.5300, Expected=16.6600
# Month=48, Predicted=16.2766, Expected=16.8310
# Month=49, Predicted=16.9141, Expected=15.7690
# Month=50, Predicted=15.0504, Expected=15.7310
# Month=51, Predicted=15.6799, Expected=15.9960
# Month=52, Predicted=16.1392, Expected=17.0210
# Month=53, Predicted=17.6452, Expected=17.5520
# Month=54, Predicted=17.8646, Expected=17.8370
# Month=55, Predicted=17.9930, Expected=17.8560
# Month=56, Predicted=17.8416, Expected=17.5710
# Month=57, Predicted=17.3604, Expected=17.0780
# Month=58, Predicted=16.7324, Expected=16.6600
# Month=59, Predicted=16.3631, Expected=16.4330
# Month=60, Predicted=16.2600, Expected=16.5840
# Run 10 — RMSE: 0.505798, MSE: 0.255831, NMSE: 0.0019199925, Time: 96.2s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1974, Expected=13.7000
# Month=2, Predicted=14.0574, Expected=13.8140
# Month=3, Predicted=13.8676, Expected=14.3830
# Month=4, Predicted=14.7404, Expected=15.0470
# Month=5, Predicted=15.4656, Expected=15.6930
# Month=6, Predicted=16.1001, Expected=15.8440
# Month=7, Predicted=15.9225, Expected=15.7120
# Month=8, Predicted=15.5999, Expected=15.3130
# Month=9, Predicted=15.0233, Expected=14.7630
# Month=10, Predicted=14.3742, Expected=13.5480
# Month=11, Predicted=12.7311, Expected=13.5860
# Month=12, Predicted=13.5882, Expected=14.5160
# Month=13, Predicted=15.0971, Expected=14.3830
# Month=14, Predicted=14.2702, Expected=14.4970
# Month=15, Predicted=14.5506, Expected=14.7440
# Month=16, Predicted=14.8873, Expected=15.8060
# Month=17, Predicted=16.4615, Expected=16.5270
# Month=18, Predicted=16.9816, Expected=16.5460
# Month=19, Predicted=16.5354, Expected=16.7170
# Month=20, Predicted=16.8090, Expected=16.4330
# Month=21, Predicted=16.2194, Expected=15.7690
# Month=22, Predicted=15.3059, Expected=15.2750
# Month=23, Predicted=14.9228, Expected=15.1230
# Month=24, Predicted=14.9975, Expected=15.5410
# Month=25, Predicted=15.7990, Expected=15.8250
# Month=26, Predicted=15.9932, Expected=16.3760
# Month=27, Predicted=16.7217, Expected=16.3570
# Month=28, Predicted=16.3208, Expected=16.9070
# Month=29, Predicted=17.2521, Expected=17.0210
# Month=30, Predicted=17.0746, Expected=17.4190
# Month=31, Predicted=17.6637, Expected=17.5330
# Month=32, Predicted=17.5866, Expected=17.2680
# Month=33, Predicted=17.0671, Expected=16.6030
# Month=34, Predicted=16.1393, Expected=15.8250
# Month=35, Predicted=15.2881, Expected=15.4460
# Month=36, Predicted=15.1695, Expected=15.6360
# Month=37, Predicted=15.7409, Expected=15.6930
# Month=38, Predicted=15.7081, Expected=16.7550
# Month=39, Predicted=17.4105, Expected=16.5090
# Month=40, Predicted=16.3207, Expected=17.7230
# Month=41, Predicted=18.4578, Expected=18.6910
# Month=42, Predicted=19.2940, Expected=19.1270
# Month=43, Predicted=19.3969, Expected=19.5640
# Month=44, Predicted=19.8346, Expected=19.2030
# Month=45, Predicted=18.9384, Expected=18.2160
# Month=46, Predicted=17.5447, Expected=17.2110
# Month=47, Predicted=16.5282, Expected=16.6600
# Month=48, Predicted=16.2705, Expected=16.8310
# Month=49, Predicted=16.9230, Expected=15.7690
# Month=50, Predicted=15.0497, Expected=15.7310
# Month=51, Predicted=15.6820, Expected=15.9960
# Month=52, Predicted=16.1515, Expected=17.0210
# Month=53, Predicted=17.6561, Expected=17.5520
# Month=54, Predicted=17.8846, Expected=17.8370
# Month=55, Predicted=18.0059, Expected=17.8560
# Month=56, Predicted=17.8454, Expected=17.5710
# Month=57, Predicted=17.3568, Expected=17.0780
# Month=58, Predicted=16.7265, Expected=16.6600
# Month=59, Predicted=16.3578, Expected=16.4330
# Month=60, Predicted=16.2574, Expected=16.5840
# Run 11 — RMSE: 0.506400, MSE: 0.256441, NMSE: 0.0019213015, Time: 91.5s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2155, Expected=13.7000
# Month=2, Predicted=14.0642, Expected=13.8140
# Month=3, Predicted=13.8863, Expected=14.3830
# Month=4, Predicted=14.7472, Expected=15.0470
# Month=5, Predicted=15.4721, Expected=15.6930
# Month=6, Predicted=16.1066, Expected=15.8440
# Month=7, Predicted=15.9401, Expected=15.7120
# Month=8, Predicted=15.6264, Expected=15.3130
# Month=9, Predicted=15.0559, Expected=14.7630
# Month=10, Predicted=14.4088, Expected=13.5480
# Month=11, Predicted=12.7661, Expected=13.5860
# Month=12, Predicted=13.6095, Expected=14.5160
# Month=13, Predicted=15.1116, Expected=14.3830
# Month=14, Predicted=14.2967, Expected=14.4970
# Month=15, Predicted=14.5693, Expected=14.7440
# Month=16, Predicted=14.9017, Expected=15.8060
# Month=17, Predicted=16.4861, Expected=16.5270
# Month=18, Predicted=16.9887, Expected=16.5460
# Month=19, Predicted=16.5573, Expected=16.7170
# Month=20, Predicted=16.8259, Expected=16.4330
# Month=21, Predicted=16.2498, Expected=15.7690
# Month=22, Predicted=15.3416, Expected=15.2750
# Month=23, Predicted=14.9568, Expected=15.1230
# Month=24, Predicted=15.0245, Expected=15.5410
# Month=25, Predicted=15.8084, Expected=15.8250
# Month=26, Predicted=16.0064, Expected=16.3760
# Month=27, Predicted=16.7287, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=17.2590, Expected=17.0210
# Month=30, Predicted=17.0933, Expected=17.4190
# Month=31, Predicted=17.6735, Expected=17.5330
# Month=32, Predicted=17.6053, Expected=17.2680
# Month=33, Predicted=17.0970, Expected=16.6030
# Month=34, Predicted=16.1749, Expected=15.8250
# Month=35, Predicted=15.3243, Expected=15.4460
# Month=36, Predicted=15.2017, Expected=15.6360
# Month=37, Predicted=15.7571, Expected=15.6930
# Month=38, Predicted=15.7287, Expected=16.7550
# Month=39, Predicted=17.4351, Expected=16.5090
# Month=40, Predicted=16.3502, Expected=17.7230
# Month=41, Predicted=18.5005, Expected=18.6910
# Month=42, Predicted=19.3109, Expected=19.1270
# Month=43, Predicted=19.4059, Expected=19.5640
# Month=44, Predicted=19.8436, Expected=19.2030
# Month=45, Predicted=18.9703, Expected=18.2160
# Month=46, Predicted=17.5808, Expected=17.2110
# Month=47, Predicted=16.5643, Expected=16.6600
# Month=48, Predicted=16.3052, Expected=16.8310
# Month=49, Predicted=16.9399, Expected=15.7690
# Month=50, Predicted=15.0856, Expected=15.7310
# Month=51, Predicted=15.7057, Expected=15.9960
# Month=52, Predicted=16.1652, Expected=17.0210
# Month=53, Predicted=17.6774, Expected=17.5520
# Month=54, Predicted=17.8918, Expected=17.8370
# Month=55, Predicted=18.0191, Expected=17.8560
# Month=56, Predicted=17.8673, Expected=17.5710
# Month=57, Predicted=17.3871, Expected=17.0780
# Month=58, Predicted=16.7605, Expected=16.6600
# Month=59, Predicted=16.3907, Expected=16.4330
# Month=60, Predicted=16.2864, Expected=16.5840
# Run 12 — RMSE: 0.503938, MSE: 0.253953, NMSE: 0.0019075117, Time: 90.5s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2202, Expected=13.7000
# Month=2, Predicted=14.1147, Expected=13.8140
# Month=3, Predicted=13.8891, Expected=14.3830
# Month=4, Predicted=14.7977, Expected=15.0470
# Month=5, Predicted=15.5279, Expected=15.6930
# Month=6, Predicted=16.1617, Expected=15.8440
# Month=7, Predicted=15.9467, Expected=15.7120
# Month=8, Predicted=15.6090, Expected=15.3130
# Month=9, Predicted=15.0277, Expected=14.7630
# Month=10, Predicted=14.3789, Expected=13.5480
# Month=11, Predicted=12.7500, Expected=13.5860
# Month=12, Predicted=13.6051, Expected=14.5160
# Month=13, Predicted=15.1583, Expected=14.3830
# Month=14, Predicted=14.2793, Expected=14.4970
# Month=15, Predicted=14.5721, Expected=14.7440
# Month=16, Predicted=14.9188, Expected=15.8060
# Month=17, Predicted=16.5128, Expected=16.5270
# Month=18, Predicted=17.0458, Expected=16.5460
# Month=19, Predicted=16.5512, Expected=16.7170
# Month=20, Predicted=16.8346, Expected=16.4330
# Month=21, Predicted=16.2249, Expected=15.7690
# Month=22, Predicted=15.3119, Expected=15.2750
# Month=23, Predicted=14.9272, Expected=15.1230
# Month=24, Predicted=15.0060, Expected=15.5410
# Month=25, Predicted=15.8448, Expected=15.8250
# Month=26, Predicted=16.0277, Expected=16.3760
# Month=27, Predicted=16.7778, Expected=16.3570
# Month=28, Predicted=16.3346, Expected=16.9070
# Month=29, Predicted=17.3080, Expected=17.0210
# Month=30, Predicted=17.0961, Expected=17.4190
# Month=31, Predicted=17.7078, Expected=17.5330
# Month=32, Predicted=17.6081, Expected=17.2680
# Month=33, Predicted=17.0728, Expected=16.6030
# Month=34, Predicted=16.1453, Expected=15.8250
# Month=35, Predicted=15.2960, Expected=15.4460
# Month=36, Predicted=15.1739, Expected=15.6360
# Month=37, Predicted=15.7679, Expected=15.6930
# Month=38, Predicted=15.7260, Expected=16.7550
# Month=39, Predicted=17.4618, Expected=16.5090
# Month=40, Predicted=16.3268, Expected=17.7230
# Month=41, Predicted=18.4923, Expected=18.6910
# Month=42, Predicted=19.3529, Expected=19.1270
# Month=43, Predicted=19.4442, Expected=19.5640
# Month=44, Predicted=19.8820, Expected=19.2030
# Month=45, Predicted=18.9430, Expected=18.2160
# Month=46, Predicted=17.5574, Expected=17.2110
# Month=47, Predicted=16.5413, Expected=16.6600
# Month=48, Predicted=16.2752, Expected=16.8310
# Month=49, Predicted=16.9486, Expected=15.7690
# Month=50, Predicted=15.0643, Expected=15.7310
# Month=51, Predicted=15.6949, Expected=15.9960
# Month=52, Predicted=16.1844, Expected=17.0210
# Month=53, Predicted=17.7107, Expected=17.5520
# Month=54, Predicted=17.9393, Expected=17.8370
# Month=55, Predicted=18.0405, Expected=17.8560
# Month=56, Predicted=17.8612, Expected=17.5710
# Month=57, Predicted=17.3622, Expected=17.0780
# Month=58, Predicted=16.7308, Expected=16.6600
# Month=59, Predicted=16.3621, Expected=16.4330
# Month=60, Predicted=16.2639, Expected=16.5840
# Run 13 — RMSE: 0.509501, MSE: 0.259592, NMSE: 0.0019328725, Time: 98.1s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1963, Expected=13.7000
# Month=2, Predicted=14.0487, Expected=13.8140
# Month=3, Predicted=13.8669, Expected=14.3830
# Month=4, Predicted=14.7317, Expected=15.0470
# Month=5, Predicted=15.4559, Expected=15.6930
# Month=6, Predicted=16.0906, Expected=15.8440
# Month=7, Predicted=15.9210, Expected=15.7120
# Month=8, Predicted=15.6062, Expected=15.3130
# Month=9, Predicted=15.0386, Expected=14.7630
# Month=10, Predicted=14.3948, Expected=13.5480
# Month=11, Predicted=12.7754, Expected=13.5860
# Month=12, Predicted=13.5896, Expected=14.5160
# Month=13, Predicted=15.0846, Expected=14.3830
# Month=14, Predicted=14.2766, Expected=14.4970
# Month=15, Predicted=14.5499, Expected=14.7440
# Month=16, Predicted=14.8837, Expected=15.8060
# Month=17, Predicted=16.4470, Expected=16.5270
# Month=18, Predicted=16.9713, Expected=16.5460
# Month=19, Predicted=16.5373, Expected=16.7170
# Month=20, Predicted=16.8071, Expected=16.4330
# Month=21, Predicted=16.2307, Expected=15.7690
# Month=22, Predicted=15.3307, Expected=15.2750
# Month=23, Predicted=14.9415, Expected=15.1230
# Month=24, Predicted=15.0044, Expected=15.5410
# Month=25, Predicted=15.7923, Expected=15.8250
# Month=26, Predicted=15.9889, Expected=16.3760
# Month=27, Predicted=16.7132, Expected=16.3570
# Month=28, Predicted=16.3238, Expected=16.9070
# Month=29, Predicted=17.2436, Expected=17.0210
# Month=30, Predicted=17.0739, Expected=17.4190
# Month=31, Predicted=17.6573, Expected=17.5330
# Month=32, Predicted=17.5859, Expected=17.2680
# Month=33, Predicted=17.0777, Expected=16.6030
# Month=34, Predicted=16.1641, Expected=15.8250
# Month=35, Predicted=15.3170, Expected=15.4460
# Month=36, Predicted=15.1841, Expected=15.6360
# Month=37, Predicted=15.7385, Expected=15.6930
# Month=38, Predicted=15.7089, Expected=16.7550
# Month=39, Predicted=17.3960, Expected=16.5090
# Month=40, Predicted=16.3307, Expected=17.7230
# Month=41, Predicted=18.4399, Expected=18.6910
# Month=42, Predicted=19.2810, Expected=19.1270
# Month=43, Predicted=19.3900, Expected=19.5640
# Month=44, Predicted=19.8276, Expected=19.2030
# Month=45, Predicted=18.9523, Expected=18.2160
# Month=46, Predicted=17.5810, Expected=17.2110
# Month=47, Predicted=16.5651, Expected=16.6600
# Month=48, Predicted=16.2912, Expected=16.8310
# Month=49, Predicted=16.9211, Expected=15.7690
# Month=50, Predicted=15.0887, Expected=15.7310
# Month=51, Predicted=15.6855, Expected=15.9960
# Month=52, Predicted=16.1474, Expected=17.0210
# Month=53, Predicted=17.6422, Expected=17.5520
# Month=54, Predicted=17.8764, Expected=17.8370
# Month=55, Predicted=18.0015, Expected=17.8560
# Month=56, Predicted=17.8473, Expected=17.5710
# Month=57, Predicted=17.3681, Expected=17.0780
# Month=58, Predicted=16.7451, Expected=16.6600
# Month=59, Predicted=16.3737, Expected=16.4330
# Month=60, Predicted=16.2668, Expected=16.5840
# Run 14 — RMSE: 0.503818, MSE: 0.253833, NMSE: 0.0019131719, Time: 104.6s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1929, Expected=13.7000
# Month=2, Predicted=14.0350, Expected=13.8140
# Month=3, Predicted=13.8640, Expected=14.3830
# Month=4, Predicted=14.7180, Expected=15.0470
# Month=5, Predicted=15.4414, Expected=15.6930
# Month=6, Predicted=16.0761, Expected=15.8440
# Month=7, Predicted=15.9172, Expected=15.7120
# Month=8, Predicted=15.6075, Expected=15.3130
# Month=9, Predicted=15.0406, Expected=14.7630
# Month=10, Predicted=14.3955, Expected=13.5480
# Month=11, Predicted=12.7606, Expected=13.5860
# Month=12, Predicted=13.5883, Expected=14.5160
# Month=13, Predicted=15.0765, Expected=14.3830
# Month=14, Predicted=14.2779, Expected=14.4970
# Month=15, Predicted=14.5470, Expected=14.7440
# Month=16, Predicted=14.8774, Expected=15.8060
# Month=17, Predicted=16.4488, Expected=16.5270
# Month=18, Predicted=16.9570, Expected=16.5460
# Month=19, Predicted=16.5364, Expected=16.7170
# Month=20, Predicted=16.8027, Expected=16.4330
# Month=21, Predicted=16.2330, Expected=15.7690
# Month=22, Predicted=15.3296, Expected=15.2750
# Month=23, Predicted=14.9428, Expected=15.1230
# Month=24, Predicted=15.0060, Expected=15.5410
# Month=25, Predicted=15.7815, Expected=15.8250
# Month=26, Predicted=15.9815, Expected=16.3760
# Month=27, Predicted=16.6997, Expected=16.3570
# Month=28, Predicted=16.3235, Expected=16.9070
# Month=29, Predicted=17.2301, Expected=17.0210
# Month=30, Predicted=17.0710, Expected=17.4190
# Month=31, Predicted=17.6470, Expected=17.5330
# Month=32, Predicted=17.5830, Expected=17.2680
# Month=33, Predicted=17.0799, Expected=16.6030
# Month=34, Predicted=16.1630, Expected=15.8250
# Month=35, Predicted=15.3137, Expected=15.4460
# Month=36, Predicted=15.1862, Expected=15.6360
# Month=37, Predicted=15.7336, Expected=15.6930
# Month=38, Predicted=15.7072, Expected=16.7550
# Month=39, Predicted=17.3978, Expected=16.5090
# Month=40, Predicted=16.3329, Expected=17.7230
# Month=41, Predicted=18.4606, Expected=18.6910
# Month=42, Predicted=19.2752, Expected=19.1270
# Month=43, Predicted=19.3787, Expected=19.5640
# Month=44, Predicted=19.8164, Expected=19.2030
# Month=45, Predicted=18.9545, Expected=18.2160
# Month=46, Predicted=17.5728, Expected=17.2110
# Month=47, Predicted=16.5564, Expected=16.6600
# Month=48, Predicted=16.2919, Expected=16.8310
# Month=49, Predicted=16.9167, Expected=15.7690
# Month=50, Predicted=15.0784, Expected=15.7310
# Month=51, Predicted=15.6856, Expected=15.9960
# Month=52, Predicted=16.1406, Expected=17.0210
# Month=53, Predicted=17.6408, Expected=17.5520
# Month=54, Predicted=17.8632, Expected=17.8370
# Month=55, Predicted=17.9942, Expected=17.8560
# Month=56, Predicted=17.8464, Expected=17.5710
# Month=57, Predicted=17.3703, Expected=17.0780
# Month=58, Predicted=16.7464, Expected=16.6600
# Month=59, Predicted=16.3756, Expected=16.4330
# Month=60, Predicted=16.2688, Expected=16.5840
# Run 15 — RMSE: 0.503843, MSE: 0.253857, NMSE: 0.0019122508, Time: 87.0s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1950, Expected=13.7000
# Month=2, Predicted=14.0431, Expected=13.8140
# Month=3, Predicted=13.8658, Expected=14.3830
# Month=4, Predicted=14.7261, Expected=15.0470
# Month=5, Predicted=15.4508, Expected=15.6930
# Month=6, Predicted=16.0853, Expected=15.8440
# Month=7, Predicted=15.9195, Expected=15.7120
# Month=8, Predicted=15.6061, Expected=15.3130
# Month=9, Predicted=15.0357, Expected=14.7630
# Month=10, Predicted=14.3887, Expected=13.5480
# Month=11, Predicted=12.7458, Expected=13.5860
# Month=12, Predicted=13.5891, Expected=14.5160
# Month=13, Predicted=15.0898, Expected=14.3830
# Month=14, Predicted=14.2764, Expected=14.4970
# Month=15, Predicted=14.5488, Expected=14.7440
# Month=16, Predicted=14.8810, Expected=15.8060
# Month=17, Predicted=16.4641, Expected=16.5270
# Month=18, Predicted=16.9673, Expected=16.5460
# Month=19, Predicted=16.5369, Expected=16.7170
# Month=20, Predicted=16.8053, Expected=16.4330
# Month=21, Predicted=16.2295, Expected=15.7690
# Month=22, Predicted=15.3214, Expected=15.2750
# Month=23, Predicted=14.9367, Expected=15.1230
# Month=24, Predicted=15.0042, Expected=15.5410
# Month=25, Predicted=15.7875, Expected=15.8250
# Month=26, Predicted=15.9857, Expected=16.3760
# Month=27, Predicted=16.7076, Expected=16.3570
# Month=28, Predicted=16.3235, Expected=16.9070
# Month=29, Predicted=17.2379, Expected=17.0210
# Month=30, Predicted=17.0728, Expected=17.4190
# Month=31, Predicted=17.6527, Expected=17.5330
# Month=32, Predicted=17.5848, Expected=17.2680
# Month=33, Predicted=17.0767, Expected=16.6030
# Month=34, Predicted=16.1548, Expected=15.8250
# Month=35, Predicted=15.3041, Expected=15.4460
# Month=36, Predicted=15.1815, Expected=15.6360
# Month=37, Predicted=15.7365, Expected=15.6930
# Month=38, Predicted=15.7083, Expected=16.7550
# Month=39, Predicted=17.4131, Expected=16.5090
# Month=40, Predicted=16.3299, Expected=17.7230
# Month=41, Predicted=18.4781, Expected=18.6910
# Month=42, Predicted=19.2891, Expected=19.1270
# Month=43, Predicted=19.3850, Expected=19.5640
# Month=44, Predicted=19.8226, Expected=19.2030
# Month=45, Predicted=18.9501, Expected=18.2160
# Month=46, Predicted=17.5606, Expected=17.2110
# Month=47, Predicted=16.5441, Expected=16.6600
# Month=48, Predicted=16.2851, Expected=16.8310
# Month=49, Predicted=16.9193, Expected=15.7690
# Month=50, Predicted=15.0654, Expected=15.7310
# Month=51, Predicted=15.6854, Expected=15.9960
# Month=52, Predicted=16.1445, Expected=17.0210
# Month=53, Predicted=17.6555, Expected=17.5520
# Month=54, Predicted=17.8708, Expected=17.8370
# Month=55, Predicted=17.9983, Expected=17.8560
# Month=56, Predicted=17.8469, Expected=17.5710
# Month=57, Predicted=17.3669, Expected=17.0780
# Month=58, Predicted=16.7403, Expected=16.6600
# Month=59, Predicted=16.3705, Expected=16.4330
# Month=60, Predicted=16.2661, Expected=16.5840
# Run 16 — RMSE: 0.505143, MSE: 0.255170, NMSE: 0.0019159517, Time: 82.7s
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1966, Expected=13.7000
# Month=2, Predicted=14.0646, Expected=13.8140
# Month=3, Predicted=13.8666, Expected=14.3830
# Month=4, Predicted=14.7476, Expected=15.0470
# Month=5, Predicted=15.4751, Expected=15.6930
# Month=6, Predicted=16.1092, Expected=15.8440
# Month=7, Predicted=15.9220, Expected=15.7120
# Month=8, Predicted=15.5982, Expected=15.3130
# Month=9, Predicted=15.0243, Expected=14.7630
# Month=10, Predicted=14.3781, Expected=13.5480
# Month=11, Predicted=12.7578, Expected=13.5860
# Month=12, Predicted=13.5868, Expected=14.5160
# Month=13, Predicted=15.1136, Expected=14.3830
# Month=14, Predicted=14.2685, Expected=14.4970
# Month=15, Predicted=14.5496, Expected=14.7440
# Month=16, Predicted=14.8880, Expected=15.8060
# Month=17, Predicted=16.4819, Expected=16.5270
# Month=18, Predicted=16.9926, Expected=16.5460
# Month=19, Predicted=16.5338, Expected=16.7170
# Month=20, Predicted=16.8087, Expected=16.4330
# Month=21, Predicted=16.2188, Expected=15.7690
# Month=22, Predicted=15.3128, Expected=15.2750
# Month=23, Predicted=14.9256, Expected=15.1230
# Month=24, Predicted=14.9959, Expected=15.5410
# Month=25, Predicted=15.8028, Expected=15.8250
# Month=26, Predicted=15.9945, Expected=16.3760
# Month=27, Predicted=16.7285, Expected=16.3570
# Month=28, Predicted=16.3191, Expected=16.9070
# Month=29, Predicted=17.2588, Expected=17.0210
# Month=30, Predicted=17.0736, Expected=17.4190
# Month=31, Predicted=17.6670, Expected=17.5330
# Month=32, Predicted=17.5856, Expected=17.2680
# Month=33, Predicted=17.0663, Expected=16.6030
# Month=34, Predicted=16.1462, Expected=15.8250
# Month=35, Predicted=15.2984, Expected=15.4460
# Month=36, Predicted=15.1702, Expected=15.6360
# Month=37, Predicted=15.7408, Expected=15.6930
# Month=38, Predicted=15.7067, Expected=16.7550
# Month=39, Predicted=17.4309, Expected=16.5090
# Month=40, Predicted=16.3197, Expected=17.7230
# Month=41, Predicted=18.4837, Expected=18.6910
# Month=42, Predicted=19.3116, Expected=19.1270
# Month=43, Predicted=19.4011, Expected=19.5640
# ...
# Month=28, Predicted=16.3240, Expected=16.9070
# Month=29, Predicted=17.2636, Expected=17.0210
# Month=30, Predicted=17.0779, Expected=17.4190
# Month=31, Predicted=17.6710, Expected=17.5330
# Month=32, Predicted=17.5899, Expected=17.2680
# Month=33, Predicted=17.0725, Expected=16.6030
# Month=34, Predicted=16.1529, Expected=15.8250
# Month=35, Predicted=15.3046, Expected=15.4460
# Month=36, Predicted=15.1768, Expected=15.6360
# Month=37, Predicted=15.7448, Expected=15.6930
# Month=38, Predicted=15.7112, Expected=16.7550
# Month=39, Predicted=17.4383, Expected=16.5090
# Month=40, Predicted=16.3259, Expected=17.7230
# Month=41, Predicted=18.4874, Expected=18.6910
# Month=42, Predicted=19.3196, Expected=19.1270
# Month=43, Predicted=19.4052, Expected=19.5640
# Month=44, Predicted=19.8429, Expected=19.2030
# Month=45, Predicted=18.9454, Expected=18.2160
# Month=46, Predicted=17.5669, Expected=17.2110
# Month=47, Predicted=16.5509, Expected=16.6600
# Month=48, Predicted=16.2814, Expected=16.8310
# Month=49, Predicted=16.9268, Expected=15.7690
# Month=50, Predicted=15.0741, Expected=15.7310
# Month=51, Predicted=15.6853, Expected=15.9960
# Month=52, Predicted=16.1563, Expected=17.0210
# Month=53, Predicted=17.6832, Expected=17.5520
# Month=54, Predicted=17.8956, Expected=17.8370
# Month=55, Predicted=18.0111, Expected=17.8560
# Month=56, Predicted=17.8486, Expected=17.5710
# Month=57, Predicted=17.3625, Expected=17.0780
# Month=58, Predicted=16.7361, Expected=16.6600
# Month=59, Predicted=16.3658, Expected=16.4330
# Month=60, Predicted=16.2623, Expected=16.5840
# Run 25 — RMSE: 0.506889, MSE: 0.256937, NMSE: 0.0019231894, Time: 78.7s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1937, Expected=13.7000
# Month=2, Predicted=14.0593, Expected=13.8140
# Month=3, Predicted=13.8637, Expected=14.3830
# Month=4, Predicted=14.7423, Expected=15.0470
# Month=5, Predicted=15.4689, Expected=15.6930
# Month=6, Predicted=16.1031, Expected=15.8440
# Month=7, Predicted=15.9190, Expected=15.7120
# Month=8, Predicted=15.5951, Expected=15.3130
# Month=9, Predicted=15.0193, Expected=14.7630
# Month=10, Predicted=14.3711, Expected=13.5480
# Month=11, Predicted=12.7342, Expected=13.5860
# Month=12, Predicted=13.5839, Expected=14.5160
# Month=13, Predicted=15.1033, Expected=14.3830
# Month=14, Predicted=14.2655, Expected=14.4970
# Month=15, Predicted=14.5467, Expected=14.7440
# Month=16, Predicted=14.8847, Expected=15.8060
# Month=17, Predicted=16.4677, Expected=16.5270
# Month=18, Predicted=16.9857, Expected=16.5460
# Month=19, Predicted=16.5310, Expected=16.7170
# Month=20, Predicted=16.8056, Expected=16.4330
# Month=21, Predicted=16.2149, Expected=15.7690
# Month=22, Predicted=15.3038, Expected=15.2750
# Month=23, Predicted=14.9194, Expected=15.1230
# Month=24, Predicted=14.9927, Expected=15.5410
# Month=25, Predicted=15.7985, Expected=15.8250
# Month=26, Predicted=15.9910, Expected=16.3760
# Month=27, Predicted=16.7232, Expected=16.3570
# Month=28, Predicted=16.3163, Expected=16.9070
# Month=29, Predicted=17.2536, Expected=17.0210
# Month=30, Predicted=17.0707, Expected=17.4190
# Month=31, Predicted=17.6629, Expected=17.5330
# Month=32, Predicted=17.5827, Expected=17.2680
# Month=33, Predicted=17.0625, Expected=16.6030
# Month=34, Predicted=16.1371, Expected=15.8250
# Month=35, Predicted=15.2870, Expected=15.4460
# Month=36, Predicted=15.1654, Expected=15.6360
# Month=37, Predicted=15.7376, Expected=15.6930
# Month=38, Predicted=15.7038, Expected=16.7550
# Month=39, Predicted=17.4167, Expected=16.5090
# Month=40, Predicted=16.3161, Expected=17.7230
# Month=41, Predicted=18.4622, Expected=18.6910
# Month=42, Predicted=19.3004, Expected=19.1270
# Month=43, Predicted=19.3967, Expected=19.5640
# Month=44, Predicted=19.8344, Expected=19.2030
# Month=45, Predicted=18.9342, Expected=18.2160
# Month=46, Predicted=17.5456, Expected=17.2110
# Month=47, Predicted=16.5292, Expected=16.6600
# Month=48, Predicted=16.2675, Expected=16.8310
# Month=49, Predicted=16.9196, Expected=15.7690
# Month=50, Predicted=15.0513, Expected=15.7310
# Month=51, Predicted=15.6774, Expected=15.9960
# Month=52, Predicted=16.1490, Expected=17.0210
# Month=53, Predicted=17.6625, Expected=17.5520
# Month=54, Predicted=17.8859, Expected=17.8370
# Month=55, Predicted=18.0037, Expected=17.8560
# Month=56, Predicted=17.8410, Expected=17.5710
# Month=57, Predicted=17.3523, Expected=17.0780
# Month=58, Predicted=16.7230, Expected=16.6600
# Month=59, Predicted=16.3539, Expected=16.4330
# Month=60, Predicted=16.2527, Expected=16.5840
# Run 26 — RMSE: 0.507305, MSE: 0.257358, NMSE: 0.0019261772, Time: 68.0s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1949, Expected=13.7000
# Month=2, Predicted=14.0446, Expected=13.8140
# Month=3, Predicted=13.8656, Expected=14.3830
# Month=4, Predicted=14.7276, Expected=15.0470
# Month=5, Predicted=15.4527, Expected=15.6930
# Month=6, Predicted=16.0872, Expected=15.8440
# Month=7, Predicted=15.9195, Expected=15.7120
# Month=8, Predicted=15.6052, Expected=15.3130
# Month=9, Predicted=15.0343, Expected=14.7630
# Month=10, Predicted=14.3870, Expected=13.5480
# Month=11, Predicted=12.7437, Expected=13.5860
# Month=12, Predicted=13.5887, Expected=14.5160
# Month=13, Predicted=15.0930, Expected=14.3830
# Month=14, Predicted=14.2756, Expected=14.4970
# Month=15, Predicted=14.5486, Expected=14.7440
# Month=16, Predicted=14.8813, Expected=15.8060
# Month=17, Predicted=16.4680, Expected=16.5270
# Month=18, Predicted=16.9694, Expected=16.5460
# Month=19, Predicted=16.5365, Expected=16.7170
# Month=20, Predicted=16.8053, Expected=16.4330
# Month=21, Predicted=16.2283, Expected=15.7690
# Month=22, Predicted=15.3196, Expected=15.2750
# Month=23, Predicted=14.9351, Expected=15.1230
# Month=24, Predicted=15.0033, Expected=15.5410
# Month=25, Predicted=15.7884, Expected=15.8250
# Month=26, Predicted=15.9861, Expected=16.3760
# Month=27, Predicted=16.7090, Expected=16.3570
# Month=28, Predicted=16.3230, Expected=16.9070
# Month=29, Predicted=17.2394, Expected=17.0210
# Month=30, Predicted=17.0726, Expected=17.4190
# Month=31, Predicted=17.6535, Expected=17.5330
# Month=32, Predicted=17.5846, Expected=17.2680
# Month=33, Predicted=17.0756, Expected=16.6030
# Month=34, Predicted=16.1530, Expected=15.8250
# Month=35, Predicted=15.3022, Expected=15.4460
# Month=36, Predicted=15.1802, Expected=15.6360
# Month=37, Predicted=15.7366, Expected=15.6930
# Month=38, Predicted=15.7079, Expected=16.7550
# Month=39, Predicted=17.4170, Expected=16.5090
# Month=40, Predicted=16.3288, Expected=17.7230
# Month=41, Predicted=18.4828, Expected=18.6910
# Month=42, Predicted=19.2925, Expected=19.1270
# Month=43, Predicted=19.3860, Expected=19.5640
# Month=44, Predicted=19.8236, Expected=19.2030
# Month=45, Predicted=18.9487, Expected=18.2160
# Month=46, Predicted=17.5585, Expected=17.2110
# Month=47, Predicted=16.5419, Expected=16.6600
# Month=48, Predicted=16.2834, Expected=16.8310
# Month=49, Predicted=16.9193, Expected=15.7690
# Month=50, Predicted=15.0632, Expected=15.7310
# Month=51, Predicted=15.6848, Expected=15.9960
# Month=52, Predicted=16.1449, Expected=17.0210
# Month=53, Predicted=17.6591, Expected=17.5520
# Month=54, Predicted=17.8721, Expected=17.8370
# Month=55, Predicted=17.9987, Expected=17.8560
# Month=56, Predicted=17.8465, Expected=17.5710
# Month=57, Predicted=17.3657, Expected=17.0780
# Month=58, Predicted=16.7387, Expected=16.6600
# Month=59, Predicted=16.3690, Expected=16.4330
# Month=60, Predicted=16.2650, Expected=16.5840
# Run 27 — RMSE: 0.505490, MSE: 0.255520, NMSE: 0.0019171523, Time: 65.9s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1931, Expected=13.7000
# Month=2, Predicted=14.0489, Expected=13.8140
# Month=3, Predicted=13.8637, Expected=14.3830
# Month=4, Predicted=14.7319, Expected=15.0470
# Month=5, Predicted=15.4577, Expected=15.6930
# Month=6, Predicted=16.0921, Expected=15.8440
# Month=7, Predicted=15.9179, Expected=15.7120
# Month=8, Predicted=15.6034, Expected=15.3130
# Month=9, Predicted=15.0369, Expected=14.7630
# Month=10, Predicted=14.3940, Expected=13.5480
# Month=11, Predicted=12.7792, Expected=13.5860
# Month=12, Predicted=13.5864, Expected=14.5160
# Month=13, Predicted=15.0933, Expected=14.3830
# Month=14, Predicted=14.2737, Expected=14.4970
# Month=15, Predicted=14.5467, Expected=14.7440
# Month=16, Predicted=14.8808, Expected=15.8060
# Month=17, Predicted=16.4600, Expected=16.5270
# Month=18, Predicted=16.9744, Expected=16.5460
# Month=19, Predicted=16.5341, Expected=16.7170
# Month=20, Predicted=16.8039, Expected=16.4330
# Month=21, Predicted=16.2285, Expected=15.7690
# Month=22, Predicted=15.3306, Expected=15.2750
# Month=23, Predicted=14.9403, Expected=15.1230
# Month=24, Predicted=15.0017, Expected=15.5410
# Month=25, Predicted=15.7905, Expected=15.8250
# Month=26, Predicted=15.9861, Expected=16.3760
# Month=27, Predicted=16.7131, Expected=16.3570
# Month=28, Predicted=16.3206, Expected=16.9070
# Month=29, Predicted=17.2434, Expected=17.0210
# Month=30, Predicted=17.0707, Expected=17.4190
# Month=31, Predicted=17.6553, Expected=17.5330
# Month=32, Predicted=17.5827, Expected=17.2680
# Month=33, Predicted=17.0754, Expected=16.6030
# Month=34, Predicted=16.1640, Expected=15.8250
# Month=35, Predicted=15.3176, Expected=15.4460
# Month=36, Predicted=15.1823, Expected=15.6360
# Month=37, Predicted=15.7354, Expected=15.6930
# Month=38, Predicted=15.7057, Expected=16.7550
# Month=39, Predicted=17.4090, Expected=16.5090
# Month=40, Predicted=16.3283, Expected=17.7230
# Month=41, Predicted=18.4583, Expected=18.6910
# Month=42, Predicted=19.2909, Expected=19.1270
# Month=43, Predicted=19.3884, Expected=19.5640
# Month=44, Predicted=19.8261, Expected=19.2030
# Month=45, Predicted=18.9505, Expected=18.2160
# Month=46, Predicted=17.5832, Expected=17.2110
# Month=47, Predicted=16.5674, Expected=16.6600
# Month=48, Predicted=16.2904, Expected=16.8310
# Month=49, Predicted=16.9179, Expected=15.7690
# Month=50, Predicted=15.0913, Expected=15.7310
# Month=51, Predicted=15.6824, Expected=15.9960
# Month=52, Predicted=16.1446, Expected=17.0210
# Month=53, Predicted=17.6540, Expected=17.5520
# Month=54, Predicted=17.8760, Expected=17.8370
# Month=55, Predicted=17.9988, Expected=17.8560
# Month=56, Predicted=17.8441, Expected=17.5710
# Month=57, Predicted=17.3659, Expected=17.0780
# Month=58, Predicted=16.7440, Expected=16.6600
# Month=59, Predicted=16.3722, Expected=16.4330
# Month=60, Predicted=16.2643, Expected=16.5840
# Run 28 — RMSE: 0.504666, MSE: 0.254688, NMSE: 0.0019168446, Time: 71.1s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.1888, Expected=13.7000
# Month=2, Predicted=14.0481, Expected=13.8140
# Month=3, Predicted=13.8592, Expected=14.3830
# Month=4, Predicted=14.7311, Expected=15.0470
# Month=5, Predicted=15.4569, Expected=15.6930
# Month=6, Predicted=16.0913, Expected=15.8440
# Month=7, Predicted=15.9138, Expected=15.7120
# Month=8, Predicted=15.5958, Expected=15.3130
# Month=9, Predicted=15.0259, Expected=14.7630
# Month=10, Predicted=14.3811, Expected=13.5480
# Month=11, Predicted=12.7574, Expected=13.5860
# Month=12, Predicted=13.5810, Expected=14.5160
# Month=13, Predicted=15.0900, Expected=14.3830
# Month=14, Predicted=14.2662, Expected=14.4970
# Month=15, Predicted=14.5422, Expected=14.7440
# Month=16, Predicted=14.8778, Expected=15.8060
# Month=17, Predicted=16.4539, Expected=16.5270
# Month=18, Predicted=16.9734, Expected=16.5460
# Month=19, Predicted=16.5285, Expected=16.7170
# Month=20, Predicted=16.8001, Expected=16.4330
# Month=21, Predicted=16.2190, Expected=15.7690
# Month=22, Predicted=15.3162, Expected=15.2750
# Month=23, Predicted=14.9281, Expected=15.1230
# Month=24, Predicted=14.9938, Expected=15.5410
# Month=25, Predicted=15.7890, Expected=15.8250
# Month=26, Predicted=15.9835, Expected=16.3760
# Month=27, Predicted=16.7123, Expected=16.3570
# Month=28, Predicted=16.3145, Expected=16.9070
# Month=29, Predicted=17.2426, Expected=17.0210
# Month=30, Predicted=17.0662, Expected=17.4190
# Month=31, Predicted=17.6537, Expected=17.5330
# Month=32, Predicted=17.5782, Expected=17.2680
# Month=33, Predicted=17.0661, Expected=16.6030
# Month=34, Predicted=16.1496, Expected=15.8250
# Month=35, Predicted=15.3018, Expected=15.4460
# Month=36, Predicted=15.1716, Expected=15.6360
# Month=37, Predicted=15.7318, Expected=15.6930
# Month=38, Predicted=15.7005, Expected=16.7550
# Month=39, Predicted=17.4029, Expected=16.5090
# Month=40, Predicted=16.3193, Expected=17.7230
# Month=41, Predicted=18.4478, Expected=18.6910
# Month=42, Predicted=19.2869, Expected=19.1270
# Month=43, Predicted=19.3870, Expected=19.5640
# Month=44, Predicted=19.8247, Expected=19.2030
# Month=45, Predicted=18.9400, Expected=18.2160
# Month=46, Predicted=17.5645, Expected=17.2110
# Month=47, Predicted=16.5485, Expected=16.6600
# Month=48, Predicted=16.2775, Expected=16.8310
# Month=49, Predicted=16.9141, Expected=15.7690
# Month=50, Predicted=15.0717, Expected=15.7310
# Month=51, Predicted=15.6761, Expected=15.9960
# Month=52, Predicted=16.1418, Expected=17.0210
# Month=53, Predicted=17.6488, Expected=17.5520
# Month=54, Predicted=17.8751, Expected=17.8370
# Month=55, Predicted=17.9962, Expected=17.8560
# Month=56, Predicted=17.8385, Expected=17.5710
# Month=57, Predicted=17.3563, Expected=17.0780
# Month=58, Predicted=16.7318, Expected=16.6600
# Month=59, Predicted=16.3609, Expected=16.4330
# Month=60, Predicted=16.2555, Expected=16.5840
# Run 29 — RMSE: 0.505846, MSE: 0.255880, NMSE: 0.0019224422, Time: 78.8s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.1885, Expected=13.7000
# Month=2, Predicted=14.0454, Expected=13.8140
# Month=3, Predicted=13.8590, Expected=14.3830
# Month=4, Predicted=14.7284, Expected=15.0470
# Month=5, Predicted=15.4547, Expected=15.6930
# Month=6, Predicted=16.0889, Expected=15.8440
# Month=7, Predicted=15.9133, Expected=15.7120
# Month=8, Predicted=15.5974, Expected=15.3130
# Month=9, Predicted=15.0289, Expected=14.7630
# Month=10, Predicted=14.3845, Expected=13.5480
# Month=11, Predicted=12.7628, Expected=13.5860
# Month=12, Predicted=13.5814, Expected=14.5160
# Month=13, Predicted=15.0929, Expected=14.3830
# Month=14, Predicted=14.2678, Expected=14.4970
# Month=15, Predicted=14.5420, Expected=14.7440
# Month=16, Predicted=14.8765, Expected=15.8060
# Month=17, Predicted=16.4623, Expected=16.5270
# Month=18, Predicted=16.9717, Expected=16.5460
# Month=19, Predicted=16.5290, Expected=16.7170
# Month=20, Predicted=16.7994, Expected=16.4330
# Month=21, Predicted=16.2214, Expected=15.7690
# Month=22, Predicted=15.3199, Expected=15.2750
# Month=23, Predicted=14.9314, Expected=15.1230
# Month=24, Predicted=14.9956, Expected=15.5410
# Month=25, Predicted=15.7866, Expected=15.8250
# Month=26, Predicted=15.9820, Expected=16.3760
# Month=27, Predicted=16.7096, Expected=16.3570
# Month=28, Predicted=16.3154, Expected=16.9070
# Month=29, Predicted=17.2399, Expected=17.0210
# Month=30, Predicted=17.0660, Expected=17.4190
# Month=31, Predicted=17.6514, Expected=17.5330
# Month=32, Predicted=17.5780, Expected=17.2680
# Month=33, Predicted=17.0685, Expected=16.6030
# Month=34, Predicted=16.1533, Expected=15.8250
# Month=35, Predicted=15.3058, Expected=15.4460
# Month=36, Predicted=15.1744, Expected=15.6360
# Month=37, Predicted=15.7309, Expected=15.6930
# Month=38, Predicted=15.7008, Expected=16.7550
# Month=39, Predicted=17.4113, Expected=16.5090
# Month=40, Predicted=16.3216, Expected=17.7230
# Month=41, Predicted=18.4650, Expected=18.6910
# Month=42, Predicted=19.2912, Expected=19.1270
# Month=43, Predicted=19.3846, Expected=19.5640
# Month=44, Predicted=19.8222, Expected=19.2030
# Month=45, Predicted=18.9428, Expected=18.2160
# Month=46, Predicted=17.5691, Expected=17.2110
# Month=47, Predicted=16.5532, Expected=16.6600
# Month=48, Predicted=16.2809, Expected=16.8310
# Month=49, Predicted=16.9134, Expected=15.7690
# Month=50, Predicted=15.0765, Expected=15.7310
# Month=51, Predicted=15.6770, Expected=15.9960
# Month=52, Predicted=16.1404, Expected=17.0210
# Month=53, Predicted=17.6554, Expected=17.5520
# Month=54, Predicted=17.8724, Expected=17.8370
# Month=55, Predicted=17.9946, Expected=17.8560
# Month=56, Predicted=17.8390, Expected=17.5710
# Month=57, Predicted=17.3588, Expected=17.0780
# Month=58, Predicted=16.7350, Expected=16.6600
# Month=59, Predicted=16.3639, Expected=16.4330
# Month=60, Predicted=16.2577, Expected=16.5840
# Run 30 — RMSE: 0.505771, MSE: 0.255804, NMSE: 0.0019213782, Time: 70.8s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — FEDformer on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.505378 ± 0.001409
# MSE:  0.255409 ± 0.001425
# NMSE: 0.0019180907 ± 0.0000057686
# Avg training time: 81.4s ± 10.6s
#
# Best run: 4
#   RMSE: 0.502372
#   MSE:  0.252378
#   NMSE: 0.0019096114

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('FEDformer — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('FEDformer — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.502372
# MSE:  0.252378
# NMSE: 0.0019096114

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'FEDformer_LakeErie_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to FEDformer_LakeErie_predictions.csv

# %% [markdown]
# ## Observations
#
# ### FEDformer on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
