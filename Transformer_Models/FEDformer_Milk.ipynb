# %% [markdown]
# # FEDformer — Monthly Milk Production
#
# **Model**: Frequency Enhanced Decomposed Transformer
# **Reference**: Zhou et al., 2022 — FEDformer: Frequency Enhanced Decomposed Transformer for Long-term Series Forecasting
#
# ## Description
# This notebook implements the **FEDformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Milk Production dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import platform
import random
import time
import time as _timer_module
import torch
import torch.nn as nn

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
import torch
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %%
# ============================================================
# GLOBAL IMPORTS (Consolidated)
# ============================================================

# ============================================================
# GLOBAL CONFIGURATION (CUDA & NOISE)
# ============================================================
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # Enable RTX 6000 Pro
if torch.cuda.is_available():
    torch.cuda.set_device(0)

noise_levels = [0.0, 0.005, 0.05, 0.10]
_molab_results = []

def add_gaussian_noise(series, noise_level):
    if noise_level == 0.0:
        return series
    noise = np.random.normal(0, noise_level, len(series))
    return series + noise
# ============================================================

# ============================================================
# FINAL RESULTS TABLE ACROSS ALL NOISE LEVELS
# ============================================================
import pandas as pd
from tabulate import tabulate
if len(_molab_results) > 0:
    df_res = pd.DataFrame(_molab_results, columns=['Noise Level (lambda)', 'RMSE', 'MSE', 'NMSE'])
    print('\n' + '='*80)
    print('FINAL RESULTS TABLE ACROSS ALL 4 NOISE LEVELS')
    print('='*80)
    print(tabulate(df_res, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# ## Theory: FEDformer Architecture
#
# ### Frequency Enhanced Attention
# FEDformer operates in the **frequency domain** rather than the time domain:
#
# 1. Transform input to frequency space via FFT: $X_f = \mathcal{F}(X)$
# 2. Randomly select $M$ Fourier modes (random mode selection)
# 3. Apply learned linear transformations to selected modes
# 4. Transform back via inverse FFT: $X = \mathcal{F}^{-1}(X_f)$
#
# ### Frequency Domain Mixing
# The Fourier block applies learned complex-valued weights:
# $$Y_f[m] = W \cdot X_f[m], \quad m \in \{\text{selected modes}\}$$
#
# where $W = W_{\text{real}} + i \cdot W_{\text{imag}}$ is a learnable complex weight matrix.
#
# ### Series Decomposition
# Like Autoformer, FEDformer uses moving-average decomposition at each layer to separate trend and seasonal components.
#
# ### Complexity
# By selecting only $M \ll L$ Fourier modes, FEDformer achieves $O(L)$ complexity.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Forcing CPU execution.')
print(f'\nUsing device: {device}')
print(f'PyTorch version: {torch.__version__}')

# %%
# ============================================================
# ALL IMPORTS
# ============================================================


print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        # MPS seed is set via torch.manual_seed
        pass

# %% [markdown]
# ### FEDformer Model Definition

# %%
# ============================================================
# FEDformer: Frequency Enhanced Decomposed Transformer
# Reference: Zhou et al., 2022
#
# Key ideas:
# 1. Frequency attention: attention in Fourier space via random
#    mode selection (keeps top-M Fourier modes)
# 2. Series decomposition (shared with Autoformer)
# 3. Mixture of Experts (MoE) for frequency domain processing
# ============================================================

class FourierBlock(nn.Module):
    """
    Fourier-based attention block.
    Operates in the frequency domain by selecting random Fourier modes
    and applying learned linear transformations.
    """
    def __init__(self, d_model, n_modes=8):
        super().__init__()
        self.d_model = d_model
        self.n_modes = n_modes

        # Learnable complex weights for frequency domain
        self.scale = 1.0 / d_model
        self.W_real = nn.Parameter(self.scale * torch.randn(d_model, d_model))
        self.W_imag = nn.Parameter(self.scale * torch.randn(d_model, d_model))

    def forward(self, x):
        # x: (B, L, D)
        B, L, D = x.shape

        # FFT along sequence dimension
        x_fft = torch.fft.rfft(x, dim=1)  # (B, L//2+1, D)
        freq_len = x_fft.shape[1]

        # Select modes (all modes for short sequences)
        n_modes = min(self.n_modes, freq_len)

        # Apply learnable frequency transform on selected modes
        out_fft = torch.zeros_like(x_fft)
        selected = x_fft[:, :n_modes, :]

        # Complex multiplication with learned weights
        W_complex = torch.complex(self.W_real, self.W_imag)
        selected_out = torch.einsum('bld,dd->bld', selected, W_complex)
        out_fft[:, :n_modes, :] = selected_out

        # Inverse FFT
        output = torch.fft.irfft(out_fft, n=L, dim=1)  # (B, L, D)
        return output


class FEDSeriesDecomposition(nn.Module):
    """Series decomposition via moving average (shared design)."""
    def __init__(self, kernel_size=3):
        super().__init__()
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class FEDformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, n_modes=8, dropout=0.1):
        super().__init__()
        self.fourier_block = FourierBlock(d_model, n_modes)
        self.decomp1 = FEDSeriesDecomposition(kernel_size=3)
        self.decomp2 = FEDSeriesDecomposition(kernel_size=3)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Fourier block + decomposition
        fourier_out = self.fourier_block(x)
        x = x + self.dropout(fourier_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class FEDformerModel(nn.Module):
    """
    FEDformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_modes=8, n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.encoder_layers = nn.ModuleList([
            FEDformerEncoderLayer(d_model, n_heads, d_ff, n_modes, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 15905
# Trainable parameters: 15905
# Memory estimate: 62.1 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = FEDformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=749.7705, Expected=804.0000
# Month=2, Predicted=805.1651, Expected=756.0000
# Month=3, Predicted=724.6353, Expected=860.0000
# Month=4, Predicted=871.9234, Expected=878.0000
# Month=5, Predicted=873.4256, Expected=942.0000
# Month=6, Predicted=945.3336, Expected=913.0000
# Month=7, Predicted=907.0612, Expected=869.0000
# Month=8, Predicted=845.1656, Expected=834.0000
# Month=9, Predicted=823.2225, Expected=790.0000
# Month=10, Predicted=766.1656, Expected=800.0000
# Month=11, Predicted=794.6827, Expected=763.0000
# Month=12, Predicted=749.8973, Expected=800.0000
# Month=13, Predicted=798.2506, Expected=826.0000
# Month=14, Predicted=822.4904, Expected=799.0000
# Month=15, Predicted=794.0071, Expected=890.0000
# Month=16, Predicted=899.0392, Expected=900.0000
# Month=17, Predicted=894.6827, Expected=961.0000
# Month=18, Predicted=963.7313, Expected=935.0000
# Month=19, Predicted=930.3701, Expected=894.0000
# Month=20, Predicted=875.2175, Expected=855.0000
# Month=21, Predicted=839.2219, Expected=809.0000
# Month=22, Predicted=781.4945, Expected=810.0000
# Month=23, Predicted=804.4911, Expected=766.0000
# Month=24, Predicted=742.1656, Expected=805.0000
# Month=25, Predicted=803.5956, Expected=821.0000
# Month=26, Predicted=816.2028, Expected=773.0000
# Month=27, Predicted=741.6353, Expected=883.0000
# Month=28, Predicted=896.2767, Expected=898.0000
# Month=29, Predicted=893.0996, Expected=957.0000
# Month=30, Predicted=959.3341, Expected=924.0000
# Month=31, Predicted=915.1879, Expected=881.0000
# Month=32, Predicted=858.9158, Expected=837.0000
# Month=33, Predicted=813.1656, Expected=784.0000
# Month=34, Predicted=742.4739, Expected=791.0000
# Month=35, Predicted=785.5281, Expected=760.0000
# Month=36, Predicted=752.7962, Expected=802.0000
# Month=37, Predicted=801.1247, Expected=828.0000
# Month=38, Predicted=824.4904, Expected=778.0000
# Month=39, Predicted=742.6360, Expected=889.0000
# Month=40, Predicted=902.5035, Expected=902.0000
# Month=41, Predicted=896.9117, Expected=969.0000
# Month=42, Predicted=972.9434, Expected=947.0000
# Month=43, Predicted=943.1999, Expected=908.0000
# Month=44, Predicted=892.2219, Expected=867.0000
# Month=45, Predicted=848.2175, Expected=815.0000
# Month=46, Predicted=775.5427, Expected=812.0000
# Month=47, Predicted=806.6943, Expected=773.0000
# Month=48, Predicted=757.2219, Expected=813.0000
# Month=49, Predicted=811.7705, Expected=834.0000
# Month=50, Predicted=829.7961, Expected=782.0000
# Month=51, Predicted=742.5427, Expected=892.0000
# Month=52, Predicted=905.2767, Expected=903.0000
# Month=53, Predicted=897.7514, Expected=966.0000
# Month=54, Predicted=969.1320, Expected=937.0000
# Month=55, Predicted=931.0612, Expected=896.0000
# Month=56, Predicted=877.2175, Expected=858.0000
# Month=57, Predicted=843.6023, Expected=817.0000
# Month=58, Predicted=798.2175, Expected=827.0000
# Month=59, Predicted=821.6827, Expected=797.0000
# Month=60, Predicted=790.4703, Expected=843.0000
# Run 1 — RMSE: 53.682870, MSE: 2881.850550, NMSE: 0.0102080912, Time: 33.1s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=751.3243, Expected=804.0000
# Month=2, Predicted=807.0631, Expected=756.0000
# Month=3, Predicted=730.5680, Expected=860.0000
# Month=4, Predicted=875.5254, Expected=878.0000
# Month=5, Predicted=874.3947, Expected=942.0000
# Month=6, Predicted=947.5491, Expected=913.0000
# Month=7, Predicted=906.6105, Expected=869.0000
# Month=8, Predicted=849.5698, Expected=834.0000
# Month=9, Predicted=824.2703, Expected=790.0000
# Month=10, Predicted=770.5698, Expected=800.0000
# Month=11, Predicted=795.3441, Expected=763.0000
# Month=12, Predicted=751.6112, Expected=800.0000
# Month=13, Predicted=799.7286, Expected=826.0000
# Month=14, Predicted=823.6901, Expected=799.0000
# Month=15, Predicted=793.2419, Expected=890.0000
# Month=16, Predicted=902.1530, Expected=900.0000
# Month=17, Predicted=895.3441, Expected=961.0000
# Month=18, Predicted=965.8575, Expected=935.0000
# Month=19, Predicted=929.4819, Expected=894.0000
# Month=20, Predicted=878.4314, Expected=855.0000
# Month=21, Predicted=841.6642, Expected=809.0000
# Month=22, Predicted=786.6805, Expected=810.0000
# Month=23, Predicted=804.6379, Expected=766.0000
# Month=24, Predicted=746.5698, Expected=805.0000
# Month=25, Predicted=805.1241, Expected=821.0000
# Month=26, Predicted=817.1046, Expected=773.0000
# Month=27, Predicted=747.5680, Expected=883.0000
# Month=28, Predicted=900.1130, Expected=898.0000
# Month=29, Predicted=893.9657, Expected=957.0000
# Month=30, Predicted=961.4019, Expected=924.0000
# Month=31, Predicted=915.6468, Expected=881.0000
# Month=32, Predicted=862.9226, Expected=837.0000
# Month=33, Predicted=817.5698, Expected=784.0000
# Month=34, Predicted=750.0059, Expected=791.0000
# Month=35, Predicted=786.0410, Expected=760.0000
# Month=36, Predicted=752.7538, Expected=802.0000
# Month=37, Predicted=802.7296, Expected=828.0000
# Month=38, Predicted=825.6901, Expected=778.0000
# Month=39, Predicted=749.2613, Expected=889.0000
# Month=40, Predicted=906.3792, Expected=902.0000
# Month=41, Predicted=897.7016, Expected=969.0000
# Month=42, Predicted=975.2502, Expected=947.0000
# Month=43, Predicted=942.0289, Expected=908.0000
# Month=44, Predicted=894.6642, Expected=867.0000
# Month=45, Predicted=851.4314, Expected=815.0000
# Month=46, Predicted=782.7917, Expected=812.0000
# Month=47, Predicted=806.5465, Expected=773.0000
# Month=48, Predicted=759.6642, Expected=813.0000
# Month=49, Predicted=813.3243, Expected=834.0000
# Month=50, Predicted=830.8574, Expected=782.0000
# Month=51, Predicted=749.7917, Expected=892.0000
# Month=52, Predicted=909.1130, Expected=903.0000
# Month=53, Predicted=898.4577, Expected=966.0000
# Month=54, Predicted=971.3175, Expected=937.0000
# Month=55, Predicted=930.6105, Expected=896.0000
# Month=56, Predicted=880.4314, Expected=858.0000
# Month=57, Predicted=845.6737, Expected=817.0000
# Month=58, Predicted=801.4314, Expected=827.0000
# Month=59, Predicted=822.3441, Expected=797.0000
# Month=60, Predicted=790.2120, Expected=843.0000
# Run 2 — RMSE: 52.405351, MSE: 2746.320793, NMSE: 0.0100390838, Time: 31.4s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=749.6843, Expected=804.0000
# Month=2, Predicted=805.5026, Expected=756.0000
# Month=3, Predicted=735.4135, Expected=860.0000
# Month=4, Predicted=873.7876, Expected=878.0000
# Month=5, Predicted=872.7069, Expected=942.0000
# Month=6, Predicted=946.0450, Expected=913.0000
# Month=7, Predicted=905.2555, Expected=869.0000
# Month=8, Predicted=853.6369, Expected=834.0000
# Month=9, Predicted=825.0478, Expected=790.0000
# Month=10, Predicted=774.6369, Expected=800.0000
# Month=11, Predicted=793.6284, Expected=763.0000
# Month=12, Predicted=753.2025, Expected=800.0000
# Month=13, Predicted=798.0736, Expected=826.0000
# Month=14, Predicted=822.0047, Expected=799.0000
# Month=15, Predicted=791.3696, Expected=890.0000
# Month=16, Predicted=900.5831, Expected=900.0000
# Month=17, Predicted=893.6284, Expected=961.0000
# Month=18, Predicted=964.3410, Expected=935.0000
# Month=19, Predicted=927.3951, Expected=894.0000
# Month=20, Predicted=881.5679, Expected=855.0000
# Month=21, Predicted=844.0560, Expected=809.0000
# Month=22, Predicted=791.2067, Expected=810.0000
# Month=23, Predicted=802.7365, Expected=766.0000
# Month=24, Predicted=750.6369, Expected=805.0000
# Month=25, Predicted=803.4788, Expected=821.0000
# Month=26, Predicted=815.4151, Expected=773.0000
# Month=27, Predicted=752.4135, Expected=883.0000
# Month=28, Predicted=898.2685, Expected=898.0000
# Month=29, Predicted=892.2745, Expected=957.0000
# Month=30, Predicted=959.8757, Expected=924.0000
# Month=31, Predicted=915.6394, Expected=881.0000
# Month=32, Predicted=866.7095, Expected=837.0000
# Month=33, Predicted=821.6369, Expected=784.0000
# Month=34, Predicted=755.1231, Expected=791.0000
# Month=35, Predicted=784.2898, Expected=760.0000
# Month=36, Predicted=752.0262, Expected=802.0000
# Month=37, Predicted=801.1007, Expected=828.0000
# Month=38, Predicted=824.0047, Expected=778.0000
# Month=39, Predicted=754.2946, Expected=889.0000
# Month=40, Predicted=904.5153, Expected=902.0000
# Month=41, Predicted=896.0044, Expected=969.0000
# Month=42, Predicted=973.7554, Expected=947.0000
# Month=43, Predicted=939.3723, Expected=908.0000
# Month=44, Predicted=897.0560, Expected=867.0000
# Month=45, Predicted=854.5679, Expected=815.0000
# Month=46, Predicted=787.9025, Expected=812.0000
# Month=47, Predicted=804.4696, Expected=773.0000
# Month=48, Predicted=762.0560, Expected=813.0000
# Month=49, Predicted=811.6843, Expected=834.0000
# Month=50, Predicted=829.1702, Expected=782.0000
# Month=51, Predicted=754.9025, Expected=892.0000
# Month=52, Predicted=907.2685, Expected=903.0000
# Month=53, Predicted=896.7497, Expected=966.0000
# Month=54, Predicted=969.8096, Expected=937.0000
# Month=55, Predicted=929.2555, Expected=896.0000
# Month=56, Predicted=883.5679, Expected=858.0000
# Month=57, Predicted=847.6696, Expected=817.0000
# Month=58, Predicted=804.5679, Expected=827.0000
# Month=59, Predicted=820.6284, Expected=797.0000
# Month=60, Predicted=789.1578, Expected=843.0000
# Run 3 — RMSE: 51.464115, MSE: 2648.555119, NMSE: 0.0100506576, Time: 27.5s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=746.2126, Expected=804.0000
# Month=2, Predicted=802.4627, Expected=756.0000
# Month=3, Predicted=732.6977, Expected=860.0000
# Month=4, Predicted=875.7644, Expected=878.0000
# Month=5, Predicted=870.1385, Expected=942.0000
# Month=6, Predicted=943.7666, Expected=913.0000
# Month=7, Predicted=912.9873, Expected=869.0000
# Month=8, Predicted=852.0424, Expected=834.0000
# Month=9, Predicted=829.5290, Expected=790.0000
# Month=10, Predicted=773.0424, Expected=800.0000
# Month=11, Predicted=792.0746, Expected=763.0000
# Month=12, Predicted=756.2129, Expected=800.0000
# Month=13, Predicted=794.5917, Expected=826.0000
# Month=14, Predicted=818.8273, Expected=799.0000
# Month=15, Predicted=799.5958, Expected=890.0000
# Month=16, Predicted=901.0539, Expected=900.0000
# Month=17, Predicted=892.0746, Expected=961.0000
# Month=18, Predicted=961.8257, Expected=935.0000
# Month=19, Predicted=935.7480, Expected=894.0000
# Month=20, Predicted=881.6739, Expected=855.0000
# Month=21, Predicted=845.5685, Expected=809.0000
# Month=22, Predicted=788.8702, Expected=810.0000
# Month=23, Predicted=802.9964, Expected=766.0000
# Month=24, Predicted=749.0424, Expected=805.0000
# Month=25, Predicted=799.9996, Expected=821.0000
# Month=26, Predicted=813.0582, Expected=773.0000
# Month=27, Predicted=749.6977, Expected=883.0000
# Month=28, Predicted=900.9445, Expected=898.0000
# Month=29, Predicted=890.0333, Expected=957.0000
# Month=30, Predicted=957.2138, Expected=924.0000
# Month=31, Predicted=921.4532, Expected=881.0000
# Month=32, Predicted=865.6117, Expected=837.0000
# Month=33, Predicted=820.0424, Expected=784.0000
# Month=34, Predicted=752.9631, Expected=791.0000
# Month=35, Predicted=783.2476, Expected=760.0000
# Month=36, Predicted=758.9441, Expected=802.0000
# Month=37, Predicted=797.6559, Expected=828.0000
# Month=38, Predicted=820.8273, Expected=778.0000
# Month=39, Predicted=751.5618, Expected=889.0000
# Month=40, Predicted=907.3074, Expected=902.0000
# Month=41, Predicted=894.0154, Expected=969.0000
# Month=42, Predicted=971.7326, Expected=947.0000
# Month=43, Predicted=947.5066, Expected=908.0000
# Month=44, Predicted=898.5685, Expected=867.0000
# Month=45, Predicted=854.6739, Expected=815.0000
# Month=46, Predicted=785.4811, Expected=812.0000
# Month=47, Predicted=805.8486, Expected=773.0000
# Month=48, Predicted=763.5685, Expected=813.0000
# Month=49, Predicted=808.2126, Expected=834.0000
# Month=50, Predicted=826.3308, Expected=782.0000
# Month=51, Predicted=752.4811, Expected=892.0000
# Month=52, Predicted=909.9445, Expected=903.0000
# Month=53, Predicted=895.0428, Expected=966.0000
# Month=54, Predicted=967.4500, Expected=937.0000
# Month=55, Predicted=936.9873, Expected=896.0000
# Month=56, Predicted=883.6739, Expected=858.0000
# Month=57, Predicted=849.9271, Expected=817.0000
# Month=58, Predicted=804.6739, Expected=827.0000
# Month=59, Predicted=819.0746, Expected=797.0000
# Month=60, Predicted=796.5214, Expected=843.0000
# Run 4 — RMSE: 52.096074, MSE: 2714.000951, NMSE: 0.0100482632, Time: 33.0s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=747.5638, Expected=804.0000
# Month=2, Predicted=803.5611, Expected=756.0000
# Month=3, Predicted=729.3304, Expected=860.0000
# Month=4, Predicted=875.0248, Expected=878.0000
# Month=5, Predicted=870.9721, Expected=942.0000
# Month=6, Predicted=944.4688, Expected=913.0000
# Month=7, Predicted=907.4343, Expected=869.0000
# Month=8, Predicted=849.2994, Expected=834.0000
# Month=9, Predicted=825.0300, Expected=790.0000
# Month=10, Predicted=770.2994, Expected=800.0000
# Month=11, Predicted=792.3954, Expected=763.0000
# Month=12, Predicted=752.2541, Expected=800.0000
# Month=13, Predicted=795.9505, Expected=826.0000
# Month=14, Predicted=820.0068, Expected=799.0000
# Month=15, Predicted=794.0073, Expected=890.0000
# Month=16, Predicted=900.6874, Expected=900.0000
# Month=17, Predicted=892.3954, Expected=961.0000
# Month=18, Predicted=962.6457, Expected=935.0000
# Month=19, Predicted=930.2054, Expected=894.0000
# Month=20, Predicted=878.6600, Expected=855.0000
# Month=21, Predicted=842.1325, Expected=809.0000
# Month=22, Predicted=785.9728, Expected=810.0000
# Month=23, Predicted=802.5211, Expected=766.0000
# Month=24, Predicted=746.2994, Expected=805.0000
# Month=25, Predicted=801.3558, Expected=821.0000
# Month=26, Predicted=813.7784, Expected=773.0000
# Month=27, Predicted=746.3304, Expected=883.0000
# Month=28, Predicted=900.0805, Expected=898.0000
# Month=29, Predicted=890.6931, Expected=957.0000
# Month=30, Predicted=958.1091, Expected=924.0000
# Month=31, Predicted=916.4720, Expected=881.0000
# Month=32, Predicted=862.8385, Expected=837.0000
# Month=33, Predicted=817.2994, Expected=784.0000
# Month=34, Predicted=746.9976, Expected=791.0000
# Month=35, Predicted=783.3342, Expected=760.0000
# Month=36, Predicted=753.5988, Expected=802.0000
# Month=37, Predicted=798.9901, Expected=828.0000
# Month=38, Predicted=822.0068, Expected=778.0000
# Month=39, Predicted=747.3944, Expected=889.0000
# Month=40, Predicted=906.4257, Expected=902.0000
# Month=41, Predicted=894.5470, Expected=969.0000
# Month=42, Predicted=972.3128, Expected=947.0000
# Month=43, Predicted=942.5074, Expected=908.0000
# Month=44, Predicted=895.1325, Expected=867.0000
# Month=45, Predicted=851.6600, Expected=815.0000
# Month=46, Predicted=780.1908, Expected=812.0000
# Month=47, Predicted=804.8903, Expected=773.0000
# Month=48, Predicted=760.1325, Expected=813.0000
# Month=49, Predicted=809.5638, Expected=834.0000
# Month=50, Predicted=827.3148, Expected=782.0000
# Month=51, Predicted=747.1908, Expected=892.0000
# Month=52, Predicted=909.0805, Expected=903.0000
# Month=53, Predicted=895.4364, Expected=966.0000
# Month=54, Predicted=968.1921, Expected=937.0000
# Month=55, Predicted=931.4343, Expected=896.0000
# Month=56, Predicted=880.6600, Expected=858.0000
# Month=57, Predicted=846.2370, Expected=817.0000
# Month=58, Predicted=801.6600, Expected=827.0000
# Month=59, Predicted=819.3954, Expected=797.0000
# Month=60, Predicted=791.0512, Expected=843.0000
# Run 5 — RMSE: 52.803843, MSE: 2788.245800, NMSE: 0.0101125426, Time: 30.8s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=746.0942, Expected=804.0000
# Month=2, Predicted=803.6130, Expected=756.0000
# Month=3, Predicted=732.1410, Expected=860.0000
# Month=4, Predicted=878.3001, Expected=878.0000
# Month=5, Predicted=868.0193, Expected=942.0000
# Month=6, Predicted=945.7153, Expected=913.0000
# Month=7, Predicted=921.2009, Expected=869.0000
# Month=8, Predicted=852.5183, Expected=834.0000
# Month=9, Predicted=833.4816, Expected=790.0000
# Month=10, Predicted=773.5183, Expected=800.0000
# Month=11, Predicted=789.9022, Expected=763.0000
# Month=12, Predicted=759.1082, Expected=800.0000
# Month=13, Predicted=794.1541, Expected=826.0000
# Month=14, Predicted=817.2778, Expected=799.0000
# Month=15, Predicted=809.3190, Expected=890.0000
# Month=16, Predicted=903.7261, Expected=900.0000
# Month=17, Predicted=889.9022, Expected=961.0000
# Month=18, Predicted=963.5866, Expected=935.0000
# Month=19, Predicted=946.1583, Expected=894.0000
# Month=20, Predicted=883.0105, Expected=855.0000
# Month=21, Predicted=847.6048, Expected=809.0000
# Month=22, Predicted=788.8284, Expected=810.0000
# Month=23, Predicted=802.2169, Expected=766.0000
# Month=24, Predicted=749.5183, Expected=805.0000
# Month=25, Predicted=799.7751, Expected=821.0000
# Month=26, Predicted=810.8608, Expected=773.0000
# Month=27, Predicted=749.1410, Expected=883.0000
# Month=28, Predicted=903.3467, Expected=898.0000
# Month=29, Predicted=887.8103, Expected=957.0000
# Month=30, Predicted=958.8368, Expected=924.0000
# Month=31, Predicted=926.6730, Expected=881.0000
# Month=32, Predicted=866.3578, Expected=837.0000
# Month=33, Predicted=820.5183, Expected=784.0000
# Month=34, Predicted=751.0127, Expected=791.0000
# Month=35, Predicted=781.3013, Expected=760.0000
# Month=36, Predicted=765.6115, Expected=802.0000
# Month=37, Predicted=797.7478, Expected=828.0000
# Month=38, Predicted=819.2778, Expected=778.0000
# Month=39, Predicted=750.4708, Expected=889.0000
# Month=40, Predicted=909.6839, Expected=902.0000
# Month=41, Predicted=891.7733, Expected=969.0000
# Month=42, Predicted=973.8460, Expected=947.0000
# Month=43, Predicted=959.6768, Expected=908.0000
# Month=44, Predicted=900.6048, Expected=867.0000
# Month=45, Predicted=856.0105, Expected=815.0000
# Month=46, Predicted=783.8256, Expected=812.0000
# Month=47, Predicted=806.6366, Expected=773.0000
# Month=48, Predicted=765.6048, Expected=813.0000
# Month=49, Predicted=808.0942, Expected=834.0000
# Month=50, Predicted=824.3848, Expected=782.0000
# Month=51, Predicted=750.8256, Expected=892.0000
# Month=52, Predicted=912.3467, Expected=903.0000
# Month=53, Predicted=892.8322, Expected=966.0000
# Month=54, Predicted=969.3387, Expected=937.0000
# Month=55, Predicted=945.2009, Expected=896.0000
# Month=56, Predicted=885.0105, Expected=858.0000
# Month=57, Predicted=852.3701, Expected=817.0000
# Month=58, Predicted=806.0105, Expected=827.0000
# Month=59, Predicted=816.9022, Expected=797.0000
# Month=60, Predicted=803.9569, Expected=843.0000
# Run 6 — RMSE: 52.834229, MSE: 2791.455765, NMSE: 0.0100019330, Time: 32.9s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=748.7649, Expected=804.0000
# Month=2, Predicted=804.3548, Expected=756.0000
# Month=3, Predicted=734.1213, Expected=860.0000
# Month=4, Predicted=872.9603, Expected=878.0000
# Month=5, Predicted=872.5541, Expected=942.0000
# Month=6, Predicted=944.8245, Expected=913.0000
# Month=7, Predicted=905.7627, Expected=869.0000
# Month=8, Predicted=852.4479, Expected=834.0000
# Month=9, Predicted=824.7823, Expected=790.0000
# Month=10, Predicted=773.4479, Expected=800.0000
# Month=11, Predicted=793.8603, Expected=763.0000
# Month=12, Predicted=752.6733, Expected=800.0000
# Month=13, Predicted=797.2305, Expected=826.0000
# Month=14, Predicted=821.5185, Expected=799.0000
# Month=15, Predicted=792.0883, Expected=890.0000
# Month=16, Predicted=899.5489, Expected=900.0000
# Month=17, Predicted=893.8603, Expected=961.0000
# Month=18, Predicted=963.1301, Expected=935.0000
# Month=19, Predicted=928.2067, Expected=894.0000
# Month=20, Predicted=880.5929, Expected=855.0000
# Month=21, Predicted=843.2855, Expected=809.0000
# Month=22, Predicted=789.9420, Expected=810.0000
# Month=23, Predicted=803.4287, Expected=766.0000
# Month=24, Predicted=749.4479, Expected=805.0000
# Month=25, Predicted=802.5838, Expected=821.0000
# Month=26, Predicted=815.3542, Expected=773.0000
# Month=27, Predicted=751.1213, Expected=883.0000
# Month=28, Predicted=897.5491, Expected=898.0000
# Month=29, Predicted=892.2608, Expected=957.0000
# Month=30, Predicted=958.6754, Expected=924.0000
# Month=31, Predicted=915.6438, Expected=881.0000
# Month=32, Predicted=865.5784, Expected=837.0000
# Month=33, Predicted=820.4479, Expected=784.0000
# Month=34, Predicted=753.8777, Expected=791.0000
# Month=35, Predicted=784.6747, Expected=760.0000
# Month=36, Predicted=752.2923, Expected=802.0000
# Month=37, Predicted=800.1355, Expected=828.0000
# Month=38, Predicted=823.5185, Expected=778.0000
# Month=39, Predicted=753.0102, Expected=889.0000
# Month=40, Predicted=903.8143, Expected=902.0000
# Month=41, Predicted=896.0871, Expected=969.0000
# Month=42, Predicted=972.5324, Expected=947.0000
# Month=43, Predicted=940.4622, Expected=908.0000
# Month=44, Predicted=896.2855, Expected=867.0000
# Month=45, Predicted=853.5929, Expected=815.0000
# Month=46, Predicted=786.6437, Expected=812.0000
# Month=47, Predicted=805.3557, Expected=773.0000
# Month=48, Predicted=761.2855, Expected=813.0000
# Month=49, Predicted=810.7649, Expected=834.0000
# Month=50, Predicted=828.8855, Expected=782.0000
# Month=51, Predicted=753.6437, Expected=892.0000
# Month=52, Predicted=906.5491, Expected=903.0000
# Month=53, Predicted=896.9314, Expected=966.0000
# Month=54, Predicted=968.5915, Expected=937.0000
# Month=55, Predicted=929.7627, Expected=896.0000
# Month=56, Predicted=882.5929, Expected=858.0000
# Month=57, Predicted=847.0160, Expected=817.0000
# Month=58, Predicted=803.5929, Expected=827.0000
# Month=59, Predicted=820.8603, Expected=797.0000
# Month=60, Predicted=789.5476, Expected=843.0000
# Run 7 — RMSE: 51.653755, MSE: 2668.110370, NMSE: 0.0100771138, Time: 25.3s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=750.0221, Expected=804.0000
# Month=2, Predicted=806.0500, Expected=756.0000
# Month=3, Predicted=727.3780, Expected=860.0000
# Month=4, Predicted=874.7509, Expected=878.0000
# Month=5, Predicted=872.6010, Expected=942.0000
# Month=6, Predicted=946.7214, Expected=913.0000
# Month=7, Predicted=896.9717, Expected=869.0000
# Month=8, Predicted=843.6339, Expected=834.0000
# Month=9, Predicted=814.7910, Expected=790.0000
# Month=10, Predicted=764.6339, Expected=800.0000
# Month=11, Predicted=793.2919, Expected=763.0000
# Month=12, Predicted=742.5672, Expected=800.0000
# Month=13, Predicted=798.3560, Expected=826.0000
# Month=14, Predicted=822.0716, Expected=799.0000
# Month=15, Predicted=783.8747, Expected=890.0000
# Month=16, Predicted=901.4549, Expected=900.0000
# Month=17, Predicted=893.2919, Expected=961.0000
# Month=18, Predicted=964.9865, Expected=935.0000
# Month=19, Predicted=920.2983, Expected=894.0000
# Month=20, Predicted=870.8708, Expected=855.0000
# Month=21, Predicted=833.2604, Expected=809.0000
# Month=22, Predicted=782.0439, Expected=810.0000
# Month=23, Predicted=801.9200, Expected=766.0000
# Month=24, Predicted=740.6339, Expected=805.0000
# Month=25, Predicted=803.7984, Expected=821.0000
# Month=26, Predicted=815.2600, Expected=773.0000
# Month=27, Predicted=744.3780, Expected=883.0000
# Month=28, Predicted=899.2822, Expected=898.0000
# Month=29, Predicted=892.0932, Expected=957.0000
# Month=30, Predicted=960.4989, Expected=924.0000
# Month=31, Predicted=905.9321, Expected=881.0000
# Month=32, Predicted=856.3996, Expected=837.0000
# Month=33, Predicted=811.6339, Expected=784.0000
# Month=34, Predicted=750.9051, Expected=791.0000
# Month=35, Predicted=783.8310, Expected=760.0000
# Month=36, Predicted=742.9917, Expected=802.0000
# Month=37, Predicted=801.4743, Expected=828.0000
# Month=38, Predicted=824.0716, Expected=778.0000
# Month=39, Predicted=747.6397, Expected=889.0000
# Month=40, Predicted=905.5380, Expected=902.0000
# Month=41, Predicted=895.7666, Expected=969.0000
# Month=42, Predicted=974.4598, Expected=947.0000
# Month=43, Predicted=933.8176, Expected=908.0000
# Month=44, Predicted=886.2604, Expected=867.0000
# Month=45, Predicted=843.8708, Expected=815.0000
# Month=46, Predicted=782.8328, Expected=812.0000
# Month=47, Predicted=803.2874, Expected=773.0000
# Month=48, Predicted=751.2604, Expected=813.0000
# Month=49, Predicted=812.0221, Expected=834.0000
# Month=50, Predicted=829.1323, Expected=782.0000
# Month=51, Predicted=749.8328, Expected=892.0000
# Month=52, Predicted=908.2822, Expected=903.0000
# Month=53, Predicted=896.4483, Expected=966.0000
# Month=54, Predicted=970.4760, Expected=937.0000
# Month=55, Predicted=920.9717, Expected=896.0000
# Month=56, Predicted=872.8708, Expected=858.0000
# Month=57, Predicted=836.9241, Expected=817.0000
# Month=58, Predicted=793.8708, Expected=827.0000
# Month=59, Predicted=820.2919, Expected=797.0000
# Month=60, Predicted=780.4915, Expected=843.0000
# Run 8 — RMSE: 52.925039, MSE: 2801.059752, NMSE: 0.0099883337, Time: 29.0s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=743.1384, Expected=804.0000
# Month=2, Predicted=794.9288, Expected=756.0000
# Month=3, Predicted=731.7959, Expected=860.0000
# Month=4, Predicted=879.8087, Expected=878.0000
# Month=5, Predicted=871.1436, Expected=942.0000
# Month=6, Predicted=932.9622, Expected=913.0000
# Month=7, Predicted=900.8044, Expected=869.0000
# Month=8, Predicted=848.0791, Expected=834.0000
# Month=9, Predicted=818.9824, Expected=790.0000
# Month=10, Predicted=769.0791, Expected=800.0000
# Month=11, Predicted=793.1547, Expected=763.0000
# Month=12, Predicted=746.8487, Expected=800.0000
# Month=13, Predicted=792.3856, Expected=826.0000
# Month=14, Predicted=818.9780, Expected=799.0000
# Month=15, Predicted=787.5645, Expected=890.0000
# Month=16, Predicted=895.9365, Expected=900.0000
# Month=17, Predicted=893.1547, Expected=961.0000
# Month=18, Predicted=951.7342, Expected=935.0000
# Month=19, Predicted=923.9133, Expected=894.0000
# Month=20, Predicted=875.2770, Expected=855.0000
# Month=21, Predicted=837.6140, Expected=809.0000
# Month=22, Predicted=786.4871, Expected=810.0000
# Month=23, Predicted=802.9739, Expected=766.0000
# Month=24, Predicted=745.0791, Expected=805.0000
# Month=25, Predicted=797.2245, Expected=821.0000
# Month=26, Predicted=814.1596, Expected=773.0000
# Month=27, Predicted=748.7959, Expected=883.0000
# Month=28, Predicted=909.5373, Expected=898.0000
# Month=29, Predicted=891.1642, Expected=957.0000
# Month=30, Predicted=947.6900, Expected=924.0000
# Month=31, Predicted=910.0174, Expected=881.0000
# Month=32, Predicted=860.8373, Expected=837.0000
# Month=33, Predicted=816.0791, Expected=784.0000
# Month=34, Predicted=755.1583, Expected=791.0000
# Month=35, Predicted=784.1212, Expected=760.0000
# Month=36, Predicted=746.9568, Expected=802.0000
# Month=37, Predicted=793.9562, Expected=828.0000
# Month=38, Predicted=820.9780, Expected=778.0000
# Month=39, Predicted=752.0090, Expected=889.0000
# Month=40, Predicted=916.6556, Expected=902.0000
# Month=41, Predicted=895.1670, Expected=969.0000
# Month=42, Predicted=960.4229, Expected=947.0000
# Month=43, Predicted=937.1151, Expected=908.0000
# Month=44, Predicted=890.6140, Expected=867.0000
# Month=45, Predicted=848.2770, Expected=815.0000
# Month=46, Predicted=787.1304, Expected=812.0000
# Month=47, Predicted=804.7946, Expected=773.0000
# Month=48, Predicted=755.6140, Expected=813.0000
# Month=49, Predicted=805.1384, Expected=834.0000
# Month=50, Predicted=827.1020, Expected=782.0000
# Month=51, Predicted=754.1304, Expected=892.0000
# Month=52, Predicted=918.5373, Expected=903.0000
# Month=53, Predicted=896.1611, Expected=966.0000
# Month=54, Predicted=956.8624, Expected=937.0000
# Month=55, Predicted=924.8044, Expected=896.0000
# Month=56, Predicted=877.2770, Expected=858.0000
# Month=57, Predicted=841.2440, Expected=817.0000
# Month=58, Predicted=798.2770, Expected=827.0000
# Month=59, Predicted=820.1547, Expected=797.0000
# Month=60, Predicted=784.3918, Expected=843.0000
# Run 9 — RMSE: 51.645810, MSE: 2667.289734, NMSE: 0.0100363867, Time: 35.0s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=747.6452, Expected=804.0000
# Month=2, Predicted=803.2548, Expected=756.0000
# Month=3, Predicted=730.9145, Expected=860.0000
# Month=4, Predicted=871.9934, Expected=878.0000
# Month=5, Predicted=871.0521, Expected=942.0000
# Month=6, Predicted=943.6884, Expected=913.0000
# Month=7, Predicted=905.1719, Expected=869.0000
# Month=8, Predicted=849.9879, Expected=834.0000
# Month=9, Predicted=823.6377, Expected=790.0000
# Month=10, Predicted=770.9879, Expected=800.0000
# Month=11, Predicted=792.1935, Expected=763.0000
# Month=12, Predicted=751.2724, Expected=800.0000
# Month=13, Predicted=796.0869, Expected=826.0000
# Month=14, Predicted=820.2045, Expected=799.0000
# Month=15, Predicted=791.5911, Expected=890.0000
# Month=16, Predicted=898.4293, Expected=900.0000
# Month=17, Predicted=892.1935, Expected=961.0000
# Month=18, Predicted=962.0050, Expected=935.0000
# Month=19, Predicted=927.7375, Expected=894.0000
# Month=20, Predicted=878.6138, Expected=855.0000
# Month=21, Predicted=841.6046, Expected=809.0000
# Month=22, Predicted=787.1296, Expected=810.0000
# Month=23, Predicted=801.7718, Expected=766.0000
# Month=24, Predicted=746.9879, Expected=805.0000
# Month=25, Predicted=801.4572, Expected=821.0000
# Month=26, Predicted=813.8045, Expected=773.0000
# Month=27, Predicted=747.9145, Expected=883.0000
# Month=28, Predicted=896.6936, Expected=898.0000
# Month=29, Predicted=890.6881, Expected=957.0000
# Month=30, Predicted=957.5576, Expected=924.0000
# Month=31, Predicted=914.7245, Expected=881.0000
# Month=32, Predicted=863.2838, Expected=837.0000
# Month=33, Predicted=817.9879, Expected=784.0000
# Month=34, Predicted=749.3499, Expected=791.0000
# Month=35, Predicted=782.9783, Expected=760.0000
# Month=36, Predicted=751.5597, Expected=802.0000
# Month=37, Predicted=799.0269, Expected=828.0000
# Month=38, Predicted=822.2045, Expected=778.0000
# Month=39, Predicted=749.3455, Expected=889.0000
# Month=40, Predicted=902.9800, Expected=902.0000
# Month=41, Predicted=894.4719, Expected=969.0000
# Month=42, Predicted=971.3859, Expected=947.0000
# Month=43, Predicted=939.9884, Expected=908.0000
# Month=44, Predicted=894.6046, Expected=867.0000
# Month=45, Predicted=851.6138, Expected=815.0000
# Month=46, Predicted=782.4317, Expected=812.0000
# Month=47, Predicted=803.8174, Expected=773.0000
# Month=48, Predicted=759.6046, Expected=813.0000
# Month=49, Predicted=809.6452, Expected=834.0000
# Month=50, Predicted=827.4568, Expected=782.0000
# Month=51, Predicted=749.4317, Expected=892.0000
# Month=52, Predicted=905.6936, Expected=903.0000
# Month=53, Predicted=895.2797, Expected=966.0000
# Month=54, Predicted=967.4590, Expected=937.0000
# Month=55, Predicted=929.1719, Expected=896.0000
# Month=56, Predicted=880.6138, Expected=858.0000
# Month=57, Predicted=845.4777, Expected=817.0000
# Month=58, Predicted=801.6138, Expected=827.0000
# Month=59, Predicted=819.1935, Expected=797.0000
# Month=60, Predicted=788.8918, Expected=843.0000
# Run 10 — RMSE: 52.366707, MSE: 2742.272039, NMSE: 0.0101406540, Time: 37.3s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=747.0991, Expected=804.0000
# Month=2, Predicted=803.3655, Expected=756.0000
# Month=3, Predicted=735.6393, Expected=860.0000
# Month=4, Predicted=874.5445, Expected=878.0000
# Month=5, Predicted=870.1434, Expected=942.0000
# Month=6, Predicted=944.4309, Expected=913.0000
# Month=7, Predicted=908.4474, Expected=869.0000
# Month=8, Predicted=853.5026, Expected=834.0000
# Month=9, Predicted=826.9929, Expected=790.0000
# Month=10, Predicted=774.5026, Expected=800.0000
# Month=11, Predicted=791.4892, Expected=763.0000
# Month=12, Predicted=754.5580, Expected=800.0000
# Month=13, Predicted=795.4221, Expected=826.0000
# Month=14, Predicted=819.2775, Expected=799.0000
# Month=15, Predicted=794.6992, Expected=890.0000
# Month=16, Predicted=900.5253, Expected=900.0000
# Month=17, Predicted=891.4892, Expected=961.0000
# Month=18, Predicted=962.5747, Expected=935.0000
# Month=19, Predicted=930.7376, Expected=894.0000
# Month=20, Predicted=881.8488, Expected=855.0000
# Month=21, Predicted=844.8315, Expected=809.0000
# Month=22, Predicted=791.1056, Expected=810.0000
# Month=23, Predicted=801.5093, Expected=766.0000
# Month=24, Predicted=750.5026, Expected=805.0000
# Month=25, Predicted=800.8697, Expected=821.0000
# Month=26, Predicted=812.9298, Expected=773.0000
# Month=27, Predicted=752.6393, Expected=883.0000
# Month=28, Predicted=899.4100, Expected=898.0000
# Month=29, Predicted=889.8348, Expected=957.0000
# Month=30, Predicted=958.0116, Expected=924.0000
# Month=31, Predicted=918.1172, Expected=881.0000
# Month=32, Predicted=866.6584, Expected=837.0000
# Month=33, Predicted=821.5026, Expected=784.0000
# Month=34, Predicted=757.4467, Expected=791.0000
# Month=35, Predicted=782.3961, Expected=760.0000
# Month=36, Predicted=754.9301, Expected=802.0000
# Month=37, Predicted=798.5685, Expected=828.0000
# Month=38, Predicted=821.2775, Expected=778.0000
# Month=39, Predicted=755.1504, Expected=889.0000
# Month=40, Predicted=905.7213, Expected=902.0000
# Month=41, Predicted=893.6699, Expected=969.0000
# Month=42, Predicted=972.2992, Expected=947.0000
# Month=43, Predicted=942.4384, Expected=908.0000
# Month=44, Predicted=897.8315, Expected=867.0000
# Month=45, Predicted=854.8488, Expected=815.0000
# Month=46, Predicted=789.6734, Expected=812.0000
# Month=47, Predicted=803.8344, Expected=773.0000
# Month=48, Predicted=762.8315, Expected=813.0000
# Month=49, Predicted=809.0991, Expected=834.0000
# Month=50, Predicted=826.5191, Expected=782.0000
# Month=51, Predicted=756.6734, Expected=892.0000
# Month=52, Predicted=908.4100, Expected=903.0000
# Month=53, Predicted=894.5401, Expected=966.0000
# Month=54, Predicted=968.1440, Expected=937.0000
# Month=55, Predicted=932.4474, Expected=896.0000
# Month=56, Predicted=883.8488, Expected=858.0000
# Month=57, Predicted=848.7293, Expected=817.0000
# Month=58, Predicted=804.8488, Expected=827.0000
# Month=59, Predicted=818.4892, Expected=797.0000
# Month=60, Predicted=792.2241, Expected=843.0000
# Run 11 — RMSE: 51.365354, MSE: 2638.399634, NMSE: 0.0100060267, Time: 38.7s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=749.7309, Expected=804.0000
# Month=2, Predicted=805.2493, Expected=756.0000
# Month=3, Predicted=730.0932, Expected=860.0000
# Month=4, Predicted=873.8262, Expected=878.0000
# Month=5, Predicted=873.2443, Expected=942.0000
# Month=6, Predicted=945.6141, Expected=913.0000
# Month=7, Predicted=907.4065, Expected=869.0000
# Month=8, Predicted=849.5850, Expected=834.0000
# Month=9, Predicted=824.9338, Expected=790.0000
# Month=10, Predicted=770.5850, Expected=800.0000
# Month=11, Predicted=794.3975, Expected=763.0000
# Month=12, Predicted=752.1802, Expected=800.0000
# Month=13, Predicted=798.1932, Expected=826.0000
# Month=14, Predicted=822.3735, Expected=799.0000
# Month=15, Predicted=794.0344, Expected=890.0000
# Month=16, Predicted=900.2623, Expected=900.0000
# Month=17, Predicted=894.3975, Expected=961.0000
# Month=18, Predicted=963.9483, Expected=935.0000
# Month=19, Predicted=930.2643, Expected=894.0000
# Month=20, Predicted=878.7287, Expected=855.0000
# Month=21, Predicted=842.1116, Expected=809.0000
# Month=22, Predicted=786.4675, Expected=810.0000
# Month=23, Predicted=804.0411, Expected=766.0000
# Month=24, Predicted=746.5850, Expected=805.0000
# Month=25, Predicted=803.5498, Expected=821.0000
# Month=26, Predicted=815.9995, Expected=773.0000
# Month=27, Predicted=747.0932, Expected=883.0000
# Month=28, Predicted=898.5334, Expected=898.0000
# Month=29, Predicted=892.8844, Expected=957.0000
# Month=30, Predicted=959.5130, Expected=924.0000
# Month=31, Predicted=916.3791, Expected=881.0000
# Month=32, Predicted=863.0398, Expected=837.0000
# Month=33, Predicted=817.5850, Expected=784.0000
# Month=34, Predicted=748.7283, Expected=791.0000
# Month=35, Predicted=785.1929, Expected=760.0000
# Month=36, Predicted=753.5299, Expected=802.0000
# Month=37, Predicted=801.0986, Expected=828.0000
# Month=38, Predicted=824.3735, Expected=778.0000
# Month=39, Predicted=748.4906, Expected=889.0000
# Month=40, Predicted=904.8213, Expected=902.0000
# Month=41, Predicted=896.6706, Expected=969.0000
# Month=42, Predicted=973.2954, Expected=947.0000
# Month=43, Predicted=942.7175, Expected=908.0000
# Month=44, Predicted=895.1116, Expected=867.0000
# Month=45, Predicted=851.7287, Expected=815.0000
# Month=46, Predicted=781.6913, Expected=812.0000
# Month=47, Predicted=806.1614, Expected=773.0000
# Month=48, Predicted=760.1116, Expected=813.0000
# Month=49, Predicted=811.7309, Expected=834.0000
# Month=50, Predicted=829.6428, Expected=782.0000
# Month=51, Predicted=748.6913, Expected=892.0000
# Month=52, Predicted=907.5334, Expected=903.0000
# Month=53, Predicted=897.4816, Expected=966.0000
# Month=54, Predicted=969.3904, Expected=937.0000
# Month=55, Predicted=931.4065, Expected=896.0000
# Month=56, Predicted=880.7287, Expected=858.0000
# Month=57, Predicted=846.1854, Expected=817.0000
# Month=58, Predicted=801.7287, Expected=827.0000
# Month=59, Predicted=821.3975, Expected=797.0000
# Month=60, Predicted=791.0010, Expected=843.0000
# Run 12 — RMSE: 52.516992, MSE: 2758.034415, NMSE: 0.0101054317, Time: 34.6s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=743.3478, Expected=804.0000
# Month=2, Predicted=792.9798, Expected=756.0000
# Month=3, Predicted=731.7366, Expected=860.0000
# Month=4, Predicted=880.9511, Expected=878.0000
# Month=5, Predicted=873.1153, Expected=942.0000
# Month=6, Predicted=929.7628, Expected=913.0000
# Month=7, Predicted=901.5493, Expected=869.0000
# Month=8, Predicted=848.1765, Expected=834.0000
# Month=9, Predicted=819.4328, Expected=790.0000
# Month=10, Predicted=769.1765, Expected=800.0000
# Month=11, Predicted=795.3238, Expected=763.0000
# Month=12, Predicted=747.2134, Expected=800.0000
# Month=13, Predicted=792.9789, Expected=826.0000
# Month=14, Predicted=820.5523, Expected=799.0000
# Month=15, Predicted=788.4192, Expected=890.0000
# Month=16, Predicted=899.5740, Expected=900.0000
# Month=17, Predicted=895.3238, Expected=961.0000
# Month=18, Predicted=948.6841, Expected=935.0000
# Month=19, Predicted=924.8246, Expected=894.0000
# Month=20, Predicted=875.4853, Expected=855.0000
# Month=21, Predicted=837.8985, Expected=809.0000
# Month=22, Predicted=786.5087, Expected=810.0000
# Month=23, Predicted=805.1304, Expected=766.0000
# Month=24, Predicted=745.1765, Expected=805.0000
# Month=25, Predicted=797.5680, Expected=821.0000
# Month=26, Predicted=816.1986, Expected=773.0000
# Month=27, Predicted=748.7366, Expected=883.0000
# Month=28, Predicted=906.1634, Expected=898.0000
# Month=29, Predicted=893.2324, Expected=957.0000
# Month=30, Predicted=944.8390, Expected=924.0000
# Month=31, Predicted=910.5597, Expected=881.0000
# Month=32, Predicted=860.9717, Expected=837.0000
# Month=33, Predicted=816.1765, Expected=784.0000
# Month=34, Predicted=754.8474, Expected=791.0000
# Month=35, Predicted=786.3142, Expected=760.0000
# Month=36, Predicted=747.5974, Expected=802.0000
# Month=37, Predicted=793.8792, Expected=828.0000
# Month=38, Predicted=822.5523, Expected=778.0000
# Month=39, Predicted=751.8596, Expected=889.0000
# Month=40, Predicted=912.3597, Expected=902.0000
# Month=41, Predicted=897.2845, Expected=969.0000
# Month=42, Predicted=957.2947, Expected=947.0000
# Month=43, Predicted=938.2602, Expected=908.0000
# Month=44, Predicted=890.8985, Expected=867.0000
# Month=45, Predicted=848.4853, Expected=815.0000
# Month=46, Predicted=786.8776, Expected=812.0000
# Month=47, Predicted=806.8641, Expected=773.0000
# Month=48, Predicted=755.8985, Expected=813.0000
# Month=49, Predicted=805.3478, Expected=834.0000
# Month=50, Predicted=828.9496, Expected=782.0000
# Month=51, Predicted=753.8776, Expected=892.0000
# Month=52, Predicted=915.1634, Expected=903.0000
# Month=53, Predicted=898.3160, Expected=966.0000
# Month=54, Predicted=953.6904, Expected=937.0000
# Month=55, Predicted=925.5493, Expected=896.0000
# Month=56, Predicted=877.4853, Expected=858.0000
# Month=57, Predicted=841.5681, Expected=817.0000
# Month=58, Predicted=798.4853, Expected=827.0000
# Month=59, Predicted=822.3238, Expected=797.0000
# Month=60, Predicted=785.0838, Expected=843.0000
# Run 13 — RMSE: 51.456936, MSE: 2647.816303, NMSE: 0.0101261283, Time: 30.0s
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=746.8974, Expected=804.0000
# Month=2, Predicted=802.7185, Expected=756.0000
# Month=3, Predicted=727.2396, Expected=860.0000
# Month=4, Predicted=873.2717, Expected=878.0000
# Month=5, Predicted=870.7317, Expected=942.0000
# Month=6, Predicted=943.4728, Expected=913.0000
# Month=7, Predicted=908.3647, Expected=869.0000
# Month=8, Predicted=847.6054, Expected=834.0000
# Month=9, Predicted=825.0260, Expected=790.0000
# Month=10, Predicted=768.6054, Expected=800.0000
# Month=11, Predicted=792.4172, Expected=763.0000
# Month=12, Predicted=751.8608, Expected=800.0000
# Month=13, Predicted=795.3280, Expected=826.0000
# Month=14, Predicted=819.5752, Expected=799.0000
# Month=15, Predicted=795.1408, Expected=890.0000
# Month=16, Predicted=899.2207, Expected=900.0000
# Month=17, Predicted=892.4172, Expected=961.0000
# Month=18, Predicted=961.6930, Expected=935.0000
# Month=19, Predicted=931.4183, Expected=894.0000
# Month=20, Predicted=877.4752, Expected=855.0000
# Month=21, Predicted=841.3381, Expected=809.0000
# Month=22, Predicted=784.0293, Expected=810.0000
# Month=23, Predicted=802.9474, Expected=766.0000
# Month=24, Predicted=744.6054, Expected=805.0000
# Month=25, Predicted=800.7038, Expected=821.0000
# Month=26, Predicted=813.5961, Expected=773.0000
# Month=27, Predicted=744.2396, Expected=883.0000
# Month=28, Predicted=898.1812, Expected=898.0000
# Month=29, Predicted=890.5414, Expected=957.0000
# Month=30, Predicted=957.1845, Expected=924.0000
# Month=31, Predicted=916.8270, Expected=881.0000
# Month=32, Predicted=861.2996, Expected=837.0000
# Month=33, Predicted=815.6054, Expected=784.0000
# Month=34, Predicted=745.1256, Expected=791.0000
# Month=35, Predicted=783.4772, Expected=760.0000
# Month=36, Predicted=754.2682, Expected=802.0000
# Month=37, Predicted=798.2956, Expected=828.0000
# Month=38, Predicted=821.5752, Expected=778.0000
# Month=39, Predicted=745.2815, Expected=889.0000
# Month=40, Predicted=904.5012, Expected=902.0000
# Month=41, Predicted=894.4607, Expected=969.0000
# Month=42, Predicted=971.2719, Expected=947.0000
# Month=43, Predicted=943.8995, Expected=908.0000
# Month=44, Predicted=894.3381, Expected=867.0000
# Month=45, Predicted=850.4752, Expected=815.0000
# Month=46, Predicted=778.1998, Expected=812.0000
# Month=47, Predicted=805.5336, Expected=773.0000
# Month=48, Predicted=759.3381, Expected=813.0000
# Month=49, Predicted=808.8974, Expected=834.0000
# Month=50, Predicted=826.9958, Expected=782.0000
# Month=51, Predicted=745.1998, Expected=892.0000
# Month=52, Predicted=907.1812, Expected=903.0000
# Month=53, Predicted=895.4208, Expected=966.0000
# Month=54, Predicted=967.2106, Expected=937.0000
# Month=55, Predicted=932.3647, Expected=896.0000
# Month=56, Predicted=879.4752, Expected=858.0000
# Month=57, Predicted=845.6433, Expected=817.0000
# Month=58, Predicted=800.4752, Expected=827.0000
# Month=59, Predicted=819.4172, Expected=797.0000
# Month=60, Predicted=791.8583, Expected=843.0000
# Run 14 — RMSE: 53.196211, MSE: 2829.836917, NMSE: 0.0101717312, Time: 34.7s
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=743.1336, Expected=804.0000
# Month=2, Predicted=799.3007, Expected=756.0000
# Month=3, Predicted=725.7536, Expected=860.0000
# Month=4, Predicted=874.9274, Expected=878.0000
# Month=5, Predicted=868.1023, Expected=942.0000
# Month=6, Predicted=940.8348, Expected=913.0000
# Month=7, Predicted=911.8980, Expected=869.0000
# Month=8, Predicted=846.5174, Expected=834.0000
# Month=9, Predicted=826.9147, Expected=790.0000
# Month=10, Predicted=767.5174, Expected=800.0000
# Month=11, Predicted=790.6147, Expected=763.0000
# Month=12, Predicted=752.9960, Expected=800.0000
# Month=13, Predicted=791.5912, Expected=826.0000
# Month=14, Predicted=816.2964, Expected=799.0000
# Month=15, Predicted=798.8864, Expected=890.0000
# Month=16, Predicted=899.4371, Expected=900.0000
# Month=17, Predicted=890.6147, Expected=961.0000
# Month=18, Predicted=958.8069, Expected=935.0000
# Month=19, Predicted=935.2003, Expected=894.0000
# Month=20, Predicted=877.1684, Expected=855.0000
# Month=21, Predicted=841.7190, Expected=809.0000
# Month=22, Predicted=782.6439, Expected=810.0000
# Month=23, Predicted=802.2075, Expected=766.0000
# Month=24, Predicted=743.5174, Expected=805.0000
# Month=25, Predicted=796.9443, Expected=821.0000
# Month=26, Predicted=811.1606, Expected=773.0000
# Month=27, Predicted=742.7536, Expected=883.0000
# Month=28, Predicted=900.4652, Expected=898.0000
# Month=29, Predicted=888.2066, Expected=957.0000
# Month=30, Predicted=954.1467, Expected=924.0000
# Month=31, Predicted=919.4017, Expected=881.0000
# Month=32, Predicted=860.4310, Expected=837.0000
# Month=33, Predicted=814.5174, Expected=784.0000
# Month=34, Predicted=744.1620, Expected=791.0000
# Month=35, Predicted=782.0130, Expected=760.0000
# Month=36, Predicted=757.4045, Expected=802.0000
# Month=37, Predicted=794.5371, Expected=828.0000
# Month=38, Predicted=818.2964, Expected=778.0000
# Month=39, Predicted=743.8844, Expected=889.0000
# Month=40, Predicted=906.8871, Expected=902.0000
# Month=41, Predicted=892.3334, Expected=969.0000
# Month=42, Predicted=968.9037, Expected=947.0000
# Month=43, Predicted=947.4157, Expected=908.0000
# Month=44, Predicted=894.7190, Expected=867.0000
# Month=45, Predicted=850.1684, Expected=815.0000
# Month=46, Predicted=777.0572, Expected=812.0000
# Month=47, Predicted=805.3415, Expected=773.0000
# Month=48, Predicted=759.7190, Expected=813.0000
# Month=49, Predicted=805.1336, Expected=834.0000
# Month=50, Predicted=824.0968, Expected=782.0000
# Month=51, Predicted=744.0572, Expected=892.0000
# Month=52, Predicted=909.4652, Expected=903.0000
# Month=53, Predicted=893.5084, Expected=966.0000
# Month=54, Predicted=964.4874, Expected=937.0000
# Month=55, Predicted=935.8980, Expected=896.0000
# Month=56, Predicted=879.1684, Expected=858.0000
# Month=57, Predicted=846.3971, Expected=817.0000
# Month=58, Predicted=800.1684, Expected=827.0000
# Month=59, Predicted=817.6147, Expected=797.0000
# Month=60, Predicted=795.2153, Expected=843.0000
# Run 15 — RMSE: 53.593737, MSE: 2872.288602, NMSE: 0.0101664439, Time: 33.6s
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=751.6716, Expected=804.0000
# Month=2, Predicted=807.4976, Expected=756.0000
# Month=3, Predicted=727.8271, Expected=860.0000
# Month=4, Predicted=874.9680, Expected=878.0000
# Month=5, Predicted=873.8917, Expected=942.0000
# Month=6, Predicted=947.9256, Expected=913.0000
# Month=7, Predicted=894.6813, Expected=869.0000
# Month=8, Predicted=843.1520, Expected=834.0000
# Month=9, Predicted=812.8954, Expected=790.0000
# Month=10, Predicted=764.1520, Expected=800.0000
# Month=11, Predicted=794.0600, Expected=763.0000
# Month=12, Predicted=740.9002, Expected=800.0000
# Month=13, Predicted=800.0244, Expected=826.0000
# Month=14, Predicted=823.6498, Expected=799.0000
# Month=15, Predicted=781.5449, Expected=890.0000
# Month=16, Predicted=902.0047, Expected=900.0000
# Month=17, Predicted=894.0600, Expected=961.0000
# Month=18, Predicted=966.2600, Expected=935.0000
# Month=19, Predicted=917.9648, Expected=894.0000
# Month=20, Predicted=869.8088, Expected=855.0000
# Month=21, Predicted=831.8714, Expected=809.0000
# Month=22, Predicted=782.0059, Expected=810.0000
# Month=23, Predicted=801.8343, Expected=766.0000
# Month=24, Predicted=740.1520, Expected=805.0000
# Month=25, Predicted=805.4557, Expected=821.0000
# Month=26, Predicted=816.4428, Expected=773.0000
# Month=27, Predicted=744.8271, Expected=883.0000
# Month=28, Predicted=899.3393, Expected=898.0000
# Month=29, Predicted=893.2164, Expected=957.0000
# Month=30, Predicted=961.8177, Expected=924.0000
# Month=31, Predicted=903.8571, Expected=881.0000
# Month=32, Predicted=855.7126, Expected=837.0000
# Month=33, Predicted=811.1520, Expected=784.0000
# Month=34, Predicted=752.7414, Expected=791.0000
# Month=35, Predicted=784.3422, Expected=760.0000
# Month=36, Predicted=740.7855, Expected=802.0000
# Month=37, Predicted=803.1037, Expected=828.0000
# Month=38, Predicted=825.6498, Expected=778.0000
# Month=39, Predicted=748.6162, Expected=889.0000
# Month=40, Predicted=905.5680, Expected=902.0000
# Month=41, Predicted=896.7590, Expected=969.0000
# Month=42, Predicted=975.5935, Expected=947.0000
# Month=43, Predicted=931.5683, Expected=908.0000
# Month=44, Predicted=884.8714, Expected=867.0000
# Month=45, Predicted=842.8088, Expected=815.0000
# Month=46, Predicted=784.3740, Expected=812.0000
# Month=47, Predicted=802.7617, Expected=773.0000
# Month=48, Predicted=749.8714, Expected=813.0000
# Month=49, Predicted=813.6716, Expected=834.0000
# Month=50, Predicted=830.5569, Expected=782.0000
# Month=51, Predicted=751.3740, Expected=892.0000
# Month=52, Predicted=908.3393, Expected=903.0000
# Month=53, Predicted=897.2949, Expected=966.0000
# Month=54, Predicted=971.7035, Expected=937.0000
# Month=55, Predicted=918.6813, Expected=896.0000
# Month=56, Predicted=871.8088, Expected=858.0000
# Month=57, Predicted=835.3900, Expected=817.0000
# Month=58, Predicted=792.8088, Expected=827.0000
# Month=59, Predicted=821.0600, Expected=797.0000
# Month=60, Predicted=778.2375, Expected=843.0000
# Run 16 — RMSE: 52.817853, MSE: 2789.725584, NMSE: 0.0099548506, Time: 76.8s
#
# ===== RUN 17/30 =====
# ...
# Month=42, Predicted=975.0145, Expected=947.0000
# Month=43, Predicted=935.4784, Expected=908.0000
# Month=44, Predicted=886.6317, Expected=867.0000
# Month=45, Predicted=844.0424, Expected=815.0000
# Month=46, Predicted=781.7092, Expected=812.0000
# Month=47, Predicted=805.7357, Expected=773.0000
# Month=48, Predicted=751.6317, Expected=813.0000
# Month=49, Predicted=814.1206, Expected=834.0000
# Month=50, Predicted=831.7787, Expected=782.0000
# Month=51, Predicted=748.7092, Expected=892.0000
# Month=52, Predicted=905.8726, Expected=903.0000
# Month=53, Predicted=899.1293, Expected=966.0000
# Month=54, Predicted=971.2919, Expected=937.0000
# Month=55, Predicted=922.1835, Expected=896.0000
# Month=56, Predicted=873.0424, Expected=858.0000
# Month=57, Predicted=837.3913, Expected=817.0000
# Month=58, Predicted=794.0424, Expected=827.0000
# Month=59, Predicted=822.9667, Expected=797.0000
# Month=60, Predicted=781.6304, Expected=843.0000
# Run 25 — RMSE: 53.005811, MSE: 2809.616031, NMSE: 0.0100474553, Time: 38.4s
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=749.3862, Expected=804.0000
# Month=2, Predicted=805.1517, Expected=756.0000
# Month=3, Predicted=731.6937, Expected=860.0000
# Month=4, Predicted=875.3122, Expected=878.0000
# Month=5, Predicted=872.8870, Expected=942.0000
# Month=6, Predicted=945.8161, Expected=913.0000
# Month=7, Predicted=902.5075, Expected=869.0000
# Month=8, Predicted=848.7530, Expected=834.0000
# Month=9, Predicted=820.6323, Expected=790.0000
# Month=10, Predicted=769.7530, Expected=800.0000
# Month=11, Predicted=794.0612, Expected=763.0000
# Month=12, Predicted=748.3802, Expected=800.0000
# Month=13, Predicted=797.8148, Expected=826.0000
# Month=14, Predicted=821.9639, Expected=799.0000
# Month=15, Predicted=789.2031, Expected=890.0000
# Month=16, Predicted=901.3351, Expected=900.0000
# Month=17, Predicted=894.0612, Expected=961.0000
# Month=18, Predicted=964.0628, Expected=935.0000
# Month=19, Predicted=925.5080, Expected=894.0000
# Month=20, Predicted=876.4024, Expected=855.0000
# Month=21, Predicted=838.9710, Expected=809.0000
# Month=22, Predicted=786.7954, Expected=810.0000
# Month=23, Predicted=803.4218, Expected=766.0000
# Month=24, Predicted=745.7530, Expected=805.0000
# Month=25, Predicted=803.1928, Expected=821.0000
# Month=26, Predicted=815.6565, Expected=773.0000
# Month=27, Predicted=748.6937, Expected=883.0000
# Month=28, Predicted=900.1991, Expected=898.0000
# Month=29, Predicted=892.5472, Expected=957.0000
# Month=30, Predicted=959.5713, Expected=924.0000
# Month=31, Predicted=911.7323, Expected=881.0000
# Month=32, Predicted=861.6751, Expected=837.0000
# Month=33, Predicted=816.7530, Expected=784.0000
# Month=34, Predicted=753.8834, Expected=791.0000
# Month=35, Predicted=784.8167, Expected=760.0000
# Month=36, Predicted=748.6875, Expected=802.0000
# Month=37, Predicted=800.7818, Expected=828.0000
# Month=38, Predicted=823.9639, Expected=778.0000
# Month=39, Predicted=751.4585, Expected=889.0000
# Month=40, Predicted=906.5160, Expected=902.0000
# Month=41, Predicted=896.3408, Expected=969.0000
# Month=42, Predicted=973.5881, Expected=947.0000
# Month=43, Predicted=938.4785, Expected=908.0000
# Month=44, Predicted=891.9710, Expected=867.0000
# Month=45, Predicted=849.4024, Expected=815.0000
# Month=46, Predicted=786.1024, Expected=812.0000
# Month=47, Predicted=805.2091, Expected=773.0000
# Month=48, Predicted=756.9710, Expected=813.0000
# Month=49, Predicted=811.3862, Expected=834.0000
# Month=50, Predicted=829.2623, Expected=782.0000
# Month=51, Predicted=753.1024, Expected=892.0000
# Month=52, Predicted=909.1991, Expected=903.0000
# Month=53, Predicted=897.1504, Expected=966.0000
# Month=54, Predicted=969.5629, Expected=937.0000
# Month=55, Predicted=926.5075, Expected=896.0000
# Month=56, Predicted=878.4024, Expected=858.0000
# Month=57, Predicted=842.6954, Expected=817.0000
# Month=58, Predicted=799.4024, Expected=827.0000
# Month=59, Predicted=821.0612, Expected=797.0000
# Month=60, Predicted=786.1138, Expected=843.0000
# Run 26 — RMSE: 51.967089, MSE: 2700.578387, NMSE: 0.0099705215, Time: 39.6s
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=754.0802, Expected=804.0000
# Month=2, Predicted=809.4008, Expected=756.0000
# Month=3, Predicted=728.0711, Expected=860.0000
# Month=4, Predicted=875.6798, Expected=878.0000
# Month=5, Predicted=877.7181, Expected=942.0000
# Month=6, Predicted=949.5226, Expected=913.0000
# Month=7, Predicted=899.0703, Expected=869.0000
# Month=8, Predicted=844.4836, Expected=834.0000
# Month=9, Predicted=816.2786, Expected=790.0000
# Month=10, Predicted=765.4836, Expected=800.0000
# Month=11, Predicted=798.5269, Expected=763.0000
# Month=12, Predicted=743.8808, Expected=800.0000
# Month=13, Predicted=802.5821, Expected=826.0000
# Month=14, Predicted=826.8778, Expected=799.0000
# Month=15, Predicted=786.1995, Expected=890.0000
# Month=16, Predicted=902.9996, Expected=900.0000
# Month=17, Predicted=898.5269, Expected=961.0000
# Month=18, Predicted=967.9334, Expected=935.0000
# Month=19, Predicted=922.7390, Expected=894.0000
# Month=20, Predicted=871.8903, Expected=855.0000
# Month=21, Predicted=834.4175, Expected=809.0000
# Month=22, Predicted=782.8054, Expected=810.0000
# Month=23, Predicted=806.9546, Expected=766.0000
# Month=24, Predicted=741.4836, Expected=805.0000
# Month=25, Predicted=807.9125, Expected=821.0000
# Month=26, Predicted=820.4282, Expected=773.0000
# Month=27, Predicted=745.0711, Expected=883.0000
# Month=28, Predicted=899.9200, Expected=898.0000
# Month=29, Predicted=897.2821, Expected=957.0000
# Month=30, Predicted=963.5445, Expected=924.0000
# Month=31, Predicted=907.6099, Expected=881.0000
# Month=32, Predicted=857.3009, Expected=837.0000
# Month=33, Predicted=812.4836, Expected=784.0000
# Month=34, Predicted=751.5102, Expected=791.0000
# Month=35, Predicted=789.0425, Expected=760.0000
# Month=36, Predicted=744.8739, Expected=802.0000
# Month=37, Predicted=805.4206, Expected=828.0000
# Month=38, Predicted=828.8778, Expected=778.0000
# Month=39, Predicted=748.2838, Expected=889.0000
# Month=40, Predicted=906.1269, Expected=902.0000
# Month=41, Predicted=900.9858, Expected=969.0000
# Month=42, Predicted=977.1178, Expected=947.0000
# Month=43, Predicted=936.7329, Expected=908.0000
# Month=44, Predicted=887.4175, Expected=867.0000
# Month=45, Predicted=844.8903, Expected=815.0000
# Month=46, Predicted=783.4465, Expected=812.0000
# Month=47, Predicted=808.1037, Expected=773.0000
# Month=48, Predicted=752.4175, Expected=813.0000
# Month=49, Predicted=816.0802, Expected=834.0000
# Month=50, Predicted=834.1504, Expected=782.0000
# Month=51, Predicted=750.4465, Expected=892.0000
# Month=52, Predicted=908.9200, Expected=903.0000
# Month=53, Predicted=901.6823, Expected=966.0000
# Month=54, Predicted=973.3255, Expected=937.0000
# Month=55, Predicted=923.0703, Expected=896.0000
# Month=56, Predicted=873.8903, Expected=858.0000
# Month=57, Predicted=838.1572, Expected=817.0000
# Month=58, Predicted=794.8903, Expected=827.0000
# Month=59, Predicted=825.5269, Expected=797.0000
# Month=60, Predicted=782.4805, Expected=843.0000
# Run 27 — RMSE: 52.729273, MSE: 2780.376277, NMSE: 0.0099655044, Time: 33.2s
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=749.5425, Expected=804.0000
# Month=2, Predicted=806.0880, Expected=756.0000
# Month=3, Predicted=732.0329, Expected=860.0000
# Month=4, Predicted=877.9606, Expected=878.0000
# Month=5, Predicted=872.0971, Expected=942.0000
# Month=6, Predicted=947.3541, Expected=913.0000
# Month=7, Predicted=908.7095, Expected=869.0000
# Month=8, Predicted=852.0418, Expected=834.0000
# Month=9, Predicted=827.3291, Expected=790.0000
# Month=10, Predicted=773.0418, Expected=800.0000
# Month=11, Predicted=793.2676, Expected=763.0000
# Month=12, Predicted=754.7884, Expected=800.0000
# Month=13, Predicted=797.7973, Expected=826.0000
# Month=14, Predicted=821.4036, Expected=799.0000
# Month=15, Predicted=794.9226, Expected=890.0000
# Month=16, Predicted=903.8091, Expected=900.0000
# Month=17, Predicted=893.2676, Expected=961.0000
# Month=18, Predicted=965.4468, Expected=935.0000
# Month=19, Predicted=930.9517, Expected=894.0000
# Month=20, Predicted=881.4155, Expected=855.0000
# Month=21, Predicted=844.8189, Expected=809.0000
# Month=22, Predicted=788.6791, Expected=810.0000
# Month=23, Predicted=803.0289, Expected=766.0000
# Month=24, Predicted=749.0418, Expected=805.0000
# Month=25, Predicted=803.2904, Expected=821.0000
# Month=26, Predicted=814.8410, Expected=773.0000
# Month=27, Predicted=749.0329, Expected=883.0000
# Month=28, Predicted=902.8812, Expected=898.0000
# Month=29, Predicted=891.7247, Expected=957.0000
# Month=30, Predicted=960.8481, Expected=924.0000
# Month=31, Predicted=918.4668, Expected=881.0000
# Month=32, Predicted=865.5959, Expected=837.0000
# Month=33, Predicted=820.0418, Expected=784.0000
# Month=34, Predicted=750.1529, Expected=791.0000
# Month=35, Predicted=784.1001, Expected=760.0000
# Month=36, Predicted=755.2430, Expected=802.0000
# Month=37, Predicted=801.0570, Expected=828.0000
# Month=38, Predicted=823.4036, Expected=778.0000
# Month=39, Predicted=750.1762, Expected=889.0000
# Month=40, Predicted=909.2014, Expected=902.0000
# Month=41, Predicted=895.5163, Expected=969.0000
# Month=42, Predicted=975.2709, Expected=947.0000
# Month=43, Predicted=942.7032, Expected=908.0000
# Month=44, Predicted=897.8189, Expected=867.0000
# Month=45, Predicted=854.4155, Expected=815.0000
# Month=46, Predicted=783.1815, Expected=812.0000
# Month=47, Predicted=805.1899, Expected=773.0000
# Month=48, Predicted=762.8189, Expected=813.0000
# Month=49, Predicted=811.5425, Expected=834.0000
# Month=50, Predicted=828.5366, Expected=782.0000
# Month=51, Predicted=750.1815, Expected=892.0000
# Month=52, Predicted=911.8812, Expected=903.0000
# Month=53, Predicted=896.3417, Expected=966.0000
# Month=54, Predicted=971.0505, Expected=937.0000
# Month=55, Predicted=932.7095, Expected=896.0000
# Month=56, Predicted=883.4155, Expected=858.0000
# Month=57, Predicted=848.8580, Expected=817.0000
# Month=58, Predicted=804.4155, Expected=827.0000
# Month=59, Predicted=820.2676, Expected=797.0000
# Month=60, Predicted=792.5115, Expected=843.0000
# Run 28 — RMSE: 52.371090, MSE: 2742.731075, NMSE: 0.0100377196, Time: 29.3s
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=750.3242, Expected=804.0000
# Month=2, Predicted=806.1539, Expected=756.0000
# Month=3, Predicted=731.7480, Expected=860.0000
# Month=4, Predicted=877.2533, Expected=878.0000
# Month=5, Predicted=873.8691, Expected=942.0000
# Month=6, Predicted=946.9363, Expected=913.0000
# Month=7, Predicted=903.8577, Expected=869.0000
# Month=8, Predicted=849.2813, Expected=834.0000
# Month=9, Predicted=821.7713, Expected=790.0000
# Month=10, Predicted=770.2813, Expected=800.0000
# Month=11, Predicted=795.1292, Expected=763.0000
# Month=12, Predicted=749.4215, Expected=800.0000
# Month=13, Predicted=798.7475, Expected=826.0000
# Month=14, Predicted=822.9049, Expected=799.0000
# Month=15, Predicted=790.6014, Expected=890.0000
# Month=16, Predicted=902.9774, Expected=900.0000
# Month=17, Predicted=895.1292, Expected=961.0000
# Month=18, Predicted=965.1444, Expected=935.0000
# Month=19, Predicted=926.9266, Expected=894.0000
# Month=20, Predicted=877.1899, Expected=855.0000
# Month=21, Predicted=839.8964, Expected=809.0000
# Month=22, Predicted=787.1077, Expected=810.0000
# Month=23, Predicted=804.6449, Expected=766.0000
# Month=24, Predicted=746.2813, Expected=805.0000
# Month=25, Predicted=804.1286, Expected=821.0000
# Month=26, Predicted=816.6554, Expected=773.0000
# Month=27, Predicted=748.7480, Expected=883.0000
# Month=28, Predicted=902.2707, Expected=898.0000
# Month=29, Predicted=893.5556, Expected=957.0000
# Month=30, Predicted=960.6300, Expected=924.0000
# Month=31, Predicted=912.9540, Expected=881.0000
# Month=32, Predicted=862.2977, Expected=837.0000
# Month=33, Predicted=817.2813, Expected=784.0000
# Month=34, Predicted=753.0680, Expected=791.0000
# Month=35, Predicted=785.9303, Expected=760.0000
# Month=36, Predicted=749.9792, Expected=802.0000
# Month=37, Predicted=801.7251, Expected=828.0000
# Month=38, Predicted=824.9049, Expected=778.0000
# Month=39, Predicted=751.2064, Expected=889.0000
# Month=40, Predicted=908.6085, Expected=902.0000
# Month=41, Predicted=897.3706, Expected=969.0000
# Month=42, Predicted=974.7515, Expected=947.0000
# Month=43, Predicted=939.9536, Expected=908.0000
# Month=44, Predicted=892.8964, Expected=867.0000
# Month=45, Predicted=850.1899, Expected=815.0000
# Month=46, Predicted=785.4895, Expected=812.0000
# Month=47, Predicted=806.5123, Expected=773.0000
# Month=48, Predicted=757.8964, Expected=813.0000
# Month=49, Predicted=812.3242, Expected=834.0000
# Month=50, Predicted=830.2245, Expected=782.0000
# Month=51, Predicted=752.4895, Expected=892.0000
# Month=52, Predicted=911.2707, Expected=903.0000
# Month=53, Predicted=898.2049, Expected=966.0000
# Month=54, Predicted=970.6697, Expected=937.0000
# Month=55, Predicted=927.8577, Expected=896.0000
# Month=56, Predicted=879.1899, Expected=858.0000
# Month=57, Predicted=843.6813, Expected=817.0000
# Month=58, Predicted=800.1899, Expected=827.0000
# Month=59, Predicted=822.1292, Expected=797.0000
# Month=60, Predicted=787.4361, Expected=843.0000
# Run 29 — RMSE: 52.039729, MSE: 2708.133360, NMSE: 0.0099488203, Time: 31.9s
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=749.3566, Expected=804.0000
# Month=2, Predicted=805.2108, Expected=756.0000
# Month=3, Predicted=727.5107, Expected=860.0000
# Month=4, Predicted=873.5062, Expected=878.0000
# Month=5, Predicted=872.2733, Expected=942.0000
# Month=6, Predicted=945.7477, Expected=913.0000
# Month=7, Predicted=905.3851, Expected=869.0000
# Month=8, Predicted=847.3236, Expected=834.0000
# Month=9, Predicted=822.8413, Expected=790.0000
# Month=10, Predicted=768.3236, Expected=800.0000
# Month=11, Predicted=793.3182, Expected=763.0000
# Month=12, Predicted=750.0766, Expected=800.0000
# Month=13, Predicted=797.7293, Expected=826.0000
# Month=14, Predicted=821.5870, Expected=799.0000
# Month=15, Predicted=792.0617, Expected=890.0000
# Month=16, Predicted=900.2648, Expected=900.0000
# Month=17, Predicted=893.3182, Expected=961.0000
# Month=18, Predicted=964.0472, Expected=935.0000
# Month=19, Predicted=928.3210, Expected=894.0000
# Month=20, Predicted=876.5748, Expected=855.0000
# Month=21, Predicted=839.9910, Expected=809.0000
# Month=22, Predicted=784.0766, Expected=810.0000
# Month=23, Predicted=802.8999, Expected=766.0000
# Month=24, Predicted=744.3236, Expected=805.0000
# Month=25, Predicted=803.1459, Expected=821.0000
# Month=26, Predicted=814.9940, Expected=773.0000
# Month=27, Predicted=744.5107, Expected=883.0000
# Month=28, Predicted=898.0195, Expected=898.0000
# Month=29, Predicted=891.8636, Expected=957.0000
# Month=30, Predicted=959.5836, Expected=924.0000
# Month=31, Predicted=914.3004, Expected=881.0000
# Month=32, Predicted=860.8241, Expected=837.0000
# Month=33, Predicted=815.3236, Expected=784.0000
# Month=34, Predicted=745.3158, Expected=791.0000
# Month=35, Predicted=784.0904, Expected=760.0000
# Month=36, Predicted=751.4737, Expected=802.0000
# Month=37, Predicted=800.7824, Expected=828.0000
# Month=38, Predicted=823.5870, Expected=778.0000
# Month=39, Predicted=745.6417, Expected=889.0000
# Month=40, Predicted=904.2726, Expected=902.0000
# Month=41, Predicted=895.6229, Expected=969.0000
# Month=42, Predicted=973.4538, Expected=947.0000
# Month=43, Predicted=940.9199, Expected=908.0000
# Month=44, Predicted=892.9910, Expected=867.0000
# Month=45, Predicted=849.5748, Expected=815.0000
# Month=46, Predicted=778.4902, Expected=812.0000
# Month=47, Predicted=804.9805, Expected=773.0000
# Month=48, Predicted=757.9910, Expected=813.0000
# Month=49, Predicted=811.3566, Expected=834.0000
# Month=50, Predicted=828.7329, Expected=782.0000
# Month=51, Predicted=745.4902, Expected=892.0000
# Month=52, Predicted=907.0195, Expected=903.0000
# Month=53, Predicted=896.4117, Expected=966.0000
# Month=54, Predicted=969.5136, Expected=937.0000
# Month=55, Predicted=929.3851, Expected=896.0000
# Month=56, Predicted=878.5748, Expected=858.0000
# Month=57, Predicted=844.0746, Expected=817.0000
# Month=58, Predicted=799.5748, Expected=827.0000
# Month=59, Predicted=820.3182, Expected=797.0000
# Month=60, Predicted=788.9605, Expected=843.0000
# Run 30 — RMSE: 53.127927, MSE: 2822.576630, NMSE: 0.0101371072, Time: 39.2s

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — FEDformer on Monthly Milk Production (30 runs) =====
# RMSE: 52.467286 ± 0.653822
# MSE:  2753.243552 ± 68.636367
# NMSE: 0.0100657867 ± 0.0000789764
# Avg training time: 37.8s ± 9.7s
#
# Best run: 11
#   RMSE: 51.365354
#   MSE:  2638.399634
#   NMSE: 0.0100060267

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('FEDformer — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('FEDformer — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 51.365354
# MSE:  2638.399634
# NMSE: 0.0100060267

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'FEDformer_Milk_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')
# Out:
# Predictions saved to FEDformer_Milk_predictions.csv

# %% [markdown]
# ## Observations
#
# ### FEDformer on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
